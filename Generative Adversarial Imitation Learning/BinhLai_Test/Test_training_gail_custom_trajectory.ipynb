# %% [markdown]
# # Train an Agent using Generative Adversarial Imitation Learning
#
# The idea of generative adversarial imitation learning is to train a discriminator network to distinguish between expert trajectories and learner trajectories.
# The learner is trained using a traditional reinforcement learning algorithm such as PPO and is rewarded for trajectories that make the discriminator think that it was an expert trajectory.

# %% [markdown]
# ### Load data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
import math
import json

import onnx
from onnx import load
import onnxruntime
from onnxruntime.training import artifacts

from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from imitation.data.types import TrajectoryWithRew

from stable_baselines3.common.logger import configure
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

import torch as th
import torch.nn as nn
import torch.nn.functional as F

# %matplotlib inline
# from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import data_split
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import itertools
# Out:
# 2024-04-17 15:12:58,785 matplotlib.pyplot [DEBUG] - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-04-17 15:12:58,789 matplotlib.pyplot [DEBUG] - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-04-17 15:12:58,797 matplotlib.pyplot [DEBUG] - Loaded backend agg version v2.2.

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
from datetime import datetime
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

TRAIN_START_DATE = '2000-01-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

# Load price data from csv file
# tic_dir = './' + DATA_SAVE_DIR + '/sp500_price_daily.csv'
# df = pd.read_csv(tic_dir,index_col=0)

# %%
processed_full = pd.read_csv('./' + DATA_SAVE_DIR + '/dow30_ready_with_filter_data_daily.csv',index_col=0)
processed_full['date'] = pd.to_datetime(processed_full.date,format='mixed')
processed_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99956 entries, 0 to 99955
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   99956 non-null  datetime64[ns]
#  1   tic                    99956 non-null  object
#  2   close                  99956 non-null  float64
#  3   gross_profit_margin    99956 non-null  float64
#  4   sga_ratio              99956 non-null  float64
#  5   dep_ratio              99956 non-null  float64
#  6   ebit_on_int            99956 non-null  float64
#  7   profit_margin          99956 non-null  float64
#  8   count_positive_profit  99956 non-null  float64
#  9   csti_on_liabilities    99956 non-null  float64
#  10  inventory_on_ebit      99956 non-null  float64
#  11  receivable_on_rev      99956 non-null  float64
#  12  roa                    99956 non-null  float64
#  13  roe                    99956 non-null  float64
#  14  liabilities_on_equity  99956 non-null  float64
#  15  debt_on_min_ebit       99956 non-null  float64
#  16  capital_cost_on_ebit   99956 non-null  float64
#  17  eps_on_mp              99956 non-null  float64
#  18  dividend_on_mp         99956 non-null  float64
#  19  mp_on_bv               99956 non-null  float64
#  20  trend_gross_margin     99956 non-null  float64
#  21  trend_profit_margin    99956 non-null  float64
#  22  fluc_sga               99956 non-null  float64
#  23  fluc_dep_ratio         99956 non-null  float64
#  24  fluc_inv_on_ebit       99956 non-null  float64
#  25  fluc_rec_on_rev        99956 non-null  float64
# dtypes: datetime64[ns](1), float64(24), object(1)
# memory usage: 20.6+ MB

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
test_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
train_data = train_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)
# Check the length of the two datasets
print(len(train_data))
print(len(test_data))
# Out:
# 75776
# 24180

# %% [markdown]
# ### Set up environment

# %%
import gymnasium as gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

from gymnasium import spaces
from gymnasium.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv
from portfolio import portfolio

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        stop_loss,
        hold_period,
        make_plots=False,
        print_verbosity=10,
        row=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        # self.row = row
        self.df = df
        # self.stock_dim = stock_dim
        self.hmax = hmax
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list        
        self.initial_amount = initial_amount
        self.hold_period = hold_period
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.stop_loss = stop_loss # the game stops when the asset loses more than stop_loss percent
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.state_space,))
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        # self.turbulence_threshold = turbulence_threshold
        # self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        self.tic_list = self.df.tic.unique()
        self.original_df = self.df.copy()
        self.row = 0
        
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _buy_stock(self, action):
        def _do_buy():
            if self.data.close > 0: # Buy only if the price is > 0 (no missing data in this particular date)
                buy_num_shares, buy_fee = self.portfolio.add_buy_stock(self.data.tic,self.data.close,action)
                # print(f'Buy amount: {buy_num_shares}')
                self.cost += buy_fee
                if buy_num_shares == 0:
                    self.reward = -5 * self.initial_amount * self.punishment_rate * self.reward_scaling
            else:
                buy_num_shares = 0

            return buy_num_shares

        buy_num_shares = _do_buy()
        return buy_num_shares
    
    def _sell_stock(self, action):
        def _do_sell_normal():
            if self.data.close > 0: # Sell only if the price is > 0 (no missing data in this particular date)
                sell_amount,surplus,sell_fee = self.portfolio.minus_sell_stock(self.data.tic,self.data.close,action)
                self.cost += sell_fee
                # print(f'Sell amount: {sell_num_shares}')
                if sell_amount == 0:
                    self.reward = -5 * self.initial_amount * self.punishment_rate * self.reward_scaling
                else:
                    self.reward += (surplus - sell_amount*self.data.close*self.sell_cost_pct) * self.reward_scaling
                    self.win_trade += 1 if surplus > 0 else 0
                    self.trades += 1
            else:
                sell_amount = 0

            return sell_amount

        sell_amount = _do_sell_normal()
        return sell_amount

    def step(self, actions):

        self.terminal = (self.row >= len(self.df.index.unique()) - 1) | (self.portfolio.get_asset_value() < self.initial_amount*(1-self.stop_loss))
        # print(f'Step {self.row}, action: {actions}, current asset: {current_total_asset}, stop loss: {self.initial_amount*(1-self.stop_loss)}, Trade: {self.trades}')

        # Reset reward to zero
        self.reward = 0
        
        # --> IN CASE THE STEP IS A TERMINATED STEP
        if self.terminal: 
            
            # Summary the training performance after an episode
            end_total_asset = self.portfolio.get_asset_value()
            tot_reward = end_total_asset - self.initial_amount * (self.df.iloc[-1].close / self.df.iloc[0].close) # compare with buy-and-hold strategy
            # tot_reward = end_total_asset - self.initial_amount # compare with initial capital

            # Show at each episode
            print(f"Episode: {self.episode}, com: {self.df.iloc[0].tic}, win trade: {self.win_trade}/{self.trades}, Total reward: {self.accumulated_reward}")

            # Print out training results after a certain amount of episodes
            if self.episode % self.print_verbosity == 0:
                print(f"Current company: {self.df.iloc[0].tic}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"surplus from buy-and-hold: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                # if df_total_value["daily_return"].std() != 0:
                #     print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")
            
            truncated = False  # we do not limit the number of steps here
            # Optionally we can pass additional info, we are not using that for now
            info = {}


            return (
                np.array(self.state).astype(np.float32),
                self.reward,
                self.terminal,
                truncated,
                info,
            )

        # --> IN A NORMAL STEP
        else: 

            # Act according to actions
            action = actions[0]
                
            if action > 0:
                self._buy_stock(action)
            elif action < 0:
                self._sell_stock(action)

            self.current_actions = actions
            self.actions_memory.append(actions)

            # Set a punishment at each step to push the agent decide an action
            self.reward += -1 * self.initial_amount * self.punishment_rate * self.reward_scaling
            self.accumulated_reward += self.reward

            # Update selected row in the dataset based on state: s -> s+1
            self.row += 1
            self.data = self.df.loc[self.row]
            self.state = self._update_state()

            end_total_asset = self.portfolio.get_asset_value()

            # Update asset memory
            self.current_asset = end_total_asset
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            
            self.rewards_memory.append(self.reward)

        truncated = False  # we do not limit the number of steps here
        # Optionally we can pass additional info, we are not using that for now
        info = {}
        
        # return self.state, self.reward, self.terminal, {}
    
        return (
            np.array(self.state).astype(np.float32),
            self.reward,
            self.terminal,
            truncated,
            info,
        )

    def reset(self, seed=None, options=None):
        # initiate state
        self.state = self._initiate_state()

        # Reset asset_memory
        self.asset_memory = [self.initial_amount]

        # Reset support variables
        self.cost = 0
        self.trades = 0
        self.win_trade = 0
        self.terminal = False
        self.accumulated_reward = 0
        self.block_remain = 0
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        self.episode += 1

        return np.array(self.state).astype(np.float32), {}

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        
        # Reset portfolio & previous_portfolio
        self.portfolio = portfolio(initial_amount=self.initial_amount,hold_period=self.hold_period,
                                   buy_cost_pct=self.buy_cost_pct,sell_cost_pct=self.sell_cost_pct)

        # Select a random ticker from df
        self.df = self.original_df[self.original_df.tic == random.choice(self.tic_list)].reset_index(drop=True)
        self.punishment_rate = 1/(len(self.df)*10)
        
        # Reset data
        self.row = 0
        self.data = self.df.loc[self.row]
        
         # Reset state
        state = ([self.portfolio.get_remain_capital()] + [self.data.close] 
                    + [self.portfolio.get_stock_weight(self.data.tic)] 
                    +[self.portfolio.get_stock_profit(self.data.tic)]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))
        
        return state

    def _update_state(self):

        self.portfolio.update_new_state(self.data.tic,self.data.close)
        state = ([self.portfolio.get_remain_capital()] + [self.data.close] 
                    + [self.portfolio.get_stock_amount(self.data.tic)]
                    +[self.portfolio.get_stock_profit(self.data.tic)]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))

        return state

    def _get_date(self):
        return self.row

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        df_account_value = pd.DataFrame({"date": date_list, "account_value": asset_list})
        return df_account_value

    def save_action_memory(self):
        
        date_list = self.date_memory[:-1]
        action_list = self.actions_memory
        df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %% [markdown]
# Full feature stone

# %%
# features = [ 'gross_profit_margin', 'sga_ratio', 'ebit_on_int', 'profit_margin', 'count_positive_profit',
#        'csti_on_liabilities', 'roa', 'roe', 'liabilities_on_equity', 'debt_on_min_ebit',
#        'capital_cost_on_ebit', 'eps_on_mp', 'dividend_on_mp', 'mp_on_bv',
#        'trend_gross_margin', 'trend_profit_margin', 'fluc_sga', 'fluc_dep_ratio', 'fluc_inv_on_ebit', 'fluc_rec_on_rev']
# # ratio_list = train_data.columns.drop(['date','tic','close'])

# action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
# state_space = 4 + len(features)
# print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 24

# %% [markdown]
# Basic stone with 4 features

# %%
features = [ 'gross_profit_margin', 'sga_ratio', 'ebit_on_int', 'profit_margin'] # just select random 4 features to set input's sharp
action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
state_space = 4 + len(features) # 4 components from the portfolio state and 4 model features
print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 8

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "tech_indicator_list": features, 
    "state_space": state_space, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.8,
    "print_verbosity":4,
    "hold_period": 5
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = test_data, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()

# %% [markdown]
# ### Build blank models

# %%
policy_kwargs = dict(net_arch=dict(pi=[64, 32, 16], vf=[64, 32, 16]))
SEED = 42

learner = PPO(
    env=env_train,
    policy=MlpPolicy,
    batch_size=2048,
    ent_coef=0.01,
    learning_rate=0.00025,
    gamma=0.95,
    n_epochs=5,
    clip_range=0.1,
    policy_kwargs=policy_kwargs,
    # seed=SEED,
)

# %% [markdown]
# #### Save the model as onnx format and configurate it

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(learner.policy)
observation_size = learner.observation_space.shape
dummy_input = th.randn(1, *observation_size)

th.onnx.export(
    onnx_policy,
    dummy_input,
    f"./{TRAINED_MODEL_DIR}/basic_stone_{observation_size[0]-4}_features.onnx",
    opset_version=17,
    input_names=["input"],
)

# %%
model_onnx = onnx.load(f"./{TRAINED_MODEL_DIR}/basic_stone_{observation_size[0]-4}_features.onnx")

# %%
m1 = model_onnx.metadata_props.add()
m1.key = 'feature_amount'
m1.value = json.dumps(observation_size[0]-4)

# %%
onnx.save(model_onnx, f"./{TRAINED_MODEL_DIR}/basic_stone_{observation_size[0]-4}_features.onnx")

# %% [markdown]
# ## Test customizing trajectory

# %%
def generate_random_trajectory(number_of_step):

    def generate_random_obs():
        random_row = processed_full.iloc[np.random.randint(len(processed_full))]
        random_port = np.random.uniform(0,env_kwargs["initial_amount"])
        random_amount = np.random.randint(1000)
        random_profit = np.random.rand(1)
        state = ([random_port] + [random_row.close] + [random_amount] + [random_profit[0]]
                    + sum([[random_row[tech]] for tech in features], []))
    
        return state

    # Generate random observations
    random_obs = np.array([generate_random_obs() for i in range(0,number_of_step + 1)])
    
    # Generate random actions
    random_acts = np.array([np.random.rand(1)*2-1 for i in range(0,number_of_step)])
    
    # Generate random rewards
    random_rews = np.random.rand(number_of_step)*10
    
    # And put all these components into the same trajectory
    random_trajectory = TrajectoryWithRew(acts=random_acts, obs=random_obs,rews=random_rews,terminal=True,infos=None)
    return random_trajectory

# %%
random_rollouts = []
number_of_step = 10
number_of_episode = 1000
for i in range(0,number_of_episode):
    random_rollouts.append(generate_random_trajectory(number_of_step))

# %% [markdown]
# Now we are ready to set up our GAIL trainer.
# Note, that the `reward_net` is actually the network of the discriminator.
# We evaluate the learner before and after training so we can see if it made any progress.
#
# First we construct a GAIL trainer ...

# %% [markdown]
# #### Trying to load PPO model from Onnx model to continue training from the training_model

# %%
with open("TestOnnx", "rb") as f:
    content = f.read()
trained_model = onnx.load_model_from_string(content)

# %%
# This is the model file you prepared
path_to_forward_only_onnx_model = 'test_model.onnx'

# Load the forward-only ONNX model
model = onnx.load(path_to_forward_only_onnx_model)

# Extract model's parameters
b = [param.name for param in model.graph.initializer]

# We choose to make all layers trainable
trainable_layers = ['fc', 'onnx']
requires_grad = [param for param in all_params if any(layer in param for layer in trainable_layers)]
frozen_params = [param for param in all_params if param not in requires_grad]
print(requires_grad, frozen_params)

# Check the output name of the model
print(model.graph.output)
# Out:
# [] ['policy.mlp_extractor.policy_net.0.weight', 'policy.mlp_extractor.policy_net.0.bias', 'policy.mlp_extractor.policy_net.2.weight', 'policy.mlp_extractor.policy_net.2.bias', 'policy.mlp_extractor.value_net.0.weight', 'policy.mlp_extractor.value_net.0.bias', 'policy.mlp_extractor.value_net.2.weight', 'policy.mlp_extractor.value_net.2.bias', 'policy.action_net.weight', 'policy.action_net.bias', 'policy.value_net.weight', 'policy.value_net.bias']
# [name: "56"
# type {
#   tensor_type {
#     elem_type: 7
#     shape {
#       dim {
#         dim_value: 1
#       }
#     }
#   }
# }
# , name: "24"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 1
#       }
#     }
#   }
# }
# , name: "54"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#     }
#   }
# }
# ]

# %%
# create this directory if it does not exist 
path_to_output_artifact_directory = 'training_artifacts'
artifacts.generate_artifacts(model,
                             requires_grad=requires_grad,
                             artifact_directory=path_to_output_artifact_directory)
# Out:
# 2024-04-09 10:31:36,079 root [INFO] - No loss function enum provided. Loss node will not be added to the graph.
# 2024-04-09 10:31:36,082 root [DEBUG] - Building training block _TrainingBlock
# 2024-04-09 10:31:36,083 root [DEBUG] - Building block: PassThrough
# 2024-04-09 10:31:36,088 root [DEBUG] - Building gradient graph for training block _TrainingBlock
# 2024-04-09 10:31:36,095 root [DEBUG] - The loss output is 56. The gradient graph will be built starting from 56_grad.
# 2024-04-09 10:31:36.092525 [I:onnxruntime:Default, constant_sharing.cc:256 ApplyImpl] Total shared scalar initializer count: 4
# 2024-04-09 10:31:36.094131 [I:onnxruntime:Default, graph.cc:3556 CleanUnusedInitializersAndNodeArgs] Removing initializer '/policy/ConstantOfShape_output_0'. It is no longer used by any node.
# 2024-04-09 10:31:36.094153 [I:onnxruntime:Default, graph.cc:3556 CleanUnusedInitializersAndNodeArgs] Removing initializer '/policy/Shape_output_0'. It is no longer used by any node.
# 2024-04-09 10:31:36.094576 [I:onnxruntime:Default, propagate_cast_ops.cc:1482 ApplyImpl] Propagate Cast operations summary:
# 2024-04-09 10:31:36.094599 [I:onnxruntime:Default, propagate_cast_ops.cc:1483 ApplyImpl] Number of passes = 2
# 2024-04-09 10:31:36.094607 [I:onnxruntime:Default, propagate_cast_ops.cc:1484 ApplyImpl] Nodes Inserted:
# 2024-04-09 10:31:36.094614 [I:onnxruntime:Default, propagate_cast_ops.cc:1487 ApplyImpl] Nodes Removed:
# 2024-04-09 10:31:36.094621 [I:onnxruntime:Default, propagate_cast_ops.cc:1488 operator()] /policy/Cast
# 2024-04-09 10:31:36.094627 [I:onnxruntime:Default, propagate_cast_ops.cc:1490 ApplyImpl] Nodes Converted to FP16:
# 2024-04-09 10:31:36.105926 [I:onnxruntime:Default, gradient_graph_builder.cc:102 GradientGraphBuilder] The model weights and inputs are non-differentiable from 56. ORT will assume no gradient will be provided for 56, is_allowed_type_for_grad: 0
# 2024-04-09 10:31:36.107814 [I:onnxruntime:Default, graph.cc:3556 CleanUnusedInitializersAndNodeArgs] Removing initializer '56_grad'. It is no longer used by any node.
# 2024-04-09 10:31:36,109 root [DEBUG] - Adding gradient accumulation nodes for training block _TrainingBlock
# 2024-04-09 10:31:36,121 root [INFO] - Saved training model to training_artifacts/training_model.onnx
# 2024-04-09 10:31:36,123 root [INFO] - Saved eval model to training_artifacts/eval_model.onnx
# 2024-04-09 10:31:36,124 root [INFO] - Saved checkpoint to training_artifacts/checkpoint
# 2024-04-09 10:31:36,125 root [INFO] - No optimizer enum provided. Skipping optimizer model generation.

# %%
from onnxruntime.training.api import CheckpointState, Module, Optimizer

# Assuming the paths are correctly defined
path_to_the_checkpoint_artifact = 'training_artifacts/checkpoint'
path_to_the_training_model = 'training_artifacts/training_model.onnx'
path_to_the_eval_model = 'training_artifacts/eval_model.onnx'
# path_to_the_optimizer_model = 'training_artifacts/optimizer_model.onnx'

# Load the checkpoint state
state = CheckpointState.load_checkpoint(path_to_the_checkpoint_artifact)

# Create the module
module = Module(path_to_the_training_model,
                state,
                path_to_the_eval_model,
                device="cpu")

# optimizer = Optimizer(path_to_the_optimizer_model, module)

# %%
module.train(2048)

# %%
# trained_model.graph.initializer
# learner.get_parameters()

# %% [markdown]
# #### Start set up GAIL trainier

# %%
policy_kwargs = dict(net_arch=dict(pi=[128,64, 32, 16], vf=[128,64, 32, 16]))
SEED = 42

learner = PPO(
    env=env_train,
    policy=MlpPolicy,
    batch_size=2048,
    ent_coef=0.01,
    learning_rate=0.00025,
    gamma=0.95,
    n_epochs=5,
    clip_range=0.1,
    policy_kwargs=policy_kwargs,
    # seed=SEED,
)
# trained_model.env = env_train
# learner = trained_model

reward_net = BasicRewardNet(
    observation_space=env_train.observation_space,
    action_space=env_train.action_space,
    normalize_input_layer=RunningNorm,
)

gail_trainer = GAIL(
    demonstrations=random_rollouts,
    demo_batch_size=64,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=env_train,
    gen_algo=learner,
    reward_net=reward_net,
)

# %% [markdown]
# ... then we evaluate it before training ...

# %%
env_train.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(learner, env_train, 1, return_episode_rewards=True)
# Out:
# Step 0, action: [0.00397809], Trade: 0
# Step 1, action: [0.00397809], Trade: 0
# Step 2, action: [0.00397809], Trade: 0
# Step 3, action: [0.00397809], Trade: 0
# Step 4, action: [0.00397809], Trade: 0
# Step 5, action: [0.00397809], Trade: 0
# Step 6, action: [0.00397809], Trade: 0
# Step 7, action: [0.00397809], Trade: 0
# Step 8, action: [0.00397809], Trade: 0
# Step 9, action: [0.00397809], Trade: 0
# Step 10, action: [0.00397809], Trade: 0
# Step 11, action: [0.00397809], Trade: 0
# Step 12, action: [0.00397809], Trade: 0
# Step 13, action: [0.00397809], Trade: 0
# Step 14, action: [0.00397809], Trade: 0
# Step 15, action: [0.00397809], Trade: 0
# Step 16, action: [0.00397809], Trade: 0
# Step 17, action: [0.00397809], Trade: 0
# Step 18, action: [0.00397809], Trade: 0
# Step 19, action: [0.00397809], Trade: 0
# Step 20, action: [0.00397809], Trade: 0
# Step 21, action: [0.00397809], Trade: 0
# Step 22, action: [0.00397809], Trade: 0
# Step 23, action: [0.00397809], Trade: 0
# Step 24, action: [0.00397809], Trade: 0
# Step 25, action: [0.00397809], Trade: 0
# Step 26, action: [0.00397809], Trade: 0
# Step 27, action: [0.00397809], Trade: 0
# Step 28, action: [0.00397809], Trade: 0
# Step 29, action: [0.00397809], Trade: 0
# Step 30, action: [0.00397809], Trade: 0
# Step 31, action: [0.00397809], Trade: 0
# Step 32, action: [0.00397809], Trade: 0
# Step 33, action: [0.00397809], Trade: 0
# Step 34, action: [0.00397809], Trade: 0
# Step 35, action: [0.00397809], Trade: 0
# Step 36, action: [0.00397809], Trade: 0
# Step 37, action: [0.00397809], Trade: 0
# Step 38, action: [0.00397809], Trade: 0
# Step 39, action: [0.00397809], Trade: 0
# Step 40, action: [0.00397809], Trade: 0
# Step 41, action: [0.00397809], Trade: 0
# Step 42, action: [0.00397809], Trade: 0
# Step 43, action: [0.00397809], Trade: 0
# Step 44, action: [0.00397809], Trade: 0
# Step 45, action: [0.00397809], Trade: 0
# Step 46, action: [0.00397809], Trade: 0
# Step 47, action: [0.00397809], Trade: 0
# Step 48, action: [0.00397809], Trade: 0
# Step 49, action: [0.00397809], Trade: 0
# Step 50, action: [0.00397809], Trade: 0
# Step 51, action: [0.00397809], Trade: 0
# Step 52, action: [0.00397809], Trade: 0
# Step 53, action: [0.00397809], Trade: 0
# Step 54, action: [0.00397809], Trade: 0
# Step 55, action: [0.00397809], Trade: 0
# Step 56, action: [0.00397809], Trade: 0
# Step 57, action: [0.00397809], Trade: 0
# Step 58, action: [0.00397809], Trade: 0
# Step 59, action: [0.00397809], Trade: 0
# Step 60, action: [0.00397809], Trade: 0
# Step 61, action: [0.00397809], Trade: 0
# Step 62, action: [0.00397809], Trade: 0
# Step 63, action: [0.00397809], Trade: 0
# Step 64, action: [0.00397809], Trade: 0
# Step 65, action: [0.00397809], Trade: 0
# Step 66, action: [0.00397809], Trade: 0
# Step 67, action: [0.00397809], Trade: 0
# Step 68, action: [0.00397809], Trade: 0
# Step 69, action: [0.00397809], Trade: 0
# Step 70, action: [0.00397809], Trade: 0
# Step 71, action: [0.00397809], Trade: 0
# Step 72, action: [0.00397809], Trade: 0
# Step 73, action: [0.00397809], Trade: 0
# Step 74, action: [0.00397809], Trade: 0
# Step 75, action: [0.00397809], Trade: 0
# Step 76, action: [0.00397809], Trade: 0
# Step 77, action: [0.00397809], Trade: 0
# Step 78, action: [0.00397809], Trade: 0
# Step 79, action: [0.00397809], Trade: 0
# Step 80, action: [0.00397809], Trade: 0
# Step 81, action: [0.00397809], Trade: 0
# Step 82, action: [0.00397809], Trade: 0
# Step 83, action: [0.00397809], Trade: 0
# Step 84, action: [0.00397809], Trade: 0
# Step 85, action: [0.00397809], Trade: 0
# Step 86, action: [0.00397809], Trade: 0
# Step 87, action: [0.00397809], Trade: 0
# Step 88, action: [0.00397809], Trade: 0
# Step 89, action: [0.00397809], Trade: 0
# Step 90, action: [0.00397809], Trade: 0
# Step 91, action: [0.00397809], Trade: 0
# Step 92, action: [0.00397809], Trade: 0
# Step 93, action: [0.00397809], Trade: 0
# Step 94, action: [0.00397809], Trade: 0
# Step 95, action: [0.00397809], Trade: 0
# Step 96, action: [0.00397809], Trade: 0
# Step 97, action: [0.00397809], Trade: 0
# Step 98, action: [0.00397809], Trade: 0
# Step 99, action: [0.00397809], Trade: 0
# Step 100, action: [0.00397809], Trade: 0
# Step 101, action: [0.00397809], Trade: 0
# Step 102, action: [0.00397809], Trade: 0
# Step 103, action: [0.00397809], Trade: 0
# Step 104, action: [0.00397809], Trade: 0
# Step 105, action: [0.00397809], Trade: 0
# Step 106, action: [0.00397809], Trade: 0
# Step 107, action: [0.00397809], Trade: 0
# Step 108, action: [0.00397809], Trade: 0
# Step 109, action: [0.00397809], Trade: 0
# Step 110, action: [0.00397809], Trade: 0
# Step 111, action: [0.00397809], Trade: 0
# Step 112, action: [0.00397809], Trade: 0
# Step 113, action: [0.00397809], Trade: 0
# Step 114, action: [0.00397809], Trade: 0
# Step 115, action: [0.00397809], Trade: 0
# Step 116, action: [0.00397809], Trade: 0
# Step 117, action: [0.00397809], Trade: 0
# Step 118, action: [0.00397809], Trade: 0
# Step 119, action: [0.00397809], Trade: 0
# Step 120, action: [0.00397809], Trade: 0
# Step 121, action: [0.00397809], Trade: 0
# Step 122, action: [0.00397809], Trade: 0
# Step 123, action: [0.00397809], Trade: 0
# Step 124, action: [0.00397809], Trade: 0
# Step 125, action: [0.00397809], Trade: 0
# Step 126, action: [0.00397809], Trade: 0
# Step 127, action: [0.00397809], Trade: 0
# Step 128, action: [0.00397809], Trade: 0
# Step 129, action: [0.00397809], Trade: 0
# Step 130, action: [0.00397809], Trade: 0
# Step 131, action: [0.00397809], Trade: 0
# Step 132, action: [0.00397809], Trade: 0
# Step 133, action: [0.00397809], Trade: 0
# Step 134, action: [0.00397809], Trade: 0
# Step 135, action: [0.00397809], Trade: 0
# Step 136, action: [0.00397809], Trade: 0
# Step 137, action: [0.00397809], Trade: 0
# Step 138, action: [0.00397809], Trade: 0
# Step 139, action: [0.00397809], Trade: 0
# Step 140, action: [0.00397809], Trade: 0
# Step 141, action: [0.00397809], Trade: 0
# Step 142, action: [0.00397809], Trade: 0
# Step 143, action: [0.00397809], Trade: 0
# Step 144, action: [0.00397809], Trade: 0
# Step 145, action: [0.00397809], Trade: 0
# Step 146, action: [0.00397809], Trade: 0
# Step 147, action: [0.00397809], Trade: 0
# Step 148, action: [0.00397809], Trade: 0
# Step 149, action: [0.00397809], Trade: 0
# Step 150, action: [0.00397809], Trade: 0
# Step 151, action: [0.00397809], Trade: 0
# Step 152, action: [0.00397809], Trade: 0
# Step 153, action: [0.00397809], Trade: 0
# Step 154, action: [0.00397809], Trade: 0
# Step 155, action: [0.00397809], Trade: 0
# Step 156, action: [0.00397809], Trade: 0
# Step 157, action: [0.00397809], Trade: 0
# Step 158, action: [0.00397809], Trade: 0
# Step 159, action: [0.00397809], Trade: 0
# Step 160, action: [0.00397809], Trade: 0
# Step 161, action: [0.00397809], Trade: 0
# Step 162, action: [0.00397809], Trade: 0
# Step 163, action: [0.00397809], Trade: 0
# Step 164, action: [0.00397809], Trade: 0
# Step 165, action: [0.00397809], Trade: 0
# Step 166, action: [0.00397809], Trade: 0
# Step 167, action: [0.00397809], Trade: 0
# Step 168, action: [0.00397809], Trade: 0
# Step 169, action: [0.00397809], Trade: 0
# Step 170, action: [0.00397809], Trade: 0
# Step 171, action: [0.00397809], Trade: 0
# Step 172, action: [0.00397809], Trade: 0
# Step 173, action: [0.00397809], Trade: 0
# Step 174, action: [0.00397809], Trade: 0
# Step 175, action: [0.00397809], Trade: 0
# Step 176, action: [0.00397809], Trade: 0
# Step 177, action: [0.00397809], Trade: 0
# Step 178, action: [0.00397809], Trade: 0
# Step 179, action: [0.00397809], Trade: 0
# Step 180, action: [0.00397809], Trade: 0
# Step 181, action: [0.00397809], Trade: 0
# Step 182, action: [0.00397809], Trade: 0
# Step 183, action: [0.00397809], Trade: 0
# Step 184, action: [0.00397809], Trade: 0
# Step 185, action: [0.00397809], Trade: 0
# Step 186, action: [0.00397809], Trade: 0
# Step 187, action: [0.00397809], Trade: 0
# Step 188, action: [0.00397809], Trade: 0
# Step 189, action: [0.00397809], Trade: 0
# Step 190, action: [0.00397809], Trade: 0
# Step 191, action: [0.00397809], Trade: 0
# Step 192, action: [0.00397809], Trade: 0
# Step 193, action: [0.00397809], Trade: 0
# Step 194, action: [0.00397809], Trade: 0
# Step 195, action: [0.00397809], Trade: 0
# Step 196, action: [0.00397809], Trade: 0
# Step 197, action: [0.00397809], Trade: 0
# Step 198, action: [0.00397809], Trade: 0
# Step 199, action: [0.00397809], Trade: 0
# Step 200, action: [0.00397809], Trade: 0
# Step 201, action: [0.00397809], Trade: 0
# Step 202, action: [0.00397809], Trade: 0
# Step 203, action: [0.00397809], Trade: 0
# Step 204, action: [0.00397809], Trade: 0
# Step 205, action: [0.00397809], Trade: 0
# Step 206, action: [0.00397809], Trade: 0
# Step 207, action: [0.00397809], Trade: 0
# Step 208, action: [0.00397809], Trade: 0
# Step 209, action: [0.00397809], Trade: 0
# Step 210, action: [0.00397809], Trade: 0
# Step 211, action: [0.00397809], Trade: 0
# Step 212, action: [0.00397809], Trade: 0
# Step 213, action: [0.00397809], Trade: 0
# Step 214, action: [0.00397809], Trade: 0
# Step 215, action: [0.00397809], Trade: 0
# Step 216, action: [0.00397809], Trade: 0
# Step 217, action: [0.00397809], Trade: 0
# Step 218, action: [0.00397809], Trade: 0
# Step 219, action: [0.00397809], Trade: 0
# Step 220, action: [0.00397809], Trade: 0
# Step 221, action: [0.00397809], Trade: 0
# Step 222, action: [0.00397809], Trade: 0
# Step 223, action: [0.00397809], Trade: 0
# Step 224, action: [0.00397809], Trade: 0
# Step 225, action: [0.00397809], Trade: 0
# Step 226, action: [0.00397809], Trade: 0
# Step 227, action: [0.00397809], Trade: 0
# Step 228, action: [0.00397809], Trade: 0
# Step 229, action: [0.00397809], Trade: 0
# Step 230, action: [0.00397809], Trade: 0
# Step 231, action: [0.00397809], Trade: 0
# Step 232, action: [0.00397809], Trade: 0
# Step 233, action: [0.00397809], Trade: 0
# Step 234, action: [0.00397809], Trade: 0
# Step 235, action: [0.00397809], Trade: 0
# Step 236, action: [0.00397809], Trade: 0
# Step 237, action: [0.00397809], Trade: 0
# Step 238, action: [0.00397809], Trade: 0
# Step 239, action: [0.00397809], Trade: 0
# Step 240, action: [0.00397809], Trade: 0
# Step 241, action: [0.00397809], Trade: 0
# Step 242, action: [0.00397809], Trade: 0
# Step 243, action: [0.00397809], Trade: 0
# Step 244, action: [0.00397809], Trade: 0
# Step 245, action: [0.00397809], Trade: 0
# Step 246, action: [0.00397809], Trade: 0
# Step 247, action: [0.00397809], Trade: 0
# Step 248, action: [0.00397809], Trade: 0
# Step 249, action: [0.00397809], Trade: 0
# Step 250, action: [0.00397809], Trade: 0
# Step 251, action: [0.00397809], Trade: 0
# Step 252, action: [0.00397809], Trade: 0
# Step 253, action: [0.00397809], Trade: 0
# Step 254, action: [0.00397809], Trade: 0
# Step 255, action: [0.00397809], Trade: 0
# Step 256, action: [0.00397809], Trade: 0
# Step 257, action: [0.00397809], Trade: 0
# Step 258, action: [0.00397809], Trade: 0
# Step 259, action: [0.00397809], Trade: 0
# Step 260, action: [0.00397809], Trade: 0
# Step 261, action: [0.00397809], Trade: 0
# Step 262, action: [0.00397809], Trade: 0
# Step 263, action: [0.00397809], Trade: 0
# Step 264, action: [0.00397809], Trade: 0
# Step 265, action: [0.00397809], Trade: 0
# Step 266, action: [0.00397809], Trade: 0
# Step 267, action: [0.00397809], Trade: 0
# Step 268, action: [0.00397809], Trade: 0
# Step 269, action: [0.00397809], Trade: 0
# Step 270, action: [0.00397809], Trade: 0
# Step 271, action: [0.00397809], Trade: 0
# Step 272, action: [0.00397809], Trade: 0
# Step 273, action: [0.00397809], Trade: 0
# Step 274, action: [0.00397809], Trade: 0
# Step 275, action: [0.00397809], Trade: 0
# Step 276, action: [0.00397809], Trade: 0
# Step 277, action: [0.00397809], Trade: 0
# Step 278, action: [0.00397809], Trade: 0
# Step 279, action: [0.00397809], Trade: 0
# Step 280, action: [0.00397809], Trade: 0
# Step 281, action: [0.00397809], Trade: 0
# Step 282, action: [0.00397809], Trade: 0
# Step 283, action: [0.00397809], Trade: 0
# Step 284, action: [0.00397809], Trade: 0
# Step 285, action: [0.00397809], Trade: 0
# Step 286, action: [0.00397809], Trade: 0
# Step 287, action: [0.00397809], Trade: 0
# Step 288, action: [0.00397809], Trade: 0
# Step 289, action: [0.00397809], Trade: 0
# Step 290, action: [0.00397809], Trade: 0
# Step 291, action: [0.00397809], Trade: 0
# Step 292, action: [0.00397809], Trade: 0
# Step 293, action: [0.00397809], Trade: 0
# Step 294, action: [0.00397809], Trade: 0
# Step 295, action: [0.00397809], Trade: 0
# Step 296, action: [0.00397809], Trade: 0
# Step 297, action: [0.00397809], Trade: 0
# Step 298, action: [0.00397809], Trade: 0
# Step 299, action: [0.00397809], Trade: 0
# Step 300, action: [0.00397809], Trade: 0
# Step 301, action: [0.00397809], Trade: 0
# Step 302, action: [0.00397809], Trade: 0
# Step 303, action: [0.00397809], Trade: 0
# Step 304, action: [0.00397809], Trade: 0
# Step 305, action: [0.00397809], Trade: 0
# Step 306, action: [0.00397809], Trade: 0
# Step 307, action: [0.00397809], Trade: 0
# Step 308, action: [0.00397809], Trade: 0
# Step 309, action: [0.00397809], Trade: 0
# Step 310, action: [0.00397809], Trade: 0
# Step 311, action: [0.00397809], Trade: 0
# Step 312, action: [0.00397809], Trade: 0
# Step 313, action: [0.00397809], Trade: 0
# Step 314, action: [0.00397809], Trade: 0
# Step 315, action: [0.00397809], Trade: 0
# Step 316, action: [0.00397809], Trade: 0
# Step 317, action: [0.00397809], Trade: 0
# Step 318, action: [0.00397809], Trade: 0
# Step 319, action: [0.00397809], Trade: 0
# Step 320, action: [0.00397809], Trade: 0
# Step 321, action: [0.00397809], Trade: 0
# Step 322, action: [0.00397809], Trade: 0
# Step 323, action: [0.00397809], Trade: 0
# Step 324, action: [0.00397809], Trade: 0
# Step 325, action: [0.00397809], Trade: 0
# Step 326, action: [0.00397809], Trade: 0
# Step 327, action: [0.00397809], Trade: 0
# Step 328, action: [0.00397809], Trade: 0
# Step 329, action: [0.00397809], Trade: 0
# Step 330, action: [0.00397809], Trade: 0
# Step 331, action: [0.00397809], Trade: 0
# Step 332, action: [0.00397809], Trade: 0
# Step 333, action: [0.00397809], Trade: 0
# Step 334, action: [0.00397809], Trade: 0
# Step 335, action: [0.00397809], Trade: 0
# Step 336, action: [0.00397809], Trade: 0
# Step 337, action: [0.00397809], Trade: 0
# Step 338, action: [0.00397809], Trade: 0
# Step 339, action: [0.00397809], Trade: 0
# Step 340, action: [0.00397809], Trade: 0
# Step 341, action: [0.00397809], Trade: 0
# Step 342, action: [0.00397809], Trade: 0
# Step 343, action: [0.00397809], Trade: 0
# Step 344, action: [0.00397809], Trade: 0
# Step 345, action: [0.00397809], Trade: 0
# Step 346, action: [0.00397809], Trade: 0
# Step 347, action: [0.00397809], Trade: 0
# Step 348, action: [0.00397809], Trade: 0
# Step 349, action: [0.00397809], Trade: 0
# Step 350, action: [0.00397809], Trade: 0
# Step 351, action: [0.00397809], Trade: 0
# Step 352, action: [0.00397809], Trade: 0
# Step 353, action: [0.00397809], Trade: 0
# Step 354, action: [0.00397809], Trade: 0
# Step 355, action: [0.00397809], Trade: 0
# Step 356, action: [0.00397809], Trade: 0
# Step 357, action: [0.00397809], Trade: 0
# Step 358, action: [0.00397809], Trade: 0
# Step 359, action: [0.00397809], Trade: 0
# Step 360, action: [0.00397809], Trade: 0
# Step 361, action: [0.00397809], Trade: 0
# Step 362, action: [0.00397809], Trade: 0
# Step 363, action: [0.00397809], Trade: 0
# Step 364, action: [0.00397809], Trade: 0
# Step 365, action: [0.00397809], Trade: 0
# Step 366, action: [0.00397809], Trade: 0
# Step 367, action: [0.00397809], Trade: 0
# Step 368, action: [0.00397809], Trade: 0
# Step 369, action: [0.00397809], Trade: 0
# Step 370, action: [0.00397809], Trade: 0
# Step 371, action: [0.00397809], Trade: 0
# Step 372, action: [0.00397809], Trade: 0
# Step 373, action: [0.00397809], Trade: 0
# Step 374, action: [0.00397809], Trade: 0
# Step 375, action: [0.00397809], Trade: 0
# Step 376, action: [0.00397809], Trade: 0
# Step 377, action: [0.00397809], Trade: 0
# Step 378, action: [0.00397809], Trade: 0
# Step 379, action: [0.00397809], Trade: 0
# Step 380, action: [0.00397809], Trade: 0
# Step 381, action: [0.00397809], Trade: 0
# Step 382, action: [0.00397809], Trade: 0
# Step 383, action: [0.00397809], Trade: 0
# Step 384, action: [0.00397809], Trade: 0
# Step 385, action: [0.00397809], Trade: 0
# Step 386, action: [0.00397809], Trade: 0
# Step 387, action: [0.00397809], Trade: 0
# Step 388, action: [0.00397809], Trade: 0
# Step 389, action: [0.00397809], Trade: 0
# Step 390, action: [0.00397809], Trade: 0
# Step 391, action: [0.00397809], Trade: 0
# Step 392, action: [0.00397809], Trade: 0
# Step 393, action: [0.00397809], Trade: 0
# Step 394, action: [0.00397809], Trade: 0
# Step 395, action: [0.00397809], Trade: 0
# Step 396, action: [0.00397809], Trade: 0
# Step 397, action: [0.00397809], Trade: 0
# Step 398, action: [0.00397809], Trade: 0
# Step 399, action: [0.00397809], Trade: 0
# Step 400, action: [0.00397809], Trade: 0
# Step 401, action: [0.00397809], Trade: 0
# Step 402, action: [0.00397809], Trade: 0
# Step 403, action: [0.00397809], Trade: 0
# Step 404, action: [0.00397809], Trade: 0
# Step 405, action: [0.00397809], Trade: 0
# Step 406, action: [0.00397809], Trade: 0
# Step 407, action: [0.00397809], Trade: 0
# Step 408, action: [0.00397809], Trade: 0
# Step 409, action: [0.00397809], Trade: 0
# Step 410, action: [0.00397809], Trade: 0
# Step 411, action: [0.00397802], Trade: 0
# Step 412, action: [0.00396339], Trade: 0
# Step 413, action: [0.00312951], Trade: 0
# Step 414, action: [0.00216541], Trade: 0
# Step 415, action: [0.00206777], Trade: 0
# Step 416, action: [0.00206739], Trade: 0
# Step 417, action: [0.00206738], Trade: 0
# Step 418, action: [0.00206738], Trade: 0
# Step 419, action: [0.00206738], Trade: 0
# Step 420, action: [0.00206738], Trade: 0
# Step 421, action: [0.00206738], Trade: 0
# Step 422, action: [0.00206738], Trade: 0
# Step 423, action: [0.00206738], Trade: 0
# Step 424, action: [0.00206738], Trade: 0
# Step 425, action: [0.00206738], Trade: 0
# Step 426, action: [0.00206738], Trade: 0
# Step 427, action: [0.00206738], Trade: 0
# Step 428, action: [0.00206738], Trade: 0
# Step 429, action: [0.00206738], Trade: 0
# Step 430, action: [0.00206738], Trade: 0
# Step 431, action: [0.00206738], Trade: 0
# Step 432, action: [0.00206738], Trade: 0
# Step 433, action: [0.00206738], Trade: 0
# Step 434, action: [0.00206738], Trade: 0
# Step 435, action: [0.00206738], Trade: 0
# Step 436, action: [0.00206738], Trade: 0
# Step 437, action: [0.00206738], Trade: 0
# Step 438, action: [0.00206738], Trade: 0
# Step 439, action: [0.00206738], Trade: 0
# Step 440, action: [0.00206738], Trade: 0
# Step 441, action: [0.00206738], Trade: 0
# Step 442, action: [0.00206738], Trade: 0
# Step 443, action: [0.00206738], Trade: 0
# Step 444, action: [0.00206738], Trade: 0
# Step 445, action: [0.00206738], Trade: 0
# Step 446, action: [0.00206738], Trade: 0
# Step 447, action: [0.00206738], Trade: 0
# Step 448, action: [0.00206738], Trade: 0
# Step 449, action: [0.00206738], Trade: 0
# Step 450, action: [0.00206738], Trade: 0
# Step 451, action: [0.00206738], Trade: 0
# Step 452, action: [0.00206738], Trade: 0
# Step 453, action: [0.00206738], Trade: 0
# Step 454, action: [0.00206738], Trade: 0
# Step 455, action: [0.00206738], Trade: 0
# Step 456, action: [0.00206738], Trade: 0
# Step 457, action: [0.00206738], Trade: 0
# Step 458, action: [0.00206738], Trade: 0
# Step 459, action: [0.00206738], Trade: 0
# Step 460, action: [0.00206738], Trade: 0
# Step 461, action: [0.00206738], Trade: 0
# Step 462, action: [0.00206738], Trade: 0
# Step 463, action: [0.00206738], Trade: 0
# Step 464, action: [0.00206738], Trade: 0
# Step 465, action: [0.00206738], Trade: 0
# Step 466, action: [0.00206738], Trade: 0
# Step 467, action: [0.00206738], Trade: 0
# Step 468, action: [0.00206738], Trade: 0
# Step 469, action: [0.00206738], Trade: 0
# Step 470, action: [0.00206738], Trade: 0
# Step 471, action: [0.00206738], Trade: 0
# Step 472, action: [0.00206738], Trade: 0
# Step 473, action: [0.00206738], Trade: 0
# Step 474, action: [0.00206738], Trade: 0
# Step 475, action: [0.00206738], Trade: 0
# Step 476, action: [0.00206738], Trade: 0
# Step 477, action: [0.00206738], Trade: 0
# Step 478, action: [0.00206738], Trade: 0
# Step 479, action: [0.00206738], Trade: 0
# Step 480, action: [0.00206738], Trade: 0
# Step 481, action: [0.00206738], Trade: 0
# Step 482, action: [0.00206738], Trade: 0
# Step 483, action: [0.00206738], Trade: 0
# Step 484, action: [0.00206738], Trade: 0
# Step 485, action: [0.00206738], Trade: 0
# Step 486, action: [0.00206738], Trade: 0
# Step 487, action: [0.00206738], Trade: 0
# Step 488, action: [0.00206738], Trade: 0
# Step 489, action: [0.00206738], Trade: 0
# Step 490, action: [0.00206738], Trade: 0
# Step 491, action: [0.00206738], Trade: 0
# Step 492, action: [0.00206738], Trade: 0
# Step 493, action: [0.00206738], Trade: 0
# Step 494, action: [0.00206738], Trade: 0
# Step 495, action: [0.00206738], Trade: 0
# Step 496, action: [0.00206738], Trade: 0
# Step 497, action: [0.00206738], Trade: 0
# Step 498, action: [0.00206738], Trade: 0
# Step 499, action: [0.00206738], Trade: 0
# Step 500, action: [0.00206738], Trade: 0
# Step 501, action: [0.00206738], Trade: 0
# Step 502, action: [0.00206738], Trade: 0
# Step 503, action: [0.00206738], Trade: 0
# Step 504, action: [0.00206738], Trade: 0
# Step 505, action: [0.00206738], Trade: 0
# Step 506, action: [0.00206738], Trade: 0
# Step 507, action: [0.00206738], Trade: 0
# Step 508, action: [0.00206738], Trade: 0
# Step 509, action: [0.00206738], Trade: 0
# Step 510, action: [0.00206738], Trade: 0
# Step 511, action: [0.00206738], Trade: 0
# Step 512, action: [0.00206738], Trade: 0
# Step 513, action: [0.00206738], Trade: 0
# Step 514, action: [0.00206738], Trade: 0
# Step 515, action: [0.00206738], Trade: 0
# Step 516, action: [0.00206738], Trade: 0
# Step 517, action: [0.00206738], Trade: 0
# Step 518, action: [0.00206738], Trade: 0
# Step 519, action: [0.00206738], Trade: 0
# Step 520, action: [0.00206738], Trade: 0
# Step 521, action: [0.00206738], Trade: 0
# Step 522, action: [0.00206738], Trade: 0
# Step 523, action: [0.00206738], Trade: 0
# Step 524, action: [0.00206738], Trade: 0
# Step 525, action: [0.00206738], Trade: 0
# Step 526, action: [0.00206738], Trade: 0
# Step 527, action: [0.00206738], Trade: 0
# Step 528, action: [0.00206738], Trade: 0
# Step 529, action: [0.00206738], Trade: 0
# Step 530, action: [0.00206738], Trade: 0
# Step 531, action: [0.00206738], Trade: 0
# Step 532, action: [0.00206738], Trade: 0
# Step 533, action: [0.00206738], Trade: 0
# Step 534, action: [0.00206738], Trade: 0
# Step 535, action: [0.00206738], Trade: 0
# Step 536, action: [0.00206738], Trade: 0
# Step 537, action: [0.00206738], Trade: 0
# Step 538, action: [0.00206738], Trade: 0
# Step 539, action: [0.00206738], Trade: 0
# Step 540, action: [0.00206738], Trade: 0
# Step 541, action: [0.00206738], Trade: 0
# Step 542, action: [0.00206738], Trade: 0
# Step 543, action: [0.00206738], Trade: 0
# Step 544, action: [0.00206738], Trade: 0
# Step 545, action: [0.00206738], Trade: 0
# Step 546, action: [0.00206738], Trade: 0
# Step 547, action: [0.00206738], Trade: 0
# Step 548, action: [0.00206738], Trade: 0
# Step 549, action: [0.00206738], Trade: 0
# Step 550, action: [0.00206738], Trade: 0
# Step 551, action: [0.00206738], Trade: 0
# Step 552, action: [0.00206738], Trade: 0
# Step 553, action: [0.00206738], Trade: 0
# Step 554, action: [0.00206738], Trade: 0
# Step 555, action: [0.00206738], Trade: 0
# Step 556, action: [0.00206738], Trade: 0
# Step 557, action: [0.00206738], Trade: 0
# Step 558, action: [0.00206738], Trade: 0
# Step 559, action: [0.00206738], Trade: 0
# Step 560, action: [0.00206738], Trade: 0
# Step 561, action: [0.00206738], Trade: 0
# Step 562, action: [0.00206738], Trade: 0
# Step 563, action: [0.00206738], Trade: 0
# Step 564, action: [0.00206738], Trade: 0
# Step 565, action: [0.00206738], Trade: 0
# Step 566, action: [0.00206738], Trade: 0
# Step 567, action: [0.00206738], Trade: 0
# Step 568, action: [0.00206738], Trade: 0
# Step 569, action: [0.00206738], Trade: 0
# Step 570, action: [0.00206738], Trade: 0
# Step 571, action: [0.00206738], Trade: 0
# Step 572, action: [0.00206738], Trade: 0
# Step 573, action: [0.00206738], Trade: 0
# Step 574, action: [0.00206738], Trade: 0
# Step 575, action: [0.00206738], Trade: 0
# Step 576, action: [0.00206738], Trade: 0
# Step 577, action: [0.00206738], Trade: 0
# Step 578, action: [0.00206738], Trade: 0
# Step 579, action: [0.00206738], Trade: 0
# Step 580, action: [0.00206738], Trade: 0
# Step 581, action: [0.00206738], Trade: 0
# Step 582, action: [0.00206738], Trade: 0
# Step 583, action: [0.00206738], Trade: 0
# Step 584, action: [0.00206738], Trade: 0
# Step 585, action: [0.00206738], Trade: 0
# Step 586, action: [0.00206738], Trade: 0
# Step 587, action: [0.00206738], Trade: 0
# Step 588, action: [0.00206738], Trade: 0
# Step 589, action: [0.00206738], Trade: 0
# Step 590, action: [0.00206738], Trade: 0
# Step 591, action: [0.00206738], Trade: 0
# Step 592, action: [0.00206738], Trade: 0
# Step 593, action: [0.00206738], Trade: 0
# Step 594, action: [0.00206738], Trade: 0
# Step 595, action: [0.00206738], Trade: 0
# Step 596, action: [0.00206738], Trade: 0
# Step 597, action: [0.00206738], Trade: 0
# Step 598, action: [0.00206738], Trade: 0
# Step 599, action: [0.00206738], Trade: 0
# Step 600, action: [0.00206738], Trade: 0
# Step 601, action: [0.00206738], Trade: 0
# Step 602, action: [0.00206738], Trade: 0
# Step 603, action: [0.00206738], Trade: 0
# Step 604, action: [0.00206738], Trade: 0
# Step 605, action: [0.00206739], Trade: 0
# Step 606, action: [0.00206755], Trade: 0
# Step 607, action: [0.00207055], Trade: 0
# Step 608, action: [0.00210054], Trade: 0
# Step 609, action: [0.00230055], Trade: 0
# Step 610, action: [0.00255919], Trade: 0
# Step 611, action: [0.00256276], Trade: 0
# Step 612, action: [0.00256278], Trade: 0
# Step 613, action: [0.00256278], Trade: 0
# Step 614, action: [0.00256278], Trade: 0
# Step 615, action: [0.00256278], Trade: 0
# Step 616, action: [0.00256278], Trade: 0
# Step 617, action: [0.00256278], Trade: 0
# Step 618, action: [0.00256281], Trade: 0
# Step 619, action: [0.00459084], Trade: 0
# Step 620, action: [0.00471121], Trade: 0
# Step 621, action: [0.00471121], Trade: 0
# Step 622, action: [0.00471121], Trade: 0
# Step 623, action: [0.00471121], Trade: 0
# Step 624, action: [0.00471121], Trade: 0
# Step 625, action: [0.00471121], Trade: 0
# Step 626, action: [0.00471121], Trade: 0
# Step 627, action: [0.00471121], Trade: 0
# Step 628, action: [0.00471121], Trade: 0
# Step 629, action: [0.00471121], Trade: 0
# Step 630, action: [0.00471121], Trade: 0
# Step 631, action: [0.00471121], Trade: 0
# Step 632, action: [0.00471121], Trade: 0
# Step 633, action: [0.00471121], Trade: 0
# Step 634, action: [0.00471121], Trade: 0
# Step 635, action: [0.00471121], Trade: 0
# Step 636, action: [0.00471121], Trade: 0
# Step 637, action: [0.00471121], Trade: 0
# Step 638, action: [0.00471121], Trade: 0
# Step 639, action: [0.00471121], Trade: 0
# Step 640, action: [0.00471121], Trade: 0
# Step 641, action: [0.00471121], Trade: 0
# Step 642, action: [0.00471121], Trade: 0
# Step 643, action: [0.00471121], Trade: 0
# Step 644, action: [0.00471121], Trade: 0
# Step 645, action: [0.00471121], Trade: 0
# Step 646, action: [0.00471121], Trade: 0
# Step 647, action: [0.00471121], Trade: 0
# Step 648, action: [0.00471121], Trade: 0
# Step 649, action: [0.00471121], Trade: 0
# Step 650, action: [0.00471121], Trade: 0
# Step 651, action: [0.00471121], Trade: 0
# Step 652, action: [0.00471121], Trade: 0
# Step 653, action: [0.00471121], Trade: 0
# Step 654, action: [0.00471121], Trade: 0
# Step 655, action: [0.00471121], Trade: 0
# Step 656, action: [0.00471121], Trade: 0
# Step 657, action: [0.00471121], Trade: 0
# Step 658, action: [0.00471121], Trade: 0
# Step 659, action: [0.00471121], Trade: 0
# Step 660, action: [0.00471121], Trade: 0
# Step 661, action: [0.00471121], Trade: 0
# Step 662, action: [0.00471121], Trade: 0
# Step 663, action: [0.00471121], Trade: 0
# Step 664, action: [0.00471121], Trade: 0
# Step 665, action: [0.00471121], Trade: 0
# Step 666, action: [0.00471121], Trade: 0
# Step 667, action: [0.00471121], Trade: 0
# Step 668, action: [0.00471121], Trade: 0
# Step 669, action: [0.00471121], Trade: 0
# Step 670, action: [0.00471121], Trade: 0
# Step 671, action: [0.00471121], Trade: 0
# Step 672, action: [0.00471121], Trade: 0
# Step 673, action: [0.00471121], Trade: 0
# Step 674, action: [0.00471121], Trade: 0
# Step 675, action: [0.00471121], Trade: 0
# Step 676, action: [0.00471121], Trade: 0
# Step 677, action: [0.00471121], Trade: 0
# Step 678, action: [0.00471121], Trade: 0
# Step 679, action: [0.00471121], Trade: 0
# Step 680, action: [0.00471121], Trade: 0
# Step 681, action: [0.00471121], Trade: 0
# Step 682, action: [0.00471121], Trade: 0
# Step 683, action: [0.00471121], Trade: 0
# Step 684, action: [0.00471121], Trade: 0
# Step 685, action: [0.00471121], Trade: 0
# Step 686, action: [0.00471121], Trade: 0
# Step 687, action: [0.00471121], Trade: 0
# Step 688, action: [0.00471121], Trade: 0
# Step 689, action: [0.00471121], Trade: 0
# Step 690, action: [0.00471121], Trade: 0
# Step 691, action: [0.00471121], Trade: 0
# Step 692, action: [0.00471121], Trade: 0
# Step 693, action: [0.00471121], Trade: 0
# Step 694, action: [0.00471121], Trade: 0
# Step 695, action: [0.00471121], Trade: 0
# Step 696, action: [0.00471121], Trade: 0
# Step 697, action: [0.00471121], Trade: 0
# Step 698, action: [0.00471121], Trade: 0
# Step 699, action: [0.00471121], Trade: 0
# Step 700, action: [0.00471121], Trade: 0
# Step 701, action: [0.00471121], Trade: 0
# Step 702, action: [0.00471121], Trade: 0
# Step 703, action: [0.00471121], Trade: 0
# Step 704, action: [0.00471121], Trade: 0
# Step 705, action: [0.00471121], Trade: 0
# Step 706, action: [0.00471121], Trade: 0
# Step 707, action: [0.00471121], Trade: 0
# Step 708, action: [0.00471121], Trade: 0
# Step 709, action: [0.00471121], Trade: 0
# Step 710, action: [0.00471121], Trade: 0
# Step 711, action: [0.00471121], Trade: 0
# Step 712, action: [0.00471121], Trade: 0
# Step 713, action: [0.00471121], Trade: 0
# Step 714, action: [0.00471121], Trade: 0
# Step 715, action: [0.00471121], Trade: 0
# Step 716, action: [0.00471121], Trade: 0
# Step 717, action: [0.00471121], Trade: 0
# Step 718, action: [0.00471121], Trade: 0
# Step 719, action: [0.00471121], Trade: 0
# Step 720, action: [0.00471121], Trade: 0
# Step 721, action: [0.00471121], Trade: 0
# Step 722, action: [0.00471121], Trade: 0
# Step 723, action: [0.00471121], Trade: 0
# Step 724, action: [0.00471121], Trade: 0
# Step 725, action: [0.00471121], Trade: 0
# Step 726, action: [0.00471121], Trade: 0
# Step 727, action: [0.00471121], Trade: 0
# Step 728, action: [0.00471121], Trade: 0
# Step 729, action: [0.00471121], Trade: 0
# Step 730, action: [0.00471121], Trade: 0
# Step 731, action: [0.00471121], Trade: 0
# Step 732, action: [0.00471121], Trade: 0
# Step 733, action: [0.00471121], Trade: 0
# Step 734, action: [0.00471121], Trade: 0
# Step 735, action: [0.00471121], Trade: 0
# Step 736, action: [0.00471121], Trade: 0
# Step 737, action: [0.00471121], Trade: 0
# Step 738, action: [0.00471121], Trade: 0
# Step 739, action: [0.00471121], Trade: 0
# Step 740, action: [0.00471121], Trade: 0
# Step 741, action: [0.00471121], Trade: 0
# Step 742, action: [0.00471121], Trade: 0
# Step 743, action: [0.00471121], Trade: 0
# Step 744, action: [0.00471121], Trade: 0
# Step 745, action: [0.00471121], Trade: 0
# Step 746, action: [0.00471124], Trade: 0
# Step 747, action: [0.00471155], Trade: 0
# Step 748, action: [0.00471383], Trade: 0
# Step 749, action: [0.00467651], Trade: 0
# Step 750, action: [0.00461909], Trade: 0
# Step 751, action: [0.00461149], Trade: 0
# Step 752, action: [0.00461088], Trade: 0
# Step 753, action: [0.00471121], Trade: 0
# Step 754, action: [0.00471121], Trade: 0
# Step 755, action: [0.00471121], Trade: 0
# Step 756, action: [0.00471121], Trade: 0
# Step 757, action: [0.00471122], Trade: 0
# Step 758, action: [0.00471127], Trade: 0
# Step 759, action: [0.0047118], Trade: 0
# Step 760, action: [0.00471396], Trade: 0
# Step 761, action: [0.00468991], Trade: 0
# Step 762, action: [0.00463803], Trade: 0
# Step 763, action: [0.00458787], Trade: 0
# Step 764, action: [0.00338192], Trade: 0
# Step 765, action: [0.00338092], Trade: 0
# Step 766, action: [0.00338083], Trade: 0
# Step 767, action: [0.00338082], Trade: 0
# Step 768, action: [0.00338082], Trade: 0
# Step 769, action: [0.00338082], Trade: 0
# Step 770, action: [0.00338082], Trade: 0
# Step 771, action: [0.00338082], Trade: 0
# Step 772, action: [0.00338082], Trade: 0
# Step 773, action: [0.00338082], Trade: 0
# Step 774, action: [0.00338082], Trade: 0
# Step 775, action: [0.00338082], Trade: 0
# Step 776, action: [0.00338082], Trade: 0
# Step 777, action: [0.00338082], Trade: 0
# Step 778, action: [0.00338082], Trade: 0
# Step 779, action: [0.00338082], Trade: 0
# Step 780, action: [0.00338082], Trade: 0
# Step 781, action: [0.00338082], Trade: 0
# Step 782, action: [0.00338082], Trade: 0
# Step 783, action: [0.00338082], Trade: 0
# Step 784, action: [0.00338082], Trade: 0
# Step 785, action: [0.00338082], Trade: 0
# Step 786, action: [0.00338082], Trade: 0
# Step 787, action: [0.00338082], Trade: 0
# Step 788, action: [0.00338082], Trade: 0
# Step 789, action: [0.00338082], Trade: 0
# Step 790, action: [0.00338082], Trade: 0
# Step 791, action: [0.00338082], Trade: 0
# Step 792, action: [0.00338082], Trade: 0
# Step 793, action: [0.00338082], Trade: 0
# Step 794, action: [0.00338082], Trade: 0
# Step 795, action: [0.00338082], Trade: 0
# Step 796, action: [0.00338082], Trade: 0
# Step 797, action: [0.00338082], Trade: 0
# Step 798, action: [0.00338082], Trade: 0
# Step 799, action: [0.00338081], Trade: 0
# Step 800, action: [0.00227823], Trade: 0
# Step 801, action: [0.00226686], Trade: 0
# Step 802, action: [0.00226686], Trade: 0
# Step 803, action: [0.00226686], Trade: 0
# Step 804, action: [0.00226686], Trade: 0
# Step 805, action: [0.00226686], Trade: 0
# Episode: 3, com: BA, win trade: 0/0, Total reward: -9.987593052109043

# %% [markdown]
# ... and train it ...

# %%
gail_trainer.train(2048)
# Out:
# round:   0%|                                              | 0/1 [00:00<?, ?it/s]
# Step 0, action: [-0.00561859], Trade: 0
# Step 1, action: [0.12219889], Trade: 0
# Step 2, action: [0.3014195], Trade: 0
# Step 3, action: [0.5027696], Trade: 0
# Step 4, action: [-0.88870114], Trade: 0
# Step 5, action: [0.56528723], Trade: 0
# Step 6, action: [-1.], Trade: 0
# Step 7, action: [-0.08654246], Trade: 1
# Step 8, action: [-0.79638976], Trade: 2
# Step 9, action: [0.02548163], Trade: 3
# Step 10, action: [1.], Trade: 3
# Step 11, action: [0.8717339], Trade: 3
# Step 12, action: [-1.], Trade: 3
# Step 13, action: [0.53921825], Trade: 4
# Step 14, action: [-0.7768738], Trade: 4
# Step 15, action: [0.3594327], Trade: 5
# Step 16, action: [-0.21822572], Trade: 5
# Step 17, action: [-1.], Trade: 6
# Step 18, action: [-0.00016832], Trade: 7
# Step 19, action: [-0.5629056], Trade: 8
# Step 20, action: [1.], Trade: 9
# Step 21, action: [1.], Trade: 9
# Step 22, action: [-0.23682944], Trade: 9
# Step 23, action: [-1.], Trade: 10
# Step 24, action: [-0.74319124], Trade: 11
# Step 25, action: [0.40653297], Trade: 11
# Step 26, action: [1.], Trade: 11
# Step 27, action: [0.32298294], Trade: 11
# Step 28, action: [-1.], Trade: 11
# Step 29, action: [0.27222592], Trade: 12
# Step 30, action: [0.05323961], Trade: 12
# Step 31, action: [-0.35917878], Trade: 12
# Step 32, action: [1.], Trade: 13
# Step 33, action: [0.93760055], Trade: 13
# Step 34, action: [0.8260415], Trade: 13
# Step 35, action: [-0.7270549], Trade: 13
# Step 36, action: [-1.], Trade: 14
# Step 37, action: [-0.78383124], Trade: 15
# Step 38, action: [0.8808752], Trade: 16
# Step 39, action: [-0.47051725], Trade: 16
# Step 40, action: [-0.8868945], Trade: 17
# Step 41, action: [-1.], Trade: 18
# Step 42, action: [-0.26125935], Trade: 19
# Step 43, action: [-1.], Trade: 19
# Step 44, action: [-0.21532701], Trade: 20
# Step 45, action: [-0.45131007], Trade: 20
# Step 46, action: [1.], Trade: 20
# Step 47, action: [0.00900001], Trade: 20
# Step 48, action: [-0.711126], Trade: 20
# Step 49, action: [-1.], Trade: 20
# Step 50, action: [0.37690413], Trade: 20
# Step 51, action: [-0.01996128], Trade: 20
# Step 52, action: [1.], Trade: 21
# Step 53, action: [0.0593725], Trade: 21
# Step 54, action: [-0.9276148], Trade: 21
# Step 55, action: [-0.82638896], Trade: 22
# Step 56, action: [-0.6000134], Trade: 23
# Step 57, action: [0.6862305], Trade: 24
# Step 58, action: [0.45175165], Trade: 24
# Step 59, action: [-0.4846984], Trade: 24
# Step 60, action: [1.], Trade: 25
# Step 61, action: [-0.8498903], Trade: 25
# Step 62, action: [-0.41247794], Trade: 26
# Step 63, action: [-1.], Trade: 27
# Step 64, action: [0.46193498], Trade: 28
# Step 65, action: [0.08700897], Trade: 28
# Step 66, action: [-0.23283951], Trade: 28
# Step 67, action: [-0.6363259], Trade: 29
# Step 68, action: [-0.9245776], Trade: 30
# Step 69, action: [-1.], Trade: 31
# Step 70, action: [0.49282965], Trade: 32
# Step 71, action: [-0.4519432], Trade: 32
# Step 72, action: [1.], Trade: 33
# Step 73, action: [0.14909616], Trade: 33
# Step 74, action: [0.9567305], Trade: 33
# Step 75, action: [-1.], Trade: 33
# Step 76, action: [0.42513642], Trade: 34
# Step 77, action: [1.], Trade: 34
# Step 78, action: [0.74605876], Trade: 34
# Step 79, action: [-1.], Trade: 34
# Step 80, action: [-0.5664631], Trade: 35
# Step 81, action: [-1.], Trade: 35
# Step 82, action: [0.8378226], Trade: 36
# Step 83, action: [-1.], Trade: 36
# Step 84, action: [0.05566004], Trade: 37
# Step 85, action: [-0.35515466], Trade: 37
# Step 86, action: [-0.84753877], Trade: 37
# Step 87, action: [-1.], Trade: 37
# Step 88, action: [-1.], Trade: 38
# Step 89, action: [-0.33530656], Trade: 38
# Step 90, action: [-1.], Trade: 39
# Step 91, action: [0.8812693], Trade: 40
# Step 92, action: [-0.24952154], Trade: 40
# Step 93, action: [0.70623845], Trade: 40
# Step 94, action: [0.58272487], Trade: 40
# Step 95, action: [-0.45645028], Trade: 40
# Step 96, action: [-0.64119893], Trade: 40
# Step 97, action: [0.33549055], Trade: 41
# Step 98, action: [0.04453293], Trade: 41
# Step 99, action: [-1.], Trade: 41
# Step 100, action: [0.1302616], Trade: 42
# Step 101, action: [0.49435097], Trade: 42
# Step 102, action: [1.], Trade: 42
# Step 103, action: [1.], Trade: 42
# Step 104, action: [-0.5250788], Trade: 42
# Step 105, action: [0.27425346], Trade: 43
# Step 106, action: [-0.20960079], Trade: 43
# Step 107, action: [-1.], Trade: 44
# Step 108, action: [-0.34368515], Trade: 45
# Step 109, action: [-1.], Trade: 45
# Step 110, action: [0.01953421], Trade: 45
# Step 111, action: [-1.], Trade: 45
# Step 112, action: [-0.37777406], Trade: 46
# Step 113, action: [-0.45961228], Trade: 46
# Step 114, action: [1.], Trade: 46
# Step 115, action: [-0.5828002], Trade: 46
# Step 116, action: [-0.8147203], Trade: 47
# Step 117, action: [-1.], Trade: 48
# Step 118, action: [-1.], Trade: 49
# Step 119, action: [-0.6341739], Trade: 49
# Step 120, action: [1.], Trade: 50
# Step 121, action: [-1.], Trade: 50
# Step 122, action: [0.9774725], Trade: 51
# Step 123, action: [-1.], Trade: 51
# Step 124, action: [0.8267933], Trade: 51
# Step 125, action: [-0.5198328], Trade: 51
# Step 126, action: [0.14829403], Trade: 52
# Step 127, action: [1.], Trade: 52
# Step 128, action: [-1.], Trade: 52
# Step 129, action: [0.838094], Trade: 53
# Step 130, action: [1.], Trade: 53
# Step 131, action: [0.6531716], Trade: 53
# Step 132, action: [-0.4097677], Trade: 53
# Step 133, action: [0.30791414], Trade: 54
# Step 134, action: [-0.45934626], Trade: 54
# Step 135, action: [0.46387857], Trade: 55
# Step 136, action: [0.04267969], Trade: 55
# Step 137, action: [-0.21765478], Trade: 55
# Step 138, action: [0.47581905], Trade: 56
# Step 139, action: [-0.0737897], Trade: 56
# Step 140, action: [0.15104797], Trade: 57
# Step 141, action: [-0.31803483], Trade: 57
# Step 142, action: [-0.8417078], Trade: 58
# Step 143, action: [1.], Trade: 59
# Step 144, action: [0.67770976], Trade: 59
# Step 145, action: [0.2808326], Trade: 59
# Step 146, action: [-0.54947114], Trade: 59
# Step 147, action: [-1.], Trade: 60
# Step 148, action: [-0.7194679], Trade: 61
# Step 149, action: [-1.], Trade: 62
# Step 150, action: [0.28212202], Trade: 63
# Step 151, action: [-1.], Trade: 63
# Step 152, action: [0.6799051], Trade: 63
# Step 153, action: [-0.7344784], Trade: 63
# Step 154, action: [-0.84610003], Trade: 63
# Step 155, action: [-1.], Trade: 63
# Step 156, action: [0.5464353], Trade: 64
# Step 157, action: [-0.5846097], Trade: 64
# Step 158, action: [0.39106762], Trade: 65
# Step 159, action: [-0.8754158], Trade: 65
# Step 160, action: [1.], Trade: 66
# Step 161, action: [0.1901661], Trade: 66
# Step 162, action: [-0.7607681], Trade: 66
# Step 163, action: [0.08926124], Trade: 67
# Step 164, action: [1.], Trade: 67
# Step 165, action: [-0.6101891], Trade: 67
# Step 166, action: [-1.], Trade: 68
# Step 167, action: [1.], Trade: 69
# Step 168, action: [0.3007726], Trade: 69
# Step 169, action: [-0.63994575], Trade: 69
# Step 170, action: [0.11208546], Trade: 70
# Step 171, action: [-1.], Trade: 70
# Step 172, action: [-1.], Trade: 71
# Step 173, action: [1.], Trade: 72
# Step 174, action: [0.37855262], Trade: 72
# Step 175, action: [0.41624725], Trade: 72
# Step 176, action: [1.], Trade: 72
# Step 177, action: [-0.5301115], Trade: 72
# Step 178, action: [-0.7725674], Trade: 73
# Step 179, action: [-1.], Trade: 74
# Step 180, action: [0.7104833], Trade: 75
# Step 181, action: [0.02007728], Trade: 75
# Step 182, action: [0.6150101], Trade: 75
# Step 183, action: [1.], Trade: 75
# Step 184, action: [0.01531116], Trade: 75
# Step 185, action: [0.6484513], Trade: 75
# Step 186, action: [1.], Trade: 75
# Step 187, action: [0.77660644], Trade: 75
# Step 188, action: [-1.], Trade: 75
# Step 189, action: [1.], Trade: 76
# Step 190, action: [1.], Trade: 76
# Step 191, action: [0.76162726], Trade: 76
# Step 192, action: [-0.08691367], Trade: 76
# Step 193, action: [-0.2870588], Trade: 76
# Step 194, action: [1.], Trade: 76
# Step 195, action: [-1.], Trade: 76
# Step 196, action: [-1.], Trade: 77
# Step 197, action: [1.], Trade: 77
# Step 198, action: [-0.7721945], Trade: 77
# Step 199, action: [-0.5421879], Trade: 77
# Step 200, action: [-0.70153666], Trade: 77
# Step 201, action: [0.7605852], Trade: 77
# Step 202, action: [-0.96938586], Trade: 77
# Step 203, action: [1.], Trade: 78
# Step 204, action: [-0.33326325], Trade: 78
# Step 205, action: [-0.12377728], Trade: 79
# Step 206, action: [-0.50066614], Trade: 80
# Step 207, action: [-0.7751946], Trade: 81
# Step 208, action: [0.7079568], Trade: 82
# Step 209, action: [1.], Trade: 82
# Step 210, action: [0.34141082], Trade: 82
# Step 211, action: [-0.6397692], Trade: 82
# Step 212, action: [-0.4821029], Trade: 83
# Step 213, action: [-0.7723222], Trade: 84
# Step 214, action: [0.25752383], Trade: 85
# Step 215, action: [-0.37211734], Trade: 85
# Step 216, action: [0.65096784], Trade: 86
# Step 217, action: [-1.], Trade: 86
# Step 218, action: [-0.8271653], Trade: 87
# Step 219, action: [0.3863101], Trade: 87
# Step 220, action: [-0.30603254], Trade: 87
# Step 221, action: [0.13082214], Trade: 88
# Step 222, action: [0.28956622], Trade: 88
# Step 223, action: [-1.], Trade: 88
# Step 224, action: [-0.806045], Trade: 89
# Step 225, action: [0.62220395], Trade: 90
# Step 226, action: [1.], Trade: 90
# Step 227, action: [1.], Trade: 90
# Step 228, action: [1.], Trade: 90
# Step 229, action: [0.5732358], Trade: 90
# Step 230, action: [0.23558949], Trade: 90
# Step 231, action: [1.], Trade: 90
# Step 232, action: [1.], Trade: 90
# Step 233, action: [0.24801902], Trade: 90
# Step 234, action: [-1.], Trade: 90
# Step 235, action: [-1.], Trade: 91
# Step 236, action: [0.5786442], Trade: 91
# Step 237, action: [-0.54450405], Trade: 91
# Step 238, action: [-0.50470626], Trade: 91
# Step 239, action: [0.9768683], Trade: 91
# Step 240, action: [-1.], Trade: 91
# Step 241, action: [-0.09467547], Trade: 91
# Step 242, action: [-0.7075484], Trade: 92
# Step 243, action: [-1.], Trade: 93
# Step 244, action: [0.10751606], Trade: 94
# Step 245, action: [0.45095667], Trade: 94
# Step 246, action: [-0.32163018], Trade: 94
# Step 247, action: [0.0280607], Trade: 95
# Step 248, action: [-0.79016393], Trade: 95
# Step 249, action: [-0.3477185], Trade: 96
# Step 250, action: [-0.94107974], Trade: 97
# Step 251, action: [-0.267669], Trade: 98
# Step 252, action: [0.5651999], Trade: 99
# Step 253, action: [-1.], Trade: 99
# Step 254, action: [0.90957147], Trade: 100
# Step 255, action: [0.38329124], Trade: 100
# Step 256, action: [1.], Trade: 100
# Step 257, action: [-0.8577059], Trade: 100
# Step 258, action: [-1.], Trade: 101
# Step 259, action: [1.], Trade: 102
# Step 260, action: [-1.], Trade: 102
# Step 261, action: [1.], Trade: 103
# Step 262, action: [-0.23887268], Trade: 103
# Step 263, action: [-1.], Trade: 104
# Step 264, action: [0.01710398], Trade: 105
# Step 265, action: [-0.740823], Trade: 105
# Step 266, action: [0.2805953], Trade: 106
# Step 267, action: [0.03144389], Trade: 106
# Step 268, action: [-1.], Trade: 106
# Step 269, action: [0.8454783], Trade: 107
# Step 270, action: [-0.19403186], Trade: 107
# Step 271, action: [-0.62537074], Trade: 108
# Step 272, action: [0.7390177], Trade: 109
# Step 273, action: [-0.19223988], Trade: 109
# Step 274, action: [0.9361202], Trade: 110
# Step 275, action: [-0.2604853], Trade: 110
# Step 276, action: [0.90334076], Trade: 111
# Step 277, action: [-0.41840917], Trade: 111
# Step 278, action: [-1.], Trade: 112
# Step 279, action: [-0.88853335], Trade: 113
# Step 280, action: [0.2584226], Trade: 114
# Step 281, action: [-0.30050352], Trade: 114
# Step 282, action: [1.], Trade: 115
# Step 283, action: [1.], Trade: 115
# Step 284, action: [-0.32063], Trade: 115
# Step 285, action: [-0.524864], Trade: 116
# Step 286, action: [-0.28276116], Trade: 117
# Step 287, action: [0.39535403], Trade: 118
# Step 288, action: [1.], Trade: 118
# Step 289, action: [-0.4826082], Trade: 118
# Step 290, action: [0.6144994], Trade: 119
# Step 291, action: [0.4281157], Trade: 119
# Step 292, action: [0.39642182], Trade: 119
# Step 293, action: [0.41962996], Trade: 119
# Step 294, action: [-0.3377236], Trade: 119
# Step 295, action: [0.2639814], Trade: 120
# Step 296, action: [-0.81473905], Trade: 120
# Step 297, action: [-0.9418126], Trade: 121
# Step 298, action: [0.6411339], Trade: 122
# Step 299, action: [-0.6862406], Trade: 122
# Step 300, action: [1.], Trade: 123
# Step 301, action: [0.00219622], Trade: 123
# Step 302, action: [1.], Trade: 123
# Step 303, action: [-1.], Trade: 123
# Step 304, action: [-1.], Trade: 124
# Step 305, action: [1.], Trade: 124
# Step 306, action: [1.], Trade: 124
# Step 307, action: [-1.], Trade: 124
# Step 308, action: [0.26787746], Trade: 125
# Step 309, action: [-0.9142234], Trade: 125
# Step 310, action: [0.640989], Trade: 125
# Step 311, action: [1.], Trade: 125
# Step 312, action: [0.11106643], Trade: 125
# Step 313, action: [-0.21796489], Trade: 125
# Step 314, action: [0.9236765], Trade: 126
# Step 315, action: [-1.], Trade: 126
# Step 316, action: [0.7877519], Trade: 127
# Step 317, action: [-1.], Trade: 127
# Step 318, action: [0.5863421], Trade: 128
# Step 319, action: [-1.], Trade: 128
# Step 320, action: [0.04877605], Trade: 129
# Step 321, action: [0.5626866], Trade: 129
# Step 322, action: [-0.36191145], Trade: 129
# Step 323, action: [0.22618255], Trade: 130
# Step 324, action: [0.75914735], Trade: 130
# Step 325, action: [0.02239404], Trade: 130
# Step 326, action: [0.40067258], Trade: 130
# Step 327, action: [-1.], Trade: 130
# Step 328, action: [-0.85858864], Trade: 131
# Step 329, action: [-1.], Trade: 132
# Step 330, action: [-1.], Trade: 133
# Step 331, action: [1.], Trade: 134
# Step 332, action: [0.14289062], Trade: 134
# Step 333, action: [0.18395355], Trade: 134
# Step 334, action: [-0.01921728], Trade: 134
# Step 335, action: [1.], Trade: 135
# Step 336, action: [-0.6986211], Trade: 135
# Step 337, action: [0.6368181], Trade: 136
# Step 338, action: [-1.], Trade: 136
# Step 339, action: [0.56543326], Trade: 137
# Step 340, action: [0.3665762], Trade: 137
# Step 341, action: [1.], Trade: 137
# Step 342, action: [0.25260448], Trade: 137
# Step 343, action: [1.], Trade: 137
# Step 344, action: [0.7661813], Trade: 137
# Step 345, action: [-0.08885556], Trade: 137
# Step 346, action: [-0.31999958], Trade: 138
# Step 347, action: [-0.3349097], Trade: 139
# Step 348, action: [0.28966317], Trade: 140
# Step 349, action: [0.5452651], Trade: 140
# Step 350, action: [1.], Trade: 140
# Step 351, action: [0.29676548], Trade: 140
# Step 352, action: [-1.], Trade: 140
# Step 353, action: [-0.43565896], Trade: 141
# Step 354, action: [1.], Trade: 142
# Step 355, action: [0.2650765], Trade: 142
# Step 356, action: [-0.85569906], Trade: 142
# Step 357, action: [-0.97493637], Trade: 143
# Step 358, action: [0.1198425], Trade: 144
# Step 359, action: [0.12798345], Trade: 144
# Step 360, action: [0.60090804], Trade: 144
# Step 361, action: [0.57050055], Trade: 144
# Step 362, action: [-1.], Trade: 144
# Step 363, action: [0.03765453], Trade: 145
# Step 364, action: [-1.], Trade: 145
# Step 365, action: [-1.], Trade: 146
# Step 366, action: [-1.], Trade: 147
# Step 367, action: [-1.], Trade: 148
# Step 368, action: [0.49862668], Trade: 148
# Step 369, action: [-0.74101865], Trade: 148
# Step 370, action: [0.8717199], Trade: 149
# Step 371, action: [-0.5322957], Trade: 149
# Step 372, action: [-0.5396088], Trade: 150
# Step 373, action: [-0.08504789], Trade: 151
# Step 374, action: [0.06301345], Trade: 152
# Step 375, action: [-0.03370903], Trade: 152
# Step 376, action: [-1.], Trade: 153
# Step 377, action: [-1.], Trade: 154
# Step 378, action: [0.66754115], Trade: 154
# Step 379, action: [1.], Trade: 154
# Step 380, action: [0.5682983], Trade: 154
# Step 381, action: [-0.33878314], Trade: 154
# Step 382, action: [0.3903958], Trade: 155
# Step 383, action: [1.], Trade: 155
# Step 384, action: [0.5371022], Trade: 155
# Step 385, action: [-1.], Trade: 155
# Step 386, action: [1.], Trade: 156
# Step 387, action: [0.35884884], Trade: 156
# Step 388, action: [-0.83354366], Trade: 156
# Step 389, action: [-0.37322202], Trade: 157
# Step 390, action: [1.], Trade: 158
# Step 391, action: [0.68361306], Trade: 158
# Step 392, action: [-0.10100017], Trade: 158
# Step 393, action: [0.8114858], Trade: 159
# Step 394, action: [-0.736542], Trade: 159
# Step 395, action: [-1.], Trade: 160
# Step 396, action: [1.], Trade: 161
# Step 397, action: [0.90595865], Trade: 161
# Step 398, action: [0.6117861], Trade: 161
# Step 399, action: [0.14176588], Trade: 161
# Step 400, action: [0.7705505], Trade: 161
# Step 401, action: [-1.], Trade: 161
# Step 402, action: [1.], Trade: 162
# Step 403, action: [-0.99336505], Trade: 162
# Step 404, action: [0.75939924], Trade: 162
# Step 405, action: [-0.89776605], Trade: 162
# Step 406, action: [1.], Trade: 162
# Step 407, action: [-1.], Trade: 162
# Step 408, action: [0.22708791], Trade: 163
# Step 409, action: [1.], Trade: 163
# Step 410, action: [-1.], Trade: 163
# Step 411, action: [1.], Trade: 163
# Step 412, action: [-0.82652724], Trade: 163
# Step 413, action: [-0.54608345], Trade: 163
# Step 414, action: [-0.4571813], Trade: 164
# Step 415, action: [0.30152947], Trade: 165
# Step 416, action: [0.67004704], Trade: 165
# Step 417, action: [-1.], Trade: 165
# Step 418, action: [1.], Trade: 166
# Step 419, action: [0.43814516], Trade: 166
# Step 420, action: [1.], Trade: 166
# Step 421, action: [-0.52838856], Trade: 166
# Step 422, action: [1.], Trade: 167
# Step 423, action: [1.], Trade: 167
# Step 424, action: [-0.05599411], Trade: 167
# Step 425, action: [-1.], Trade: 168
# Step 426, action: [0.35707933], Trade: 169
# Step 427, action: [1.], Trade: 169
# Step 428, action: [-0.76057595], Trade: 169
# Step 429, action: [-0.10710249], Trade: 170
# Step 430, action: [0.16978127], Trade: 171
# Step 431, action: [-1.], Trade: 171
# Step 432, action: [1.], Trade: 172
# Step 433, action: [0.56439537], Trade: 172
# Step 434, action: [0.48841986], Trade: 172
# Step 435, action: [-0.78214854], Trade: 172
# Step 436, action: [1.], Trade: 173
# Step 437, action: [1.], Trade: 173
# Step 438, action: [-0.12149625], Trade: 173
# Step 439, action: [-0.4731445], Trade: 174
# Step 440, action: [-1.], Trade: 175
# Step 441, action: [-0.86322135], Trade: 176
# Step 442, action: [1.], Trade: 177
# Step 443, action: [1.], Trade: 177
# Step 444, action: [-0.77274996], Trade: 177
# Step 445, action: [-1.], Trade: 178
# Step 446, action: [-1.], Trade: 179
# Step 447, action: [0.44633538], Trade: 179
# Step 448, action: [-0.5083171], Trade: 179
# Step 449, action: [-0.7553096], Trade: 180
# Step 450, action: [-0.26185963], Trade: 181
# Step 451, action: [-1.], Trade: 182
# Step 452, action: [1.], Trade: 183
# Step 453, action: [0.682498], Trade: 183
# Step 454, action: [-0.7192547], Trade: 183
# Step 455, action: [0.49156657], Trade: 184
# Step 456, action: [0.5916429], Trade: 184
# Step 457, action: [-0.00535516], Trade: 184
# Step 458, action: [-1.], Trade: 185
# Step 459, action: [0.84089077], Trade: 186
# Step 460, action: [-0.2704419], Trade: 186
# Step 461, action: [-0.05709857], Trade: 187
# Step 462, action: [1.], Trade: 188
# Step 463, action: [-0.43222225], Trade: 188
# Step 464, action: [1.], Trade: 189
# Step 465, action: [-0.29224858], Trade: 189
# Step 466, action: [1.], Trade: 190
# Step 467, action: [-0.08515149], Trade: 190
# Step 468, action: [0.3036891], Trade: 191
# Step 469, action: [0.25907406], Trade: 191
# Step 470, action: [-0.45595744], Trade: 191
# Step 471, action: [1.], Trade: 192
# Step 472, action: [1.], Trade: 192
# Step 473, action: [-0.67987454], Trade: 192
# Step 474, action: [0.62417173], Trade: 193
# Step 475, action: [-0.33692604], Trade: 193
# Step 476, action: [-0.40622523], Trade: 194
# Step 477, action: [-1.], Trade: 195
# Step 478, action: [0.15822117], Trade: 196
# Step 479, action: [0.10064372], Trade: 196
# Step 480, action: [0.74664116], Trade: 196
# Step 481, action: [-1.], Trade: 196
# Step 482, action: [-0.881663], Trade: 197
# Step 483, action: [-0.24073802], Trade: 197
# Step 484, action: [0.2722781], Trade: 198
# Step 485, action: [-0.5491547], Trade: 198
# Step 486, action: [0.31473166], Trade: 199
# Step 487, action: [-0.62879294], Trade: 199
# Step 488, action: [-0.07419975], Trade: 200
# Step 489, action: [-0.67022043], Trade: 201
# Step 490, action: [0.05784771], Trade: 202
# Step 491, action: [-0.2602736], Trade: 202
# Step 492, action: [-1.], Trade: 203
# Step 493, action: [0.99378], Trade: 204
# Step 494, action: [1.], Trade: 204
# Step 495, action: [-0.00182443], Trade: 204
# Step 496, action: [0.11187762], Trade: 205
# Step 497, action: [-0.47575328], Trade: 205
# Step 498, action: [0.27722582], Trade: 206
# Step 499, action: [0.5036417], Trade: 206
# Step 500, action: [0.96678424], Trade: 206
# Step 501, action: [1.], Trade: 206
# Step 502, action: [-0.04295856], Trade: 206
# Step 503, action: [1.], Trade: 207
# Step 504, action: [-0.47339606], Trade: 207
# Step 505, action: [1.], Trade: 208
# Step 506, action: [0.9676001], Trade: 208
# Step 507, action: [-0.9489736], Trade: 208
# Step 508, action: [-0.33288231], Trade: 209
# Step 509, action: [-0.66786724], Trade: 210
# Step 510, action: [0.6740358], Trade: 211
# Step 511, action: [-1.], Trade: 211
# Step 512, action: [-0.00588593], Trade: 212
# Step 513, action: [0.6886317], Trade: 212
# Step 514, action: [-0.33700868], Trade: 212
# Step 515, action: [0.00386043], Trade: 212
# Step 516, action: [0.20089582], Trade: 212
# Step 517, action: [0.60221344], Trade: 212
# Step 518, action: [-1.], Trade: 212
# Step 519, action: [0.7607712], Trade: 213
# Step 520, action: [-0.46684676], Trade: 213
# Step 521, action: [0.5299401], Trade: 214
# Step 522, action: [1.], Trade: 214
# Step 523, action: [0.32758972], Trade: 214
# Step 524, action: [-0.3512239], Trade: 214
# Step 525, action: [0.7236224], Trade: 215
# Step 526, action: [0.26520222], Trade: 215
# Step 527, action: [-0.36164558], Trade: 215
# Step 528, action: [-1.], Trade: 216
# Step 529, action: [0.83420646], Trade: 217
# Step 530, action: [-1.], Trade: 217
# Step 531, action: [-0.60744226], Trade: 218
# Step 532, action: [0.13827273], Trade: 219
# Step 533, action: [-0.5194148], Trade: 219
# Step 534, action: [0.7671983], Trade: 220
# Step 535, action: [1.], Trade: 220
# Step 536, action: [-0.14693543], Trade: 220
# Step 537, action: [-0.07306881], Trade: 221
# Step 538, action: [-1.], Trade: 222
# Step 539, action: [-0.3430691], Trade: 223
# Step 540, action: [-0.7394753], Trade: 224
# Step 541, action: [-0.65795094], Trade: 225
# Step 542, action: [-0.5790153], Trade: 226
# Step 543, action: [-1.], Trade: 227
# Step 544, action: [-0.50043666], Trade: 228
# Step 545, action: [0.8689663], Trade: 228
# Step 546, action: [-0.7001422], Trade: 228
# Step 547, action: [0.7242537], Trade: 228
# Step 548, action: [-0.6224796], Trade: 228
# Step 549, action: [-1.], Trade: 228
# Step 550, action: [-0.994929], Trade: 228
# Step 551, action: [0.5518292], Trade: 229
# Step 552, action: [-1.], Trade: 229
# Step 553, action: [-0.10456196], Trade: 230
# Step 554, action: [1.], Trade: 230
# Step 555, action: [1.], Trade: 230
# Step 556, action: [-0.8212198], Trade: 230
# Step 557, action: [0.13755125], Trade: 231
# Step 558, action: [-1.], Trade: 231
# Step 559, action: [-0.16521545], Trade: 232
# Step 560, action: [-1.], Trade: 233
# Step 561, action: [0.25706592], Trade: 234
# Step 562, action: [-0.91504866], Trade: 234
# Step 563, action: [-0.31535038], Trade: 235
# Step 564, action: [1.], Trade: 236
# Step 565, action: [-1.], Trade: 236
# Step 566, action: [-0.6037865], Trade: 237
# Step 567, action: [0.59598494], Trade: 238
# Step 568, action: [0.74179417], Trade: 238
# Step 569, action: [1.], Trade: 238
# Step 570, action: [1.], Trade: 238
# Step 571, action: [1.], Trade: 238
# Step 572, action: [1.], Trade: 238
# Step 573, action: [-1.], Trade: 238
# Step 574, action: [1.], Trade: 239
# Step 575, action: [0.7890643], Trade: 239
# Step 576, action: [0.24173997], Trade: 239
# Step 577, action: [0.20167474], Trade: 239
# Step 578, action: [0.641035], Trade: 239
# Step 579, action: [0.2558185], Trade: 239
# Step 580, action: [0.93817604], Trade: 239
# Step 581, action: [-0.46376395], Trade: 239
# Step 582, action: [-0.64241886], Trade: 240
# Step 583, action: [-0.37670863], Trade: 241
# Step 584, action: [1.], Trade: 242
# Step 585, action: [-1.], Trade: 242
# Step 586, action: [-0.30519152], Trade: 243
# Step 587, action: [-0.42605042], Trade: 243
# Step 588, action: [-0.6169903], Trade: 243
# Step 589, action: [0.9487749], Trade: 243
# Step 590, action: [0.7425594], Trade: 243
# Step 591, action: [-0.36443138], Trade: 243
# Step 592, action: [0.84780586], Trade: 244
# Step 593, action: [0.39032426], Trade: 244
# Step 594, action: [-1.], Trade: 244
# Step 595, action: [1.], Trade: 245
# Step 596, action: [-1.], Trade: 245
# Step 597, action: [-0.8633623], Trade: 246
# Step 598, action: [0.20009513], Trade: 247
# Step 599, action: [0.04102371], Trade: 247
# Step 600, action: [-1.], Trade: 247
# Step 601, action: [1.], Trade: 248
# Step 602, action: [-0.03527482], Trade: 248
# Step 603, action: [-0.0367553], Trade: 248
# Step 604, action: [0.57194763], Trade: 249
# Step 605, action: [-0.00626172], Trade: 249
# Step 606, action: [-1.], Trade: 250
# Step 607, action: [1.], Trade: 251
# Step 608, action: [-0.6956296], Trade: 251
# Step 609, action: [0.09262555], Trade: 251
# Step 610, action: [-1.], Trade: 251
# Step 611, action: [-0.6064142], Trade: 252
# Step 612, action: [0.35897487], Trade: 252
# Step 613, action: [-0.16790475], Trade: 252
# Step 614, action: [-0.50640804], Trade: 253
# Step 615, action: [1.], Trade: 254
# Step 616, action: [1.], Trade: 254
# Step 617, action: [0.64390635], Trade: 254
# Step 618, action: [0.19202127], Trade: 254
# Step 619, action: [0.35227817], Trade: 254
# Step 620, action: [-0.862931], Trade: 254
# Step 621, action: [0.36952177], Trade: 255
# Step 622, action: [-0.85250354], Trade: 255
# Step 623, action: [-1.], Trade: 256
# Step 624, action: [-1.], Trade: 257
# Step 625, action: [0.3820972], Trade: 257
# Step 626, action: [0.83382076], Trade: 257
# Step 627, action: [0.40074947], Trade: 257
# Step 628, action: [-0.26896158], Trade: 257
# Step 629, action: [-0.7626214], Trade: 258
# Step 630, action: [-0.6433409], Trade: 259
# Step 631, action: [0.4817033], Trade: 260
# Step 632, action: [1.], Trade: 260
# Step 633, action: [0.3764092], Trade: 260
# Step 634, action: [-0.76234484], Trade: 260
# Step 635, action: [-0.6694184], Trade: 261
# Step 636, action: [0.43109617], Trade: 262
# Step 637, action: [1.], Trade: 262
# Step 638, action: [0.64125055], Trade: 262
# Step 639, action: [0.5319222], Trade: 262
# Step 640, action: [0.6496267], Trade: 262
# Step 641, action: [1.], Trade: 262
# Step 642, action: [0.93320173], Trade: 262
# Step 643, action: [1.], Trade: 262
# Step 644, action: [0.20999338], Trade: 262
# Step 645, action: [-0.503077], Trade: 262
# Step 646, action: [-1.], Trade: 263
# Step 647, action: [-0.08675523], Trade: 264
# Step 648, action: [0.297935], Trade: 264
# Step 649, action: [1.], Trade: 264
# Step 650, action: [0.13758451], Trade: 264
# Step 651, action: [1.], Trade: 264
# Step 652, action: [-1.], Trade: 264
# Step 653, action: [0.5230501], Trade: 264
# Step 654, action: [1.], Trade: 264
# Step 655, action: [0.40403366], Trade: 264
# Step 656, action: [0.06828583], Trade: 264
# Step 657, action: [0.22888942], Trade: 264
# Step 658, action: [-1.], Trade: 264
# Step 659, action: [-0.37636876], Trade: 265
# Step 660, action: [1.], Trade: 265
# Step 661, action: [0.79740196], Trade: 265
# Step 662, action: [1.], Trade: 265
# Step 663, action: [0.66906184], Trade: 265
# Step 664, action: [0.21561423], Trade: 265
# Step 665, action: [-0.39904088], Trade: 265
# Step 666, action: [0.26007098], Trade: 266
# Step 667, action: [-1.], Trade: 266
# Step 668, action: [-0.37596604], Trade: 267
# Step 669, action: [1.], Trade: 267
# Step 670, action: [-0.09807029], Trade: 267
# Step 671, action: [0.7673051], Trade: 267
# Step 672, action: [0.300639], Trade: 267
# Step 673, action: [1.], Trade: 267
# Step 674, action: [1.], Trade: 267
# Step 675, action: [0.2508203], Trade: 267
# Step 676, action: [-1.], Trade: 267
# Step 677, action: [-1.], Trade: 268
# Step 678, action: [-0.6429795], Trade: 268
# Step 679, action: [0.8299068], Trade: 268
# Step 680, action: [0.6796979], Trade: 268
# Step 681, action: [-0.5483403], Trade: 268
# Step 682, action: [-1.], Trade: 268
# Step 683, action: [-0.1022657], Trade: 268
# Step 684, action: [-0.63740253], Trade: 268
# Step 685, action: [1.], Trade: 269
# Step 686, action: [0.01527109], Trade: 269
# Step 687, action: [-0.14981447], Trade: 269
# Step 688, action: [-0.65548944], Trade: 270
# Step 689, action: [-0.23395306], Trade: 271
# Step 690, action: [-0.33537927], Trade: 272
# Step 691, action: [-0.03622813], Trade: 273
# Step 692, action: [0.270906], Trade: 274
# Step 693, action: [0.277365], Trade: 274
# Step 694, action: [1.], Trade: 274
# Step 695, action: [-0.22816318], Trade: 274
# Step 696, action: [1.], Trade: 275
# Step 697, action: [1.], Trade: 275
# Step 698, action: [1.], Trade: 275
# Step 699, action: [1.], Trade: 275
# Step 700, action: [-0.4997702], Trade: 275
# Step 701, action: [0.8982194], Trade: 276
# Step 702, action: [-0.43377224], Trade: 276
# Step 703, action: [-0.29606774], Trade: 277
# Step 704, action: [0.96149874], Trade: 278
# Step 705, action: [-1.], Trade: 278
# Step 706, action: [0.81234604], Trade: 279
# Step 707, action: [-0.36706713], Trade: 279
# Step 708, action: [-0.47159988], Trade: 280
# Step 709, action: [-0.02991003], Trade: 281
# Step 710, action: [-0.8671454], Trade: 282
# Step 711, action: [-0.8134121], Trade: 283
# Step 712, action: [-0.14348252], Trade: 284
# Step 713, action: [-0.43436572], Trade: 285
# Step 714, action: [-0.43374798], Trade: 286
# Step 715, action: [1.], Trade: 287
# Step 716, action: [0.14080499], Trade: 287
# Step 717, action: [-1.], Trade: 287
# Step 718, action: [-0.00747577], Trade: 288
# Step 719, action: [-1.], Trade: 288
# Step 720, action: [1.], Trade: 288
# Step 721, action: [-0.1948796], Trade: 288
# Step 722, action: [0.753272], Trade: 289
# Step 723, action: [-0.96240824], Trade: 289
# Step 724, action: [1.], Trade: 290
# Step 725, action: [-0.42841235], Trade: 290
# Step 726, action: [-1.], Trade: 291
# Step 727, action: [-0.09858448], Trade: 292
# Step 728, action: [-0.18750858], Trade: 293
# Step 729, action: [-0.306529], Trade: 294
# Step 730, action: [0.19593279], Trade: 295
# Step 731, action: [1.], Trade: 295
# Step 732, action: [0.05491513], Trade: 295
# Step 733, action: [0.29733622], Trade: 295
# Step 734, action: [-1.], Trade: 295
# Step 735, action: [-0.22794916], Trade: 296
# Step 736, action: [1.], Trade: 297
# Step 737, action: [0.7515101], Trade: 297
# Step 738, action: [1.], Trade: 297
# Step 739, action: [1.], Trade: 297
# Step 740, action: [0.1176396], Trade: 297
# Step 741, action: [-0.69743204], Trade: 297
# Step 742, action: [0.49880877], Trade: 298
# Step 743, action: [-0.57741255], Trade: 298
# Step 744, action: [1.], Trade: 299
# Step 745, action: [0.27322766], Trade: 299
# Step 746, action: [0.77712303], Trade: 299
# Step 747, action: [0.70278865], Trade: 299
# Step 748, action: [-1.], Trade: 299
# Step 749, action: [-1.], Trade: 300
# Step 750, action: [-0.37890112], Trade: 301
# Step 751, action: [0.07819695], Trade: 301
# Step 752, action: [0.00323682], Trade: 301
# Step 753, action: [1.], Trade: 301
# Step 754, action: [-0.9136269], Trade: 301
# Step 755, action: [-0.16893283], Trade: 301
# Step 756, action: [0.88480806], Trade: 301
# Step 757, action: [0.7938382], Trade: 301
# Step 758, action: [0.62137055], Trade: 301
# Step 759, action: [0.8963137], Trade: 301
# Step 760, action: [0.5918284], Trade: 301
# Step 761, action: [-0.22248633], Trade: 301
# Step 762, action: [0.6357822], Trade: 302
# Step 763, action: [-0.85899776], Trade: 302
# Step 764, action: [0.95939654], Trade: 303
# Step 765, action: [-0.12409394], Trade: 303
# Step 766, action: [-0.19785622], Trade: 304
# Step 767, action: [0.20112146], Trade: 305
# Step 768, action: [0.01306149], Trade: 305
# Step 769, action: [-1.], Trade: 305
# Step 770, action: [-0.6832225], Trade: 306
# Step 771, action: [-0.9861111], Trade: 306
# Step 772, action: [1.], Trade: 306
# Step 773, action: [-0.63734615], Trade: 306
# Step 774, action: [-1.], Trade: 307
# Step 775, action: [1.], Trade: 308
# Step 776, action: [-0.7357268], Trade: 308
# Step 777, action: [1.], Trade: 308
# Step 778, action: [-0.25000986], Trade: 308
# Step 779, action: [1.], Trade: 309
# Step 780, action: [0.20937373], Trade: 309
# Step 781, action: [-0.06422779], Trade: 309
# Step 782, action: [-0.55798966], Trade: 310
# Step 783, action: [-1.], Trade: 311
# Step 784, action: [-1.], Trade: 312
# Step 785, action: [-0.35773018], Trade: 313
# Step 786, action: [-0.5509204], Trade: 313
# Step 787, action: [0.91611767], Trade: 313
# Step 788, action: [1.], Trade: 313
# Step 789, action: [-0.8444725], Trade: 313
# Step 790, action: [0.49747065], Trade: 313
# Step 791, action: [-1.], Trade: 313
# Step 792, action: [0.6011264], Trade: 313
# Step 793, action: [0.07259648], Trade: 313
# Step 794, action: [-0.85068333], Trade: 313
# Step 795, action: [1.], Trade: 314
# Step 796, action: [0.5978441], Trade: 314
# Step 797, action: [-0.93359596], Trade: 314
# Step 798, action: [-0.39229074], Trade: 315
# Step 799, action: [0.33258572], Trade: 316
# Step 800, action: [1.], Trade: 316
# Step 801, action: [0.48334393], Trade: 316
# Step 802, action: [-1.], Trade: 316
# Step 803, action: [-0.888419], Trade: 317
# Step 804, action: [1.], Trade: 317
# Step 805, action: [0.49041492], Trade: 317
# Episode: 6, com: WBA, win trade: 142/317, Total reward: -57.03420212609433
# Step 0, action: [0.16028705], Trade: 0
# Step 1, action: [-0.3601413], Trade: 0
# Step 2, action: [0.9424248], Trade: 0
# Step 3, action: [-1.], Trade: 0
# Step 4, action: [1.], Trade: 0
# Step 5, action: [1.], Trade: 0
# Step 6, action: [-0.18827014], Trade: 0
# Step 7, action: [0.04648007], Trade: 1
# Step 8, action: [-0.10687728], Trade: 1
# Step 9, action: [-0.3237344], Trade: 2
# Step 10, action: [-1.], Trade: 3
# Step 11, action: [0.04034489], Trade: 4
# Step 12, action: [1.], Trade: 4
# Step 13, action: [0.5868651], Trade: 4
# Step 14, action: [0.5625016], Trade: 4
# Step 15, action: [-0.5759822], Trade: 4
# Step 16, action: [1.], Trade: 5
# Step 17, action: [-0.4825426], Trade: 5
# Step 18, action: [-1.], Trade: 6
# Step 19, action: [0.0593446], Trade: 7
# Step 20, action: [-0.03119354], Trade: 7
# Step 21, action: [1.], Trade: 7
# Step 22, action: [-1.], Trade: 7
# Step 23, action: [0.893352], Trade: 7
# Step 24, action: [0.9409886], Trade: 7
# Step 25, action: [-1.], Trade: 7
# Step 26, action: [1.], Trade: 8
# Step 27, action: [1.], Trade: 8
# Step 28, action: [-1.], Trade: 8
# Step 29, action: [-0.9755146], Trade: 9
# Step 30, action: [0.41305596], Trade: 9
# Step 31, action: [-0.5997487], Trade: 9
# Step 32, action: [-0.74313366], Trade: 10
# Step 33, action: [-0.32329974], Trade: 11
# Step 34, action: [-0.7242024], Trade: 12
# Step 35, action: [0.67380524], Trade: 13
# Step 36, action: [0.16274917], Trade: 13
# Step 37, action: [1.], Trade: 13
# Step 38, action: [-0.34087703], Trade: 13
# Step 39, action: [0.90811527], Trade: 14
# Step 40, action: [0.09535805], Trade: 14
# Step 41, action: [0.33220077], Trade: 14
# Step 42, action: [1.], Trade: 14
# Step 43, action: [-1.], Trade: 14
# Step 44, action: [-1.], Trade: 15
# Step 45, action: [-1.], Trade: 16
# Step 46, action: [0.8556865], Trade: 17
# Step 47, action: [-0.03797883], Trade: 17
# Step 48, action: [-1.], Trade: 18
# Step 49, action: [0.5284701], Trade: 19
# Step 50, action: [0.17030136], Trade: 19
# Step 51, action: [0.20424125], Trade: 19
# Step 52, action: [0.15987231], Trade: 19
# Step 53, action: [0.869816], Trade: 19
# Step 54, action: [-0.5257759], Trade: 19
# Step 55, action: [-0.3179187], Trade: 20
# Step 56, action: [1.], Trade: 21
# Step 57, action: [-0.518445], Trade: 21
# Step 58, action: [1.], Trade: 22
# Step 59, action: [0.93526214], Trade: 22
# Step 60, action: [-0.6561099], Trade: 22
# Step 61, action: [-0.68556637], Trade: 23
# Step 62, action: [0.45374885], Trade: 24
# Step 63, action: [0.5391743], Trade: 24
# Step 64, action: [-1.], Trade: 24
# Step 65, action: [-0.51920855], Trade: 25
# Step 66, action: [1.], Trade: 25
# Step 67, action: [-1.], Trade: 25
# Step 68, action: [0.61571], Trade: 26
# Step 69, action: [-0.32249576], Trade: 26
# Step 70, action: [1.], Trade: 27
# Step 71, action: [0.21462305], Trade: 27
# Step 72, action: [-1.], Trade: 27
# Step 73, action: [-0.8071621], Trade: 28
# Step 74, action: [0.96495026], Trade: 29
# Step 75, action: [0.71800727], Trade: 29
# Step 76, action: [-0.30019993], Trade: 29
# Step 77, action: [-0.15468538], Trade: 30
# Step 78, action: [1.], Trade: 31
# Step 79, action: [-0.19458829], Trade: 31
# Step 80, action: [1.], Trade: 32
# Step 81, action: [-0.40133262], Trade: 32
# Step 82, action: [0.7578131], Trade: 33
# Step 83, action: [0.8981328], Trade: 33
# Step 84, action: [-1.], Trade: 33
# Step 85, action: [-1.], Trade: 34
# Step 86, action: [1.], Trade: 35
# Step 87, action: [-0.0316762], Trade: 35
# Step 88, action: [-1.], Trade: 36
# Step 89, action: [-1.], Trade: 37
# Step 90, action: [-1.], Trade: 37
# Step 91, action: [-1.], Trade: 37
# Step 92, action: [0.134514], Trade: 38
# Step 93, action: [-1.], Trade: 38
# Step 94, action: [1.], Trade: 38
# Step 95, action: [0.9657407], Trade: 38
# Step 96, action: [1.], Trade: 38
# Step 97, action: [-1.], Trade: 38
# Step 98, action: [0.85693854], Trade: 39
# Step 99, action: [-0.9012882], Trade: 39
# Step 100, action: [0.12380788], Trade: 40
# Step 101, action: [-0.9152373], Trade: 40
# Step 102, action: [0.10150321], Trade: 41
# Step 103, action: [-0.21329011], Trade: 41
# Step 104, action: [-1.], Trade: 42
# Step 105, action: [-1.], Trade: 43
# Step 106, action: [1.], Trade: 44
# Step 107, action: [-1.], Trade: 44
# Step 108, action: [-1.], Trade: 45
# Step 109, action: [0.26028764], Trade: 45
# Step 110, action: [-1.], Trade: 45
# Step 111, action: [-0.8430434], Trade: 45
# Step 112, action: [0.47751632], Trade: 46
# Step 113, action: [-0.08021308], Trade: 46
# Step 114, action: [-0.6628657], Trade: 47
# Step 115, action: [0.98914194], Trade: 48
# Step 116, action: [-1.], Trade: 48
# Step 117, action: [0.55850905], Trade: 49
# Step 118, action: [1.], Trade: 49
# Step 119, action: [-1.], Trade: 49
# Step 120, action: [1.], Trade: 50
# Step 121, action: [-0.67272294], Trade: 50
# Step 122, action: [1.], Trade: 51
# Step 123, action: [-1.], Trade: 51
# Step 124, action: [-1.], Trade: 52
# Step 125, action: [0.24054502], Trade: 52
# Step 126, action: [0.6921074], Trade: 52
# Step 127, action: [1.], Trade: 52
# Step 128, action: [1.], Trade: 52
# Step 129, action: [-0.50956833], Trade: 52
# Step 130, action: [0.3478501], Trade: 53
# Step 131, action: [-1.], Trade: 53
# Step 132, action: [0.31585053], Trade: 54
# Step 133, action: [-0.10340258], Trade: 54
# Step 134, action: [-0.03011055], Trade: 55
# Step 135, action: [-0.4610329], Trade: 56
# Step 136, action: [0.13952395], Trade: 57
# Step 137, action: [1.], Trade: 57
# Step 138, action: [-0.91654843], Trade: 57
# Step 139, action: [0.23311497], Trade: 58
# Step 140, action: [-0.81792647], Trade: 58
# Step 141, action: [-1.], Trade: 59
# Step 142, action: [0.79038686], Trade: 60
# Step 143, action: [-0.02637919], Trade: 60
# Step 144, action: [0.5445687], Trade: 61
# Step 145, action: [1.], Trade: 61
# Step 146, action: [-0.09786277], Trade: 61
# Step 147, action: [0.00766627], Trade: 62
# Step 148, action: [1.], Trade: 62
# Step 149, action: [-1.], Trade: 62
# Step 150, action: [1.], Trade: 63
# Step 151, action: [-0.49703377], Trade: 63
# Step 152, action: [-0.79697883], Trade: 64
# Step 153, action: [-0.690878], Trade: 65
# Step 154, action: [1.], Trade: 66
# Step 155, action: [-0.6108791], Trade: 66
# Step 156, action: [-0.83464044], Trade: 67
# Step 157, action: [0.6156351], Trade: 68
# Step 158, action: [0.00684264], Trade: 68
# Step 159, action: [-0.7690478], Trade: 68
# Step 160, action: [0.31594136], Trade: 69
# Step 161, action: [1.], Trade: 69
# Step 162, action: [-1.], Trade: 69
# Step 163, action: [-0.8722085], Trade: 70
# Step 164, action: [1.], Trade: 71
# Step 165, action: [1.], Trade: 71
# Step 166, action: [-0.07027431], Trade: 71
# Step 167, action: [-0.2645157], Trade: 72
# Step 168, action: [0.3909876], Trade: 73
# Step 169, action: [0.09910046], Trade: 73
# Step 170, action: [0.54529375], Trade: 73
# Step 171, action: [0.2835183], Trade: 73
# Step 172, action: [0.01281278], Trade: 73
# Step 173, action: [-1.], Trade: 73
# Step 174, action: [1.], Trade: 74
# Step 175, action: [1.], Trade: 74
# Step 176, action: [-0.85338587], Trade: 74
# Step 177, action: [0.4994677], Trade: 75
# Step 178, action: [-0.09789145], Trade: 75
# Step 179, action: [-0.15454563], Trade: 76
# Step 180, action: [-0.7606671], Trade: 77
# Step 181, action: [-1.], Trade: 78
# Step 182, action: [-0.6677329], Trade: 79
# Step 183, action: [0.41182324], Trade: 80
# Step 184, action: [-0.94379514], Trade: 80
# Step 185, action: [-0.4385264], Trade: 81
# Step 186, action: [-0.9854696], Trade: 82
# Step 187, action: [-0.29237387], Trade: 83
# Step 188, action: [-0.66690546], Trade: 83
# Step 189, action: [0.89207757], Trade: 84
# Step 190, action: [1.], Trade: 84
# Step 191, action: [0.9755477], Trade: 84
# Step 192, action: [0.6156848], Trade: 84
# Step 193, action: [0.78643924], Trade: 84
# Step 194, action: [-0.31197393], Trade: 84
# Step 195, action: [0.30319577], Trade: 85
# Step 196, action: [1.], Trade: 85
# Step 197, action: [0.1772772], Trade: 85
# Step 198, action: [-1.], Trade: 85
# Step 199, action: [-0.02160692], Trade: 86
# Step 200, action: [1.], Trade: 86
# Step 201, action: [-0.89368224], Trade: 86
# Step 202, action: [-0.4687542], Trade: 87
# Step 203, action: [0.30563974], Trade: 88
# Step 204, action: [-0.60313624], Trade: 88
# Step 205, action: [-0.25755802], Trade: 89
# Step 206, action: [-0.5943128], Trade: 90
# Step 207, action: [0.70328677], Trade: 91
# Step 208, action: [-1.], Trade: 91
# Step 209, action: [0.67165226], Trade: 92
# Step 210, action: [0.952105], Trade: 92
# Step 211, action: [0.79522574], Trade: 92
# Step 212, action: [-0.19853505], Trade: 92
# Step 213, action: [1.], Trade: 93
# Step 214, action: [1.], Trade: 93
# Step 215, action: [0.20732589], Trade: 93
# Step 216, action: [-0.02948163], Trade: 93
# Step 217, action: [0.9814945], Trade: 94
# Step 218, action: [-1.], Trade: 94
# Step 219, action: [-0.21513805], Trade: 95
# Step 220, action: [-0.01170491], Trade: 95
# Step 221, action: [-1.], Trade: 95
# Step 222, action: [1.], Trade: 95
# Step 223, action: [0.5160301], Trade: 95
# Step 224, action: [-0.22614533], Trade: 95
# Step 225, action: [0.03686535], Trade: 96
# Step 226, action: [0.16543013], Trade: 96
# Step 227, action: [-0.47453013], Trade: 96
# Step 228, action: [0.5964759], Trade: 97
# Step 229, action: [-0.5880933], Trade: 97
# Step 230, action: [0.8561531], Trade: 98
# Step 231, action: [-0.2910388], Trade: 98
# Step 232, action: [0.08794272], Trade: 99
# Step 233, action: [-0.38423055], Trade: 99
# Step 234, action: [0.23934446], Trade: 100
# Step 235, action: [-0.45401368], Trade: 100
# Step 236, action: [0.09210515], Trade: 101
# Step 237, action: [-1.], Trade: 101
# Step 238, action: [-0.21010695], Trade: 102
# Step 239, action: [-0.07199515], Trade: 102
# Step 240, action: [-0.8812805], Trade: 103
# Step 241, action: [0.21395789], Trade: 104
# Step 242, action: [-0.3894313], Trade: 104
# Step 243, action: [1.], Trade: 105
# Step 244, action: [0.15535134], Trade: 105
# Step 245, action: [-0.01081197], Trade: 105
# Step 246, action: [0.20971423], Trade: 106
# Step 247, action: [-0.62658966], Trade: 106
# Step 248, action: [-0.71902484], Trade: 107
# Step 249, action: [1.], Trade: 108
# Step 250, action: [1.], Trade: 108
# Step 251, action: [0.48508292], Trade: 108
# Step 252, action: [-0.42167813], Trade: 108
# Step 253, action: [1.], Trade: 109
# Step 254, action: [-0.7226061], Trade: 109
# Step 255, action: [-1.], Trade: 110
# Step 256, action: [0.08848518], Trade: 111
# Step 257, action: [1.], Trade: 111
# Step 258, action: [-1.], Trade: 111
# Step 259, action: [-0.76665395], Trade: 112
# Step 260, action: [0.5897446], Trade: 112
# Step 261, action: [-1.], Trade: 112
# Step 262, action: [-1.], Trade: 113
# Step 263, action: [0.1865178], Trade: 114
# Step 264, action: [1.], Trade: 114
# Step 265, action: [0.7541217], Trade: 114
# Step 266, action: [0.4315055], Trade: 114
# Step 267, action: [0.7391115], Trade: 114
# Step 268, action: [0.25947383], Trade: 114
# Step 269, action: [-0.44213766], Trade: 114
# Step 270, action: [-1.], Trade: 115
# Step 271, action: [1.], Trade: 116
# Step 272, action: [-1.], Trade: 116
# Step 273, action: [0.72430086], Trade: 116
# Step 274, action: [-0.07150172], Trade: 116
# Step 275, action: [-0.80492234], Trade: 116
# Step 276, action: [0.659064], Trade: 116
# Step 277, action: [-0.5813964], Trade: 116
# Step 278, action: [-0.3513184], Trade: 117
# Step 279, action: [0.8007982], Trade: 118
# Step 280, action: [0.9045746], Trade: 118
# Step 281, action: [0.39370546], Trade: 118
# Step 282, action: [0.66837966], Trade: 118
# Step 283, action: [-0.19444562], Trade: 118
# Step 284, action: [0.07510478], Trade: 119
# Step 285, action: [0.11570831], Trade: 119
# Step 286, action: [0.856176], Trade: 119
# Step 287, action: [-1.], Trade: 119
# Step 288, action: [0.15711989], Trade: 120
# Step 289, action: [-0.03244236], Trade: 120
# Step 290, action: [-0.61438185], Trade: 121
# Step 291, action: [0.24131036], Trade: 122
# Step 292, action: [0.778776], Trade: 122
# Step 293, action: [-1.], Trade: 122
# Step 294, action: [1.], Trade: 123
# Step 295, action: [1.], Trade: 123
# Step 296, action: [1.], Trade: 123
# Step 297, action: [1.], Trade: 123
# Step 298, action: [-1.], Trade: 123
# Step 299, action: [0.2498097], Trade: 124
# Step 300, action: [-0.00619754], Trade: 124
# Step 301, action: [-1.], Trade: 125
# Step 302, action: [-0.40424088], Trade: 126
# Step 303, action: [0.38387498], Trade: 126
# Step 304, action: [0.1412181], Trade: 126
# Step 305, action: [1.], Trade: 126
# Step 306, action: [0.5161988], Trade: 126
# Step 307, action: [-0.11569199], Trade: 126
# Step 308, action: [1.], Trade: 127
# Step 309, action: [0.37618917], Trade: 127
# Step 310, action: [0.5275317], Trade: 127
# Step 311, action: [1.], Trade: 127
# Step 312, action: [0.19309126], Trade: 127
# Step 313, action: [0.14226303], Trade: 127
# Step 314, action: [0.7886119], Trade: 127
# Step 315, action: [1.], Trade: 127
# Step 316, action: [1.], Trade: 127
# Step 317, action: [1.], Trade: 127
# Step 318, action: [0.5606941], Trade: 127
# Step 319, action: [-0.3662151], Trade: 127
# Step 320, action: [1.], Trade: 128
# Step 321, action: [-0.59016466], Trade: 128
# Step 322, action: [-0.4414195], Trade: 129
# Step 323, action: [1.], Trade: 130
# Step 324, action: [-0.6237903], Trade: 130
# Step 325, action: [1.], Trade: 131
# Step 326, action: [1.], Trade: 131
# Step 327, action: [-1.], Trade: 131
# Step 328, action: [0.21787451], Trade: 132
# Step 329, action: [-1.], Trade: 132
# Step 330, action: [-0.21165857], Trade: 133
# Step 331, action: [-1.], Trade: 134
# Step 332, action: [0.7460824], Trade: 135
# Step 333, action: [-0.68718624], Trade: 135
# Step 334, action: [-1.], Trade: 136
# Step 335, action: [1.], Trade: 137
# Step 336, action: [0.06406198], Trade: 137
# Step 337, action: [0.3110735], Trade: 137
# Step 338, action: [0.20205277], Trade: 137
# Step 339, action: [1.], Trade: 137
# Step 340, action: [-0.5032274], Trade: 137
# Step 341, action: [-0.9500817], Trade: 138
# Step 342, action: [1.], Trade: 139
# Step 343, action: [-0.06038553], Trade: 139
# Step 344, action: [-0.41603932], Trade: 140
# Step 345, action: [1.], Trade: 141
# Step 346, action: [0.8916052], Trade: 141
# Step 347, action: [-0.16474524], Trade: 141
# Step 348, action: [0.98887444], Trade: 142
# Step 349, action: [0.1719527], Trade: 142
# Step 350, action: [-0.9300379], Trade: 142
# Step 351, action: [0.06459069], Trade: 143
# Step 352, action: [1.], Trade: 143
# Step 353, action: [-0.43155906], Trade: 143
# Step 354, action: [0.9524993], Trade: 144
# Step 355, action: [0.20046541], Trade: 144
# Step 356, action: [0.63883984], Trade: 144
# Step 357, action: [-0.94993305], Trade: 144
# Step 358, action: [-1.], Trade: 145
# Step 359, action: [0.77431273], Trade: 146
# Step 360, action: [1.], Trade: 146
# Step 361, action: [1.], Trade: 146
# Step 362, action: [1.], Trade: 146
# Step 363, action: [0.08194553], Trade: 146
# Step 364, action: [-0.0647793], Trade: 146
# Step 365, action: [1.], Trade: 147
# Step 366, action: [0.03089726], Trade: 147
# Step 367, action: [0.28876522], Trade: 147
# Step 368, action: [-0.6792368], Trade: 147
# Step 369, action: [-1.], Trade: 148
# Step 370, action: [0.50021], Trade: 149
# Step 371, action: [0.35726455], Trade: 149
# Step 372, action: [-0.41365832], Trade: 149
# Step 373, action: [0.65021324], Trade: 150
# Step 374, action: [-0.9456592], Trade: 150
# Step 375, action: [1.], Trade: 151
# Step 376, action: [0.69321567], Trade: 151
# Step 377, action: [-0.30354017], Trade: 151
# Step 378, action: [0.40434316], Trade: 152
# Step 379, action: [1.], Trade: 152
# Step 380, action: [-1.], Trade: 152
# Step 381, action: [-0.2469802], Trade: 153
# Step 382, action: [-0.6191765], Trade: 153
# Step 383, action: [-0.13438712], Trade: 153
# Step 384, action: [-0.86451787], Trade: 154
# Step 385, action: [0.7418478], Trade: 155
# Step 386, action: [0.09903466], Trade: 155
# Step 387, action: [0.18498516], Trade: 155
# Step 388, action: [0.9092583], Trade: 155
# Step 389, action: [0.5484152], Trade: 155
# ...
# Step 218, action: [0.40133002], Trade: 87
# Step 219, action: [1.], Trade: 87
# Step 220, action: [0.2472415], Trade: 87
# Step 221, action: [0.22124822], Trade: 87
# Step 222, action: [-0.6396419], Trade: 87
# Step 223, action: [-0.440837], Trade: 88
# Step 224, action: [0.45916054], Trade: 89
# Step 225, action: [0.03762652], Trade: 89
# Step 226, action: [0.528672], Trade: 89
# Step 227, action: [0.02010996], Trade: 89
# Step 228, action: [0.52125055], Trade: 89
# Step 229, action: [0.7694155], Trade: 89
# Step 230, action: [0.8105615], Trade: 89
# Step 231, action: [0.06107546], Trade: 89
# Step 232, action: [0.60116005], Trade: 89
# Step 233, action: [0.91422707], Trade: 89
# Step 234, action: [-0.42425758], Trade: 89
# Step 235, action: [-1.], Trade: 90
# Step 236, action: [-0.89154345], Trade: 91
# Step 237, action: [0.82317424], Trade: 92
# Step 238, action: [-0.9908395], Trade: 92
# Step 239, action: [-1.], Trade: 93
# Step 240, action: [-0.60393137], Trade: 93
# Step 241, action: [-0.65892255], Trade: 93
# Step 242, action: [-0.4152525], Trade: 93
# Step 243, action: [0.1409238], Trade: 94
# Step 244, action: [0.43208772], Trade: 94
# Step 245, action: [0.48767826], Trade: 94
# Step 246, action: [0.16627988], Trade: 94
# Step 247, action: [-0.6239073], Trade: 94
# Step 248, action: [-0.45010796], Trade: 95
# Step 249, action: [0.22891779], Trade: 96
# Step 250, action: [-0.02513067], Trade: 96
# Step 251, action: [-0.29791215], Trade: 97
# Step 252, action: [-1.], Trade: 98
# Step 253, action: [0.18374942], Trade: 99
# Step 254, action: [-1.], Trade: 99
# Step 255, action: [1.], Trade: 100
# Step 256, action: [0.27696824], Trade: 100
# Step 257, action: [0.29962954], Trade: 100
# Step 258, action: [-0.3530664], Trade: 100
# Step 259, action: [0.55822587], Trade: 101
# Step 260, action: [-1.], Trade: 101
# Step 261, action: [0.7659533], Trade: 102
# Step 262, action: [-0.08876816], Trade: 102
# Step 263, action: [1.], Trade: 102
# Step 264, action: [0.2275973], Trade: 102
# Step 265, action: [0.62486297], Trade: 102
# Step 266, action: [0.13144615], Trade: 102
# Step 267, action: [-0.47740266], Trade: 102
# Step 268, action: [-0.9454716], Trade: 103
# Step 269, action: [-1.], Trade: 104
# Step 270, action: [-0.21461672], Trade: 105
# Step 271, action: [-1.], Trade: 105
# Step 272, action: [0.51357716], Trade: 105
# Step 273, action: [-0.27431247], Trade: 105
# Step 274, action: [-0.40548545], Trade: 105
# Step 275, action: [-1.], Trade: 105
# Step 276, action: [0.9829952], Trade: 105
# Step 277, action: [0.7773335], Trade: 105
# Step 278, action: [0.14796223], Trade: 105
# Step 279, action: [0.4966814], Trade: 105
# Step 280, action: [1.], Trade: 105
# Step 281, action: [-1.], Trade: 105
# Step 282, action: [-1.], Trade: 106
# Step 283, action: [0.7256999], Trade: 107
# Step 284, action: [-0.63923216], Trade: 107
# Step 285, action: [1.], Trade: 108
# Step 286, action: [0.58153415], Trade: 108
# Step 287, action: [-0.8152866], Trade: 108
# Step 288, action: [-0.29745042], Trade: 109
# Step 289, action: [0.50116974], Trade: 110
# Step 290, action: [-0.13524729], Trade: 110
# Step 291, action: [1.], Trade: 111
# Step 292, action: [-1.], Trade: 111
# Step 293, action: [0.76458627], Trade: 112
# Step 294, action: [-0.23977478], Trade: 112
# Step 295, action: [-0.69724363], Trade: 113
# Step 296, action: [0.46205816], Trade: 114
# Step 297, action: [-0.5015053], Trade: 114
# Step 298, action: [-1.], Trade: 115
# Step 299, action: [-0.5780381], Trade: 116
# Step 300, action: [-0.24002393], Trade: 116
# Step 301, action: [-1.], Trade: 116
# Step 302, action: [1.], Trade: 117
# Step 303, action: [-0.0855699], Trade: 117
# Step 304, action: [1.], Trade: 117
# Step 305, action: [0.6314608], Trade: 117
# Step 306, action: [0.12764995], Trade: 117
# Step 307, action: [-0.33828935], Trade: 117
# Step 308, action: [-0.65054053], Trade: 118
# Step 309, action: [0.46754742], Trade: 119
# Step 310, action: [0.22820021], Trade: 119
# Step 311, action: [-0.19983402], Trade: 119
# Step 312, action: [-1.], Trade: 120
# Step 313, action: [-0.8248021], Trade: 121
# Step 314, action: [1.], Trade: 121
# Step 315, action: [1.], Trade: 121
# Step 316, action: [-0.9860784], Trade: 121
# Step 317, action: [-1.], Trade: 122
# Step 318, action: [-0.51297575], Trade: 123
# Step 319, action: [1.], Trade: 123
# Step 320, action: [-0.5105682], Trade: 123
# Step 321, action: [-1.], Trade: 124
# Step 322, action: [-0.25949556], Trade: 125
# Step 323, action: [0.20049357], Trade: 125
# Step 324, action: [-0.7301159], Trade: 125
# Step 325, action: [0.10966931], Trade: 126
# Step 326, action: [1.], Trade: 126
# Step 327, action: [-0.13116054], Trade: 126
# Step 328, action: [0.29098776], Trade: 127
# Step 329, action: [-0.79241973], Trade: 127
# Step 330, action: [1.], Trade: 128
# Step 331, action: [0.7752272], Trade: 128
# Step 332, action: [-0.8770657], Trade: 128
# Step 333, action: [0.18887046], Trade: 129
# Step 334, action: [0.8764711], Trade: 129
# Step 335, action: [1.], Trade: 129
# Step 336, action: [-0.78988785], Trade: 129
# Step 337, action: [0.07471369], Trade: 130
# Step 338, action: [1.], Trade: 130
# Step 339, action: [-0.31827375], Trade: 130
# Step 340, action: [-0.8725666], Trade: 131
# Step 341, action: [0.44521406], Trade: 132
# Step 342, action: [1.], Trade: 132
# Step 343, action: [-1.], Trade: 132
# Step 344, action: [1.], Trade: 133
# Step 345, action: [-0.86695033], Trade: 133
# Step 346, action: [-0.04139689], Trade: 133
# Step 347, action: [-1.], Trade: 134
# Step 348, action: [-0.999733], Trade: 135
# Step 349, action: [-0.26575136], Trade: 135
# Step 350, action: [0.88596004], Trade: 136
# Step 351, action: [-1.], Trade: 136
# Step 352, action: [1.], Trade: 137
# Step 353, action: [1.], Trade: 137
# Step 354, action: [1.], Trade: 137
# Step 355, action: [0.02301859], Trade: 137
# Step 356, action: [-1.], Trade: 137
# Step 357, action: [-1.], Trade: 138
# Step 358, action: [-0.4328517], Trade: 139
# Step 359, action: [-0.12369003], Trade: 139
# Step 360, action: [0.02986116], Trade: 139
# Step 361, action: [-0.6442868], Trade: 139
# Step 362, action: [0.6704102], Trade: 139
# Step 363, action: [0.1391192], Trade: 139
# Step 364, action: [0.7656752], Trade: 139
# Step 365, action: [-1.], Trade: 139
# Step 366, action: [-0.9486543], Trade: 140
# Step 367, action: [-1.], Trade: 140
# Step 368, action: [0.0304593], Trade: 141
# Step 369, action: [-1.], Trade: 141
# Step 370, action: [-0.30592623], Trade: 142
# Step 371, action: [0.30504945], Trade: 142
# Step 372, action: [-0.5494091], Trade: 142
# Step 373, action: [-1.], Trade: 142
# Step 374, action: [-0.6615066], Trade: 143
# Step 375, action: [-1.], Trade: 143
# Step 376, action: [0.50106984], Trade: 143
# Step 377, action: [-1.], Trade: 143
# Step 378, action: [-1.], Trade: 144
# Step 379, action: [-0.2811469], Trade: 144
# Step 380, action: [1.], Trade: 144
# Step 381, action: [-0.9231848], Trade: 144
# Step 382, action: [1.], Trade: 145
# Step 383, action: [0.48661575], Trade: 145
# Step 384, action: [-0.24987389], Trade: 145
# Step 385, action: [-0.98684996], Trade: 146
# Step 386, action: [1.], Trade: 147
# Step 387, action: [1.], Trade: 147
# Step 388, action: [0.8602887], Trade: 147
# Step 389, action: [1.], Trade: 147
# Step 390, action: [0.5173457], Trade: 147
# Step 391, action: [-1.], Trade: 147
# Step 392, action: [-0.07423026], Trade: 148
# Step 393, action: [0.5731968], Trade: 148
# Step 394, action: [-1.], Trade: 148
# Step 395, action: [-0.42223254], Trade: 148
# Step 396, action: [-0.37268114], Trade: 148
# Step 397, action: [-0.5770103], Trade: 148
# Step 398, action: [0.9160661], Trade: 148
# Step 399, action: [0.8475913], Trade: 148
# Step 400, action: [1.], Trade: 148
# Step 401, action: [0.47291327], Trade: 148
# Step 402, action: [-0.60176414], Trade: 148
# Step 403, action: [0.5952094], Trade: 149
# Step 404, action: [0.66013694], Trade: 149
# Step 405, action: [1.], Trade: 149
# Step 406, action: [-1.], Trade: 149
# Step 407, action: [-0.58786345], Trade: 150
# Step 408, action: [-1.], Trade: 150
# Step 409, action: [0.62703806], Trade: 151
# Step 410, action: [0.58864737], Trade: 151
# Step 411, action: [1.], Trade: 151
# Step 412, action: [0.9055015], Trade: 151
# Step 413, action: [-0.71582776], Trade: 151
# Step 414, action: [0.10528173], Trade: 152
# Step 415, action: [0.4701032], Trade: 152
# Step 416, action: [1.], Trade: 152
# Step 417, action: [0.9468914], Trade: 152
# Step 418, action: [-0.02758924], Trade: 152
# Step 419, action: [1.], Trade: 153
# Step 420, action: [0.96467793], Trade: 153
# Step 421, action: [-0.48153958], Trade: 153
# Step 422, action: [-0.71325105], Trade: 154
# Step 423, action: [0.19098227], Trade: 155
# Step 424, action: [-1.], Trade: 155
# Step 425, action: [1.], Trade: 156
# Step 426, action: [1.], Trade: 156
# Step 427, action: [-0.9927298], Trade: 156
# Step 428, action: [0.10333894], Trade: 156
# Step 429, action: [1.], Trade: 156
# Step 430, action: [-0.00146111], Trade: 156
# Step 431, action: [0.05636908], Trade: 157
# Step 432, action: [-0.9987031], Trade: 157
# Step 433, action: [1.], Trade: 158
# Step 434, action: [-0.07596877], Trade: 158
# Step 435, action: [-0.8504751], Trade: 159
# --------------------------------------
# | raw/                        |      |
# |    gen/time/fps             | 128  |
# |    gen/time/iterations      | 1    |
# |    gen/time/time_elapsed    | 15   |
# |    gen/time/total_timesteps | 2048 |
# --------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.453    |
# |    disc/disc_acc_expert             | 0.906    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.698    |
# |    disc/disc_proportion_expert_pred | 0.953    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.484    |
# |    disc/disc_acc_expert             | 0.969    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.695    |
# |    disc/disc_proportion_expert_pred | 0.984    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.692    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.692    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.684    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.691    |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.492     |
# |    disc/disc_acc_expert             | 0.984     |
# |    disc/disc_acc_gen                | 0         |
# |    disc/disc_entropy                | 0.69      |
# |    disc/disc_loss                   | 0.686     |
# |    disc/disc_proportion_expert_pred | 0.992     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 1         |
# |    disc/n_expert                    | 64        |
# |    disc/n_generated                 | 64        |
# |    gen/time/fps                     | 128       |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 15        |
# |    gen/time/total_timesteps         | 2.05e+03  |
# |    gen/train/approx_kl              | 1.83e-08  |
# |    gen/train/clip_fraction          | 0         |
# |    gen/train/clip_range             | 0.1       |
# |    gen/train/entropy_loss           | -1.42     |
# |    gen/train/explained_variance     | -2.12e-05 |
# |    gen/train/learning_rate          | 0.00025   |
# |    gen/train/loss                   | 4.09e+08  |
# |    gen/train/n_updates              | 5         |
# |    gen/train/policy_gradient_loss   | -2.72e-05 |
# |    gen/train/std                    | 1         |
# |    gen/train/value_loss             | 8.19e+08  |
# ---------------------------------------------------
# round: 100%|██████████████████████████████████████| 1/1 [00:16<00:00, 16.08s/it]

# %% [markdown]
# ... and finally evaluate it again.

# %%
env_train.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, env_train, 1, return_episode_rewards=True
)
# Out:
# Step 0, action: [-0.00141055], Trade: 0
# Step 1, action: [-0.00141055], Trade: 0
# Step 2, action: [-0.00141055], Trade: 0
# Step 3, action: [-0.00141055], Trade: 0
# Step 4, action: [-0.00141055], Trade: 0
# Step 5, action: [-0.00141055], Trade: 0
# Step 6, action: [-0.00141055], Trade: 0
# Step 7, action: [-0.00141055], Trade: 0
# Step 8, action: [-0.00141055], Trade: 0
# Step 9, action: [-0.00141055], Trade: 0
# Step 10, action: [-0.00141055], Trade: 0
# Step 11, action: [-0.00141055], Trade: 0
# Step 12, action: [-0.00141055], Trade: 0
# Step 13, action: [-0.00141055], Trade: 0
# Step 14, action: [-0.00141055], Trade: 0
# Step 15, action: [-0.00141055], Trade: 0
# Step 16, action: [-0.00141055], Trade: 0
# Step 17, action: [-0.00141055], Trade: 0
# Step 18, action: [-0.00141055], Trade: 0
# Step 19, action: [-0.00141055], Trade: 0
# Step 20, action: [-0.00141055], Trade: 0
# Step 21, action: [-0.00141055], Trade: 0
# Step 22, action: [-0.00141055], Trade: 0
# Step 23, action: [-0.00141055], Trade: 0
# Step 24, action: [-0.00141055], Trade: 0
# Step 25, action: [-0.00141055], Trade: 0
# Step 26, action: [-0.00141055], Trade: 0
# Step 27, action: [-0.00141055], Trade: 0
# Step 28, action: [-0.00141055], Trade: 0
# Step 29, action: [-0.00141055], Trade: 0
# Step 30, action: [-0.00141055], Trade: 0
# Step 31, action: [-0.00141055], Trade: 0
# Step 32, action: [-0.00141055], Trade: 0
# Step 33, action: [-0.00141055], Trade: 0
# Step 34, action: [-0.00141055], Trade: 0
# Step 35, action: [-0.00141055], Trade: 0
# Step 36, action: [-0.00141055], Trade: 0
# Step 37, action: [-0.00141055], Trade: 0
# Step 38, action: [-0.00141055], Trade: 0
# Step 39, action: [-0.00141055], Trade: 0
# Step 40, action: [-0.00141055], Trade: 0
# Step 41, action: [-0.00141055], Trade: 0
# Step 42, action: [-0.00141055], Trade: 0
# Step 43, action: [-0.00141055], Trade: 0
# Step 44, action: [-0.00141055], Trade: 0
# Step 45, action: [-0.00141055], Trade: 0
# Step 46, action: [-0.00141055], Trade: 0
# Step 47, action: [-0.00141055], Trade: 0
# Step 48, action: [-0.00141055], Trade: 0
# Step 49, action: [-0.00141055], Trade: 0
# Step 50, action: [-0.00141055], Trade: 0
# Step 51, action: [-0.00141055], Trade: 0
# Step 52, action: [-0.00141055], Trade: 0
# Step 53, action: [-0.00141055], Trade: 0
# Step 54, action: [-0.00141055], Trade: 0
# Step 55, action: [-0.00141055], Trade: 0
# Step 56, action: [-0.00141055], Trade: 0
# Step 57, action: [-0.00141055], Trade: 0
# Step 58, action: [-0.00141055], Trade: 0
# Step 59, action: [-0.00141055], Trade: 0
# Step 60, action: [-0.00141055], Trade: 0
# Step 61, action: [-0.00141055], Trade: 0
# Step 62, action: [-0.00141055], Trade: 0
# Step 63, action: [-0.00141055], Trade: 0
# Step 64, action: [-0.00141055], Trade: 0
# Step 65, action: [-0.00141055], Trade: 0
# Step 66, action: [-0.00141055], Trade: 0
# Step 67, action: [-0.00141055], Trade: 0
# Step 68, action: [-0.00141055], Trade: 0
# Step 69, action: [-0.00141055], Trade: 0
# Step 70, action: [-0.00141055], Trade: 0
# Step 71, action: [-0.00141055], Trade: 0
# Step 72, action: [-0.00141055], Trade: 0
# Step 73, action: [-0.00141055], Trade: 0
# Step 74, action: [-0.00141055], Trade: 0
# Step 75, action: [-0.00141055], Trade: 0
# Step 76, action: [-0.00141055], Trade: 0
# Step 77, action: [-0.00141055], Trade: 0
# Step 78, action: [-0.00141055], Trade: 0
# Step 79, action: [-0.00141055], Trade: 0
# Step 80, action: [-0.00141055], Trade: 0
# Step 81, action: [-0.00141055], Trade: 0
# Step 82, action: [-0.00141055], Trade: 0
# Step 83, action: [-0.00141055], Trade: 0
# Step 84, action: [-0.00141055], Trade: 0
# Step 85, action: [-0.00141055], Trade: 0
# Step 86, action: [-0.00141055], Trade: 0
# Step 87, action: [-0.00141055], Trade: 0
# Step 88, action: [-0.00141055], Trade: 0
# Step 89, action: [-0.00141055], Trade: 0
# Step 90, action: [-0.00141055], Trade: 0
# Step 91, action: [-0.00141055], Trade: 0
# Step 92, action: [-0.00141055], Trade: 0
# Step 93, action: [-0.00141055], Trade: 0
# Step 94, action: [-0.00141055], Trade: 0
# Step 95, action: [-0.00141055], Trade: 0
# Step 96, action: [-0.00141055], Trade: 0
# Step 97, action: [-0.00141055], Trade: 0
# Step 98, action: [-0.00141055], Trade: 0
# Step 99, action: [-0.00141055], Trade: 0
# Step 100, action: [-0.00141055], Trade: 0
# Step 101, action: [-0.00141055], Trade: 0
# Step 102, action: [-0.00141055], Trade: 0
# Step 103, action: [-0.00141055], Trade: 0
# Step 104, action: [-0.00141055], Trade: 0
# Step 105, action: [-0.00141055], Trade: 0
# Step 106, action: [-0.00141055], Trade: 0
# Step 107, action: [-0.00141055], Trade: 0
# Step 108, action: [-0.00141055], Trade: 0
# Step 109, action: [-0.00141055], Trade: 0
# Step 110, action: [-0.00141055], Trade: 0
# Step 111, action: [-0.00141055], Trade: 0
# Step 112, action: [-0.00141055], Trade: 0
# Step 113, action: [-0.00141055], Trade: 0
# Step 114, action: [-0.00141055], Trade: 0
# Step 115, action: [-0.00141055], Trade: 0
# Step 116, action: [-0.00141055], Trade: 0
# Step 117, action: [-0.00141055], Trade: 0
# Step 118, action: [-0.00141055], Trade: 0
# Step 119, action: [-0.00141055], Trade: 0
# Step 120, action: [-0.00141055], Trade: 0
# Step 121, action: [-0.00141055], Trade: 0
# Step 122, action: [-0.00141055], Trade: 0
# Step 123, action: [-0.00141055], Trade: 0
# Step 124, action: [-0.00141055], Trade: 0
# Step 125, action: [-0.00141055], Trade: 0
# Step 126, action: [-0.00141055], Trade: 0
# Step 127, action: [-0.00141055], Trade: 0
# Step 128, action: [-0.00141055], Trade: 0
# Step 129, action: [-0.00141055], Trade: 0
# Step 130, action: [-0.00141055], Trade: 0
# Step 131, action: [-0.00141055], Trade: 0
# Step 132, action: [-0.00141055], Trade: 0
# Step 133, action: [-0.00141055], Trade: 0
# Step 134, action: [-0.00141055], Trade: 0
# Step 135, action: [-0.00141055], Trade: 0
# Step 136, action: [-0.00141055], Trade: 0
# Step 137, action: [-0.00141055], Trade: 0
# Step 138, action: [-0.00141055], Trade: 0
# Step 139, action: [-0.00141055], Trade: 0
# Step 140, action: [-0.00141055], Trade: 0
# Step 141, action: [-0.00141055], Trade: 0
# Step 142, action: [-0.00141055], Trade: 0
# Step 143, action: [-0.00141055], Trade: 0
# Step 144, action: [-0.00141055], Trade: 0
# Step 145, action: [-0.00141055], Trade: 0
# Step 146, action: [-0.00141055], Trade: 0
# Step 147, action: [-0.00141055], Trade: 0
# Step 148, action: [-0.00141055], Trade: 0
# Step 149, action: [-0.00141055], Trade: 0
# Step 150, action: [-0.00141055], Trade: 0
# Step 151, action: [-0.00141055], Trade: 0
# Step 152, action: [-0.00141055], Trade: 0
# Step 153, action: [-0.00141055], Trade: 0
# Step 154, action: [-0.00141055], Trade: 0
# Step 155, action: [-0.00141055], Trade: 0
# Step 156, action: [-0.00141055], Trade: 0
# Step 157, action: [-0.00141055], Trade: 0
# Step 158, action: [-0.00141055], Trade: 0
# Step 159, action: [-0.00141055], Trade: 0
# Step 160, action: [-0.00141055], Trade: 0
# Step 161, action: [-0.00141055], Trade: 0
# Step 162, action: [-0.00141055], Trade: 0
# Step 163, action: [-0.00141055], Trade: 0
# Step 164, action: [-0.00141055], Trade: 0
# Step 165, action: [-0.00141055], Trade: 0
# Step 166, action: [-0.00141055], Trade: 0
# Step 167, action: [-0.00141055], Trade: 0
# Step 168, action: [-0.00141055], Trade: 0
# Step 169, action: [-0.00141055], Trade: 0
# Step 170, action: [-0.00141055], Trade: 0
# Step 171, action: [-0.00141055], Trade: 0
# Step 172, action: [-0.00141055], Trade: 0
# Step 173, action: [-0.00141055], Trade: 0
# Step 174, action: [-0.00141055], Trade: 0
# Step 175, action: [-0.00141055], Trade: 0
# Step 176, action: [-0.00141055], Trade: 0
# Step 177, action: [-0.00141055], Trade: 0
# Step 178, action: [-0.00141055], Trade: 0
# Step 179, action: [-0.00141055], Trade: 0
# Step 180, action: [-0.00141055], Trade: 0
# Step 181, action: [-0.00141055], Trade: 0
# Step 182, action: [-0.00141055], Trade: 0
# Step 183, action: [-0.00141055], Trade: 0
# Step 184, action: [-0.00141055], Trade: 0
# Step 185, action: [-0.00141055], Trade: 0
# Step 186, action: [-0.00141055], Trade: 0
# Step 187, action: [-0.00141055], Trade: 0
# Step 188, action: [-0.00141055], Trade: 0
# Step 189, action: [-0.00141055], Trade: 0
# Step 190, action: [-0.00141055], Trade: 0
# Step 191, action: [-0.00141055], Trade: 0
# Step 192, action: [-0.00141055], Trade: 0
# Step 193, action: [-0.00141055], Trade: 0
# Step 194, action: [-0.00141055], Trade: 0
# Step 195, action: [-0.00141055], Trade: 0
# Step 196, action: [-0.00141055], Trade: 0
# Step 197, action: [-0.00141055], Trade: 0
# Step 198, action: [-0.00141055], Trade: 0
# Step 199, action: [-0.00141055], Trade: 0
# Step 200, action: [-0.00141055], Trade: 0
# Step 201, action: [-0.00141055], Trade: 0
# Step 202, action: [-0.00141055], Trade: 0
# Step 203, action: [-0.00141055], Trade: 0
# Step 204, action: [-0.00141055], Trade: 0
# Step 205, action: [-0.00141055], Trade: 0
# Step 206, action: [-0.00141055], Trade: 0
# Step 207, action: [-0.00141055], Trade: 0
# Step 208, action: [-0.00141055], Trade: 0
# Step 209, action: [-0.00141055], Trade: 0
# Step 210, action: [-0.00141055], Trade: 0
# Step 211, action: [-0.00141055], Trade: 0
# Step 212, action: [-0.00141055], Trade: 0
# Step 213, action: [-0.00141055], Trade: 0
# Step 214, action: [-0.00141055], Trade: 0
# Step 215, action: [-0.00141055], Trade: 0
# Step 216, action: [-0.00141055], Trade: 0
# Step 217, action: [-0.00141055], Trade: 0
# Step 218, action: [-0.00141055], Trade: 0
# Step 219, action: [-0.00141055], Trade: 0
# Step 220, action: [-0.00141055], Trade: 0
# Step 221, action: [-0.00141055], Trade: 0
# Step 222, action: [-0.00141055], Trade: 0
# Step 223, action: [-0.00141055], Trade: 0
# Step 224, action: [-0.00141055], Trade: 0
# Step 225, action: [-0.00141055], Trade: 0
# Step 226, action: [-0.00141055], Trade: 0
# Step 227, action: [-0.00141055], Trade: 0
# Step 228, action: [-0.00141055], Trade: 0
# Step 229, action: [-0.00141055], Trade: 0
# Step 230, action: [-0.00141055], Trade: 0
# Step 231, action: [-0.00141055], Trade: 0
# Step 232, action: [-0.00141055], Trade: 0
# Step 233, action: [-0.00141055], Trade: 0
# Step 234, action: [-0.00141055], Trade: 0
# Step 235, action: [-0.00141055], Trade: 0
# Step 236, action: [-0.00141055], Trade: 0
# Step 237, action: [-0.00141055], Trade: 0
# Step 238, action: [-0.00141055], Trade: 0
# Step 239, action: [-0.00141055], Trade: 0
# Step 240, action: [-0.00141055], Trade: 0
# Step 241, action: [-0.00141055], Trade: 0
# Step 242, action: [-0.00141055], Trade: 0
# Step 243, action: [-0.00141055], Trade: 0
# Step 244, action: [-0.00141055], Trade: 0
# Step 245, action: [-0.00141055], Trade: 0
# Step 246, action: [-0.00141055], Trade: 0
# Step 247, action: [-0.00141055], Trade: 0
# Step 248, action: [-0.00141055], Trade: 0
# Step 249, action: [-0.00141055], Trade: 0
# Step 250, action: [-0.00141055], Trade: 0
# Step 251, action: [-0.00141055], Trade: 0
# Step 252, action: [-0.00141055], Trade: 0
# Step 253, action: [-0.00141055], Trade: 0
# Step 254, action: [-0.00141055], Trade: 0
# Step 255, action: [-0.00141055], Trade: 0
# Step 256, action: [-0.00141055], Trade: 0
# Step 257, action: [-0.00141055], Trade: 0
# Step 258, action: [-0.00141055], Trade: 0
# Step 259, action: [-0.00141055], Trade: 0
# Step 260, action: [-0.00141055], Trade: 0
# Step 261, action: [-0.00141055], Trade: 0
# Step 262, action: [-0.00141055], Trade: 0
# Step 263, action: [-0.00141055], Trade: 0
# Step 264, action: [-0.00141055], Trade: 0
# Step 265, action: [-0.00141055], Trade: 0
# Step 266, action: [-0.00141055], Trade: 0
# Step 267, action: [-0.00141055], Trade: 0
# Step 268, action: [-0.00141055], Trade: 0
# Step 269, action: [-0.00141055], Trade: 0
# Step 270, action: [-0.00141055], Trade: 0
# Step 271, action: [-0.00141055], Trade: 0
# Step 272, action: [-0.00141055], Trade: 0
# Step 273, action: [-0.00141055], Trade: 0
# Step 274, action: [-0.00141055], Trade: 0
# Step 275, action: [-0.00141055], Trade: 0
# Step 276, action: [-0.00141055], Trade: 0
# Step 277, action: [-0.00141055], Trade: 0
# Step 278, action: [-0.00141055], Trade: 0
# Step 279, action: [-0.00141055], Trade: 0
# Step 280, action: [-0.00141055], Trade: 0
# Step 281, action: [-0.00141055], Trade: 0
# Step 282, action: [-0.00141055], Trade: 0
# Step 283, action: [-0.00141055], Trade: 0
# Step 284, action: [-0.00141055], Trade: 0
# Step 285, action: [-0.00141055], Trade: 0
# Step 286, action: [-0.00141055], Trade: 0
# Step 287, action: [-0.00141055], Trade: 0
# Step 288, action: [-0.00141055], Trade: 0
# Step 289, action: [-0.00141055], Trade: 0
# Step 290, action: [-0.00141055], Trade: 0
# Step 291, action: [-0.00141055], Trade: 0
# Step 292, action: [-0.00141055], Trade: 0
# Step 293, action: [-0.00141055], Trade: 0
# Step 294, action: [-0.00141055], Trade: 0
# Step 295, action: [-0.00141055], Trade: 0
# Step 296, action: [-0.00141055], Trade: 0
# Step 297, action: [-0.00141055], Trade: 0
# Step 298, action: [-0.00141055], Trade: 0
# Step 299, action: [-0.00141055], Trade: 0
# Step 300, action: [-0.00141055], Trade: 0
# Step 301, action: [-0.00141055], Trade: 0
# Step 302, action: [-0.00141055], Trade: 0
# Step 303, action: [-0.00141055], Trade: 0
# Step 304, action: [-0.00141055], Trade: 0
# Step 305, action: [-0.00141055], Trade: 0
# Step 306, action: [-0.00141055], Trade: 0
# Step 307, action: [-0.00141055], Trade: 0
# Step 308, action: [-0.00141055], Trade: 0
# Step 309, action: [-0.00141055], Trade: 0
# Step 310, action: [-0.00141055], Trade: 0
# Step 311, action: [-0.00141055], Trade: 0
# Step 312, action: [-0.00141055], Trade: 0
# Step 313, action: [-0.00141055], Trade: 0
# Step 314, action: [-0.00141055], Trade: 0
# Step 315, action: [-0.00141055], Trade: 0
# Step 316, action: [-0.00141055], Trade: 0
# Step 317, action: [-0.00141055], Trade: 0
# Step 318, action: [-0.00141055], Trade: 0
# Step 319, action: [-0.00141055], Trade: 0
# Step 320, action: [-0.00141055], Trade: 0
# Step 321, action: [-0.00141055], Trade: 0
# Step 322, action: [-0.00141055], Trade: 0
# Step 323, action: [-0.00141055], Trade: 0
# Step 324, action: [-0.00141055], Trade: 0
# Step 325, action: [-0.00141055], Trade: 0
# Step 326, action: [-0.00141055], Trade: 0
# Step 327, action: [-0.00141055], Trade: 0
# Step 328, action: [-0.00141055], Trade: 0
# Step 329, action: [-0.00141055], Trade: 0
# Step 330, action: [-0.00141055], Trade: 0
# Step 331, action: [-0.00141055], Trade: 0
# Step 332, action: [-0.00141055], Trade: 0
# Step 333, action: [-0.00141055], Trade: 0
# Step 334, action: [-0.00141055], Trade: 0
# Step 335, action: [-0.00141055], Trade: 0
# Step 336, action: [-0.00141055], Trade: 0
# Step 337, action: [-0.00141055], Trade: 0
# Step 338, action: [-0.00141055], Trade: 0
# Step 339, action: [-0.00141055], Trade: 0
# Step 340, action: [-0.00141055], Trade: 0
# Step 341, action: [-0.00141055], Trade: 0
# Step 342, action: [-0.00141055], Trade: 0
# Step 343, action: [-0.00141055], Trade: 0
# Step 344, action: [-0.00141055], Trade: 0
# Step 345, action: [-0.00141055], Trade: 0
# Step 346, action: [-0.00141055], Trade: 0
# Step 347, action: [-0.00141055], Trade: 0
# Step 348, action: [-0.00141055], Trade: 0
# Step 349, action: [-0.00141055], Trade: 0
# Step 350, action: [-0.00141055], Trade: 0
# Step 351, action: [-0.00141055], Trade: 0
# Step 352, action: [-0.00141055], Trade: 0
# Step 353, action: [-0.00141055], Trade: 0
# Step 354, action: [-0.00141055], Trade: 0
# Step 355, action: [-0.00141055], Trade: 0
# Step 356, action: [-0.00141055], Trade: 0
# Step 357, action: [-0.00141055], Trade: 0
# Step 358, action: [-0.00141055], Trade: 0
# Step 359, action: [-0.00141055], Trade: 0
# Step 360, action: [-0.00141055], Trade: 0
# Step 361, action: [-0.00141055], Trade: 0
# Step 362, action: [-0.00141055], Trade: 0
# Step 363, action: [-0.00141055], Trade: 0
# Step 364, action: [-0.00141055], Trade: 0
# Step 365, action: [-0.00141055], Trade: 0
# Step 366, action: [-0.00141055], Trade: 0
# Step 367, action: [-0.00141055], Trade: 0
# Step 368, action: [-0.00141055], Trade: 0
# Step 369, action: [-0.00141055], Trade: 0
# Step 370, action: [-0.00141055], Trade: 0
# Step 371, action: [-0.00141055], Trade: 0
# Step 372, action: [-0.00141055], Trade: 0
# Step 373, action: [-0.00141055], Trade: 0
# Step 374, action: [-0.00141055], Trade: 0
# Step 375, action: [-0.00141055], Trade: 0
# Step 376, action: [-0.00141055], Trade: 0
# Step 377, action: [-0.00141055], Trade: 0
# Step 378, action: [-0.00141055], Trade: 0
# Step 379, action: [-0.00141055], Trade: 0
# Step 380, action: [-0.00141055], Trade: 0
# Step 381, action: [-0.00141055], Trade: 0
# Step 382, action: [-0.00141055], Trade: 0
# Step 383, action: [-0.00141055], Trade: 0
# Step 384, action: [-0.00141055], Trade: 0
# Step 385, action: [-0.00141055], Trade: 0
# Step 386, action: [-0.00141055], Trade: 0
# Step 387, action: [-0.00141055], Trade: 0
# Step 388, action: [-0.00141055], Trade: 0
# Step 389, action: [-0.00141055], Trade: 0
# Step 390, action: [-0.00141055], Trade: 0
# Step 391, action: [-0.00141055], Trade: 0
# Step 392, action: [-0.00141055], Trade: 0
# Step 393, action: [-0.00141055], Trade: 0
# Step 394, action: [-0.00141055], Trade: 0
# Step 395, action: [-0.00141055], Trade: 0
# Step 396, action: [-0.00141055], Trade: 0
# Step 397, action: [-0.00141055], Trade: 0
# Step 398, action: [-0.00141055], Trade: 0
# Step 399, action: [-0.00141055], Trade: 0
# Step 400, action: [-0.00141055], Trade: 0
# Step 401, action: [-0.00141055], Trade: 0
# Step 402, action: [-0.00141055], Trade: 0
# Step 403, action: [-0.00141055], Trade: 0
# Step 404, action: [-0.00141055], Trade: 0
# Step 405, action: [-0.00141055], Trade: 0
# Step 406, action: [-0.00141055], Trade: 0
# Step 407, action: [-0.00141055], Trade: 0
# Step 408, action: [-0.00141055], Trade: 0
# Step 409, action: [-0.00141055], Trade: 0
# Step 410, action: [-0.00141055], Trade: 0
# Step 411, action: [-0.00141055], Trade: 0
# Step 412, action: [-0.00141055], Trade: 0
# Step 413, action: [-0.00141055], Trade: 0
# Step 414, action: [-0.00141055], Trade: 0
# Step 415, action: [-0.00141055], Trade: 0
# Step 416, action: [-0.00141055], Trade: 0
# Step 417, action: [-0.00141055], Trade: 0
# Step 418, action: [-0.00141055], Trade: 0
# Step 419, action: [-0.00141055], Trade: 0
# Step 420, action: [-0.00141055], Trade: 0
# Step 421, action: [-0.00141055], Trade: 0
# Step 422, action: [-0.00141055], Trade: 0
# Step 423, action: [-0.00141055], Trade: 0
# Step 424, action: [-0.00141055], Trade: 0
# Step 425, action: [-0.00141055], Trade: 0
# Step 426, action: [-0.00141055], Trade: 0
# Step 427, action: [-0.00141055], Trade: 0
# Step 428, action: [-0.00141055], Trade: 0
# Step 429, action: [-0.00141055], Trade: 0
# Step 430, action: [-0.00141055], Trade: 0
# Step 431, action: [-0.00141055], Trade: 0
# Step 432, action: [-0.00141055], Trade: 0
# Step 433, action: [-0.00141055], Trade: 0
# Step 434, action: [-0.00141055], Trade: 0
# Step 435, action: [-0.00141055], Trade: 0
# Step 436, action: [-0.00141055], Trade: 0
# Step 437, action: [-0.00141055], Trade: 0
# Step 438, action: [-0.00141055], Trade: 0
# Step 439, action: [-0.00141055], Trade: 0
# Step 440, action: [-0.00141055], Trade: 0
# Step 441, action: [-0.00141055], Trade: 0
# Step 442, action: [-0.00141055], Trade: 0
# Step 443, action: [-0.00141055], Trade: 0
# Step 444, action: [-0.00141055], Trade: 0
# Step 445, action: [-0.00141055], Trade: 0
# Step 446, action: [-0.00141055], Trade: 0
# Step 447, action: [-0.00141055], Trade: 0
# Step 448, action: [-0.00141055], Trade: 0
# Step 449, action: [-0.00141055], Trade: 0
# Step 450, action: [-0.00141055], Trade: 0
# Step 451, action: [-0.00141055], Trade: 0
# Step 452, action: [-0.00141055], Trade: 0
# Step 453, action: [-0.00141055], Trade: 0
# Step 454, action: [-0.00141055], Trade: 0
# Step 455, action: [-0.00141055], Trade: 0
# Step 456, action: [-0.00141055], Trade: 0
# Step 457, action: [-0.00141055], Trade: 0
# Step 458, action: [-0.00141055], Trade: 0
# Step 459, action: [-0.00141055], Trade: 0
# Step 460, action: [-0.00141055], Trade: 0
# Step 461, action: [-0.00141055], Trade: 0
# Step 462, action: [-0.00141055], Trade: 0
# Step 463, action: [-0.00141055], Trade: 0
# Step 464, action: [-0.00141055], Trade: 0
# Step 465, action: [-0.00141055], Trade: 0
# Step 466, action: [-0.00141055], Trade: 0
# Step 467, action: [-0.00141055], Trade: 0
# Step 468, action: [-0.00141055], Trade: 0
# Step 469, action: [-0.00141055], Trade: 0
# Step 470, action: [-0.00141055], Trade: 0
# Step 471, action: [-0.00141055], Trade: 0
# Step 472, action: [-0.00141055], Trade: 0
# Step 473, action: [-0.00141055], Trade: 0
# Step 474, action: [-0.00141055], Trade: 0
# Step 475, action: [-0.00141055], Trade: 0
# Step 476, action: [-0.00141055], Trade: 0
# Step 477, action: [-0.00141055], Trade: 0
# Step 478, action: [-0.00141055], Trade: 0
# Step 479, action: [-0.00141055], Trade: 0
# Step 480, action: [-0.00141055], Trade: 0
# Step 481, action: [-0.00141055], Trade: 0
# Step 482, action: [-0.00141055], Trade: 0
# Step 483, action: [-0.00141055], Trade: 0
# Step 484, action: [-0.00141055], Trade: 0
# Step 485, action: [-0.00141055], Trade: 0
# Step 486, action: [-0.00141055], Trade: 0
# Step 487, action: [-0.00141055], Trade: 0
# Step 488, action: [-0.00141055], Trade: 0
# Step 489, action: [-0.00141055], Trade: 0
# Step 490, action: [-0.00141055], Trade: 0
# Step 491, action: [-0.00141055], Trade: 0
# Step 492, action: [-0.00141055], Trade: 0
# Step 493, action: [-0.00141055], Trade: 0
# Step 494, action: [-0.00141055], Trade: 0
# Step 495, action: [-0.00141055], Trade: 0
# Step 496, action: [-0.00141055], Trade: 0
# Step 497, action: [-0.00141055], Trade: 0
# Step 498, action: [-0.00141055], Trade: 0
# Step 499, action: [-0.00141055], Trade: 0
# Step 500, action: [-0.00141055], Trade: 0
# Step 501, action: [-0.00141055], Trade: 0
# Step 502, action: [-0.00141055], Trade: 0
# Step 503, action: [-0.00141055], Trade: 0
# Step 504, action: [-0.00141055], Trade: 0
# Step 505, action: [-0.00141055], Trade: 0
# Step 506, action: [-0.00141055], Trade: 0
# Step 507, action: [-0.00141055], Trade: 0
# Step 508, action: [-0.00141055], Trade: 0
# Step 509, action: [-0.00141055], Trade: 0
# Step 510, action: [-0.00141055], Trade: 0
# Step 511, action: [-0.00141055], Trade: 0
# Step 512, action: [-0.00141055], Trade: 0
# Step 513, action: [-0.00141055], Trade: 0
# Step 514, action: [-0.00141055], Trade: 0
# Step 515, action: [-0.00141055], Trade: 0
# Step 516, action: [-0.00141055], Trade: 0
# Step 517, action: [-0.00141055], Trade: 0
# Step 518, action: [-0.00141055], Trade: 0
# Step 519, action: [-0.00141055], Trade: 0
# Step 520, action: [-0.00141055], Trade: 0
# Step 521, action: [-0.00141055], Trade: 0
# Step 522, action: [-0.00141055], Trade: 0
# Step 523, action: [-0.00141055], Trade: 0
# Step 524, action: [-0.00141055], Trade: 0
# Step 525, action: [-0.00141055], Trade: 0
# Step 526, action: [-0.00141055], Trade: 0
# Step 527, action: [-0.00141055], Trade: 0
# Step 528, action: [-0.00141055], Trade: 0
# Step 529, action: [-0.00141055], Trade: 0
# Step 530, action: [-0.00141055], Trade: 0
# Step 531, action: [-0.00141055], Trade: 0
# Step 532, action: [-0.00141055], Trade: 0
# Step 533, action: [-0.00141055], Trade: 0
# Step 534, action: [-0.00141055], Trade: 0
# Step 535, action: [-0.00141055], Trade: 0
# Step 536, action: [-0.00141055], Trade: 0
# Step 537, action: [-0.00141055], Trade: 0
# Step 538, action: [-0.00141055], Trade: 0
# Step 539, action: [-0.00141055], Trade: 0
# Step 540, action: [-0.00141055], Trade: 0
# Step 541, action: [-0.00141055], Trade: 0
# Step 542, action: [-0.00141055], Trade: 0
# Step 543, action: [-0.00141055], Trade: 0
# Step 544, action: [-0.00141055], Trade: 0
# Step 545, action: [-0.00141055], Trade: 0
# Step 546, action: [-0.00141055], Trade: 0
# Step 547, action: [-0.00141055], Trade: 0
# Step 548, action: [-0.00141055], Trade: 0
# Step 549, action: [-0.00141055], Trade: 0
# Step 550, action: [-0.00141055], Trade: 0
# Step 551, action: [-0.00141055], Trade: 0
# Step 552, action: [-0.00141055], Trade: 0
# Step 553, action: [-0.00141055], Trade: 0
# Step 554, action: [-0.00141055], Trade: 0
# Step 555, action: [-0.00141055], Trade: 0
# Step 556, action: [-0.00141055], Trade: 0
# Step 557, action: [-0.00141055], Trade: 0
# Step 558, action: [-0.00141055], Trade: 0
# Step 559, action: [-0.00141055], Trade: 0
# Step 560, action: [-0.00141055], Trade: 0
# Step 561, action: [-0.00141055], Trade: 0
# Step 562, action: [-0.00141055], Trade: 0
# Step 563, action: [-0.00141055], Trade: 0
# Step 564, action: [-0.00141055], Trade: 0
# Step 565, action: [-0.00141055], Trade: 0
# Step 566, action: [-0.00141055], Trade: 0
# Step 567, action: [-0.00141055], Trade: 0
# Step 568, action: [-0.00141055], Trade: 0
# Step 569, action: [-0.00141055], Trade: 0
# Step 570, action: [-0.00141055], Trade: 0
# Step 571, action: [-0.00141055], Trade: 0
# Step 572, action: [-0.00141055], Trade: 0
# Step 573, action: [-0.00141055], Trade: 0
# Step 574, action: [-0.00141055], Trade: 0
# Step 575, action: [-0.00141055], Trade: 0
# Step 576, action: [-0.00141055], Trade: 0
# Step 577, action: [-0.00141055], Trade: 0
# Step 578, action: [-0.00141055], Trade: 0
# Step 579, action: [-0.00141055], Trade: 0
# Step 580, action: [-0.00141055], Trade: 0
# Step 581, action: [-0.00141055], Trade: 0
# Step 582, action: [-0.00141055], Trade: 0
# Step 583, action: [-0.00141055], Trade: 0
# Step 584, action: [-0.00141055], Trade: 0
# Step 585, action: [-0.00141055], Trade: 0
# Step 586, action: [-0.00141055], Trade: 0
# Step 587, action: [-0.00141055], Trade: 0
# Step 588, action: [-0.00141055], Trade: 0
# Step 589, action: [-0.00141055], Trade: 0
# Step 590, action: [-0.00141055], Trade: 0
# Step 591, action: [-0.00141055], Trade: 0
# Step 592, action: [-0.00141055], Trade: 0
# Step 593, action: [-0.00141055], Trade: 0
# Step 594, action: [-0.00141055], Trade: 0
# Step 595, action: [-0.00141055], Trade: 0
# Step 596, action: [-0.00141055], Trade: 0
# Step 597, action: [-0.00141055], Trade: 0
# Step 598, action: [-0.00141055], Trade: 0
# Step 599, action: [-0.00141055], Trade: 0
# Step 600, action: [-0.00141055], Trade: 0
# Step 601, action: [-0.00141055], Trade: 0
# Step 602, action: [-0.00141055], Trade: 0
# Step 603, action: [-0.00141055], Trade: 0
# Step 604, action: [-0.00141055], Trade: 0
# Step 605, action: [-0.00141055], Trade: 0
# Step 606, action: [-0.00141055], Trade: 0
# Step 607, action: [-0.00141055], Trade: 0
# Step 608, action: [-0.00141055], Trade: 0
# Step 609, action: [-0.00141055], Trade: 0
# Step 610, action: [-0.00141055], Trade: 0
# Step 611, action: [-0.00141055], Trade: 0
# Step 612, action: [-0.00141055], Trade: 0
# Step 613, action: [-0.00141055], Trade: 0
# Step 614, action: [-0.00141055], Trade: 0
# Step 615, action: [-0.00141055], Trade: 0
# Step 616, action: [-0.00141055], Trade: 0
# Step 617, action: [-0.00141055], Trade: 0
# Step 618, action: [-0.00141055], Trade: 0
# Step 619, action: [-0.00141055], Trade: 0
# Step 620, action: [-0.00141055], Trade: 0
# Step 621, action: [-0.00141055], Trade: 0
# Step 622, action: [-0.00141055], Trade: 0
# Step 623, action: [-0.00141055], Trade: 0
# Step 624, action: [-0.00141055], Trade: 0
# Step 625, action: [-0.00141055], Trade: 0
# Step 626, action: [-0.00141055], Trade: 0
# Step 627, action: [-0.00141055], Trade: 0
# Step 628, action: [-0.00141055], Trade: 0
# Step 629, action: [-0.00141055], Trade: 0
# Step 630, action: [-0.00141055], Trade: 0
# Step 631, action: [-0.00141055], Trade: 0
# Step 632, action: [-0.00141055], Trade: 0
# Step 633, action: [-0.00141055], Trade: 0
# Step 634, action: [-0.00141055], Trade: 0
# Step 635, action: [-0.00141055], Trade: 0
# Step 636, action: [-0.00141055], Trade: 0
# Step 637, action: [-0.00141055], Trade: 0
# Step 638, action: [-0.00141055], Trade: 0
# Step 639, action: [-0.00141055], Trade: 0
# Step 640, action: [-0.00141055], Trade: 0
# Step 641, action: [-0.00141055], Trade: 0
# Step 642, action: [-0.00141055], Trade: 0
# Step 643, action: [-0.00141055], Trade: 0
# Step 644, action: [-0.00141055], Trade: 0
# Step 645, action: [-0.00141055], Trade: 0
# Step 646, action: [-0.00141055], Trade: 0
# Step 647, action: [-0.00141055], Trade: 0
# Step 648, action: [-0.00141055], Trade: 0
# Step 649, action: [-0.00141055], Trade: 0
# Step 650, action: [-0.00141055], Trade: 0
# Step 651, action: [-0.00141055], Trade: 0
# Step 652, action: [-0.00141055], Trade: 0
# Step 653, action: [-0.00141055], Trade: 0
# Step 654, action: [-0.00141055], Trade: 0
# Step 655, action: [-0.00141055], Trade: 0
# Step 656, action: [-0.00141055], Trade: 0
# Step 657, action: [-0.00141055], Trade: 0
# Step 658, action: [-0.00141055], Trade: 0
# Step 659, action: [-0.00141055], Trade: 0
# Step 660, action: [-0.00141055], Trade: 0
# Step 661, action: [-0.00141055], Trade: 0
# Step 662, action: [-0.00141055], Trade: 0
# Step 663, action: [-0.00141055], Trade: 0
# Step 664, action: [-0.00141055], Trade: 0
# Step 665, action: [-0.00141055], Trade: 0
# Step 666, action: [-0.00141055], Trade: 0
# Step 667, action: [-0.00141055], Trade: 0
# Step 668, action: [-0.00141055], Trade: 0
# Step 669, action: [-0.00141055], Trade: 0
# Step 670, action: [-0.00141055], Trade: 0
# Step 671, action: [-0.00141055], Trade: 0
# Step 672, action: [-0.00141055], Trade: 0
# Step 673, action: [-0.00141055], Trade: 0
# Step 674, action: [-0.00141055], Trade: 0
# Step 675, action: [-0.00141055], Trade: 0
# Step 676, action: [-0.00141055], Trade: 0
# Step 677, action: [-0.00141055], Trade: 0
# Step 678, action: [-0.00141055], Trade: 0
# Step 679, action: [-0.00141055], Trade: 0
# Step 680, action: [-0.00141055], Trade: 0
# Step 681, action: [-0.00141055], Trade: 0
# Step 682, action: [-0.00141055], Trade: 0
# Step 683, action: [-0.00141055], Trade: 0
# Step 684, action: [-0.00141055], Trade: 0
# Step 685, action: [-0.00141055], Trade: 0
# Step 686, action: [-0.00141055], Trade: 0
# Step 687, action: [-0.00141055], Trade: 0
# Step 688, action: [-0.00141055], Trade: 0
# Step 689, action: [-0.00141055], Trade: 0
# Step 690, action: [-0.00141055], Trade: 0
# Step 691, action: [-0.00141055], Trade: 0
# Step 692, action: [-0.00141055], Trade: 0
# Step 693, action: [-0.00141055], Trade: 0
# Step 694, action: [-0.00141055], Trade: 0
# Step 695, action: [-0.00141055], Trade: 0
# Step 696, action: [-0.00141055], Trade: 0
# Step 697, action: [-0.00141055], Trade: 0
# Step 698, action: [-0.00141055], Trade: 0
# Step 699, action: [-0.00141055], Trade: 0
# Step 700, action: [-0.00141055], Trade: 0
# Step 701, action: [-0.00141055], Trade: 0
# Step 702, action: [-0.00141055], Trade: 0
# Step 703, action: [-0.00141055], Trade: 0
# Step 704, action: [-0.00141055], Trade: 0
# Step 705, action: [-0.00141055], Trade: 0
# Step 706, action: [-0.00141055], Trade: 0
# Step 707, action: [-0.00141055], Trade: 0
# Step 708, action: [-0.00141055], Trade: 0
# Step 709, action: [-0.00141055], Trade: 0
# Step 710, action: [-0.00141055], Trade: 0
# Step 711, action: [-0.00141055], Trade: 0
# Step 712, action: [-0.00141055], Trade: 0
# Step 713, action: [-0.00141055], Trade: 0
# Step 714, action: [-0.00141055], Trade: 0
# Step 715, action: [-0.00141055], Trade: 0
# Step 716, action: [-0.00141055], Trade: 0
# Step 717, action: [-0.00141055], Trade: 0
# Step 718, action: [-0.00141055], Trade: 0
# Step 719, action: [-0.00141055], Trade: 0
# Step 720, action: [-0.00141055], Trade: 0
# Step 721, action: [-0.00141055], Trade: 0
# Step 722, action: [-0.00141055], Trade: 0
# Step 723, action: [-0.00141055], Trade: 0
# Step 724, action: [-0.00141055], Trade: 0
# Step 725, action: [-0.00141055], Trade: 0
# Step 726, action: [-0.00141055], Trade: 0
# Step 727, action: [-0.00141055], Trade: 0
# Step 728, action: [-0.00141055], Trade: 0
# Step 729, action: [-0.00141055], Trade: 0
# Step 730, action: [-0.00141055], Trade: 0
# Step 731, action: [-0.00141055], Trade: 0
# Step 732, action: [-0.00141055], Trade: 0
# Step 733, action: [-0.00141055], Trade: 0
# Step 734, action: [-0.00141055], Trade: 0
# Step 735, action: [-0.00141055], Trade: 0
# Step 736, action: [-0.00141055], Trade: 0
# Step 737, action: [-0.00141055], Trade: 0
# Step 738, action: [-0.00141055], Trade: 0
# Step 739, action: [-0.00141055], Trade: 0
# Step 740, action: [-0.00141055], Trade: 0
# Step 741, action: [-0.00141055], Trade: 0
# Step 742, action: [-0.00141055], Trade: 0
# Step 743, action: [-0.00141055], Trade: 0
# Step 744, action: [-0.00141055], Trade: 0
# Step 745, action: [-0.00141055], Trade: 0
# Step 746, action: [-0.00141055], Trade: 0
# Step 747, action: [-0.00141055], Trade: 0
# Step 748, action: [-0.00141055], Trade: 0
# Step 749, action: [-0.00141055], Trade: 0
# Step 750, action: [-0.00141055], Trade: 0
# Step 751, action: [-0.00141055], Trade: 0
# Step 752, action: [-0.00141055], Trade: 0
# Step 753, action: [-0.00141055], Trade: 0
# Step 754, action: [-0.00141055], Trade: 0
# Step 755, action: [-0.00141055], Trade: 0
# Step 756, action: [-0.00141055], Trade: 0
# Step 757, action: [-0.00141055], Trade: 0
# Step 758, action: [-0.00141055], Trade: 0
# Step 759, action: [-0.00141055], Trade: 0
# Step 760, action: [-0.00141055], Trade: 0
# Step 761, action: [-0.00141055], Trade: 0
# Step 762, action: [-0.00141055], Trade: 0
# Step 763, action: [-0.00141055], Trade: 0
# Step 764, action: [-0.00141055], Trade: 0
# Step 765, action: [-0.00141055], Trade: 0
# Step 766, action: [-0.00141055], Trade: 0
# Step 767, action: [-0.00141055], Trade: 0
# Step 768, action: [-0.00141055], Trade: 0
# Step 769, action: [-0.00141055], Trade: 0
# Step 770, action: [-0.00141055], Trade: 0
# Step 771, action: [-0.00141055], Trade: 0
# Step 772, action: [-0.00141055], Trade: 0
# Step 773, action: [-0.00141055], Trade: 0
# Step 774, action: [-0.00141055], Trade: 0
# Step 775, action: [-0.00141055], Trade: 0
# Step 776, action: [-0.00141055], Trade: 0
# Step 777, action: [-0.00141055], Trade: 0
# Step 778, action: [-0.00141055], Trade: 0
# Step 779, action: [-0.00141055], Trade: 0
# Step 780, action: [-0.00141055], Trade: 0
# Step 781, action: [-0.00141055], Trade: 0
# Step 782, action: [-0.00141055], Trade: 0
# Step 783, action: [-0.00141055], Trade: 0
# Step 784, action: [-0.00141055], Trade: 0
# Step 785, action: [-0.00141055], Trade: 0
# Step 786, action: [-0.00141055], Trade: 0
# Step 787, action: [-0.00141055], Trade: 0
# Step 788, action: [-0.00141055], Trade: 0
# Step 789, action: [-0.00141055], Trade: 0
# Step 790, action: [-0.00141055], Trade: 0
# Step 791, action: [-0.00141055], Trade: 0
# Step 792, action: [-0.00141055], Trade: 0
# Step 793, action: [-0.00141055], Trade: 0
# Step 794, action: [-0.00141055], Trade: 0
# Step 795, action: [-0.00141055], Trade: 0
# Step 796, action: [-0.00141055], Trade: 0
# Step 797, action: [-0.00141055], Trade: 0
# Step 798, action: [-0.00141055], Trade: 0
# Step 799, action: [-0.00141055], Trade: 0
# Step 800, action: [-0.00141055], Trade: 0
# Step 801, action: [-0.00141055], Trade: 0
# Step 802, action: [-0.00141055], Trade: 0
# Step 803, action: [-0.00141055], Trade: 0
# Step 804, action: [-0.00141055], Trade: 0
# Step 805, action: [-0.00141055], Trade: 0
# Episode: 9, com: MCD, win trade: 0/0, Total reward: -59.92555831265569

# %% [markdown]
# We can see that an untrained policy performs poorly, while GAIL matches expert returns (500):

# %%
print(
    "Rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)
print(
    "Rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# Rewards before training: -9.98759315814823 +/- 0.0
# Rewards after training: -59.92555744946003 +/- 0.0

# %%
def DRL_prediction(model, environment, deterministic=False):
        """make a prediction and get results"""
        # test_env, test_obs = environment.get_sb_env()
        # account_memory = None  # This help avoid unnecessary list creation
        # actions_memory = None  # optimize memory consumption

        test_obs = environment.reset()[0]
        # max_steps = len(environment.df.index.unique()) - 1

        for i in range(0,len(environment.df)):
            action = model.predict(np.asarray(test_obs), deterministic=deterministic)
            test_obs,reward,terminal,truncated,info = environment.step(action[0])

            if terminal:
                print("hit end!")
                break
        return pd.DataFrame(environment.asset_memory, columns=['account_value']), pd.DataFrame(environment.actions_memory)

# %%
df_account_value_ppo, df_actions_ppo = DRL_prediction(model=learner, environment = e_train_gym)
# Out:
# Step 0, action: [1.], Trade: 0
# Step 1, action: [1.], Trade: 0
# Step 2, action: [1.], Trade: 0
# Step 3, action: [0.98270357], Trade: 0
# Step 4, action: [0.6782824], Trade: 0
# Step 5, action: [-1.], Trade: 0
# Step 6, action: [-0.02467314], Trade: 1
# Step 7, action: [-1.], Trade: 1
# Step 8, action: [1.], Trade: 1
# Step 9, action: [-0.247977], Trade: 1
# Step 10, action: [-0.43289724], Trade: 1
# Step 11, action: [0.46846297], Trade: 1
# Step 12, action: [0.83208895], Trade: 1
# Step 13, action: [-0.8413053], Trade: 1
# Step 14, action: [-0.49260035], Trade: 2
# Step 15, action: [-0.83476055], Trade: 3
# Step 16, action: [1.], Trade: 4
# Step 17, action: [-0.91973305], Trade: 4
# Step 18, action: [0.47894198], Trade: 5
# Step 19, action: [0.6353611], Trade: 5
# Step 20, action: [0.29584122], Trade: 5
# Step 21, action: [-0.43691295], Trade: 5
# Step 22, action: [1.], Trade: 6
# Step 23, action: [-0.4579729], Trade: 6
# Step 24, action: [1.], Trade: 7
# Step 25, action: [-0.8712025], Trade: 7
# Step 26, action: [-0.19992101], Trade: 8
# Step 27, action: [-0.29477158], Trade: 9
# Step 28, action: [0.01824084], Trade: 10
# Step 29, action: [0.13718012], Trade: 10
# Step 30, action: [-0.7515317], Trade: 10
# Step 31, action: [-1.], Trade: 11
# Step 32, action: [-0.46970573], Trade: 12
# Step 33, action: [-0.04327412], Trade: 12
# Step 34, action: [0.12965943], Trade: 13
# Step 35, action: [-0.25502837], Trade: 13
# Step 36, action: [0.9920308], Trade: 14
# Step 37, action: [-1.], Trade: 14
# Step 38, action: [-0.33008447], Trade: 15
# Step 39, action: [1.], Trade: 15
# Step 40, action: [-0.596958], Trade: 15
# Step 41, action: [-1.], Trade: 16
# Step 42, action: [0.7345925], Trade: 17
# Step 43, action: [0.98592997], Trade: 17
# Step 44, action: [0.3546371], Trade: 17
# Step 45, action: [-0.64389026], Trade: 17
# Step 46, action: [0.8644917], Trade: 18
# Step 47, action: [0.3784617], Trade: 18
# Step 48, action: [-1.], Trade: 18
# Step 49, action: [-0.2356691], Trade: 19
# Step 50, action: [0.93018496], Trade: 20
# Step 51, action: [1.], Trade: 20
# Step 52, action: [0.49689382], Trade: 20
# Step 53, action: [-0.46982917], Trade: 20
# Step 54, action: [0.0045753], Trade: 21
# Step 55, action: [-0.16330391], Trade: 21
# Step 56, action: [-0.50355446], Trade: 22
# Step 57, action: [0.91898006], Trade: 23
# Step 58, action: [-0.71317714], Trade: 23
# Step 59, action: [1.], Trade: 24
# Step 60, action: [-1.], Trade: 24
# Step 61, action: [-0.74461055], Trade: 25
# Step 62, action: [-0.07615238], Trade: 25
# Step 63, action: [-0.33540833], Trade: 26
# Step 64, action: [0.8187908], Trade: 27
# Step 65, action: [-0.42272455], Trade: 27
# Step 66, action: [-1.], Trade: 28
# Step 67, action: [-0.4105676], Trade: 29
# Step 68, action: [0.5296579], Trade: 29
# Step 69, action: [0.20734823], Trade: 29
# Step 70, action: [-0.13853955], Trade: 29
# Step 71, action: [1.], Trade: 30
# Step 72, action: [-1.], Trade: 30
# Step 73, action: [-1.], Trade: 31
# Step 74, action: [-0.81134427], Trade: 32
# Step 75, action: [-1.], Trade: 33
# Step 76, action: [1.], Trade: 34
# Step 77, action: [1.], Trade: 34
# Step 78, action: [-0.79718775], Trade: 34
# Step 79, action: [0.08884196], Trade: 35
# Step 80, action: [1.], Trade: 35
# Step 81, action: [0.2556248], Trade: 35
# Step 82, action: [1.], Trade: 35
# Step 83, action: [-0.5676849], Trade: 35
# Step 84, action: [-0.35232544], Trade: 36
# Step 85, action: [1.], Trade: 37
# Step 86, action: [-0.17650767], Trade: 37
# Step 87, action: [-0.07598577], Trade: 38
# Step 88, action: [-0.15098263], Trade: 39
# Step 89, action: [1.], Trade: 40
# Step 90, action: [-1.], Trade: 40
# Step 91, action: [-0.17313486], Trade: 41
# Step 92, action: [-0.34623787], Trade: 41
# Step 93, action: [-0.59977674], Trade: 41
# Step 94, action: [-1.], Trade: 41
# Step 95, action: [-1.], Trade: 42
# Step 96, action: [1.], Trade: 42
# Step 97, action: [-0.2504004], Trade: 42
# Step 98, action: [1.], Trade: 42
# Step 99, action: [0.11829079], Trade: 42
# Step 100, action: [0.16778599], Trade: 42
# Step 101, action: [-0.85888964], Trade: 42
# Step 102, action: [0.20649977], Trade: 43
# Step 103, action: [0.33654064], Trade: 43
# Step 104, action: [0.59848565], Trade: 43
# Step 105, action: [0.15237013], Trade: 43
# Step 106, action: [0.13417989], Trade: 43
# Step 107, action: [0.17493482], Trade: 43
# Step 108, action: [0.8097002], Trade: 43
# Step 109, action: [0.93399], Trade: 43
# Step 110, action: [0.26174152], Trade: 43
# Step 111, action: [-0.65257716], Trade: 43
# Step 112, action: [-1.], Trade: 44
# Step 113, action: [-0.11008038], Trade: 45
# Step 114, action: [-1.], Trade: 46
# Step 115, action: [-0.00054923], Trade: 47
# Step 116, action: [0.29181147], Trade: 48
# Step 117, action: [-0.635812], Trade: 48
# Step 118, action: [-0.6145437], Trade: 49
# Step 119, action: [-0.41311842], Trade: 49
# Step 120, action: [0.9954136], Trade: 49
# Step 121, action: [1.], Trade: 49
# Step 122, action: [1.], Trade: 49
# Step 123, action: [0.08684275], Trade: 49
# Step 124, action: [-0.7636991], Trade: 49
# Step 125, action: [0.44433618], Trade: 50
# Step 126, action: [-0.95420575], Trade: 50
# Step 127, action: [0.7637849], Trade: 51
# Step 128, action: [0.5313022], Trade: 51
# Step 129, action: [-0.8866009], Trade: 51
# Step 130, action: [-0.66159153], Trade: 52
# Step 131, action: [-0.80546504], Trade: 53
# Step 132, action: [-0.18358958], Trade: 54
# Step 133, action: [-0.9954827], Trade: 55
# Step 134, action: [-0.7002631], Trade: 56
# Step 135, action: [1.], Trade: 57
# Step 136, action: [-1.], Trade: 57
# Step 137, action: [-1.], Trade: 58
# Step 138, action: [-0.74571115], Trade: 58
# Step 139, action: [-1.], Trade: 58
# Step 140, action: [-1.], Trade: 58
# Step 141, action: [0.28236142], Trade: 59
# Step 142, action: [1.], Trade: 59
# Step 143, action: [-0.9769784], Trade: 59
# Step 144, action: [-1.], Trade: 59
# Step 145, action: [0.7670762], Trade: 59
# Step 146, action: [0.06596283], Trade: 59
# Step 147, action: [0.51764625], Trade: 59
# Step 148, action: [-0.4639015], Trade: 59
# Step 149, action: [-0.56510067], Trade: 60
# Step 150, action: [-0.648668], Trade: 61
# Step 151, action: [-0.33032787], Trade: 62
# Step 152, action: [0.18851106], Trade: 63
# Step 153, action: [1.], Trade: 63
# Step 154, action: [-1.], Trade: 63
# Step 155, action: [1.], Trade: 64
# Step 156, action: [-1.], Trade: 64
# Step 157, action: [-0.6743986], Trade: 64
# Step 158, action: [-1.], Trade: 65
# Step 159, action: [0.1041149], Trade: 66
# Step 160, action: [-0.02044165], Trade: 66
# Step 161, action: [-0.760301], Trade: 67
# Step 162, action: [-1.], Trade: 68
# Step 163, action: [-0.96343344], Trade: 69
# Step 164, action: [-0.64279246], Trade: 69
# Step 165, action: [1.], Trade: 70
# Step 166, action: [0.48546982], Trade: 70
# Step 167, action: [1.], Trade: 70
# Step 168, action: [-0.2989431], Trade: 70
# Step 169, action: [-1.], Trade: 71
# Step 170, action: [-0.87746906], Trade: 72
# Step 171, action: [-0.59006304], Trade: 73
# Step 172, action: [-1.], Trade: 74
# Step 173, action: [0.18689655], Trade: 75
# Step 174, action: [-1.], Trade: 75
# Step 175, action: [0.5282697], Trade: 75
# Step 176, action: [1.], Trade: 75
# Step 177, action: [-1.], Trade: 75
# Step 178, action: [-0.18980393], Trade: 75
# Step 179, action: [0.613548], Trade: 76
# Step 180, action: [0.76138717], Trade: 76
# Step 181, action: [-1.], Trade: 76
# Step 182, action: [-0.11809074], Trade: 77
# Step 183, action: [-1.], Trade: 77
# Step 184, action: [-0.40649426], Trade: 77
# Step 185, action: [-0.40266618], Trade: 78
# Step 186, action: [0.4934584], Trade: 79
# Step 187, action: [-0.805647], Trade: 79
# Step 188, action: [1.], Trade: 80
# Step 189, action: [-0.6553195], Trade: 80
# Step 190, action: [1.], Trade: 81
# Step 191, action: [-0.71898377], Trade: 81
# Step 192, action: [-0.37337548], Trade: 82
# Step 193, action: [-0.75332344], Trade: 83
# Step 194, action: [1.], Trade: 84
# Step 195, action: [0.99811554], Trade: 84
# Step 196, action: [0.542636], Trade: 84
# Step 197, action: [-0.9688512], Trade: 84
# Step 198, action: [0.2550508], Trade: 85
# Step 199, action: [-0.47447675], Trade: 85
# Step 200, action: [-0.6713726], Trade: 86
# Step 201, action: [-0.4287542], Trade: 87
# Step 202, action: [0.4864602], Trade: 88
# Step 203, action: [-1.], Trade: 88
# Step 204, action: [1.], Trade: 89
# Step 205, action: [0.10324942], Trade: 89
# Step 206, action: [-0.68154305], Trade: 89
# Step 207, action: [-0.4852074], Trade: 89
# Step 208, action: [0.3133513], Trade: 90
# Step 209, action: [0.8513422], Trade: 90
# Step 210, action: [1.], Trade: 90
# Step 211, action: [-1.], Trade: 90
# Step 212, action: [-0.14200972], Trade: 91
# Step 213, action: [0.4760196], Trade: 91
# Step 214, action: [1.], Trade: 91
# Step 215, action: [0.12502542], Trade: 91
# Step 216, action: [0.78126365], Trade: 91
# Step 217, action: [-0.6732786], Trade: 91
# Step 218, action: [1.], Trade: 92
# Step 219, action: [0.7607941], Trade: 92
# Step 220, action: [-0.14314501], Trade: 92
# Step 221, action: [-1.], Trade: 93
# Step 222, action: [0.6493108], Trade: 94
# Step 223, action: [-0.21584177], Trade: 94
# Step 224, action: [-0.5321985], Trade: 95
# Step 225, action: [-0.4693009], Trade: 96
# Step 226, action: [0.08590635], Trade: 97
# Step 227, action: [1.], Trade: 97
# Step 228, action: [-0.30135864], Trade: 97
# Step 229, action: [-1.], Trade: 98
# Step 230, action: [0.3030379], Trade: 99
# Step 231, action: [-0.1692448], Trade: 99
# Step 232, action: [0.53888476], Trade: 100
# Step 233, action: [1.], Trade: 100
# Step 234, action: [1.], Trade: 100
# Step 235, action: [-0.33394936], Trade: 100
# Step 236, action: [-0.47907], Trade: 101
# Step 237, action: [1.], Trade: 102
# Step 238, action: [1.], Trade: 102
# Step 239, action: [0.465625], Trade: 102
# Step 240, action: [1.], Trade: 102
# Step 241, action: [-1.], Trade: 102
# Step 242, action: [0.09856246], Trade: 103
# Step 243, action: [-0.18554571], Trade: 103
# Step 244, action: [1.], Trade: 104
# Step 245, action: [-1.], Trade: 104
# Step 246, action: [-0.6206109], Trade: 105
# Step 247, action: [-1.], Trade: 105
# Step 248, action: [0.662831], Trade: 106
# Step 249, action: [0.839011], Trade: 106
# Step 250, action: [-0.45343378], Trade: 106
# Step 251, action: [-1.], Trade: 107
# Step 252, action: [-0.56084085], Trade: 108
# Step 253, action: [-1.], Trade: 108
# Step 254, action: [-1.], Trade: 109
# Step 255, action: [-0.4570836], Trade: 110
# Step 256, action: [1.], Trade: 110
# Step 257, action: [-1.], Trade: 110
# Step 258, action: [-1.], Trade: 110
# Step 259, action: [-1.], Trade: 110
# Step 260, action: [1.], Trade: 110
# Step 261, action: [-0.42063445], Trade: 110
# Step 262, action: [1.], Trade: 111
# Step 263, action: [-0.14045095], Trade: 111
# Step 264, action: [0.14466383], Trade: 112
# Step 265, action: [-0.9180907], Trade: 112
# Step 266, action: [-0.52002704], Trade: 113
# Step 267, action: [0.8136929], Trade: 114
# Step 268, action: [0.00371719], Trade: 114
# Step 269, action: [-1.], Trade: 114
# Step 270, action: [-0.97562534], Trade: 115
# Step 271, action: [1.], Trade: 115
# Step 272, action: [0.3735653], Trade: 115
# Step 273, action: [-0.3637073], Trade: 115
# Step 274, action: [0.7843938], Trade: 116
# Step 275, action: [-0.7594127], Trade: 116
# Step 276, action: [-1.], Trade: 117
# Step 277, action: [0.61762017], Trade: 118
# Step 278, action: [-0.09016193], Trade: 118
# Step 279, action: [1.], Trade: 118
# Step 280, action: [-0.41833127], Trade: 118
# Step 281, action: [-0.62138325], Trade: 119
# Step 282, action: [0.5142341], Trade: 120
# Step 283, action: [-0.2658494], Trade: 120
# Step 284, action: [-0.2648434], Trade: 121
# Step 285, action: [-0.12869352], Trade: 122
# Step 286, action: [0.98079747], Trade: 123
# Step 287, action: [0.7297927], Trade: 123
# Step 288, action: [-0.0634326], Trade: 123
# Step 289, action: [1.], Trade: 124
# Step 290, action: [1.], Trade: 124
# Step 291, action: [-0.7360582], Trade: 124
# Step 292, action: [0.99487], Trade: 125
# Step 293, action: [-0.39574966], Trade: 125
# Step 294, action: [-0.52845687], Trade: 126
# Step 295, action: [1.], Trade: 127
# Step 296, action: [-1.], Trade: 127
# Step 297, action: [0.38553232], Trade: 128
# Step 298, action: [1.], Trade: 128
# Step 299, action: [-0.4223138], Trade: 128
# Step 300, action: [-1.], Trade: 129
# Step 301, action: [-1.], Trade: 130
# Step 302, action: [-1.], Trade: 130
# Step 303, action: [0.6724957], Trade: 131
# Step 304, action: [0.5468194], Trade: 131
# Step 305, action: [0.40704012], Trade: 131
# Step 306, action: [0.0054931], Trade: 131
# Step 307, action: [-1.], Trade: 131
# Step 308, action: [0.92847484], Trade: 132
# Step 309, action: [1.], Trade: 132
# Step 310, action: [0.7325233], Trade: 132
# Step 311, action: [0.3516042], Trade: 132
# Step 312, action: [-0.29938805], Trade: 132
# Step 313, action: [-0.19558303], Trade: 133
# Step 314, action: [-0.1047511], Trade: 134
# Step 315, action: [-1.], Trade: 135
# Step 316, action: [-0.26639736], Trade: 136
# Step 317, action: [0.43757293], Trade: 136
# Step 318, action: [-0.01603228], Trade: 136
# Step 319, action: [-0.38400716], Trade: 136
# Step 320, action: [-1.], Trade: 136
# Step 321, action: [-0.24382079], Trade: 136
# Step 322, action: [-1.], Trade: 136
# Step 323, action: [0.45808622], Trade: 137
# Step 324, action: [1.], Trade: 137
# Step 325, action: [-0.06317785], Trade: 137
# Step 326, action: [-0.14356032], Trade: 137
# Step 327, action: [0.7688515], Trade: 137
# Step 328, action: [1.], Trade: 137
# Step 329, action: [0.8962795], Trade: 137
# Step 330, action: [-0.383612], Trade: 137
# Step 331, action: [-0.02984082], Trade: 138
# Step 332, action: [-1.], Trade: 139
# Step 333, action: [-1.], Trade: 140
# Step 334, action: [-0.3481487], Trade: 140
# Step 335, action: [1.], Trade: 140
# Step 336, action: [-0.3552179], Trade: 140
# Step 337, action: [-0.40756485], Trade: 140
# Step 338, action: [-0.89112604], Trade: 140
# Step 339, action: [0.01788108], Trade: 140
# Step 340, action: [0.9321874], Trade: 140
# Step 341, action: [-1.], Trade: 140
# Step 342, action: [-0.63414425], Trade: 141
# Step 343, action: [-0.5166194], Trade: 141
# Step 344, action: [0.8622495], Trade: 141
# Step 345, action: [0.5269787], Trade: 141
# Step 346, action: [-0.36400566], Trade: 141
# Step 347, action: [0.7823813], Trade: 141
# Step 348, action: [-1.], Trade: 141
# Step 349, action: [-1.], Trade: 141
# Step 350, action: [0.00769879], Trade: 142
# Step 351, action: [1.], Trade: 142
# Step 352, action: [-0.23692325], Trade: 142
# Step 353, action: [1.], Trade: 143
# Step 354, action: [-1.], Trade: 143
# Step 355, action: [-0.6876465], Trade: 144
# Step 356, action: [-1.], Trade: 145
# Step 357, action: [-0.43682924], Trade: 146
# Step 358, action: [-1.], Trade: 146
# Step 359, action: [0.01731193], Trade: 147
# Step 360, action: [-0.67280436], Trade: 147
# Step 361, action: [-0.45846736], Trade: 147
# Step 362, action: [0.31136826], Trade: 147
# Step 363, action: [1.], Trade: 147
# Step 364, action: [0.56426734], Trade: 147
# Step 365, action: [1.], Trade: 147
# Step 366, action: [-1.], Trade: 147
# Step 367, action: [0.5539174], Trade: 148
# Step 368, action: [-0.5281614], Trade: 148
# Step 369, action: [-0.6196886], Trade: 149
# Step 370, action: [0.45744643], Trade: 150
# Step 371, action: [-0.18748224], Trade: 150
# Step 372, action: [0.44516507], Trade: 151
# Step 373, action: [-0.42228496], Trade: 151
# Step 374, action: [-1.], Trade: 152
# Step 375, action: [-0.43161768], Trade: 153
# Step 376, action: [0.5293816], Trade: 154
# Step 377, action: [0.63106716], Trade: 154
# Step 378, action: [0.63827735], Trade: 154
# Step 379, action: [1.], Trade: 154
# Step 380, action: [0.5307116], Trade: 154
# Step 381, action: [-1.], Trade: 154
# Step 382, action: [0.21478619], Trade: 155
# Step 383, action: [-0.3297232], Trade: 155
# Step 384, action: [-0.64621234], Trade: 156
# Step 385, action: [-0.30764282], Trade: 157
# Step 386, action: [-0.23115908], Trade: 158
# Step 387, action: [0.7684539], Trade: 159
# Step 388, action: [-0.16717537], Trade: 159
# Step 389, action: [0.25818923], Trade: 160
# Step 390, action: [0.01028029], Trade: 160
# Step 391, action: [-1.], Trade: 160
# Step 392, action: [1.], Trade: 161
# Step 393, action: [0.39450374], Trade: 161
# Step 394, action: [1.], Trade: 161
# Step 395, action: [-1.], Trade: 161
# Step 396, action: [1.], Trade: 162
# Step 397, action: [1.], Trade: 162
# Step 398, action: [-1.], Trade: 162
# Step 399, action: [-0.09059466], Trade: 163
# Step 400, action: [-0.40359226], Trade: 163
# Step 401, action: [1.], Trade: 163
# Step 402, action: [1.], Trade: 163
# Step 403, action: [-0.05556779], Trade: 163
# Step 404, action: [-0.57293457], Trade: 164
# Step 405, action: [0.7263271], Trade: 165
# Step 406, action: [0.90565], Trade: 165
# Step 407, action: [-0.7627656], Trade: 165
# Step 408, action: [0.26679155], Trade: 166
# Step 409, action: [-0.40988418], Trade: 166
# Step 410, action: [-0.50720495], Trade: 167
# Step 411, action: [-0.3277774], Trade: 168
# Step 412, action: [0.7989238], Trade: 169
# Step 413, action: [0.78094316], Trade: 169
# Step 414, action: [1.], Trade: 169
# Step 415, action: [1.], Trade: 169
# Step 416, action: [-1.], Trade: 169
# Step 417, action: [-0.3166917], Trade: 170
# Step 418, action: [-0.1623886], Trade: 171
# Step 419, action: [0.20394157], Trade: 172
# Step 420, action: [-0.05786235], Trade: 172
# Step 421, action: [0.5556216], Trade: 173
# Step 422, action: [-0.35138318], Trade: 173
# Step 423, action: [0.50699365], Trade: 174
# Step 424, action: [1.], Trade: 174
# Step 425, action: [0.5092819], Trade: 174
# Step 426, action: [-1.], Trade: 174
# Step 427, action: [-1.], Trade: 175
# Step 428, action: [1.], Trade: 175
# Step 429, action: [-0.58010095], Trade: 175
# Step 430, action: [0.16421683], Trade: 176
# Step 431, action: [-1.], Trade: 176
# Step 432, action: [0.38202927], Trade: 177
# Step 433, action: [-0.9375334], Trade: 177
# Step 434, action: [-0.5261337], Trade: 178
# Step 435, action: [-1.], Trade: 179
# Step 436, action: [-0.19907829], Trade: 180
# Step 437, action: [0.6755873], Trade: 180
# Step 438, action: [1.], Trade: 180
# Step 439, action: [-0.3087242], Trade: 180
# Step 440, action: [-0.11768025], Trade: 181
# Step 441, action: [-0.938449], Trade: 182
# Step 442, action: [0.12839083], Trade: 183
# Step 443, action: [-0.49628264], Trade: 183
# Step 444, action: [0.60547745], Trade: 184
# Step 445, action: [-0.8991552], Trade: 184
# Step 446, action: [-0.36990976], Trade: 185
# Step 447, action: [1.], Trade: 186
# Step 448, action: [0.48486453], Trade: 186
# Step 449, action: [0.32978114], Trade: 186
# Step 450, action: [-0.6814093], Trade: 186
# Step 451, action: [0.3604191], Trade: 187
# Step 452, action: [-1.], Trade: 187
# Step 453, action: [0.29311135], Trade: 188
# Step 454, action: [-0.01941711], Trade: 188
# Step 455, action: [0.27148426], Trade: 188
# Step 456, action: [-0.54167277], Trade: 188
# Step 457, action: [0.31659997], Trade: 189
# Step 458, action: [0.36283323], Trade: 189
# Step 459, action: [0.72049683], Trade: 189
# Step 460, action: [1.], Trade: 189
# Step 461, action: [0.7065142], Trade: 189
# Step 462, action: [1.], Trade: 189
# Step 463, action: [-0.8172416], Trade: 189
# Step 464, action: [-0.64945734], Trade: 190
# Step 465, action: [-0.22352415], Trade: 191
# Step 466, action: [-0.03930935], Trade: 192
# Step 467, action: [1.], Trade: 193
# Step 468, action: [0.5691951], Trade: 193
# Step 469, action: [0.27221823], Trade: 193
# Step 470, action: [0.7701756], Trade: 193
# Step 471, action: [0.7598337], Trade: 193
# Step 472, action: [0.6734782], Trade: 193
# Step 473, action: [1.], Trade: 193
# Step 474, action: [-0.4164274], Trade: 193
# Step 475, action: [0.6708453], Trade: 194
# Step 476, action: [0.6186906], Trade: 194
# Step 477, action: [0.09171993], Trade: 194
# Step 478, action: [0.06083499], Trade: 194
# Step 479, action: [0.18715207], Trade: 194
# Step 480, action: [-1.], Trade: 194
# Step 481, action: [0.8157287], Trade: 195
# Step 482, action: [-0.16024615], Trade: 195
# Step 483, action: [1.], Trade: 196
# Step 484, action: [-0.20625767], Trade: 196
# Step 485, action: [0.6823109], Trade: 197
# Step 486, action: [0.4925087], Trade: 197
# Step 487, action: [0.4638297], Trade: 197
# Step 488, action: [1.], Trade: 197
# Step 489, action: [0.6583714], Trade: 197
# Step 490, action: [-0.30278468], Trade: 197
# Step 491, action: [-1.], Trade: 198
# Step 492, action: [0.9010099], Trade: 199
# Step 493, action: [0.75393826], Trade: 199
# Step 494, action: [1.], Trade: 199
# Step 495, action: [0.57335955], Trade: 199
# Step 496, action: [-0.7267327], Trade: 199
# Step 497, action: [-0.71806633], Trade: 200
# Step 498, action: [-0.46865088], Trade: 201
# Step 499, action: [-0.4739061], Trade: 202
# Step 500, action: [-0.6506269], Trade: 203
# Step 501, action: [1.], Trade: 204
# Step 502, action: [-0.922096], Trade: 204
# Step 503, action: [-1.], Trade: 205
# Step 504, action: [-0.05378279], Trade: 206
# Step 505, action: [-0.4542962], Trade: 206
# Step 506, action: [-0.1326936], Trade: 206
# Step 507, action: [0.6311776], Trade: 207
# Step 508, action: [-0.68290347], Trade: 207
# Step 509, action: [-0.11733326], Trade: 208
# Step 510, action: [-1.], Trade: 209
# Step 511, action: [-0.92394817], Trade: 210
# Step 512, action: [-0.11639538], Trade: 210
# Step 513, action: [-1.], Trade: 211
# Step 514, action: [-1.], Trade: 212
# Step 515, action: [-1.], Trade: 212
# Step 516, action: [-1.], Trade: 212
# Step 517, action: [1.], Trade: 212
# Step 518, action: [0.2328347], Trade: 212
# Step 519, action: [-0.46136886], Trade: 212
# Step 520, action: [0.8563965], Trade: 212
# Step 521, action: [-0.28106308], Trade: 212
# Step 522, action: [-0.49376327], Trade: 212
# Step 523, action: [0.8627806], Trade: 213
# Step 524, action: [-0.43813005], Trade: 213
# Step 525, action: [0.88791716], Trade: 214
# Step 526, action: [0.30190745], Trade: 214
# Step 527, action: [1.], Trade: 214
# Step 528, action: [0.46182004], Trade: 214
# Step 529, action: [-1.], Trade: 214
# Step 530, action: [-0.4913452], Trade: 215
# Step 531, action: [-0.6908111], Trade: 216
# Step 532, action: [0.30343497], Trade: 217
# Step 533, action: [1.], Trade: 217
# Step 534, action: [-1.], Trade: 217
# Step 535, action: [0.07387166], Trade: 218
# Step 536, action: [-1.], Trade: 218
# Step 537, action: [1.], Trade: 218
# Step 538, action: [-0.18531068], Trade: 218
# Step 539, action: [0.3091649], Trade: 219
# Step 540, action: [1.], Trade: 219
# Step 541, action: [1.], Trade: 219
# Step 542, action: [-0.85002834], Trade: 219
# Step 543, action: [-0.43302658], Trade: 220
# Step 544, action: [1.], Trade: 221
# Step 545, action: [0.8572157], Trade: 221
# Step 546, action: [-1.], Trade: 221
# Step 547, action: [0.72766304], Trade: 222
# Step 548, action: [1.], Trade: 222
# Step 549, action: [-0.7359802], Trade: 222
# Step 550, action: [-0.73767436], Trade: 223
# Step 551, action: [-0.9659507], Trade: 224
# Step 552, action: [0.6142348], Trade: 225
# Step 553, action: [-0.08877336], Trade: 225
# Step 554, action: [-0.80315095], Trade: 226
# Step 555, action: [-0.28528118], Trade: 227
# Step 556, action: [0.28741968], Trade: 228
# Step 557, action: [0.6366555], Trade: 228
# Step 558, action: [0.09774575], Trade: 228
# Step 559, action: [-1.], Trade: 228
# Step 560, action: [0.7313892], Trade: 229
# Step 561, action: [-0.32468694], Trade: 229
# Step 562, action: [0.79458034], Trade: 230
# Step 563, action: [-1.], Trade: 230
# Step 564, action: [-0.53655666], Trade: 231
# Step 565, action: [-0.86315113], Trade: 231
# Step 566, action: [0.6079083], Trade: 232
# Step 567, action: [-0.33232048], Trade: 232
# Step 568, action: [1.], Trade: 233
# Step 569, action: [-0.68212134], Trade: 233
# Step 570, action: [-0.300129], Trade: 234
# Step 571, action: [-1.], Trade: 235
# Step 572, action: [0.66187084], Trade: 236
# Step 573, action: [0.93842083], Trade: 236
# Step 574, action: [-0.14572139], Trade: 236
# Step 575, action: [0.4921491], Trade: 237
# Step 576, action: [0.49887598], Trade: 237
# Step 577, action: [-1.], Trade: 237
# Step 578, action: [1.], Trade: 238
# Step 579, action: [-1.], Trade: 238
# Step 580, action: [-0.7677826], Trade: 239
# Step 581, action: [0.3709967], Trade: 240
# Step 582, action: [-0.34572977], Trade: 240
# Step 583, action: [1.], Trade: 241
# Step 584, action: [1.], Trade: 241
# Step 585, action: [0.7844457], Trade: 241
# Step 586, action: [0.14038864], Trade: 241
# Step 587, action: [0.9134416], Trade: 241
# Step 588, action: [-0.6436623], Trade: 241
# Step 589, action: [-0.21117961], Trade: 242
# Step 590, action: [-0.6184479], Trade: 243
# Step 591, action: [1.], Trade: 244
# Step 592, action: [0.25565413], Trade: 244
# Step 593, action: [1.], Trade: 244
# Step 594, action: [0.14980929], Trade: 244
# Step 595, action: [-0.9581022], Trade: 244
# Step 596, action: [0.20496525], Trade: 245
# Step 597, action: [-0.01691326], Trade: 245
# Step 598, action: [0.6765952], Trade: 246
# Step 599, action: [0.52346265], Trade: 246
# Step 600, action: [0.4505069], Trade: 246
# Step 601, action: [0.0288944], Trade: 246
# Step 602, action: [-0.25718352], Trade: 246
# Step 603, action: [-0.50928247], Trade: 247
# Step 604, action: [0.71929985], Trade: 248
# Step 605, action: [-1.], Trade: 248
# Step 606, action: [-0.0480698], Trade: 249
# Step 607, action: [1.], Trade: 250
# Step 608, action: [0.70395476], Trade: 250
# Step 609, action: [0.5085736], Trade: 250
# Step 610, action: [-0.77812666], Trade: 250
# Step 611, action: [-0.2532534], Trade: 251
# Step 612, action: [0.48780653], Trade: 252
# Step 613, action: [-1.], Trade: 252
# Step 614, action: [1.], Trade: 253
# Step 615, action: [-0.21098499], Trade: 253
# Step 616, action: [0.8455575], Trade: 253
# Step 617, action: [-0.50636595], Trade: 253
# Step 618, action: [-0.48759013], Trade: 254
# Step 619, action: [-0.8177309], Trade: 255
# Step 620, action: [-0.59069216], Trade: 256
# Step 621, action: [-1.], Trade: 257
# Step 622, action: [-0.04272568], Trade: 258
# Step 623, action: [-0.39725885], Trade: 258
# Step 624, action: [-0.98729736], Trade: 258
# Step 625, action: [1.], Trade: 258
# Step 626, action: [0.55556965], Trade: 258
# Step 627, action: [0.38416505], Trade: 258
# Step 628, action: [1.], Trade: 258
# Step 629, action: [-0.38737494], Trade: 258
# Step 630, action: [-0.935842], Trade: 258
# Step 631, action: [0.05413361], Trade: 259
# Step 632, action: [-1.], Trade: 259
# Step 633, action: [0.8486363], Trade: 260
# Step 634, action: [-0.6509357], Trade: 260
# Step 635, action: [0.7714415], Trade: 260
# Step 636, action: [1.], Trade: 260
# Step 637, action: [-0.9942702], Trade: 260
# Step 638, action: [-0.08485647], Trade: 261
# Step 639, action: [1.], Trade: 262
# Step 640, action: [-0.04121966], Trade: 262
# Step 641, action: [-0.93672323], Trade: 263
# Step 642, action: [-0.25390497], Trade: 264
# Step 643, action: [0.13306716], Trade: 265
# Step 644, action: [-1.], Trade: 265
# Step 645, action: [-0.3801538], Trade: 266
# Step 646, action: [0.3155721], Trade: 266
# Step 647, action: [-0.2663069], Trade: 266
# Step 648, action: [-0.9423283], Trade: 266
# Step 649, action: [0.57879907], Trade: 267
# Step 650, action: [1.], Trade: 267
# Step 651, action: [0.7784604], Trade: 267
# Step 652, action: [-0.5716686], Trade: 267
# Step 653, action: [0.52501667], Trade: 268
# Step 654, action: [0.8052465], Trade: 268
# Step 655, action: [-1.], Trade: 268
# Step 656, action: [-1.], Trade: 269
# Step 657, action: [-1.], Trade: 269
# Step 658, action: [-0.22139476], Trade: 269
# Step 659, action: [-0.6285379], Trade: 270
# Step 660, action: [-0.86547196], Trade: 271
# Step 661, action: [-0.4619792], Trade: 272
# Step 662, action: [-1.], Trade: 273
# Step 663, action: [0.35661066], Trade: 274
# Step 664, action: [-0.15780243], Trade: 274
# Step 665, action: [-0.36329377], Trade: 274
# Step 666, action: [-0.7565153], Trade: 274
# Step 667, action: [-0.01841602], Trade: 274
# Step 668, action: [-0.0754039], Trade: 274
# Step 669, action: [-0.3276988], Trade: 275
# Step 670, action: [-0.33052117], Trade: 276
# Step 671, action: [0.18843132], Trade: 277
# Step 672, action: [0.5733638], Trade: 277
# Step 673, action: [1.], Trade: 277
# Step 674, action: [1.], Trade: 277
# Step 675, action: [-1.], Trade: 277
# Step 676, action: [-1.], Trade: 278
# Step 677, action: [-0.44998327], Trade: 279
# Step 678, action: [-0.70287174], Trade: 280
# Step 679, action: [1.], Trade: 281
# Step 680, action: [-0.14734344], Trade: 281
# Step 681, action: [0.7593559], Trade: 282
# Step 682, action: [0.91966414], Trade: 282
# Step 683, action: [0.77854246], Trade: 282
# Step 684, action: [0.06600369], Trade: 282
# Step 685, action: [1.], Trade: 282
# Step 686, action: [0.7728806], Trade: 282
# Step 687, action: [1.], Trade: 282
# Step 688, action: [-1.], Trade: 282
# Step 689, action: [0.23275207], Trade: 283
# Step 690, action: [-0.41141546], Trade: 283
# Step 691, action: [0.9002606], Trade: 283
# Step 692, action: [-0.4158264], Trade: 283
# Step 693, action: [-1.], Trade: 283
# Step 694, action: [-0.9585458], Trade: 283
# Step 695, action: [0.37936425], Trade: 284
# Step 696, action: [-0.695726], Trade: 284
# Step 697, action: [0.39321062], Trade: 285
# Step 698, action: [0.8290073], Trade: 285
# Step 699, action: [-0.13642108], Trade: 285
# Step 700, action: [-0.38434663], Trade: 286
# Step 701, action: [-0.15047085], Trade: 287
# Step 702, action: [1.], Trade: 288
# Step 703, action: [-0.41746682], Trade: 288
# Step 704, action: [1.], Trade: 289
# Step 705, action: [-0.5980514], Trade: 289
# Step 706, action: [-1.], Trade: 290
# Step 707, action: [0.71747077], Trade: 291
# Step 708, action: [-0.9412198], Trade: 291
# Step 709, action: [-1.], Trade: 292
# Step 710, action: [-0.334439], Trade: 293
# Step 711, action: [0.42379624], Trade: 293
# Step 712, action: [0.26623735], Trade: 293
# Step 713, action: [1.], Trade: 293
# Step 714, action: [0.00404606], Trade: 293
# Step 715, action: [1.], Trade: 293
# Step 716, action: [0.3729744], Trade: 293
# Step 717, action: [0.7401823], Trade: 293
# Step 718, action: [0.3892869], Trade: 293
# Step 719, action: [0.9695255], Trade: 293
# Step 720, action: [0.03915625], Trade: 293
# Step 721, action: [-0.9689023], Trade: 293
# Step 722, action: [0.9703257], Trade: 294
# Step 723, action: [1.], Trade: 294
# Step 724, action: [0.09984311], Trade: 294
# Step 725, action: [0.40080392], Trade: 294
# Step 726, action: [-0.669761], Trade: 294
# Step 727, action: [0.32224023], Trade: 295
# Step 728, action: [0.5352676], Trade: 295
# Step 729, action: [-0.63458484], Trade: 295
# Step 730, action: [0.9844261], Trade: 296
# Step 731, action: [-1.], Trade: 296
# Step 732, action: [1.], Trade: 297
# Step 733, action: [-1.], Trade: 297
# Step 734, action: [1.], Trade: 298
# Step 735, action: [-1.], Trade: 298
# Step 736, action: [-1.], Trade: 299
# Step 737, action: [0.6091527], Trade: 299
# Step 738, action: [0.5453151], Trade: 299
# Step 739, action: [0.4155074], Trade: 299
# Step 740, action: [0.8293732], Trade: 299
# Step 741, action: [1.], Trade: 299
# Step 742, action: [0.7806115], Trade: 299
# Step 743, action: [0.58190435], Trade: 299
# Step 744, action: [-0.12488284], Trade: 299
# Step 745, action: [-0.23069257], Trade: 300
# Step 746, action: [-1.], Trade: 301
# Step 747, action: [-1.], Trade: 302
# Step 748, action: [1.], Trade: 302
# Step 749, action: [-0.87581104], Trade: 302
# Step 750, action: [1.], Trade: 302
# Step 751, action: [1.], Trade: 302
# Step 752, action: [0.314129], Trade: 302
# Step 753, action: [0.00282953], Trade: 302
# Step 754, action: [0.37006187], Trade: 302
# Step 755, action: [0.8710149], Trade: 302
# Step 756, action: [0.39848763], Trade: 302
# Step 757, action: [0.00463628], Trade: 302
# Step 758, action: [-0.6561312], Trade: 302
# Step 759, action: [0.6208492], Trade: 303
# Step 760, action: [0.19801], Trade: 303
# Step 761, action: [-1.], Trade: 303
# Step 762, action: [-1.], Trade: 304
# Step 763, action: [-1.], Trade: 304
# Step 764, action: [-1.], Trade: 304
# Step 765, action: [-0.01371166], Trade: 305
# Step 766, action: [0.6049928], Trade: 306
# Step 767, action: [-1.], Trade: 306
# Step 768, action: [1.], Trade: 307
# Step 769, action: [-0.44099113], Trade: 307
# Step 770, action: [-0.52285886], Trade: 307
# Step 771, action: [1.], Trade: 307
# Step 772, action: [0.8827506], Trade: 307
# Step 773, action: [0.63890123], Trade: 307
# Step 774, action: [-0.50472635], Trade: 307
# Step 775, action: [0.40083265], Trade: 308
# Step 776, action: [-0.6519593], Trade: 308
# Step 777, action: [1.], Trade: 309
# Step 778, action: [0.02041286], Trade: 309
# Step 779, action: [-0.7178821], Trade: 309
# Step 780, action: [-0.16900147], Trade: 310
# Step 781, action: [0.32098156], Trade: 311
# Step 782, action: [1.], Trade: 311
# Step 783, action: [0.58384156], Trade: 311
# Step 784, action: [-0.20776294], Trade: 311
# Step 785, action: [-1.], Trade: 312
# Step 786, action: [-1.], Trade: 313
# Step 787, action: [-0.27450255], Trade: 314
# Step 788, action: [-0.5141494], Trade: 315
# Step 789, action: [-0.4974902], Trade: 316
# Step 790, action: [1.], Trade: 317
# Step 791, action: [-1.], Trade: 317
# Step 792, action: [-0.91612124], Trade: 318
# Step 793, action: [0.90551794], Trade: 318
# Step 794, action: [-0.36825502], Trade: 318
# Step 795, action: [-0.5066428], Trade: 318
# Step 796, action: [0.8335921], Trade: 319
# Step 797, action: [-0.17870897], Trade: 319
# Step 798, action: [1.], Trade: 320
# Step 799, action: [-0.7699572], Trade: 320
# Step 800, action: [0.40160736], Trade: 321
# Step 801, action: [0.9465674], Trade: 321
# Step 802, action: [-0.05696342], Trade: 321
# Step 803, action: [-1.], Trade: 322
# Step 804, action: [0.77788645], Trade: 323
# Step 805, action: [-1.], Trade: 323
# Episode: 13, com: AXP, win trade: 179/323, Total reward: 15.880455767055734
# hit end!
