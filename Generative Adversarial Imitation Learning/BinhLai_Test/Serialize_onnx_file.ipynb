# %% [markdown]
# # TEST THE CONNECTING FLOW FROM PYTHON SCRIPT TO UNITY CLOUD

# %% [markdown]
# ## Test loading an ML model from local files

# %%
import os

current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/Generative Adversarial Imitation Learning/BinhLai_Test

# %% [markdown]
# #### Load an available model & save it as txt file

# %%
from onnx import load

onnx_model = load("test_model.onnx")
with open("text_model.txt", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# #### Load model from txt file and save it as onnx model

# %%
with open("text_model.txt", "rb") as f:
    content = f.read()

with open("test_save_model.onnx", "wb") as f:
    f.write(content)

# %%
with open("test_save_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# #### Read onnx model from txt file downloaded from UGC

# %% [markdown]
# Turn UGC file to a text model

# %%
with open("TestOnnx", "rb") as f:
    content = f.read()

# %% [markdown]
# Turn the text model into an onnx model

# %%
with open("test_save_model_from_UGC.onnx", "wb") as f:
    f.write(content)

# %%
from onnx import load
onnx_model = load("test_model.onnx")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# #### Read onnx model from zip file downloaded from UGC

# %%
from stable_baselines3 import PPO

with open("zip_text_model", "rb") as f:
    zip_text_content = f.read()

with open("zip_model.zip", "wb") as f:
    f.write(zip_text_content)
    
trained_model = PPO.load("zip_model")
trained_model.get_parameters()
# Out:
# {'policy': OrderedDict([('mlp_extractor.policy_net.0.weight',
#                tensor([[-0.5232, -1.6719, -0.1394,  ...,  0.0394, -0.1465,  0.0982],
#                        [ 0.3431, -0.2289, -0.1181,  ...,  0.0684,  0.0246, -0.0075],
#                        [-0.2149,  0.5828, -0.1231,  ...,  0.0398,  0.0325,  0.0484],
#                        ...,
#                        [-0.0372, -2.6689, -0.1152,  ...,  0.0908,  0.1516, -0.0619],
#                        [-0.0856, -1.2947,  0.1236,  ..., -0.0893,  0.0108,  0.3068],
#                        [ 0.2195, -1.3214,  0.3023,  ..., -0.0439,  0.1932, -0.2450]])),
#               ('mlp_extractor.policy_net.0.bias',
#                tensor([ 0.0765, -0.2225,  0.0138, -0.0794, -0.0554, -0.0346,  0.0076, -0.0507,
#                         0.0871, -0.1378,  0.0586, -0.1396,  0.0561,  0.0589,  0.2004, -0.0183,
#                        -0.0330, -0.1161, -0.1134,  0.0064,  0.0986, -0.0325, -0.0580,  0.1622,
# ...

# %% [markdown]
# ## Test connecting to Unity Cloud

# %%
import requests

# %%
url = "https://cloud-save.services.api.unity.com/v1/data/projects/dec49a5b-f225-4337-9ffb-3d095b81a994/environments/ee2d923d-2aab-451e-8d78-1fbdc487711a/player-id/oZFhVsAuYjXVfx1C6B2K8LMY4sN2/items"
method = "GET"  # Adjust based on the API documentation (GET, POST, etc.)
headers = {"Authorization": "serviceToken"}  # Optional headers
data = {"key": "GAME_PROCESS"}  # Optional data for POST/PUT requests

# %%
response = requests.request(method, url, headers=headers, data=data)

# %%
response
# Out:
# <Response [401]>

# %%
url = "https://services.api.unity.com/auth/v1/token-exchange?projectId=dec49a5b-f225-4337-9ffb-3d095b81a994&environmentId=ee2d923d-2aab-451e-8d78-1fbdc487711a"
method = "POST"
headers = {"Authorization": "Basic <ENCODED_SECRET>"}

# %%
response = requests.request(method=method,url=url, headers=headers)

# %%
response
# Out:
# <Response [401]>

# %%
url = "http://localhost:8086/v4/token"
method = "GET"

# %%
response = requests.request(method=method,url=url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ...

# %%
response
# Out:
# <Response [404]>

# %% [markdown]
# Anonymous login

# %%
url = "https://player-auth.services.api.unity.com/v1/authentication/anonymous"
method = "POST"  # Adjust based on the API documentation (GET, POST, etc.)
headers = {"ProjectId": "dec49a5b-f225-4337-9ffb-3d095b81a994","UnityEnvironment":"dev"}  # Optional headers
# data = {"nonce": "eyJhbGciOiJSUzI1NiIsImtpZCI6InB1YmxpYzo2NzQ2QjA5NC0zODNCLTRFMDYtQjA0OS04OUU4MTU1NjdBOUQiLCJ0eXAiOiJKV1QifQ.....Ruggtvew-RAKk-a1Gz2AriuttdR6XYnf_zZ2sPPNd8LdL7tK6mCtYTIxbGxPOdgs7E-Z9DyNRFBB6Hi6GapIDDE9TS5kCqU9RPST_BtGTmbl1QVFyyzuNQ11vQ9ifehoaNQgtlxvz05Cy6ZDgtG_QyFcCumR3IJYYxvnQOGTzKFaoL4-4w0bAtC68lKWXRQiiQIjL9oUJDWgE5e5-vBVWPJVJYseJHVlpjRlR2_KXHh8aYL-2AzcKNNTv-xVvbW17KbkKdy_Rm61O7pCEXileDi_I3IjsHO_PSbU2eqZxwu2FyLAObc9LeltvCxPE52zOuvVcLE0mTSH6ECtwNzadw"}  # Optional data for POST/PUT requests
response0 = requests.request(method, url, headers=headers)
response0.text
# Out:
# '{"expiresIn":3599,"idToken":"eyJhbGciOiJSUzI1NiIsImtpZCI6InB1YmxpYzo2NzQ2QjA5NC0zODNCLTRFMDYtQjA0OS04OUU4MTU1NjdBOUQiLCJ0eXAiOiJKV1QifQ.....akpojnI2nwCoZUv4ylzwXrOBCfSe73AeC60KiqbOI0Ui7RMXBtOfro_oazJ1vkKg_uNCoXDyXQz1F7GURdosIcZ3lyGxR53dS9ghzCk9I2MJMUtcX-qgzyh0kl4XDkiTW1THxYQFZPPnyHeZkZXFTg1e4P_kSRKMx7K9MPAFq9JbP1xV4gz0EyEER6mtWlvBjihCF0kV30xW71U_r7z5jt9y1oG3L3KE89Genl6BxgywkurQAk7zFiCqvfyZzFLGXlnARwHI_jh9Kyz9Lw05GcvOezodQ2fZ6NEmGBxemVz37EnoJTZ-5fkmntY_O8PD3CC07NZPoQXVKEWKIq1piw","sessionToken":"ermNlU_nieDU2wHuZK9ZgHr5IzCYHrE2Ahm7e6NuEKhh8_YRpzw8bRSFP8n52MvyClyuy7wxL_AYStZJkL-DOcDwdx03LiGrGF6So0oL2Iu_L5UwgzAYKl36dzdvQJfimpFDUYhQ0a_SPE3x7O7RqhR44EEreZqA7IdWXK3diMg.cIQkx7TbonUk3GR_9QHJOY3ArHDa94kEM056eoKVm-Q","user":{"disabled":false,"externalIds":[],"id":"xUI2UquDzfBq8AyISOg24S52CIPq"},"userId":"xUI2UquDzfBq8AyISOg24S52CIPq"}\n'

# %%
url = "https://player-auth.services.api.unity.com/v1/authentication/session-token"
method = "POST"  # Adjust based on the API documentation (GET, POST, etc.)
headers = {"ProjectId": "dec49a5b-f225-4337-9ffb-3d095b81a994","UnityEnvironment":"dev","Content-Type": "application/json"}  # Optional headers
data = {"sessionToken": "lo42aDkla2tr_GkMzRxS9vhuqrpMOxZtniS4GvYTRYrso4fsmKVp5e208aI-Nv6q9TTs8zRoPjojE36l5WvkBkDjTrEYdMceVJxQAzMNYS0hrPjgeJXRkUFTBuOKpKhKB4gyMVe5Lw57lWk5ReGQr35B_FhS_QtO5NY0JueP8pQ.KedS3F44QHOnHor7wHP_ujVBfrQ85wN-nsU4z4ROCbU"}
response1 = requests.request(method, url, headers=headers, data=data)
response1.text
# Out:
# <Response [500]>

# %% [markdown]
# Get player's information

# %%
url = "https://player-auth.services.api.unity.com/v1/users/xUI2UquDzfBq8AyISOg24S52CIPq"
method = "GET"  # Adjust based on the API documentation (GET, POST, etc.)
headers = {"ProjectId": "dec49a5b-f225-4337-9ffb-3d095b81a994","Authorization":"Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6InB1YmxpYzo2NzQ2QjA5NC0zODNCLTRFMDYtQjA0OS04OUU4MTU1NjdBOUQiLCJ0eXAiOiJKV1QifQ.....akpojnI2nwCoZUv4ylzwXrOBCfSe73AeC60KiqbOI0Ui7RMXBtOfro_oazJ1vkKg_uNCoXDyXQz1F7GURdosIcZ3lyGxR53dS9ghzCk9I2MJMUtcX-qgzyh0kl4XDkiTW1THxYQFZPPnyHeZkZXFTg1e4P_kSRKMx7K9MPAFq9JbP1xV4gz0EyEER6mtWlvBjihCF0kV30xW71U_r7z5jt9y1oG3L3KE89Genl6BxgywkurQAk7zFiCqvfyZzFLGXlnARwHI_jh9Kyz9Lw05GcvOezodQ2fZ6NEmGBxemVz37EnoJTZ-5fkmntY_O8PD3CC07NZPoQXVKEWKIq1piw"}  # Optional headers
# data = {"key": "GAME_PROCESS"}  # Optional data for POST/PUT requests
response2 = requests.request(method, url, headers=headers)
response2.text
# Out:
# '{"createdAt":"1712926167","disabled":false,"externalIds":[],"id":"xUI2UquDzfBq8AyISOg24S52CIPq","lastLoginAt":"1712926167"}\n'

# %% [markdown]
# Get player's data

# %%
url = "https://cloud-save.services.api.unity.com/v1/data/projects/dec49a5b-f225-4337-9ffb-3d095b81a994/players/xUI2UquDzfBq8AyISOg24S52CIPq/items"
method = "GET"  # Adjust based on the API documentation (GET, POST, etc.)
headers = {"ProjectId": "dec49a5b-f225-4337-9ffb-3d095b81a994", "Authorization":"Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6InVuaXR5LWtleXM6MzU0OWFkNDMtN2RjYS00YTdkLTg2MWMtYjJmM2ZjZmMyZTAyIiwiamt1IjoiaHR0cHM6Ly9rZXlzLnNlcnZpY2VzLnVuaXR5LmNvbS8ifQ.....AvVxkHi3KtHNh89a2DiUa8keNMaV9YfSro4d28em13Zj4c8JUZ2ZyZHSVNpAFdSHyw22ahZymyBaZJbiaNxgAzyyx71kpJ8BrFB_TWL3nYANsM1XeaEZMn1M7gpiEH0vVwpjO7cewO01TvEr7NrUR0RcsKY2UMPXnuLnDtH4wWE8Cu_TRJ_5pKW77rPaGj_tf-HHznr6QGyJMubFyXRA0An6NDE95ODasg-AqUgMXEJgOL8tN2SO5LVUoVGCOeznU8oXv_exKeMJsn7gaPgA0tCsFwG6CTL7Q4SwIBkOzBSYGhwRdIaQdKiOlxTFjfTR4xnXK71YZlxwRZ_xIIBRug"}
data = {"key": "GAME_PROCESS"}
response2 = requests.request(method, url, headers=headers)
response2.text
# Out:
# '{"results":[],"links":{"next":null}}'

# %% [markdown]
# Authenticate an API using service account credentials

# %%
url = "https://services.api.unity.com/auth/v1/token-exchange?projectId=dec49a5b-f225-4337-9ffb-3d095b81a994&environmentId=ee2d923d-2aab-451e-8d78-1fbdc487711a"
method = "POST"
headers = {"Authorization": "Basic d2aedefb-5574-4234-9f21-9679914c6cd1:bxn_jkbj5SMF4ZtrljxdYiby2LJ_vJrZ"}
response4 = requests.request(method, url, headers=headers)
response4.text
# Out:
# '{"accessToken":"eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6InVuaXR5LWtleXM6MzU0OWFkNDMtN2RjYS00YTdkLTg2MWMtYjJmM2ZjZmMyZTAyIiwiamt1IjoiaHR0cHM6Ly9rZXlzLnNlcnZpY2VzLnVuaXR5LmNvbS8ifQ.....AvVxkHi3KtHNh89a2DiUa8keNMaV9YfSro4d28em13Zj4c8JUZ2ZyZHSVNpAFdSHyw22ahZymyBaZJbiaNxgAzyyx71kpJ8BrFB_TWL3nYANsM1XeaEZMn1M7gpiEH0vVwpjO7cewO01TvEr7NrUR0RcsKY2UMPXnuLnDtH4wWE8Cu_TRJ_5pKW77rPaGj_tf-HHznr6QGyJMubFyXRA0An6NDE95ODasg-AqUgMXEJgOL8tN2SO5LVUoVGCOeznU8oXv_exKeMJsn7gaPgA0tCsFwG6CTL7Q4SwIBkOzBSYGhwRdIaQdKiOlxTFjfTR4xnXK71YZlxwRZ_xIIBRug"}'

# %% [markdown]
# Get another player's data

# %%
url = "https://cloud-save.services.api.unity.com/v1/data/projects/dec49a5b-f225-4337-9ffb-3d095b81a994/players/oZFhVsAuYjXVfx1C6B2K8LMY4sN2/items"
method = "GET"  # Adjust based on the API documentation (GET, POST, etc.)
headers = {"ProjectId": "dec49a5b-f225-4337-9ffb-3d095b81a994","Authorization":"Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6InVuaXR5LWtleXM6MzU0OWFkNDMtN2RjYS00YTdkLTg2MWMtYjJmM2ZjZmMyZTAyIiwiamt1IjoiaHR0cHM6Ly9rZXlzLnNlcnZpY2VzLnVuaXR5LmNvbS8ifQ.....AvVxkHi3KtHNh89a2DiUa8keNMaV9YfSro4d28em13Zj4c8JUZ2ZyZHSVNpAFdSHyw22ahZymyBaZJbiaNxgAzyyx71kpJ8BrFB_TWL3nYANsM1XeaEZMn1M7gpiEH0vVwpjO7cewO01TvEr7NrUR0RcsKY2UMPXnuLnDtH4wWE8Cu_TRJ_5pKW77rPaGj_tf-HHznr6QGyJMubFyXRA0An6NDE95ODasg-AqUgMXEJgOL8tN2SO5LVUoVGCOeznU8oXv_exKeMJsn7gaPgA0tCsFwG6CTL7Q4SwIBkOzBSYGhwRdIaQdKiOlxTFjfTR4xnXK71YZlxwRZ_xIIBRug"}
data = {"key": "GAME_PROCESS"}  # Optional data for POST/PUT requests
response3 = requests.request(method, url, headers=headers)
response3.text
# Out:
# '{"results":[{"key":"GAME_PROCESS","value":{"testString":"Binh Lai test this Cloud Save"},"writeLock":"69565b464dcb4c1d2d1f99b245abee25","modified":{"date":"2024-04-09T12:33:24Z"},"created":{"date":"2024-04-09T12:33:24Z"}}],"links":{"next":null}}'
