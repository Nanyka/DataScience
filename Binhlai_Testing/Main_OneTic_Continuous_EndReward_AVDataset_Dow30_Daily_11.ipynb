# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch
# ## Main_RandomTic_Continuous_AVDataset_Dow30_Daily
# Network: 128x64x32x16

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Check Additional Packages](#1.1)
#     * [2.2. Import Packages](#1.2)
#     * [2.3. Create Folders & Relevant Configurations¶](#1.3)
# * [3. Download Data](#2)
# * [4. Preprocess fundamental data](#3)
#     * [4.1. Import the financial data](#3.1)
#     * [4.2. Specify items needed to calculate financial ratios](#3.2)
#     * [4.3. Turn the final_ratios to daily basis](#3.3)
#     * [4.4. Merge stock price data and ratios into one dataframe](#3.4)
#     * [4.5. Finish data preparation](#3.5)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. Set up the training environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Train DRL Agent](#5)
# * [7.Backtest Our Strategy](#6)
#     * [7.1. BackTest with DJIA](#6.1)
#     * [7.2. BackTest with Buy&Hold Strategy](#6.2)
# * [8.Save & load model](#7)
#     * [8.1. Save model](#7.1)
#     * [8.2. Load model](#7.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−1, ... ,0, ..., 1}, to denote the magnitude of the transaction based on the proportion of a baseline asset.
# For example, "Buy AAPL with 10% remain capital" or "Sell 10% shares of AAPL" are 0.1 or −0.1, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents from 1st January,2012 to 31st December 2021
#
#
# The data of the single stock that we will be using for this case study is obtained from Alpha Vantage API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# ### If continuing the previous training, jump to [**this point**](#8.1)

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
import datetime
import math
from stable_baselines3.common.logger import configure

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Create Folders & Relevant Configurations

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
from datetime import datetime
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

TRAIN_START_DATE = '2000-01-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

# Load price data from csv file
tic_dir = './' + DATA_SAVE_DIR + '/sp500_price_daily.csv'
df = pd.read_csv(tic_dir,index_col=0)

# %% [markdown]
# If the data is available locally, we can skip downloading steps and jump directly to part [**4.5.Finish data preparation**](#3.5)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Price Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# Download data from YFinance
# tic_dir = './' + DATA_SAVE_DIR + '/sp500_ticker.csv'
# tic_list = pd.read_csv(tic_dir,index_col=0)
# SP_500_TICKER = np.array(tic_list.tic).tolist()
# df = YahooDownloader(start_date = TRAIN_START_DATE,
#                      end_date = TEST_END_DATE,
#                      ticker_list = SP_500_TICKER).fetch_data()

# %%
# df.head()

# %%
# df.tail()

# %%
# df.shape

# %%
# df.sort_values(['date','tic']).head()

# %%
# len(df.tic.unique())

# %%
# df.tic.value_counts()

# %% [markdown]
# <a id='3'></a>
# # Part 4: Preprocess fundamental data
# - Import finanical data downloaded from Alpha Vantage
# - Preprocess the dataset and calculate financial ratios
# - Turn yearly ratio into daily basis

# %% [markdown]
# <a id='3.1'></a>
# ## 4.1 Import the financial data

# %% [markdown]
# #### Define configurations of the collecting data & download data via Alpha Vantage API

# %%
# import requests

# api_key = 'GZWRUSYXT18ZTR6C'
# features_cols = ['fiscalDateEnding','totalRevenue','costOfRevenue','sellingGeneralAndAdministrative','researchAndDevelopment','depreciation','interestExpense','totalCurrentLiabilities','incomeTaxExpense','netIncome','commonStockSharesOutstanding','cashAndCashEquivalentsAtCarryingValue','cashAndShortTermInvestments','operatingCashflow','totalLiabilities','inventory','currentNetReceivables','propertyPlantEquipment','capitalExpenditures','longTermInvestments','totalShareholderEquity','longTermDebt','retainedEarnings','dividendPayoutCommonStock','paymentsForRepurchaseOfCommonStock','treasuryStock','currentLongTermDebt']
# price_cols = ['open','high','low','close','volume']

# %% [markdown]
# Function to download fundamental data from financial reports by ticket

# %%
# def collect_fundamental(ticket):
#     # Download income statement
#     url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_is = r.json()

#     # Download balance sheet
#     url = f'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_bs = r.json()

#     # Download cash flow
#     url = f'https://www.alphavantage.co/query?function=CASH_FLOW&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_cf = r.json()

#     df_is = pd.json_normalize(data_is['annualReports'])
#     df_bs = pd.json_normalize(data_bs['annualReports'])
#     df_cf = pd.json_normalize(data_cf['annualReports'])

#     merged_df = df_is.merge(df_bs).merge(df_cf)
#     merged_df['tic'] = ticket
#     merged_df = merged_df[['tic']+features_cols]
#     merged_df['fiscalDateEnding'] = pd.to_datetime(merged_df.fiscalDateEnding,format='mixed')

#     return merged_df

# %% [markdown]
# Function to download stock price by ticket

# %%
# def collect_price(ticket):
#     url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_monthly_price = r.json()

#     price_monthly = pd.DataFrame.from_dict(data_monthly_price['Monthly Time Series'], orient='index')
#     price_monthly.columns = price_cols
#     price_monthly['fiscalDateEnding'] = pd.to_datetime(price_monthly.index,format='mixed')
#     price_monthly.reset_index(inplace=True,drop=True)
#     price_monthly = price_monthly[['fiscalDateEnding','open','high','low','close','volume']]
#     return price_monthly

# %% [markdown]
# Function to merge monthly stock price into yearly fundamental data

# %%
# def merge_price_to_df(merged_df,price_monthly):
#     merged_df['year'] = merged_df.fiscalDateEnding.dt.year
#     merged_df['month'] = merged_df.fiscalDateEnding.dt.month
#     price_monthly['year'] = price_monthly.fiscalDateEnding.dt.year
#     price_monthly['month'] = price_monthly.fiscalDateEnding.dt.month
#     merged_final = pd.merge(merged_df,price_monthly,how="left",on=['year','month'])
#     merged_final.drop(columns=['year','month','fiscalDateEnding_y'],inplace=True)
#     merged_final = df_final.rename(columns={'fiscalDateEnding_x': 'date'})
#     merged_final['tic'] = ticket

#     merged_columns = [merged_final.columns[-1]]
#     for i in range(0,len(merged_final.columns)-1):
#         merged_columns.append(merged_final.columns[i])
#     merged_final = merged_final[merged_columns]
    
#     return merged_final

# %%
# download_tics = SP_500_TICKER[453:]
# print(download_tics)

# %%
# fund_data = pd.DataFrame()

# for ticket in download_tics:
#     df_fund = collect_fundamental(ticket)
#     fund_data = pd.concat([fund_data, df_fund], ignore_index=True)

# %%
# fund_data.to_csv('sp500_6.csv')

# %%
# Check dropped tickers which are not available data to download from Alpha Vantage

# tics_1 = pd.DataFrame()
# tics_2 = pd.DataFrame()
# tics_1['tic'] = df.tic.unique()
# tics_2['tic'] = fund_data.tic.unique()

# merged_df = tics_1.merge(tics_2, how='outer', indicator=True)
# unique_in_df = merged_df[merged_df['_merge'] == 'left_only']
# unique_in_df

# %% [markdown]
# #### Check reach download limitation

# %%
# url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=IBM&apikey=GZWRUSYXT18ZTR6C'
# r = requests.get(url)
# data_is = r.json()
# data_is

# %% [markdown]
# #### Load data from csv file

# %%
# fund_data = pd.read_csv('./' + DATA_SAVE_DIR + '/dow30_fundamental.csv',index_col=0)
# # fund_data = fund_data.rename(columns={'fiscalDateEnding_x':'date'})
# fund_data['date'] = pd.to_datetime(fund_data.date,format='mixed')
# fund_data

# %% [markdown]
# Select tickers in DJ index only.

# %%
# fund_data = fund_data[fund_data.tic.isin(DOW_30_TICKER)].reset_index(drop=True)
# fund_data.tic.nunique()

# %%
# # UTIL TOOL: merge yearly fundamental data to daily stock price

# start_date = df.iloc[0].date
# end_date = df.iloc[-1].date
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')
# date_range = pd.DataFrame(date_range)
# date_range.columns = ['date']

# fund_data = fund_data.rename(columns={'fiscalDateEnding':'date'})
# fund_data['date'] = pd.to_datetime(fund_data.date,format='mixed')

# fund_data_with_price = pd.DataFrame()
# for ticket in fund_data.tic.unique():
#     price_by_ticket = df[df.tic == ticket]
#     price_by_ticket['date'] = pd.to_datetime(price_by_ticket['date'],format='mixed')
#     price_by_ticket = pd.merge(date_range,price_by_ticket,how='left')
#     price_by_ticket.bfill(inplace=True)
#     price_by_ticket = pd.merge(fund_data.loc[fund_data.tic==ticket],price_by_ticket,how='left',on=['date'])
#     price_by_ticket.drop(columns=['tic_y','day'],inplace=True,axis=0)
#     price_by_ticket = price_by_ticket.rename(columns={'tic_x':'tic'})
#     fund_data_with_price = pd.concat([fund_data_with_price, price_by_ticket], ignore_index=True)

# fund_data = fund_data_with_price

# %% [markdown]
# #### Data cleaning ####
# Refine the data before computing fundamental ratios

# %%
# print(fund_data.info(),'\n')
# print(fund_data.isna().sum())

# %% [markdown]
# The company with zero totalRevenue might cause problems for computing ratios while it is the denominator in some formulars.<br>
# Deleting all tickers containing this issue is a good solution.

# %%
# zero_revenue_tics = fund_data[fund_data.totalRevenue == 0].tic.unique()
# fund_data = fund_data[~fund_data.tic.isin(zero_revenue_tics)]
# fund_data[fund_data.totalRevenue == 0]

# %% [markdown]
# While removing zero revenue data was neccessary, other columns with zero values might indicate some potential issues that require further investigations

# %%
# column_nan = fund_data.eq(0).any()
# column_nan

# %%
# fund_data = fund_data.fillna(0)
# # for i in fund_data.columns:
# #     print(i,'\n',fund_data[i].unique(),'\n')

# %% [markdown]
# <a id='3.2'></a>
# ## 4.2 Compute fundamental ratio

# %% [markdown]
# Define support functions before computing fundamental ratios

# %%
# # Define a function to count positive values within a window
# def count_positives(window):
#   return window[window > 0].count()

# def count_positives_window(data,k):
#     df = pd.DataFrame(data, columns=['values'])

#     # Create a new column with the adjusted positive count (using a shifted window)
#     df['positive_count'] = df['values'].rolling(window=k, min_periods=1).apply(count_positives)

#     # Set positive_count of the first k rows to positive_count of row k
#     df.loc[:k-1,'positive_count'] = df.loc[k-1].positive_count

#     return df

# %%
# # Define a function to get min items in a window
# def get_min(window):
#   return window.min()

# def min_in_window(data,k):
#     df = pd.DataFrame(data, columns=['values'])

#     # Create a new column with the min in the window (using a shifted window)
#     df['min'] = df['values'].rolling(window=k, min_periods=1).apply(get_min)

#     return df

# %% [markdown]
# At this point, data and supporting functions are ready for computing fundamental ratios required

# %%
# def compute_fund_ratios(df_final):
#     pos_count_window = 10  # number of years to look back for count_positive_profit
#     min_ebit_window = 4  # number of years to look back for min_ebit
    
#     gross_income = df_final.totalRevenue - df_final.costOfRevenue
#     ebit = gross_income - df_final.sellingGeneralAndAdministrative
#     profit = ebit - df_final.interestExpense - df_final.incomeTaxExpense
#     market_equity = df_final.commonStockSharesOutstanding * df_final.close
#     market_asset = df_final.totalLiabilities + market_equity
    
#     # Gross profit margin
#     gross_profit_margin = (gross_income/df_final.totalRevenue).to_frame('gross_profit_margin')
    
#     # SGA Expense / Gross Profit
#     sga_ratio = (df_final.sellingGeneralAndAdministrative/gross_income).to_frame('sga_ratio')
    
#     # Depreciation / Gross Profit
#     dep_ratio = (df_final.depreciation/gross_income).to_frame('dep_ratio')
    
#     # EBIT / Bond interest
#     ebit_on_int = (ebit/df_final.interestExpense).to_frame('ebit_on_int')
    
#     # Profit margin
#     profit_margin = (profit/df_final.totalRevenue).to_frame('profit_margin')
    
#     # Amount of positive profit within a window
#     count_positive_profit = count_positives_window(profit,pos_count_window)
#     count_positive_profit = count_positive_profit['positive_count'].to_frame('count_positive_profit')
#     count_positive_profit = count_positive_profit / pos_count_window # Standadize the positive profit
    
#     # Cash And Short Term Investments / Total Liabilities
#     csti_on_liabilities = (df_final.cashAndShortTermInvestments/df_final.totalLiabilities).to_frame('csti_on_liabilities')
    
#     # Inventory / EBIT
#     inventory_on_ebit = (df_final.inventory / ebit).to_frame('inventory_on_ebit')
    
#     # Receivable / Revenue
#     receivable_on_rev = (df_final.currentNetReceivables / df_final.totalRevenue).to_frame('receivable_on_rev')
    
#     # ROA
#     roa = (profit / market_asset).to_frame('roa')
    
#     # ROE
#     roe = (profit / market_equity).to_frame('roe')
    
#     # Long-term debt / minEBIT
#     min_ebit = min_in_window(ebit,min_ebit_window)['min']
#     debt_on_min_ebit = (df_final.longTermDebt / min_ebit).to_frame('debt_on_min_ebit')
    
#     # Total Liabilities / Total Equity
#     liabilities_on_equity = (df_final.totalLiabilities / market_equity).to_frame('liabilities_on_equity')
    
#     # Capital Expenditures / EBIT
#     capital_cost_on_ebit = (df_final.capitalExpenditures / ebit).to_frame('capital_cost_on_ebit')
    
#     # EPS / MP
#     eps = profit / df_final.commonStockSharesOutstanding
#     eps_on_mp = (eps / df_final.close).to_frame('eps_on_mp')
    
#     # Cash and Stock Dividend & Repurchase Common / MP
#     dividend_on_mp = ((df_final.dividendPayoutCommonStock + df_final.paymentsForRepurchaseOfCommonStock) / df_final.close).to_frame('dividend_on_mp')
    
#     # MP / BV
#     mp_on_bv = (df_final.close / (df_final.cashAndShortTermInvestments + df_final.currentNetReceivables*0.8 +df_final.inventory*0.5 + df_final.propertyPlantEquipment*0.2 + df_final.longTermInvestments - df_final.totalLiabilities)).to_frame('mp_on_bv')

#     # Turn market-relevance metrics to dataframe
#     profit = profit.to_frame('profit')
#     common_stock = df_final.commonStockSharesOutstanding.to_frame('common_stock')
#     total_liabilities = df_final.totalLiabilities.to_frame('total_liabilities')   
#     eps = eps.to_frame('eps')
#     dividend = (df_final.dividendPayoutCommonStock + df_final.paymentsForRepurchaseOfCommonStock).to_frame('dividend')
#     bv = (df_final.cashAndShortTermInvestments + df_final.currentNetReceivables*0.8 +df_final.inventory*0.5 + df_final.propertyPlantEquipment*0.2 + df_final.longTermInvestments - df_final.totalLiabilities).to_frame('bv')
    
#     # Create a dataframe that merges all the ratios
#     ratios = pd.concat([df_final.date,df_final.tic,df_final.close,profit,common_stock,total_liabilities,eps, dividend, bv,
#                         gross_profit_margin,sga_ratio,dep_ratio,ebit_on_int,profit_margin,count_positive_profit,
#                         csti_on_liabilities,inventory_on_ebit,receivable_on_rev,roa,roe,debt_on_min_ebit,
#                         liabilities_on_equity,capital_cost_on_ebit,eps_on_mp,dividend_on_mp,mp_on_bv,], axis=1)
    
#     return ratios

# %%
# ratios = compute_fund_ratios(fund_data)
# ratios

# %% [markdown]
# #### At this point, we must do some feature engineering on ratios to ensure the trends and fluctuations are able to be computed

# %% [markdown]
# Check columns with inf values

# %%
# ratio_list = ratios.columns.drop(['date','tic'])
# check_ratios = ratios[ratio_list]
# inf_cols = check_ratios.columns[~np.isfinite(check_ratios).all()]
# inf_cols

# %% [markdown]
# Check rows with inf values

# %%
# ratio_inf = ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
# print(len(ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]))
# ratio_inf.head()

# %% [markdown]
# The **ebit_on_int** has infinity values for companies without banking support. We need to address these cases separately: <br>
#  * Replace positive inf with maximum value in ebit_on_int
#  * Replace negative inf with minimum value in ebit_on_int

# %%
# ratio_finite = ratios[~((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
# ratios['ebit_on_int'] = ratios.ebit_on_int.replace(np.inf,ratio_finite.ebit_on_int.max())
# ratios['ebit_on_int'] = ratios.ebit_on_int.replace(-np.inf,ratio_finite.ebit_on_int.min())
# print(len(ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]))

# %% [markdown]
# #### Define support functions using for computing trends and fluctuations of certain ratios

# %%
# # Define a function to get different of values in a window
# def trend_in_window(data,window_size):
#     df = data.to_frame('values')
#     if window_size <= 0:
#         raise ValueError("Window size must be a positive integer.")
    
#     # Handle cases where the DataFrame has fewer elements than the window size
#     if len(df) < window_size:
#         return pd.Series(np.nan, index=df.index)
    
#     # Use rolling window with offset to get the difference
#     differences = df.iloc[:, 0].rolling(window=window_size, min_periods = 1).apply(lambda x: (x[-1] - x[0])/window_size, raw=True)
    
#     return differences

# %%
# # Define a function to get fluctuations of items in a window

# def fluctuation_in_window(data, window_size):

#     df = data.to_frame('values')
#     if window_size <= 0:
#         raise ValueError("Window size must be a positive integer.")
    
#     def calculate_fluctuation(x):
#         # Handle cases where the window size is larger than the available data
#         if (len(x) == 1):
#             return 0
#         else:
#             return np.std(x)
    
#     # Apply rolling window with custom function for fluctuation calculation
#     fluctuations = df.iloc[:, 0].rolling(window=window_size, min_periods=1).apply(calculate_fluctuation, raw=True)
    
#     return fluctuations

# %%
# def compute_stats(ratios):
    
#     trend_window = 3 # interval of computing gross_margin and profit_margin trends
#     fluc_window = 5 # interval of computing fluctuations of ratios
    
#     # Gross Profit Margin 3 years trending
#     trend_gross_margin = trend_in_window(ratios.gross_profit_margin,trend_window).to_frame('trend_gross_margin')
    
#     # Profit Margin 3 years trending
#     trend_profit_margin = trend_in_window(ratios.profit_margin,trend_window).to_frame('trend_profit_margin')

#     # Stde of SGA
#     fluc_sga = fluctuation_in_window(ratios.sga_ratio, fluc_window).to_frame('fluc_sga')

#     # Stde of dep_ratio
#     fluc_dep_ratio = fluctuation_in_window(ratios.dep_ratio, fluc_window).to_frame('fluc_dep_ratio')

#     # Stde of inventory_on_ebit
#     fluc_inv_on_ebit = fluctuation_in_window(ratios.inventory_on_ebit, fluc_window).to_frame('fluc_inv_on_ebit')

#     # Stde of receivable_on_revenue
#     fluc_rec_on_rev = fluctuation_in_window(ratios.receivable_on_rev, fluc_window).to_frame('fluc_rec_on_rev')

#     stats = pd.concat([trend_gross_margin,trend_profit_margin,fluc_sga,fluc_dep_ratio,fluc_inv_on_ebit,fluc_rec_on_rev], axis=1)
    
#     return stats

# %%
# add_stats = pd.DataFrame()
# for tic in ratios.tic.unique():
#     tic_ratios = ratios[ratios.tic == tic].reset_index(drop=True)
#     tic_ratios.sort_values(['date'],ascending=True,inplace=True)
#     tic_ratios = pd.concat([tic_ratios,compute_stats(tic_ratios)],axis=1)
#     add_stats = pd.concat([add_stats,tic_ratios],ignore_index=True)
# add_stats

# %%
# add_stats.to_csv('./' + DATA_SAVE_DIR + '/dow30_fund_with_filter_yearly.csv')

# %% [markdown]
# <a id='3.3'></a>
# ## 4.3 Turn the final_ratios to daily basis¶
# After our initial inspection, we’ll want to dig deeper to investigate the following:
# - The data type of each variable.
# - How discrete/categorical data is coded (and whether we need to make any changes).
# - How the data are scaled.
# - Whether there is missing data and how it is coded.
# - Whether there are outliers.
# - The distributions of continuous features.
# - The relationships between pairs of features.

# %% [markdown]
# ### Data types
# It is important to check the data type for each feature. <br>
# The **date** should be in datetime type <br>
# The **ratios** should be read in as float64 — and categorical variables should be stored as object

# %%
# ratios = pd.read_csv('./' + DATA_SAVE_DIR + '/dow30_fund_with_filter_yearly.csv',index_col=0)
# ratios['date'] = pd.to_datetime(ratios['date'],format='mixed')
# ratios

# %% [markdown]
# Remove the first year of each ticker to remove zero trends and fluctuations

# %%
# ratios = ratios[ratios.date.dt.year != 2015]

# %% [markdown]
# We see that there is no missing values from all ratios

# %% [markdown]
# ### Turn the final_ratios to daily basis

# %%
# start_date = df.iloc[0].date
# end_date = df.iloc[-1].date
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')
# date_range = pd.DataFrame(date_range)
# date_range.columns = ['date']
# date_range.head()

# %% [markdown]
# Interpolate missing data in the middle of years for each ticket

# %%
# daily_ratios = pd.DataFrame()
# for ticket in ratios.tic.unique():
#     # Interpolate data for each ticket
#     one_tic_ratios = pd.merge(date_range,ratios[ratios.tic == ticket],how="left",on=['date'])
#     one_tic_ratios['tic'] = ticket
#     one_tic_ratios.ffill(axis=0, inplace=True)
#     daily_ratios = pd.concat([daily_ratios, one_tic_ratios], ignore_index=True)

#     # Check data by drawing it out
#     %matplotlib inline
#     plt.figure(figsize=(16, 4)) 
#     plt.plot(one_tic_ratios.date, one_tic_ratios.gross_profit_margin, color = 'red')
#     plt.title(f'Gross profit margin of {ticket}')
#     plt.show()

# %%
# daily_ratios.dropna(subset='gross_profit_margin',inplace=True)
# daily_ratios.reset_index(inplace=True,drop=True)
# daily_ratios

# %% [markdown]
# <a id='3.4'></a>
# ## 4.4 Merge stock price data and ratios into one dataframe
# - Merge the price dataframe preprocessed in Part 3 and the ratio dataframe created in this part
# - Since the prices are daily and ratios are quartely, we have NAs in the ratio columns after merging the two dataframes. We deal with this by backfilling the ratios.

# %%
# daily_ratios.drop(columns=['close'],inplace=True)
# df_date = pd.DataFrame(df)[['date','tic','close']]
# df_date.columns = ['date','tic','close']
# df_date['date'] = pd.to_datetime(df_date.date)
# final_ratios = pd.merge(daily_ratios,df_date,how="left",on=['date','tic'])
# final_ratios

# %%
# final_ratios.dropna(subset=['close'],inplace=True,how='any')
# final_ratios.reset_index(drop=True,inplace=True)
# final_ratios.isna().sum()

# %%
# def compute_market_ratios(df_final):
    
#     market_equity = df_final.common_stock * df_final.close
#     market_asset = df_final.total_liabilities + market_equity

#     # ROA
#     roa = (df_final.profit / market_asset).to_frame('roa')
    
#     # ROE
#     roe = (df_final.profit / market_equity).to_frame('roe')
    
#     # Total Liabilities / Total Equity
#     liabilities_on_equity = (df_final.total_liabilities / market_equity).to_frame('liabilities_on_equity')
    
#     # EPS / MP
#     eps_on_mp = (df_final.eps / df_final.close).to_frame('eps_on_mp')
    
#     # Cash and Stock Dividend & Repurchase Common / MP
#     dividend_on_mp = (df_final.dividend / market_equity).to_frame('dividend_on_mp')
    
#     # MP / BV
#     mp_on_bv = (market_equity / df_final.bv).to_frame('mp_on_bv')
    
#     # Create a dataframe that merges all the ratios
#     ratios = pd.concat([roa,roe,liabilities_on_equity,eps_on_mp,dividend_on_mp,mp_on_bv], axis=1)
    
#     return ratios

# %%
# market_ratios = compute_market_ratios(final_ratios)

# %%
# ratios = final_ratios.drop(columns=['roa','roe','liabilities_on_equity','eps_on_mp','dividend_on_mp','mp_on_bv'])
# ratios = pd.concat([ratios,market_ratios],axis=1)

# %%
# columns = ['date', 'tic', 'close', 'profit', 'common_stock', 'total_liabilities', 'eps',
#         'dividend', 'bv', 'gross_profit_margin', 'sga_ratio', 'dep_ratio','ebit_on_int', 'profit_margin', 
#         'count_positive_profit','csti_on_liabilities', 'inventory_on_ebit', 'receivable_on_rev','roa', 'roe', 'liabilities_on_equity',
#         'debt_on_min_ebit', 'capital_cost_on_ebit','eps_on_mp', 'dividend_on_mp', 'mp_on_bv', 'trend_gross_margin',
#         'trend_profit_margin', 'fluc_sga', 'fluc_dep_ratio', 'fluc_inv_on_ebit','fluc_rec_on_rev']
# ratios = ratios[columns]
# ratios.columns

# %%
# ratios.drop(columns=['profit', 'common_stock', 'total_liabilities','eps', 'dividend', 'bv'],inplace=True)

# %%
# ratios.to_csv('./' + DATA_SAVE_DIR + '/dow30_ready_with_filter_data_daily.csv')

# %% [markdown]
# <a id='3.5'></a>
# ## 4.5 Finish data preparation

# %% [markdown]
# <a id='3.5.1'></a>
# ### 4.5.1 Load available data

# %%
# If the data is available in the data storage, load processed_full from readied data
processed_full = pd.read_csv('./' + DATA_SAVE_DIR + '/dow30_ready_daily_forGame.csv',index_col=0)
processed_full['date'] = pd.to_datetime(processed_full.date,format='mixed')
processed_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100976 entries, 0 to 100975
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   date                                   100976 non-null  datetime64[ns]
#  1   tic                                    100976 non-null  object
#  2   totalRevenue                           100976 non-null  float64
#  3   costOfRevenue                          100976 non-null  float64
#  4   sellingGeneralAndAdministrative        100976 non-null  float64
#  5   researchAndDevelopment                 100976 non-null  float64
#  6   depreciation                           100976 non-null  float64
#  7   interestExpense                        100976 non-null  float64
#  8   totalCurrentLiabilities                100976 non-null  float64
#  9   incomeTaxExpense                       100976 non-null  float64
#  10  netIncome                              100976 non-null  float64
#  11  commonStockSharesOutstanding           100976 non-null  float64
#  12  cashAndCashEquivalentsAtCarryingValue  100976 non-null  float64
#  13  cashAndShortTermInvestments            100976 non-null  float64
#  14  operatingCashflow                      100976 non-null  float64
#  15  totalLiabilities                       100976 non-null  float64
#  16  inventory                              100976 non-null  float64
#  17  currentNetReceivables                  100976 non-null  float64
#  18  propertyPlantEquipment                 100976 non-null  float64
#  19  capitalExpenditures                    100976 non-null  float64
#  20  longTermInvestments                    100976 non-null  float64
#  21  totalShareholderEquity                 100976 non-null  float64
#  22  longTermDebt                           100976 non-null  float64
#  23  retainedEarnings                       100976 non-null  float64
#  24  dividendPayoutCommonStock              100976 non-null  float64
#  25  paymentsForRepurchaseOfCommonStock     100976 non-null  float64
#  26  treasuryStock                          100976 non-null  float64
#  27  currentLongTermDebt                    100976 non-null  float64
#  28  gross_profit_margin                    100976 non-null  float64
#  29  sga_ratio                              100976 non-null  float64
#  30  dep_ratio                              100976 non-null  float64
#  31  ebit_on_int                            100976 non-null  float64
#  32  profit_margin                          100976 non-null  float64
#  33  count_positive_profit                  100976 non-null  float64
#  34  csti_on_liabilities                    100976 non-null  float64
#  35  inventory_on_ebit                      100976 non-null  float64
#  36  receivable_on_rev                      100976 non-null  float64
#  37  debt_on_min_ebit                       100976 non-null  float64
#  38  capital_cost_on_ebit                   100976 non-null  float64
#  39  trend_gross_margin                     100976 non-null  float64
#  40  trend_profit_margin                    100976 non-null  float64
#  41  fluc_sga                               100976 non-null  float64
#  42  fluc_dep_ratio                         100976 non-null  float64
#  43  fluc_inv_on_ebit                       100976 non-null  float64
#  44  fluc_rec_on_rev                        100976 non-null  float64
#  45  roa                                    100976 non-null  float64
#  46  roe                                    100976 non-null  float64
#  47  liabilities_on_equity                  100976 non-null  float64
#  48  eps_on_mp                              100976 non-null  float64
#  49  dividend_on_mp                         100976 non-null  float64
#  50  mp_on_bv                               100976 non-null  float64
#  51  open                                   100976 non-null  float64
#  52  high                                   100976 non-null  float64
#  53  low                                    100976 non-null  float64
#  54  close                                  100976 non-null  float64
#  55  volume                                 100976 non-null  float64
#  56  close_5_sma                            100976 non-null  float64
#  57  close_20_sma                           100976 non-null  float64
#  58  close_60_sma                           100976 non-null  float64
#  59  close_120_sma                          100976 non-null  float64
#  60  close_240_sma                          100976 non-null  float64
# dtypes: datetime64[ns](1), float64(59), object(1)
# memory usage: 47.8+ MB

# %%
processed_full = processed_full[processed_full.tic.isin(DOW_30_TICKER)]
processed_full.tic.unique()
# Out:
# array(['WBA', 'AAPL', 'MSFT', 'V', 'UNH', 'JNJ', 'JPM', 'WMT', 'PG', 'HD',
#        'CVX', 'MRK', 'KO', 'CSCO', 'MCD', 'CRM', 'NKE', 'DIS', 'AMGN',
#        'CAT', 'VZ', 'INTC', 'BA', 'IBM', 'HON', 'AXP', 'GS', 'MMM', 'DOW',
#        'TRV'], dtype=object)

# %%
processed_full
# Out:
#              date  tic  totalRevenue  costOfRevenue  \
# 0      2016-08-31  WBA  1.173510e+11   8.747700e+10
# 1      2016-09-01  WBA  1.173534e+11   8.748132e+10
# 2      2016-09-02  WBA  1.173557e+11   8.748563e+10
# 3      2016-09-06  WBA  1.173652e+11   8.750289e+10
# 4      2016-09-07  WBA  1.173676e+11   8.750721e+10
# ...           ...  ...           ...            ...
# 100971 2024-04-30  TRV  4.136400e+10   6.385300e+10
# 100972 2024-05-01  TRV  4.136400e+10   6.385300e+10
# 100973 2024-05-02  TRV  4.136400e+10   6.385300e+10
# 100974 2024-05-03  TRV  4.136400e+10   6.385300e+10
# 100975 2024-05-06  TRV  4.136400e+10   6.385300e+10
#
#         sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                          2.391000e+10                     0.0  1.300000e+09
# 1                          2.390973e+10                     0.0  1.300000e+09
# 2                          2.390947e+10                     0.0  1.300000e+09
# 3                          2.390841e+10                     0.0  1.300000e+09
# 4                          2.390814e+10                     0.0  1.300000e+09
# ...                                 ...                     ...           ...
# 100971                     5.176000e+09                     0.0  0.000000e+00
# 100972                     5.176000e+09                     0.0  0.000000e+00
# 100973                     5.176000e+09                     0.0  0.000000e+00
# 100974                     5.176000e+09                     0.0  0.000000e+00
# 100975                     5.176000e+09                     0.0  0.000000e+00
#
#         interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0          5.960000e+08             1.701300e+10      9.970000e+08  ...
# 1          5.962658e+08             1.701720e+10      9.963507e+08  ...
# 2          5.965315e+08             1.702141e+10      9.957014e+08  ...
# 3          5.975945e+08             1.703822e+10      9.931041e+08  ...
# 4          5.978603e+08             1.704242e+10      9.924548e+08  ...
# ...                 ...                      ...               ...  ...
# 100971     3.760000e+08             8.060000e+08      3.800000e+08  ...
# 100972     3.760000e+08             8.060000e+08      3.800000e+08  ...
# 100973     3.760000e+08             8.060000e+08      3.800000e+08  ...
# 100974     3.760000e+08             8.060000e+08      3.800000e+08  ...
# 100975     3.760000e+08             8.060000e+08      3.800000e+08  ...
#
#               open        high         low       close     volume  \
# 0        80.540001   80.830002   80.250000   60.654713  3282700.0
# 1        81.040001   81.709999   80.589996   61.278488  3296100.0
# 2        81.870003   82.250000   81.720001   61.789516  3029600.0
# 3        82.050003   82.139999   81.199997   61.353642  3726000.0
# 4        81.820000   83.059998   81.410004   62.285511  3315900.0
# ...            ...         ...         ...         ...        ...
# 100971  212.750000  213.820007  211.740005  212.160004  1385700.0
# 100972  212.160004  215.240005  212.160004  213.149994  1143900.0
# 100973  213.869995  215.070007  212.419998  214.369995  1001400.0
# 100974  213.080002  214.360001  211.190002  213.850006  1298400.0
# 100975  215.160004  216.979996  214.919998  215.910004   668600.0
#
#         close_5_sma  close_20_sma  close_60_sma  close_120_sma  close_240_sma
# 0         60.293992     61.218433     61.211967      60.677354      60.927799
# 1         60.498407     61.295525     61.242776      60.682119      60.911777
# 2         60.923769     61.372733     61.287464      60.692383      60.902620
# 3         61.117657     61.424407     61.281746      60.694175      60.889402
# 4         61.472374     61.512948     61.267995      60.696286      60.885263
# ...             ...           ...           ...            ...            ...
# 100971   213.185999    218.926500    219.719502     203.421700     184.737804
# 100972   213.129999    218.131000    219.736765     203.795488     184.885378
# 100973   213.205997    217.424500    219.775524     204.191241     185.031270
# 100974   213.285999    216.572500    219.785541     204.582413     185.173446
# 100975   213.888000    215.838500    219.836693     204.979448     185.334884
#
# [100976 rows x 61 columns]

# %%
# print(processed_full.describe())

# %%
# columns = ['date', 'tic', 'close', 'gross_profit_margin', 'sga_ratio', 'ebit_on_int', 'profit_margin', 'count_positive_profit',
#        'csti_on_liabilities', 'roa', 'roe', 'liabilities_on_equity', 'debt_on_min_ebit',
#        'capital_cost_on_ebit', 'eps_on_mp', 'dividend_on_mp', 'mp_on_bv',
#        'trend_gross_margin', 'trend_profit_margin', 'fluc_sga', 'fluc_dep_ratio', 'fluc_inv_on_ebit', 'fluc_rec_on_rev']
# processed_full = processed_full[columns]

# %% [markdown]
# Calculate price-relevant features

# %%
# processed_full.columns

# %%
processed_full['weekly_advance'] = processed_full.close - processed_full.close_5_sma
processed_full['monthly_advance'] = processed_full.close - processed_full.close_20_sma
processed_full['quaterly_advance'] = processed_full.close - processed_full.close_60_sma
processed_full['semiyearly_advance'] = processed_full.close - processed_full.close_120_sma
processed_full['yearly_advance'] = processed_full.close - processed_full.close_240_sma

# %% [markdown]
# <a id='3.5.2'></a>
# ### 4.5.2 Finished data

# %% [markdown]
# Reset **TRAIN_START_DATE** and **TEST_END_DATE**

# %%
TRAIN_START_DATE = processed_full.date.min().strftime("%Y-%m-%d")
TEST_END_DATE = processed_full.date.max().strftime("%Y-%m-%d")
print('TRAIN_START_DATE: ',TRAIN_START_DATE,'\n')
print('TRAIN_END_DATE: ',TRAIN_END_DATE,'\n')
print('TEST_START_DATE: ',TEST_START_DATE,'\n')
print('TEST_END_DATE: ',TEST_END_DATE,'\n')
# Out:
# TRAIN_START_DATE:  2009-09-30
#
# TRAIN_END_DATE:  2021-01-01
#
# TEST_START_DATE:  2021-01-01
#
# TEST_END_DATE:  2024-05-06

# %% [markdown]
# ### 4.5.3 Select only on ticker

# %%
selected_tic = 'AAPL'
selected_df = processed_full[processed_full.tic == selected_tic].reset_index(drop=True)
selected_df
# Out:
#            date   tic  totalRevenue  costOfRevenue  \
# 0    2009-09-30  AAPL  4.290500e+10   2.983200e+10
# 1    2009-10-01  AAPL  4.296615e+10   2.987595e+10
# 2    2009-10-02  AAPL  4.302730e+10   2.991990e+10
# 3    2009-10-05  AAPL  4.321075e+10   3.005174e+10
# 4    2009-10-06  AAPL  4.327190e+10   3.009569e+10
# ...         ...   ...           ...            ...
# 3669 2024-04-30  AAPL  3.793520e+11   2.390690e+11
# 3670 2024-05-01  AAPL  3.793520e+11   2.390690e+11
# 3671 2024-05-02  AAPL  3.793520e+11   2.390690e+11
# 3672 2024-05-03  AAPL  3.793520e+11   2.390690e+11
# 3673 2024-05-06  AAPL  3.793520e+11   2.390690e+11
#
#       sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                        4.149000e+09            1.333000e+09  0.000000e+00
# 1                        4.152748e+09            1.334230e+09  0.000000e+00
# 2                        4.156496e+09            1.335460e+09  0.000000e+00
# 3                        4.167740e+09            1.339151e+09  0.000000e+00
# 4                        4.171488e+09            1.340381e+09  0.000000e+00
# ...                               ...                     ...           ...
# 3669                     2.493200e+10            2.991500e+10  8.500000e+09
# 3670                     2.493200e+10            2.991500e+10  8.500000e+09
# 3671                     2.493200e+10            2.991500e+10  8.500000e+09
# 3672                     2.493200e+10            2.991500e+10  8.500000e+09
# 3673                     2.493200e+10            2.991500e+10  8.500000e+09
#
#       interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0        3.260000e+08             1.150600e+10      3.831000e+09  ...
# 1        3.255315e+08             1.153125e+10      3.832907e+09  ...
# 2        3.250630e+08             1.155650e+10      3.834814e+09  ...
# 3        3.236575e+08             1.163225e+10      3.840534e+09  ...
# 4        3.231890e+08             1.165750e+10      3.842441e+09  ...
# ...               ...                      ...               ...  ...
# 3669     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 3670     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 3671     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 3672     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 3673     3.933000e+09             1.453080e+11      1.674100e+10  ...
#
#       close_5_sma  close_20_sma  close_60_sma  close_120_sma  close_240_sma  \
# 0        5.581933      5.394381      5.015875       4.499253       3.686776
# 1        5.564033      5.418085      5.037866       4.514532       3.697290
# 2        5.579332      5.445827      5.062327       4.531310       3.708182
# 3        5.578547      5.469577      5.086264       4.548540       3.720092
# 4        5.606545      5.495398      5.110286       4.565814       3.731825
# ...           ...           ...           ...            ...            ...
# 3669   170.408002    169.621500    175.117803     182.408039     181.395000
# 3670   170.464001    169.604000    174.815456     182.307627     181.383705
# 3671   171.092001    169.814500    174.548310     182.229406     181.378158
# 3672   173.908002    170.504500    174.451833     182.241424     181.415278
# 3673   175.550003    171.167500    174.345667     182.204320     181.449425
#
#       weekly_advance  monthly_advance  quaterly_advance  semiyearly_advance  \
# 0           0.022254         0.209806          0.588312            1.104934
# 1          -0.095604         0.050344          0.430563            0.953897
# 2           0.011247         0.144752          0.528252            1.059269
# 3           0.045897         0.154867          0.538180            1.075905
# 4           0.138540         0.249687          0.634799            1.179271
# ...              ...              ...               ...                 ...
# 3669       -0.078000         0.708502         -4.787801          -12.078037
# 3670       -1.163998        -0.303997         -5.515453          -13.007624
# 3671        1.937997         3.215499         -1.518312           -9.199407
# 3672        9.472003        12.875505          8.928172            1.138581
# 3673        6.160004        10.542506          7.364340           -0.494313
#
#       yearly_advance
# 0           1.917411
# 1           1.771139
# 2           1.882397
# 3           1.904352
# 4           2.013259
# ...              ...
# 3669      -11.064998
# 3670      -12.083702
# 3671       -8.348159
# 3672        1.964726
# 3673        0.260581
#
# [3674 rows x 66 columns]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.

# %% [markdown]
# <a id='4.1'></a>
# ## 5.1 Training & Trade Data Split
# - Training data period: 2009-01-01 to 2020-01-01
# - Trade data period: 2020-01-01 to 2023-12-29

# %%
train_data = data_split(selected_df, TRAIN_START_DATE, TRAIN_END_DATE)
test_data = data_split(selected_df, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(test_data))
# Out:
# 2834
# 839

# %%
train_data = train_data.reset_index(drop=True)
train_data
# Out:
#            date   tic  totalRevenue  costOfRevenue  \
# 0    2009-09-30  AAPL  4.290500e+10   2.983200e+10
# 1    2009-10-01  AAPL  4.296615e+10   2.987595e+10
# 2    2009-10-02  AAPL  4.302730e+10   2.991990e+10
# 3    2009-10-05  AAPL  4.321075e+10   3.005174e+10
# 4    2009-10-06  AAPL  4.327190e+10   3.009569e+10
# ...         ...   ...           ...            ...
# 2829 2020-12-24  AAPL  2.929572e+11   2.000660e+11
# 2830 2020-12-28  AAPL  2.939603e+11   2.005644e+11
# 2831 2020-12-29  AAPL  2.942110e+11   2.006890e+11
# 2832 2020-12-30  AAPL  2.944618e+11   2.008136e+11
# 2833 2020-12-31  AAPL  2.947126e+11   2.009382e+11
#
#       sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                        4.149000e+09            1.333000e+09  0.000000e+00
# 1                        4.152748e+09            1.334230e+09  0.000000e+00
# 2                        4.156496e+09            1.335460e+09  0.000000e+00
# 3                        4.167740e+09            1.339151e+09  0.000000e+00
# 4                        4.171488e+09            1.340381e+09  0.000000e+00
# ...                               ...                     ...           ...
# 2829                     2.039503e+10            1.948836e+10  9.653425e+09
# 2830                     2.041757e+10            1.952301e+10  9.651233e+09
# 2831                     2.042321e+10            1.953167e+10  9.650685e+09
# 2832                     2.042884e+10            1.954033e+10  9.650137e+09
# 2833                     2.043448e+10            1.954900e+10  9.649589e+09
#
#       interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0        3.260000e+08             1.150600e+10      3.831000e+09  ...
# 1        3.255315e+08             1.153125e+10      3.832907e+09  ...
# 2        3.250630e+08             1.155650e+10      3.834814e+09  ...
# 3        3.236575e+08             1.163225e+10      3.840534e+09  ...
# 4        3.231890e+08             1.165750e+10      3.842441e+09  ...
# ...               ...                      ...               ...  ...
# 2829     2.819904e+09             1.100703e+11      1.080875e+10  ...
# 2830     2.817405e+09             1.102904e+11      1.086187e+10  ...
# 2831     2.816781e+09             1.103455e+11      1.087515e+10  ...
# 2832     2.816156e+09             1.104005e+11      1.088843e+10  ...
# 2833     2.815532e+09             1.104555e+11      1.090171e+10  ...
#
#       close_5_sma  close_20_sma  close_60_sma  close_120_sma  close_240_sma  \
# 0        5.581933      5.394381      5.015875       4.499253       3.686776
# 1        5.564033      5.418085      5.037866       4.514532       3.697290
# 2        5.579332      5.445827      5.062327       4.531310       3.708182
# 3        5.578547      5.469577      5.086264       4.548540       3.720092
# 4        5.606545      5.495398      5.110286       4.565814       3.731825
# ...           ...           ...           ...            ...            ...
# 2829   127.522240    122.578958    117.028503     112.485891      93.341967
# 2830   129.490912    123.565258    117.357288     112.826786      93.585358
# 2831   130.794205    124.341540    117.717862     113.149456      93.817355
# 2832   131.155356    124.881305    118.002804     113.461355      94.041111
# 2833   131.494913    125.352863    118.325435     113.768437      94.262845
#
#       weekly_advance  monthly_advance  quaterly_advance  semiyearly_advance  \
# 0           0.022254         0.209806          0.588312            1.104934
# 1          -0.095604         0.050344          0.430563            0.953897
# 2           0.011247         0.144752          0.528252            1.059269
# 3           0.045897         0.154867          0.538180            1.075905
# 4           0.138540         0.249687          0.634799            1.179271
# ...              ...              ...               ...                 ...
# 2829        1.992241         6.935522         12.485978           17.028590
# 2830        4.655725        10.581379         16.789349           21.319851
# 2831        1.566299         8.018964         14.642642           19.211049
# 2832        0.076547         6.350598         13.229099           17.770548
# 2833       -1.273874         4.868176         11.895604           16.452602
#
#       yearly_advance
# 0           1.917411
# 1           1.771139
# 2           1.882397
# 3           1.904352
# 4           2.013259
# ...              ...
# 2829       36.172514
# 2830       40.561279
# 2831       38.543150
# 2832       37.190792
# 2833       35.958194
#
# [2834 rows x 66 columns]

# %% [markdown]
# Adjust train_data to ensure the trajectory's length equals n_steps

# %%
for tic in train_data.tic.unique():
    print(f'{tic}:{len(train_data[train_data.tic == tic])}')
# Out:
# AAPL:2834

# %%
qualified_tics = ['AAPL', 'V', 'AMGN', 'AXP', 'BA', 'CAT', 'CVX', 'GS', 'HON', 'IBM',
       'INTC', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'TRV', 'UNH', 'VZ',
       'CRM', 'HD', 'WMT', 'NKE', 'MSFT', 'PG', 'CSCO', 'JNJ']
train_data = train_data[train_data.tic.isin(qualified_tics)]

# %%
n_steps = 2048
train_data_by_length = train_data.groupby('tic').tail(n_steps)
train_data_by_length.reset_index(inplace=True,drop=True)

# %%
for tic in train_data_by_length.tic.unique():
    print(f'{tic}:{len(train_data_by_length[train_data_by_length.tic == tic])}')
# Out:
# AAPL:2048

# %%
train_data = train_data_by_length

# %% [markdown]
# Because the predictions employ only the state, the model accepts any dataset as long as it provide appropriate input format

# %%
test_data = test_data.reset_index(drop=True)
test_data
# Out:
#           date   tic  totalRevenue  costOfRevenue  \
# 0   2021-01-04  AAPL  2.957156e+11   2.014366e+11
# 1   2021-01-05  AAPL  2.959664e+11   2.015612e+11
# 2   2021-01-06  AAPL  2.962172e+11   2.016858e+11
# 3   2021-01-07  AAPL  2.964679e+11   2.018104e+11
# 4   2021-01-08  AAPL  2.967187e+11   2.019350e+11
# ..         ...   ...           ...            ...
# 834 2024-04-29  AAPL  3.793520e+11   2.390690e+11
# 835 2024-04-30  AAPL  3.793520e+11   2.390690e+11
# 836 2024-05-01  AAPL  3.793520e+11   2.390690e+11
# 837 2024-05-02  AAPL  3.793520e+11   2.390690e+11
# 838 2024-05-03  AAPL  3.793520e+11   2.390690e+11
#
#      sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                       2.045702e+10            1.958365e+10  9.647397e+09
# 1                       2.046265e+10            1.959231e+10  9.646849e+09
# 2                       2.046829e+10            1.960098e+10  9.646301e+09
# 3                       2.047393e+10            1.960964e+10  9.645753e+09
# 4                       2.047956e+10            1.961830e+10  9.645205e+09
# ..                               ...                     ...           ...
# 834                     2.493200e+10            2.991500e+10  8.500000e+09
# 835                     2.493200e+10            2.991500e+10  8.500000e+09
# 836                     2.493200e+10            2.991500e+10  8.500000e+09
# 837                     2.493200e+10            2.991500e+10  8.500000e+09
# 838                     2.493200e+10            2.991500e+10  8.500000e+09
#
#      interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0       2.813033e+09             1.106757e+11      1.095483e+10  ...
# 1       2.812408e+09             1.107307e+11      1.096811e+10  ...
# 2       2.811784e+09             1.107858e+11      1.098139e+10  ...
# 3       2.811159e+09             1.108408e+11      1.099467e+10  ...
# 4       2.810534e+09             1.108958e+11      1.100795e+10  ...
# ..               ...                      ...               ...  ...
# 834     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 835     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 836     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 837     3.933000e+09             1.453080e+11      1.674100e+10  ...
# 838     3.933000e+09             1.453080e+11      1.674100e+10  ...
#
#      close_5_sma  close_20_sma  close_60_sma  close_120_sma  close_240_sma  \
# 0     130.992439    125.670345    118.563066     114.035818      94.470021
# 1     129.877577    126.100195    118.828664     114.310844      94.682190
# 2     128.254355    126.240044    118.989473     114.559604      94.877257
# 3     127.704776    126.560960    119.099622     114.845283      95.099477
# 4     127.579163    127.064906    119.282138     115.123660      95.317459
# ..           ...           ...           ...            ...            ...
# 834   169.722000    169.546999    175.372522     182.478339     181.399430
# 835   170.408002    169.621500    175.117803     182.408039     181.395000
# 836   170.464001    169.604000    174.815456     182.307627     181.383705
# 837   171.092001    169.814500    174.548310     182.229406     181.378158
# 838   173.908002    170.504500    174.451833     182.241424     181.415278
#
#      weekly_advance  monthly_advance  quaterly_advance  semiyearly_advance  \
# 0         -3.990326         1.331769          8.439047           12.966296
# 1         -1.305251         2.472131          9.743663           14.261483
# 2         -4.009962        -1.995652          5.254919            9.684789
# 3          0.779233         1.923048          9.384386           13.638726
# 4          2.013809         2.528066         10.310834           14.469311
# ..              ...              ...               ...                 ...
# 834        3.778000         3.953001         -1.872522           -8.978339
# 835       -0.078000         0.708502         -4.787801          -12.078037
# 836       -1.163998        -0.303997         -5.515453          -13.007624
# 837        1.937997         3.215499         -1.518312           -9.199407
# 838        9.472003        12.875505          8.928172            1.138581
#
#      yearly_advance
# 0         32.532092
# 1         33.890137
# 2         29.367135
# 3         33.384532
# 4         34.275513
# ..              ...
# 834       -7.899430
# 835      -11.064998
# 836      -12.083702
# 837       -8.348159
# 838        1.964726
#
# [839 rows x 66 columns]

# %% [markdown]
# <a id='4.2'></a>
# ## 5.2 Initialize Environment

# %% [markdown]
# State's space include remain_capital, price, stock_amount, current_return, and the indicators decided in ratio_list

# %%
features = ['close','close_5_sma','close_20_sma','close_60_sma','close_120_sma','close_240_sma',
            'gross_profit_margin', 'sga_ratio', 'ebit_on_int', 'profit_margin', 'count_positive_profit',
       'csti_on_liabilities', 'roa', 'roe', 'liabilities_on_equity', 'debt_on_min_ebit',
       'capital_cost_on_ebit', 'eps_on_mp', 'dividend_on_mp', 'mp_on_bv',
       'trend_gross_margin', 'trend_profit_margin', 'fluc_sga', 'fluc_dep_ratio', 'fluc_inv_on_ebit', 'fluc_rec_on_rev']
# ratio_list = train_data.columns.drop(['date','tic','close'])

action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
state_space = 4 + len(features)
print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 30

# %% [markdown]
# #### Initiate environment

# %%
from trading_environment_end_reward import StockTradingEnv

# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "tech_indicator_list": features, 
    "state_space": state_space, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.8,
    "print_verbosity":4,
    "hold_period": 5
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %%
from stable_baselines3.common.env_checker import check_env

# If the environment don't follow the interface, an error will be thrown
check_env(e_train_gym, warn=True)

# %%
from stable_baselines3 import PPO, A2C, DQN, DDPG

# Instantiate the env
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='8.1'></a>
# #### If the training starts from the previous model, the section should **run all cells above** this line and then jump to [**Load trained model**](#7.2.1) to keep the traning going on.

# %% [markdown]
# #### Test Environment

# %%
# Get samples from train_data
test_env_data = train_data

#Establish the training environment using StockTradingEnv() class
test_train_gym = StockTradingEnv(df = test_env_data, **env_kwargs)

# test reset state
print(test_train_gym.reset())
# Out:
# (array([1.0000000e+06, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.6560732e+01, 1.6646387e+01, 1.8107763e+01, 1.9574476e+01,
#        1.8756325e+01, 1.7060223e+01, 3.4835634e-01, 1.8507423e-01,
#        3.0824771e+03, 1.9610113e-01, 1.0000000e+00, 5.0136679e-01,
#        4.0473822e-01, 1.9986641e+00, 3.9381649e+00, 5.5696119e-02,
#        1.8546383e-01, 1.9964892e+00, 4.0178493e-01, 2.0384263e-01,
#        1.6291354e-02, 1.7274035e-02, 5.3518008e-02, 0.0000000e+00,
#        2.2196550e-02, 1.3035445e-02], dtype=float32), {})

# %%
for i in range(0,100):
    action = test_train_gym.action_space.sample()
    # print(test_train_gym.data)
    state,reward,terminal,truncated,info = test_train_gym.step(action)
    
    print(f'Step {test_train_gym.row}, action: {action[0]}, reward: {test_train_gym.reward}, Trade: {test_train_gym.trades}')
    # print(f'{test_train_gym.punishment_rate}')
    print(f'Price: {test_train_gym.data.close},State:{test_train_gym.state[:4]}')
    print(f'{test_train_gym.portfolio.portfolio}\n')
    
    if terminal:
        test_train_gym.reset()
# Out:
# Step 1, action: -0.8677321076393127, reward: 0, Trade: 0
# Price: 16.377098083496094,State:[1000000.0, 0, 0, 0]
#    tic      price  buy_price  amount  weight  hold_on
# 0  cap  1000000.0  1000000.0       1     1.0        0
#
# Step 2, action: -0.6041383743286133, reward: 0, Trade: 0
# Price: 16.033615112304688,State:[1000000.0, 0, 0, 0]
#    tic      price  buy_price  amount  weight  hold_on
# 0  cap  1000000.0  1000000.0       1     1.0        0
#
# Step 3, action: -0.717217743396759, reward: 0, Trade: 0
# Price: 16.096454620361328,State:[1000000.0, 0, 0, 0]
#    tic      price  buy_price  amount  weight  hold_on
# 0  cap  1000000.0  1000000.0       1     1.0        0
#
# Step 4, action: 0.04100553318858147, reward: 0.0721085631799685, Trade: 0
# Price: 17.25714683532715,State:[958945.2198609466, 0, 0, 1.0721085631799685]
#     tic          price       buy_price  amount    weight  hold_on
# 0   cap  958945.219861  1000000.000000       1  0.956157        0
# 1  AAPL      17.257147       16.096455    2548  0.043843        4
#
# Step 5, action: -0.29465481638908386, reward: 0.06297414274233826, Trade: 0
# Price: 17.11011505126953,State:[958945.2198609466, 0, 0, 1.0629741427423383]
#     tic          price       buy_price  amount    weight  hold_on
# 0   cap  958945.219861  1000000.000000       1  0.956514        0
# 1  AAPL      17.110115       16.096455    2548  0.043486        3
#
# Step 6, action: -0.6037880778312683, reward: 0.06447120797783867, Trade: 0
# Price: 17.134212493896484,State:[958945.2198609466, 0, 0, 1.0644712079778387]
#     tic          price       buy_price  amount    weight  hold_on
# 0   cap  958945.219861  1000000.000000       1  0.956455        0
# 1  AAPL      17.134212       16.096455    2548  0.043545        2
#
# Step 7, action: -0.05714551731944084, reward: 0.08304304044777822, Trade: 0
# Price: 17.43315315246582,State:[958945.2198609466, 0, 0, 1.0830430404477782]
#     tic          price       buy_price  amount    weight  hold_on
# 0   cap  958945.219861  1000000.000000       1  0.955729        0
# 1  AAPL      17.433153       16.096455    2548  0.044271        1
#
# Step 8, action: -0.7991929054260254, reward: 0.11721094163436296, Trade: 0
# Price: 17.983135223388672,State:[958945.2198609466, 2548, 0.04560367012894565, 1.117210941634363]
#     tic          price       buy_price  amount    weight  hold_on
# 0   cap
#      tic      price       buy_price  amount    weight  hold_on
# 0    cap   2.273865  1000000.000000       1  0.000003        0
# 1   AAPL  13.076970       13.142627     828  0.014116        0
# 2   AAPL  13.076970       13.269960     952  0.016230        0
# 3   AAPL  13.076970       13.890656   13088  0.223123        0
# 4   AAPL  13.076970       14.223555   27318  0.465715        0
# 5   AAPL  13.076970       14.148688    5946  0.101367        0
# 6   AAPL  13.076970       13.581687    3986  0.067953        0
# 7   AAPL  13.076970       13.159808    5064  0.086331        0
# 8   AAPL  13.076970       13.186810     684  0.011661        1
# 9   AAPL  13.076970       13.254311     677  0.011541        2
# 10  AAPL  13.076970       13.123298     115  0.001961        3
#
# Step 99, action: -0.0534491129219532, reward: -0.06257603129811318, Trade: 42
# Price: 13.10059642791748,State:[39938.59516456128, 54809, 0.9345160352580589, 0.9374239687018868]
#     tic         price       buy_price  amount    weight  hold_on
# 0   cap  39938.595165  1000000.000000       1  0.051980        0
# 1  AAPL     13.100596       13.890656   11811  0.201382        0
# 2  AAPL     13.100596       14.223555   27318  0.465783        0
# 3  AAPL     13.100596       14.148688    5946  0.101382        0
# 4  AAPL     13.100596       13.581687    3986  0.067963        0
# 5  AAPL     13.100596       13.159808    5064  0.086343        0
# 6  AAPL     13.100596       13.186810     684  0.011662        0
# 7  AAPL     13.100596       13.254311     677  0.011543        1
# 8  AAPL     13.100596       13.123298     115  0.001961        2
#
# Step 100, action: 0.291747123003006, reward: -0.042509661109444874, Trade: 42
# Price: 13.367834091186523,State:[28267.404812893874, 55486, 0.9467698544163593, 0.9574903388905551]
#     tic         price       buy_price  amount    weight  hold_on
# 0   cap  28267.404813  1000000.000000       1  0.036082        0
# 1  AAPL     13.367834       13.890656   11811  0.201534        0
# 2  AAPL     13.367834       14.223555   27318  0.466133        0
# 3  AAPL     13.367834       14.148688    5946  0.101458        0
# 4  AAPL     13.367834       13.581687    3986  0.068014        0
# 5  AAPL     13.367834       13.159808    5064  0.086408        0
# 6  AAPL     13.367834       13.186810     684  0.011671        0
# 7  AAPL     13.367834       13.254311     677  0.011552        0
# 8  AAPL     13.367834       13.123298     115  0.001962        1
# 9  AAPL     13.367834       13.100596     890  0.015186        4

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# Define callback function for the training

# %%
from stable_baselines3.common.callbacks import BaseCallback

class TensorboardCallback(BaseCallback):
    """
    Custom callback for plotting additional values in tensorboard.
    """

    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self) -> bool:
        try:
            self.logger.record(key="train/reward", value=self.locals["rewards"][0])

        except BaseException as error:
            try:
                self.logger.record(key="train/reward", value=self.locals["reward"][0])

            except BaseException as inner_error:
                # Handle the case where neither "rewards" nor "reward" is found
                self.logger.record(key="train/reward", value=None)
                # Print the original error and the inner error for debugging
                print("Original Error:", error)
                print("Inner Error:", inner_error)
        return True

# %% [markdown]
# ### Model 1: PPO

# %%
policy_kwargs = dict(net_arch=dict(pi=[256,128,64], vf=[256,128,64]))
# policy_kwargs = dict(net_arch=dict(pi=[64,64,64], vf=[64,64,64]))
total_training_step = 2000000
device = "cuda" # in case the GPU is available in the training device

# %%
try:
  trained_model
except NameError:
    print('No any model')
else:
    print('Ready for keeping training')
# Out:
# Ready for keeping training

# %%
try:
  trained_model
except NameError:
    trained_ppo = PPO("MlpPolicy", env_train,n_steps=n_steps,ent_coef=0.01,learning_rate=0.0002,batch_size=256,clip_range=0.1,
                      policy_kwargs=policy_kwargs,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo",verbose=1,device=device)
    trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
else:
    trained_model.env = env_train
    trained_ppo = trained_model.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
# Out:
# Logging to tensorboard_log/test_ppo/ppo_115
# Episode: 5, com: AAPL, win trade: 150/254, Total profit: 3004161.0554930796 ,Surplus from buy-hold: -3859080.7203220488
# -----------------------------------
# | time/              |            |
# |    fps             | 168        |
# |    iterations      | 1          |
# |    time_elapsed    | 12         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -385.90808 |
# -----------------------------------
# Episode: 6, com: AAPL, win trade: 151/241, Total profit: 2245991.928246758 ,Surplus from buy-hold: -4617249.84756837
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 2             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 9.2425034e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.422         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 87.9          |
# |    n_updates            | 125500        |
# |    policy_gradient_loss | -2.73e-05     |
# |    reward               | -461.72498    |
# |    std                  | 755           |
# |    value_loss           | 521           |
# -------------------------------------------
# Episode: 7, com: AAPL, win trade: 139/247, Total profit: 586025.7265826745 ,Surplus from buy-hold: -6277216.049232454
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 175           |
# |    iterations           | 3             |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 3.7660357e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.591         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 156           |
# |    n_updates            | 125510        |
# |    policy_gradient_loss | 2.59e-05      |
# |    reward               | -627.7216     |
# |    std                  | 755           |
# |    value_loss           | 495           |
# -------------------------------------------
# Episode: 8, com: AAPL, win trade: 155/252, Total profit: 1438264.0384159656 ,Surplus from buy-hold: -5424977.737399163
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 2438264.04
# total profit: 1438264.04
# surplus from buy-and-hold: -5424977.74
# total_cost: 702499.97
# total_trades: 252
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 175          |
# |    iterations           | 4            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 4.955218e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 125520       |
# |    policy_gradient_loss | -2.64e-06    |
# |    reward               | -542.4978    |
# |    std                  | 754          |
# |    value_loss           | 1.36e+03     |
# ------------------------------------------
# Episode: 9, com: AAPL, win trade: 143/250, Total profit: 906353.3017999995 ,Surplus from buy-hold: -5956888.474015129
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 5            |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 2.008368e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.389        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 209          |
# |    n_updates            | 125530       |
# |    policy_gradient_loss | -2.09e-05    |
# |    reward               | -595.68884   |
# |    std                  | 756          |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# Episode: 10, com: AAPL, win trade: 147/242, Total profit: 4786174.045982274 ,Surplus from buy-hold: -2077067.7298328541
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 157           |
# |    iterations           | 6             |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 2.8006616e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.528         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 674           |
# |    n_updates            | 125540        |
# |    policy_gradient_loss | -5.77e-06     |
# |    reward               | -207.70677    |
# |    std                  | 755           |
# |    value_loss           | 1.12e+03      |
# -------------------------------------------
# Episode: 11, com: AAPL, win trade: 147/239, Total profit: 1525637.718932007 ,Surplus from buy-hold: -5337604.056883121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 7            |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 5.689799e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 67.5         |
# |    n_updates            | 125550       |
# |    policy_gradient_loss | -1.33e-05    |
# |    reward               | -533.7604    |
# |    std                  | 756          |
# |    value_loss           | 211          |
# ------------------------------------------
# Episode: 12, com: AAPL, win trade: 152/250, Total profit: 1478784.9460380725 ,Surplus from buy-hold: -5384456.829777056
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 2478784.95
# total profit: 1478784.95
# surplus from buy-and-hold: -5384456.83
# total_cost: 666999.19
# total_trades: 250
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 8            |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 7.341732e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 574          |
# |    n_updates            | 125560       |
# |    policy_gradient_loss | -1.76e-06    |
# |    reward               | -538.4457    |
# |    std                  | 755          |
# |    value_loss           | 935          |
# ------------------------------------------
# Episode: 13, com: AAPL, win trade: 153/245, Total profit: 1002669.9178328866 ,Surplus from buy-hold: -5860571.857982242
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 9             |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 2.4818873e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.441         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 105           |
# |    n_updates            | 125570        |
# |    policy_gradient_loss | -1.71e-05     |
# |    reward               | -586.0572     |
# |    std                  | 756           |
# |    value_loss           | 732           |
# -------------------------------------------
# Episode: 14, com: AAPL, win trade: 150/254, Total profit: 1614677.9978666264 ,Surplus from buy-hold: -5248563.777948502
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 10           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 2.089946e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 264          |
# |    n_updates            | 125580       |
# |    policy_gradient_loss | -3.19e-06    |
# |    reward               | -524.8564    |
# |    std                  | 756          |
# |    value_loss           | 859          |
# ------------------------------------------
# Episode: 15, com: AAPL, win trade: 155/248, Total profit: 6208582.648533375 ,Surplus from buy-hold: -654659.1272817533
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 11            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.0302756e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.598         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 1.22e+03      |
# |    n_updates            | 125590        |
# |    policy_gradient_loss | -4.99e-07     |
# |    reward               | -65.46591     |
# |    std                  | 756           |
# |    value_loss           | 725           |
# -------------------------------------------
# Episode: 16, com: AAPL, win trade: 156/252, Total profit: 4203322.299366466 ,Surplus from buy-hold: -2659919.4764486626
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 5203322.30
# total profit: 4203322.30
# surplus from buy-and-hold: -2659919.48
# total_cost: 838919.27
# total_trades: 252
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 12           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 3.837631e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | -0.203       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 37.5         |
# |    n_updates            | 125600       |
# |    policy_gradient_loss | -1.69e-05    |
# |    reward               | -265.99194   |
# |    std                  | 757          |
# |    value_loss           | 118          |
# ------------------------------------------
# Episode: 17, com: AAPL, win trade: 137/251, Total profit: 653034.2358567154 ,Surplus from buy-hold: -6210207.539958413
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 155            |
# |    iterations           | 13             |
# |    time_elapsed         | 171            |
# |    total_timesteps      | 26624          |
# | train/                  |                |
# |    approx_kl            | 1.16427545e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -8.05          |
# |    explained_variance   | 0.365          |
# |    learning_rate        | 0.0002         |
# |    loss                 | 123            |
# |    n_updates            | 125610         |
# |    policy_gradient_loss | -6.67e-05      |
# |    reward               | -621.02075     |
# |    std                  | 754            |
# |    value_loss           | 216            |
# --------------------------------------------
# Episode: 18, com: AAPL, win trade: 151/252, Total profit: 847745.819650009 ,Surplus from buy-hold: -6015495.956165119
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 154           |
# |    iterations           | 14            |
# |    time_elapsed         | 185           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.9045547e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.378         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 966           |
# |    n_updates            | 125620        |
# |    policy_gradient_loss | 1.63e-06      |
# |    reward               | -601.5496     |
# |    std                  | 755           |
# |    value_loss           | 1.11e+03      |
# -------------------------------------------
# Episode: 19, com: AAPL, win trade: 144/240, Total profit: 1360869.6584877712 ,Surplus from buy-hold: -5502372.117327357
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 15            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 3.5506673e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.504         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 221           |
# |    n_updates            | 125630        |
# |    policy_gradient_loss | 1.06e-06      |
# |    reward               | -550.2372     |
# |    std                  | 755           |
# |    value_loss           | 1.02e+03      |
# -------------------------------------------
# Episode: 20, com: AAPL, win trade: 144/240, Total profit: 1681583.070827513 ,Surplus from buy-hold: -5181658.704987615
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 2681583.07
# total profit: 1681583.07
# surplus from buy-and-hold: -5181658.70
# total_cost: 527288.72
# total_trades: 240
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 16            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.9240542e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.583         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 242           |
# |    n_updates            | 125640        |
# |    policy_gradient_loss | -1.92e-05     |
# |    reward               | -518.1659     |
# |    std                  | 756           |
# |    value_loss           | 737           |
# -------------------------------------------
# Episode: 21, com: AAPL, win trade: 152/248, Total profit: 3722263.481136854 ,Surplus from buy-hold: -3140978.2946782745
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 17           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 1.915032e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 144          |
# |    n_updates            | 125650       |
# |    policy_gradient_loss | 1.78e-07     |
# |    reward               | -314.09784   |
# |    std                  | 756          |
# |    value_loss           | 727          |
# ------------------------------------------
# Episode: 22, com: AAPL, win trade: 145/240, Total profit: 1407931.6750159035 ,Surplus from buy-hold: -5455310.100799225
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 18            |
# |    time_elapsed         | 236           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 3.5273843e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.651         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 186           |
# |    n_updates            | 125660        |
# |    policy_gradient_loss | 8.99e-07      |
# |    reward               | -545.531      |
# |    std                  | 756           |
# |    value_loss           | 383           |
# -------------------------------------------
# Episode: 23, com: AAPL, win trade: 149/244, Total profit: 3995861.9941545725 ,Surplus from buy-hold: -2867379.781660556
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 19            |
# |    time_elapsed         | 248           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 1.1883094e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.612         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 216           |
# |    n_updates            | 125670        |
# |    policy_gradient_loss | 3.51e-06      |
# |    reward               | -286.73798    |
# |    std                  | 756           |
# |    value_loss           | 755           |
# -------------------------------------------
# Episode: 24, com: AAPL, win trade: 144/247, Total profit: 337997.9728893982 ,Surplus from buy-hold: -6525243.80292573
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 1337997.97
# total profit: 337997.97
# surplus from buy-and-hold: -6525243.80
# total_cost: 508890.59
# total_trades: 247
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 20            |
# |    time_elapsed         | 261           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 5.6403223e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.441         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 150           |
# |    n_updates            | 125680        |
# |    policy_gradient_loss | -2.07e-07     |
# |    reward               | -652.52435    |
# |    std                  | 757           |
# |    value_loss           | 345           |
# -------------------------------------------
# Episode: 25, com: AAPL, win trade: 131/240, Total profit: 622459.7115509175 ,Surplus from buy-hold: -6240782.064264211
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 21           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 3.334717e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 352          |
# |    n_updates            | 125690       |
# |    policy_gradient_loss | 9.96e-06     |
# |    reward               | -624.0782    |
# |    std                  | 757          |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# Episode: 26, com: AAPL, win trade: 143/243, Total profit: 3094608.2538099806 ,Surplus from buy-hold: -3768633.5220051478
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 22          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 7.67177e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -8.05       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 183         |
# |    n_updates            | 125700      |
# |    policy_gradient_loss | -8.02e-07   |
# |    reward               | -376.86334  |
# |    std                  | 758         |
# |    value_loss           | 939         |
# -----------------------------------------
# Episode: 27, com: AAPL, win trade: 156/241, Total profit: 3243688.383659838 ,Surplus from buy-hold: -3619553.3921552906
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 23            |
# |    time_elapsed         | 300           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 9.6071744e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.173         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 449           |
# |    n_updates            | 125710        |
# |    policy_gradient_loss | 6.79e-08      |
# |    reward               | -361.95535    |
# |    std                  | 758           |
# |    value_loss           | 783           |
# -------------------------------------------
# Episode: 28, com: AAPL, win trade: 154/252, Total profit: 2453367.587265587 ,Surplus from buy-hold: -4409874.188549541
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 3453367.59
# total profit: 2453367.59
# surplus from buy-and-hold: -4409874.19
# total_cost: 707870.29
# total_trades: 252
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 24           |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 4.270987e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 148          |
# |    n_updates            | 125720       |
# |    policy_gradient_loss | -1.08e-05    |
# |    reward               | -440.98743   |
# |    std                  | 757          |
# |    value_loss           | 423          |
# ------------------------------------------
# Episode: 29, com: AAPL, win trade: 151/247, Total profit: 1361507.9515601671 ,Surplus from buy-hold: -5501733.824254962
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 25           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 6.693881e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 41           |
# |    n_updates            | 125730       |
# |    policy_gradient_loss | -6.8e-07     |
# |    reward               | -550.1734    |
# |    std                  | 757          |
# |    value_loss           | 438          |
# ------------------------------------------
# Episode: 30, com: AAPL, win trade: 146/246, Total profit: 3280588.4435335584 ,Surplus from buy-hold: -3582653.33228157
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 26            |
# |    time_elapsed         | 340           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 1.9641302e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.632         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 151           |
# |    n_updates            | 125740        |
# |    policy_gradient_loss | -3.5e-05      |
# |    reward               | -358.26532    |
# |    std                  | 756           |
# |    value_loss           | 783           |
# -------------------------------------------
# Episode: 31, com: AAPL, win trade: 149/252, Total profit: 1729468.2214103593 ,Surplus from buy-hold: -5133773.554404769
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 27            |
# |    time_elapsed         | 353           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 3.2171374e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.654         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 117           |
# |    n_updates            | 125750        |
# |    policy_gradient_loss | -1.43e-05     |
# |    reward               | -513.3774     |
# |    std                  | 756           |
# |    value_loss           | 509           |
# -------------------------------------------
# Episode: 32, com: AAPL, win trade: 148/242, Total profit: 2698897.5225144015 ,Surplus from buy-hold: -4164344.253300727
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 3698897.52
# total profit: 2698897.52
# surplus from buy-and-hold: -4164344.25
# total_cost: 804866.69
# total_trades: 242
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 28            |
# |    time_elapsed         | 367           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 2.3769098e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.637         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 269           |
# |    n_updates            | 125760        |
# |    policy_gradient_loss | -2.6e-06      |
# |    reward               | -416.43442    |
# |    std                  | 755           |
# |    value_loss           | 661           |
# -------------------------------------------
# Episode: 33, com: AAPL, win trade: 158/247, Total profit: 2066919.5724719441 ,Surplus from buy-hold: -4796322.203343185
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 29            |
# |    time_elapsed         | 380           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 2.0710868e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.679         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 70.6          |
# |    n_updates            | 125770        |
# |    policy_gradient_loss | -1.64e-05     |
# |    reward               | -479.63223    |
# |    std                  | 756           |
# |    value_loss           | 445           |
# -------------------------------------------
# Episode: 34, com: AAPL, win trade: 143/248, Total profit: 1232189.80186505 ,Surplus from buy-hold: -5631051.973950079
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 30            |
# |    time_elapsed         | 394           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 2.1775195e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.767         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 181           |
# |    n_updates            | 125780        |
# |    policy_gradient_loss | -3.09e-05     |
# |    reward               | -563.1052     |
# |    std                  | 758           |
# |    value_loss           | 463           |
# -------------------------------------------
# Episode: 35, com: AAPL, win trade: 151/249, Total profit: 5228468.111459271 ,Surplus from buy-hold: -1634773.6643558573
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 31            |
# |    time_elapsed         | 407           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 4.8894435e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.704         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 427           |
# |    n_updates            | 125790        |
# |    policy_gradient_loss | -1.38e-06     |
# |    reward               | -163.47737    |
# |    std                  | 758           |
# |    value_loss           | 817           |
# -------------------------------------------
# Episode: 36, com: AAPL, win trade: 146/242, Total profit: 1998289.5436330172 ,Surplus from buy-hold: -4864952.232182112
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 2998289.54
# total profit: 1998289.54
# surplus from buy-and-hold: -4864952.23
# total_cost: 929501.49
# total_trades: 242
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 32           |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 1.717126e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | -0.0141      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 105          |
# |    n_updates            | 125800       |
# |    policy_gradient_loss | 6.37e-07     |
# |    reward               | -486.4952    |
# |    std                  | 758          |
# |    value_loss           | 610          |
# ------------------------------------------
# Episode: 37, com: AAPL, win trade: 155/251, Total profit: 3049752.2138670064 ,Surplus from buy-hold: -3813489.561948122
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 33            |
# |    time_elapsed         | 433           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.0477379e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.472         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 304           |
# |    n_updates            | 125810        |
# |    policy_gradient_loss | 5.4e-07       |
# |    reward               | -381.34897    |
# |    std                  | 758           |
# |    value_loss           | 718           |
# -------------------------------------------
# Episode: 38, com: AAPL, win trade: 134/243, Total profit: 628670.372880325 ,Surplus from buy-hold: -6234571.402934804
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 34            |
# |    time_elapsed         | 446           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 3.8938015e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.602         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 79.4          |
# |    n_updates            | 125820        |
# |    policy_gradient_loss | -2.43e-06     |
# |    reward               | -623.45715    |
# |    std                  | 758           |
# |    value_loss           | 392           |
# -------------------------------------------
# Episode: 39, com: AAPL, win trade: 144/242, Total profit: 3843057.054946729 ,Surplus from buy-hold: -3020184.7208683994
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 35          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 9.84699e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -8.05       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 895         |
# |    n_updates            | 125830      |
# |    policy_gradient_loss | -1.68e-05   |
# |    reward               | -302.01846  |
# |    std                  | 758         |
# |    value_loss           | 873         |
# -----------------------------------------
# Episode: 40, com: AAPL, win trade: 153/242, Total profit: 2385447.922258085 ,Surplus from buy-hold: -4477793.853557043
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 3385447.92
# total profit: 2385447.92
# surplus from buy-and-hold: -4477793.85
# total_cost: 796971.06
# total_trades: 242
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 36            |
# |    time_elapsed         | 472           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 4.0075975e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.444         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 102           |
# |    n_updates            | 125840        |
# |    policy_gradient_loss | -1.26e-05     |
# |    reward               | -447.7794     |
# |    std                  | 759           |
# |    value_loss           | 297           |
# -------------------------------------------
# Episode: 41, com: AAPL, win trade: 155/242, Total profit: 2032641.6101658856 ,Surplus from buy-hold: -4830600.165649243
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 37           |
# |    time_elapsed         | 485          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 1.869048e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 471          |
# |    n_updates            | 125850       |
# |    policy_gradient_loss | -3.76e-06    |
# |    reward               | -483.06003   |
# |    std                  | 759          |
# |    value_loss           | 519          |
# ------------------------------------------
# Episode: 42, com: AAPL, win trade: 140/241, Total profit: 2087282.8333335114 ,Surplus from buy-hold: -4775958.9424816165
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 38            |
# |    time_elapsed         | 497           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 2.3574103e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.61          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 149           |
# |    n_updates            | 125860        |
# |    policy_gradient_loss | -3.77e-07     |
# |    reward               | -477.5959     |
# |    std                  | 759           |
# |    value_loss           | 674           |
# -------------------------------------------
# Episode: 43, com: AAPL, win trade: 150/250, Total profit: 3533064.7833252046 ,Surplus from buy-hold: -3330176.9924899237
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 39           |
# |    time_elapsed         | 510          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 1.063745e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 514          |
# |    n_updates            | 125870       |
# |    policy_gradient_loss | -2.82e-06    |
# |    reward               | -333.0177    |
# |    std                  | 759          |
# |    value_loss           | 609          |
# ------------------------------------------
# Episode: 44, com: AAPL, win trade: 149/252, Total profit: 3388773.3491286226 ,Surplus from buy-hold: -3474468.426686506
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 4388773.35
# total profit: 3388773.35
# surplus from buy-and-hold: -3474468.43
# total_cost: 909615.44
# total_trades: 252
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 156        |
# |    iterations           | 40         |
# |    time_elapsed         | 523        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.0        |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -8.05      |
# |    explained_variance   | 0.736      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 103        |
# |    n_updates            | 125880     |
# |    policy_gradient_loss | 3.04e-07   |
# |    reward               | -347.44684 |
# |    std                  | 759        |
# |    value_loss           | 300        |
# ----------------------------------------
# Episode: 45, com: AAPL, win trade: 144/253, Total profit: 1673362.8209264707 ,Surplus from buy-hold: -5189878.954888658
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 41            |
# |    time_elapsed         | 536           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 5.0326926e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.707         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 238           |
# |    n_updates            | 125890        |
# |    policy_gradient_loss | -8.99e-05     |
# |    reward               | -518.9879     |
# |    std                  | 757           |
# |    value_loss           | 360           |
# -------------------------------------------
# Episode: 46, com: AAPL, win trade: 145/248, Total profit: 3221924.5648852233 ,Surplus from buy-hold: -3641317.210929905
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 42           |
# |    time_elapsed         | 549          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 9.902578e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 272          |
# |    n_updates            | 125900       |
# |    policy_gradient_loss | -1.7e-05     |
# |    reward               | -364.1317    |
# |    std                  | 756          |
# |    value_loss           | 699          |
# ------------------------------------------
# Episode: 47, com: AAPL, win trade: 154/248, Total profit: 1653659.4906771132 ,Surplus from buy-hold: -5209582.285138015
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 43            |
# |    time_elapsed         | 562           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 3.3905962e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.627         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 353           |
# |    n_updates            | 125910        |
# |    policy_gradient_loss | -5.31e-07     |
# |    reward               | -520.95825    |
# |    std                  | 756           |
# |    value_loss           | 417           |
# -------------------------------------------
# Episode: 48, com: AAPL, win trade: 136/244, Total profit: 1001335.8903044104 ,Surplus from buy-hold: -5861905.885510718
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 2001335.89
# total profit: 1001335.89
# surplus from buy-and-hold: -5861905.89
# total_cost: 561369.52
# total_trades: 244
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 44           |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 5.500333e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 399          |
# |    n_updates            | 125920       |
# |    policy_gradient_loss | -1.5e-05     |
# |    reward               | -586.1906    |
# |    std                  | 756          |
# |    value_loss           | 737          |
# ------------------------------------------
# Episode: 49, com: AAPL, win trade: 139/248, Total profit: 1187873.9361541714 ,Surplus from buy-hold: -5675367.839660957
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 45            |
# |    time_elapsed         | 588           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 2.1932647e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.641         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 152           |
# |    n_updates            | 125930        |
# |    policy_gradient_loss | -1.92e-05     |
# |    reward               | -567.5368     |
# |    std                  | 757           |
# |    value_loss           | 892           |
# -------------------------------------------
# Episode: 50, com: AAPL, win trade: 143/250, Total profit: 1210480.9023056533 ,Surplus from buy-hold: -5652760.873509475
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 46            |
# |    time_elapsed         | 602           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.5412515e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.05         |
# |    explained_variance   | 0.694         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 118           |
# |    n_updates            | 125940        |
# |    policy_gradient_loss | -3.03e-05     |
# |    reward               | -565.27606    |
# |    std                  | 758           |
# |    value_loss           | 804           |
# -------------------------------------------
# Episode: 51, com: AAPL, win trade: 138/243, Total profit: 696127.8263250722 ,Surplus from buy-hold: -6167113.949490056
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 47           |
# |    time_elapsed         | 615          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 4.407484e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# ...
# |    value_loss           | 742           |
# -------------------------------------------
# Episode: 611, com: AAPL, win trade: 140/247, Total profit: 1104236.1624691538 ,Surplus from buy-hold: -5759005.613345975
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 607           |
# |    time_elapsed         | 8010          |
# |    total_timesteps      | 1243136       |
# | train/                  |               |
# |    approx_kl            | 2.3600296e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.657         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 179           |
# |    n_updates            | 131550        |
# |    policy_gradient_loss | -7.28e-06     |
# |    reward               | -575.9006     |
# |    std                  | 925           |
# |    value_loss           | 374           |
# -------------------------------------------
# Episode: 612, com: AAPL, win trade: 151/251, Total profit: 2207338.2049568347 ,Surplus from buy-hold: -4655903.570858294
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 3207338.20
# total profit: 2207338.20
# surplus from buy-and-hold: -4655903.57
# total_cost: 659507.64
# total_trades: 251
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 608           |
# |    time_elapsed         | 8023          |
# |    total_timesteps      | 1245184       |
# | train/                  |               |
# |    approx_kl            | 3.1397212e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.633         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 178           |
# |    n_updates            | 131560        |
# |    policy_gradient_loss | 2.2e-06       |
# |    reward               | -465.59036    |
# |    std                  | 925           |
# |    value_loss           | 783           |
# -------------------------------------------
# Episode: 613, com: AAPL, win trade: 141/242, Total profit: 1490892.481720353 ,Surplus from buy-hold: -5372349.294094775
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 609         |
# |    time_elapsed         | 8036        |
# |    total_timesteps      | 1247232     |
# | train/                  |             |
# |    approx_kl            | 3.45608e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 623         |
# |    n_updates            | 131570      |
# |    policy_gradient_loss | -1.09e-05   |
# |    reward               | -537.2349   |
# |    std                  | 926         |
# |    value_loss           | 650         |
# -----------------------------------------
# Episode: 614, com: AAPL, win trade: 146/248, Total profit: 1070634.2337150574 ,Surplus from buy-hold: -5792607.542100071
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 610          |
# |    time_elapsed         | 8048         |
# |    total_timesteps      | 1249280      |
# | train/                  |              |
# |    approx_kl            | 7.962808e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -8.25        |
# |    explained_variance   | 0.589        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 164          |
# |    n_updates            | 131580       |
# |    policy_gradient_loss | 1.53e-06     |
# |    reward               | -579.26074   |
# |    std                  | 926          |
# |    value_loss           | 905          |
# ------------------------------------------
# Episode: 615, com: AAPL, win trade: 146/245, Total profit: 1024823.9242502779 ,Surplus from buy-hold: -5838417.851564851
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 611           |
# |    time_elapsed         | 8064          |
# |    total_timesteps      | 1251328       |
# | train/                  |               |
# |    approx_kl            | 1.9324943e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.666         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 124           |
# |    n_updates            | 131590        |
# |    policy_gradient_loss | -5.46e-07     |
# |    reward               | -583.8418     |
# |    std                  | 926           |
# |    value_loss           | 874           |
# -------------------------------------------
# Episode: 616, com: AAPL, win trade: 155/248, Total profit: 959549.7257271644 ,Surplus from buy-hold: -5903692.050087964
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 1959549.73
# total profit: 959549.73
# surplus from buy-and-hold: -5903692.05
# total_cost: 586789.41
# total_trades: 248
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 612           |
# |    time_elapsed         | 8081          |
# |    total_timesteps      | 1253376       |
# | train/                  |               |
# |    approx_kl            | 2.2823224e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.669         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 705           |
# |    n_updates            | 131600        |
# |    policy_gradient_loss | 1.3e-06       |
# |    reward               | -590.3692     |
# |    std                  | 927           |
# |    value_loss           | 928           |
# -------------------------------------------
# Episode: 617, com: AAPL, win trade: 155/255, Total profit: 4476126.835149071 ,Surplus from buy-hold: -2387114.940666057
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 613           |
# |    time_elapsed         | 8094          |
# |    total_timesteps      | 1255424       |
# | train/                  |               |
# |    approx_kl            | 8.2858605e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.572         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 722           |
# |    n_updates            | 131610        |
# |    policy_gradient_loss | -1.74e-05     |
# |    reward               | -238.71149    |
# |    std                  | 928           |
# |    value_loss           | 1.08e+03      |
# -------------------------------------------
# Episode: 618, com: AAPL, win trade: 150/247, Total profit: 3064990.4152827263 ,Surplus from buy-hold: -3798251.360532402
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 614           |
# |    time_elapsed         | 8108          |
# |    total_timesteps      | 1257472       |
# | train/                  |               |
# |    approx_kl            | 1.3507088e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.244         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 156           |
# |    n_updates            | 131620        |
# |    policy_gradient_loss | -5.59e-06     |
# |    reward               | -379.82513    |
# |    std                  | 928           |
# |    value_loss           | 339           |
# -------------------------------------------
# Episode: 619, com: AAPL, win trade: 154/252, Total profit: 1601354.0045295763 ,Surplus from buy-hold: -5261887.7712855525
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 615           |
# |    time_elapsed         | 8122          |
# |    total_timesteps      | 1259520       |
# | train/                  |               |
# |    approx_kl            | 1.6624108e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -8.25         |
# |    explained_variance   | 0.464         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 319           |
# |    n_updates            | 131630        |
# |    policy_gradient_loss | -9.23e-06     |
# |    reward               | -526.1888     |
# |    std                  | 928           |
# |    value_loss           | 410           |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yp/xsyhd9vn1bj7xbmj2dyszbh40000gn/T/ipykernel_1719/3205720820.py in ?()
#       5                       policy_kwargs=policy_kwargs,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo",verbose=1,device=device)
#       6     trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
#       7 else:
#       8     trained_model.env = env_train
# ----> 9     trained_ppo = trained_model.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py in ?(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     311         tb_log_name: str = "PPO",
#     312         reset_num_timesteps: bool = True,
#     313         progress_bar: bool = False,
#     314     ) -> SelfPPO:
# --> 315         return super().learn(
#     316             total_timesteps=total_timesteps,
#     317             callback=callback,
#     318             log_interval=log_interval,
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py in ?(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     273
#     274         assert self.env is not None
#     275
#     276         while self.num_timesteps < total_timesteps:
# --> 277             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     278
#     279             if not continue_training:
#     280                 break
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py in ?(self, env, callback, rollout_buffer, n_rollout_steps)
#     190                     # Otherwise, clip the actions to avoid out of bound error
#     191                     # as we are sampling from an unbounded Gaussian distribution
#     192                     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     193
# --> 194             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     195
#     196             self.num_timesteps += env.num_envs
#     197
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in ?(self, actions)
#     202         :param actions: the action
#     203         :return: observation, reward, done, information
#     204         """
#     205         self.step_async(actions)
# --> 206         return self.step_wait()
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in ?(self)
#      55     def step_wait(self) -> VecEnvStepReturn:
#      56         # Avoid circular imports
#      57         for env_idx in range(self.num_envs):
# ---> 58             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59                 self.actions[env_idx]
#      60             )
#      61             # convert to SB3 VecEnv api
#
# ~/Desktop/GameProjects/DataScience/Binhlai_Testing/trading_environment_end_reward.py in ?(self, actions)
#     177             action = actions[0]
#     178
#     179             # self.reward = 0 # Reset reward
#     180             if action > 0:
# --> 181                 self._buy_stock(action)
#     182             elif action < 0:
#     183                 self._sell_stock(action)
#     184
#
# ~/Desktop/GameProjects/DataScience/Binhlai_Testing/trading_environment_end_reward.py in ?(self, action)
#      99                 buy_num_shares = 0
#     100
#     101             return buy_num_shares
#     102
# --> 103         buy_num_shares = _do_buy()
#     104         return buy_num_shares
#
# ~/Desktop/GameProjects/DataScience/Binhlai_Testing/trading_environment_end_reward.py in ?()
#      93         def _do_buy():
#      94             if self.data.close > 0: # Buy only if the price is > 0 (no missing data in this particular date)
# ---> 95                 buy_num_shares, buy_fee = self.portfolio.add_buy_stock(self.data.tic,self.data.close,action)
#      96                 # print(f'Buy amount: {buy_num_shares}')
#      97                 self.cost += buy_fee
#      98             else:
#
# ~/Desktop/GameProjects/DataScience/Binhlai_Testing/portfolio.py in ?(self, tic, buy_price, prop)
#      17             return 0,0
#      18         # Buy amount = prop * NAV
#      19         # prop_nav = self.get_asset_value * abs(prop)
#      20         # cost = math.min(prop_nav,self.portfolio.loc[0].price)
# ---> 21         cost = self.portfolio.loc[0].price*prop
#      22         buy_amount = math.ceil(abs(cost/buy_price))
#      23         buy_fee = buy_amount*buy_price*self.buy_cost_pct
#      24         self.portfolio.loc[len(self.portfolio)] = [tic,buy_price,buy_price,buy_amount,0,self.hold_period]
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, key)
#    1187             axis = self.axis or 0
#    1188
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, key, axis)
#    1427                 return self.obj.iloc[tuple(indexer)]
#    1428
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, label, axis)
#    1379     def _get_label(self, label, axis: AxisInt):
#    1380         # GH#5567 this will fail if the label is not present in the axis.
# -> 1381         return self.obj.xs(label, axis=axis)
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis, level, drop_level)
#    4306
#    4307             if not is_scalar(loc):
#    4308                 new_index = index[loc]
#    4309
# -> 4310         if is_scalar(loc) and axis == 0:
#    4311             # In this case loc should be an integer
#    4312             if self.ndim == 1:
#    4313                 # if we encounter an array-like and we only have 1 dim
#
# KeyboardInterrupt:

# %% [markdown]
# Keep continuing the current training

# %%
trained_ppo = trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
# Out:
# Logging to tensorboard_log/test_ppo/ppo_107
# Episode: 983, com: AAPL, win trade: 12/14, Total profit: 6426742.372354128 ,Surplus from buy-hold: -436499.40346099995
# ----------------------------------
# | time/              |           |
# |    fps             | 196       |
# |    iterations      | 1         |
# |    time_elapsed    | 10        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | -43.64994 |
# ----------------------------------
# Episode: 984, com: AAPL, win trade: 12/20, Total profit: 6549615.594935783 ,Surplus from buy-hold: -313626.18087934516
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7549615.59
# total profit: 6549615.59
# surplus from buy-and-hold: -313626.18
# total_cost: 80994.18
# total_trades: 20
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 2            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 2.869463e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.857        |
# |    n_updates            | 50750        |
# |    policy_gradient_loss | -0.000132    |
# |    reward               | -31.362617   |
# |    std                  | 16.3         |
# |    value_loss           | 2.93         |
# ------------------------------------------
# Episode: 985, com: AAPL, win trade: 11/16, Total profit: 6032579.421036236 ,Surplus from buy-hold: -830662.3547788924
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 177          |
# |    iterations           | 3            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 6.979768e-05 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.594        |
# |    n_updates            | 50760        |
# |    policy_gradient_loss | -6.19e-05    |
# |    reward               | -83.06624    |
# |    std                  | 16.3         |
# |    value_loss           | 1.81         |
# ------------------------------------------
# Episode: 986, com: AAPL, win trade: 14/20, Total profit: 6647290.61956006 ,Surplus from buy-hold: -215951.15625506826
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 170           |
# |    iterations           | 4             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.0703487e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.21         |
# |    explained_variance   | 0.595         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.08          |
# |    n_updates            | 50770         |
# |    policy_gradient_loss | -7.52e-05     |
# |    reward               | -21.595116    |
# |    std                  | 16.3          |
# |    value_loss           | 9.94          |
# -------------------------------------------
# Episode: 987, com: AAPL, win trade: 16/20, Total profit: 6629820.265708869 ,Surplus from buy-hold: -233421.51010625903
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 133          |
# |    iterations           | 5            |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 8.781065e-05 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.34         |
# |    n_updates            | 50780        |
# |    policy_gradient_loss | -0.000592    |
# |    reward               | -23.342152   |
# |    std                  | 16.2         |
# |    value_loss           | 6.12         |
# ------------------------------------------
# Episode: 988, com: AAPL, win trade: 13/17, Total profit: 5660026.770102174 ,Surplus from buy-hold: -1203215.0057129543
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 6660026.77
# total profit: 5660026.77
# surplus from buy-and-hold: -1203215.01
# total_cost: 72066.71
# total_trades: 17
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 137           |
# |    iterations           | 6             |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00015950445 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.21         |
# |    explained_variance   | 0.814         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.574         |
# |    n_updates            | 50790         |
# |    policy_gradient_loss | -0.000604     |
# |    reward               | -120.3215     |
# |    std                  | 16.2          |
# |    value_loss           | 2.71          |
# -------------------------------------------
# Episode: 989, com: AAPL, win trade: 14/19, Total profit: 7524017.000643201 ,Surplus from buy-hold: 660775.2248280728
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 7            |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 3.605988e-05 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 21.3         |
# |    n_updates            | 50800        |
# |    policy_gradient_loss | -0.000582    |
# |    reward               | 66.07752     |
# |    std                  | 16.2         |
# |    value_loss           | 47.3         |
# ------------------------------------------
# Episode: 990, com: AAPL, win trade: 11/15, Total profit: 6506746.169338562 ,Surplus from buy-hold: -356495.60647656675
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 136           |
# |    iterations           | 8             |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 4.5795576e-05 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.2          |
# |    explained_variance   | -0.0931       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 15.8          |
# |    n_updates            | 50810         |
# |    policy_gradient_loss | -2.54e-05     |
# |    reward               | -35.64956     |
# |    std                  | 16.2          |
# |    value_loss           | 19.6          |
# -------------------------------------------
# Episode: 991, com: AAPL, win trade: 8/10, Total profit: 6698998.337276943 ,Surplus from buy-hold: -164243.43853818532
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 136           |
# |    iterations           | 9             |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 3.3926306e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.2          |
# |    explained_variance   | -0.0104       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.624         |
# |    n_updates            | 50820         |
# |    policy_gradient_loss | -0.000113     |
# |    reward               | -16.424343    |
# |    std                  | 16.3          |
# |    value_loss           | 5.14          |
# -------------------------------------------
# Episode: 992, com: AAPL, win trade: 18/22, Total profit: 7063652.01289401 ,Surplus from buy-hold: 200410.23707888182
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 8063652.01
# total profit: 7063652.01
# surplus from buy-and-hold: 200410.24
# total_cost: 90999.19
# total_trades: 22
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 10           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 1.575565e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | -0.00756     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.169        |
# |    n_updates            | 50830        |
# |    policy_gradient_loss | 1.46e-06     |
# |    reward               | 20.041023    |
# |    std                  | 16.3         |
# |    value_loss           | 1.08         |
# ------------------------------------------
# Episode: 993, com: AAPL, win trade: 11/15, Total profit: 6555986.970006327 ,Surplus from buy-hold: -307254.8058088012
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 11           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 8.791685e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 7.42         |
# |    n_updates            | 50840        |
# |    policy_gradient_loss | -9.11e-05    |
# |    reward               | -30.725481   |
# |    std                  | 16.3         |
# |    value_loss           | 24.2         |
# ------------------------------------------
# Episode: 994, com: AAPL, win trade: 6/10, Total profit: 6672195.624318191 ,Surplus from buy-hold: -191046.1514969375
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 12           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0005853126 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | -0.125       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.342        |
# |    n_updates            | 50850        |
# |    policy_gradient_loss | -0.000508    |
# |    reward               | -19.104614   |
# |    std                  | 16.2         |
# |    value_loss           | 3.78         |
# ------------------------------------------
# Episode: 995, com: AAPL, win trade: 9/13, Total profit: 6714912.89515554 ,Surplus from buy-hold: -148328.8806595886
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 142           |
# |    iterations           | 13            |
# |    time_elapsed         | 186           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00092122384 |
# |    clip_fraction        | 0.00806       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.2          |
# |    explained_variance   | -0.0193       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.486         |
# |    n_updates            | 50860         |
# |    policy_gradient_loss | -0.0013       |
# |    reward               | -14.832888    |
# |    std                  | 16            |
# |    value_loss           | 1.39          |
# -------------------------------------------
# Episode: 996, com: AAPL, win trade: 13/19, Total profit: 7444114.37322307 ,Surplus from buy-hold: 580872.5974079417
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 8444114.37
# total profit: 7444114.37
# surplus from buy-and-hold: 580872.60
# total_cost: 83932.35
# total_trades: 19
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 14           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 6.678645e-05 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 2.18         |
# |    n_updates            | 50870        |
# |    policy_gradient_loss | -0.000254    |
# |    reward               | 58.08726     |
# |    std                  | 16           |
# |    value_loss           | 4.87         |
# ------------------------------------------
# Episode: 997, com: AAPL, win trade: 13/17, Total profit: 6598389.336833214 ,Surplus from buy-hold: -264852.43898191396
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 15            |
# |    time_elapsed         | 212           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 2.5557849e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -1.94         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 4.21          |
# |    n_updates            | 50880         |
# |    policy_gradient_loss | -0.000134     |
# |    reward               | -26.485245    |
# |    std                  | 16            |
# |    value_loss           | 13.3          |
# -------------------------------------------
# Episode: 998, com: AAPL, win trade: 7/8, Total profit: 7164247.634008569 ,Surplus from buy-hold: 301005.85819344036
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 16          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.000252783 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | -0.032      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.27        |
# |    n_updates            | 50890       |
# |    policy_gradient_loss | -0.000433   |
# |    reward               | 30.100586   |
# |    std                  | 16          |
# |    value_loss           | 2.81        |
# -----------------------------------------
# Episode: 999, com: AAPL, win trade: 10/13, Total profit: 7820417.788774297 ,Surplus from buy-hold: 957176.0129591683
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 145           |
# |    iterations           | 17            |
# |    time_elapsed         | 239           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00012056381 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -0.00466      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 1.46          |
# |    n_updates            | 50900         |
# |    policy_gradient_loss | -0.000141     |
# |    reward               | 95.7176       |
# |    std                  | 16            |
# |    value_loss           | 4.1           |
# -------------------------------------------
# Episode: 1000, com: AAPL, win trade: 10/14, Total profit: 6447576.763174976 ,Surplus from buy-hold: -415665.0126401521
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7447576.76
# total profit: 6447576.76
# surplus from buy-and-hold: -415665.01
# total_cost: 52712.39
# total_trades: 14
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 18            |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.0207877e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | 0.28          |
# |    learning_rate        | 0.0002        |
# |    loss                 | 11.7          |
# |    n_updates            | 50910         |
# |    policy_gradient_loss | -1.02e-05     |
# |    reward               | -41.5665      |
# |    std                  | 16            |
# |    value_loss           | 24.8          |
# -------------------------------------------
# Episode: 1001, com: AAPL, win trade: 7/8, Total profit: 6354011.186893302 ,Surplus from buy-hold: -509230.58892182633
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 19            |
# |    time_elapsed         | 268           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 6.5507193e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -2.07         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.61          |
# |    n_updates            | 50920         |
# |    policy_gradient_loss | 2.23e-06      |
# |    reward               | -50.923058    |
# |    std                  | 16            |
# |    value_loss           | 8.31          |
# -------------------------------------------
# Episode: 1002, com: AAPL, win trade: 7/9, Total profit: 6633966.422082992 ,Surplus from buy-hold: -229275.35373213608
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 20            |
# |    time_elapsed         | 284           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 6.7603134e-05 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -0.00353      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.68          |
# |    n_updates            | 50930         |
# |    policy_gradient_loss | -0.000166     |
# |    reward               | -22.927536    |
# |    std                  | 16            |
# |    value_loss           | 10.9          |
# -------------------------------------------
# Episode: 1003, com: AAPL, win trade: 6/6, Total profit: 6370583.773709685 ,Surplus from buy-hold: -492658.00210544374
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 21           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0017951316 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | -0.0876      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.507        |
# |    n_updates            | 50940        |
# |    policy_gradient_loss | -0.00176     |
# |    reward               | -49.2658     |
# |    std                  | 16           |
# |    value_loss           | 2.15         |
# ------------------------------------------
# Episode: 1004, com: AAPL, win trade: 2/5, Total profit: 6657269.735517419 ,Surplus from buy-hold: -205972.0402977094
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7657269.74
# total profit: 6657269.74
# surplus from buy-and-hold: -205972.04
# total_cost: 26032.37
# total_trades: 5
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 22            |
# |    time_elapsed         | 312           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00010092513 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | 0.0151        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.957         |
# |    n_updates            | 50950         |
# |    policy_gradient_loss | -0.00021      |
# |    reward               | -20.597204    |
# |    std                  | 16            |
# |    value_loss           | 5.3           |
# -------------------------------------------
# Episode: 1005, com: AAPL, win trade: 4/6, Total profit: 7050208.656291233 ,Surplus from buy-hold: 186966.88047610503
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 23            |
# |    time_elapsed         | 325           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 2.9074436e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | 0.811         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.25          |
# |    n_updates            | 50960         |
# |    policy_gradient_loss | -6.11e-05     |
# |    reward               | 18.696688     |
# |    std                  | 16            |
# |    value_loss           | 2.29          |
# -------------------------------------------
# Episode: 1006, com: AAPL, win trade: 6/8, Total profit: 6681011.957745024 ,Surplus from buy-hold: -182229.81807010435
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 24            |
# |    time_elapsed         | 340           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 3.1175907e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -0.614        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.48          |
# |    n_updates            | 50970         |
# |    policy_gradient_loss | -0.000143     |
# |    reward               | -18.222982    |
# |    std                  | 16            |
# |    value_loss           | 4.68          |
# -------------------------------------------
# Episode: 1007, com: AAPL, win trade: 5/9, Total profit: 6568231.8738222625 ,Surplus from buy-hold: -295009.90199286584
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 25           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 7.355056e-05 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | -0.319       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.482        |
# |    n_updates            | 50980        |
# |    policy_gradient_loss | -0.000807    |
# |    reward               | -29.50099    |
# |    std                  | 15.9         |
# |    value_loss           | 1.44         |
# ------------------------------------------
# Episode: 1008, com: AAPL, win trade: 5/8, Total profit: 6676179.943545369 ,Surplus from buy-hold: -187061.83226975892
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7676179.94
# total profit: 6676179.94
# surplus from buy-and-hold: -187061.83
# total_cost: 32010.46
# total_trades: 8
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 145           |
# |    iterations           | 26            |
# |    time_elapsed         | 367           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 4.6500703e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -0.00368      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.863         |
# |    n_updates            | 50990         |
# |    policy_gradient_loss | -2.94e-05     |
# |    reward               | -18.706182    |
# |    std                  | 15.9          |
# |    value_loss           | 3.58          |
# -------------------------------------------
# Episode: 1009, com: AAPL, win trade: 4/5, Total profit: 6448358.733365307 ,Surplus from buy-hold: -414883.0424498217
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 27           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 1.662472e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | -0.0185      |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.00322     |
# |    n_updates            | 51000        |
# |    policy_gradient_loss | -2.11e-05    |
# |    reward               | -41.488304   |
# |    std                  | 16           |
# |    value_loss           | 1.46         |
# ------------------------------------------
# Episode: 1010, com: AAPL, win trade: 6/13, Total profit: 5851323.136436298 ,Surplus from buy-hold: -1011918.6393788308
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 145           |
# |    iterations           | 28            |
# |    time_elapsed         | 393           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00058897806 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | -0.000291     |
# |    learning_rate        | 0.0002        |
# |    loss                 | 4.08          |
# |    n_updates            | 51010         |
# |    policy_gradient_loss | -0.000852     |
# |    reward               | -101.191864   |
# |    std                  | 16            |
# |    value_loss           | 7.09          |
# -------------------------------------------
# Episode: 1011, com: AAPL, win trade: 7/9, Total profit: 6912712.053620311 ,Surplus from buy-hold: 49470.27780518308
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 146           |
# |    iterations           | 29            |
# |    time_elapsed         | 406           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 3.9941806e-05 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | 0.0356        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.51          |
# |    n_updates            | 51020         |
# |    policy_gradient_loss | -0.00011      |
# |    reward               | 4.9470277     |
# |    std                  | 16            |
# |    value_loss           | 39.2          |
# -------------------------------------------
# Episode: 1012, com: AAPL, win trade: 5/6, Total profit: 6348665.013883913 ,Surplus from buy-hold: -514576.7619312154
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7348665.01
# total profit: 6348665.01
# surplus from buy-and-hold: -514576.76
# total_cost: 40289.74
# total_trades: 6
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 30           |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0002685272 |
# |    clip_fraction        | 0.00493      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | -2.88        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0347       |
# |    n_updates            | 51030        |
# |    policy_gradient_loss | 0.00028      |
# |    reward               | -51.457676   |
# |    std                  | 16           |
# |    value_loss           | 0.384        |
# ------------------------------------------
# Episode: 1013, com: AAPL, win trade: 2/2, Total profit: 6672626.395666545 ,Surplus from buy-hold: -190615.3801485831
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 146           |
# |    iterations           | 31            |
# |    time_elapsed         | 433           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 1.8947234e-05 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | 0.747         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 1.55          |
# |    n_updates            | 51040         |
# |    policy_gradient_loss | 3.52e-05      |
# |    reward               | -19.061539    |
# |    std                  | 16            |
# |    value_loss           | 4.28          |
# -------------------------------------------
# Episode: 1014, com: AAPL, win trade: 6/9, Total profit: 6742843.342989607 ,Surplus from buy-hold: -120398.43282552157
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 146           |
# |    iterations           | 32            |
# |    time_elapsed         | 448           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 4.5928813e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.19         |
# |    explained_variance   | 0.884         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.549         |
# |    n_updates            | 51050         |
# |    policy_gradient_loss | -0.000182     |
# |    reward               | -12.039844    |
# |    std                  | 15.9          |
# |    value_loss           | 0.966         |
# -------------------------------------------
# Episode: 1015, com: AAPL, win trade: 5/7, Total profit: 6773012.48296411 ,Surplus from buy-hold: -90229.29285101872
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 33           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 6.750753e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | -0.901       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.192        |
# |    n_updates            | 51060        |
# |    policy_gradient_loss | -0.000426    |
# |    reward               | -9.022929    |
# |    std                  | 15.8         |
# |    value_loss           | 0.601        |
# ------------------------------------------
# Episode: 1016, com: AAPL, win trade: 7/10, Total profit: 7008420.395390332 ,Surplus from buy-hold: 145178.6195752034
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 8008420.40
# total profit: 7008420.40
# surplus from buy-and-hold: 145178.62
# total_cost: 44235.52
# total_trades: 10
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 146           |
# |    iterations           | 34            |
# |    time_elapsed         | 474           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.9407977e-05 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | -0.0545       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.0455        |
# |    n_updates            | 51070         |
# |    policy_gradient_loss | -0.000147     |
# |    reward               | 14.517862     |
# |    std                  | 15.7          |
# |    value_loss           | 0.296         |
# -------------------------------------------
# Episode: 1017, com: AAPL, win trade: 5/7, Total profit: 6189405.748375336 ,Surplus from buy-hold: -673836.0274397926
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 35           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0007462795 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | -0.954       |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.0405       |
# |    n_updates            | 51080        |
# |    policy_gradient_loss | -0.00079     |
# |    reward               | -67.383606   |
# |    std                  | 15.7         |
# |    value_loss           | 1.33         |
# ------------------------------------------
# Episode: 1018, com: AAPL, win trade: 3/3, Total profit: 7152044.567089518 ,Surplus from buy-hold: 288802.79127438925
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 36           |
# |    time_elapsed         | 501          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 6.872404e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | -0.00041     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 7.85         |
# |    n_updates            | 51090        |
# |    policy_gradient_loss | 5.23e-05     |
# |    reward               | 28.88028     |
# |    std                  | 15.8         |
# |    value_loss           | 18.5         |
# ------------------------------------------
# Episode: 1019, com: AAPL, win trade: 5/5, Total profit: 6953091.944699853 ,Surplus from buy-hold: 89850.16888472438
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 146           |
# |    iterations           | 37            |
# |    time_elapsed         | 515           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 3.4956378e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | -0.41         |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.795         |
# |    n_updates            | 51100         |
# |    policy_gradient_loss | -7.3e-05      |
# |    reward               | 8.985017      |
# |    std                  | 15.8          |
# |    value_loss           | 3.09          |
# -------------------------------------------
# Episode: 1020, com: AAPL, win trade: 6/7, Total profit: 6624284.559226099 ,Surplus from buy-hold: -238957.21658902895
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7624284.56
# total profit: 6624284.56
# surplus from buy-and-hold: -238957.22
# total_cost: 26133.89
# total_trades: 7
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 147           |
# |    iterations           | 38            |
# |    time_elapsed         | 528           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00026020245 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | -0.0103       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.0889        |
# |    n_updates            | 51110         |
# |    policy_gradient_loss | -0.000177     |
# |    reward               | -23.895721    |
# |    std                  | 15.7          |
# |    value_loss           | 0.47          |
# -------------------------------------------
# Episode: 1021, com: AAPL, win trade: 2/2, Total profit: 6834942.115671589 ,Surplus from buy-hold: -28299.66014353931
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 147           |
# |    iterations           | 39            |
# |    time_elapsed         | 541           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00028682122 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | -0.00287      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.356         |
# |    n_updates            | 51120         |
# |    policy_gradient_loss | -0.000146     |
# |    reward               | -2.829966     |
# |    std                  | 15.8          |
# |    value_loss           | 2.18          |
# -------------------------------------------
# Episode: 1022, com: AAPL, win trade: 6/9, Total profit: 6819991.398222756 ,Surplus from buy-hold: -43250.37759237271
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 40           |
# |    time_elapsed         | 552          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0010112068 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | -0.7         |
# |    learning_rate        | 0.0002       |
# |    loss                 | -0.0263      |
# |    n_updates            | 51130        |
# |    policy_gradient_loss | -0.000631    |
# |    reward               | -4.325038    |
# |    std                  | 16           |
# |    value_loss           | 0.0213       |
# ------------------------------------------
# Episode: 1023, com: AAPL, win trade: 5/5, Total profit: 6774591.157216407 ,Surplus from buy-hold: -88650.61859872099
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 41           |
# |    time_elapsed         | 564          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0006444083 |
# |    clip_fraction        | 0.00801      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | -0.0144      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 0.00461      |
# |    n_updates            | 51140        |
# |    policy_gradient_loss | -0.000692    |
# |    reward               | -8.865062    |
# |    std                  | 16.4         |
# |    value_loss           | 0.0499       |
# ------------------------------------------
# Episode: 1024, com: AAPL, win trade: 5/7, Total profit: 6282090.739084828 ,Surplus from buy-hold: -581151.0367303006
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7282090.74
# total profit: 6282090.74
# surplus from buy-and-hold: -581151.04
# total_cost: 34211.85
# total_trades: 7
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 149           |
# |    iterations           | 42            |
# |    time_elapsed         | 576           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00014927203 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.22         |
# |    explained_variance   | 4.89e-05      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.0272        |
# |    n_updates            | 51150         |
# |    policy_gradient_loss | -5.82e-05     |
# |    reward               | -58.115105    |
# |    std                  | 16.6          |
# |    value_loss           | 0.268         |
# -------------------------------------------
# Episode: 1025, com: AAPL, win trade: 0/1, Total profit: 6513196.564771838 ,Surplus from buy-hold: -350045.2110432908
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 149           |
# |    iterations           | 43            |
# |    time_elapsed         | 587           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 1.2590055e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.23         |
# |    explained_variance   | -0.015        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.764         |
# |    n_updates            | 51160         |
# |    policy_gradient_loss | -0.000111     |
# |    reward               | -35.00452     |
# |    std                  | 16.6          |
# |    value_loss           | 10.2          |
# -------------------------------------------
# Episode: 1026, com: AAPL, win trade: 5/6, Total profit: 6664999.093411706 ,Surplus from buy-hold: -198242.68240342196
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 44           |
# |    time_elapsed         | 599          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 5.873444e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | -0.00245     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 3.55         |
# |    n_updates            | 51170        |
# |    policy_gradient_loss | -1.13e-05    |
# |    reward               | -19.824268   |
# |    std                  | 16.6         |
# |    value_loss           | 5.05         |
# ------------------------------------------
# Episode: 1027, com: AAPL, win trade: 7/8, Total profit: 7276068.652363585 ,Surplus from buy-hold: 412826.87654845696
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 150           |
# |    iterations           | 45            |
# |    time_elapsed         | 612           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 5.3356634e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.23         |
# |    explained_variance   | 0.0151        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 2.08          |
# |    n_updates            | 51180         |
# |    policy_gradient_loss | -7.54e-05     |
# |    reward               | 41.28269      |
# |    std                  | 16.6          |
# |    value_loss           | 2.34          |
# -------------------------------------------
# Episode: 1028, com: AAPL, win trade: 8/9, Total profit: 6670011.886238793 ,Surplus from buy-hold: -193229.88957633544
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7670011.89
# total profit: 6670011.89
# surplus from buy-and-hold: -193229.89
# total_cost: 54301.45
# total_trades: 9
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 150           |
# |    iterations           | 46            |
# |    time_elapsed         | 625           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 4.1192194e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.23         |
# |    explained_variance   | -0.175        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 3.87          |
# |    n_updates            | 51190         |
# |    policy_gradient_loss | -0.000366     |
# |    reward               | -19.322989    |
# |    std                  | 16.6          |
# |    value_loss           | 7.9           |
# -------------------------------------------
# Episode: 1029, com: AAPL, win trade: 3/5, Total profit: 6933616.958681605 ,Surplus from buy-hold: 70375.18286647648
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 47            |
# |    time_elapsed         | 637           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# ...
# |    loss                 | 23.4          |
# |    n_updates            | 56970         |
# |    policy_gradient_loss | -7.96e-05     |
# |    reward               | -17.977695    |
# |    std                  | 24.2          |
# |    value_loss           | 50.6          |
# -------------------------------------------
# Episode: 1607, com: AAPL, win trade: 24/34, Total profit: 6103076.215487947 ,Surplus from buy-hold: -760165.5603271816
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 625         |
# |    time_elapsed         | 10792       |
# |    total_timesteps      | 1280000     |
# | train/                  |             |
# |    approx_kl            | 0.000114216 |
# |    clip_fraction        | 0.00132     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | -0.0246     |
# |    learning_rate        | 0.0002      |
# |    loss                 | 0.317       |
# |    n_updates            | 56980       |
# |    policy_gradient_loss | -0.000197   |
# |    reward               | -76.016556  |
# |    std                  | 24          |
# |    value_loss           | 0.936       |
# -----------------------------------------
# Episode: 1608, com: AAPL, win trade: 18/28, Total profit: 6203290.661100435 ,Surplus from buy-hold: -659951.1147146933
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7203290.66
# total profit: 6203290.66
# surplus from buy-and-hold: -659951.11
# total_cost: 100982.20
# total_trades: 28
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 626          |
# |    time_elapsed         | 10812        |
# |    total_timesteps      | 1282048      |
# | train/                  |              |
# |    approx_kl            | 4.640626e-05 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | -0.0021      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 5.61         |
# |    n_updates            | 56990        |
# |    policy_gradient_loss | -0.000277    |
# |    reward               | -65.99511    |
# |    std                  | 24           |
# |    value_loss           | 22.1         |
# ------------------------------------------
# Episode: 1609, com: AAPL, win trade: 14/23, Total profit: 6349656.738560709 ,Surplus from buy-hold: -513585.0372544192
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 627           |
# |    time_elapsed         | 10838         |
# |    total_timesteps      | 1284096       |
# | train/                  |               |
# |    approx_kl            | 3.9592443e-05 |
# |    clip_fraction        | 0.00083       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.6          |
# |    explained_variance   | -0.012        |
# |    learning_rate        | 0.0002        |
# |    loss                 | 4.82          |
# |    n_updates            | 57000         |
# |    policy_gradient_loss | -5.85e-05     |
# |    reward               | -51.358505    |
# |    std                  | 23.9          |
# |    value_loss           | 16.6          |
# -------------------------------------------
# Episode: 1610, com: AAPL, win trade: 21/28, Total profit: 7800244.215207012 ,Surplus from buy-hold: 937002.439391884
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 628          |
# |    time_elapsed         | 10859        |
# |    total_timesteps      | 1286144      |
# | train/                  |              |
# |    approx_kl            | 7.697666e-05 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.6         |
# |    explained_variance   | 0.000707     |
# |    learning_rate        | 0.0002       |
# |    loss                 | 8.29         |
# |    n_updates            | 57010        |
# |    policy_gradient_loss | -0.000187    |
# |    reward               | 93.70024     |
# |    std                  | 24.1         |
# |    value_loss           | 9.84         |
# ------------------------------------------
# Episode: 1611, com: AAPL, win trade: 22/30, Total profit: 6228203.10122165 ,Surplus from buy-hold: -635038.6745934784
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 629          |
# |    time_elapsed         | 10881        |
# |    total_timesteps      | 1288192      |
# | train/                  |              |
# |    approx_kl            | 6.622629e-05 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | 0.00205      |
# |    learning_rate        | 0.0002       |
# |    loss                 | 17.4         |
# |    n_updates            | 57020        |
# |    policy_gradient_loss | -0.000174    |
# |    reward               | -63.50387    |
# |    std                  | 24.3         |
# |    value_loss           | 38.8         |
# ------------------------------------------
# Episode: 1612, com: AAPL, win trade: 23/33, Total profit: 6527281.646091689 ,Surplus from buy-hold: -335960.129723439
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 7527281.65
# total profit: 6527281.65
# surplus from buy-and-hold: -335960.13
# total_cost: 157565.87
# total_trades: 33
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 630          |
# |    time_elapsed         | 10896        |
# |    total_timesteps      | 1290240      |
# | train/                  |              |
# |    approx_kl            | 0.0004836642 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -4.61        |
# |    explained_variance   | -0.000301    |
# |    learning_rate        | 0.0002       |
# |    loss                 | 11.4         |
# |    n_updates            | 57030        |
# |    policy_gradient_loss | -0.000521    |
# |    reward               | -33.596012   |
# |    std                  | 24.3         |
# |    value_loss           | 16           |
# ------------------------------------------
# Episode: 1613, com: AAPL, win trade: 14/22, Total profit: 6179775.558142665 ,Surplus from buy-hold: -683466.2176724635
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 631           |
# |    time_elapsed         | 10916         |
# |    total_timesteps      | 1292288       |
# | train/                  |               |
# |    approx_kl            | 0.00014890279 |
# |    clip_fraction        | 0.00278       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | -0.0256       |
# |    learning_rate        | 0.0002        |
# |    loss                 | 0.8           |
# |    n_updates            | 57040         |
# |    policy_gradient_loss | -0.000997     |
# |    reward               | -68.34662     |
# |    std                  | 24.3          |
# |    value_loss           | 4.14          |
# -------------------------------------------
# Episode: 1614, com: AAPL, win trade: 24/33, Total profit: 5438351.527004903 ,Surplus from buy-hold: -1424890.2488102252
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 118            |
# |    iterations           | 632            |
# |    time_elapsed         | 10937          |
# |    total_timesteps      | 1294336        |
# | train/                  |                |
# |    approx_kl            | 0.000108791515 |
# |    clip_fraction        | 0.00244        |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -4.61          |
# |    explained_variance   | 0.00381        |
# |    learning_rate        | 0.0002         |
# |    loss                 | 10.5           |
# |    n_updates            | 57050          |
# |    policy_gradient_loss | -0.000868      |
# |    reward               | -142.48903     |
# |    std                  | 24.2           |
# |    value_loss           | 18.5           |
# --------------------------------------------
# Episode: 1615, com: AAPL, win trade: 22/33, Total profit: 7538981.456527291 ,Surplus from buy-hold: 675739.6807121625
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 633           |
# |    time_elapsed         | 10953         |
# |    total_timesteps      | 1296384       |
# | train/                  |               |
# |    approx_kl            | 2.6071764e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | -0.00287      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 54.3          |
# |    n_updates            | 57060         |
# |    policy_gradient_loss | -7.21e-05     |
# |    reward               | 67.57397      |
# |    std                  | 24.2          |
# |    value_loss           | 82.4          |
# -------------------------------------------
# Episode: 1616, com: AAPL, win trade: 21/28, Total profit: 5568433.604044422 ,Surplus from buy-hold: -1294808.1717707068
# Current company: AAPL
# begin_total_asset: 1000000.00
# end_total_asset: 6568433.60
# total profit: 5568433.60
# surplus from buy-and-hold: -1294808.17
# total_cost: 128351.24
# total_trades: 28
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 634           |
# |    time_elapsed         | 10968         |
# |    total_timesteps      | 1298432       |
# | train/                  |               |
# |    approx_kl            | 1.8883904e-05 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 0.000788      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 6.47          |
# |    n_updates            | 57070         |
# |    policy_gradient_loss | -0.000201     |
# |    reward               | -129.48082    |
# |    std                  | 24.2          |
# |    value_loss           | 20.6          |
# -------------------------------------------
# Episode: 1617, com: AAPL, win trade: 22/30, Total profit: 5784191.99086429 ,Surplus from buy-hold: -1079049.7849508384
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 635           |
# |    time_elapsed         | 10982         |
# |    total_timesteps      | 1300480       |
# | train/                  |               |
# |    approx_kl            | 1.0679185e-05 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -4.61         |
# |    explained_variance   | 0.000234      |
# |    learning_rate        | 0.0002        |
# |    loss                 | 31.2          |
# |    n_updates            | 57080         |
# |    policy_gradient_loss | -1e-05        |
# |    reward               | -107.904976   |
# |    std                  | 24.2          |
# |    value_loss           | 68.1          |
# -------------------------------------------
# Episode: 1618, com: AAPL, win trade: 24/37, Total profit: 4926957.662589032 ,Surplus from buy-hold: -1936284.1132260961
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 636         |
# |    time_elapsed         | 10996       |
# |    total_timesteps      | 1302528     |
# | train/                  |             |
# |    approx_kl            | 1.68822e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.00112     |
# |    learning_rate        | 0.0002      |
# |    loss                 | 20.1        |
# |    n_updates            | 57090       |
# |    policy_gradient_loss | -3.37e-05   |
# |    reward               | -193.62842  |
# |    std                  | 24.3        |
# |    value_loss           | 46.6        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 trained_ppo = trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:194, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     189     else:
#     190         # Otherwise, clip the actions to avoid out of bound error
#     191         # as we are sampling from an unbounded Gaussian distribution
#     192         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 194 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:72, in DummyVecEnv.step_wait(self)
#      70         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71     self._save_obs(env_idx, obs)
# ---> 72 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/copy.py:144, in deepcopy(x, memo, _nil)
#     140     return y
#     142 cls = type(x)
# --> 144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
#     146     y = copier(x, memo)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model 2: DDPG

# %%
# agent_ddpg = DRLAgent(env = env_train)
# DDPG_PARAMS = {"batch_size": 128, "buffer_size": episode_length, "learning_rate": 0.001}
# model_ddpg = agent_ddpg.get_model("ddpg",model_kwargs = DDPG_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ddpg_tensorboard/")

# # set up logger
# tmp_path = TENSORBOARD_LOG_DIR + '/ddpg'
# new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_ddpg)

# %%
# the training log just show up when total_timesteps higher than 15.000
# trained_ddpg = agent_ddpg.train_model(model=model_ddpg,
#                              tb_log_name='ddpg',
#                              total_timesteps=total_training_step)

# %%
# from stable_baselines3.common.noise import NormalActionNoise

# # The noise objects for DDPG
# n_actions = env_train.action_space.shape[-1]
# action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# # Train the agent
# trained_ddpg = DDPG("MlpPolicy", env_train, action_noise=action_noise, verbose=1)
# trained_ddpg.learn(total_timesteps=total_timesteps, log_interval=10)

# %% [markdown]
# ### Model 3: SAC

# %%
# episode_length = len(e_train_gym.df) + 1
# episode_amount = 4
# total_training_step = episode_length*episode_amount

# %%
# agent_sac = DRLAgent(env = env_train)
# SAC_PARAMS = {
#     "batch_size": 2048,
#     "buffer_size": episode_length,
#     "learning_rate": 0.0003,
#     "learning_starts": episode_length,
#     "ent_coef": "auto_0.1",
# }

# model_sac = agent_sac.get_model("sac",model_kwargs = SAC_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_sac/")

# # # set up logger
# # tmp_path = TENSORBOARD_LOG_DIR + '/test_sac/sac_12'
# # new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # # Set new logger
# # model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 2048, 'buffer_size': 58204, 'learning_rate': 0.0003, 'learning_starts': 58204, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
# trained_sac = agent_sac.train_model(model=model_sac, 
#                              tb_log_name='sac',
#                              total_timesteps=total_training_step)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ### Model 4: TD3

# %%
# agent_td3 = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100, 
#               "buffer_size": 1000000, 
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3, 
#                              tb_log_name='td3',
#                              total_timesteps=10000)

# %% [markdown]
# ### Model 5: A2C

# %%
# agent_a2c = DRLAgent(env = env_train)

# A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
# model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)

# %%
# trained_a2c = agent.train_model(model=model_a2c, 
#                                 tb_log_name='a2c',
#                                 total_timesteps=10000)

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at the begining. We use the PPO model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2018-12 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
test_sub_set = test_data[test_data.tic == 'AAPL'].reset_index(drop=True)
e_trade_gym = StockTradingEnv(df = test_sub_set, **env_kwargs)

# %% [markdown]
# DRL_prediction function allow testing the model using test_data dataset

# %%
def DRL_prediction(model, environment, deterministic=False):
        """make a prediction and get results"""
        # test_env, test_obs = environment.get_sb_env()
        # account_memory = None  # This help avoid unnecessary list creation
        # actions_memory = None  # optimize memory consumption

        test_obs = environment.reset()[0]
        # max_steps = len(environment.df.index.unique()) - 1

        for i in range(0,len(environment.df)):
            action = model.predict(np.asarray(test_obs), deterministic=deterministic)
            test_obs,reward,terminal,truncated,info = environment.step(action[0])

            if terminal:
                print("hit end!")
                break
        return pd.DataFrame(environment.asset_memory, columns=['account_value']), pd.DataFrame(environment.actions_memory)

# %%
df_account_value_ppo, df_actions_ppo = DRL_prediction(model=trained_ppo, environment = e_trade_gym)

# df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
#     model=trained_ddpg, 
#     environment = e_trade_gym)

# df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
#     model=trained_sac, 
#     environment = e_trade_gym)

# df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
#     model=trained_a2c, 
#     environment = e_trade_gym) if if_using_a2c else [None, None]

# df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
#     model=trained_td3, 
#     environment = e_trade_gym) if if_using_td3 else [None, None]
# Out:
# Episode: 1, com: AAPL, win trade: 29/53, Total profit: 232385.9531221774 ,Surplus from buy-hold: -211527.0657784019
# hit end!

# %%
df_account_value_ppo.shape
# df_account_value_ddpg.shape
# df_account_value_sac.shape
# df_account_value_td3.shape
# df_account_value_a2c.shape
# Out:
# (839, 1)

# %%
df_account_value_ppo['date'] = test_sub_set.date
# df_account_value_ddpg['date'] = trade_data.date

# %%
df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
# df_account_value_sac.tail()
# df_account_value_td3.tail()
# df_account_value_a2c.tail()
# Out:
#      account_value       date
# 834   1.145744e+06 2024-04-29
# 835   1.145744e+06 2024-04-30
# 836   1.137670e+06 2024-05-01
# 837   1.162761e+06 2024-05-02
# 838   1.232386e+06 2024-05-03

# %%
# df_actions_ppo.actions.unique()
# df_actions_ddpg.head()
# df_actions_sac.head()
# df_actions_td3.head()
# df_actions_a2c.head()

# %%
df_actions_ppo['date'] = test_sub_set.date
df_actions_ppo.head()
# Out:
#      0       date
# 0  1.0 2021-01-04
# 1 -1.0 2021-01-05
# 2 -1.0 2021-01-06
# 3 -1.0 2021-01-07
# 4  1.0 2021-01-08

# %%
# test_action_performance = df_actions_ppo.merge(df_account_value_ppo)
# test_action_performance.iloc[100:150]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_account_value = pd.DataFrame(df_account_value_ppo.date.unique())
df_account_value.columns = ['date']
df_account_value['account_value'] = df_account_value.apply(lambda x: \
                                    df_account_value_ppo[df_account_value_ppo.date == x.date].iloc[-1].account_value, axis=1)
df_account_value.head()

# df_account_value = pd.DataFrame(df_account_value_ddpg.date.unique())
# df_account_value.columns = ['date']
# df_account_value['account_value'] = df_account_value.apply(lambda x: \
#                                     df_account_value_ddpg[df_account_value_ddpg.date == x.date].iloc[-1].account_value, axis=1)
# df_account_value.head()
# Out:
#         date  account_value
# 0 2021-01-04   1.000000e+06
# 1 2021-01-05   1.011364e+06
# 2 2021-01-06   9.772857e+05
# 3 2021-01-07   1.010668e+06
# 4 2021-01-08   1.019400e+06

# %% [markdown]
# There's a missmatch between the quarterly computation of df_account_value and the daily frequency of the comparison datasets. We need to transform the df_account_value to a daily basis.
# To fill up the missing data, th **ffill** function effectively imputes values, providing the continous picture of account value trends until the next recorded change. However, for the entries preceding the first recorded change, we will use the **initial_amount**.

# %%
daily_account_value = pd.DataFrame(df.date.unique())
daily_account_value.columns = ['date']
daily_account_value['date'] = pd.to_datetime(daily_account_value.date)
daily_account_value = daily_account_value.merge(df_account_value,how='left')
daily_account_value.ffill(inplace=True)
daily_account_value.fillna(env_kwargs["initial_amount"],inplace=True)
daily_account_value = daily_account_value[daily_account_value.date >= TEST_START_DATE]
daily_account_value.reset_index(inplace=True,drop=True)
daily_account_value
# Out:
#           date  account_value
# 0   2021-01-04   1.000000e+06
# 1   2021-01-05   1.011364e+06
# 2   2021-01-06   9.772857e+05
# 3   2021-01-07   1.010668e+06
# 4   2021-01-08   1.019400e+06
# ..         ...            ...
# 835 2024-04-30   1.145744e+06
# 836 2024-05-01   1.137670e+06
# 837 2024-05-02   1.162761e+06
# 838 2024-05-03   1.232386e+06
# 839 2024-05-06   1.232386e+06
#
# [840 rows x 2 columns]

# %%
print("==============Get Backtest Results===========")
# now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

print("\n ppo:")
perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
# perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

# print("\n ddpg:")
# perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
# perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
# perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

# print("\n sac:")
# perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
# perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
#   perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')

#   print("\n atd3:")
#   perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
#   perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
#   perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

#   print("\n a2c:")
#   perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
#   perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
#   perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.064772
# Cumulative returns     0.232386
# Annual volatility      0.265918
# Sharpe ratio           0.368899
# Calmar ratio           0.200098
# Stability              0.383445
# Max drawdown          -0.323699
# Omega ratio            1.066394
# Sortino ratio          0.536929
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.993280
# Daily value at risk   -0.033113
# dtype: float64

# %%
import logging
logging.getLogger('yfinance').setLevel(logging.INFO)

matplotlib.pyplot.set_loglevel (level = 'warning')

import peewee
peewee.debug = False

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# 2024-05-12 22:30:41,076 peewee [DEBUG] - ('CREATE TABLE IF NOT EXISTS "_kv" ("key" VARCHAR(255) NOT NULL PRIMARY KEY, "value" VARCHAR(255)) WITHOUT ROWID', [])
# 2024-05-12 22:30:41,079 peewee [DEBUG] - ('SELECT "t1"."key", "t1"."value" FROM "_kv" AS "t1" WHERE ("t1"."key" = ?) LIMIT ? OFFSET ?', ['^DJI', 1, 0])
# 2024-05-12 22:30:41,142 peewee [DEBUG] - ('CREATE TABLE IF NOT EXISTS "_cookieschema" ("strategy" VARCHAR(255) NOT NULL PRIMARY KEY, "fetch_date" DATETIME NOT NULL, "cookie_bytes" BLOB NOT NULL) WITHOUT ROWID', [])
# 2024-05-12 22:30:41,143 peewee [DEBUG] - ('SELECT "t1"."strategy", "t1"."fetch_date", "t1"."cookie_bytes" FROM "_cookieschema" AS "t1" WHERE ("t1"."strategy" = ?) LIMIT ? OFFSET ?', ['basic', 1, 0])
# 2024-05-12 22:30:41,218 urllib3.connectionpool [DEBUG] - Starting new HTTPS connection (1): fc.yahoo.com:443
# ==============Get Baseline Stats===========
# 2024-05-12 22:30:41,319 urllib3.connectionpool [DEBUG] - https://fc.yahoo.com:443 "GET / HTTP/1.1" 404 4742
# 2024-05-12 22:30:41,322 peewee [DEBUG] - ('DELETE FROM "_cookieschema" WHERE ("_cookieschema"."strategy" = ?)', ['basic'])
# 2024-05-12 22:30:41,325 peewee [DEBUG] - ('BEGIN', None)
# 2024-05-12 22:30:41,327 peewee [DEBUG] - ('INSERT INTO "_cookieschema" ("strategy", "fetch_date", "cookie_bytes") VALUES (?, ?, ?)', ['basic', '2024-05-12T22:30:41.327480', <memory at 0x7fcbc03f0dc0>])
# 2024-05-12 22:30:41,335 urllib3.connectionpool [DEBUG] - Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# 2024-05-12 22:30:41,465 urllib3.connectionpool [DEBUG] - https://query1.finance.yahoo.com:443 "GET /v1/test/getcrumb HTTP/1.1" 200 11
# 2024-05-12 22:30:41,555 urllib3.connectionpool [DEBUG] - Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# 2024-05-12 22:30:41,721 urllib3.connectionpool [DEBUG] - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/%5EDJI?period1=1609477200&period2=1714968000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=DVvnM.AOQYB HTTP/1.1" 200 None
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (839, 8)
# Annual return          0.076873
# Cumulative returns     0.279639
# Annual volatility      0.145603
# Sharpe ratio           0.582123
# Calmar ratio           0.350366
# Stability              0.168146
# Max drawdown          -0.219408
# Omega ratio            1.104132
# Sortino ratio          0.828770
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.980979
# Daily value at risk   -0.018008
# dtype: float64

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTest with DJIA

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

backtest_plot(daily_account_value, 
            baseline_ticker = '^DJI', 
            baseline_start = TEST_START_DATE,
            baseline_end = TEST_END_DATE)
# Out:
# 2024-05-12 22:30:43,030 peewee [DEBUG] - ('SELECT "t1"."key", "t1"."value" FROM "_kv" AS "t1" WHERE ("t1"."key" = ?) LIMIT ? OFFSET ?', ['^DJI', 1, 0])
# [*********************100%%**********************]  1 of 1 completed
# ==============Compare to DJIA===========
# Shape of DataFrame:  (839, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-05-06</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>40</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.469%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>23.239%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.576%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.37</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.20</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-32.37%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.54</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.309%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>32.37</td>
#       <td>2022-08-17</td>
#       <td>2023-01-05</td>
#       <td>2023-06-12</td>
#       <td>214</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25.40</td>
#       <td>2022-01-03</td>
#       <td>2022-06-16</td>
#       <td>2022-08-17</td>
#       <td>163</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20.94</td>
#       <td>2023-06-30</td>
#       <td>2024-04-19</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>17.50</td>
#       <td>2021-01-22</td>
#       <td>2021-03-08</td>
#       <td>2021-07-06</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8.69</td>
#       <td>2021-09-07</td>
#       <td>2021-10-04</td>
#       <td>2021-11-17</td>
#       <td>52</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compare to Buy&Hold Strategy
# pass in df_account_value, this information is stored in env class

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTest with Buy&Hold Strategy

# %%
# print(DOW_30_TICKER)
# test_portfolio = DOW_30_TICKER
test_portfolio = ['AAPL']
modify_fields = ['open','high','low','close']
used_columns = ['date','close']

# %%
#baseline stats
print("==============Get Baseline Stats===========")
shape = daily_account_value.shape
df_hold_ = pd.DataFrame(0,index=range(shape[0]), columns=range(shape[1]))
df_hold_.columns = used_columns
df_hold_['date'] = daily_account_value.date

for stock in test_portfolio:
    df_stock_ = get_baseline(
        ticker=stock, 
        start = TEST_START_DATE,
        end = TEST_END_DATE)
    # for field in modify_fields:
    if len(df_stock_) < len(df_hold_):
        final_row = df_stock_.iloc[-1]
        new_rows = pd.DataFrame([final_row] * (len(df_hold_) - len(df_stock_)))
        df_stock_ = pd.concat([df_stock_, new_rows], ignore_index=True)
        
        for i in range(0,len(df_stock_) < len(df_hold_)):
            df_stock_.iloc[en(df_stock_)] = df_stock_.iloc[len(df_stock_-1)]
    df_stock_['close'] = df_stock_['close']/df_stock_.iloc[0]['close']/len(test_portfolio)
    df_hold_['close'] = df_hold_.close + df_stock_.close

stats = backtest_stats(df_hold_, value_col_name = 'close')
# Out:
# 2024-05-12 22:31:05,261 peewee [DEBUG] - ('SELECT "t1"."key", "t1"."value" FROM "_kv" AS "t1" WHERE ("t1"."key" = ?) LIMIT ? OFFSET ?', ['AAPL', 1, 0])
# 2024-05-12 22:31:05,401 urllib3.connectionpool [DEBUG] - https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/AAPL?period1=1609477200&period2=1714968000&interval=1d&includePrePost=False&events=div%2Csplits%2CcapitalGains&crumb=DVvnM.AOQYB HTTP/1.1" 200 None
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (839, 8)
# Annual return          0.116509
# Cumulative returns     0.443913
# Annual volatility      0.274100
# Sharpe ratio           0.539295
# Calmar ratio           0.376896
# Stability              0.568681
# Max drawdown          -0.309128
# Omega ratio            1.095313
# Sortino ratio          0.789072
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.971789
# Daily value at risk   -0.033947
# dtype: float64

# %% [markdown]
# The model' calculation encompass the entire timeframe, including non-working days. To address this, we need to determine the most appropriate method to fill up the weekend plots, for example backfilling.

# %%
df_hold = pd.DataFrame()
df_hold['date'] = daily_account_value['date']
df_hold['hold'] = df_hold_['close'] / df_hold_['close'][0] * env_kwargs["initial_amount"]
# print("df_hold: ", df_hold)
# df_dji.to_csv("df_dji.csv")
df_hold = df_hold.set_index(df_hold.columns[0])
print("df_hold: ", df_hold)
# df_hold.to_csv("df_dji+.csv")

# df_account_value.to_csv('df_account_value.csv')
# Out:
# df_hold:                      hold
# date
# 2021-01-04  1.000000e+06
# 2021-01-05  1.012363e+06
# 2021-01-06  9.782858e+05
# 2021-01-07  1.011668e+06
# 2021-01-08  1.020400e+06
# ...                  ...
# 2024-04-30  1.341159e+06
# 2024-05-01  1.333049e+06
# 2024-05-02  1.362418e+06
# 2024-05-03  1.443913e+06
# 2024-05-06  1.443913e+06
#
# [840 rows x 1 columns]

# %%
print("==============Compare to Buy&Hold===========")
df_result = pd.DataFrame({'date': df_account_value_ppo['date'], 'stock': df_account_value_ppo['account_value']})
df_result = df_result.set_index('date')

result = pd.DataFrame()
result = pd.merge(df_result, df_hold, left_index=True, right_index=True)
print("result: ", result)
# result.to_csv("result.csv")
result.columns = ['model', 'buy_and_hold']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# ==============Compare to Buy&Hold===========
# result:                     stock          hold
# date
# 2021-01-04  1.000000e+06  1.000000e+06
# 2021-01-05  1.011364e+06  1.012363e+06
# 2021-01-06  9.772857e+05  9.782858e+05
# 2021-01-07  1.010668e+06  1.011668e+06
# 2021-01-08  1.019400e+06  1.020400e+06
# ...                  ...           ...
# 2024-04-29  1.145744e+06  1.366119e+06
# 2024-04-30  1.145744e+06  1.341159e+06
# 2024-05-01  1.137670e+06  1.333049e+06
# 2024-05-02  1.162761e+06  1.362418e+06
# 2024-05-03  1.232386e+06  1.443913e+06
#
# [839 rows x 2 columns]

# %% [markdown]
# <a id='7'></a>
# # 8. Save and load model #

# %% [markdown]
# <a id='7.1'></a>
# ## 8.1 Save model

# %% [markdown]
# ### 8.1.1 Save trained model

# %%
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/main_dow30_oneTic_filter_3hiden_ppo11_23m_steps"
model_name
# Out:
# './trained_models/main_dow30_oneTic_filter_3hiden_ppo11_23m_steps'

# %%
trained_ppo.save(model_name)

# %% [markdown]
# ### 8.1.2 Save model as ONNX file

# %%
import torch as th
import torch.onnx
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import DDPG
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(trained_ppo.policy)
observation_size = trained_ppo.observation_space.shape
dummy_input = th.randn(1, *observation_size)

# th.onnx.export(
#     onnx_policy,
#     dummy_input,
#     "main_dow30_randomTic_discrete_shortSell_256neu_ppo_4m_steps.onnx",
#     opset_version=17,
#     input_names=["input"],
# )

# %%
onnx_policy
# Out:
# OnnxableSB3Policy(
#   (policy): ActorCriticPolicy(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (pi_features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (vf_features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (mlp_extractor): MlpExtractor(
#       (policy_net): Sequential(
#         (0): Linear(in_features=19, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=256, out_features=256, bias=True)
#         (3): Tanh()
#       )
#       (value_net): Sequential(
#         (0): Linear(in_features=19, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=256, out_features=256, bias=True)
#         (3): Tanh()
#       )
#     )
#     (action_net): Linear(in_features=256, out_features=3, bias=True)
#     (value_net): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# <a id='7.2'></a>
# ## 8.2 Load model

# %% [markdown]
# <a id='7.2.1'></a>
# ### 8.2.1 Load trained model

# %%
from stable_baselines3 import PPO
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/main_dow30_oneTic_filter_3hiden_ppo11_23m_steps"
model_name
# Out:
# './trained_models/main_dow30_oneTic_filter_3hiden_ppo11_23m_steps'

# %%
trained_model = PPO.load(model_name)

# %% [markdown]
# Continous training based on the previous model at [**Part5. Train DRL Agents**](#5)

# %%
# #Establish the training environment using StockTradingEnv() class
# agent = DRLAgent(env = env_train)
# trained_model.env = env_train

# %%
# trained_ppo = agent.train_model(model=trained_model, 
#                              tb_log_name='ppo',
#                              total_timesteps=total_training_step)

# %% [markdown]
# #### Test loaded model

# %%
test_env = StockTradingEnv(df = trade_data, **env_kwargs)

# %%
test_step = 1000
test_result = []
test_env.reset()
for i in range(0,test_step):
    observation = [test_env.state]
    observation = np.array(observation).astype(np.float32)
    actions, values, log_prob = ort_sess.run(None, {"input": observation})
    result = test_env.step(actions)
    test_result.append(result[1])
    if result[2] == True:
        break

# %% [markdown]
# ### 8.2.2 Load ONNX model

# %%
import onnx
import onnxruntime as ort
import numpy as np

# %%
onnx_path = "all_in_one_ppo.onnx"
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)

# # Check that the predictions are the same
# with th.no_grad():
#     print(model.policy(th.as_tensor(observation), deterministic=True))

# %%
observation = np.zeros((1, state_space)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
actions, values, log_prob = ort_sess.run(None, {"input": observation})
print(actions, values, log_prob)
