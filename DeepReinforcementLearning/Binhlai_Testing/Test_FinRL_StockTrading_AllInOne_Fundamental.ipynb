# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: All_In_One

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. Set up the training environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Train DRL Agent](#5)
# * [7.Backtest Our Strategy](#6)
#     * [7.1. BackTest with DJIA](#6.1)
#     * [7.2. BackTest with Buy&Hold Strategy](#6.2)
# * [8.Save PPO model as ONNX file](#7)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import math
from stable_baselines3.common.logger import configure

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# 2024-03-05 08:57:31.724795: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2019-01-01'
TEST_START_DATE = '2019-01-01'
TEST_END_DATE = '2021-01-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (88061, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.743889  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  42.406399    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.144921   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941093    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  30.950016    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
df.tail()
# Out:
#              date        open        high         low       close    volume  \
# 88056  2020-12-31  345.040009  351.089996  344.049988  336.380615   1969000
# 88057  2020-12-31  218.399994  219.820007  216.199997  213.664185   5922200
# 88058  2020-12-31   58.060001   58.799999   58.020000   48.816616  12906300
# 88059  2020-12-31   39.330002   40.000000   39.029999   33.866371   7696000
# 88060  2020-12-31   48.066666   48.090000   47.616669   45.866272  17814000
#
#        tic  day
# 88056  UNH    3
# 88057    V    3
# 88058   VZ    3
# 88059  WBA    3
# 88060  WMT    3

# %%
df.shape
# Out:
# (88061, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.743889  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  42.406399    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.144921   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941093    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  30.950016    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# tic
# AAPL    3021
# AMGN    3021
# WMT     3021
# WBA     3021
# VZ      3021
# V       3021
# UNH     3021
# TRV     3021
# PG      3021
# NKE     3021
# MSFT    3021
# MRK     3021
# MMM     3021
# MCD     3021
# KO      3021
# JPM     3021
# JNJ     3021
# INTC    3021
# IBM     3021
# HON     3021
# HD      3021
# GS      3021
# DIS     3021
# CVX     3021
# CSCO    3021
# CRM     3021
# CAT     3021
# BA      3021
# AXP     3021
# DOW      452
# Name: count, dtype: int64

# %% [markdown]
# <a id='3'></a>
# # Part 4: Preprocess fundamental data
# - Import finanical data downloaded from Compustat via WRDS(Wharton Research Data Service)
# - Preprocess the dataset and calculate financial ratios
# - Add those ratios to the price data preprocessed in Part 3
# - Calculate price-related ratios such as P/E and P/B

# %% [markdown]
# <a id='3.1'></a>
# ## 4.1 Import the financial data

# %%
# Import fundamental data from my GitHub repository
url = 'https://raw.githubusercontent.com/mariko-sawada/FinRL_with_fundamental_data/main/dow_30_fundamental_wrds.csv'

fund = pd.read_csv(url)

# %%
# Check the imported dataset
fund.head()
# Out:
#    gvkey  datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt  tic  ...  \
# 0   1447  19990630    1999     2   12   INDL      C      D     STD  AXP  ...
# 1   1447  19990930    1999     3   12   INDL      C      D     STD  AXP  ...
# 2   1447  19991231    1999     4   12   INDL      C      D     STD  AXP  ...
# 3   1447  20000331    2000     1   12   INDL      C      D     STD  AXP  ...
# 4   1447  20000630    2000     2   12   INDL      C      D     STD  AXP  ...
#
#   dvpsxq mkvaltq     prccq     prchq     prclq  adjex ggroup    gind gsector  \
# 0  0.225     NaN  130.1250  142.6250  114.5000    3.0   4020  402020      40
# 1  0.000     NaN  135.0000  150.6250  121.8750    3.0   4020  402020      40
# 2  0.225     NaN  166.2500  168.8750  130.2500    3.0   4020  402020      40
# 3  0.225     NaN  148.9375  169.5000  119.5000    3.0   4020  402020      40
# 4  0.080     NaN   52.1250   57.1875   43.9375    1.0   4020  402020      40
#
#     gsubind
# 0  40202010
# 1  40202010
# 2  40202010
# 3  40202010
# 4  40202010
#
# [5 rows x 647 columns]

# %%
fund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2456 entries, 0 to 2455
# Columns: 647 entries, gvkey to gsubind
# dtypes: float64(617), int64(12), object(18)
# memory usage: 12.1+ MB

# %% [markdown]
# <a id='3.2'></a>
# ## 4.2 Specify items needed to calculate financial ratios
# - To learn more about the data description of the dataset, please check WRDS's website(https://wrds-www.wharton.upenn.edu/). Login will be required.

# %%
# List items that are used to calculate financial ratios

items = [
    'datadate', # Date
    'tic', # Ticker
    'oiadpq', # Quarterly operating income
    'revtq', # Quartely revenue
    'niq', # Quartely net income
    'atq', # Total asset
    'teqq', # Shareholder's equity
    'epspiy', # EPS(Basic) incl. Extraordinary items
    'ceqq', # Common Equity
    'cshoq', # Common Shares Outstanding
    'dvpspq', # Dividends per share
    'actq', # Current assets
    'lctq', # Current liabilities
    'cheq', # Cash & Equivalent
    'rectq', # Recievalbles
    'cogsq', # Cost of  Goods Sold
    'invtq', # Inventories
    'apq',# Account payable
    'dlttq', # Long term debt
    'dlcq', # Debt in current liabilites
    'ltq' # Liabilities   
]

# Omit items that will not be used
fund_data = fund[items]

# %%
# Rename column names for the sake of readability
fund_data = fund_data.rename(columns={
    'datadate':'date', # Date
    'oiadpq':'op_inc_q', # Quarterly operating income
    'revtq':'rev_q', # Quartely revenue
    'niq':'net_inc_q', # Quartely net income
    'atq':'tot_assets', # Assets
    'teqq':'sh_equity', # Shareholder's equity
    'epspiy':'eps_incl_ex', # EPS(Basic) incl. Extraordinary items
    'ceqq':'com_eq', # Common Equity
    'cshoq':'sh_outstanding', # Common Shares Outstanding
    'dvpspq':'div_per_sh', # Dividends per share
    'actq':'cur_assets', # Current assets
    'lctq':'cur_liabilities', # Current liabilities
    'cheq':'cash_eq', # Cash & Equivalent
    'rectq':'receivables', # Receivalbles
    'cogsq':'cogs_q', # Cost of  Goods Sold
    'invtq':'inventories', # Inventories
    'apq': 'payables',# Account payable
    'dlttq':'long_debt', # Long term debt
    'dlcq':'short_debt', # Debt in current liabilites
    'ltq':'tot_liabilities' # Liabilities   
})

# %%
# Check the data
fund_data.date = pd.to_datetime(fund_data['date'],format='%Y%m%d')
fund_data.sort_values('date')
fund_data.head()
# Out:
#         date  tic  op_inc_q   rev_q  net_inc_q  tot_assets  sh_equity  \
# 0 1999-06-30  AXP     896.0  5564.0      646.0    132452.0     9762.0
# 1 1999-09-30  AXP     906.0  5584.0      648.0    132616.0     9744.0
# 2 1999-12-31  AXP     845.0  6009.0      606.0    148517.0    10095.0
# 3 2000-03-31  AXP     920.0  6021.0      656.0    150662.0    10253.0
# 4 2000-06-30  AXP    1046.0  6370.0      740.0    148553.0    10509.0
#
#    eps_incl_ex   com_eq  sh_outstanding  ...  cur_assets  cur_liabilities  \
# 0         2.73   9762.0           449.0  ...         NaN              NaN
# 1         4.18   9744.0           447.6  ...         NaN              NaN
# 2         5.54  10095.0           446.9  ...         NaN              NaN
# 3         1.48  10253.0           444.7  ...         NaN              NaN
# 4         1.05  10509.0          1333.0  ...         NaN              NaN
#
#    cash_eq  receivables  cogs_q  inventories  payables  long_debt  short_debt  \
# 0   6096.0      46774.0  4668.0        448.0   22282.0     7005.0     24785.0
# 1   5102.0      48827.0  4678.0        284.0   23587.0     6720.0     24683.0
# 2  10391.0      54033.0  5164.0        277.0   25719.0     4685.0     32437.0
# 3   7425.0      53663.0  5101.0        315.0   26379.0     5670.0     29342.0
# 4   6841.0      54286.0  5324.0        261.0   29536.0     5336.0     26170.0
#
#    tot_liabilities
# 0         122690.0
# 1         122872.0
# 2         138422.0
# 3         140409.0
# 4         138044.0
#
# [5 rows x 21 columns]

# %%
fund_data.bfill(inplace=True)

# %%
fund_data
# Out:
#            date  tic  op_inc_q   rev_q  net_inc_q  tot_assets  sh_equity  \
# 0    1999-06-30  AXP     896.0  5564.0      646.0    132452.0     9762.0
# 1    1999-09-30  AXP     906.0  5584.0      648.0    132616.0     9744.0
# 2    1999-12-31  AXP     845.0  6009.0      606.0    148517.0    10095.0
# 3    2000-03-31  AXP     920.0  6021.0      656.0    150662.0    10253.0
# 4    2000-06-30  AXP    1046.0  6370.0      740.0    148553.0    10509.0
# ...         ...  ...       ...     ...        ...         ...        ...
# 2451 2020-03-31    V    3937.0  5854.0     3084.0     72820.0    34585.0
# 2452 2020-06-30    V    3004.0  4837.0     2373.0     77884.0    35524.0
# 2453 2020-09-30    V    3150.0  5101.0     2137.0     80919.0    36210.0
# 2454 2020-12-31    V    3848.0  5687.0     3126.0     80426.0    37679.0
# 2455 2021-03-31    V    3741.0  5729.0     3026.0     80195.0    37696.0
#
#       eps_incl_ex   com_eq  sh_outstanding  ...  cur_assets  cur_liabilities  \
# 0            2.73   9762.0           449.0  ...      4298.0           1539.0
# 1            4.18   9744.0           447.6  ...      4298.0           1539.0
# 2            5.54  10095.0           446.9  ...      4298.0           1539.0
# 3            1.48  10253.0           444.7  ...      4298.0           1539.0
# 4            1.05  10509.0          1333.0  ...      4298.0           1539.0
# ...           ...      ...             ...  ...         ...              ...
# 2451         2.85  29123.0          2134.0  ...     19907.0          15942.0
# 2452         3.92  30226.0          2128.0  ...     25011.0          16100.0
# 2453         4.90  31124.0          2124.0  ...     27645.0          14510.0
# 2454         1.42  33996.0          2137.0  ...     26280.0          12390.0
# 2455         2.80  34349.0          2135.0  ...     26901.0          12711.0
#
#       cash_eq  receivables  cogs_q  inventories  payables  long_debt  \
# 0      6096.0      46774.0  4668.0        448.0   22282.0     7005.0
# 1      5102.0      48827.0  4678.0        284.0   23587.0     6720.0
# 2     10391.0      54033.0  5164.0        277.0   25719.0     4685.0
# 3      7425.0      53663.0  5101.0        315.0   26379.0     5670.0
# 4      6841.0      54286.0  5324.0        261.0   29536.0     5336.0
# ...       ...          ...     ...          ...       ...        ...
# 2451  15227.0       2948.0  1725.0          0.0    2030.0    13893.0
# 2452  19673.0       3564.0  1636.0          0.0    2878.0    17880.0
# 2453  22923.0       2975.0  1755.0          0.0    1910.0    21071.0
# 2454  21064.0       3342.0  1642.0          0.0    2179.0    21055.0
# 2455  21616.0       3225.0  1787.0          0.0    2126.0    20974.0
#
#       short_debt  tot_liabilities
# 0        24785.0         122690.0
# 1        24683.0         122872.0
# 2        32437.0         138422.0
# 3        29342.0         140409.0
# 4        26170.0         138044.0
# ...          ...              ...
# 2451      3999.0          38235.0
# 2452      2999.0          42360.0
# 2453      2999.0          44709.0
# 2454         0.0          42747.0
# 2455         0.0          42499.0
#
# [2456 rows x 21 columns]

# %% [markdown]
# <a id='3.3'></a>
# ## 4.3 Calculate financial ratios
# - For items from Profit/Loss statements, we calculate LTM (Last Twelve Months) and use them to derive profitability related ratios such as Operating Maring and ROE. For items from balance sheets, we use the numbers on the day.
# - To check the definitions of the financial ratios calculated here, please refer to CFI's website: https://corporatefinanceinstitute.com/resources/knowledge/finance/financial-ratios/

# %%
# Calculate financial ratios
date = pd.to_datetime(fund_data['date'],format='%Y%m%d')

tic = fund_data['tic'].to_frame('tic')

# Profitability ratios
# Operating Margin
OPM = (fund_data['op_inc_q']/fund_data['rev_q']).to_frame('OPM')

# Net Profit Margin        
NPM = (fund_data['net_inc_q']/fund_data['rev_q']).to_frame('NPM')

# Return On Assets
ROA = (fund_data['net_inc_q']/fund_data['tot_assets']).to_frame('ROA')

# Return on Equity
ROE = (fund_data['net_inc_q']/fund_data['sh_equity']).to_frame('ROE')

# For calculating valuation ratios in the next subpart, calculate per-share items in advance
# Earnings Per Share       
EPS = fund_data['eps_incl_ex'].to_frame('EPS')

# Book Per Share
BPS = (fund_data['com_eq']/fund_data['sh_outstanding']).to_frame('BPS')

#Dividend Per Share
DPS = fund_data['div_per_sh'].to_frame('DPS')

# Liquidity ratios
# Current ratio
cur_ratio = (fund_data['cur_assets']/fund_data['cur_liabilities']).to_frame('cur_ratio')

# Quick ratio
quick_ratio = ((fund_data['cash_eq'] + fund_data['receivables'] )/fund_data['cur_liabilities']).to_frame('quick_ratio')

# Cash ratio
cash_ratio = (fund_data['cash_eq']/fund_data['cur_liabilities']).to_frame('cash_ratio')


# Efficiency ratios
# Inventory turnover ratio
inv_turnover = (fund_data['cogs_q']/fund_data['inventories']).to_frame('inv_turnover')

# Receivables turnover ratio       
acc_rec_turnover = (fund_data['rev_q']/fund_data['receivables']).to_frame('acc_rec_turnover')

# Payable turnover ratio
acc_pay_turnover = (fund_data['cogs_q']/fund_data['payables']).to_frame('acc_pay_turnover')
        
## Leverage financial ratios
# Debt ratio
debt_ratio = (fund_data['tot_liabilities']/fund_data['tot_assets']).to_frame('debt_ratio')

# Debt to Equity ratio
debt_to_equity = (fund_data['tot_liabilities']/fund_data['sh_equity']).to_frame('debt_to_equity')

# %%
# Create a dataframe that merges all the ratios
ratios = pd.concat([date,tic,OPM,NPM,ROA,ROE,EPS,BPS,DPS,
                    cur_ratio,quick_ratio,cash_ratio,inv_turnover,acc_rec_turnover,acc_pay_turnover,
                   debt_ratio,debt_to_equity], axis=1)

# %%
# Check the ratio data
ratios.head()
# Out:
#         date  tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 0 1999-06-30  AXP  0.161035  0.116104  0.004877  0.066175  2.73  21.741648
# 1 1999-09-30  AXP  0.162249  0.116046  0.004886  0.066502  4.18  21.769437
# 2 1999-12-31  AXP  0.140622  0.100849  0.004080  0.060030  5.54  22.588946
# 3 2000-03-31  AXP  0.152799  0.108952  0.004354  0.063981  1.48  23.055993
# 4 2000-06-30  AXP  0.164207  0.116170  0.004981  0.070416  1.05   7.883721
#
#      DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  acc_rec_turnover  \
# 0  0.225   2.792723    34.353476    3.961014     10.419643          0.118955
# 1  0.225   2.792723    35.041585    3.315140     16.471831          0.114363
# 2  0.225   2.792723    41.860949    6.751787     18.642599          0.111210
# 3  0.225   2.792723    39.693307    4.824561     16.193651          0.112200
# 4  0.080   2.792723    39.718648    4.445094     20.398467          0.117341
#
#    acc_pay_turnover  debt_ratio  debt_to_equity
# 0          0.209496    0.926298       12.568121
# 1          0.198330    0.926525       12.610016
# 2          0.200785    0.932028       13.711937
# 3          0.193374    0.931947       13.694431
# 4          0.180255    0.929258       13.135788

# %%
ratios.tail()
# Out:
#            date tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 2451 2020-03-31   V  0.672532  0.526819  0.042351  0.089172  2.85  13.647142
# 2452 2020-06-30   V  0.621046  0.490593  0.030468  0.066800  3.92  14.203947
# 2453 2020-09-30   V  0.617526  0.418937  0.026409  0.059017  4.90  14.653484
# 2454 2020-12-31   V  0.676631  0.549675  0.038868  0.082964  1.42  15.908283
# 2455 2021-03-31   V  0.652994  0.528190  0.037733  0.080274  2.80  16.088525
#
#        DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  \
# 2451  0.30   1.248714     1.140070    0.955150           inf
# 2452  0.30   1.553478     1.443292    1.221925           inf
# 2453  0.30   1.905238     1.784838    1.579807           inf
# 2454  0.32   2.121065     1.969814    1.700081           inf
# 2455  0.32   2.116356     1.954292    1.700574           inf
#
#       acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity
# 2451          1.985753          0.849754    0.525062        1.105537
# 2452          1.357183          0.568450    0.543886        1.192433
# 2453          1.714622          0.918848    0.552515        1.234714
# 2454          1.701676          0.753557    0.531507        1.134505
# 2455          1.776434          0.840546    0.529946        1.127414

# %% [markdown]
# <a id='3.4'></a>
# ## 4.4 Deal with NAs and infinite values
# After our initial inspection, we’ll want to dig deeper to investigate the following:
# - The data type of each variable.
# - How discrete/categorical data is coded (and whether we need to make any changes).
# - How the data are scaled.
# - Whether there is missing data and how it is coded.
# - Whether there are outliers.
# - The distributions of continuous features.
# - The relationships between pairs of features.

# %% [markdown]
# ### Data types
# It is important to check the data type for each feature.
# The ratios should be read in as float64 — and categorical variables should be stored as object

# %%
ratios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2456 entries, 0 to 2455
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2456 non-null   datetime64[ns]
#  1   tic               2456 non-null   object
#  2   OPM               2456 non-null   float64
#  3   NPM               2456 non-null   float64
#  4   ROA               2456 non-null   float64
#  5   ROE               2456 non-null   float64
#  6   EPS               2456 non-null   float64
#  7   BPS               2456 non-null   float64
#  8   DPS               2456 non-null   float64
#  9   cur_ratio         2456 non-null   float64
#  10  quick_ratio       2456 non-null   float64
#  11  cash_ratio        2456 non-null   float64
#  12  inv_turnover      2456 non-null   float64
#  13  acc_rec_turnover  2456 non-null   float64
#  14  acc_pay_turnover  2456 non-null   float64
#  15  debt_ratio        2456 non-null   float64
#  16  debt_to_equity    2456 non-null   float64
# dtypes: datetime64[ns](1), float64(15), object(1)
# memory usage: 326.3+ KB

# %%
ratios.isna().sum()
# Out:
# date                0
# tic                 0
# OPM                 0
# NPM                 0
# ROA                 0
# ROE                 0
# EPS                 0
# BPS                 0
# DPS                 0
# cur_ratio           0
# quick_ratio         0
# cash_ratio          0
# inv_turnover        0
# acc_rec_turnover    0
# acc_pay_turnover    0
# debt_ratio          0
# debt_to_equity      0
# dtype: int64

# %% [markdown]
# We see that there is no missing values in all ratios

# %%
ratios.dtypes
# Out:
# date                datetime64[ns]
# tic                         object
# OPM                        float64
# NPM                        float64
# ROA                        float64
# ROE                        float64
# EPS                        float64
# BPS                        float64
# DPS                        float64
# cur_ratio                  float64
# quick_ratio                float64
# cash_ratio                 float64
# inv_turnover               float64
# acc_rec_turnover           float64
# acc_pay_turnover           float64
# debt_ratio                 float64
# debt_to_equity             float64
# dtype: object

# %% [markdown]
# Since we have both continuous (float64) and categorical (object) variables in our data, it might be informative to look at the number of unique values in each column using the nunique() function.

# %%
ratios.nunique()
# Out:
# date                 263
# tic                   29
# OPM                 2452
# NPM                 2451
# ROA                 2450
# ROE                 2442
# EPS                  789
# BPS                 2442
# DPS                  203
# cur_ratio           2092
# quick_ratio         2443
# cash_ratio          2442
# inv_turnover        2174
# acc_rec_turnover    2452
# acc_pay_turnover    2450
# debt_ratio          2443
# debt_to_equity      2442
# dtype: int64

# %%
# Replace NAs infinite values with zero
final_ratios = ratios.copy()
final_ratios = final_ratios.fillna(0)
final_ratios = final_ratios.replace(np.inf,0)

# %%
final_ratios.head()
# Out:
#         date  tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 0 1999-06-30  AXP  0.161035  0.116104  0.004877  0.066175  2.73  21.741648
# 1 1999-09-30  AXP  0.162249  0.116046  0.004886  0.066502  4.18  21.769437
# 2 1999-12-31  AXP  0.140622  0.100849  0.004080  0.060030  5.54  22.588946
# 3 2000-03-31  AXP  0.152799  0.108952  0.004354  0.063981  1.48  23.055993
# 4 2000-06-30  AXP  0.164207  0.116170  0.004981  0.070416  1.05   7.883721
#
#      DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  acc_rec_turnover  \
# 0  0.225   2.792723    34.353476    3.961014     10.419643          0.118955
# 1  0.225   2.792723    35.041585    3.315140     16.471831          0.114363
# 2  0.225   2.792723    41.860949    6.751787     18.642599          0.111210
# 3  0.225   2.792723    39.693307    4.824561     16.193651          0.112200
# 4  0.080   2.792723    39.718648    4.445094     20.398467          0.117341
#
#    acc_pay_turnover  debt_ratio  debt_to_equity
# 0          0.209496    0.926298       12.568121
# 1          0.198330    0.926525       12.610016
# 2          0.200785    0.932028       13.711937
# 3          0.193374    0.931947       13.694431
# 4          0.180255    0.929258       13.135788

# %%
final_ratios.tail()
# Out:
#            date tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 2451 2020-03-31   V  0.672532  0.526819  0.042351  0.089172  2.85  13.647142
# 2452 2020-06-30   V  0.621046  0.490593  0.030468  0.066800  3.92  14.203947
# 2453 2020-09-30   V  0.617526  0.418937  0.026409  0.059017  4.90  14.653484
# 2454 2020-12-31   V  0.676631  0.549675  0.038868  0.082964  1.42  15.908283
# 2455 2021-03-31   V  0.652994  0.528190  0.037733  0.080274  2.80  16.088525
#
#        DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  \
# 2451  0.30   1.248714     1.140070    0.955150           0.0
# 2452  0.30   1.553478     1.443292    1.221925           0.0
# 2453  0.30   1.905238     1.784838    1.579807           0.0
# 2454  0.32   2.121065     1.969814    1.700081           0.0
# 2455  0.32   2.116356     1.954292    1.700574           0.0
#
#       acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity
# 2451          1.985753          0.849754    0.525062        1.105537
# 2452          1.357183          0.568450    0.543886        1.192433
# 2453          1.714622          0.918848    0.552515        1.234714
# 2454          1.701676          0.753557    0.531507        1.134505
# 2455          1.776434          0.840546    0.529946        1.127414

# %% [markdown]
# <a id='3.5'></a>
# ## 4.5 Merge stock price data and ratios into one dataframe
# - Merge the price dataframe preprocessed in Part 3 and the ratio dataframe created in this part
# - Since the prices are daily and ratios are quartely, we have NAs in the ratio columns after merging the two dataframes. We deal with this by backfilling the ratios.

# %%
df['date'] = pd.to_datetime(df.date)
list_ticker = df["tic"].unique().tolist()
list_date = list(pd.date_range(df['date'].min(),df['date'].max()))
combination = list(itertools.product(list_date,list_ticker))

# Merge stock price data and ratios into one dataframe
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(df,on=["date","tic"],how="left")
processed_full = processed_full.merge(final_ratios,how='left',on=['date','tic'])
processed_full = processed_full.sort_values(['tic','date'])

# Backfill the ratio data to make them daily
processed_full = processed_full.bfill(axis='rows')

# %% [markdown]
# <a id='3.6'></a>
# ## 4.6 Calculate market valuation ratios using daily stock price data

# %%
# Calculate P/E, P/B and dividend yield using daily closing price
processed_full['PE'] = processed_full['close']/processed_full['EPS']
processed_full['PB'] = processed_full['close']/processed_full['BPS']
processed_full['Div_yield'] = processed_full['DPS']/processed_full['close']

# Drop per share items used for the above calculation
processed_full = processed_full.drop(columns=['day','EPS','BPS','DPS'])
# Replace NAs infinite values with zero
processed_full = processed_full.copy()
processed_full = processed_full.fillna(0)
processed_full = processed_full.replace(np.inf,0)

# %%
processed_full = processed_full[processed_full.date.isin(final_ratios.date)]

# %%
# Check the final data
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#         date   tic       open       high        low      close       volume  \
# 0 2009-01-31  AAPL   3.182143   3.285714   3.175000   2.766868  558247200.0
# 1 2009-01-31  AMGN  54.430000  55.709999  54.299999  39.796875    7060400.0
# 2 2009-01-31   AXP  16.350000  17.120001  16.070000  13.418340   14544600.0
# 3 2009-01-31    BA  41.730000  41.730000  40.110001  30.603237    8107400.0
# 4 2009-01-31   CAT  30.100000  30.799999  29.600000  20.200163   16966700.0
# 5 2009-01-31   CRM   6.625000   6.715000   6.487500   6.660000    9271200.0
# 6 2009-01-31  CSCO  14.860000  15.460000  14.830000  10.467290   55290500.0
# 7 2009-01-31   CVX  69.519997  70.849998  69.120003  38.525234   12445000.0
# 8 2009-01-31   DIS  20.080000  20.500000  19.840000  17.337706   16499500.0
# 9 2009-01-31   DOW  52.750000  53.500000  49.500000  38.225899    2350800.0
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.255724  0.178336  0.037468  ...     2.039779    1.818995     16.910256
# 1  0.095047  0.067428  0.003606  ...    57.359324   13.513320      0.000000
# 2  0.095047  0.067428  0.003606  ...    57.359324   13.513320      0.000000
# 3  0.063204  0.036965  0.011023  ...     0.368463    0.148507      0.850789
# 4  0.161084 -0.012141 -0.001738  ...     0.890488    0.163158      0.812437
# 5  0.195071  0.165475  0.024512  ...     2.498162    2.170759      2.779584
# 6  0.195071  0.165475  0.024512  ...     2.498162    2.170759      2.779584
# 7  0.061614  0.055537  0.011523  ...     0.952878    0.373760      4.171437
# 8  0.159144  0.075801  0.009725  ...     0.815629    0.330748      3.235830
# 9  0.537326  0.403438  0.054307  ...     1.236512    0.524199      4.769523
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity          PE  \
# 0          2.992095          1.326962    0.437727        0.778495    0.636062
# 1          0.096045          0.176988    0.869784        6.679531  128.377016
# 2          0.096045          0.176988    0.869784        6.679531   43.284967
# 3          2.503717          0.758503    1.009198     -109.722986   35.176135
# 4          0.574194          1.944012    0.893715        9.089489 -106.316647
# 5          2.040638          4.923200    0.400215        0.667591   10.571428
# 6          2.040638          4.923200    0.400215        0.667591   16.614746
# 7          2.294464          1.966557    0.449174        0.815455   41.875255
# 8          1.637376          1.226549    0.455848        0.837721   21.946463
# 9          1.192136          7.771188    0.657544        1.920085  166.199560
#
#           PB  Div_yield
# 0   0.101510   0.000000
# 1   3.685597   0.004523
# 2   1.242675   0.013414
# 3 -32.235194   0.013724
# 4   1.949734   0.020792
# 5   1.058126   0.000000
# 6   1.663019   0.000000
# 7   0.884524   0.016872
# 8   0.948227   0.020187
# 9   1.781531   0.000000
#
# [10 rows x 22 columns]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %% [markdown]
# <a id='4.1'></a>
# ## 5.1 Training & Trade Data Split
# - Training data period: 2009-01-01 to 2019-01-01
# - Trade data period: 2019-01-01 to 2020-12-31

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(trade_data))
# Out:
# 3600
# 720

# %%
train_data = train_data.reset_index(drop=True)
train_data
# Out:
#            date   tic        open        high         low       close  \
# 0    2009-01-31  AAPL    3.182143    3.285714    3.175000    2.766868
# 1    2009-01-31  AMGN   54.430000   55.709999   54.299999   39.796875
# 2    2009-01-31   AXP   16.350000   17.120001   16.070000   13.418340
# 3    2009-01-31    BA   41.730000   41.730000   40.110001   30.603237
# 4    2009-01-31   CAT   30.100000   30.799999   29.600000   20.200163
# ...         ...   ...         ...         ...         ...         ...
# 3595 2018-12-31   UNH  248.059998  250.279999  246.940002  231.183182
# 3596 2018-12-31     V  131.679993  132.440002  130.229996  127.279045
# 3597 2018-12-31    VZ   55.529999   56.230000   55.070000   42.939342
# 3598 2018-12-31   WBA   68.540001   68.720001   67.739998   53.873112
# 3599 2018-12-31   WMT   30.889999   31.129999   30.750000   28.573530
#
#            volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0     558247200.0  0.255724  0.178336  0.037468  ...     2.039779    1.818995
# 1       7060400.0  0.095047  0.067428  0.003606  ...    57.359324   13.513320
# 2      14544600.0  0.095047  0.067428  0.003606  ...    57.359324   13.513320
# 3       8107400.0  0.063204  0.036965  0.011023  ...     0.368463    0.148507
# 4      16966700.0  0.161084 -0.012141 -0.001738  ...     0.890488    0.163158
# ...           ...       ...       ...       ...  ...          ...         ...
# 3595    3123200.0  0.076981  0.052040  0.019971  ...     0.612190    0.269203
# 3596    7976000.0  0.676353  0.540683  0.041546  ...     1.426843    1.088655
# 3597   15331800.0  0.211050  0.056562  0.007322  ...     0.781730    0.099974
# 3598    4870900.0  0.048685  0.033480  0.016413  ...     0.349247    0.039877
# 3599   21017400.0  0.043756  0.026565  0.016813  ...     0.180763    0.099668
#
#       inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0        16.910256          2.992095          1.326962    0.437727
# 1         0.000000          0.096045          0.176988    0.869784
# 2         0.000000          0.096045          0.176988    0.869784
# 3         0.850789          2.503717          0.758503    1.009198
# 4         0.812437          0.574194          1.944012    0.893715
# ...            ...               ...               ...         ...
# 3595      0.000000          3.200932          1.218166    0.630623
# 3596      0.000000          1.215989          0.404335    0.524178
# 3597     11.445359          1.325689          2.114353    0.793414
# 3598      2.574443          4.410833          1.828199    0.639194
# 3599      2.308071         22.090244          2.171186    0.636864
#
#       debt_to_equity          PE         PB  Div_yield
# 0           0.778495    0.636062   0.101510   0.000000
# 1           6.679531  128.377016   3.685597   0.004523
# 2           6.679531   43.284967   1.242675   0.013414
# 3        -109.722986   35.176135 -32.235194   0.013724
# 4           9.089489 -106.316647   1.949734   0.020792
# ...              ...         ...        ...        ...
# 3595        1.767227   18.568930   4.293095   0.003893
# 3596        1.101628   97.906958   9.784540   0.001964
# 3597        3.840596   11.420038   3.338541   0.014031
# 3598        1.771574   22.170005   1.988272   0.008167
# 3599        1.753786   12.532250   1.134333   0.018199
#
# [3600 rows x 22 columns]

# %%
trade_data = trade_data.reset_index(drop=True)
trade_data
# Out:
#           date   tic        open        high         low       close  \
# 0   2019-01-31  AAPL   41.527500   42.250000   41.139999   39.886833
# 1   2019-01-31  AMGN  184.779999  187.600006  183.910004  159.341492
# 2   2019-01-31   AXP  102.000000  102.900002  101.699997   95.704002
# 3   2019-01-31    BA  387.160004  388.989990  382.079987  374.705719
# 4   2019-01-31   CAT  130.320007  133.339996  129.039993  118.100647
# ..         ...   ...         ...         ...         ...         ...
# 715 2020-12-31   UNH  345.040009  351.089996  344.049988  336.380615
# 716 2020-12-31     V  218.399994  219.820007  216.199997  213.664185
# 717 2020-12-31    VZ   58.060001   58.799999   58.020000   48.816616
# 718 2020-12-31   WBA   39.330002   40.000000   39.029999   33.866371
# 719 2020-12-31   WMT   48.066666   48.090000   47.616669   45.866272
#
#           volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0    162958400.0  0.231233  0.199276  0.033804  ...     1.134347    0.854114
# 1      4397900.0  0.095047  0.067428  0.003606  ...    57.359324   13.513320
# 2      4302100.0  0.199130  0.137668  0.007860  ...   116.940221   24.546459
# 3      6878500.0  0.097744  0.093773  0.017877  ...     0.262465    0.092436
# 4      6643300.0  0.203104  0.139685  0.023893  ...     0.919490    0.266175
# ..           ...       ...       ...       ...  ...          ...         ...
# 715    1969000.0  0.053722  0.033788  0.011212  ...     0.623930    0.273143
# 716    5922200.0  0.676631  0.549675  0.038868  ...     1.969814    1.700081
# 717   12906300.0  0.210596  0.132250  0.014497  ...     1.210691    0.589158
# 718    7696000.0  0.062153  0.034870  0.023203  ...     0.201841    0.131341
# 719   17814000.0  0.000000  0.000000  0.000000  ...     0.000000    0.000000
#
#      inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0        6.788288          2.207740          1.089052    0.690466
# 1        0.000000          0.096045          0.176988    0.869784
# 2        0.000000          0.079181          0.096330    0.887329
# 3        0.276981          1.611943          1.232287    0.998070
# 4        0.675527          0.752585          1.158099    0.803394
# ..            ...               ...               ...         ...
# 715      0.000000          2.577035          1.120292    0.642459
# 716      0.000000          1.701676          0.753557    0.531507
# 717      8.252784          1.407383          2.223189    0.781118
# 718      2.325635         27.848143          2.782072    0.587123
# 719      0.000000          0.000000          0.000000    0.000000
#
#      debt_to_equity          PE           PB  Div_yield
# 0          2.230663    5.953259     1.735972   0.018302
# 1          6.679531  514.004812    14.756649   0.001130
# 2          7.875371   52.875139     3.605376   0.004075
# 3        517.142241   98.866944  1688.906591   0.005484
# 4          4.086316   35.896853     4.373802   0.007282
# ..              ...         ...          ...        ...
# 715        1.855023   20.725854     4.858928   0.003716
# 716        1.134505  150.467736    13.431003   0.001498
# 717        3.568671   11.352701     2.977647   0.012854
# 718        1.501283    9.960697     2.036080   0.007013
# 719        0.000000    0.000000     0.000000   0.000000
#
# [720 rows x 22 columns]

# %% [markdown]
# <a id='4.2'></a>
# ## 5.2 Set up the training environment

# %% [markdown]
# ### New environment

# %%
import gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv
# from gym.spaces import Box

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        # stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        # turbulence_threshold=None,
        # risk_indicator_col="turbulence",
        make_plots=False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        self.day = day
        self.df = df
        # self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        # self.turbulence_threshold = turbulence_threshold
        # self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        self.portfolio_columns = ['tic','price','buy_price','amount','weight']
        self.row = 0
        
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _buy_stock(self, action):
        def _do_buy():
            if self.data.close > 0: # Buy only if the price is > 0 (no missing data in this particular date)
                buy_amount = (self.portfolio.loc[0].price * action)
                buy_num_shares = math.floor(buy_amount/self.data.close)
                if buy_num_shares > 0:
                    if self.portfolio[self.portfolio.tic == self.data.tic].empty:
                        selected_index = len(self.portfolio)
                        selected_row = [self.data.tic,0,self.data.close,0,0]
                    else:
                        selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
                        selected_row = self.portfolio.loc[selected_index]
                        selected_row[2] = (buy_num_shares*self.data.close + selected_row[2]*selected_row[3]) \
                                    /(buy_num_shares + selected_row[3])
                    selected_row[1] = self.data.close
                    selected_row[3] += buy_num_shares
                    self.portfolio.loc[selected_index] = selected_row
    
                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_change = buy_num_shares * self.data.close * (1 + self.buy_cost_pct)
                    capital_row[1] -= capital_change
                    capital_row[2] -= capital_change
                    self.portfolio.loc[0] = capital_row
                    
                    self._compute_weight()
                    self.cost += selected_row[1] * buy_num_shares * self.buy_cost_pct
                    self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        buy_num_shares = _do_buy()
        return buy_num_shares
    
    def _sell_stock(self, action):
        def _do_sell_normal():
            if self.data.close > 0: # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.portfolio[self.portfolio.tic == self.data.tic].empty:            
                    sell_num_shares = 0
                else:
                    sell_num_shares = math.floor(abs(action) * self.portfolio[self.portfolio.tic == self.data.tic].amount) 
                    sell_amount = self.data.close * sell_num_shares * (1 - self.sell_cost_pct) # remember to adjust buy_cost_pct
                    
                    # update stock row in the portfolio
                    selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
                    selected_row = self.portfolio.loc[selected_index]
                    selected_row[1] = self.data.close
                    selected_row[3] -= sell_num_shares
                    self.portfolio.loc[selected_index] = selected_row

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_row[1] += sell_amount
                    capital_row[2] += sell_amount
                    self.portfolio.loc[0] = capital_row

                    self._compute_weight()
                    self.cost += selected_row[1] * sell_num_shares * self.sell_cost_pct
                    self.trades += 1
            else:
                sell_num_shares = 0

            return sell_num_shares

        sell_num_shares = _do_sell_normal()
        return sell_num_shares

    def _compute_weight(self):
        nav = sum(self.portfolio.price*self.portfolio.amount)
        self.portfolio['weight'] = self.portfolio.apply(lambda x: x.price * x.amount / nav, axis=1)
    
    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig("results/account_value_trade_{}.png".format(self.episode))
        plt.close()

    def step(self, actions):
        self.terminal = (self.day >= len(self.df.index.unique()) - 1)
        # self.terminal = self.day >= len(self.df.index.unique()) - 1
        
        # --> IN CASE THE STEP IS THE TERMINATED STEP
        if self.terminal: 
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
                
            # Summary the training performance after an episode
            end_total_asset = sum(self.portfolio.price*self.portfolio.amount)
            tot_reward = end_total_asset - self.initial_amount

            # Summary total_value
            df_total_value = pd.DataFrame(self.asset_memory)
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(1)
            if df_total_value["daily_return"].std() != 0:
                sharpe = ((252 ** 0.5)* df_total_value["daily_return"].mean()/ df_total_value["daily_return"].std())

            # Summary rewards
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]

            # Print out training results after a certain amount of episodes
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.close()

            return self.state, self.reward, self.terminal, {}

        # --> IN A NORMAL STEP
        else: 

            begin_total_asset = sum(self.portfolio.price * self.portfolio.amount)
            
            # update previous_portfolio
            self.previous_port = self.portfolio.copy()
        
            self.data = self.df.loc[self.day]
            if actions[0] > 0:
                self._buy_stock(actions[0])
            else:
                self._sell_stock(actions[0])

            # actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            # actions = actions.astype(int)  # convert into integer because we can't by fraction of shares
            # print(type(actions))
            self.actions_memory.append(actions)

            # Update selected row in the dataset based on state: s -> s+1
            # self.day += 1
            # self.data = self.df.loc[self.day, :]
            self.day += 1
            self.data = self.df.loc[self.day]
            self.state = self._update_state()
    
            end_total_asset = sum(self.portfolio.price * self.portfolio.amount)

            # Update summary arrays
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        # initiate state
        self.state = self._initiate_state()

        # Reset asset_memory
        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = sum(self.previous_port.price * self.previous_port.amount)
            self.asset_memory = [previous_total_asset]

        # Reset support variables
        # self.day = 0
        # self.data = self.df.loc[self.day, :]
        # self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]

        self.episode += 1

        return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        
        # Reset portfolio & previous_portfolio
        if self.initial:
            self.portfolio = pd.DataFrame([['cap',self.initial_amount,self.initial_amount,1,1]])
            self.portfolio.columns = self.portfolio_columns
            self.previous_port = self.portfolio.copy()
        else:
            self.portfolio = self.previous_port.copy()

        # Reset data
        self.day = 0
        self.data = self.df.loc[self.day]
        
         # Reset state
        state = self._update_state()
        
        return state

    def _update_state(self):
    
        # if the stock appear in the portfolio already
        if self.portfolio[self.portfolio.tic == self.data.tic].empty:
            state = ([self.portfolio.loc[0].price] + [0] + [0] + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))
            
        else:
            selected_row = self.portfolio[self.portfolio.tic == self.data.tic]
            state = (
                    [self.portfolio.iloc[0].price]
                    + [(selected_row.buy_price.iloc[0]/selected_row.price.iloc[0]-1)]
                    + [selected_row.weight.iloc[0]]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
    
        return state

    def _get_date(self):
        # return self.data.date
        return self.day

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        
        date_list = self.date_memory[:-1]
        action_list = self.actions_memory
        df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %% [markdown]
# <a id='4.3'></a>
# ## 5.3 Initialize Environment

# %% [markdown]
# State's space include current capital amount, the return of the current stock, the weight of this stock in the portfolio, and the indicators decided in ratio_list

# %%
ratio_list = ['OPM', 'NPM','ROA', 'ROE', 'cur_ratio', 'quick_ratio', 'cash_ratio', 'inv_turnover','acc_rec_turnover', 'acc_pay_turnover', 'debt_ratio', 'debt_to_equity',
       'PE', 'PB', 'Div_yield']

action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
state_space = 1 + 2*action_dimension + len(ratio_list)
print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 18

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ### Test environment

# %%
from gym.spaces import Box

# %%
# Define bounds, shape, and data type
lower_bound = -1.0
upper_bound = 1.0
shape = (1,)
dtype = np.float32

# Create the Box object
action_space = Box(low=lower_bound, high=upper_bound, shape=shape, dtype=dtype)

# Sample a value within the action space
action = action_space.sample()

print(f"Action: {action}")
# Out:
# Action: [-0.352389]

# %%
# test reset state
e_train_gym.reset()
# Out:
# [1000000,
#  0,
#  0,
#  0.25572435050638487,
#  0.178335535006605,
#  0.03746790942942387,
#  0.0666365019949817,
#  2.461857319467675,
#  2.0397789251690788,
#  1.818994982183114,
#  16.91025641025641,
#  2.992094861660079,
#  1.3269617706237424,
#  0.43772694682794827,
#  0.7784953313314961,
#  0.6360617999372812,
#  0.10150974915304276,
#  0.0]

# %%
 # test buying 100 AXP
e_train_gym.step(action)
e_train_gym.state
# Out:
# [1000000,
#  0,
#  0,
#  0.09504706063879031,
#  0.06742786607005091,
#  0.003606116369457762,
#  0.027693282636248415,
#  2.792722547108512,
#  57.35932423651722,
#  13.51332033788174,
#  0.0,
#  0.0960446953867129,
#  0.17698811343711976,
#  0.8697837155376579,
#  6.679531051964512,
#  128.3769792126071,
#  3.68559599058839,
#  0.004522969498516608]

# %%
e_train_gym.actions_memory
# Out:
# [array([-0.352389], dtype=float32)]

# %%
print(e_train_gym.state)
# Out:
# [1000000, 0, 0, 0.25572435050638487, 0.178335535006605, 0.03746790942942387, 0.0666365019949817, 2.461857319467675, 2.0397789251690788, 1.818994982183114, 16.91025641025641, 2.992094861660079, 1.3269617706237424, 0.43772694682794827, 0.7784953313314961, 0.6360616903195436, 0.10150973165903661, 0.0]

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Model 1: PPO

# %%
agent_ppo = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
    "clip_range":0.1
}
model_ppo = agent_ppo.get_model("ppo",model_kwargs = PPO_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo/")
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128, 'clip_range': 0.1}
# Using cpu device

# %%
trained_ppo = agent_ppo.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=300000)
# Out:
# Logging to tensorboard_log/test_ppo/ppo_1
# -------------------------------------
# | time/              |              |
# |    fps             | 224          |
# |    iterations      | 1            |
# |    time_elapsed    | 9            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.060795218 |
# -------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0014861922 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00441     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.37         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00266     |
# |    reward               | -0.7938705   |
# |    std                  | 1            |
# |    value_loss           | 13.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 3             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00081770576 |
# |    clip_fraction        | 0.0137        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.000612      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 17.9          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00148      |
# |    reward               | 0.0           |
# |    std                  | 1             |
# |    value_loss           | 36.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 4             |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0014938713  |
# |    clip_fraction        | 0.034         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.0869       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.22          |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00197      |
# |    reward               | -0.0065155006 |
# |    std                  | 1.01          |
# |    value_loss           | 10            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 5            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0004539817 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0199      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 10.2         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000775    |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 25           |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 6             |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00063784595 |
# |    clip_fraction        | 0.0106        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.0377       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.1           |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000514     |
# |    reward               | 2.6493304     |
# |    std                  | 1.01          |
# |    value_loss           | 13.7          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 224          |
# |    iterations           | 7            |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0004507957 |
# |    clip_fraction        | 0.002        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0419      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18           |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000692    |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 36.7         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 223           |
# |    iterations           | 8             |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00021560455 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.00917      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 21.6          |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000204     |
# |    reward               | 0.0           |
# |    std                  | 1.01          |
# |    value_loss           | 84.7          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 9            |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0002514704 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0748      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000695    |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 24.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 10           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0011531966 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0176      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 43.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00167     |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 61           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 224          |
# |    iterations           | 11           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0009839442 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0613      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.27         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.001       |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 13.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 220           |
# |    iterations           | 12            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.0010304959  |
# |    clip_fraction        | 0.0398        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.108        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 13            |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00138      |
# |    reward               | -0.0010485861 |
# |    std                  | 1.01          |
# |    value_loss           | 32.8          |
# -------------------------------------------
# day: 3599, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5194215.32
# total_reward: 4194215.32
# total_cost: 237665.88
# total_trades: 3000
# Sharpe: 1.380
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 219          |
# |    iterations           | 13           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0018765723 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0562      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 10.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00162     |
# |    reward               | 0.005823372  |
# |    std                  | 1.01         |
# |    value_loss           | 22.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 14           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0005716935 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0413      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.8         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0019      |
# |    reward               | 0.38237926   |
# |    std                  | 1.02         |
# |    value_loss           | 28.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 15           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0010157012 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.0464      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.3         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00153     |
# |    reward               | 0.37418914   |
# |    std                  | 1.01         |
# |    value_loss           | 36           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 218          |
# |    iterations           | 16           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0014640249 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.052       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.66         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00229     |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 16.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 219           |
# |    iterations           | 17            |
# |    time_elapsed         | 158           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00066430017 |
# |    clip_fraction        | 0.019         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.109        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 14.6          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.0021       |
# |    reward               | 0.0           |
# |    std                  | 1.02          |
# |    value_loss           | 16            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 18           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0016734492 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0681      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.22         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00149     |
# |    reward               | 0.0          |
# |    std                  | 1            |
# |    value_loss           | 8.37         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 222           |
# |    iterations           | 19            |
# |    time_elapsed         | 174           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00017734032 |
# |    clip_fraction        | 0.0382        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.0259       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 22.4          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 0.000334      |
# |    reward               | 0.0           |
# |    std                  | 1             |
# |    value_loss           | 40            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 224          |
# |    iterations           | 20           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0008048173 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0436      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.1         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00184     |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 22.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 225          |
# |    iterations           | 21           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0009200098 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0274      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 27.1         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00144     |
# |    reward               | 0.0          |
# |    std                  | 1            |
# |    value_loss           | 46.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 227           |
# |    iterations           | 22            |
# |    time_elapsed         | 198           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.0012598118  |
# |    clip_fraction        | 0.0292        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.0997       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.01          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00163      |
# |    reward               | 0.00040837176 |
# |    std                  | 1             |
# |    value_loss           | 16.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 227          |
# |    iterations           | 23           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0005881594 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.033       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.3          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00215     |
# |    reward               | 0.0          |
# |    std                  | 0.997        |
# |    value_loss           | 18.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 228          |
# |    iterations           | 24           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0007363116 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.049       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 19.1         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00293     |
# |    reward               | 0.8446215    |
# |    std                  | 0.995        |
# |    value_loss           | 34.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 25            |
# |    time_elapsed         | 223           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00092794676 |
# |    clip_fraction        | 0.0182        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.0739       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.11          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00153      |
# |    reward               | 0.59839785    |
# |    std                  | 0.997         |
# |    value_loss           | 13.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 26           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0016254073 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0396      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00169     |
# |    reward               | 1.269456     |
# |    std                  | 1            |
# |    value_loss           | 34.1         |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 230            |
# |    iterations           | 27             |
# |    time_elapsed         | 240            |
# |    total_timesteps      | 55296          |
# | train/                  |                |
# |    approx_kl            | 0.00053185166  |
# |    clip_fraction        | 0.0176         |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -0.0993        |
# |    learning_rate        | 0.00025        |
# |    loss                 | 7.71           |
# |    n_updates            | 260            |
# |    policy_gradient_loss | -0.00108       |
# |    reward               | -0.00024680598 |
# |    std                  | 0.996          |
# |    value_loss           | 16.7           |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 28           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0014237142 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0117      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 26.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00165     |
# |    reward               | 0.0          |
# |    std                  | 0.995        |
# |    value_loss           | 56.9         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 228           |
# |    iterations           | 29            |
# |    time_elapsed         | 259           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00068413676 |
# |    clip_fraction        | 0.0261        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.0276       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 18            |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.0014       |
# |    reward               | 0.0           |
# |    std                  | 0.995         |
# |    value_loss           | 38.5          |
# -------------------------------------------
# day: 3599, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4604504.87
# total_reward: 3604504.87
# total_cost: 209105.32
# total_trades: 3043
# Sharpe: 1.067
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 228          |
# |    iterations           | 30           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0008146117 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0315      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.9         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00155     |
# |    reward               | 0.0          |
# |    std                  | 0.988        |
# |    value_loss           | 29.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 228           |
# |    iterations           | 31            |
# |    time_elapsed         | 277           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00031557525 |
# |    clip_fraction        | 0.0131        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.0144       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 56.3          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00114      |
# |    reward               | -0.062033135  |
# |    std                  | 0.987         |
# |    value_loss           | 68.8          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 32            |
# |    time_elapsed         | 285           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.0004036724  |
# |    clip_fraction        | 0.00659       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.0401       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 23.7          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.00128      |
# |    reward               | -0.0005843084 |
# |    std                  | 0.982         |
# |    value_loss           | 49.7          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 33           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0009969668 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0063      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 71.6         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0016      |
# |    reward               | -0.014097108 |
# |    std                  | 0.982        |
# |    value_loss           | 195          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 34           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0018142993 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0307      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.8         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00117     |
# |    reward               | 0.0          |
# |    std                  | 0.985        |
# |    value_loss           | 36.6         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 35            |
# |    time_elapsed         | 310           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00036808234 |
# |    clip_fraction        | 0.0158        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.039        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 34.8          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00166      |
# |    reward               | -0.007679582  |
# |    std                  | 0.983         |
# |    value_loss           | 76.3          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 36           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0018957464 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0829      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.27         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00244     |
# |    reward               | 0.013211729  |
# |    std                  | 0.985        |
# |    value_loss           | 15.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 37           |
# |    time_elapsed         | 327          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0011277664 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0316      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 10.8         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00215     |
# |    reward               | 0.0          |
# |    std                  | 0.987        |
# |    value_loss           | 20.6         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 38            |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00035825092 |
# |    clip_fraction        | 0.0146        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.0363       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.86          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000669     |
# |    reward               | 0.0           |
# |    std                  | 0.99          |
# |    value_loss           | 30            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 39           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0008931806 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00386     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.3         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00179     |
# |    reward               | -0.010571294 |
# |    std                  | 0.989        |
# |    value_loss           | 46.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 40            |
# |    time_elapsed         | 355           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00049435184 |
# |    clip_fraction        | 0.00752       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.00651      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 147           |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000779     |
# |    reward               | 0.0           |
# |    std                  | 0.99          |
# |    value_loss           | 185           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 41            |
# |    time_elapsed         | 363           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00071754854 |
# |    clip_fraction        | 0.0236        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.045        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.87          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.00141      |
# |    reward               | 0.0           |
# |    std                  | 0.983         |
# |    value_loss           | 13            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 42           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0008043714 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0103      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 24.5         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00183     |
# |    reward               | -0.18650758  |
# |    std                  | 0.986        |
# |    value_loss           | 37.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 43           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011638409 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0423      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.7         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00153     |
# |    reward               | -1.2609884   |
# |    std                  | 0.983        |
# |    value_loss           | 27.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 44           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0016865281 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0339      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15           |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00217     |
# |    reward               | 0.0          |
# |    std                  | 0.99         |
# |    value_loss           | 34.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 45            |
# |    time_elapsed         | 396           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00029195132 |
# |    clip_fraction        | 0.0246        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.0434       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 16.7          |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00193      |
# |    reward               | 0.037767448   |
# |    std                  | 0.985         |
# |    value_loss           | 37            |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 46          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.001718052 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.03       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.89        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000769    |
# |    reward               | 0.0         |
# |    std                  | 0.994       |
# |    value_loss           | 17.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 47           |
# |    time_elapsed         | 415          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0003029893 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0332      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 23.6         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00115     |
# |    reward               | 0.0          |
# |    std                  | 0.997        |
# |    value_loss           | 41.8         |
# ------------------------------------------
# day: 3599, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 2861856.87
# total_reward: 1861856.87
# total_cost: 151014.24
# total_trades: 3098
# Sharpe: 0.772
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 48           |
# |    time_elapsed         | 423          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0005838737 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.101       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.99         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00165     |
# |    reward               | 0.0          |
# |    std                  | 0.998        |
# |    value_loss           | 6.33         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 49            |
# |    time_elapsed         | 431           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00072952243 |
# |    clip_fraction        | 0.0156        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.0106       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 20.5          |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.00172      |
# |    reward               | -5.3949084    |
# |    std                  | 0.993         |
# |    value_loss           | 38.8          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 50           |
# |    time_elapsed         | 439          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0006457675 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0187      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.2         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00135     |
# |    reward               | -0.014189452 |
# |    std                  | 0.993        |
# |    value_loss           | 31.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 233           |
# |    iterations           | 51            |
# |    time_elapsed         | 448           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00088568544 |
# |    clip_fraction        | 0.033         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.0051        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 14            |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.0018       |
# |    reward               | 0.0           |
# |    std                  | 0.994         |
# |    value_loss           | 33.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 52           |
# |    time_elapsed         | 456          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0005140256 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0212      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.3         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00141     |
# |    reward               | 0.15889508   |
# |    std                  | 0.995        |
# |    value_loss           | 35.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 53           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0015670459 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0279       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 19.9         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00247     |
# |    reward               | 0.0          |
# |    std                  | 0.997        |
# |    value_loss           | 37.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 54           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0008943282 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0131      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 39.9         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00149     |
# |    reward               | 0.04151222   |
# |    std                  | 0.992        |
# |    value_loss           | 94.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 55           |
# |    time_elapsed         | 482          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0046006124 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.329       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.28         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00114     |
# |    reward               | 0.0          |
# |    std                  | 0.988        |
# |    value_loss           | 16.7         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 56            |
# ...
# |    policy_gradient_loss | -0.00209      |
# |    reward               | 0.0008674489  |
# |    std                  | 1.06          |
# |    value_loss           | 15.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 130          |
# |    time_elapsed         | 1111         |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0017435236 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | -0.00961     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.4         |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00426     |
# |    reward               | 8.293865     |
# |    std                  | 1.07         |
# |    value_loss           | 35.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 131          |
# |    time_elapsed         | 1119         |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0014149131 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | -0.0202      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.03         |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.0018      |
# |    reward               | -0.011691907 |
# |    std                  | 1.07         |
# |    value_loss           | 17.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 132          |
# |    time_elapsed         | 1127         |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0010775223 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | -0.0333      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.96         |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00225     |
# |    reward               | 0.0019278396 |
# |    std                  | 1.07         |
# |    value_loss           | 13.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 133          |
# |    time_elapsed         | 1135         |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0012583734 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.0241       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.5         |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00309     |
# |    reward               | -0.08828032  |
# |    std                  | 1.06         |
# |    value_loss           | 35.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 134         |
# |    time_elapsed         | 1143        |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.001043671 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | -0.0255     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.81        |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00279    |
# |    reward               | 0.014531432 |
# |    std                  | 1.05        |
# |    value_loss           | 6.89        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 135          |
# |    time_elapsed         | 1152         |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0011636867 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.0256       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.2         |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00244     |
# |    reward               | -1.6909525   |
# |    std                  | 1.05         |
# |    value_loss           | 29.4         |
# ------------------------------------------
# day: 3599, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 4568549.29
# total_reward: 3568549.29
# total_cost: 260831.72
# total_trades: 3082
# Sharpe: 1.112
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 136          |
# |    time_elapsed         | 1160         |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0016318809 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.0689      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.37         |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00201     |
# |    reward               | 1.6893945    |
# |    std                  | 1.05         |
# |    value_loss           | 13.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 137          |
# |    time_elapsed         | 1168         |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0016332088 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.6         |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00225     |
# |    reward               | -1.256625    |
# |    std                  | 1.05         |
# |    value_loss           | 35.5         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 138           |
# |    time_elapsed         | 1176          |
# |    total_timesteps      | 282624        |
# | train/                  |               |
# |    approx_kl            | 0.00082722376 |
# |    clip_fraction        | 0.0445        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | -0.0244       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 21.3          |
# |    n_updates            | 1370          |
# |    policy_gradient_loss | -0.0012       |
# |    reward               | 0.0           |
# |    std                  | 1.05          |
# |    value_loss           | 32.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 139           |
# |    time_elapsed         | 1184          |
# |    total_timesteps      | 284672        |
# | train/                  |               |
# |    approx_kl            | 0.0010737791  |
# |    clip_fraction        | 0.0416        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | -0.00508      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 15            |
# |    n_updates            | 1380          |
# |    policy_gradient_loss | -0.00421      |
# |    reward               | -0.0006105871 |
# |    std                  | 1.04          |
# |    value_loss           | 28            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 140          |
# |    time_elapsed         | 1192         |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0009822643 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.0127       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 26           |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00314     |
# |    reward               | 0.0          |
# |    std                  | 1.04         |
# |    value_loss           | 37.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 141          |
# |    time_elapsed         | 1200         |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0023896687 |
# |    clip_fraction        | 0.0814       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.0513      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.16         |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00341     |
# |    reward               | 0.26097426   |
# |    std                  | 1.06         |
# |    value_loss           | 11.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 142           |
# |    time_elapsed         | 1209          |
# |    total_timesteps      | 290816        |
# | train/                  |               |
# |    approx_kl            | 0.00090625044 |
# |    clip_fraction        | 0.0178        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0.00907       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 28.2          |
# |    n_updates            | 1410          |
# |    policy_gradient_loss | -0.00164      |
# |    reward               | 0.0           |
# |    std                  | 1.05          |
# |    value_loss           | 51.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 143           |
# |    time_elapsed         | 1217          |
# |    total_timesteps      | 292864        |
# | train/                  |               |
# |    approx_kl            | 0.00075252866 |
# |    clip_fraction        | 0.0189        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | -0.018        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 13.6          |
# |    n_updates            | 1420          |
# |    policy_gradient_loss | -0.00133      |
# |    reward               | 0.0001629516  |
# |    std                  | 1.05          |
# |    value_loss           | 25            |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 144           |
# |    time_elapsed         | 1225          |
# |    total_timesteps      | 294912        |
# | train/                  |               |
# |    approx_kl            | 0.00089766644 |
# |    clip_fraction        | 0.0376        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | -0.00443      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 23.2          |
# |    n_updates            | 1430          |
# |    policy_gradient_loss | -0.0023       |
# |    reward               | -0.7818694    |
# |    std                  | 1.05          |
# |    value_loss           | 61.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 145          |
# |    time_elapsed         | 1233         |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0016844922 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.63         |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00389     |
# |    reward               | 0.0          |
# |    std                  | 1.04         |
# |    value_loss           | 24.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 146           |
# |    time_elapsed         | 1242          |
# |    total_timesteps      | 299008        |
# | train/                  |               |
# |    approx_kl            | 0.00047697313 |
# |    clip_fraction        | 0.0187        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | -0.00495      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 16.7          |
# |    n_updates            | 1450          |
# |    policy_gradient_loss | -0.00209      |
# |    reward               | 0.0           |
# |    std                  | 1.03          |
# |    value_loss           | 35.7          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 147         |
# |    time_elapsed         | 1250        |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.001134187 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.00743     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.9        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.0024     |
# |    reward               | 0.22086318  |
# |    std                  | 1.03        |
# |    value_loss           | 41.5        |
# -----------------------------------------

# %% [markdown]
# ### Model 2: DDPG

# %%
# agent_ddpg = DRLAgent(env = env_train)
# DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}
# model_ddpg = agent_ddpg.get_model("ddpg",model_kwargs = DDPG_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ddpg_tensorboard/")

# # set up logger
# tmp_path = RESULTS_DIR + '/ddpg'
# new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_ddpg)

# %%
# the training log just show up when total_timesteps higher than 15.000
# trained_ddpg = agent_ddpg.train_model(model=model_ddpg,
#                              tb_log_name='ddpg',
#                              total_timesteps=1000)

# %% [markdown]
# ### Model 3: SAC

# %%
# agent_sac = DRLAgent(env = env_train)
# SAC_PARAMS = {
#     "batch_size": 128,
#     "buffer_size": 100000,
#     "learning_rate": 0.0003,
#     "learning_starts": 100,
#     "ent_coef": "auto_0.1",
# }

# model_sac = agent_sac.get_model("sac",model_kwargs = SAC_PARAMS)

# # set up logger
# tmp_path = RESULTS_DIR + '/sac'
# new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_sac)

# %%
# trained_sac = agent_sac.train_model(model=model_sac, 
#                              tb_log_name='sac',
#                              total_timesteps=1000)

# %% [markdown]
# ### Model 4: TD3

# %%
# agent_td3 = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100, 
#               "buffer_size": 1000000, 
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3, 
#                              tb_log_name='td3',
#                              total_timesteps=10000)

# %% [markdown]
# ### Model 5: A2C

# %%
# agent_a2c = DRLAgent(env = env_train)

# A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
# model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)

# %%
# trained_a2c = agent.train_model(model=model_a2c, 
#                                 tb_log_name='a2c',
#                                 total_timesteps=10000)

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at the begining. We use the PPO model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2018-12 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
test_data = trade_data.reset_index(drop=True)
test_data
# Out:
#           date   tic        open        high         low       close  \
# 0   2019-01-31  AAPL   41.527500   42.250000   41.139999   39.886845
# 1   2019-01-31  AMGN  184.779999  187.600006  183.910004  159.341492
# 2   2019-01-31   AXP  102.000000  102.900002  101.699997   95.703987
# 3   2019-01-31    BA  387.160004  388.989990  382.079987  374.705688
# 4   2019-01-31   CAT  130.320007  133.339996  129.039993  118.100616
# ..         ...   ...         ...         ...         ...         ...
# 715 2020-12-31   UNH  345.040009  351.089996  344.049988  336.380615
# 716 2020-12-31     V  218.399994  219.820007  216.199997  213.664185
# 717 2020-12-31    VZ   58.060001   58.799999   58.020000   48.816624
# 718 2020-12-31   WBA   39.330002   40.000000   39.029999   33.866367
# 719 2020-12-31   WMT   48.066666   48.090000   47.616669   45.866280
#
#           volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0    162958400.0  0.231233  0.199276  0.033804  ...     1.134347    0.854114
# 1      4397900.0  0.095047  0.067428  0.003606  ...    57.359324   13.513320
# 2      4302100.0  0.199130  0.137668  0.007860  ...   116.940221   24.546459
# 3      6878500.0  0.097744  0.093773  0.017877  ...     0.262465    0.092436
# 4      6643300.0  0.203104  0.139685  0.023893  ...     0.919490    0.266175
# ..           ...       ...       ...       ...  ...          ...         ...
# 715    1969000.0  0.053722  0.033788  0.011212  ...     0.623930    0.273143
# 716    5922200.0  0.676631  0.549675  0.038868  ...     1.969814    1.700081
# 717   12906300.0  0.210596  0.132250  0.014497  ...     1.210691    0.589158
# 718    7696000.0  0.062153  0.034870  0.023203  ...     0.201841    0.131341
# 719   17814000.0  0.000000  0.000000  0.000000  ...     0.000000    0.000000
#
#      inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0        6.788288          2.207740          1.089052    0.690466
# 1        0.000000          0.096045          0.176988    0.869784
# 2        0.000000          0.079181          0.096330    0.887329
# 3        0.276981          1.611943          1.232287    0.998070
# 4        0.675527          0.752585          1.158099    0.803394
# ..            ...               ...               ...         ...
# 715      0.000000          2.577035          1.120292    0.642459
# 716      0.000000          1.701676          0.753557    0.531507
# 717      8.252784          1.407383          2.223189    0.781118
# 718      2.325635         27.848143          2.782072    0.587123
# 719      0.000000          0.000000          0.000000    0.000000
#
#      debt_to_equity          PE           PB  Div_yield
# 0          2.230663    5.953260     1.735972   0.018302
# 1          6.679531  514.004812    14.756649   0.001130
# 2          7.875371   52.875131     3.605376   0.004075
# 3        517.142241   98.866936  1688.906453   0.005484
# 4          4.086316   35.896844     4.373801   0.007282
# ..              ...         ...          ...        ...
# 715        1.855023   20.725854     4.858928   0.003716
# 716        1.134505  150.467736    13.431003   0.001498
# 717        3.568671   11.352703     2.977647   0.012854
# 718        1.501283    9.960696     2.036080   0.007013
# 719        0.000000    0.000000     0.000000   0.000000
#
# [720 rows x 22 columns]

# %%
# trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = test_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = e_trade_gym)

# df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
#     model=trained_ddpg, 
#     environment = e_trade_gym)

# df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
#     model=trained_sac, 
#     environment = e_trade_gym)

# df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
#     model=trained_a2c, 
#     environment = e_trade_gym) if if_using_a2c else [None, None]

# df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
#     model=trained_td3, 
#     environment = e_trade_gym) if if_using_td3 else [None, None]
# Out:
# hit end!

# %%
df_account_value_ppo.shape
# df_account_value_ddpg.shape
# df_account_value_sac.shape
# df_account_value_td3.shape
# df_account_value_a2c.shape
# Out:
# (720, 2)

# %%
df_account_value_ppo['date'] = test_data.date

# %%
df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
# df_account_value_sac.tail()
# df_account_value_td3.tail()
# df_account_value_a2c.tail()
# Out:
#           date  account_value
# 715 2020-12-31        1000000
# 716 2020-12-31        1000000
# 717 2020-12-31        1000000
# 718 2020-12-31        1000000
# 719 2020-12-31        1000000

# %%
df_actions_ppo['date'] = test_data.date

# %%
df_actions_ppo.head()
# df_actions_ddpg.head()
# df_actions_sac.head()
# df_actions_td3.head()
# df_actions_a2c.head()
# Out:
#         date       actions
# 0 2019-01-31  [-0.1891561]
# 1 2019-01-31  [-0.1891561]
# 2 2019-01-31  [-0.1891561]
# 3 2019-01-31  [-0.1891561]
# 4 2019-01-31  [-0.1891561]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_account_value = pd.DataFrame(df_account_value_ppo.date.unique())
df_account_value.columns = ['date']
df_account_value['account_value'] = df_account_value.apply(lambda x: \
                                    df_account_value_ppo[df_account_value_ppo.date == x.date].iloc[-1].account_value, axis=1)
df_account_value.head()
# Out:
#         date  account_value
# 0 2019-01-31        1000000
# 1 2019-02-28        1000000
# 2 2019-03-31        1000000
# 3 2019-04-30        1000000
# 4 2019-05-31        1000000

# %% [markdown]
# There's a missmatch between the quarterly computation of df_account_value and the daily frequency of the comparison datasets. We need to transform the df_account_value to a daily basis.
# To fill up the missing data, th **ffill** function effectively imputes values, providing the continous picture of account value trends until the next recorded change. However, for the entries preceding the first recorded change, we will use the **initial_amount**.

# %%
daily_account_value = pd.DataFrame(df.date.unique())
daily_account_value.columns = ['date']
daily_account_value = daily_account_value.merge(df_account_value,how='left')
daily_account_value.ffill(inplace=True)
daily_account_value.fillna(env_kwargs["initial_amount"],inplace=True)
daily_account_value = daily_account_value[daily_account_value.date >= TEST_START_DATE]
daily_account_value.reset_index(inplace=True,drop=True)
daily_account_value
# Out:
#           date  account_value
# 0   2019-01-02      1000000.0
# 1   2019-01-03      1000000.0
# 2   2019-01-04      1000000.0
# 3   2019-01-07      1000000.0
# 4   2019-01-08      1000000.0
# ..         ...            ...
# 500 2020-12-24      1000000.0
# 501 2020-12-28      1000000.0
# 502 2020-12-29      1000000.0
# 503 2020-12-30      1000000.0
# 504 2020-12-31      1000000.0
#
# [505 rows x 2 columns]

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

print("\n ppo:")
perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
# perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

# print("\n ddpg:")
# perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
# perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
# perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

# print("\n sac:")
# perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
# perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
#   perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')

#   print("\n atd3:")
#   perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
#   perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
#   perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

#   print("\n a2c:")
#   perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
#   perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
#   perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.0
# Cumulative returns     0.0
# Annual volatility      0.0
# Sharpe ratio           NaN
# Calmar ratio           NaN
# Stability              0.0
# Max drawdown           0.0
# Omega ratio            NaN
# Sortino ratio          NaN
# Skew                   NaN
# Kurtosis               NaN
# Tail ratio             NaN
# Daily value at risk    0.0
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ==============Get Baseline Stats===========
# Shape of DataFrame:  (505, 8)
# Annual return          0.144674
# Cumulative returns     0.310981
# Annual volatility      0.274619
# Sharpe ratio           0.631418
# Calmar ratio           0.390102
# Stability              0.116677
# Max drawdown          -0.370862
# Omega ratio            1.149365
# Sortino ratio          0.870084
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.860710
# Daily value at risk   -0.033911
# dtype: float64

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTest with DJIA

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

backtest_plot(daily_account_value, 
            baseline_ticker = '^DJI', 
            baseline_start = TEST_START_DATE,
            baseline_end = TEST_END_DATE)

# backtest_plot(df_account_value_ddpg, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)

# backtest_plot(df_account_value_sac, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)

# if if_using_td3:
#   backtest_plot(df_account_value_td3, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)

# if if_using_a2c:
#   backtest_plot(df_account_value_a2c, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)
# Out:
# ==============Compare to DJIA===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>24</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.00</td>
#       <td>2019-01-02</td>
#       <td>2019-01-02</td>
#       <td>2019-01-02</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:295, in DatetimeConverter.convert(values, unit, axis)
#     294 else:
# --> 295     values = DatetimeConverter._convert_1d(values, unit, axis)
#     296 return values
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/plotting/_matplotlib/converter.py:330, in DatetimeConverter._convert_1d(values, unit, axis)
#     328         pass
# --> 330     values = mdates.date2num(values)
#     332 return values
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/dates.py:461, in date2num(d)
#     460         d = np.asarray(d)
# --> 461     d = d.astype('datetime64[us]')
#     463 d = np.ma.masked_array(d, mask=mask) if masked else d
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[92], line 7
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 # S&P 500: ^GSPC
#       4 # Dow Jones Index: ^DJI
#       5 # NASDAQ 100: ^NDX
# ----> 7 backtest_plot(daily_account_value,
#       8             baseline_ticker = '^DJI',
#       9             baseline_start = TEST_START_DATE,
#      10             baseline_end = TEST_END_DATE)
#      12 # backtest_plot(df_account_value_ddpg,
#      13 #               baseline_ticker = '^DJI',
#      14 #               baseline_start = TEST_START_DATE,
#    (...)
#      31 #               baseline_start = TEST_START_DATE,
#      32 #               baseline_end = TEST_END_DATE)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/finrl/plot.py:71, in backtest_plot(account_value, baseline_start, baseline_end, baseline_ticker, value_col_name)
#      68 baseline_returns = get_daily_return(baseline_df, value_col_name="close")
#      70 with pyfolio.plotting.plotting_context(font_scale=1.1):
# ---> 71     pyfolio.create_full_tear_sheet(
#      72         returns=test_returns, benchmark_rets=baseline_returns, set_context=False
#      73     )
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pyfolio/tears.py:180, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     174     returns = txn.adjust_returns_for_slippage(returns, positions,
#     175                                               transactions, slippage)
#     177 positions = utils.check_intraday(estimate_intraday, returns,
#     178                                  positions, transactions)
# --> 180 create_returns_tear_sheet(
#     181     returns,
#     182     positions=positions,
#     183     transactions=transactions,
#     184     live_start_date=live_start_date,
#     185     cone_std=cone_std,
#     186     benchmark_rets=benchmark_rets,
#     187     bootstrap=bootstrap,
#     188     turnover_denom=turnover_denom,
#     189     header_rows=header_rows,
#     190     set_context=set_context)
#     192 create_interesting_times_tear_sheet(returns,
#     193                                     benchmark_rets=benchmark_rets,
#     194                                     set_context=set_context)
#     196 if positions is not None:
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pyfolio/plotting.py:54, in customize.<locals>.call_w_context(*args, **kwargs)
#      52         return func(*args, **kwargs)
#      53 else:
# ---> 54     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pyfolio/tears.py:569, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     565 plotting.plot_rolling_sharpe(
#     566     returns, ax=ax_rolling_sharpe)
#     568 # Drawdowns
# --> 569 plotting.plot_drawdown_periods(
#     570     returns, top=5, ax=ax_drawdown)
#     572 plotting.plot_drawdown_underwater(
#     573     returns=returns, ax=ax_underwater)
#     575 plotting.plot_monthly_returns_heatmap(returns, ax=ax_monthly_heatmap)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pyfolio/plotting.py:442, in plot_drawdown_periods(returns, top, ax, **kwargs)
#     440     if pd.isnull(recovery):
#     441         recovery = returns.index[-1]
# --> 442     ax.fill_between((peak, recovery),
#     443                     lim[0],
#     444                     lim[1],
#     445                     alpha=.4,
#     446                     color=colors[i])
#     447 ax.set_ylim(lim)
#     448 ax.set_title('Top %i drawdown periods' % top)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5512, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5510 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5511                  step=None, **kwargs):
# -> 5512     return self._fill_between_x_or_y(
#    5513         "x", x, y1, y2,
#    5514         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5413, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5408         kwargs["facecolor"] = \
#    5409             self._get_patches_for_fill.get_next_color()
#    5411 # Handle united data, such as dates
#    5412 ind, dep1, dep2 = map(
# -> 5413     ma.masked_invalid, self._process_unit_info(
#    5414         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5416 for name, array in [
#    5417         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5418     if array.ndim > 1:
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:2573, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2571             if dataset_axis_name == axis_name and data is not None:
#    2572                 axis.update_units(data)
# -> 2573 return [axis_map[axis_name].convert_units(data)
#    2574         if convert and data is not None else data
#    2575         for axis_name, data in datasets]
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:2573, in <listcomp>(.0)
#    2571             if dataset_axis_name == axis_name and data is not None:
#    2572                 axis.update_units(data)
# -> 2573 return [axis_map[axis_name].convert_units(data)
#    2574         if convert and data is not None else data
#    2575         for axis_name, data in datasets]
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/matplotlib/axis.py:1771, in Axis.convert_units(self, x)
#    1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
# -> 1771     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1772                                  f'units: {x!r}') from e
#    1773 return ret
#
# ConversionError: Failed to convert value(s) to axis units: (NaT, Timestamp('2020-12-31 00:00:00+0000', tz='UTC'))

# %% [markdown]
# ### Compare to Buy&Hold Strategy
# pass in df_account_value, this information is stored in env class

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTest with Buy&Hold Strategy

# %%
# print(DOW_30_TICKER)
test_portfolio = DOW_30_TICKER
len(test_portfolio)

# %%
modify_fields = ['open','high','low','close']
used_columns = ['date','close']

# %%
# df_stock_test_ = get_baseline(
#         ticker='AXP', 
#         start = TEST_START_DATE,
#         end = TEST_END_DATE)
# df_stock_test_

# %%
# for field in modify_fields:
#     df_stock_test_[field] = df_stock_test_[field]/df_stock_test_.iloc[0][field]/len(test_portfolio)
# df_stock_test_ = df_stock_test_[used_columns]

# %%
daily_account_value.shape

# %%
#baseline stats
print("==============Get Baseline Stats===========")
shape = daily_account_value.shape
df_hold_ = pd.DataFrame(0,index=range(shape[0]), columns=range(shape[1]))
df_hold_.columns = used_columns
df_hold_['date'] = daily_account_value.date

for stock in test_portfolio:
    df_stock_ = get_baseline(
        ticker=stock, 
        start = TEST_START_DATE,
        end = TEST_END_DATE)
    # for field in modify_fields:
    if len(df_stock_) < len(df_hold_):
        final_row = df_stock_.iloc[-1]
        new_rows = pd.DataFrame([final_row] * (len(df_hold_) - len(df_stock_)))
        df_stock_ = pd.concat([df_stock_, new_rows], ignore_index=True)
        
        for i in range(0,len(df_stock_) < len(df_hold_)):
            df_stock_.iloc[en(df_stock_)] = df_stock_.iloc[len(df_stock_-1)]
    df_stock_['close'] = df_stock_['close']/df_stock_.iloc[0]['close']/len(test_portfolio)
    df_hold_['close'] = df_hold_.close + df_stock_.close

stats = backtest_stats(df_hold_, value_col_name = 'close')

# %%
df_hold_

# %% [markdown]
# The model' calculation encompass the entire timeframe, including non-working days. To address this, we need to determine the most appropriate method to fill up the weekend plots, for example backfilling.

# %%
# df_hold_.date = pd.to_datetime(df_hold_['date'])
# df_hold_ = pd.merge(df_account_value_ppo['date'],df_hold_,how='left')
# df_hold_.bfill(inplace=True)
# df_hold_

# %%
df_hold = pd.DataFrame()
df_hold['date'] = daily_account_value['date']
df_hold['hold'] = df_hold_['close'] / df_hold_['close'][0] * env_kwargs["initial_amount"]
# print("df_hold: ", df_hold)
# df_dji.to_csv("df_dji.csv")
df_hold = df_hold.set_index(df_hold.columns[0])
print("df_hold: ", df_hold)
# df_hold.to_csv("df_dji+.csv")

# df_account_value.to_csv('df_account_value.csv')

# %%
print("==============Compare to Buy&Hold===========")
df_result = pd.DataFrame({'date': df_account_value_ppo['date'], 'stock': df_account_value_ppo['account_value']})
df_result = df_result.set_index('date')

result = pd.DataFrame()
result = pd.merge(df_result, df_hold, left_index=True, right_index=True)
print("result: ", result)
# result.to_csv("result.csv")
result.columns = ['model', 'buy_and_hold']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();

# %% [markdown]
# <a id='7'></a>
# # 8. Save and load model as ONNX file #

# %% [markdown]
# <a id='7.1'></a>
# ## 8.1 Save model as ONNX file

# %%
import torch as th
import torch.onnx
from stable_baselines3 import PPO
from stable_baselines3 import DDPG
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(trained_ppo.policy)
observation_size = trained_ppo.observation_space.shape
dummy_input = th.randn(1, *observation_size)

th.onnx.export(
    onnx_policy,
    dummy_input,
    "all_in_one_ppo.onnx",
    opset_version=17,
    input_names=["input"],
)

# %% [markdown]
# <a id='7.2'></a>
# ## 8.2 Load model as ONNX file

# %% [markdown]
# Load model from the directory

# %%
import onnx
import onnxruntime as ort
import numpy as np

# %%
onnx_path = "all_in_one_ppo.onnx"
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)

# # Check that the predictions are the same
# with th.no_grad():
#     print(model.policy(th.as_tensor(observation), deterministic=True))

# %%
observation = np.zeros((1, state_space)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
actions, values, log_prob = ort_sess.run(None, {"input": observation})
print(actions, values, log_prob)
# Out:
# [[-0.18915609]] [[11.657145]] [-0.9448749]

# %% [markdown]
# Initiate the environment

# %%
test_env = StockTradingEnv(df = trade_data, **env_kwargs)

# %%
test_step = 1000
test_result = []
test_env.reset()
for i in range(0,test_step):
    observation = [test_env.state]
    observation = np.array(observation).astype(np.float32)
    actions, values, log_prob = ort_sess.run(None, {"input": observation})
    result = test_env.step(actions)
    test_result.append(result[1])
    if result[2] == True:
        break
