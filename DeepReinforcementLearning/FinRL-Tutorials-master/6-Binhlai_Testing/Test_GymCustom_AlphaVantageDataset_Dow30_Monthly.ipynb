# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch
# ## BinhLai_Dataset_Daily

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Check Additional Packages](#1.1)
#     * [2.2. Import Packages](#1.2)
#     * [2.3. Create Folders & Relevant Configurations¶](#1.3)
# * [3. Download Data](#2)
# * [4. Preprocess fundamental data](#3)
#     * [4.1. Import the financial data](#3.1)
#     * [4.2. Specify items needed to calculate financial ratios](#3.2)
#     * [4.3. Turn the final_ratios to daily basis](#3.3)
#     * [4.4. Merge stock price data and ratios into one dataframe](#3.4)
#     * [4.5. Finish data preparation](#3.5)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. Set up the training environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Train DRL Agent](#5)
# * [7.Backtest Our Strategy](#6)
#     * [7.1. BackTest with DJIA](#6.1)
#     * [7.2. BackTest with Buy&Hold Strategy](#6.2)
# * [8.Save & load model](#7)
#     * [8.1. Save model](#7.1)
#     * [8.2. Load model](#7.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import math
from stable_baselines3.common.logger import configure

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Create Folders & Relevant Configurations

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
from datetime import datetime
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

TRAIN_START_DATE = '2000-01-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

# Load price data from csv file
tic_dir = './' + DATA_SAVE_DIR + '/sp500_price_monthly.csv'
df = pd.read_csv(tic_dir,index_col=0)

# %% [markdown]
# If the data is available locally, we can skip downloading steps and jump directly to part [**4.5.Finish data preparation**](#3.5)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Price Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# Download data from YFinance
# tic_dir = './' + DATA_SAVE_DIR + '/sp500_ticker.csv'
# tic_list = pd.read_csv(tic_dir,index_col=0)
# SP_500_TICKER = np.array(tic_list.tic).tolist()
# df = YahooDownloader(start_date = TRAIN_START_DATE,
#                      end_date = TEST_END_DATE,
#                      ticker_list = SP_500_TICKER).fetch_data()

# %%
# df.head()

# %%
# df.tail()

# %%
# df.shape

# %%
# df.sort_values(['date','tic']).head()

# %%
# len(df.tic.unique())

# %%
# df.tic.value_counts()

# %% [markdown]
# <a id='3'></a>
# # Part 4: Preprocess fundamental data
# - Import finanical data downloaded from Alpha Vantage
# - Preprocess the dataset and calculate financial ratios
# - Turn yearly ratio into daily basis

# %% [markdown]
# <a id='3.1'></a>
# ## 4.1 Import the financial data

# %% [markdown]
# #### Define configurations of the collecting data & download data via Alpha Vantage API

# %%
# import requests

# api_key = 'GZWRUSYXT18ZTR6C'
# features_cols = ['fiscalDateEnding','totalRevenue','costOfRevenue','sellingGeneralAndAdministrative','researchAndDevelopment','depreciation','interestExpense','totalCurrentLiabilities','incomeTaxExpense','netIncome','commonStockSharesOutstanding','cashAndCashEquivalentsAtCarryingValue','cashAndShortTermInvestments','operatingCashflow','totalLiabilities','inventory','currentNetReceivables','propertyPlantEquipment','capitalExpenditures','longTermInvestments','totalShareholderEquity','longTermDebt','retainedEarnings','dividendPayoutCommonStock','paymentsForRepurchaseOfCommonStock','treasuryStock','currentLongTermDebt']
# price_cols = ['open','high','low','close','volume']

# %% [markdown]
# Function to download fundamental data from financial reports by ticket

# %%
# def collect_fundamental(ticket):
#     # Download income statement
#     url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_is = r.json()

#     # Download balance sheet
#     url = f'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_bs = r.json()

#     # Download cash flow
#     url = f'https://www.alphavantage.co/query?function=CASH_FLOW&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_cf = r.json()

#     df_is = pd.json_normalize(data_is['annualReports'])
#     df_bs = pd.json_normalize(data_bs['annualReports'])
#     df_cf = pd.json_normalize(data_cf['annualReports'])

#     merged_df = df_is.merge(df_bs).merge(df_cf)
#     merged_df['tic'] = ticket
#     merged_df = merged_df[['tic']+features_cols]
#     merged_df['fiscalDateEnding'] = pd.to_datetime(merged_df.fiscalDateEnding,format='mixed')

#     return merged_df

# %% [markdown]
# Function to download stock price by ticket

# %%
# def collect_price(ticket):
#     url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_monthly_price = r.json()

#     price_monthly = pd.DataFrame.from_dict(data_monthly_price['Monthly Time Series'], orient='index')
#     price_monthly.columns = price_cols
#     price_monthly['fiscalDateEnding'] = pd.to_datetime(price_monthly.index,format='mixed')
#     price_monthly.reset_index(inplace=True,drop=True)
#     price_monthly = price_monthly[['fiscalDateEnding','open','high','low','close','volume']]
#     return price_monthly

# %% [markdown]
# Function to merge monthly stock price into yearly fundamental data

# %%
# def merge_price_to_df(merged_df,price_monthly):
#     merged_df['year'] = merged_df.fiscalDateEnding.dt.year
#     merged_df['month'] = merged_df.fiscalDateEnding.dt.month
#     price_monthly['year'] = price_monthly.fiscalDateEnding.dt.year
#     price_monthly['month'] = price_monthly.fiscalDateEnding.dt.month
#     merged_final = pd.merge(merged_df,price_monthly,how="left",on=['year','month'])
#     merged_final.drop(columns=['year','month','fiscalDateEnding_y'],inplace=True)
#     merged_final = df_final.rename(columns={'fiscalDateEnding_x': 'date'})
#     merged_final['tic'] = ticket

#     merged_columns = [merged_final.columns[-1]]
#     for i in range(0,len(merged_final.columns)-1):
#         merged_columns.append(merged_final.columns[i])
#     merged_final = merged_final[merged_columns]
    
#     return merged_final

# %%
# download_tics = SP_500_TICKER[453:]
# print(download_tics)

# %%
# fund_data = pd.DataFrame()

# for ticket in download_tics:
#     df_fund = collect_fundamental(ticket)
#     fund_data = pd.concat([fund_data, df_fund], ignore_index=True)

# %%
# fund_data.to_csv('sp500_6.csv')

# %%
# Check dropped tickers which are not available data to download from Alpha Vantage

# tics_1 = pd.DataFrame()
# tics_2 = pd.DataFrame()
# tics_1['tic'] = df.tic.unique()
# tics_2['tic'] = fund_data.tic.unique()

# merged_df = tics_1.merge(tics_2, how='outer', indicator=True)
# unique_in_df = merged_df[merged_df['_merge'] == 'left_only']
# unique_in_df

# %% [markdown]
# #### Check reach download limitation

# %%
# url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=IBM&apikey=GZWRUSYXT18ZTR6C'
# r = requests.get(url)
# data_is = r.json()
# data_is

# %% [markdown]
# #### Load data from csv file

# %%
fund_data = pd.read_csv('./' + DATA_SAVE_DIR + '/sp500_fundamental.csv',index_col=0)
# fund_data = fund_data.rename(columns={'fiscalDateEnding_x':'date'})
fund_data['date'] = pd.to_datetime(fund_data.date,format='mixed')
fund_data
# Out:
#        tic       date  totalRevenue  costOfRevenue  \
# 0     WYNN 2023-12-31    6041535000     1856250000
# 1     WYNN 2022-12-31    3310708000     1581172000
# 2     WYNN 2021-12-31    3369783000     1529675000
# 3     WYNN 2020-12-31    1656561000     1452857000
# 4     WYNN 2019-12-31    6181404000     1623557000
# ...    ...        ...           ...            ...
# 6776   DLR 2014-12-31    1616438000     1239395000
# 6777   DLR 2013-12-31    1482259000     1094847000
# 6778   DLR 2012-12-31    1279067000      912989000
# 6779   DLR 2011-12-31    1062710000      884076000
# 6780   DLR 2010-12-31     865401000       90400000
#
#       sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                        1.065022e+09                     0.0   625000000.0
# 1                        8.304500e+08                     0.0   652100000.0
# 2                        7.965920e+08                     0.0   685700000.0
# 3                        7.208490e+08                     0.0   699600000.0
# 4                        8.966700e+08                     0.0   602900000.0
# ...                               ...                     ...           ...
# 6776                     9.318800e+07                     0.0           0.0
# 6777                     6.565300e+07                     0.0           0.0
# 6778                     5.720900e+07                     0.0           0.0
# 6779                     5.362400e+07                     0.0           0.0
# 6780                     4.719600e+07                     0.0           0.0
#
#       interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0         751509000.0             2.200454e+09        -496834000  ...
# 1         650885000.0             1.811423e+09           9332000  ...
# 2         605562000.0             1.287880e+09            474000  ...
# 3         556474000.0             1.880888e+09         564671000  ...
# 4         414030000.0             1.982884e+09         176840000  ...
# ...               ...                      ...               ...  ...
# 6776      191085000.0             1.252657e+09           5238000  ...
# 6777      189399000.0             1.489864e+09           1292000  ...
# 6778      157108000.0             1.463590e+09           2647000  ...
# 6779      149350000.0             3.905880e+08            -42000  ...
# 6780      137384000.0             2.888410e+08           1851000  ...
#
#       retainedEarnings  dividendPayoutCommonStock  \
# 0        -2.066953e+09                 84733000.0
# 1        -2.711808e+09                  1445000.0
# 2        -2.288078e+09                  1553000.0
# 3        -1.532420e+09                108777000.0
# 4         6.418180e+08                566521000.0
# ...                ...                        ...
# 6776     -1.096603e+09                441694000.0
# 6777     -7.852220e+08                400953000.0
# 6778     -6.561040e+08                334429000.0
# 6779     -4.886920e+08                261286000.0
# 6780     -3.481480e+08                171549000.0
#
#       paymentsForRepurchaseOfCommonStock  treasuryStock  currentLongTermDebt  \
# 0                            212455000.0   1.836326e+09         7.095930e+08
# 1                            187499000.0   1.623872e+09         5.475430e+08
# 2                             13842000.0   1.436373e+09         5.000000e+07
# 3                             11533000.0   1.422531e+09         5.964080e+08
# 4                             66986000.0   1.410998e+09         3.238760e+08
# ...                                  ...            ...                  ...
# 6776                                 0.0   0.000000e+00         4.673127e+09
# 6777                                 0.0   0.000000e+00         0.000000e+00
# 6778                                 0.0   0.000000e+00         0.000000e+00
# 6779                                 0.0   0.000000e+00         0.000000e+00
# 6780                                 0.0   0.000000e+00         0.000000e+00
#
#             open        high         low       close     volume
# 0      90.830002   95.680000   90.680000   94.376312  3013600.0
# 1      86.120003   86.500000   83.930000   84.742332  3318600.0
# 2      85.510002   86.839996   84.889999   84.178108  2406200.0
# 3     112.769997  113.919998  110.059998  111.686455  2103400.0
# 4     138.660004  140.070007  138.250000  136.318619  1142600.0
# ...          ...         ...         ...         ...        ...
# 6776   67.139999   67.900002   66.190002   46.811867   653700.0
# 6777   48.750000   49.419998   48.700001   32.833439  1259300.0
# 6778   67.379997   67.980003   67.230003   42.913818   757000.0
# 6779   67.830002   68.010002   65.879997   40.241833   866200.0
# 6780   51.779999   52.380001   51.450001   29.862902  1427300.0
#
# [6781 rows x 33 columns]

# %%
# UTIL TOOL: merge yearly fundamental data to daily stock price

# start_date = df.iloc[0].date
# end_date = df.iloc[-1].date
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')
# date_range = pd.DataFrame(date_range)
# date_range.columns = ['date']

# fund_data = fund_data.rename(columns={'fiscalDateEnding':'date'})
# fund_data['date'] = pd.to_datetime(fund_data.date,format='mixed')

# fund_data_with_price = pd.DataFrame()
# for ticket in fund_data.tic.unique():
#     price_by_ticket = df[df.tic == ticket]
#     price_by_ticket['date'] = pd.to_datetime(price_by_ticket['date'],format='mixed')
#     price_by_ticket = pd.merge(date_range,price_by_ticket,how='left')
#     price_by_ticket.bfill(inplace=True)
#     price_by_ticket = pd.merge(fund_data.loc[fund_data.tic==ticket],price_by_ticket,how='left',on=['date'])
#     price_by_ticket.drop(columns=['tic_y','day'],inplace=True,axis=0)
#     price_by_ticket = price_by_ticket.rename(columns={'tic_x':'tic'})
#     fund_data_with_price = pd.concat([fund_data_with_price, price_by_ticket], ignore_index=True)

# %% [markdown]
# #### Data cleaning ####
# Refine the data before computing fundamental ratios

# %%
print(fund_data.info(),'\n')
print(fund_data.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6740 entries, 0 to 6780
# Data columns (total 33 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tic                                    6740 non-null   object
#  1   date                                   6740 non-null   datetime64[ns]
#  2   totalRevenue                           6740 non-null   int64
#  3   costOfRevenue                          6740 non-null   int64
#  4   sellingGeneralAndAdministrative        6740 non-null   float64
#  5   researchAndDevelopment                 6740 non-null   float64
#  6   depreciation                           6740 non-null   float64
#  7   interestExpense                        6740 non-null   float64
#  8   totalCurrentLiabilities                6740 non-null   float64
#  9   incomeTaxExpense                       6740 non-null   int64
#  10  netIncome                              6740 non-null   int64
#  11  commonStockSharesOutstanding           6740 non-null   float64
#  12  cashAndCashEquivalentsAtCarryingValue  6740 non-null   float64
#  13  cashAndShortTermInvestments            6740 non-null   float64
#  14  operatingCashflow                      6740 non-null   int64
#  15  totalLiabilities                       6740 non-null   int64
#  16  inventory                              6740 non-null   float64
#  17  currentNetReceivables                  6740 non-null   float64
#  18  propertyPlantEquipment                 6740 non-null   float64
#  19  capitalExpenditures                    6740 non-null   float64
#  20  longTermInvestments                    6740 non-null   float64
#  21  totalShareholderEquity                 6740 non-null   int64
#  22  longTermDebt                           6740 non-null   float64
#  23  retainedEarnings                       6740 non-null   float64
#  24  dividendPayoutCommonStock              6740 non-null   float64
#  25  paymentsForRepurchaseOfCommonStock     6740 non-null   float64
#  26  treasuryStock                          6740 non-null   float64
#  27  currentLongTermDebt                    6740 non-null   float64
#  28  open                                   6740 non-null   float64
#  29  high                                   6740 non-null   float64
#  30  low                                    6740 non-null   float64
#  31  close                                  6740 non-null   float64
#  32  volume                                 6740 non-null   float64
# dtypes: datetime64[ns](1), float64(24), int64(7), object(1)
# memory usage: 1.7+ MB
# None
#
# tic                                      0
# date                                     0
# totalRevenue                             0
# costOfRevenue                            0
# sellingGeneralAndAdministrative          0
# researchAndDevelopment                   0
# depreciation                             0
# interestExpense                          0
# totalCurrentLiabilities                  0
# incomeTaxExpense                         0
# netIncome                                0
# commonStockSharesOutstanding             0
# cashAndCashEquivalentsAtCarryingValue    0
# cashAndShortTermInvestments              0
# operatingCashflow                        0
# totalLiabilities                         0
# inventory                                0
# currentNetReceivables                    0
# propertyPlantEquipment                   0
# capitalExpenditures                      0
# longTermInvestments                      0
# totalShareholderEquity                   0
# longTermDebt                             0
# retainedEarnings                         0
# dividendPayoutCommonStock                0
# paymentsForRepurchaseOfCommonStock       0
# treasuryStock                            0
# currentLongTermDebt                      0
# open                                     0
# high                                     0
# low                                      0
# close                                    0
# volume                                   0
# dtype: int64

# %% [markdown]
# The company with zero totalRevenue might cause problems for computing ratios while it is the denominator in some formulars.<br>
# Deleting all tickers containing this issue is a good solution.

# %%
zero_revenue_tics = fund_data[fund_data.totalRevenue == 0].tic.unique()
fund_data = fund_data[~fund_data.tic.isin(zero_revenue_tics)]
fund_data[fund_data.totalRevenue == 0]
# Out:
# Empty DataFrame
# Columns: [tic, date, totalRevenue, costOfRevenue, sellingGeneralAndAdministrative, researchAndDevelopment, depreciation, interestExpense, totalCurrentLiabilities, incomeTaxExpense, netIncome, commonStockSharesOutstanding, cashAndCashEquivalentsAtCarryingValue, cashAndShortTermInvestments, operatingCashflow, totalLiabilities, inventory, currentNetReceivables, propertyPlantEquipment, capitalExpenditures, longTermInvestments, totalShareholderEquity, longTermDebt, retainedEarnings, dividendPayoutCommonStock, paymentsForRepurchaseOfCommonStock, treasuryStock, currentLongTermDebt, open, high, low, close, volume]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# While removing zero revenue data was neccessary, other columns with zero values might indicate some potential issues that require further investigations

# %%
column_nan = fund_data.eq(0).any()
column_nan
# Out:
# tic                                      False
# date                                     False
# totalRevenue                             False
# costOfRevenue                            False
# sellingGeneralAndAdministrative           True
# researchAndDevelopment                    True
# depreciation                              True
# interestExpense                           True
# totalCurrentLiabilities                   True
# incomeTaxExpense                          True
# netIncome                                 True
# commonStockSharesOutstanding              True
# cashAndCashEquivalentsAtCarryingValue     True
# cashAndShortTermInvestments               True
# operatingCashflow                         True
# totalLiabilities                         False
# inventory                                 True
# currentNetReceivables                     True
# propertyPlantEquipment                    True
# capitalExpenditures                       True
# longTermInvestments                       True
# totalShareholderEquity                    True
# longTermDebt                              True
# retainedEarnings                          True
# dividendPayoutCommonStock                 True
# paymentsForRepurchaseOfCommonStock        True
# treasuryStock                             True
# currentLongTermDebt                       True
# open                                     False
# high                                     False
# low                                      False
# close                                    False
# volume                                    True
# dtype: bool

# %%
# fund_data = fund_data.fillna(0)
# for i in fund_data.columns:
#     print(i,'\n',fund_data[i].unique(),'\n')

# %% [markdown]
# ## 4.2 Compute fundamental ratio

# %% [markdown]
# Define support functions before computing fundamental ratios

# %%
# Define a function to count positive values within a window
def count_positives(window):
  return window[window > 0].count()

def count_positives_window(data,k):
    df = pd.DataFrame(data, columns=['values'])

    # Create a new column with the adjusted positive count (using a shifted window)
    df['positive_count'] = df['values'].rolling(window=k, min_periods=1).apply(count_positives)

    # Set positive_count of the first k rows to positive_count of row k
    df.loc[:k-1,'positive_count'] = df.loc[k-1].positive_count

    return df

# %%
# Define a function to min value within a window
def get_min(window):
  return window.min()

def min_in_window(data,k):
    df = pd.DataFrame(data, columns=['values'])

    # Create a new column with the min in the window (using a shifted window)
    df['min'] = df['values'].rolling(window=k, min_periods=1).apply(get_min)

    return df

# %% [markdown]
# At this point, data and supporting functions are ready for computing fundamental ratios required

# %%
def compute_fund_ratios(df_final):
    pos_count_window = 10  # number of years to look back for count_positive_profit
    min_ebit_window = 4  # number of years to look back for min_ebit
    
    gross_income = df_final.totalRevenue - df_final.costOfRevenue
    ebit = gross_income - df_final.sellingGeneralAndAdministrative
    profit = ebit - df_final.interestExpense - df_final.incomeTaxExpense
    market_equity = df_final.commonStockSharesOutstanding * df_final.close
    market_asset = df_final.totalLiabilities + market_equity
    
    # Gross profit margin
    gross_profit_margin = (gross_income/df_final.totalRevenue).to_frame('gross_profit_margin')
    
    # SGA Expense / Gross Profit
    sga_ratio = (df_final.sellingGeneralAndAdministrative/gross_income).to_frame('sga_ratio')
    
    # Depreciation / Gross Profit
    dep_ratio = (df_final.depreciation/gross_income).to_frame('dep_ratio')
    
    # EBIT / Bond interest
    ebit_on_int = (ebit/df_final.interestExpense).to_frame('ebit_on_int')
    
    # Profit margin
    profit_margin = (profit/df_final.totalRevenue).to_frame('profit_margin')
    
    # Amount of positive profit within a window
    count_positive_profit = count_positives_window(profit,pos_count_window)
    count_positive_profit = count_positive_profit['positive_count'].to_frame('count_positive_profit')
    
    # Cash And Short Term Investments / Total Liabilities
    csti_on_liabilities = (df_final.cashAndShortTermInvestments/df_final.totalLiabilities).to_frame('csti_on_liabilities')
    
    # Inventory / EBIT
    inventory_on_ebit = (df_final.inventory / ebit).to_frame('inventory_on_ebit')
    
    # Receivable / Revenue
    receivable_on_rev = (df_final.currentNetReceivables / df_final.totalRevenue).to_frame('receivable_on_rev')
    
    # ROA
    roa = (profit / market_asset).to_frame('roa')
    
    # ROE
    roe = (profit / market_equity).to_frame('roe')
    
    # Long-term debt / minEBIT
    min_ebit = min_in_window(ebit,min_ebit_window)['min']
    debt_on_min_ebit = (df_final.longTermDebt / min_ebit).to_frame('debt_on_min_ebit')
    
    # Total Liabilities / Total Equity
    liabilities_on_equity = (df_final.totalLiabilities / market_equity).to_frame('liabilities_on_equity')
    
    # Capital Expenditures / EBIT
    capital_cost_on_ebit = (df_final.capitalExpenditures / ebit).to_frame('capital_cost_on_ebit')
    
    # EPS / MP
    eps = profit / df_final.commonStockSharesOutstanding
    eps_on_mp = (eps / df_final.close).to_frame('eps_on_mp')
    
    # Cash and Stock Dividend & Repurchase Common / MP
    dividend_on_mp = ((df_final.dividendPayoutCommonStock + df_final.paymentsForRepurchaseOfCommonStock) / df_final.close).to_frame('dividend_on_mp')
    
    # MP / BV
    mp_on_bv = (df_final.close / (df_final.cashAndShortTermInvestments + df_final.currentNetReceivables*0.8 +df_final.inventory*0.5 + df_final.propertyPlantEquipment*0.2 + df_final.longTermInvestments - df_final.totalLiabilities)).to_frame('mp_on_bv')

    # Create a dataframe that merges all the ratios
    ratios = pd.concat([df_final.date,df_final.tic,gross_profit_margin,sga_ratio,dep_ratio,
                    ebit_on_int,profit_margin,count_positive_profit,csti_on_liabilities,
                    inventory_on_ebit,receivable_on_rev,roa,roe,debt_on_min_ebit,
                   liabilities_on_equity,capital_cost_on_ebit,eps_on_mp,dividend_on_mp,mp_on_bv], axis=1)

    return ratios

# %%
ratios = compute_fund_ratios(fund_data)
ratios.head()
# Out:
#         date   tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 0 2023-12-31  WYNN             0.692752   0.254468   0.149333     4.151997
# 1 2022-12-31  WYNN             0.522407   0.480158   0.377038     1.381328
# 2 2021-12-31  WYNN             0.546061   0.432905   0.372641     1.723219
# 3 2020-12-31  WYNN             0.122968   3.538708   3.434395    -0.929325
# 4 2019-12-31  WYNN             0.737348   0.196731   0.132277     8.842782
#
#    profit_margin  count_positive_profit  csti_on_liabilities  \
# 0       0.474315                    7.0             0.210264
# 1       0.072150                    7.0             0.242466
# 2       0.129824                    7.0             0.188713
# 3      -0.988971                    7.0             0.238383
# 4       0.496701                    7.0             0.190749
#
#    inventory_on_ebit  receivable_on_rev       roa       roe  debt_on_min_ebit  \
# 0           0.024213           0.056560  0.111751  0.271740          3.761970
# 1           0.077961           0.065253  0.009685  0.024864         13.476863
# 2           0.067049           0.059192  0.018932  0.044913         13.274087
# 3          -0.128175           0.120827 -0.061459 -0.135961        -25.265196
# 4           0.024178           0.056044  0.113861  0.209782        -20.117876
#
#    liabilities_on_equity  capital_cost_on_ebit  eps_on_mp  dividend_on_mp  \
# 0               1.431641              0.141909   0.271740    3.148968e+06
# 1               1.567104              0.333813   0.024864    2.229629e+06
# 2               1.372292              0.278536   0.044913    1.828860e+05
# 3               1.212222             -0.560994  -0.135961    1.077212e+06
# 4               0.842447              0.290424   0.209782    4.647252e+06
#
#        mp_on_bv
# 0 -9.267999e-09
# 1 -8.666597e-09
# 2 -9.461515e-09
# 3 -1.228372e-08
# 4 -1.763105e-08

# %% [markdown]
# Check columns with inf values

# %%
ratio_list = ratios.columns.drop(['date','tic'])
check_ratios = ratios[ratio_list]
inf_cols = check_ratios.columns[~np.isfinite(check_ratios).all()]
inf_cols
# Out:
# Index(['sga_ratio', 'dep_ratio', 'ebit_on_int', 'roe', 'liabilities_on_equity',
#        'eps_on_mp'],
#       dtype='object')

# %% [markdown]
# Check rows with inf values

# %%
ratio_inf = ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
print(len(ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]))
ratio_inf.head()
# Out:
# 162
#           date   tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 196 2018-12-31  MKTX             0.642616   0.083840        0.0          inf
# 197 2017-12-31  MKTX             0.897569   0.061265        0.0          inf
# 198 2016-12-31  MKTX             0.885378   0.074997        0.0          inf
# 199 2015-12-31  MKTX             0.875624   0.072178        0.0          inf
# 200 2014-12-31  MKTX             0.936360   0.062682        0.0          inf
#
#      profit_margin  count_positive_profit  csti_on_liabilities  \
# 196       0.484887                    6.0             3.872429
# 197       0.710454                    7.0             3.934205
# 198       0.642100                    8.0             4.060987
# 199       0.641314                    9.0             4.132759
# 200       0.711250                   10.0             3.698310
#
#      inventory_on_ebit  receivable_on_rev       roa       roe  \
# 196          -0.087617                0.0  0.027365  0.027679
# 197          -0.054677                0.0  0.039252  0.039610
# 198          -0.038349                0.0  0.044101  0.044598
# 199          -0.040123                0.0  0.049077  0.049684
# 200          -0.028986                0.0  0.073826  0.075183
#
#      debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  eps_on_mp  \
# 196          0.006629               0.011488              0.185596   0.027679
# 197          0.003510               0.009121              0.074659   0.039610
# 198          0.003510               0.011271              0.061075   0.044598
# 199          0.004467               0.012353              0.062475   0.049684
# 200          0.000000               0.018374              0.064116   0.075183
#
#      dividend_on_mp      mp_on_bv
# 196   432139.938320  4.109673e-07
# 197   471608.445084  4.474490e-07
# 198   440011.418818  3.747320e-07
# 199   503828.206985  5.238294e-07
# 200   929468.875771  4.293658e-07

# %% [markdown]
# The **ebit_on_int** has infinity values for companies without banking support. We need to address these cases separately: <br>
#  * Replace positive inf with maximum value in ebit_on_int
#  * Replace negative inf with minimum value in ebit_on_int

# %%
ratio_finite = ratios[~((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
ratios['ebit_on_int'] = ratios.ebit_on_int.replace(np.inf,ratio_finite.ebit_on_int.max())
ratios['ebit_on_int'] = ratios.ebit_on_int.replace(-np.inf,ratio_finite.ebit_on_int.min())
print(len(ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]))
# Out:
# 4

# %% [markdown]
# While data processing greatly reduces the number of inf values, some still remain.<br>
# Since the remain inf values represent a small portion of the data, we can safely remove the corresponding rows

# %%
ratios = ratios[~((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
ratios.reset_index(inplace=True,drop=True)
check_ratios = ratios[ratio_list]
inf_cols = check_ratios.columns[~np.isfinite(check_ratios).all()]
inf_cols
# Out:
# Index([], dtype='object')

# %% [markdown]
# <a id='3.3'></a>
# ## 4.3 Turn the final_ratios to monthly basis¶
# After our initial inspection, we’ll want to dig deeper to investigate the following:
# - The data type of each variable.
# - How discrete/categorical data is coded (and whether we need to make any changes).
# - How the data are scaled.
# - Whether there is missing data and how it is coded.
# - Whether there are outliers.
# - The distributions of continuous features.
# - The relationships between pairs of features.

# %% [markdown]
# ### Data types
# It is important to check the data type for each feature. <br>
# The **date** should be in datetime type <br>
# The **ratios** should be read in as float64 — and categorical variables should be stored as object

# %%
ratios['date'] = pd.to_datetime(ratios['date'],format='mixed')
ratios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6736 entries, 0 to 6735
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   6736 non-null   datetime64[ns]
#  1   tic                    6736 non-null   object
#  2   gross_profit_margin    6736 non-null   float64
#  3   sga_ratio              6736 non-null   float64
#  4   dep_ratio              6736 non-null   float64
#  5   ebit_on_int            6736 non-null   float64
#  6   profit_margin          6736 non-null   float64
#  7   count_positive_profit  6736 non-null   float64
#  8   csti_on_liabilities    6736 non-null   float64
#  9   inventory_on_ebit      6736 non-null   float64
#  10  receivable_on_rev      6736 non-null   float64
#  11  roa                    6736 non-null   float64
#  12  roe                    6736 non-null   float64
#  13  debt_on_min_ebit       6736 non-null   float64
#  14  liabilities_on_equity  6736 non-null   float64
#  15  capital_cost_on_ebit   6736 non-null   float64
#  16  eps_on_mp              6736 non-null   float64
#  17  dividend_on_mp         6736 non-null   float64
#  18  mp_on_bv               6736 non-null   float64
# dtypes: datetime64[ns](1), float64(17), object(1)
# memory usage: 1000.0+ KB

# %% [markdown]
# We see that there is no missing values from all ratios

# %%
ratios.head()
# Out:
#         date   tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 0 2023-12-31  WYNN             0.692752   0.254468   0.149333     4.151997
# 1 2022-12-31  WYNN             0.522407   0.480158   0.377038     1.381328
# 2 2021-12-31  WYNN             0.546061   0.432905   0.372641     1.723219
# 3 2020-12-31  WYNN             0.122968   3.538708   3.434395    -0.929325
# 4 2019-12-31  WYNN             0.737348   0.196731   0.132277     8.842782
#
#    profit_margin  count_positive_profit  csti_on_liabilities  \
# 0       0.474315                    7.0             0.210264
# 1       0.072150                    7.0             0.242466
# 2       0.129824                    7.0             0.188713
# 3      -0.988971                    7.0             0.238383
# 4       0.496701                    7.0             0.190749
#
#    inventory_on_ebit  receivable_on_rev       roa       roe  debt_on_min_ebit  \
# 0           0.024213           0.056560  0.111751  0.271740          3.761970
# 1           0.077961           0.065253  0.009685  0.024864         13.476863
# 2           0.067049           0.059192  0.018932  0.044913         13.274087
# 3          -0.128175           0.120827 -0.061459 -0.135961        -25.265196
# 4           0.024178           0.056044  0.113861  0.209782        -20.117876
#
#    liabilities_on_equity  capital_cost_on_ebit  eps_on_mp  dividend_on_mp  \
# 0               1.431641              0.141909   0.271740    3.148968e+06
# 1               1.567104              0.333813   0.024864    2.229629e+06
# 2               1.372292              0.278536   0.044913    1.828860e+05
# 3               1.212222             -0.560994  -0.135961    1.077212e+06
# 4               0.842447              0.290424   0.209782    4.647252e+06
#
#        mp_on_bv
# 0 -9.267999e-09
# 1 -8.666597e-09
# 2 -9.461515e-09
# 3 -1.228372e-08
# 4 -1.763105e-08

# %%
ratios.tail()
# Out:
#            date  tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 6731 2014-12-31  DLR             0.233255   0.247155        0.0     1.485491
# 6732 2013-12-31  DLR             0.261366   0.169466        0.0     1.698842
# 6733 2012-12-31  DLR             0.286207   0.156275        0.0     1.965966
# 6734 2011-12-31  DLR             0.168093   0.300189        0.0     0.837027
# 6735 2010-12-31  DLR             0.895540   0.060898        0.0     5.297597
#
#       profit_margin  count_positive_profit  csti_on_liabilities  \
# 6731       0.054151                   10.0             0.009421
# 6732       0.088424                   10.0             0.016248
# 6733       0.116580                   10.0             0.018856
# 6734      -0.022864                    9.0             0.027229
# 6735       0.680112                    9.0             0.021919
#
#       inventory_on_ebit  receivable_on_rev       roa       roe  \
# 6731                0.0                0.0  0.007318  0.013787
# 6732                0.0                0.0  0.012852  0.031076
# 6733                0.0                0.0  0.013947  0.027767
# 6734                0.0                0.0 -0.003121 -0.005694
# 6735                0.0                0.0  0.098142  0.216205
#
#       debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 6731         11.169703               0.884016              3.088517
# 6732         10.392066               1.417933              4.226244
# 6733          8.915105               0.990794              7.789357
# 6734         23.519798               0.824462              6.668091
# 6735         22.453836               1.202970              2.347794
#
#       eps_on_mp  dividend_on_mp      mp_on_bv
# 6731   0.013787    9.435513e+06  1.683652e-08
# 6732   0.031076    1.221173e+07  1.242458e-08
# 6733   0.027767    7.793038e+06 -8.550406e-09
# 6734  -0.005694    6.492895e+06 -1.224601e-08
# 6735   0.216205    5.744552e+06 -9.669366e-09

# %% [markdown]
# ### Turn the final_ratios to monthly basis

# %%
# UTIL TOOL: Get monthly price for each company

def get_end_month_price (df):
    # Set date as index
    df.set_index('date', inplace=True)
    # Resample by month and get the last day of each month
    last_day_of_month = df.resample('M').last()
    df = df.reset_index()
    return last_day_of_month

df['date'] = pd.to_datetime(df.date,format='mixed')
monthly_price = pd.DataFrame()
for ticket in fund_data.tic.unique():
    price_by_tic = get_end_month_price(df[df.tic == ticket])
    monthly_price = pd.concat([monthly_price, price_by_tic])

# %%
start_date = df.iloc[0].date
end_date = df.iloc[-1].date
date_range = pd.date_range(start=start_date, end=end_date, freq='D')
date_range = pd.DataFrame(date_range)
date_range.columns = ['date']
date_range.head()
# Out:
#         date
# 0 2002-10-31
# 1 2002-11-01
# 2 2002-11-02
# 3 2002-11-03
# 4 2002-11-04

# %% [markdown]
# Interpolate missing data in the middle of years for each ticket

# %%
daily_ratios = pd.DataFrame()
for ticket in ratios.tic.unique():
    # Interpolate data for each ticket
    one_tic_ratios = pd.merge(date_range,ratios[ratios.tic == ticket],how="left",on=['date'])
    one_tic_ratios['tic'] = ticket
    one_tic_ratios = one_tic_ratios.interpolate('linear')
    daily_ratios = pd.concat([daily_ratios, one_tic_ratios], ignore_index=True)

    # Check data by drawing it out
    # %matplotlib inline
    # plt.figure(figsize=(16, 4)) 
    # plt.plot(one_tic_ratios.date, one_tic_ratios.gross_profit_margin, color = 'red')
    # plt.title(f'Gross profit margin of {ticket}')
    # plt.show()

# %%
daily_ratios.dropna(subset='gross_profit_margin',inplace=True)
daily_ratios.reset_index(inplace=True,drop=True)

# %% [markdown]
# <a id='3.4'></a>
# ## 4.4 Merge stock price data and ratios into one dataframe
# - Merge the price dataframe preprocessed in Part 3 and the ratio dataframe created in this part
# - Since the prices are daily and ratios are quartely, we have NAs in the ratio columns after merging the two dataframes. We deal with this by backfilling the ratios.

# %%
df_date = pd.DataFrame(df)[['date','tic','close']]
df_date.columns = ['date','tic','close']
df_date['date'] = pd.to_datetime(df_date.date)
final_ratios = pd.merge(df_date,daily_ratios,how="left",on=['date','tic'])

# %%
final_ratios.dropna(subset=['gross_profit_margin'],inplace=True,how='any')
final_ratios.reset_index(drop=True,inplace=True)
final_ratios.isna().sum()
# Out:
# date                     0
# tic                      0
# close                    0
# gross_profit_margin      0
# sga_ratio                0
# dep_ratio                0
# ebit_on_int              0
# profit_margin            0
# count_positive_profit    0
# csti_on_liabilities      0
# inventory_on_ebit        0
# receivable_on_rev        0
# roa                      0
# roe                      0
# debt_on_min_ebit         0
# liabilities_on_equity    0
# capital_cost_on_ebit     0
# eps_on_mp                0
# dividend_on_mp           0
# mp_on_bv                 0
# dtype: int64

# %%
# final_ratios.to_csv('./' + DATA_SAVE_DIR + '/sp500_ready_data_monthly.csv')

# %% [markdown]
# <a id='3.5'></a>
# ## 4.5 Finish data preparation

# %%
# If the data is available in the data storage, load processed_full from readied data
processed_full = pd.read_csv('./' + DATA_SAVE_DIR + '/sp500_ready_data_monthly.csv',index_col=0)
processed_full['date'] = pd.to_datetime(processed_full.date,format='mixed')
processed_full
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#             date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0     2010-12-31  WYNN   73.214867             0.211086   0.442929   0.447057
# 1     2011-01-31  WYNN   82.021240             0.213774   0.431861   0.435689
# 2     2011-02-28  WYNN   86.674721             0.216202   0.421864   0.425421
# 3     2011-03-31  WYNN   89.657188             0.218889   0.410796   0.414053
# 4     2011-04-30  WYNN  104.108864             0.221490   0.400084   0.403052
# ...          ...   ...         ...                  ...        ...        ...
# 77024 2023-11-30   DLR  136.375320             0.585775   0.141156   0.000000
# 77025 2023-12-31   DLR  133.439255             0.586954   0.139685   0.000000
# 77026 2024-01-31   DLR  139.269424             0.586954   0.139685   0.000000
# 77027 2024-02-29   DLR  145.565582             0.586954   0.139685   0.000000
# 77028 2024-03-31   DLR  142.210007             0.586954   0.139685   0.000000
#
#        ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0         2.207989       0.059447               8.000000             0.293089
# 1         2.336475       0.065084               7.915068             0.293346
# 2         2.452528       0.070176               7.838356             0.293578
# 3         2.581014       0.075813               7.753425             0.293836
# 4         2.705356       0.081269               7.671233             0.294084
# ...            ...            ...                    ...                  ...
# 77024     6.425107       0.411360               1.084932             0.064895
# 77025     6.318181       0.411244               1.000000             0.070316
# 77026     6.318181       0.411244               1.000000             0.070316
# 77027     6.318181       0.411244               1.000000             0.070316
# 77028     6.318181       0.411244               1.000000             0.070316
#
#        inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0               0.176490           0.044797  0.018542  0.027270
# 1               0.168655           0.044943  0.020557  0.030128
# 2               0.161577           0.045075  0.022376  0.032710
# 3               0.153742           0.045221  0.024391  0.035569
# 4               0.146159           0.045362  0.026341  0.038335
# ...                  ...                ...       ...       ...
# 77024           0.064176           0.000000  0.035026  0.055106
# 77025           0.000000           0.000000  0.034707  0.053909
# 77026           0.000000           0.000000  0.034707  0.053909
# 77027           0.000000           0.000000  0.034707  0.053909
# 77028           0.000000           0.000000  0.034707  0.053909
#
#        debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0              6.640253               0.470693              0.576794
# 1              6.528927               0.468225              0.546087
# 2              6.428374               0.465995              0.518353
# 3              6.317048               0.463527              0.487647
# 4              6.209312               0.461139              0.457931
# ...                 ...                    ...                   ...
# 77024         -3.871747               0.571512              1.265520
# 77025         -3.660527               0.553281              1.274745
# 77026         -3.660527               0.553281              1.274745
# 77027         -3.660527               0.553281              1.274745
# 77028         -3.660527               0.553281              1.274745
#
#        eps_on_mp  dividend_on_mp      mp_on_bv
# 0       0.027270    1.628273e+07 -3.950014e-08
# 1       0.030128    1.594436e+07 -3.974793e-08
# 2       0.032710    1.563873e+07 -3.997174e-08
# 3       0.035569    1.530035e+07 -4.021954e-08
# 4       0.038335    1.497289e+07 -4.045934e-08
# ...          ...             ...           ...
# 77024   0.055106    1.163776e+07 -6.910170e-09
# 77025   0.053909    1.134100e+07 -7.065183e-09
# 77026   0.053909    1.134100e+07 -7.065183e-09
# 77027   0.053909    1.134100e+07 -7.065183e-09
# 77028   0.053909    1.134100e+07 -7.065183e-09
#
# [77029 rows x 20 columns]

# %%
processed_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77029 entries, 0 to 77028
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   77029 non-null  datetime64[ns]
#  1   tic                    77029 non-null  object
#  2   close                  77029 non-null  float64
#  3   gross_profit_margin    77029 non-null  float64
#  4   sga_ratio              77029 non-null  float64
#  5   dep_ratio              77029 non-null  float64
#  6   ebit_on_int            77029 non-null  float64
#  7   profit_margin          77029 non-null  float64
#  8   count_positive_profit  77029 non-null  float64
#  9   csti_on_liabilities    77029 non-null  float64
#  10  inventory_on_ebit      77029 non-null  float64
#  11  receivable_on_rev      77029 non-null  float64
#  12  roa                    77029 non-null  float64
#  13  roe                    77029 non-null  float64
#  14  debt_on_min_ebit       77029 non-null  float64
#  15  liabilities_on_equity  77029 non-null  float64
#  16  capital_cost_on_ebit   77029 non-null  float64
#  17  eps_on_mp              77029 non-null  float64
#  18  dividend_on_mp         77029 non-null  float64
#  19  mp_on_bv               77029 non-null  float64
# dtypes: datetime64[ns](1), float64(18), object(1)
# memory usage: 12.3+ MB

# %%
processed_full = processed_full[processed_full.tic.isin(DOW_30_TICKER)]
processed_full.tic.unique()
# Out:
# array(['WBA', 'AAPL', 'MSFT', 'V', 'UNH', 'JNJ', 'JPM', 'WMT', 'PG', 'HD',
#        'CVX', 'MRK', 'KO', 'CSCO', 'MCD', 'CRM', 'NKE', 'DIS', 'AMGN',
#        'CAT', 'VZ', 'INTC', 'BA', 'IBM', 'HON', 'AXP', 'GS', 'MMM', 'DOW',
#        'TRV'], dtype=object)

# %% [markdown]
# Reset **TRAIN_START_DATE** and **TEST_END_DATE**

# %%
TRAIN_START_DATE = processed_full.date.min().strftime("%Y-%m-%d")
TEST_END_DATE = processed_full.date.max().strftime("%Y-%m-%d")
print('TRAIN_START_DATE: ',TRAIN_START_DATE,'\n')
print('TRAIN_END_DATE: ',TRAIN_END_DATE,'\n')
print('TEST_START_DATE: ',TEST_START_DATE,'\n')
print('TEST_END_DATE: ',TEST_END_DATE,'\n')
# Out:
# TRAIN_START_DATE:  2009-09-30
#
# TRAIN_END_DATE:  2021-01-01
#
# TEST_START_DATE:  2021-01-01
#
# TEST_END_DATE:  2024-03-31

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %% [markdown]
# <a id='4.1'></a>
# ## 5.1 Training & Trade Data Split
# - Training data period: 2009-01-01 to 2020-01-01
# - Trade data period: 2020-01-01 to 2023-12-29

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(trade_data))
# Out:
# 3655
# 1140

# %%
train_data = train_data.reset_index(drop=True)
train_data
# Out:
#            date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0    2009-09-30  AAPL    5.604187             0.304696   0.317372   0.000000
# 1    2009-09-30     V   15.578794             0.732890   0.247976   0.000000
# 2    2009-10-31  AAPL    5.699428             0.304017   0.314630   0.000000
# 3    2009-10-31     V   17.077837             0.735809   0.245074   0.000000
# 4    2009-11-30  AAPL    6.044419             0.303359   0.311976   0.000000
# ...         ...   ...         ...                  ...        ...        ...
# 3650 2020-12-31   UNH  335.059784             0.707009   0.229394   0.005501
# 3651 2020-12-31     V  213.664169             0.697420   0.133718   0.000000
# 3652 2020-12-31    VZ   48.816624             0.618534   0.397880   0.179892
# 3653 2020-12-31   WBA   33.866371            -0.009526  -1.021455   0.000000
# 3654 2020-12-31   WMT   45.710587             0.248178   0.837881   0.000000
#
#       ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0       27.374233       0.111106              10.000000             1.479352
# 1       33.121739       0.296050              10.000000             0.670885
# 2       32.630120       0.113588              10.000000             1.433146
# 3       36.047435       0.303752              10.000000             0.673774
# 4       37.716462       0.115990              10.000000             1.388430
# ...           ...            ...                    ...                  ...
# 3650    84.243536       0.519019              10.000000             0.156063
# 3651    26.193962       0.441171               9.000000             0.441947
# 3652    11.250294       0.295529              10.000000             0.078657
# 3653   -39.212650      -0.202215               6.334247             0.012180
# 3654     9.754111       0.024076               4.084699             0.176538
#
#       inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0              0.050986           0.078336  0.228046  0.945331
# 1              0.639013           0.064245  0.091882  0.155239
# 2              0.053108           0.078857  0.230731  0.963965
# 3              0.632417           0.063802  0.095074  0.158929
# 4              0.055161           0.079362  0.233329  0.981998
# ...                 ...                ...       ...       ...
# 3650           0.000000           0.098794  0.300780  0.421057
# 3651           0.269140           0.080325  0.022702  0.025326
# 3652           0.037589           0.186426  0.078316  0.187464
# 3653          -0.305243           0.048514 -0.293656 -0.918168
# 3654           2.007618           0.011682  0.045633  0.109269
#
#       debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0             0.000000               3.145352              0.128194
# 1             0.014702               0.689547              0.080336
# 2             0.000000               3.174256              0.129614
# 3             0.014221               0.676396              0.077720
# 4             0.000000               3.202228              0.130989
# ...                ...                    ...                   ...
# 3650          0.400580               0.399884              0.014640
# 3651          3.067416               0.115467              0.054096
# 3652          2.972570               1.393680              0.425241
# 3653         -0.310980               2.088399             -0.052435
# 3654          2.188798               1.392779              0.460734
#
#       eps_on_mp  dividend_on_mp      mp_on_bv
# 0      0.945331    0.000000e+00  2.618375e-10
# 1      0.155239    1.902586e+08 -1.542455e-08
# 2      0.963965    0.000000e+00  2.647365e-10
# 3      0.158929    1.809975e+08 -1.856696e-08
# 4      0.981998    0.000000e+00  2.675419e-10
# ...         ...             ...           ...
# 3650   0.421057    2.636544e+07 -7.671028e-09
# 3651   0.025326    5.456423e+07 -9.743528e-09
# 3652   0.187464    2.096007e+08 -2.217831e-10
# 3653  -0.918168    8.263157e+07 -8.529535e-10
# 3654   0.109269    2.090669e+08 -4.641799e-10
#
# [3655 rows x 20 columns]

# %%
trade_data = trade_data.reset_index(drop=True)
trade_data
# Out:
#            date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0    2021-01-31  AAPL  129.504669             0.319523   0.218454   0.103238
# 1    2021-01-31  AMGN  217.708099             0.711596   0.302525   0.033894
# 2    2021-01-31   AXP  111.826149             0.176514   1.697894   0.000000
# 3    2021-01-31    BA  194.190002            -0.085335  -0.658330   0.000000
# 4    2021-01-31   CAT  171.592255             0.303381   0.364843   0.164570
# ...         ...   ...         ...                  ...        ...        ...
# 1135 2024-02-29   UNH  491.661804             0.737986   0.199189   0.004011
# 1136 2024-02-29     V  282.640015             0.704715   0.118495   0.000000
# 1137 2024-02-29    VZ   40.020000             0.567685   0.430544   0.196397
# 1138 2024-02-29   WBA   21.260000            -0.066540  -3.659463  -0.000000
# 1139 2024-02-29   WMT   58.411064             0.243754   0.829020   0.000000
#
#       ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0       27.902059       0.203952              10.000000             0.306527
# 1       11.155836       0.416334               7.000000             0.203956
# 2       -2.105818      -0.202210               5.084932             0.187780
# 3       -4.249637      -0.165574               6.084932             0.146597
# 4       16.041624       0.155662              10.000000             0.147812
# ...           ...            ...                    ...                  ...
# 1135    67.659889       0.566194              10.000000             0.169496
# 1136   -30.854037       0.523667               8.000000             0.314608
# 1137     7.840333       0.245525              10.000000             0.006308
# 1138   -75.089655      -0.300945               9.000000             0.010845
# 1139    10.449516       0.029082               1.000000             0.108676
#
#       inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0              0.064123           0.139187  0.026718  0.030204
# 1              0.299618           0.201385  0.068308  0.099096
# 2             -0.719761           0.000000 -0.029549 -0.082446
# 3             -1.805860           0.034362 -0.024994 -0.044602
# 4              1.418429           0.396750  0.042134  0.070558
# ...                 ...                ...       ...       ...
# 1135           0.012749           0.104865  0.313486  0.423878
# 1136           0.240010           0.078065  0.035065  0.039327
# 1137           0.047495           0.194038  0.067325  0.204009
# 1138          -0.189589           0.038307 -0.473656 -2.002519
# 1139           2.032134           0.013571  0.012578  0.014171
#
#       debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0            14.161230               0.131329              0.113005
# 1            25.551601               0.448228              0.047456
# 2           -12.795540               1.768630              0.001715
# 3            -9.837667               0.782739             -0.186545
# 4             3.278032               0.674961              0.261999
# ...                ...                    ...                   ...
# 1135         16.703334               0.352142              0.015417
# 1136         13.643292               0.121541              0.053296
# 1137         74.999502               2.030192              0.567144
# 1138         -0.208762               3.227792             -0.048609
# 1139         -6.715134               0.126712              0.762846
#
#       eps_on_mp  dividend_on_mp      mp_on_bv
# 0      0.030204    7.477079e+08 -3.792017e-09
# 1      0.099096    3.560891e+07 -5.854302e-09
# 2     -0.082446    2.463522e+07 -1.551313e-09
# 3     -0.044602    4.960369e+06 -1.598125e-09
# 4      0.070558    2.032006e+07 -9.165359e-09
# ...         ...             ...           ...
# 1135   0.423878    2.747652e+07 -8.568411e-09
# 1136   0.039327    6.881727e+07 -8.084724e-09
# 1137   0.204009    2.883466e+08 -1.361466e-10
# 1138  -2.002519    7.399533e+07 -4.587726e-10
# 1139   0.014171    1.624698e+08 -5.866425e-10
#
# [1140 rows x 20 columns]

# %% [markdown]
# <a id='4.2'></a>
# ## 5.2 Set up the training environment

# %% [markdown]
# Describe the environment

# %%
import gymnasium as gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gymnasium import spaces
from gymnasium.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv
# from gym.spaces import Box

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        # stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        stop_loss,
        punishment_rate,
        make_plots=False,
        print_verbosity=10,
        row=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        # self.row = row
        self.df = df
        # self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.punishment_rate = punishment_rate
        self.stop_loss = stop_loss # the game stops when the asset loses more than stop_loss percent
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        # self.data = self.df.loc[self.row, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        # self.turbulence_threshold = turbulence_threshold
        # self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        self.portfolio_columns = ['tic','price','buy_price','amount','weight']
        self.row = 0
        
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _buy_stock(self, action):
        def _do_buy():
            if self.data.close > 0: # Buy only if the price is > 0 (no missing data in this particular date)
                buy_amount = (self.portfolio.loc[0].price * action)
                buy_num_shares = math.floor(buy_amount/self.data.close)
                if buy_num_shares > 0:
                    if self.portfolio[self.portfolio.tic == self.data.tic].empty:
                        selected_index = len(self.portfolio)
                        selected_row = [self.data.tic,0,self.data.close,0,0]
                    else:
                        selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
                        selected_row = self.portfolio.loc[selected_index]
                        selected_row[2] = (buy_num_shares*self.data.close + selected_row[2]*selected_row[3]) \
                                    /(buy_num_shares + selected_row[3])
                    selected_row[1] = self.data.close
                    selected_row[3] += buy_num_shares
                    self.portfolio.loc[selected_index] = selected_row
    
                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_change = buy_num_shares * self.data.close * (1 + self.buy_cost_pct)
                    capital_row[1] -= capital_change
                    capital_row[2] -= capital_change
                    self.portfolio.loc[0] = capital_row
                    
                    self._compute_weight()
                    self.cost += selected_row[1] * buy_num_shares * self.buy_cost_pct
                    self.trades += 1
                else:
                    # Punish a certain amount of money if buying without avaiable capital
                    self.reward = -1 * self.initial_amount * self.punishment_rate
                    # print(f'Set punishment for unavailable buying: {self.reward}')
                    
            else:
                buy_num_shares = 0

            return buy_num_shares

        buy_num_shares = _do_buy()
        return buy_num_shares
    
    def _sell_stock(self, action):
        def _do_sell_normal():
            # TODO: Punish a certain amount of money if selling without avaiable stock in the inventory
            if self.data.close > 0: # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.portfolio[self.portfolio.tic == self.data.tic].empty:            
                    sell_num_shares = 0
                    
                    # Punish a certain amount of money if selling without avaiable stock in the inventory
                    self.reward = -1 * self.initial_amount * self.punishment_rate
                
                else:
                    sell_num_shares = math.floor(abs(action) * self.portfolio[self.portfolio.tic == self.data.tic].amount) 
                    sell_amount = self.data.close * sell_num_shares * (1 - self.sell_cost_pct)

                    # Update reward only when closing a deal
                    # buy_amount = self.portfolio[self.portfolio.tic == self.data.tic].buy_price * sell_num_shares
                    # self.reward = (sell_amount - buy_amount).values[0].item()
                    
                    # update stock row in the portfolio
                    selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
                    selected_row = self.portfolio.loc[selected_index]
                    selected_row[1] = self.data.close
                    selected_row[3] -= sell_num_shares

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_row[1] += sell_amount
                    capital_row[2] += sell_amount

                    # Update changes to portfolio
                    self.portfolio.loc[selected_index] = selected_row
                    self.portfolio.loc[0] = capital_row
                    self._compute_weight()
                    self.cost += selected_row[1] * sell_num_shares * self.sell_cost_pct
                    self.trades += 1
            else:
                sell_num_shares = 0

            return sell_num_shares

        sell_num_shares = _do_sell_normal()
        return sell_num_shares

    def _compute_weight(self):
        nav = sum(self.portfolio.price*self.portfolio.amount)
        self.portfolio['weight'] = self.portfolio.apply(lambda x: x.price * x.amount / nav, axis=1)
    
    # def _make_plot(self):
    #     plt.plot(self.asset_memory, "r")
    #     plt.savefig("results/account_value_trade_{}.png".format(self.episode))
    #     plt.close()

    def step(self, actions):

        current_total_asset = sum(self.portfolio.price * self.portfolio.amount)
        self.terminal = (self.row >= len(self.df.index.unique()) - 1) | (current_total_asset < self.initial_amount*(1-self.stop_loss))
        # print(f'Action of step {self.row} is {actions[0]}')
        
        # --> IN CASE THE STEP IS THE TERMINATED STEP
        if self.terminal: 
            print(f"Episode: {self.episode}")
            # if self.make_plots:
            #     self._make_plot()
                
            # Summary the training performance after an episode
            end_total_asset = sum(self.portfolio.price*self.portfolio.amount)
            tot_reward = end_total_asset - self.initial_amount

            # Summary total_value
            # df_total_value = pd.DataFrame(self.asset_memory)
            # df_total_value.columns = ["account_value"]
            # df_total_value["date"] = self.date_memory
            # df_total_value["daily_return"] = df_total_value["account_value"].pct_change(1)
            # if df_total_value["daily_return"].std() != 0:
            #     sharpe = ((252 ** 0.5)* df_total_value["daily_return"].mean()/ df_total_value["daily_return"].std())

            # Take tot_reward into account
            self.reward = tot_reward
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling
            
            # Summary rewards
            # df_rewards = pd.DataFrame(self.rewards_memory)
            # df_rewards.columns = ["account_rewards"]
            # df_rewards["date"] = self.date_memory[:-1]

            # Print out training results after a certain amount of episodes
            if self.episode % self.print_verbosity == 0:
                print(f"row: {self.row}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                # if df_total_value["daily_return"].std() != 0:
                #     print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")

            # if (self.model_name != "") and (self.mode != ""):
                # df_actions = self.save_action_memory()
                # df_actions.to_csv(
                #     "results/actions_{}_{}_{}.csv".format(
                #         self.mode, self.model_name, self.iteration
                #     )
                # )
                # df_total_value.to_csv(
                #     "results/account_value_{}_{}_{}.csv".format(
                #         self.mode, self.model_name, self.iteration
                #     ),
                #     index=False,
                # )
                # df_rewards.to_csv(
                #     "results/account_rewards_{}_{}_{}.csv".format(
                #         self.mode, self.model_name, self.iteration
                #     ),
                #     index=False,
                # )
                # plt.plot(self.asset_memory, "r")
                # plt.savefig(
                #     "results/account_value_{}_{}_{}.png".format(
                #         self.mode, self.model_name, self.iteration
                #     ),
                #     index=False,
                # )
                # plt.close()
            
            truncated = False  # we do not limit the number of steps here
            # Optionally we can pass additional info, we are not using that for now
            info = {}


            return (
                np.array(self.state).astype(np.float32),
                self.reward,
                self.terminal,
                truncated,
                info,
            )

        # --> IN A NORMAL STEP
        else: 

            # begin_total_asset = sum(self.portfolio.price * self.portfolio.amount)
            
            # update previous_portfolio
            self.previous_port = self.portfolio.copy()
        
            # sell_number_share = 0 # Default value at each transaction to detect reward value
            self.reward = 0
            if actions[0] > 0:
                self._buy_stock(actions[0])
            else:
                sell_number_share = self._sell_stock(actions[0])

            # actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            # actions = actions.astype(int)  # convert into integer because we can't by fraction of shares
            # print(type(actions))
            self.actions_memory.append(actions)

            # Update selected row in the dataset based on state: s -> s+1
            self.row += 1
            self.data = self.df.loc[self.row]
            self.state = self._update_state()
    
            end_total_asset = sum(self.portfolio.price * self.portfolio.amount)
            # print(f'Begin asset: {begin_total_asset}, End asset: {end_total_asset}')

            # Update asset memory
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())

            # Update reward
            # if self.reward == 0:
            #     self.reward = end_total_asset - self.initial_amount
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        truncated = False  # we do not limit the number of steps here
        # Optionally we can pass additional info, we are not using that for now
        info = {}
        
        # return self.state, self.reward, self.terminal, {}
    
        return (
            np.array(self.state).astype(np.float32),
            self.reward,
            self.terminal,
            truncated,
            info,
        )

    def reset(self, seed=None, options=None):
        # initiate state
        self.state = self._initiate_state()

        # Reset asset_memory
        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = sum(self.previous_port.price * self.previous_port.amount)
            self.asset_memory = [previous_total_asset]

        # Reset support variables
        # self.row = 0
        # self.data = self.df.loc[self.row, :]
        # self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        self.episode += 1

        return np.array(self.state).astype(np.float32), {}
        # return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        
        # Reset portfolio & previous_portfolio
        if self.initial:
            self.portfolio = pd.DataFrame([['cap',self.initial_amount,self.initial_amount,1,1]])
            self.portfolio.columns = self.portfolio_columns
            self.previous_port = self.portfolio.copy()
        else:
            self.portfolio = self.previous_port.copy()

        # Reset data
        self.row = 0
        self.data = self.df.loc[self.row]
        
         # Reset state
        state = self._update_state()
        
        return state

    def _update_state(self):

        # if the stock appear in the portfolio already
        if self.portfolio[self.portfolio.tic == self.data.tic].empty:
            state = ([self.portfolio.loc[0].price] + [self.data['close']] + [0] + [0] + [0] + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))
            
        else:
            # Update stock's prices in portfolio before updating state
            selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
            selected_row = self.portfolio.loc[selected_index]
            selected_row['price'] = self.data.close
            self.portfolio.loc[selected_index] = selected_row
            self._compute_weight()
            selected_row = self.portfolio.loc[selected_index]
            # print("Update portfolio at ",self.data.tic," price: ", self.data.close,"; with weight: ", selected_row.weight)
            
            state = (
                    [self.portfolio.iloc[0].price]
                    + [(selected_row.buy_price/selected_row.price-1)]
                    + [self.data.close]
                    + [selected_row.amount]
                    + [selected_row.weight]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
    
        return state

    def _get_date(self):
        # return self.data.date
        return self.row

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        
        date_list = self.date_memory[:-1]
        action_list = self.actions_memory
        df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %% [markdown]
# <a id='4.3'></a>
# ## 5.3 Initialize Environment

# %% [markdown]
# State's space include current capital amount, the return of the current stock, the weight of this stock in the portfolio, and the indicators decided in ratio_list

# %%
ratio_list = train_data.columns.drop(['date','tic','close'])

action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
state_space = 1 + 4*action_dimension + len(ratio_list)
print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 22

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.01,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.3,
    "print_verbosity":4,
    "punishment_rate": 0.001
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %%
action = e_train_gym.action_space.sample()
action
# Out:
# array([-0.96182674], dtype=float32)

# %%
from stable_baselines3.common.env_checker import check_env

# If the environment don't follow the interface, an error will be thrown
check_env(e_train_gym, warn=True)

# %%
from stable_baselines3 import PPO, A2C, DQN, DDPG

# Instantiate the env
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# #### Test Environment

# %%
# Get samples from train_data
test_env_data = trade_data.iloc[:20]
test_env_data.close = [10,100,15,90,20,80,25,85,18,92,10,100,15,90,20,80,25,85,18,92]

# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.3,
    "print_verbosity":4,
    "punishment_rate": 0.001
}

#Establish the training environment using StockTradingEnv() class
test_train_gym = StockTradingEnv(df = test_env_data, **env_kwargs)

# test reset state
print(test_train_gym.reset())
# Out:
# (array([ 1.0000000e+06,  1.0000000e+01,  0.0000000e+00,  0.0000000e+00,
#         0.0000000e+00,  3.1952330e-01,  2.1845427e-01,  1.0323844e-01,
#         2.7902060e+01,  2.0395163e-01,  1.0000000e+01,  3.0652669e-01,
#         6.4122640e-02,  1.3918664e-01,  2.6717506e-02,  3.0203652e-02,
#         1.4161230e+01,  1.3132939e-01,  1.1300485e-01,  3.0203652e-02,
#         7.4770790e+08, -3.7920169e-09], dtype=float32), {})

# %%
state,reward,terminal,truncated,info = test_train_gym.step(test_train_gym.action_space.sample())
# print(test_train_gym.save_action_memory())
print(reward,' type ',type(reward),'\n')
print(terminal,'\n')
# print(test_train_gym.data,'\n')
print(state,'\n')
print(test_train_gym.portfolio,'\n')
print(test_train_gym.previous_port)
# Out:
# -0.08670039999999572  type  <class 'float'>
#
# False
#
# [ 1.3212900e+05  1.0000000e+01  0.0000000e+00  0.0000000e+00
#   0.0000000e+00  4.0905833e-01  1.8385564e-01  0.0000000e+00
#   2.2016940e+00  1.1519501e-01  3.9150684e+00  1.6816315e-01
#  -4.3736530e+01  0.0000000e+00  5.3027575e-03  7.1566217e-02
#  -2.3824003e+01  1.2638437e+01  3.4592119e-01  7.1566217e-02
#   1.7932014e+07 -2.1007690e-10]
#
#     tic       price   buy_price  amount    weight
# 0   cap  132128.996  132128.996       1  0.132244
# 1  AAPL      10.000      10.000   23164  0.231841
# 2   CRM      80.000      80.000    4829  0.386655
# 3   DOW      92.000      92.000    2707  0.249260
#
#     tic      price  buy_price  amount    weight
# 0   cap  381422.04  381422.04       1  0.381658
# 1  AAPL      10.00      10.00   23164  0.231783
# 2   CRM      80.00      80.00    4829  0.386559

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %%
episode_length = len(e_train_gym.df)
episode_amount = 256
total_training_step = episode_length*episode_amount
total_training_step
# Out:
# 935680

# %% [markdown]
# ### Model 1: PPO

# %%
agent_ppo = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": episode_length,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": episode_length,
    "clip_range":0.1
}

model_ppo = agent_ppo.get_model("ppo",model_kwargs = PPO_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo/",verbose=10)
# Out:
# {'n_steps': 3655, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 3655, 'clip_range': 0.1}
# Using cpu device

# %%
trained_ppo = agent_ppo.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=total_training_step)
# Out:
# Logging to tensorboard_log/test_ppo/ppo_31
# Episode: 5
# ---------------------------------
# | time/              |          |
# |    fps             | 199      |
# |    iterations      | 1        |
# |    time_elapsed    | 18       |
# |    total_timesteps | 3655     |
# | train/             |          |
# |    reward          | 395.4551 |
# ---------------------------------
# Episode: 6
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 172          |
# |    iterations           | 2            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 7310         |
# | train/                  |              |
# |    approx_kl            | 0.0011703916 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00018     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 185          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000225    |
# |    reward               | 247.77452    |
# |    std                  | 1            |
# |    value_loss           | 370          |
# ------------------------------------------
# Episode: 7
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 3            |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 10965        |
# | train/                  |              |
# |    approx_kl            | 0.0009263783 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -6.08e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 72.3         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000237    |
# |    reward               | 280.44214    |
# |    std                  | 1            |
# |    value_loss           | 145          |
# ------------------------------------------
# Episode: 8
# row: 3654, episode: 8
# begin_total_asset: 1000000.00
# end_total_asset: 3678613.26
# total_reward: 2678613.26
# total_cost: 804280.90
# total_trades: 2893
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 4           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 14620       |
# | train/                  |             |
# |    approx_kl            | 0.000840672 |
# |    clip_fraction        | 0.00285     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.000125    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 92.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -7.96e-05   |
# |    reward               | 267.86133   |
# |    std                  | 1           |
# |    value_loss           | 185         |
# -----------------------------------------
# Episode: 9
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 157           |
# |    iterations           | 5             |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 18275         |
# | train/                  |               |
# |    approx_kl            | 2.5751799e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 5.94e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 83.9          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -1.07e-06     |
# |    reward               | 365.21402     |
# |    std                  | 0.998         |
# |    value_loss           | 168           |
# -------------------------------------------
# Episode: 10
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 159           |
# |    iterations           | 6             |
# |    time_elapsed         | 137           |
# |    total_timesteps      | 21930         |
# | train/                  |               |
# |    approx_kl            | 0.00013745786 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.000153      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 156           |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.000115      |
# |    reward               | 221.96155     |
# |    std                  | 0.998         |
# |    value_loss           | 312           |
# -------------------------------------------
# Episode: 11
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 7            |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 25585        |
# | train/                  |              |
# |    approx_kl            | 0.0014915967 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000558    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 57.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000141    |
# |    reward               | 257.3579     |
# |    std                  | 0.999        |
# |    value_loss           | 114          |
# ------------------------------------------
# Episode: 12
# row: 3654, episode: 12
# begin_total_asset: 1000000.00
# end_total_asset: 3787416.16
# total_reward: 2787416.16
# total_cost: 977765.07
# total_trades: 2998
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 8            |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 29240        |
# | train/                  |              |
# |    approx_kl            | 0.0040797484 |
# |    clip_fraction        | 0.0745       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000743    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 76.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000972    |
# |    reward               | 278.7416     |
# |    std                  | 1            |
# |    value_loss           | 154          |
# ------------------------------------------
# Episode: 13
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 160           |
# |    iterations           | 9             |
# |    time_elapsed         | 205           |
# |    total_timesteps      | 32895         |
# | train/                  |               |
# |    approx_kl            | 8.8989655e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000399     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 90.1          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | 2.28e-06      |
# |    reward               | 205.46503     |
# |    std                  | 1             |
# |    value_loss           | 180           |
# -------------------------------------------
# Episode: 14
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 160           |
# |    iterations           | 10            |
# |    time_elapsed         | 227           |
# |    total_timesteps      | 36550         |
# | train/                  |               |
# |    approx_kl            | 1.2924341e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.00218      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 48.6          |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -1.65e-06     |
# |    reward               | 348.34583     |
# |    std                  | 1             |
# |    value_loss           | 97.3          |
# -------------------------------------------
# Episode: 15
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 11           |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 40205        |
# | train/                  |              |
# |    approx_kl            | 3.635595e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000292    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 141          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -2.51e-05    |
# |    reward               | 244.02936    |
# |    std                  | 1            |
# |    value_loss           | 282          |
# ------------------------------------------
# Episode: 16
# row: 3654, episode: 16
# begin_total_asset: 1000000.00
# end_total_asset: 3755709.94
# total_reward: 2755709.94
# total_cost: 1066671.15
# total_trades: 2942
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 162           |
# |    iterations           | 12            |
# |    time_elapsed         | 270           |
# |    total_timesteps      | 43860         |
# | train/                  |               |
# |    approx_kl            | 3.9361683e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000941     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 68.5          |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -1.94e-05     |
# |    reward               | 275.57098     |
# |    std                  | 1             |
# |    value_loss           | 137           |
# -------------------------------------------
# Episode: 17
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 163           |
# |    iterations           | 13            |
# |    time_elapsed         | 291           |
# |    total_timesteps      | 47515         |
# | train/                  |               |
# |    approx_kl            | 1.2271169e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000972     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 87.4          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 2.16e-05      |
# |    reward               | 299.2159      |
# |    std                  | 1             |
# |    value_loss           | 175           |
# -------------------------------------------
# Episode: 18
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 163          |
# |    iterations           | 14           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 51170        |
# | train/                  |              |
# |    approx_kl            | 6.606701e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000489    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 103          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -4.39e-05    |
# |    reward               | 339.48505    |
# |    std                  | 1            |
# |    value_loss           | 206          |
# ------------------------------------------
# Episode: 19
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 15           |
# |    time_elapsed         | 334          |
# |    total_timesteps      | 54825        |
# | train/                  |              |
# |    approx_kl            | 0.0008525513 |
# |    clip_fraction        | 0.00367      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000388    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 133          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 8.21e-07     |
# |    reward               | 222.6923     |
# |    std                  | 1.01         |
# |    value_loss           | 266          |
# ------------------------------------------
# Episode: 20
# row: 3654, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4204592.80
# total_reward: 3204592.80
# total_cost: 1440815.86
# total_trades: 3120
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 16          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 58480       |
# | train/                  |             |
# |    approx_kl            | 0.005358205 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -0.00173    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 56.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00171    |
# |    reward               | 320.4593    |
# |    std                  | 1.01        |
# |    value_loss           | 113         |
# -----------------------------------------
# Episode: 21
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 17           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 62135        |
# | train/                  |              |
# |    approx_kl            | 0.0029868798 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.000485    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 118          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00129     |
# |    reward               | 82.17254     |
# |    std                  | 1.01         |
# |    value_loss           | 235          |
# ------------------------------------------
# Episode: 22
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 164           |
# |    iterations           | 18            |
# |    time_elapsed         | 399           |
# |    total_timesteps      | 65790         |
# | train/                  |               |
# |    approx_kl            | 0.00064637884 |
# |    clip_fraction        | 0.00126       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.0188       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.6           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 8.65e-05      |
# |    reward               | 296.69812     |
# |    std                  | 1.01          |
# |    value_loss           | 15.3          |
# -------------------------------------------
# Episode: 23
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 19           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 69445        |
# | train/                  |              |
# |    approx_kl            | 0.0005941925 |
# |    clip_fraction        | 0.000575     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 101          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000244    |
# |    reward               | 230.97267    |
# |    std                  | 1.01         |
# |    value_loss           | 202          |
# ------------------------------------------
# Episode: 24
# row: 3654, episode: 24
# begin_total_asset: 1000000.00
# end_total_asset: 4183711.33
# total_reward: 3183711.33
# total_cost: 1233203.46
# total_trades: 2994
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 20           |
# |    time_elapsed         | 442          |
# |    total_timesteps      | 73100        |
# | train/                  |              |
# |    approx_kl            | 0.0009002057 |
# |    clip_fraction        | 0.00345      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0015      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 60.6         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000102    |
# |    reward               | 318.37112    |
# |    std                  | 1.01         |
# |    value_loss           | 121          |
# ------------------------------------------
# Episode: 25
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 21           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 76755        |
# | train/                  |              |
# |    approx_kl            | 3.532835e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.000327    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 116          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 6.77e-05     |
# |    reward               | 196.25943    |
# |    std                  | 1.01         |
# |    value_loss           | 233          |
# ------------------------------------------
# Episode: 26
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 165           |
# |    iterations           | 22            |
# |    time_elapsed         | 486           |
# |    total_timesteps      | 80410         |
# | train/                  |               |
# |    approx_kl            | 0.00011529306 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.00243      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 43.6          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | 2.93e-05      |
# |    reward               | 183.46783     |
# |    std                  | 1.01          |
# |    value_loss           | 87.2          |
# -------------------------------------------
# Episode: 27
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 23           |
# |    time_elapsed         | 507          |
# |    total_timesteps      | 84065        |
# | train/                  |              |
# |    approx_kl            | 0.0012978831 |
# |    clip_fraction        | 0.00818      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.00269     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 38           |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000434    |
# |    reward               | 231.54271    |
# |    std                  | 1.01         |
# |    value_loss           | 76.1         |
# ------------------------------------------
# Episode: 28
# row: 3654, episode: 28
# begin_total_asset: 1000000.00
# end_total_asset: 4279658.53
# total_reward: 3279658.53
# total_cost: 1265601.98
# total_trades: 3091
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 24           |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 87720        |
# | train/                  |              |
# |    approx_kl            | 0.0029443358 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.00107     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 61.1         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000344    |
# |    reward               | 327.96585    |
# |    std                  | 1.02         |
# |    value_loss           | 122          |
# ------------------------------------------
# Episode: 29
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 166           |
# |    iterations           | 25            |
# |    time_elapsed         | 550           |
# |    total_timesteps      | 91375         |
# | train/                  |               |
# |    approx_kl            | 0.00028052356 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.000519     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 124           |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -9.24e-05     |
# |    reward               | 282.50046     |
# |    std                  | 1.02          |
# |    value_loss           | 248           |
# -------------------------------------------
# Episode: 30
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 26           |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 95030        |
# | train/                  |              |
# |    approx_kl            | 0.0011610588 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000914    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 91.4         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000263    |
# |    reward               | 102.33074    |
# |    std                  | 1.02         |
# |    value_loss           | 183          |
# ------------------------------------------
# Episode: 31
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 166           |
# |    iterations           | 27            |
# |    time_elapsed         | 591           |
# |    total_timesteps      | 98685         |
# | train/                  |               |
# |    approx_kl            | 0.00087684195 |
# |    clip_fraction        | 0.0032        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.00901      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 11.8          |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000722     |
# |    reward               | 256.08636     |
# |    std                  | 1.02          |
# |    value_loss           | 23.7          |
# -------------------------------------------
# Episode: 32
# row: 3654, episode: 32
# begin_total_asset: 1000000.00
# end_total_asset: 4397848.36
# total_reward: 3397848.36
# total_cost: 1115478.13
# total_trades: 2870
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 28           |
# |    time_elapsed         | 611          |
# |    total_timesteps      | 102340       |
# | train/                  |              |
# |    approx_kl            | 0.0032038384 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000408    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 74.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000414    |
# |    reward               | 339.78485    |
# |    std                  | 1.02         |
# |    value_loss           | 150          |
# ------------------------------------------
# Episode: 33
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 167           |
# |    iterations           | 29            |
# |    time_elapsed         | 633           |
# |    total_timesteps      | 105995        |
# | train/                  |               |
# |    approx_kl            | 5.5660643e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.000137     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 133           |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -4.73e-05     |
# |    reward               | 250.12277     |
# |    std                  | 1.02          |
# |    value_loss           | 266           |
# -------------------------------------------
# Episode: 34
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 30           |
# |    time_elapsed         | 654          |
# |    total_timesteps      | 109650       |
# | train/                  |              |
# |    approx_kl            | 0.0017414788 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000523    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 71.6         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000751    |
# |    reward               | 387.03088    |
# |    std                  | 1.02         |
# |    value_loss           | 143          |
# ------------------------------------------
# Episode: 35
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 31           |
# |    time_elapsed         | 675          |
# |    total_timesteps      | 113305       |
# | train/                  |              |
# |    approx_kl            | 0.0012828402 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000134    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 173          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000465     |
# |    reward               | 163.87802    |
# |    std                  | 1.02         |
# |    value_loss           | 346          |
# ------------------------------------------
# Episode: 36
# row: 3654, episode: 36
# begin_total_asset: 1000000.00
# end_total_asset: 2701334.94
# total_reward: 1701334.94
# total_cost: 861817.95
# total_trades: 3022
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 167           |
# |    iterations           | 32            |
# |    time_elapsed         | 696           |
# |    total_timesteps      | 116960        |
# | train/                  |               |
# |    approx_kl            | 0.00014487775 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.00193      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 30.3          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000109     |
# |    reward               | 170.1335      |
# |    std                  | 1.02          |
# |    value_loss           | 60.6          |
# -------------------------------------------
# Episode: 37
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 33           |
# |    time_elapsed         | 718          |
# |    total_timesteps      | 120615       |
# | train/                  |              |
# |    approx_kl            | 0.0005745662 |
# |    clip_fraction        | 0.000492     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.00151     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 32.6         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000319    |
# |    reward               | 277.06213    |
# |    std                  | 1.02         |
# |    value_loss           | 65.2         |
# ------------------------------------------
# Episode: 38
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 34           |
# |    time_elapsed         | 739          |
# |    total_timesteps      | 124270       |
# | train/                  |              |
# |    approx_kl            | 0.0010131403 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -2.5e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 87.9         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -6.93e-05    |
# |    reward               | 357.89417    |
# |    std                  | 1.02         |
# |    value_loss           | 176          |
# ------------------------------------------
# Episode: 39
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 35            |
# |    time_elapsed         | 761           |
# |    total_timesteps      | 127925        |
# | train/                  |               |
# |    approx_kl            | 0.00082909106 |
# |    clip_fraction        | 0.00222       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.000174     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 148           |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000537     |
# |    reward               | 132.69029     |
# |    std                  | 1.02          |
# |    value_loss           | 295           |
# -------------------------------------------
# Episode: 40
# row: 3654, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 2812636.28
# total_reward: 1812636.28
# total_cost: 1011974.80
# total_trades: 3145
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 167           |
# |    iterations           | 36            |
# |    time_elapsed         | 784           |
# |    total_timesteps      | 131580        |
# | train/                  |               |
# |    approx_kl            | 0.00012539446 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.0029       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 19.6          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 0.000239      |
# |    reward               | 181.26363     |
# |    std                  | 1.02          |
# |    value_loss           | 39.2          |
# -------------------------------------------
# Episode: 41
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 37           |
# |    time_elapsed         | 805          |
# |    total_timesteps      | 135235       |
# | train/                  |              |
# |    approx_kl            | 0.0010297617 |
# |    clip_fraction        | 0.00337      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000891    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 37           |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000294    |
# |    reward               | 346.08615    |
# |    std                  | 1.02         |
# |    value_loss           | 74.1         |
# ------------------------------------------
# Episode: 42
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 38           |
# |    time_elapsed         | 826          |
# |    total_timesteps      | 138890       |
# | train/                  |              |
# |    approx_kl            | 0.0012170798 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000422    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 138          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 1.81e-05     |
# |    reward               | 385.12094    |
# |    std                  | 1.02         |
# |    value_loss           | 276          |
# ------------------------------------------
# Episode: 43
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 39            |
# |    time_elapsed         | 847           |
# |    total_timesteps      | 142545        |
# | train/                  |               |
# |    approx_kl            | 4.8199592e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | -0.000318     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 171           |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 4.68e-05      |
# |    reward               | 241.63264     |
# |    std                  | 1.02          |
# |    value_loss           | 343           |
# -------------------------------------------
# Episode: 44
# row: 3654, episode: 44
# begin_total_asset: 1000000.00
# end_total_asset: 3046731.84
# total_reward: 2046731.84
# total_cost: 1030330.75
# total_trades: 2945
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 40           |
# |    time_elapsed         | 868          |
# |    total_timesteps      | 146200       |
# | train/                  |              |
# |    approx_kl            | 0.0005109657 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000503    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 66.4         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000154    |
# |    reward               | 204.67319    |
# |    std                  | 1.02         |
# |    value_loss           | 133          |
# ------------------------------------------
# Episode: 45
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 41            |
# |    time_elapsed         | 889           |
# |    total_timesteps      | 149855        |
# | train/                  |               |
# |    approx_kl            | 0.00032707083 |
# |    clip_fraction        | 0.000383      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.000929     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 47.3          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -2.44e-05     |
# |    reward               | 244.26576     |
# |    std                  | 1.03          |
# |    value_loss           | 94.7          |
# -------------------------------------------
# Episode: 46
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 42            |
# |    time_elapsed         | 910           |
# |    total_timesteps      | 153510        |
# | train/                  |               |
# |    approx_kl            | 4.3761844e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.000572     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 68.2          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -4.2e-05      |
# |    reward               | 351.60013     |
# |    std                  | 1.03          |
# |    value_loss           | 136           |
# -------------------------------------------
# Episode: 47
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 43           |
# |    time_elapsed         | 931          |
# |    total_timesteps      | 157165       |
# | train/                  |              |
# |    approx_kl            | 5.018874e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -1.07e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 143          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 5.53e-05     |
# |    reward               | 179.95847    |
# |    std                  | 1.04         |
# |    value_loss           | 285          |
# ------------------------------------------
# Episode: 48
# row: 3654, episode: 48
# begin_total_asset: 1000000.00
# end_total_asset: 5297669.72
# total_reward: 4297669.72
# total_cost: 1228522.60
# total_trades: 2973
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 44            |
# |    time_elapsed         | 952           |
# |    total_timesteps      | 160820        |
# | train/                  |               |
# |    approx_kl            | 3.2735588e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.000713     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 36.5          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -4.17e-06     |
# |    reward               | 429.76697     |
# |    std                  | 1.04          |
# |    value_loss           | 73.1          |
# -------------------------------------------
# Episode: 49
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 169           |
# |    iterations           | 45            |
# |    time_elapsed         | 973           |
# |    total_timesteps      | 164475        |
# | train/                  |               |
# |    approx_kl            | 1.4363659e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 5.39e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 214           |
# |    n_updates            | 440           |
# |    policy_gradient_loss | 2.13e-05      |
# |    reward               | 354.15158     |
# |    std                  | 1.04          |
# |    value_loss           | 427           |
# -------------------------------------------
# Episode: 50
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 46           |
# |    time_elapsed         | 995          |
# |    total_timesteps      | 168130       |
# | train/                  |              |
# |    approx_kl            | 0.0003213594 |
# |    clip_fraction        | 5.47e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -5.32e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 144          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000223    |
# |    reward               | 257.0105     |
# |    std                  | 1.04         |
# |    value_loss           | 289          |
# ------------------------------------------
# Episode: 51
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 47           |
# |    time_elapsed         | 1018         |
# |    total_timesteps      | 171785       |
# | train/                  |              |
# |    approx_kl            | 0.0053703603 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.000211    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 75.3         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00109     |
# |    reward               | 173.25455    |
# |    std                  | 1.04         |
# |    value_loss           | 151          |
# ------------------------------------------
# Episode: 52
# row: 3654, episode: 52
# begin_total_asset: 1000000.00
# end_total_asset: 2705888.19
# total_reward: 1705888.19
# total_cost: 1067605.44
# total_trades: 3102
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 48            |
# |    time_elapsed         | 1038          |
# |    total_timesteps      | 175440        |
# | train/                  |               |
# |    approx_kl            | 0.00019843498 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | -0.00156      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 33.7          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -7.4e-05      |
# |    reward               | 170.58882     |
# |    std                  | 1.04          |
# |    value_loss           | 67.6          |
# -------------------------------------------
# Episode: 53
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 49           |
# |    time_elapsed         | 1058         |
# |    total_timesteps      | 179095       |
# | train/                  |              |
# |    approx_kl            | 0.0011174778 |
# |    clip_fraction        | 0.00575      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.00209     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 32.8         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000458    |
# |    reward               | 113.88302    |
# |    std                  | 1.04         |
# |    value_loss           | 65.7         |
# ------------------------------------------
# Episode: 54
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 50          |
# |    time_elapsed         | 1078        |
# |    total_timesteps      | 182750      |
# | train/                  |             |
# |    approx_kl            | 0.002697339 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.0028     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.4        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000805   |
# |    reward               | 432.41055   |
# |    std                  | 1.04        |
# |    value_loss           | 28.9        |
# -----------------------------------------
# Episode: 55
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 169           |
# |    iterations           | 51            |
# |    time_elapsed         | 1100          |
# |    total_timesteps      | 186405        |
# | train/                  |               |
# |    approx_kl            | 0.00057728606 |
# |    clip_fraction        | 0.000602      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 0.000128      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 217           |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -3.59e-05     |
# |    reward               | 155.70631     |
# |    std                  | 1.04          |
# |    value_loss           | 434           |
# -------------------------------------------
# Episode: 56
# row: 3654, episode: 56
# begin_total_asset: 1000000.00
# end_total_asset: 2254131.06
# total_reward: 1254131.06
# total_cost: 921446.21
# total_trades: 3238
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 169           |
# |    iterations           | 52            |
# |    time_elapsed         | 1122          |
# |    total_timesteps      | 190060        |
# | train/                  |               |
# |    approx_kl            | 0.00053285266 |
# |    clip_fraction        | 0.000192      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | -0.000299     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 27.3          |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000125     |
# |    reward               | 125.41311     |
# |    std                  | 1.04          |
# |    value_loss           | 54.7          |
# -------------------------------------------
# Episode: 57
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 53           |
# |    time_elapsed         | 1144         |
# |    total_timesteps      | 193715       |
# | train/                  |              |
# |    approx_kl            | 0.0029279783 |
# |    clip_fraction        | 0.0573       |
# ...
# |    reward               | 0.0          |
# |    std                  | 1.13         |
# |    value_loss           | 232          |
# ------------------------------------------
# Episode: 244
# row: 3654, episode: 244
# begin_total_asset: 1000000.00
# end_total_asset: 1801945.77
# total_reward: 801945.77
# total_cost: 988833.98
# total_trades: 3270
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 240          |
# |    time_elapsed         | 5440         |
# |    total_timesteps      | 877200       |
# | train/                  |              |
# |    approx_kl            | 0.0006806944 |
# |    clip_fraction        | 0.000903     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.00276      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 54.3         |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.000479    |
# |    reward               | 0.0          |
# |    std                  | 1.13         |
# |    value_loss           | 109          |
# ------------------------------------------
# Episode: 245
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 161           |
# |    iterations           | 241           |
# |    time_elapsed         | 5460          |
# |    total_timesteps      | 880855        |
# | train/                  |               |
# |    approx_kl            | 0.00066251337 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | -0.00163      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.32          |
# |    n_updates            | 2400          |
# |    policy_gradient_loss | 8.11e-05      |
# |    reward               | 0.0           |
# |    std                  | 1.13          |
# |    value_loss           | 14.7          |
# -------------------------------------------
# Episode: 246
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 161           |
# |    iterations           | 242           |
# |    time_elapsed         | 5483          |
# |    total_timesteps      | 884510        |
# | train/                  |               |
# |    approx_kl            | 0.00010974321 |
# |    clip_fraction        | 5.47e-05      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.54         |
# |    explained_variance   | 0.000814      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 18.5          |
# |    n_updates            | 2410          |
# |    policy_gradient_loss | -7.67e-05     |
# |    reward               | 0.0           |
# |    std                  | 1.12          |
# |    value_loss           | 37.1          |
# -------------------------------------------
# Episode: 247
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 243          |
# |    time_elapsed         | 5505         |
# |    total_timesteps      | 888165       |
# | train/                  |              |
# |    approx_kl            | 7.678375e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | -0.0405      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.318        |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -4.03e-06    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 0.713        |
# ------------------------------------------
# Episode: 248
# row: 3654, episode: 248
# begin_total_asset: 1000000.00
# end_total_asset: 1778631.48
# total_reward: 778631.48
# total_cost: 971972.59
# total_trades: 3297
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 244         |
# |    time_elapsed         | 5526        |
# |    total_timesteps      | 891820      |
# | train/                  |             |
# |    approx_kl            | 0.001631856 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.00188     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.21        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.000399   |
# |    reward               | 0.0         |
# |    std                  | 1.12        |
# |    value_loss           | 18.5        |
# -----------------------------------------
# Episode: 249
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 245          |
# |    time_elapsed         | 5546         |
# |    total_timesteps      | 895475       |
# | train/                  |              |
# |    approx_kl            | 0.0003810001 |
# |    clip_fraction        | 0.000547     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.00086     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.9          |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.000116    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 13.8         |
# ------------------------------------------
# Episode: 250
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 161           |
# |    iterations           | 246           |
# |    time_elapsed         | 5568          |
# |    total_timesteps      | 899130        |
# | train/                  |               |
# |    approx_kl            | 0.00053770776 |
# |    clip_fraction        | 0.000766      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.53         |
# |    explained_variance   | -0.00117      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.59          |
# |    n_updates            | 2450          |
# |    policy_gradient_loss | -7.91e-05     |
# |    reward               | 0.0           |
# |    std                  | 1.12          |
# |    value_loss           | 11.2          |
# -------------------------------------------
# Episode: 251
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 247          |
# |    time_elapsed         | 5587         |
# |    total_timesteps      | 902785       |
# | train/                  |              |
# |    approx_kl            | 0.0036647406 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.000626    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.6         |
# |    n_updates            | 2460         |
# |    policy_gradient_loss | -0.000861    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 35.3         |
# ------------------------------------------
# Episode: 252
# row: 3654, episode: 252
# begin_total_asset: 1000000.00
# end_total_asset: 1602240.30
# total_reward: 602240.30
# total_cost: 990942.49
# total_trades: 3258
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 248          |
# |    time_elapsed         | 5606         |
# |    total_timesteps      | 906440       |
# | train/                  |              |
# |    approx_kl            | 0.0017866935 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.000237    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 20.7         |
# |    n_updates            | 2470         |
# |    policy_gradient_loss | -0.00018     |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 41.5         |
# ------------------------------------------
# Episode: 253
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 249          |
# |    time_elapsed         | 5627         |
# |    total_timesteps      | 910095       |
# | train/                  |              |
# |    approx_kl            | 0.0022672047 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.00145     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.12         |
# |    n_updates            | 2480         |
# |    policy_gradient_loss | 0.000501     |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 8.29         |
# ------------------------------------------
# Episode: 254
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 250          |
# |    time_elapsed         | 5648         |
# |    total_timesteps      | 913750       |
# | train/                  |              |
# |    approx_kl            | 0.0014383182 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.0018       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.7         |
# |    n_updates            | 2490         |
# |    policy_gradient_loss | -0.000177    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 29.4         |
# ------------------------------------------
# Episode: 255
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 251          |
# |    time_elapsed         | 5669         |
# |    total_timesteps      | 917405       |
# | train/                  |              |
# |    approx_kl            | 4.004943e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -0.0102      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.451        |
# |    n_updates            | 2500         |
# |    policy_gradient_loss | -7.87e-06    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 0.962        |
# ------------------------------------------
# Episode: 256
# row: 3654, episode: 256
# begin_total_asset: 1000000.00
# end_total_asset: 2391119.26
# total_reward: 1391119.26
# total_cost: 1087650.83
# total_trades: 3371
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 252          |
# |    time_elapsed         | 5688         |
# |    total_timesteps      | 921060       |
# | train/                  |              |
# |    approx_kl            | 0.0018209101 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.000615     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.4         |
# |    n_updates            | 2510         |
# |    policy_gradient_loss | -0.000339    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 30.8         |
# ------------------------------------------
# Episode: 257
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 253          |
# |    time_elapsed         | 5707         |
# |    total_timesteps      | 924715       |
# | train/                  |              |
# |    approx_kl            | 0.0032170152 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | -0.00023     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 22.3         |
# |    n_updates            | 2520         |
# |    policy_gradient_loss | -0.000429    |
# |    reward               | 0.0          |
# |    std                  | 1.12         |
# |    value_loss           | 44.7         |
# ------------------------------------------
# Episode: 258
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 254          |
# |    time_elapsed         | 5725         |
# |    total_timesteps      | 928370       |
# | train/                  |              |
# |    approx_kl            | 0.0013852295 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.000481     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.3         |
# |    n_updates            | 2530         |
# |    policy_gradient_loss | -0.000242    |
# |    reward               | 0.0          |
# |    std                  | 1.13         |
# |    value_loss           | 30.6         |
# ------------------------------------------
# Episode: 259
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 255          |
# |    time_elapsed         | 5744         |
# |    total_timesteps      | 932025       |
# | train/                  |              |
# |    approx_kl            | 0.0008747994 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.000188     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 28.3         |
# |    n_updates            | 2540         |
# |    policy_gradient_loss | -0.000272    |
# |    reward               | 0.0          |
# |    std                  | 1.13         |
# |    value_loss           | 56.6         |
# ------------------------------------------
# Episode: 260
# row: 3654, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 3046243.05
# total_reward: 2046243.05
# total_cost: 1065084.60
# total_trades: 3301
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 256          |
# |    time_elapsed         | 5762         |
# |    total_timesteps      | 935680       |
# | train/                  |              |
# |    approx_kl            | 0.0022435333 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.000957     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 111          |
# |    n_updates            | 2550         |
# |    policy_gradient_loss | -0.00015     |
# |    reward               | 0.0          |
# |    std                  | 1.14         |
# |    value_loss           | 222          |
# ------------------------------------------

# %%
# trained_ppo = PPO("MlpPolicy", env_train,n_steps=2048,ent_coef=0.01,learning_rate=0.00025,batch_size=2048,clip_range=0.1,
#                   tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo/",verbose=10)
# trained_ppo.learn(total_timesteps=total_training_step)

# %% [markdown]
# ### Model 2: DDPG

# %%
# agent_ddpg = DRLAgent(env = env_train)
# DDPG_PARAMS = {"batch_size": 128, "buffer_size": episode_length, "learning_rate": 0.001}
# model_ddpg = agent_ddpg.get_model("ddpg",model_kwargs = DDPG_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ddpg_tensorboard/")

# # set up logger
# tmp_path = TENSORBOARD_LOG_DIR + '/ddpg'
# new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_ddpg)

# %%
# the training log just show up when total_timesteps higher than 15.000
# trained_ddpg = agent_ddpg.train_model(model=model_ddpg,
#                              tb_log_name='ddpg',
#                              total_timesteps=total_training_step)

# %%
# from stable_baselines3.common.noise import NormalActionNoise

# # The noise objects for DDPG
# n_actions = env_train.action_space.shape[-1]
# action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# # Train the agent
# trained_ddpg = DDPG("MlpPolicy", env_train, action_noise=action_noise, verbose=1)
# trained_ddpg.learn(total_timesteps=total_timesteps, log_interval=10)

# %% [markdown]
# ### Model 3: SAC

# %%
episode_length = len(e_train_gym.df) + 1
episode_amount = 4
total_training_step = episode_length*episode_amount

# %%
agent_sac = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 2048,
    "buffer_size": episode_length,
    "learning_rate": 0.0003,
    "learning_starts": episode_length,
    "ent_coef": "auto_0.1",
}

model_sac = agent_sac.get_model("sac",model_kwargs = SAC_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_sac/")

# # set up logger
# tmp_path = TENSORBOARD_LOG_DIR + '/test_sac/sac_12'
# new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 2048, 'buffer_size': 58204, 'learning_rate': 0.0003, 'learning_starts': 58204, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent_sac.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=total_training_step)
# Out:
# Logging to tensorboard_log/test_sac/sac_13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 trained_sac = agent_sac.train_model(model=model_sac,
#       2                              tb_log_name='sac',
#       3                              total_timesteps=total_training_step)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/finrl/agents/stablebaselines3/models.py:117, in DRLAgent.train_model(model, tb_log_name, total_timesteps)
#     113 @staticmethod
#     114 def train_model(
#     115     model, tb_log_name, total_timesteps=5000
#     116 ):  # this function is static method, so it can be called without creating an instance of the class
# --> 117     model = model.learn(
#     118         total_timesteps=total_timesteps,
#     119         tb_log_name=tb_log_name,
#     120         callback=TensorboardCallback(),
#     121     )
#     122     return model
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:222, in SAC.train(self, gradient_steps, batch_size)
#     219     self.actor.reset_noise()
#     221 # Action by the current actor for the sampled state
# --> 222 actions_pi, log_prob = self.actor.action_log_prob(replay_data.observations)
#     223 log_prob = log_prob.reshape(-1, 1)
#     225 ent_coef_loss = None
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/sac/policies.py:175, in Actor.action_log_prob(self, obs)
#     173 mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     174 # return action and associated log prob
# --> 175 return self.action_dist.log_prob_from_params(mean_actions, log_std, **kwargs)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/distributions.py:258, in SquashedDiagGaussianDistribution.log_prob_from_params(self, mean_actions, log_std)
#     257 def log_prob_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
# --> 258     action = self.actions_from_params(mean_actions, log_std)
#     259     log_prob = self.log_prob(action, self.gaussian_actions)
#     260     return action, log_prob
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/distributions.py:190, in DiagGaussianDistribution.actions_from_params(self, mean_actions, log_std, deterministic)
#     188 def actions_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor, deterministic: bool = False) -> th.Tensor:
#     189     # Update the proba distribution
# --> 190     self.proba_distribution(mean_actions, log_std)
#     191     return self.get_actions(deterministic=deterministic)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/distributions.py:224, in SquashedDiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     221 def proba_distribution(
#     222     self: SelfSquashedDiagGaussianDistribution, mean_actions: th.Tensor, log_std: th.Tensor
#     223 ) -> SelfSquashedDiagGaussianDistribution:
# --> 224     super().proba_distribution(mean_actions, log_std)
#     225     return self
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)
#     161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/torch/distributions/normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/torch/distributions/distribution.py:68, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      66         valid = constraint.check(value)
#      67         if not valid.all():
# ---> 68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      71                 f"of distribution {repr(self)} "
#      72                 f"to satisfy the constraint {repr(constraint)}, "
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (2048, 1)) of distribution Normal(loc: torch.Size([2048, 1]), scale: torch.Size([2048, 1])) to satisfy the constraint Real(), but found invalid values:
# tensor([[144083.2031],
#         [  3981.0178],
#         [651328.1875],
#         ...,
#         [226908.4219],
#         [  7578.4351],
#         [623024.6875]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ### Model 4: TD3

# %%
# agent_td3 = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100, 
#               "buffer_size": 1000000, 
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3, 
#                              tb_log_name='td3',
#                              total_timesteps=10000)

# %% [markdown]
# ### Model 5: A2C

# %%
# agent_a2c = DRLAgent(env = env_train)

# A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
# model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)

# %%
# trained_a2c = agent.train_model(model=model_a2c, 
#                                 tb_log_name='a2c',
#                                 total_timesteps=10000)

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at the begining. We use the PPO model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2018-12 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
trade_data = trade_data.reset_index(drop=True)

# %%
# trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = trade_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# DRL_prediction function allow testing the model using trading_data dataset

# %%
def DRL_prediction(model, environment, deterministic=False):
        """make a prediction and get results"""
        # test_env, test_obs = environment.get_sb_env()
        # account_memory = None  # This help avoid unnecessary list creation
        # actions_memory = None  # optimize memory consumption

        test_obs = environment.reset()[0]
        # max_steps = len(environment.df.index.unique()) - 1

        for i in range(0,len(environment.df)):
            action = model.predict(np.asarray(test_obs), deterministic=deterministic)
            test_obs,reward,terminal,truncated,info = environment.step(action)
            # test_obs, rewards, dones, info = test_env.step(action)

            # if (i == max_steps - 1):  # more descriptive condition for early termination to clarify the logic
            #     account_memory = environment.env_method(method_name="save_asset_memory")
            #     actions_memory = environment.env_method(method_name="save_action_memory")

            if terminal:
                print("hit end!")
                break
        return pd.DataFrame(e_trade_gym.asset_memory, columns=['account_value']), pd.DataFrame(e_trade_gym.actions_memory,columns=['actions','none'])

# %%
df_account_value_ppo, df_actions_ppo = DRL_prediction(model=trained_ppo, environment = e_trade_gym)

# df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
#     model=trained_ddpg, 
#     environment = e_trade_gym)

# df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
#     model=trained_sac, 
#     environment = e_trade_gym)

# df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
#     model=trained_a2c, 
#     environment = e_trade_gym) if if_using_a2c else [None, None]

# df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
#     model=trained_td3, 
#     environment = e_trade_gym) if if_using_td3 else [None, None]
# Out:
# Episode: 1
# hit end!

# %%
df_account_value_ppo.shape
# df_account_value_ddpg.shape
# df_account_value_sac.shape
# df_account_value_td3.shape
# df_account_value_a2c.shape
# Out:
# (1140, 1)

# %%
df_account_value_ppo['date'] = trade_data.date
# df_account_value_ddpg['date'] = trade_data.date

# %%
df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
# df_account_value_sac.tail()
# df_account_value_td3.tail()
# df_account_value_a2c.tail()
# Out:
#       account_value       date
# 1135   1.269145e+06 2024-02-29
# 1136   1.269145e+06 2024-02-29
# 1137   1.268991e+06 2024-02-29
# 1138   1.268991e+06 2024-02-29
# 1139   1.317198e+06 2024-02-29

# %%
# df_actions_ppo.actions.unique()
# df_actions_ddpg.head()
# df_actions_sac.head()
# df_actions_td3.head()
# df_actions_a2c.head()

# %%
df_actions_ppo['date'] = trade_data.date
df_actions_ppo.head()
# Out:
#         actions  none       date
# 0        [-1.0]  None 2021-01-31
# 1        [-1.0]  None 2021-01-31
# 2        [-1.0]  None 2021-01-31
# 3        [-1.0]  None 2021-01-31
# 4  [0.47518504]  None 2021-01-31

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_account_value = pd.DataFrame(df_account_value_ppo.date.unique())
df_account_value.columns = ['date']
df_account_value['account_value'] = df_account_value.apply(lambda x: \
                                    df_account_value_ppo[df_account_value_ppo.date == x.date].iloc[-1].account_value, axis=1)
df_account_value.head()

# df_account_value = pd.DataFrame(df_account_value_ddpg.date.unique())
# df_account_value.columns = ['date']
# df_account_value['account_value'] = df_account_value.apply(lambda x: \
#                                     df_account_value_ddpg[df_account_value_ddpg.date == x.date].iloc[-1].account_value, axis=1)
# df_account_value.head()
# Out:
#         date  account_value
# 0 2021-01-31   9.990005e+05
# 1 2021-02-28   1.076307e+06
# 2 2021-03-31   1.079006e+06
# 3 2021-04-30   1.082255e+06
# 4 2021-05-31   1.068405e+06

# %% [markdown]
# There's a missmatch between the quarterly computation of df_account_value and the daily frequency of the comparison datasets. We need to transform the df_account_value to a daily basis.
# To fill up the missing data, th **ffill** function effectively imputes values, providing the continous picture of account value trends until the next recorded change. However, for the entries preceding the first recorded change, we will use the **initial_amount**.

# %%
daily_account_value = pd.DataFrame(df.date.unique())
daily_account_value.columns = ['date']
daily_account_value['date'] = pd.to_datetime(daily_account_value.date)
daily_account_value = daily_account_value.merge(df_account_value,how='left')
daily_account_value.ffill(inplace=True)
daily_account_value.fillna(env_kwargs["initial_amount"],inplace=True)
daily_account_value = daily_account_value[daily_account_value.date >= TEST_START_DATE]
daily_account_value.reset_index(inplace=True,drop=True)
daily_account_value
# Out:
#          date  account_value
# 0  2021-01-31   9.990005e+05
# 1  2021-02-28   1.076307e+06
# 2  2021-03-31   1.079006e+06
# 3  2021-04-30   1.082255e+06
# 4  2021-05-31   1.068405e+06
# 5  2021-06-30   1.081685e+06
# 6  2021-07-31   1.094098e+06
# 7  2021-08-31   1.153302e+06
# 8  2021-09-30   1.143719e+06
# 9  2021-10-31   1.191292e+06
# 10 2021-11-30   1.044470e+06
# 11 2021-12-31   1.069061e+06
# 12 2022-01-31   1.036538e+06
# 13 2022-02-28   9.874448e+05
# 14 2022-03-31   9.722624e+05
# 15 2022-04-30   9.606011e+05
# 16 2022-05-31   9.504723e+05
# 17 2022-06-30   9.233700e+05
# 18 2022-07-31   9.968174e+05
# 19 2022-08-31   9.839942e+05
# 20 2022-09-30   9.690769e+05
# 21 2022-10-31   1.112790e+06
# 22 2022-11-30   1.162074e+06
# 23 2022-12-31   1.120269e+06
# 24 2023-01-31   1.249843e+06
# 25 2023-02-28   1.203660e+06
# 26 2023-03-31   1.295433e+06
# 27 2023-04-30   1.290123e+06
# 28 2023-05-31   1.308891e+06
# 29 2023-06-30   1.337821e+06
# 30 2023-07-31   1.488209e+06
# 31 2023-08-31   1.400175e+06
# 32 2023-09-30   1.195256e+06
# 33 2023-10-31   1.170094e+06
# 34 2023-11-30   1.253082e+06
# 35 2023-12-31   1.292869e+06
# 36 2024-01-31   1.246511e+06
# 37 2024-02-29   1.317198e+06
# 38 2024-03-31   1.317198e+06

# %%
print("==============Get Backtest Results===========")
# now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

print("\n ppo:")
perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
# perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

# print("\n ddpg:")
# perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
# perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
# perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

# print("\n sac:")
# perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
# perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
#   perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')

#   print("\n atd3:")
#   perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
#   perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
#   perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

#   print("\n a2c:")
#   perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
#   perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
#   perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.062794
# Cumulative returns     0.317198
# Annual volatility      0.167681
# Sharpe ratio           0.445658
# Calmar ratio           0.271662
# Stability              0.395268
# Max drawdown          -0.231149
# Omega ratio            1.365993
# Sortino ratio          0.787385
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.262418
# Daily value at risk   -0.020829
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Annual return          0.087168
# Cumulative returns     0.307314
# Annual volatility      0.146594
# Sharpe ratio           0.644200
# Calmar ratio           0.397288
# Stability              0.105645
# Max drawdown          -0.219408
# Omega ratio            1.116040
# Sortino ratio          0.919881
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.004049
# Daily value at risk   -0.018094
# dtype: float64

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTest with DJIA

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

backtest_plot(daily_account_value, 
            baseline_ticker = '^DJI', 
            baseline_start = TEST_START_DATE,
            baseline_end = TEST_END_DATE)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ==============Compare to DJIA===========
# Shape of DataFrame:  (808, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-01-31</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-03-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>1</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>496.948%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>31.852%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>94.13%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.41</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>22.10</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.41</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-22.49%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.64</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-10.958%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>3.21</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.62</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>22.49</td>
#       <td>2021-10-31</td>
#       <td>2022-06-30</td>
#       <td>2023-01-31</td>
#       <td>327</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>21.38</td>
#       <td>2023-07-31</td>
#       <td>2023-10-31</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.70</td>
#       <td>2023-01-31</td>
#       <td>2023-02-28</td>
#       <td>2023-03-31</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.28</td>
#       <td>2021-04-30</td>
#       <td>2021-05-31</td>
#       <td>2021-07-31</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.83</td>
#       <td>2021-08-31</td>
#       <td>2021-09-30</td>
#       <td>2021-10-31</td>
#       <td>44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compare to Buy&Hold Strategy
# pass in df_account_value, this information is stored in env class

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTest with Buy&Hold Strategy

# %%
# print(DOW_30_TICKER)
test_portfolio = DOW_30_TICKER
len(test_portfolio)
# Out:
# 30

# %%
modify_fields = ['open','high','low','close']
used_columns = ['date','close']

# %%
# df_stock_test_ = get_baseline(
#         ticker='AXP', 
#         start = TEST_START_DATE,
#         end = TEST_END_DATE)
# df_stock_test_

# %%
# for field in modify_fields:
#     df_stock_test_[field] = df_stock_test_[field]/df_stock_test_.iloc[0][field]/len(test_portfolio)
# df_stock_test_ = df_stock_test_[used_columns]

# %%
daily_account_value.shape
# Out:
# (39, 2)

# %%
#baseline stats
print("==============Get Baseline Stats===========")
shape = daily_account_value.shape
df_hold_ = pd.DataFrame(0,index=range(shape[0]), columns=range(shape[1]))
df_hold_.columns = used_columns
df_hold_['date'] = daily_account_value.date

for stock in test_portfolio:
    df_stock_ = get_baseline(
        ticker=stock, 
        start = TEST_START_DATE,
        end = TEST_END_DATE)
    # for field in modify_fields:
    if len(df_stock_) < len(df_hold_):
        final_row = df_stock_.iloc[-1]
        new_rows = pd.DataFrame([final_row] * (len(df_hold_) - len(df_stock_)))
        df_stock_ = pd.concat([df_stock_, new_rows], ignore_index=True)
        
        for i in range(0,len(df_stock_) < len(df_hold_)):
            df_stock_.iloc[en(df_stock_)] = df_stock_.iloc[len(df_stock_-1)]
    df_stock_['close'] = df_stock_['close']/df_stock_.iloc[0]['close']/len(test_portfolio)
    df_hold_['close'] = df_hold_.close + df_stock_.close

stats = backtest_stats(df_hold_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (808, 8)
# Shape of DataFrame:  (808, 8)
# Annual return           0.415404
# Cumulative returns      0.055238
# Annual volatility       0.142013
# Sharpe ratio            2.581802
# Calmar ratio           10.349355
# Stability               0.407411
# Max drawdown           -0.040138
# Omega ratio             1.575704
# Sortino ratio           3.763792
# Skew                         NaN
# Kurtosis                     NaN
# Tail ratio              0.848876
# Daily value at risk    -0.016437
# dtype: float64

# %%
df_hold_
# Out:
#          date     close
# 0  2021-01-31  1.000000
# 1  2021-02-28  1.006314
# 2  2021-03-31  1.021052
# 3  2021-04-30  1.029017
# 4  2021-05-31  1.030249
# 5  2021-06-30  1.029785
# 6  2021-07-31  1.033666
# 7  2021-08-31  1.035076
# 8  2021-09-30  1.035051
# 9  2021-10-31  1.026937
# 10 2021-11-30  1.030746
# 11 2021-12-31  1.039045
# 12 2022-01-31  1.038597
# 13 2022-02-28  1.029507
# 14 2022-03-31  1.028421
# 15 2022-04-30  1.027227
# 16 2022-05-31  1.009060
# 17 2022-06-30  1.018215
# 18 2022-07-31  0.997340
# 19 2022-08-31  1.004524
# 20 2022-09-30  1.018989
# 21 2022-10-31  1.020445
# 22 2022-11-30  1.033378
# 23 2022-12-31  1.038320
# 24 2023-01-31  1.046430
# 25 2023-02-28  1.044933
# 26 2023-03-31  1.047083
# 27 2023-04-30  1.047593
# 28 2023-05-31  1.049621
# 29 2023-06-30  1.051232
# 30 2023-07-31  1.054914
# 31 2023-08-31  1.050851
# 32 2023-09-30  1.052054
# 33 2023-10-31  1.054023
# 34 2023-11-30  1.055057
# 35 2023-12-31  1.069562
# 36 2024-01-31  1.051501
# 37 2024-02-29  1.034710
# 38 2024-03-31  1.055238

# %% [markdown]
# The model' calculation encompass the entire timeframe, including non-working days. To address this, we need to determine the most appropriate method to fill up the weekend plots, for example backfilling.

# %%
# df_hold_.date = pd.to_datetime(df_hold_['date'])
# df_hold_ = pd.merge(df_account_value_ppo['date'],df_hold_,how='left')
# df_hold_.bfill(inplace=True)
# df_hold_

# %%
df_hold = pd.DataFrame()
df_hold['date'] = daily_account_value['date']
df_hold['hold'] = df_hold_['close'] / df_hold_['close'][0] * env_kwargs["initial_amount"]
# print("df_hold: ", df_hold)
# df_dji.to_csv("df_dji.csv")
df_hold = df_hold.set_index(df_hold.columns[0])
print("df_hold: ", df_hold)
# df_hold.to_csv("df_dji+.csv")

# df_account_value.to_csv('df_account_value.csv')
# Out:
# df_hold:                      hold
# date
# 2021-01-31  1.000000e+06
# 2021-02-28  1.006314e+06
# 2021-03-31  1.021052e+06
# 2021-04-30  1.029017e+06
# 2021-05-31  1.030249e+06
# 2021-06-30  1.029785e+06
# 2021-07-31  1.033666e+06
# 2021-08-31  1.035076e+06
# 2021-09-30  1.035051e+06
# 2021-10-31  1.026937e+06
# 2021-11-30  1.030746e+06
# 2021-12-31  1.039045e+06
# 2022-01-31  1.038597e+06
# 2022-02-28  1.029507e+06
# 2022-03-31  1.028421e+06
# 2022-04-30  1.027227e+06
# 2022-05-31  1.009060e+06
# 2022-06-30  1.018215e+06
# 2022-07-31  9.973398e+05
# 2022-08-31  1.004524e+06
# 2022-09-30  1.018989e+06
# 2022-10-31  1.020445e+06
# 2022-11-30  1.033378e+06
# 2022-12-31  1.038320e+06
# 2023-01-31  1.046430e+06
# 2023-02-28  1.044933e+06
# 2023-03-31  1.047083e+06
# 2023-04-30  1.047593e+06
# 2023-05-31  1.049621e+06
# 2023-06-30  1.051232e+06
# 2023-07-31  1.054914e+06
# 2023-08-31  1.050851e+06
# 2023-09-30  1.052054e+06
# 2023-10-31  1.054023e+06
# 2023-11-30  1.055057e+06
# 2023-12-31  1.069562e+06
# 2024-01-31  1.051501e+06
# 2024-02-29  1.034710e+06
# 2024-03-31  1.055238e+06

# %%
print("==============Compare to Buy&Hold===========")
df_result = pd.DataFrame({'date': df_account_value_ppo['date'], 'stock': df_account_value_ppo['account_value']})
df_result = df_result.set_index('date')

result = pd.DataFrame()
result = pd.merge(df_result, df_hold, left_index=True, right_index=True)
print("result: ", result)
# result.to_csv("result.csv")
result.columns = ['model', 'buy_and_hold']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# ==============Compare to Buy&Hold===========
# result:                     stock          hold
# date
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# ...                  ...           ...
# 2024-02-29  1.269145e+06  1.034710e+06
# 2024-02-29  1.269145e+06  1.034710e+06
# 2024-02-29  1.268991e+06  1.034710e+06
# 2024-02-29  1.268991e+06  1.034710e+06
# 2024-02-29  1.317198e+06  1.034710e+06
#
# [1140 rows x 2 columns]

# %% [markdown]
# <a id='7'></a>
# # 8. Save and load model #

# %% [markdown]
# <a id='7.1'></a>
# ## 8.1 Save model

# %% [markdown]
# ### 8.1.1 Save trained model

# %%
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/DeepReinforcementLearning/FinRL-Tutorials-master/6-Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/dow30_endRecord_ppo_256episode"
model_name
# Out:
# './trained_models/dow30_endRecord_ppo_256episode'

# %%
trained_ppo.save(model_name)

# %% [markdown]
# ### 8.1.2 Save model as ONNX file

# %%
import torch as th
import torch.onnx
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import DDPG
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(trained_ppo.policy)
observation_size = trained_ppo.observation_space.shape
dummy_input = th.randn(1, *observation_size)

th.onnx.export(
    onnx_policy,
    dummy_input,
    "sac_model_1200k_sac9.onnx",
    opset_version=17,
    input_names=["input"],
)

# %% [markdown]
# <a id='7.2'></a>
# ## 8.2 Load model

# %% [markdown]
# ### 8.2.1 Load trained model

# %%
from stable_baselines3 import PPO
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/DeepReinforcementLearning/FinRL-Tutorials-master/6-Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/ppo_model_384steps"
model_name
# Out:
# './trained_models/ppo_model_384steps'

# %%
trained_model = PPO.load(model_name)

# %% [markdown]
# Continous training based on the previous model

# %%
episode_length = len(e_train_gym.df)
episode_amount = 128
total_training_step = episode_length*episode_amount

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.3,
    "print_verbosity":4,
    "punishment_rate": 0.001
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()
agent = DRLAgent(env = env_train)
trained_model.env = env_train

# %%
trained_ppo = agent.train_model(model=trained_model, 
                             tb_log_name='ppo',
                             total_timesteps=total_training_step)
# Out:
# Logging to tensorboard_log/test_ppo/ppo_13
# -----------------------------
# | time/              |      |
# |    fps             | 289  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# | train/             |      |
# |    reward          | -0.1 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 2             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00077376503 |
# |    clip_fraction        | 0.00811       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.65         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.85          |
# |    n_updates            | 9460          |
# |    policy_gradient_loss | -0.000406     |
# |    reward               | 0.025211712   |
# |    std                  | 3.44          |
# |    value_loss           | 6.71          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 3             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 9.2789734e-05 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.66         |
# |    explained_variance   | -7.99e-05     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.1           |
# |    n_updates            | 9470          |
# |    policy_gradient_loss | -2.51e-05     |
# |    reward               | -0.1          |
# |    std                  | 3.46          |
# |    value_loss           | 8.93          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 4            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0011321616 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 3.02e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.66         |
# |    n_updates            | 9480         |
# |    policy_gradient_loss | -0.000378    |
# |    reward               | -0.1         |
# |    std                  | 3.47         |
# |    value_loss           | 6.37         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 5            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0007965357 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.66        |
# |    explained_variance   | 9.31e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.84         |
# |    n_updates            | 9490         |
# |    policy_gradient_loss | -0.000284    |
# |    reward               | -0.1         |
# |    std                  | 3.48         |
# |    value_loss           | 6.42         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 6             |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00014287909 |
# |    clip_fraction        | 0.00522       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.67         |
# |    explained_variance   | 4.14e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.15          |
# |    n_updates            | 9500          |
# |    policy_gradient_loss | -0.000378     |
# |    reward               | 0.4296632     |
# |    std                  | 3.51          |
# |    value_loss           | 8.77          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 7            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0007449471 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.58         |
# |    n_updates            | 9510         |
# |    policy_gradient_loss | -0.000569    |
# |    reward               | -0.1         |
# |    std                  | 3.52         |
# |    value_loss           | 5.5          |
# ------------------------------------------
# day: 4710, episode: 4
# begin_total_asset: 1000000.00
# end_total_asset: 699757.31
# total_reward: -300242.69
# total_cost: 727365.69
# total_trades: 1514
# Sharpe: -0.053
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 8             |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00095034787 |
# |    clip_fraction        | 0.0126        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.68         |
# |    explained_variance   | -0.000131     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.63          |
# |    n_updates            | 9520          |
# |    policy_gradient_loss | -0.000454     |
# |    reward               | -2.7742026    |
# |    std                  | 3.53          |
# |    value_loss           | 6.65          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 9             |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00042320014 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.69         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.87          |
# |    n_updates            | 9530          |
# |    policy_gradient_loss | -0.000138     |
# |    reward               | -0.1          |
# |    std                  | 3.56          |
# |    value_loss           | 8.51          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 10            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00015124812 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.69         |
# |    explained_variance   | -7.37e-05     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.97          |
# |    n_updates            | 9540          |
# |    policy_gradient_loss | -8.85e-05     |
# |    reward               | -0.1          |
# |    std                  | 3.6           |
# |    value_loss           | 11.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 11            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00032187646 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.7          |
# |    explained_variance   | 3.22e-06      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.19          |
# |    n_updates            | 9550          |
# |    policy_gradient_loss | -9.78e-05     |
# |    reward               | -0.1          |
# |    std                  | 3.59          |
# |    value_loss           | 10.1          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 12           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 6.526825e-05 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | -0.000173    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.42         |
# |    n_updates            | 9560         |
# |    policy_gradient_loss | 6.06e-06     |
# |    reward               | -0.1         |
# |    std                  | 3.6          |
# |    value_loss           | 26.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 13           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0006223691 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 1.2e-05      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.42         |
# |    n_updates            | 9570         |
# |    policy_gradient_loss | -7.89e-05    |
# |    reward               | -0.1         |
# |    std                  | 3.63         |
# |    value_loss           | 16.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 278           |
# |    iterations           | 14            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00033265701 |
# |    clip_fraction        | 0.00288       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.71         |
# |    explained_variance   | 0.000345      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.52          |
# |    n_updates            | 9580          |
# |    policy_gradient_loss | 3.72e-05      |
# |    reward               | -0.1          |
# |    std                  | 3.63          |
# |    value_loss           | 6.39          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 15           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 3.086854e-05 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 3.99e-06     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.4          |
# |    n_updates            | 9590         |
# |    policy_gradient_loss | 0.000184     |
# |    reward               | -0.1         |
# |    std                  | 3.62         |
# |    value_loss           | 4.57         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 16            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00013305509 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.71         |
# |    explained_variance   | 0.000108      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.06          |
# |    n_updates            | 9600          |
# |    policy_gradient_loss | 3.65e-05      |
# |    reward               | 0.14476709    |
# |    std                  | 3.64          |
# |    value_loss           | 7.33          |
# -------------------------------------------
# day: 5033, episode: 8
# begin_total_asset: 1000000.00
# end_total_asset: 1171968.03
# total_reward: 171968.03
# total_cost: 924681.18
# total_trades: 1802
# Sharpe: 0.127
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 17           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0009050268 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.85         |
# |    n_updates            | 9610         |
# |    policy_gradient_loss | -0.00107     |
# |    reward               | 0.0          |
# |    std                  | 3.63         |
# |    value_loss           | 9.16         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 18            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00026150572 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.71         |
# |    explained_variance   | 9.55e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.97          |
# |    n_updates            | 9620          |
# |    policy_gradient_loss | 7.63e-05      |
# |    reward               | 0.110206105   |
# |    std                  | 3.63          |
# |    value_loss           | 7.62          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 19            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00075625436 |
# |    clip_fraction        | 0.0193        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.71         |
# |    explained_variance   | -0.000224     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.11          |
# |    n_updates            | 9630          |
# |    policy_gradient_loss | -0.000316     |
# |    reward               | -0.1          |
# |    std                  | 3.63          |
# |    value_loss           | 10.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 273           |
# |    iterations           | 20            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00022276191 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.71         |
# |    explained_variance   | 0.000168      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.79          |
# |    n_updates            | 9640          |
# |    policy_gradient_loss | -0.000217     |
# |    reward               | 0.0           |
# |    std                  | 3.66          |
# |    value_loss           | 9.32          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 21           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0006584681 |
# |    clip_fraction        | 0.00142      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.000382     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.78         |
# |    n_updates            | 9650         |
# |    policy_gradient_loss | -0.000496    |
# |    reward               | -0.1         |
# |    std                  | 3.66         |
# |    value_loss           | 21.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 261          |
# |    iterations           | 22           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0009651884 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | -0.000548    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.1         |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | 0.000121     |
# |    reward               | 0.0          |
# |    std                  | 3.67         |
# |    value_loss           | 36.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 23            |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00038530253 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.72         |
# |    explained_variance   | 0.00116       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.52          |
# |    n_updates            | 9670          |
# |    policy_gradient_loss | 3.1e-05       |
# |    reward               | -0.1          |
# |    std                  | 3.68          |
# |    value_loss           | 10.2          |
# -------------------------------------------
# day: 5033, episode: 12
# begin_total_asset: 1000000.00
# end_total_asset: 2120656.12
# total_reward: 1120656.12
# total_cost: 1470160.71
# total_trades: 2285
# Sharpe: 0.339
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 24            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00012359506 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 1.94e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.77          |
# |    n_updates            | 9680          |
# |    policy_gradient_loss | -0.000148     |
# |    reward               | 0.0           |
# |    std                  | 3.73          |
# |    value_loss           | 8.61          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 25           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0008532709 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 5.16e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.14         |
# |    n_updates            | 9690         |
# |    policy_gradient_loss | -0.00103     |
# |    reward               | 0.0          |
# |    std                  | 3.73         |
# |    value_loss           | 10.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 26           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0013806897 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | -0.000239    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.97         |
# |    n_updates            | 9700         |
# |    policy_gradient_loss | -0.00127     |
# |    reward               | 0.0          |
# |    std                  | 3.74         |
# |    value_loss           | 14.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 27           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0009462243 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | -0.000451    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.84         |
# |    n_updates            | 9710         |
# |    policy_gradient_loss | -0.00087     |
# |    reward               | -0.1         |
# |    std                  | 3.77         |
# |    value_loss           | 11.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 28           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0012935539 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.42         |
# |    n_updates            | 9720         |
# |    policy_gradient_loss | -0.000844    |
# |    reward               | 0.0          |
# |    std                  | 3.79         |
# |    value_loss           | 6.63         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 29           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0009281464 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.000227     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.5          |
# |    n_updates            | 9730         |
# |    policy_gradient_loss | -0.00104     |
# |    reward               | -0.1         |
# |    std                  | 3.78         |
# |    value_loss           | 6.36         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 255           |
# |    iterations           | 30            |
# |    time_elapsed         | 240           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00026196783 |
# |    clip_fraction        | 0.00229       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.75         |
# |    explained_variance   | -0.000137     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.97          |
# |    n_updates            | 9740          |
# |    policy_gradient_loss | -4.23e-05     |
# |    reward               | 0.0           |
# |    std                  | 3.78          |
# |    value_loss           | 6.33          |
# -------------------------------------------
# day: 577, episode: 16
# begin_total_asset: 1000000.00
# end_total_asset: 693687.93
# total_reward: -306312.07
# total_cost: 129386.75
# total_trades: 336
# Sharpe: -0.911
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 31          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.001034747 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.3         |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | -0.00077    |
# |    reward               | -0.1        |
# |    std                  | 3.75        |
# |    value_loss           | 5.23        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 32          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.001193244 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.21        |
# |    n_updates            | 9760        |
# |    policy_gradient_loss | -0.00118    |
# |    reward               | 0.0         |
# |    std                  | 3.73        |
# |    value_loss           | 8.15        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 253           |
# |    iterations           | 33            |
# |    time_elapsed         | 266           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00022103524 |
# |    clip_fraction        | 0.00122       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | -0.000126     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.24          |
# |    n_updates            | 9770          |
# |    policy_gradient_loss | 2.41e-05      |
# |    reward               | -0.1          |
# |    std                  | 3.75          |
# |    value_loss           | 15.6          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 252           |
# |    iterations           | 34            |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00027964328 |
# |    clip_fraction        | 0.00308       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 0.00107       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.97          |
# |    n_updates            | 9780          |
# |    policy_gradient_loss | -9.16e-05     |
# |    reward               | 0.24272752    |
# |    std                  | 3.77          |
# |    value_loss           | 16.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 35           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0010743757 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.00346      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.92         |
# |    n_updates            | 9790         |
# |    policy_gradient_loss | -0.000364    |
# |    reward               | 0.3097935    |
# |    std                  | 3.8          |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 36           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0005615256 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | -0.000262    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.68         |
# |    n_updates            | 9800         |
# |    policy_gradient_loss | -0.000513    |
# |    reward               | 0.0          |
# |    std                  | 3.8          |
# |    value_loss           | 11.2         |
# ------------------------------------------
# day: 2411, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 699198.49
# total_reward: -300801.51
# total_cost: 636148.78
# total_trades: 1627
# Sharpe: -0.198
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 250           |
# |    iterations           | 37            |
# |    time_elapsed         | 302           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00051482685 |
# |    clip_fraction        | 0.00605       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.76         |
# |    explained_variance   | -0.00729      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.63          |
# |    n_updates            | 9810          |
# |    policy_gradient_loss | -0.000639     |
# |    reward               | 0.0           |
# |    std                  | 3.87          |
# |    value_loss           | 6.31          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 38           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0016609719 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.63         |
# |    n_updates            | 9820         |
# |    policy_gradient_loss | -0.00198     |
# |    reward               | -0.1         |
# |    std                  | 3.88         |
# |    value_loss           | 5.03         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 248          |
# |    iterations           | 39           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0005058973 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.00202      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.49         |
# |    n_updates            | 9830         |
# |    policy_gradient_loss | -0.000235    |
# |    reward               | -0.1         |
# |    std                  | 3.84         |
# |    value_loss           | 3.89         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 40         |
# |    time_elapsed         | 331        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00167998 |
# |    clip_fraction        | 0.0367     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | -0.000725  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.38       |
# |    n_updates            | 9840       |
# |    policy_gradient_loss | -0.00154   |
# |    reward               | -0.1       |
# |    std                  | 3.85       |
# |    value_loss           | 6.19       |
# ----------------------------------------
# day: 2886, episode: 24
# begin_total_asset: 1000000.00
# end_total_asset: 699587.79
# total_reward: -300412.21
# total_cost: 793720.66
# total_trades: 2041
# Sharpe: -0.169
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 41           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0003327074 |
# |    clip_fraction        | 0.00474      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.52         |
# |    n_updates            | 9850         |
# |    policy_gradient_loss | -0.000525    |
# |    reward               | -0.19697756  |
# |    std                  | 3.93         |
# |    value_loss           | 4.95         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 42           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0005351673 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 5.08e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.54         |
# |    n_updates            | 9860         |
# |    policy_gradient_loss | -0.00113     |
# |    reward               | 0.0          |
# |    std                  | 3.99         |
# |    value_loss           | 3.55         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 43           |
# |    time_elapsed         | 361          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0005365212 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.00113      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.87         |
# |    n_updates            | 9870         |
# |    policy_gradient_loss | -0.000484    |
# |    reward               | 0.0          |
# |    std                  | 3.99         |
# |    value_loss           | 4.35         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 44           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0012677398 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | -0.00102     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.45         |
# |    n_updates            | 9880         |
# |    policy_gradient_loss | -0.00121     |
# |    reward               | -3.2045193   |
# |    std                  | 3.96         |
# |    value_loss           | 3.37         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 45           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0010043931 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | -0.00038     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.61         |
# |    n_updates            | 9890         |
# |    policy_gradient_loss | -8.19e-05    |
# |    reward               | 0.0          |
# |    std                  | 3.96         |
# |    value_loss           | 3.59         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 46            |
# |    time_elapsed         | 389           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 4.2186846e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 8.18e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.52          |
# |    n_updates            | 9900          |
# |    policy_gradient_loss | 5.26e-05      |
# |    reward               | 0.0           |
# |    std                  | 3.96          |
# |    value_loss           | 5.68          |
# -------------------------------------------
# day: 1369, episode: 28
# begin_total_asset: 1000000.00
# end_total_asset: 697746.93
# total_reward: -302253.07
# total_cost: 365740.95
# total_trades: 992
# Sharpe: -0.373
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 47           |
# |    time_elapsed         | 398          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0006685604 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.65         |
# |    n_updates            | 9910         |
# |    policy_gradient_loss | -6.78e-05    |
# |    reward               | 0.0          |
# |    std                  | 3.96         |
# |    value_loss           | 6.62         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 48            |
# |    time_elapsed         | 408           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00014263275 |
# |    clip_fraction        | 0.000684      |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.8          |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.13          |
# |    n_updates            | 9920          |
# |    policy_gradient_loss | -0.000169     |
# |    reward               | 0.0           |
# |    std                  | 4             |
# |    value_loss           | 4.29          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 49            |
# |    time_elapsed         | 417           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00063694164 |
# |    clip_fraction        | 0.016         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.000197      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.26          |
# |    n_updates            | 9930          |
# |    policy_gradient_loss | -0.000652     |
# |    reward               | 0.0           |
# |    std                  | 4.02          |
# |    value_loss           | 3.65          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 50           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0012495747 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.83         |
# |    n_updates            | 9940         |
# |    policy_gradient_loss | -0.000634    |
# |    reward               | -0.88086426  |
# |    std                  | 4.02         |
# |    value_loss           | 5.77         |
# ------------------------------------------
# day: 2850, episode: 32
# begin_total_asset: 1000000.00
# end_total_asset: 695821.05
# total_reward: -304178.95
# total_cost: 887733.19
# total_trades: 2091
# Sharpe: -0.187
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 239           |
# |    iterations           | 51            |
# |    time_elapsed         | 436           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00048575227 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0.00106       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.31          |
# |    n_updates            | 9950          |
# |    policy_gradient_loss | -0.000178     |
# |    reward               | 0.0           |
# |    std                  | 4.04          |
# |    value_loss           | 6.83          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 52           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 3.821685e-05 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.000638     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.24         |
# |    n_updates            | 9960         |
# |    policy_gradient_loss | 0.00011      |
# |    reward               | 0.0          |
# |    std                  | 4.05         |
# |    value_loss           | 4.71         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 53           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0013907005 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.24         |
# |    n_updates            | 9970         |
# |    policy_gradient_loss | -0.00138     |
# |    reward               | -0.1         |
# |    std                  | 4.06         |
# |    value_loss           | 4.04         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 237           |
# |    iterations           | 54            |
# |    time_elapsed         | 465           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00032836766 |
# |    clip_fraction        | 0.0042        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.5           |
# |    n_updates            | 9980          |
# |    policy_gradient_loss | -0.000525     |
# |    reward               | -4.015626     |
# |    std                  | 4             |
# |    value_loss           | 4.19          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 237           |
# ...
# | time/                   |              |
# |    fps                  | 183          |
# |    iterations           | 298          |
# |    time_elapsed         | 3322         |
# |    total_timesteps      | 610304       |
# | train/                  |              |
# |    approx_kl            | 0.0007078642 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.00352      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00856      |
# |    n_updates            | 12420        |
# |    policy_gradient_loss | -0.000594    |
# |    reward               | 0.0          |
# |    std                  | 4.96         |
# |    value_loss           | 0.0913       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 183          |
# |    iterations           | 299          |
# |    time_elapsed         | 3335         |
# |    total_timesteps      | 612352       |
# | train/                  |              |
# |    approx_kl            | 0.0008542048 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 1.64e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.234        |
# |    n_updates            | 12430        |
# |    policy_gradient_loss | -0.00105     |
# |    reward               | 0.0          |
# |    std                  | 4.96         |
# |    value_loss           | 0.563        |
# ------------------------------------------
# day: 5033, episode: 168
# begin_total_asset: 1000000.00
# end_total_asset: 908115.71
# total_reward: -91884.29
# total_cost: 176511.57
# total_trades: 4910
# Sharpe: -0.115
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 183          |
# |    iterations           | 300          |
# |    time_elapsed         | 3347         |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0006001547 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.0102       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.238        |
# |    n_updates            | 12440        |
# |    policy_gradient_loss | -0.000295    |
# |    reward               | 0.0          |
# |    std                  | 5.01         |
# |    value_loss           | 0.543        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 183          |
# |    iterations           | 301          |
# |    time_elapsed         | 3359         |
# |    total_timesteps      | 616448       |
# | train/                  |              |
# |    approx_kl            | 0.0006675681 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | -0.00195     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.176        |
# |    n_updates            | 12450        |
# |    policy_gradient_loss | -0.000677    |
# |    reward               | 0.0          |
# |    std                  | 5            |
# |    value_loss           | 0.51         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 183           |
# |    iterations           | 302           |
# |    time_elapsed         | 3371          |
# |    total_timesteps      | 618496        |
# | train/                  |               |
# |    approx_kl            | 4.3492357e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0472        |
# |    n_updates            | 12460         |
# |    policy_gradient_loss | 4.27e-05      |
# |    reward               | 0.0           |
# |    std                  | 4.99          |
# |    value_loss           | 0.283         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 183          |
# |    iterations           | 303          |
# |    time_elapsed         | 3385         |
# |    total_timesteps      | 620544       |
# | train/                  |              |
# |    approx_kl            | 0.0013061743 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0483       |
# |    n_updates            | 12470        |
# |    policy_gradient_loss | -0.00166     |
# |    reward               | 0.0          |
# |    std                  | 5            |
# |    value_loss           | 0.13         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 183           |
# |    iterations           | 304           |
# |    time_elapsed         | 3397          |
# |    total_timesteps      | 622592        |
# | train/                  |               |
# |    approx_kl            | 0.00038666764 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0805        |
# |    n_updates            | 12480         |
# |    policy_gradient_loss | 2.49e-05      |
# |    reward               | 0.0           |
# |    std                  | 5             |
# |    value_loss           | 0.267         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 183            |
# |    iterations           | 305            |
# |    time_elapsed         | 3409           |
# |    total_timesteps      | 624640         |
# | train/                  |                |
# |    approx_kl            | 0.000103315455 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.1            |
# |    entropy_loss         | -3.03          |
# |    explained_variance   | -0.0093        |
# |    learning_rate        | 0.00025        |
# |    loss                 | 0.0246         |
# |    n_updates            | 12490          |
# |    policy_gradient_loss | 7.87e-05       |
# |    reward               | 0.0            |
# |    std                  | 4.98           |
# |    value_loss           | 0.164          |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 183           |
# |    iterations           | 306           |
# |    time_elapsed         | 3421          |
# |    total_timesteps      | 626688        |
# | train/                  |               |
# |    approx_kl            | 0.00089619635 |
# |    clip_fraction        | 0.0175        |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | 0.00124       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.078         |
# |    n_updates            | 12500         |
# |    policy_gradient_loss | -0.000918     |
# |    reward               | 0.0           |
# |    std                  | 4.99          |
# |    value_loss           | 0.223         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 183           |
# |    iterations           | 307           |
# |    time_elapsed         | 3433          |
# |    total_timesteps      | 628736        |
# | train/                  |               |
# |    approx_kl            | 0.00017450101 |
# |    clip_fraction        | 0.00171       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | 0.00617       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0227        |
# |    n_updates            | 12510         |
# |    policy_gradient_loss | -0.000238     |
# |    reward               | 0.0           |
# |    std                  | 5.02          |
# |    value_loss           | 0.124         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 183           |
# |    iterations           | 308           |
# |    time_elapsed         | 3446          |
# |    total_timesteps      | 630784        |
# | train/                  |               |
# |    approx_kl            | 0.00082402397 |
# |    clip_fraction        | 0.00576       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | 0.0015        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.101         |
# |    n_updates            | 12520         |
# |    policy_gradient_loss | -0.000489     |
# |    reward               | 0.0           |
# |    std                  | 5.02          |
# |    value_loss           | 0.265         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 309          |
# |    time_elapsed         | 3458         |
# |    total_timesteps      | 632832       |
# | train/                  |              |
# |    approx_kl            | 0.0009579563 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0439       |
# |    n_updates            | 12530        |
# |    policy_gradient_loss | -0.000658    |
# |    reward               | -1.3494122   |
# |    std                  | 4.99         |
# |    value_loss           | 0.112        |
# ------------------------------------------
# day: 5033, episode: 172
# begin_total_asset: 1000000.00
# end_total_asset: 765494.25
# total_reward: -234505.75
# total_cost: 141195.92
# total_trades: 4957
# Sharpe: -0.469
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 310          |
# |    time_elapsed         | 3470         |
# |    total_timesteps      | 634880       |
# | train/                  |              |
# |    approx_kl            | 0.0006705982 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0514       |
# |    n_updates            | 12540        |
# |    policy_gradient_loss | -0.000953    |
# |    reward               | 0.0          |
# |    std                  | 4.93         |
# |    value_loss           | 0.089        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 311          |
# |    time_elapsed         | 3485         |
# |    total_timesteps      | 636928       |
# | train/                  |              |
# |    approx_kl            | 0.0002761262 |
# |    clip_fraction        | 0.00107      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.16         |
# |    n_updates            | 12550        |
# |    policy_gradient_loss | -0.000113    |
# |    reward               | 0.0          |
# |    std                  | 4.95         |
# |    value_loss           | 0.357        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 312          |
# |    time_elapsed         | 3500         |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0012626096 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | -0.0204      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.122        |
# |    n_updates            | 12560        |
# |    policy_gradient_loss | -0.00103     |
# |    reward               | 0.0          |
# |    std                  | 4.97         |
# |    value_loss           | 0.247        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 182           |
# |    iterations           | 313           |
# |    time_elapsed         | 3516          |
# |    total_timesteps      | 641024        |
# | train/                  |               |
# |    approx_kl            | 0.00024265869 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -3.03         |
# |    explained_variance   | -0.000971     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.131         |
# |    n_updates            | 12570         |
# |    policy_gradient_loss | -0.000174     |
# |    reward               | 0.0           |
# |    std                  | 5             |
# |    value_loss           | 0.635         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 314          |
# |    time_elapsed         | 3532         |
# |    total_timesteps      | 643072       |
# | train/                  |              |
# |    approx_kl            | 0.0008410122 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0261       |
# |    n_updates            | 12580        |
# |    policy_gradient_loss | -0.000455    |
# |    reward               | 0.0          |
# |    std                  | 5.01         |
# |    value_loss           | 0.158        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 181          |
# |    iterations           | 315          |
# |    time_elapsed         | 3546         |
# |    total_timesteps      | 645120       |
# | train/                  |              |
# |    approx_kl            | 0.0010176316 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -3.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00531     |
# |    n_updates            | 12590        |
# |    policy_gradient_loss | -0.000543    |
# |    reward               | 0.0          |
# |    std                  | 5            |
# |    value_loss           | 0.119        |
# ------------------------------------------

# %% [markdown]
# #### Test loaded model

# %%
test_env = StockTradingEnv(df = trade_data, **env_kwargs)

# %%
test_step = 1000
test_result = []
test_env.reset()
for i in range(0,test_step):
    observation = [test_env.state]
    observation = np.array(observation).astype(np.float32)
    actions, values, log_prob = ort_sess.run(None, {"input": observation})
    result = test_env.step(actions)
    test_result.append(result[1])
    if result[2] == True:
        break

# %% [markdown]
# ### 8.2.2 Load ONNX model

# %%
import onnx
import onnxruntime as ort
import numpy as np

# %%
onnx_path = "all_in_one_ppo.onnx"
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)

# # Check that the predictions are the same
# with th.no_grad():
#     print(model.policy(th.as_tensor(observation), deterministic=True))

# %%
observation = np.zeros((1, state_space)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
actions, values, log_prob = ort_sess.run(None, {"input": observation})
print(actions, values, log_prob)
