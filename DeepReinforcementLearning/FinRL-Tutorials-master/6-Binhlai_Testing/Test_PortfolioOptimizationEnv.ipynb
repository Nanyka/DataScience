# %% [markdown]
# # A guide Portfolio Optimization Environment
#
# This notebook aims to provide an example of using PortfolioOptimizationEnv (or POE) to train a reinforcement learning model that learns to solve the portfolio optimization problem.
#
# In this document, we will reproduce a famous architecture called EIIE (ensemble of identical independent evaluators), introduced in the following paper:
#
# - Zhengyao Jiang, Dixing Xu, & Jinjun Liang. (2017). A Deep Reinforcement Learning Framework for the Financial Portfolio Management Problem. https://doi.org/10.48550/arXiv.1706.10059.
#
# It's advisable to read it to understand the algorithm implemented in this notebook.
#
# ### Note
# If you're using this environment, consider citing the following paper (in adittion to FinRL references):
#
# - Caio Costa, & Anna Costa (2023). POE: A General Portfolio Optimization Environment for FinRL. In *Anais do II Brazilian Workshop on Artificial Intelligence in Finance* (pp. 132–143). SBC. https://doi.org/10.5753/bwaif.2023.231144.
#
# ```
# @inproceedings{bwaif,
#  author = {Caio Costa and Anna Costa},
#  title = {POE: A General Portfolio Optimization Environment for FinRL},
#  booktitle = {Anais do II Brazilian Workshop on Artificial Intelligence in Finance},
#  location = {João Pessoa/PB},
#  year = {2023},
#  keywords = {},
#  issn = {0000-0000},
#  pages = {132--143},
#  publisher = {SBC},
#  address = {Porto Alegre, RS, Brasil},
#  doi = {10.5753/bwaif.2023.231144},
#  url = {https://sol.sbc.org.br/index.php/bwaif/article/view/24959}
# }
#
# ```

# %% [markdown]
# ## Installation and imports
#
# To run this notebook in google colab, uncomment the cells below.

# %%
## install finrl library
# !sudo apt install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
## We also need to install quantstats, because the environment uses it to plot graphs
# !pip install quantstats
# Out:
# Requirement already satisfied: quantstats in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (0.0.62)
# Requirement already satisfied: pandas>=0.24.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (2.2.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (1.26.4)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (3.8.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (1.12.0)
# Requirement already satisfied: tabulate>=0.8.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (0.2.37)
# Requirement already satisfied: python-dateutil>=2.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from quantstats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from matplotlib>=3.0.0->quantstats) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from pandas>=0.24.0->quantstats) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from pandas>=0.24.0->quantstats) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from python-dateutil>=2.0->quantstats) (1.16.0)
# Requirement already satisfied: requests>=2.31 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.5)
# Requirement already satisfied: webencodings in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2024.2.2)

# %%
## Hide matplotlib warnings
# import warnings
# warnings.filterwarnings('ignore')

import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %% [markdown]
# #### Import the necessary code libraries

# %%
import copy
import gym
import torch
import random
import functools

import numpy as np
import torch.nn.functional as F

from tqdm.notebook import tqdm
from collections import deque

from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data.dataset import IterableDataset
from torch.optim import AdamW

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Fetch data
#
# In his paper, *Jiang et al* creates a portfolio composed by the top-11 cryptocurrencies based on 30-days volume. Since it's not specified when this classification was done, it's difficult to reproduce, so we will use a similar approach in the Brazillian stock market:
#
# - We select top-10 stocks from Brazillian stock market;
# - For simplicity, we disconsider stocks that have missing data for a days in period 2011-01-01 to 2019-12-31 (9 years);

# %%
# TOP_BRL = [
#     "ITUB4.SA", "BBDC4.SA", "VALE3.SA", "PETR4.SA", "ABEV3.SA",
#     "BBAS3.SA"
# ]

TOP_BRL = [
    "VALE3.SA", "PETR4.SA", "ITUB4.SA", "BBDC4.SA",
    "BBAS3.SA", "RENT3.SA", "LREN3.SA", "PRIO3.SA",
    "WEGE3.SA", "ABEV3.SA"
]

# %%
print(len(TOP_BRL))

portfolio_raw_df = YahooDownloader(start_date = '2011-01-01',
                                end_date = '2019-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_raw_df
# Out:
# 10
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (22330, 8)
#              date       open       high        low      close    volume  \
# 0      2011-01-03   8.632311   8.728203   8.630313   5.265023    576145
# 1      2011-01-03  31.500000  31.799999  31.379999  13.514757   3313400
# 2      2011-01-03  11.809763  11.927362  11.724237   6.700338  10862336
# 3      2011-01-03  18.031555  18.250118  17.963253  10.109592  10014663
# 4      2011-01-03   8.422694   8.629907   8.422694   6.281180   3652542
# ...           ...        ...        ...        ...        ...       ...
# 22325  2019-12-30  30.549999  30.709999  30.150000  11.857764  22111600
# 22326  2019-12-30   6.780000   6.832000   6.570000   6.601397   8933500
# 22327  2019-12-30  47.735199  48.063652  47.078293  44.257679   2714322
# 22328  2019-12-30  53.650002  53.860001  53.200001  37.320976  11928100
# 22329  2019-12-30  17.700001  17.740000  17.330000  16.295254   5838200
#
#             tic  day
# 0      ABEV3.SA    0
# 1      BBAS3.SA    0
# 2      BBDC4.SA    0
# 3      ITUB4.SA    0
# 4      LREN3.SA    0
# ...         ...  ...
# 22325  PETR4.SA    0
# 22326  PRIO3.SA    0
# 22327  RENT3.SA    0
# 22328  VALE3.SA    0
# 22329  WEGE3.SA    0
#
# [22330 rows x 8 columns]

# %%
portfolio_raw_df.groupby("tic").count()
# Out:
#           date  open  high   low  close  volume   day
# tic
# ABEV3.SA  2233  2233  2233  2233   2233    2233  2233
# BBAS3.SA  2233  2233  2233  2233   2233    2233  2233
# BBDC4.SA  2233  2233  2233  2233   2233    2233  2233
# ITUB4.SA  2233  2233  2233  2233   2233    2233  2233
# LREN3.SA  2233  2233  2233  2233   2233    2233  2233
# PETR4.SA  2233  2233  2233  2233   2233    2233  2233
# PRIO3.SA  2233  2233  2233  2233   2233    2233  2233
# RENT3.SA  2233  2233  2233  2233   2233    2233  2233
# VALE3.SA  2233  2233  2233  2233   2233    2233  2233
# WEGE3.SA  2233  2233  2233  2233   2233    2233  2233

# %% [markdown]
# ## Portfolio Optimization Environment
#
# Since POE was not merged to FinRL yet, we add its code below.

# %%
"""From FinRL https://github.com/AI4Finance-LLC/FinRL/tree/master/finrl/env"""
import gym
import math
import matplotlib
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding

matplotlib.use("Agg")
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv
from pathlib import Path

try:
    import quantstats as qs
except ModuleNotFoundError:
    raise ModuleNotFoundError(
        """QuantStats module not found, environment can't plot results and calculate indicadors.
        This module is not installed with FinRL. Install by running one of the options:
        pip install quantstats --upgrade --no-cache-dir
        conda install -c ranaroussi quantstats
        """
        )

class PortfolioOptimizationEnv(gym.Env):
    """A portfolio allocantion environment for OpenAI gym.

    This environment simulates the interactions between an agent and the financial market
    based on data provided by a dataframe. The dataframe contains the time series of
    features defined by the user (such as closing, high and low prices) and must have
    a time and a tic column with a list of datetimes and ticker symbols respectively.
    An example of dataframe is shown below::

            date        high            low             close           tic
        0   2020-12-23  0.157414        0.127420        0.136394        ADA-USD
        1   2020-12-23  34.381519       30.074295       31.097898       BNB-USD
        2   2020-12-23  24024.490234    22802.646484    23241.345703    BTC-USD
        3   2020-12-23  0.004735        0.003640        0.003768        DOGE-USD
        4   2020-12-23  637.122803      560.364258      583.714600      ETH-USD
        ... ...         ...             ...             ...             ...

    Based on this dataframe, the environment will create an observation space that can
    be a Dict or a Box. The Box observation space is a three-dimensional array of shape
    (f, n, t), where f is the number of features, n is the number of stocks in the
    portfolio and t is the user-defined time window. If the environment is created with
    the parameter return_last_action set to True, the observation space is a Dict with
    the following keys::

        {
        "state": three-dimensional Box (f, n, t) representing the time series,
        "last_action": one-dimensional Box (n+1,) representing the portfolio weights
        }

    Note that the action space of this environment is an one-dimensional Box with size
    n + 1 because the portfolio weights must contains the weights related to all the
    stocks in the portfolio and to the remaining cash.

    Attributes:
        action_space: Action space.
        observation_space: Observation space.
        episode_length: Number of timesteps of an episode.
    """
    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        initial_amount,
        order_df=True,
        return_last_action=False,
        normalize_df="by_previous_time",
        reward_scaling=1,
        comission_fee_model="trf",
        comission_fee_pct=0,
        features=["close", "high", "low"],
        valuation_feature="close",
        time_column="date",
        time_format="%Y-%m-%d",
        tic_column="tic",
        time_window=1,
        cwd="./",
        new_gym_api=False
    ):
        """Initializes environment's instance.

        Args:
            df: Dataframe with market information over a period of time.
            initial_amount: Initial amount of cash available to be invested.
            order_df: If True input dataframe is ordered by time.
            return_last_action: If True, observations also return the last performed
                action. Note that, in that case, the observation space is a Dict.
            normalize_df: Defines the normalization method applied to input dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
            reward_scaling: A scaling factor to multiply the reward function. This
                factor can help training.
            comission_fee_model: Model used to simulate comission fee. Possible values
                are "trf" (for transaction remainder factor model) and "wvm" (for weights
                vector modifier model). If None, commission fees are not considered.
            comission_fee_pct: Percentage to be used in comission fee. It must be a value
                between 0 and 1.
            features: List of features to be considered in the observation space. The
                items of the list must be names of columns of the input dataframe.
            valuation_feature: Feature to be considered in the portfolio value calculation.
            time_column: Name of the dataframe's column that contain the datetimes that
                index the dataframe.
            time_format: Formatting string of time column.
            tic_name: Name of the dataframe's column that contain ticker symbols.
            time_window: Size of time window.
            cwd: Local repository in which resulting graphs will be saved.
            new_gym_api: If True, the environment will use the new gym api standard for
                step and reset methods.
        """
        # super(StockEnv, self).__init__()
        # money = 10 , scope = 1
        self._time_window = time_window
        self._time_index = time_window - 1
        self._time_column = time_column
        self._time_format = time_format
        self._tic_column = tic_column
        self._df = df
        self._initial_amount = initial_amount
        self._return_last_action = return_last_action
        self._reward_scaling = reward_scaling
        self._comission_fee_pct = comission_fee_pct
        self._comission_fee_model = comission_fee_model
        self._features = features
        self._valuation_feature = valuation_feature
        self._cwd = Path(cwd)
        self._new_gym_api = new_gym_api

        # results file
        self._results_file = self._cwd / "results" / "rl"
        self._results_file.mkdir(parents=True, exist_ok=True)

        # price variation
        self._df_price_variation = None

        # preprocess data
        self._preprocess_data(order_df, normalize_df)

        # dims and spaces
        self._tic_list = self._df[self._tic_column].unique()
        self._stock_dim = len(self._tic_list)
        action_space = 1 + self._stock_dim

        # sort datetimes and define episode length
        self._sorted_times = sorted(set(self._df[time_column]))
        self.episode_length = len(self._sorted_times) - time_window + 1

        # define action space
        self.action_space = spaces.Box(low=0, high=1, shape=(action_space,))

        # define observation state
        if self._return_last_action:
            # if  last action must be returned, a dict observation
            # is defined
            self.observation_space = spaces.Dict({
                "state": spaces.Box(
                    low=-np.inf,
                    high=np.inf,
                    shape=(
                        len(self._features),
                        self._stock_dim,
                        self._time_window
                    )
                ),
                "last_action": spaces.Box(
                    low=0, high=1, shape=(action_space,)
                )
            })
        else:
            # if information about last action is not relevant,
            # a 3D observation space is defined
            self.observation_space = spaces.Box(
                low=-np.inf,
                high=np.inf,
                shape=(
                    len(self._features),
                    self._stock_dim,
                    self._time_window
                ),
            )

        self._reset_memory()

        self._portfolio_value = self._initial_amount
        self._terminal = False

    def step(self, actions):
        """Performs a simulation step.

        Args:
            actions: An unidimensional array containing the new portfolio
                weights.

        Note:
            If the environment was created with "return_last_action" set to
            True, the next state returned will be a Dict. If it's set to False,
            the next state will be a Box. You can check the observation state
            through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, reward, terminal, truncated, info). If it's set to False,
            the following tuple is returned: (state, reward, terminal, info).

            state: Next simulation state.
            reward: Reward related to the last performed action.
            terminal: If True, the environment is in a terminal state.
            truncated: If True, the environment has passed it's simulation
                time limit. Currently, it's always False.
            info: A dictionary containing informations about the last state.
        """
        self._terminal = self._time_index >= len(self._sorted_times) - 1

        if self._terminal:
            metrics_df = pd.DataFrame(
                {"date": self._date_memory,
                 "returns": self._portfolio_return_memory,
                 "rewards": self._portfolio_reward_memory,
                 "portfolio_values": self._asset_memory["final"]}
            )
            metrics_df.set_index("date", inplace=True)

            plt.plot(metrics_df["portfolio_values"], "r")
            plt.title("Portfolio Value Over Time")
            plt.xlabel("Time")
            plt.ylabel("Portfolio value")
            plt.savefig(self._results_file / "portfolio_value.png")
            plt.close()

            plt.plot(self._portfolio_reward_memory, "r")
            plt.title("Reward Over Time")
            plt.xlabel("Time")
            plt.ylabel("Reward")
            plt.savefig(self._results_file / "reward.png")
            plt.close()

            plt.plot(self._actions_memory)
            plt.title("Actions performed")
            plt.xlabel("Time")
            plt.ylabel("Weight")
            plt.savefig(self._results_file / "actions.png")
            plt.close()

            print("=================================")
            print("Initial portfolio value:{}".format(self._asset_memory['final'][0]))
            print("Final portfolio value: {}".format(self._portfolio_value))
            print("Final accumulative portfolio value: {}".format(self._portfolio_value / self._asset_memory['final'][0]))
            print("Maximum DrawDown: {}".format(qs.stats.max_drawdown(metrics_df["portfolio_values"])))
            print("Sharpe ratio: {}".format(qs.stats.sharpe(metrics_df["returns"])))
            print("=================================")

            qs.plots.snapshot(metrics_df["returns"], show=False, savefig=self._results_file / "portfolio_summary.png")

            if self._new_gym_api:
                return self._state, self._reward, self._terminal, False, self._info
            return self._state, self._reward, self._terminal, self._info

        else:
            # transform action to numpy array (if it's a list)
            actions = np.array(actions, dtype=np.float32)

            # if necessary, normalize weights
            if math.isclose(np.sum(actions), 1, abs_tol=1e-6) and np.min(actions) >= 0:
                weights = actions
            else:
                weights = self._softmax_normalization(actions)

            # save initial portfolio weights for this time step
            self._actions_memory.append(weights)

            # get last step final weights and portfolio_value
            last_weights = self._final_weights[-1]

            # load next state
            self._time_index += 1
            self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)

            # if using weights vector modifier, we need to modify weights vector
            if self._comission_fee_model == "wvm":
                delta_weights = weights - last_weights
                delta_assets = delta_weights[1:] # disconsider
                # calculate fees considering weights modification
                fees = np.sum(np.abs(delta_assets * self._portfolio_value))
                if fees > weights[0] * self._portfolio_value:
                    weights = last_weights
                    # maybe add negative reward
                else:
                    portfolio = weights * self._portfolio_value
                    portfolio[0] -= fees
                    self._portfolio_value = np.sum(portfolio) # new portfolio value
                    weights = portfolio / self._portfolio_value # new weights
            elif self._comission_fee_model == "trf":
                last_mu = 1
                mu = 1 - 2 * self._comission_fee_pct + self._comission_fee_pct ** 2
                while abs(mu - last_mu) > 1e-10:
                    last_mu = mu
                    mu = (1 - self._comission_fee_pct * weights[0] -
                          (2 * self._comission_fee_pct - self._comission_fee_pct ** 2) *
                          np.sum(np.maximum(last_weights[1:] - mu * weights[1:], 0))) / (1 - self._comission_fee_pct * weights[0])
                self._info["trf_mu"] = mu
                self._portfolio_value = mu * self._portfolio_value

            # save initial portfolio value of this time step
            self._asset_memory["initial"].append(self._portfolio_value)

            # time passes and time variation changes the portfolio distribution
            portfolio = self._portfolio_value * (weights * self._price_variation)

            # calculate new portfolio value and weights
            self._portfolio_value = np.sum(portfolio)
            weights = portfolio / self._portfolio_value

            # save final portfolio value and weights of this time step
            self._asset_memory["final"].append(self._portfolio_value)
            self._final_weights.append(weights)

            # save date memory
            self._date_memory.append(self._info["end_time"])

            # define portfolio return
            rate_of_return = self._asset_memory["final"][-1] / self._asset_memory["final"][-2]
            portfolio_return = rate_of_return - 1
            portfolio_reward = np.log(rate_of_return)

            # save portfolio return memory
            self._portfolio_return_memory.append(portfolio_return)
            self._portfolio_reward_memory.append(portfolio_reward)

            # Define portfolio return
            self._reward = portfolio_reward
            self._reward = self._reward * self._reward_scaling

        if self._new_gym_api:
            return self._state, self._reward, self._terminal, False, self._info
        return self._state, self._reward, self._terminal, self._info

    def reset(self):
        """Resets the environment and returns it to its initial state (the
        fist date of the dataframe).

        Note:
            If the environment was created with "return_last_action" set to
            True, the initial state will be a Dict. If it's set to False,
            the initial state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, info). If it's set to False, only the initial state is
            returned.

            state: Initial state.
            info: Initial state info.
        """
        # time_index must start a little bit in the future to implement lookback
        self._time_index = self._time_window - 1
        self._reset_memory()

        self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)
        self._portfolio_value = self._initial_amount
        self._terminal = False

        if self._new_gym_api:
            return self._state, self._info
        return self._state

    def _get_state_and_info_from_time_index(self, time_index):
        """Gets state and information given a time index. It also updates "data"
        attribute with information about the current simulation step.

        Args:
            time_index: An integer that represents the index of a specific datetime.
                The initial datetime of the dataframe is given by 0.

        Note:
            If the environment was created with "return_last_action" set to
            True, the returned state will be a Dict. If it's set to False,
            the returned state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            A tuple with the following form: (state, info).

            state: The state of the current time index. It can be a Box or a Dict.
            info: A dictionary with some informations about the current simulation
                step. The dict has the following keys::

                {
                "tics": List of ticker symbols,
                "start_time": Start time of current time window,
                "start_time_index": Index of start time of current time window,
                "end_time": End time of current time window,
                "end_time_index": Index of end time of current time window,
                "data": Data related to the current time window,
                "price_variation": Price variation of current time step
                }
        """
        # returns state in form (channels, tics, timesteps)
        end_time = self._sorted_times[time_index]
        start_time = self._sorted_times[time_index - (self._time_window - 1)]

        # define data to be used in this time step
        self._data = self._df[
            (self._df[self._time_column] >= start_time) &
            (self._df[self._time_column] <= end_time)
        ][[self._time_column, self._tic_column] + self._features]

        # define price variation of this time_step
        self._price_variation = self._df_price_variation[
                self._df_price_variation[self._time_column] == end_time
            ][self._valuation_feature].to_numpy()
        self._price_variation = np.insert(self._price_variation, 0, 1)

        # define state to be returned
        state = None
        for tic in self._tic_list:
            tic_data = self._data[self._data[self._tic_column] == tic]
            tic_data = tic_data[self._features].to_numpy().T
            tic_data = tic_data[..., np.newaxis]
            state = tic_data if state is None else np.append(state, tic_data, axis=2)
        state = state.transpose((0, 2, 1))
        info = {
            "tics": self._tic_list,
            "start_time": start_time,
            "start_time_index": time_index - (self._time_window - 1),
            "end_time": end_time,
            "end_time_index": time_index,
            "data": self._data,
            "price_variation": self._price_variation
        }
        return self._standardize_state(state), info

    def render(self, mode="human"):
        """Renders the environment.

        Returns:
            Observation of current simulation step.
        """
        return self._state

    def _softmax_normalization(self, actions):
        """Normalizes the action vector using softmax function.

        Returns:
            Normalized action vector (portfolio vector).
        """
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator / denominator
        return softmax_output

    def enumerate_portfolio(self):
        """Enumerates the current porfolio by showing the ticker symbols
        of all the investments considered in the portfolio.
        """
        print("Index: 0. Tic: Cash")
        for index, tic in enumerate(self._tic_list):
            print("Index: {}. Tic: {}".format(index + 1, tic))

    def _preprocess_data(self, order, normalize):
        """Orders and normalizes the environment's dataframe.

        Args:
            order: If true, the dataframe will be ordered by ticker list
                and datetime.
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
        """
        # order time dataframe by tic and time
        if order:
            self._df = self._df.sort_values(by=[self._tic_column, self._time_column])
        # defining price variation after ordering dataframe
        self._df_price_variation = self._temporal_variation_df()
        # apply normalization
        if normalize:
            self._normalize_dataframe(normalize)
        # transform str to datetime
        self._df[self._time_column] = pd.to_datetime(self._df[self._time_column])
        self._df_price_variation[self._time_column] = pd.to_datetime(self._df_price_variation[self._time_column])
        # transform numeric variables to float32 (compatibility with pytorch)
        self._df[self._features] = self._df[self._features].astype("float32")
        self._df_price_variation[self._features] = self._df_price_variation[self._features].astype("float32")

    def _reset_memory(self):
        """Resets the environment's memory."""
        date_time = self._sorted_times[self._time_index]
        # memorize portfolio value each step
        self._asset_memory = {
            "initial" : [self._initial_amount],
            "final" : [self._initial_amount]
        }
        # memorize portfolio return and reward each step
        self._portfolio_return_memory = [0]
        self._portfolio_reward_memory = [0]
        # initial action: all money is allocated in cash
        self._actions_memory = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize portfolio weights at the ending of time step
        self._final_weights = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize datetimes
        self._date_memory = [date_time]

    def _standardize_state(self, state):
        """Standardize the state given the observation space. If "return_last_action"
        is set to False, a three-dimensional box is returned. If it's set to True, a
        dictionary is returned. The dictionary follows the standard below::

            {
            "state": Three-dimensional box representing the current state,
            "last_action": One-dimensional box representing the last action
            }
        """
        last_action = self._actions_memory[-1]
        if self._return_last_action:
            return { "state": state, "last_action": last_action }
        else:
            return state

    def _normalize_dataframe(self, normalize):
        """"Normalizes the environment's dataframe.

        Args:
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.

        Note:
            If a custom function is used in the normalization, it must have an
            argument representing the environment's dataframe.
        """
        if type(normalize) == str:
            if normalize == "by_fist_time_window_value":
                print("Normalizing {} by first time window value...".format(self._features))
                self._df = self._temporal_variation_df(self._time_window - 1)
            elif normalize == "by_previous_time":
                print("Normalizing {} by previous time...".format(self._features))
                self._df = self._temporal_variation_df()
            elif normalize.startswith("by_"):
                normalizer_column = normalize[3:]
                print("Normalizing {} by {}".format(self._features, normalizer_column))
                for column in self._features:
                    self._df[column] = self._df[column] / self._df[normalizer_column]
        elif callable(normalize):
            print("Applying custom normalization function...")
            self._df = normalize(self._df)
        else:
            print("No normalization was performed.")


    def _temporal_variation_df(self, periods=1):
        """Calculates the temporal variation dataframe. For each feature, this
        dataframe contains the rate of the current feature's value and the last
        feature's value given a period. It's used to normalize the dataframe.

        Args:
            periods: Periods (in time indexes) to calculate temporal variation.

        Returns:
            Temporal variation dataframe.
        """
        df_temporal_variation = self._df.copy()
        prev_columns = []
        for column in self._features:
            prev_column = "prev_{}".format(column)
            prev_columns.append(prev_column)
            df_temporal_variation[prev_column] = df_temporal_variation.groupby(self._tic_column)[column].shift(periods=periods)
            df_temporal_variation[column] = df_temporal_variation[column] / df_temporal_variation[prev_column]
        df_temporal_variation = df_temporal_variation.drop(columns=prev_columns).fillna(1).reset_index(drop=True)
        return df_temporal_variation

    def _seed(self, seed=None):
        """Seeds the sources of randomness of this environment to guarantee
        reproducibility.

        Args:
            seed: Seed value to be applied.

        Returns:
            Seed value applied.
        """
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self, env_number=1):
        """Generates an environment compatible with Stable Baselines 3. The
        generated environment is a vectorized version of the current one.

        Returns:
            A tuple with the generated environment and an initial observation.
        """
        e = DummyVecEnv([lambda: self] * env_number)
        obs = e.reset()
        return e, obs

# %% [markdown]
# ## Define Architecture

# %%
# Define constants
PORTFOLIO_SIZE = len(TOP_BRL)

# %% [markdown]
# #### Create the gradient policy
#
# The gradient policy below is identical to the EIIE architecture from *Jiang et al* paper.

# %%
class GradientPolicy(nn.Module):
    def __init__(self):
        """DDPG policy network initializer."""
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=2, kernel_size=(1, 3)),
            nn.ReLU(),
            nn.Conv2d(in_channels=2, out_channels=20, kernel_size=(1, 48)),
            nn.ReLU()
        )

        self.final_convolution = nn.Conv2d(in_channels=21, out_channels=1, kernel_size=(1, 1))

        self.softmax = nn.Sequential(
            nn.Softmax(dim=-1)
        )

    def mu(self, observation, last_action):
        """Defines a most favorable action of this policy given input x.

        Args:
          observation: environment observation .
          last_action: Last action performed by agent.

        Returns:
          Most favorable action.
        """

        if isinstance(observation, np.ndarray):
            observation = torch.from_numpy(observation).to(device)
        if isinstance(last_action, np.ndarray):
            last_action = torch.from_numpy(last_action).to(device)

        last_stocks, cash_bias = self._process_last_action(last_action)

        output = self.sequential(observation) # shape [N, PORTFOLIO_SIZE + 1, 19, 1]
        output = torch.cat([output, last_stocks], dim=1) # shape [N, 21, PORTFOLIO_SIZE, 1]
        output = self.final_convolution(output) # shape [N, 1, PORTFOLIO_SIZE, 1]
        output = torch.cat([output, cash_bias], dim=2) # shape [N, 1, PORTFOLIO_SIZE + 1, 1]

        # output shape must be [N, features] = [1, PORTFOLIO_SIZE + 1], being N batch size (1)
        # and size the number of features (weights vector).
        output = torch.squeeze(output, 3)
        output = torch.squeeze(output, 1) # shape [N, PORTFOLIO_SIZE + 1]

        output = self.softmax(output)

        return output

    def forward(self, observation, last_action):
        """Policy network's forward propagation.

        Args:
          observation: environment observation (dictionary).
          epsilon: exploration noise to be applied.

        Returns:
          Action to be taken (numpy array).
        """
        mu = self.mu(observation, last_action)
        action = mu.cpu().detach().numpy().squeeze()
        return action

    def _process_last_action(self, last_action):
        batch_size = last_action.shape[0]
        stocks = last_action.shape[1] - 1
        last_stocks = last_action[:, 1:].reshape((batch_size, 1, stocks, 1))
        cash_bias = last_action[:, 0].reshape((batch_size, 1, 1, 1))
        return last_stocks, cash_bias

# %% [markdown]
# #### Portfolio Vector Memory
#
# The portfolio vector memory is an object that saves all the portfolio vectors generated by the policy. It's useful because the algorithm can get the last action performed, an information necessary to do forward propagation. Read *Jiang et al* article for more information.

# %%
class PVM:
    def __init__(self, capacity):
        """Initializes portfolio vector memory.

        Args:
          capacity: Max capacity of memory.
        """
        # initially, memory will have the same actions
        self.capacity = capacity
        self.reset()

    def reset(self):
        self.memory = [np.array([1] + [0] * PORTFOLIO_SIZE, dtype=np.float32)] * (self.capacity + 1)
        self.index = 0 # initial index to retrieve data

    def retrieve(self):
        last_action = self.memory[self.index]
        self.index = 0 if self.index == self.capacity else self.index + 1
        return last_action

    def add(self, action):
        self.memory[self.index] = action

# %% [markdown]
# #### ReplayBuffer and RLDataset
#
# The replay buffer implemented in this work is slightly different from the one in famous algorithms. Usually, experiences are constantly added to the replay buffer and when it's completely filled, older experiences are overwritten by new ones (deque behavior). A reinforcement learning algorithm can constantly sample experiences from the buffer to update their neural networks and, as the time passes, older experiences will be disconsidered due to the deque behavior.
#
# In this replay buffer, however, the deque behavior is still present, but when an algorithm sample a batch of experiences, all the experiences in the replay buffer are returned and it is cleared. This behavior is necessary given the policy gradient algorithm introduced by *Jiang et al*.

# %%
class ReplayBuffer:
  def __init__(self, capacity):
    """Initializes replay buffer.

    Args:
      capacity: Max capacity of buffer.
    """
    self.buffer = deque(maxlen=capacity)

  def __len__(self):
    """Represents the size of the buffer

    Returns:
      Size of the buffer.
    """
    return len(self.buffer)

  def append(self, experience):
    """Append experience to buffer. When buffer is full, it pops
       an old experience.

    Args:
      experience: experience to be saved.
    """
    self.buffer.append(experience)

  def sample(self):
    """Sample from replay buffer. All data from replay buffer is
    returned and the buffer is cleared.

    Returns:
      Sample of batch_size size.
    """
    buffer = list(self.buffer)
    self.buffer.clear()
    return buffer

# %%
class RLDataset(IterableDataset):
  def __init__(self, buffer):
    """Initializes reinforcement learning dataset.

    Args:
        buffer: replay buffer to become iterable dataset.

    Note:
        It's a subclass of pytorch's IterableDataset,
        check https://pytorch.org/docs/stable/data.html#torch.utils.data.IterableDataset
    """
    self.buffer = buffer

  def __iter__(self):
    """Iterates over RLDataset.

    Returns:
      Every experience of a sample from replay buffer.
    """
    for experience in self.buffer.sample():
        yield experience

# %% [markdown]
# #### Create Polyak average function
#
# The Polyak average function allows us to have a target function that is incrementally updated. It's useful to avoid oscillations in the final policy performance.

# %%
def polyak_average(net, target_net, tau=0.01):
  """Applies polyak average to incrementally update target net.

  Args:
    net: trained neural network.
    target_net: target neural network.
    tau: update rate.
  """
  for qp, tp in zip(net.parameters(), target_net.parameters()):
    tp.data.copy_(tau * qp.data + (1 - tau) * tp.data)

# %% [markdown]
# ### Create PG class
#
# This class implements the Policy Gradient algorithm used in *Jiang et al* paper. This algorithm is inspired by DDPG (deep deterministic policy gradient), but there are a couple of differences:
# - DDPG is an actor-critic algorithm, so it has an actor and a critic neural network. The algorithm below, however, doesn't have a critic neural network and uses the portfolio value as value function: the policy will be updated to maximize the portfolio value.
# - DDPG usually makes use of a noise parameter in the action during training to create an exploratory behavior. PG algorithm, on the other hand, has a full-exploit approach.
# - DDPG randomly samples experiences from its replay buffer. The implemented policy gradient, however, samples a sequential batch of experiences in time, to make it possible to calculate the variation of the portfolio value in the batch and use it as value function.
#
# The algorithm can be described as follows:
# 1. Initializes policy network, target policy network (if used) and replay buffer;
# 2. For each episode, do the following:
#     1. For each period of `batch_size` timesteps, do the following:
#         1. For each timestep, define an action to be performed, simulate the timestep and save the experiences in the replay buffer.
#         2. After `batch_size` timesteps are simulated, sample the replay buffer.
#         3. Update target policy network (if used).
#         4. Calculate the value function: $V = \sum\limits_{t=1}^{batch\_size} ln(\mu_{t}(W_{t} \cdot P_{t}))$, where $W_{t}$ is the action performed at timestep t, $P_{t}$ is the price variation vector at timestep t and $\mu_{t}$ is the transaction remainder factor at timestep t. Check *Jiang et al* paper for more details.
#         5. Perform gradient ascent in the policy network.
#     2. If, in the and of episode, there is sequence of remaining experiences in the replay buffer, perform steps "a" to "e" with the remaining experiences.

# %%
class PG:
    def __init__(self,
                 env,
                 batch_size=100,
                 lr=1e-3,
                 optimizer=AdamW,
                 tau=0.05):
        """Initializes Policy Gradient for portfolio optimization.

          Args:
            env: environment.
            batch_size: batch size to train neural network.
            lr: policy neural network learning rate.
            optim: Optimizer of neural network.
            tau: update rate in Polyak averaging.
        """
        # environment
        self.env = env

        # neural networks
        self.policy = GradientPolicy().to(device)
        self.target_policy = copy.deepcopy(self.policy)
        self.optimizer = optimizer(self.policy.parameters(), lr=lr)
        self.tau = tau

        # replay buffer and portfolio vector memory
        self.batch_size = batch_size
        self.buffer = ReplayBuffer(capacity=batch_size)
        self.pvm = PVM(self.env.episode_length)

        # dataset and dataloader
        dataset = RLDataset(self.buffer)
        self.dataloader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            pin_memory=True)

    def train(self, episodes=100):
        """Training sequence

        Args:
            episodes: Number of episodes to simulate
        """
        for i in tqdm(range(1, episodes + 1)):
            obs = self.env.reset() # observation
            self.pvm.reset() # reset portfolio vector memory
            done = False

            while not done:
                # define last_action and action and update portfolio vector memory
                last_action = self.pvm.retrieve()
                obs_batch = np.expand_dims(obs, axis=0)
                last_action_batch = np.expand_dims(last_action, axis=0)
                action = self.policy(obs_batch, last_action_batch)
                self.pvm.add(action)

                # run simulation step
                next_obs, reward, done, info = self.env.step(action)

                # add experience to replay buffer
                exp = (obs, last_action, info["price_variation"], info["trf_mu"])
                self.buffer.append(exp)

                # update policy networks
                if len(self.buffer) == self.batch_size:
                    self._gradient_ascent()

                obs = next_obs

            # gradient ascent with episode remaining buffer data
            self._gradient_ascent()



    def _gradient_ascent(self):
        # update target neural network
        polyak_average(self.policy, self.target_policy, tau=self.tau)

        # get batch data from dataloader
        obs, last_actions, price_variations, trf_mu = next(iter(self.dataloader))
        obs = obs.to(device)
        last_actions = last_actions.to(device)
        price_variations = price_variations.to(device)
        trf_mu = trf_mu.unsqueeze(1).to(device)

        # define policy loss (negative for gradient ascent)
        mu = self.policy.mu(obs, last_actions)
        policy_loss = - torch.mean(torch.log(torch.sum(mu * price_variations * trf_mu, dim=1)))

        # update policy network
        self.policy.zero_grad()
        policy_loss.backward()
        self.optimizer.step()

# %% [markdown]
# ### Train Algorithm

# %%
df_portfolio = portfolio_raw_df[["date", "tic", "close", "high", "low"]]

environment = PortfolioOptimizationEnv(
        df_portfolio,
        initial_amount=100000,
        comission_fee_pct=0.0025,
        time_window=50,
        features=["close", "high", "low"]
    )

algo = PG(environment, lr=0.0001)

algo.train(episodes=5)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
#   0%|          | 0/250 [00:00<?, ?it/s]
# =================================
# Initial portfolio value:100000
# Final portfolio value: 371342.96875
# Final accumulative portfolio value: 3.7134296875
# Maximum DrawDown: -0.43360983780675255
# Sharpe ratio: 0.8046687938318555
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 372560.5
# Final accumulative portfolio value: 3.725605
# Maximum DrawDown: -0.4325133264337707
# Sharpe ratio: 0.8071284741064052
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 373408.03125
# Final accumulative portfolio value: 3.7340803125
# Maximum DrawDown: -0.431543882162985
# Sharpe ratio: 0.8089685693888692
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 374255.53125
# Final accumulative portfolio value: 3.7425553125
# Maximum DrawDown: -0.43054424855893003
# Sharpe ratio: 0.810822570852662
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 375141.34375
# Final accumulative portfolio value: 3.7514134375
# Maximum DrawDown: -0.429487865361898
# Sharpe ratio: 0.8127645892645922
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 376087.28125
# Final accumulative portfolio value: 3.7608728125
# Maximum DrawDown: -0.42836068268431426
# Sharpe ratio: 0.8148312760951242
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 377089.65625
# Final accumulative portfolio value: 3.7708965625
# Maximum DrawDown: -0.4271553270151882
# Sharpe ratio: 0.81701826150199
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 378193.90625
# Final accumulative portfolio value: 3.7819390625
# Maximum DrawDown: -0.425860852741641
# Sharpe ratio: 0.8193813543353493
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 379302.03125
# Final accumulative portfolio value: 3.7930203125
# Maximum DrawDown: -0.4245306151199456
# Sharpe ratio: 0.8217526445985541
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 380322.6875
# Final accumulative portfolio value: 3.803226875
# Maximum DrawDown: -0.42329915910494564
# Sharpe ratio: 0.8239619442364012
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 381431.125
# Final accumulative portfolio value: 3.81431125
# Maximum DrawDown: -0.42198364250596576
# Sharpe ratio: 0.8263451964076591
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 382609.0625
# Final accumulative portfolio value: 3.826090625
# Maximum DrawDown: -0.4205818989653496
# Sharpe ratio: 0.8288667836171862
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 383859.6875
# Final accumulative portfolio value: 3.838596875
# Maximum DrawDown: -0.41908564816272154
# Sharpe ratio: 0.831538970097022
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 385192.625
# Final accumulative portfolio value: 3.85192625
# Maximum DrawDown: -0.4174914987575228
# Sharpe ratio: 0.8343754484574871
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 386615.0
# Final accumulative portfolio value: 3.86615
# Maximum DrawDown: -0.415785853377279
# Sharpe ratio: 0.8373884923186198
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 388133.75
# Final accumulative portfolio value: 3.8813375
# Maximum DrawDown: -0.41396509476233956
# Sharpe ratio: 0.8405879260753713
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 389749.3125
# Final accumulative portfolio value: 3.897493125
# Maximum DrawDown: -0.4120195550738345
# Sharpe ratio: 0.8439794326589167
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 391478.1875
# Final accumulative portfolio value: 3.914781875
# Maximum DrawDown: -0.40993995951734974
# Sharpe ratio: 0.8475833048704123
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 393321.46875
# Final accumulative portfolio value: 3.9332146875
# Maximum DrawDown: -0.4077172486532329
# Sharpe ratio: 0.8514040908029561
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 395292.125
# Final accumulative portfolio value: 3.95292125
# Maximum DrawDown: -0.4053419881752143
# Sharpe ratio: 0.8554563226149408
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 397392.40625
# Final accumulative portfolio value: 3.9739240625
# Maximum DrawDown: -0.40280205967040594
# Sharpe ratio: 0.8597461521033178
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 399634.125
# Final accumulative portfolio value: 3.99634125
# Maximum DrawDown: -0.4000878497259843
# Sharpe ratio: 0.8642861921383934
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 402026.40625
# Final accumulative portfolio value: 4.0202640625
# Maximum DrawDown: -0.3971884016716912
# Sharpe ratio: 0.8690847344983328
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 404582.96875
# Final accumulative portfolio value: 4.0458296875
# Maximum DrawDown: -0.39409114510407917
# Sharpe ratio: 0.8741531664059955
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 407317.25
# Final accumulative portfolio value: 4.0731725
# Maximum DrawDown: -0.3908294930262265
# Sharpe ratio: 0.8794857206730634
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 410036.34375
# Final accumulative portfolio value: 4.1003634375
# Maximum DrawDown: -0.3876042775873244
# Sharpe ratio: 0.8847205848225135
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 412860.625
# Final accumulative portfolio value: 4.12860625
# Maximum DrawDown: -0.384177303389576
# Sharpe ratio: 0.8901052523040506
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 415831.1875
# Final accumulative portfolio value: 4.158311875
# Maximum DrawDown: -0.38055528019942064
# Sharpe ratio: 0.895704232636886
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 418980.96875
# Final accumulative portfolio value: 4.1898096875
# Maximum DrawDown: -0.37670719333535074
# Sharpe ratio: 0.901541921992268
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 422308.59375
# Final accumulative portfolio value: 4.2230859375
# Maximum DrawDown: -0.3726330603889457
# Sharpe ratio: 0.907602024746003
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 425827.25
# Final accumulative portfolio value: 4.2582725
# Maximum DrawDown: -0.36832284221735534
# Sharpe ratio: 0.9138814600601477
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 429527.28125
# Final accumulative portfolio value: 4.2952728125
# Maximum DrawDown: -0.3637950456821575
# Sharpe ratio: 0.92034970309523
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 433425.375
# Final accumulative portfolio value: 4.33425375
# Maximum DrawDown: -0.35908708055466787
# Sharpe ratio: 0.9270011204630758
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 437509.1875
# Final accumulative portfolio value: 4.375091875
# Maximum DrawDown: -0.35448026157945334
# Sharpe ratio: 0.9337927698416043
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 441800.6875
# Final accumulative portfolio value: 4.418006875
# Maximum DrawDown: -0.3513716199284689
# Sharpe ratio: 0.9407184672559912
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 446243.3125
# Final accumulative portfolio value: 4.462433125
# Maximum DrawDown: -0.34816690256202876
# Sharpe ratio: 0.947664973590607
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 450943.71875
# Final accumulative portfolio value: 4.5094371875
# Maximum DrawDown: -0.3447457101866416
# Sharpe ratio: 0.9547614781073109
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 455799.375
# Final accumulative portfolio value: 4.55799375
# Maximum DrawDown: -0.3412337475539907
# Sharpe ratio: 0.9618078343687622
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 460833.875
# Final accumulative portfolio value: 4.60833875
# Maximum DrawDown: -0.3385600143590636
# Sharpe ratio: 0.9688071482419085
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 466032.53125
# Final accumulative portfolio value: 4.6603253125
# Maximum DrawDown: -0.3366924623134967
# Sharpe ratio: 0.9757005588194787
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 471385.75
# Final accumulative portfolio value: 4.7138575
# Maximum DrawDown: -0.33477987033634593
# Sharpe ratio: 0.9824420398405379
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 476882.75
# Final accumulative portfolio value: 4.7688275
# Maximum DrawDown: -0.3328290933690946
# Sharpe ratio: 0.988982964873414
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 482501.28125
# Final accumulative portfolio value: 4.8250128125
# Maximum DrawDown: -0.33084739924745066
# Sharpe ratio: 0.9952668681647656
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 488220.8125
# Final accumulative portfolio value: 4.882208125
# Maximum DrawDown: -0.32884098283814145
# Sharpe ratio: 1.0012452459224765
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 494025.125
# Final accumulative portfolio value: 4.94025125
# Maximum DrawDown: -0.3268176341645882
# Sharpe ratio: 1.0068834425667477
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 499899.28125
# Final accumulative portfolio value: 4.9989928125
# Maximum DrawDown: -0.3247824377196641
# Sharpe ratio: 1.0121464345151345
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 505812.25
# Final accumulative portfolio value: 5.0581225
# Maximum DrawDown: -0.32274661611172095
# Sharpe ratio: 1.01700039675
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 511753.0
# Final accumulative portfolio value: 5.11753
# Maximum DrawDown: -0.32090089484398165
# Sharpe ratio: 1.0214379310263406
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 517684.625
# Final accumulative portfolio value: 5.17684625
# Maximum DrawDown: -0.3198689532603367
# Sharpe ratio: 1.0254245460985105
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 523593.9375
# Final accumulative portfolio value: 5.235939375
# Maximum DrawDown: -0.3188517272246907
# Sharpe ratio: 1.0289698971761316
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 529469.125
# Final accumulative portfolio value: 5.29469125
# Maximum DrawDown: -0.3178543608197346
# Sharpe ratio: 1.0320834266036152
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 535282.375
# Final accumulative portfolio value: 5.35282375
# Maximum DrawDown: -0.3168751256875524
# Sharpe ratio: 1.0347653290913332
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 541015.25
# Final accumulative portfolio value: 5.4101525
# Maximum DrawDown: -0.31598030683230294
# Sharpe ratio: 1.0370346296824398
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 546662.25
# Final accumulative portfolio value: 5.4666225
# Maximum DrawDown: -0.31531128877089043
# Sharpe ratio: 1.038912939308874
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 552196.8125
# Final accumulative portfolio value: 5.521968125
# Maximum DrawDown: -0.31466502694945153
# Sharpe ratio: 1.0404190680238499
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 557617.75
# Final accumulative portfolio value: 5.5761775
# Maximum DrawDown: -0.31539960239955245
# Sharpe ratio: 1.0415876634594339
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 562905.9375
# Final accumulative portfolio value: 5.629059375
# Maximum DrawDown: -0.31627036718909673
# Sharpe ratio: 1.042435812738729
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 568058.5
# Final accumulative portfolio value: 5.680585
# Maximum DrawDown: -0.31712524679570886
# Sharpe ratio: 1.043003143739625
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 573072.25
# Final accumulative portfolio value: 5.7307225
# Maximum DrawDown: -0.31796138014028974
# Sharpe ratio: 1.0433155685857403
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 577935.5
# Final accumulative portfolio value: 5.779355
# Maximum DrawDown: -0.31877928125641664
# Sharpe ratio: 1.0433995687785194
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 582651.75
# Final accumulative portfolio value: 5.8265175
# Maximum DrawDown: -0.3195752173223114
# Sharpe ratio: 1.0432837518739828
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 587213.0
# Final accumulative portfolio value: 5.87213
# Maximum DrawDown: -0.3203513177399573
# Sharpe ratio: 1.0429904623240147
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 591620.5625
# Final accumulative portfolio value: 5.916205625
# Maximum DrawDown: -0.32110532756648935
# Sharpe ratio: 1.0425425669451582
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 595880.8125
# Final accumulative portfolio value: 5.958808125
# Maximum DrawDown: -0.32183865953732627
# Sharpe ratio: 1.0419717842122438
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 599986.0
# Final accumulative portfolio value: 5.99986
# Maximum DrawDown: -0.32254855515210457
# Sharpe ratio: 1.0412847760493495
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 603938.9375
# Final accumulative portfolio value: 6.039389375
# Maximum DrawDown: -0.3232388515596929
# Sharpe ratio: 1.0405027256477577
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 607746.5
# Final accumulative portfolio value: 6.077465
# Maximum DrawDown: -0.32390735045738717
# Sharpe ratio: 1.0396470102734703
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 611420.1875
# Final accumulative portfolio value: 6.114201875
# Maximum DrawDown: -0.3245514004052076
# Sharpe ratio: 1.038736322084645
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 614949.3125
# Final accumulative portfolio value: 6.149493125
# Maximum DrawDown: -0.3251770029499723
# Sharpe ratio: 1.0377697743829597
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 618339.375
# Final accumulative portfolio value: 6.18339375
# Maximum DrawDown: -0.32578127280393787
# Sharpe ratio: 1.0367627194800992
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 621601.25
# Final accumulative portfolio value: 6.2160125
# Maximum DrawDown: -0.3263637682643785
# Sharpe ratio: 1.035727069434034
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 624736.0
# Final accumulative portfolio value: 6.24736
# Maximum DrawDown: -0.3269308655437516
# Sharpe ratio: 1.0346715985521278
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 627750.875
# Final accumulative portfolio value: 6.27750875
# Maximum DrawDown: -0.32747369954398553
# Sharpe ratio: 1.0336029962729965
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 630645.9375
# Final accumulative portfolio value: 6.306459375
# Maximum DrawDown: -0.32800002177676635
# Sharpe ratio: 1.0325267716568682
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 633436.625
# Final accumulative portfolio value: 6.33436625
# Maximum DrawDown: -0.32850777749873117
# Sharpe ratio: 1.031455818579327
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 636105.75
# Final accumulative portfolio value: 6.3610575
# Maximum DrawDown: -0.3289971295933699
# Sharpe ratio: 1.0303762229801698
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 638675.25
# Final accumulative portfolio value: 6.3867525
# Maximum DrawDown: -0.32947131371035177
# Sharpe ratio: 1.0293070512938725
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 641151.625
# Final accumulative portfolio value: 6.41151625
# Maximum DrawDown: -0.32992769982235126
# Sharpe ratio: 1.028251450623296
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 643518.9375
# Final accumulative portfolio value: 6.435189375
# Maximum DrawDown: -0.33037023954525935
# Sharpe ratio: 1.0271985531338887
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 645808.125
# Final accumulative portfolio value: 6.45808125
# Maximum DrawDown: -0.330795769234967
# Sharpe ratio: 1.026170801134291
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 648007.25
# Final accumulative portfolio value: 6.4800725
# Maximum DrawDown: -0.33120616396363667
# Sharpe ratio: 1.0251553190647185
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 650117.0
# Final accumulative portfolio value: 6.50117
# Maximum DrawDown: -0.33160406542389387
# Sharpe ratio: 1.024153935810065
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 652152.0
# Final accumulative portfolio value: 6.52152
# Maximum DrawDown: -0.33198977512878924
# Sharpe ratio: 1.02317683315744
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 654105.125
# Final accumulative portfolio value: 6.54105125
# Maximum DrawDown: -0.33235807419189034
# Sharpe ratio: 1.02221198477474
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 655988.8125
# Final accumulative portfolio value: 6.559888125
# Maximum DrawDown: -0.3327171812172919
# Sharpe ratio: 1.0212721132487055
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 657803.0
# Final accumulative portfolio value: 6.57803
# Maximum DrawDown: -0.333061260197441
# Sharpe ratio: 1.0203524753430206
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 659550.9375
# Final accumulative portfolio value: 6.595509375
# Maximum DrawDown: -0.33339651063448517
# Sharpe ratio: 1.0194528021321783
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 661239.0
# Final accumulative portfolio value: 6.61239
# Maximum DrawDown: -0.33371969478657926
# Sharpe ratio: 1.0185766149058464
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 662855.3125
# Final accumulative portfolio value: 6.628553125
# Maximum DrawDown: -0.3340315982411194
# Sharpe ratio: 1.0177138793987022
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 664422.625
# Final accumulative portfolio value: 6.64422625
# Maximum DrawDown: -0.33433413864666806
# Sharpe ratio: 1.0168785326851497
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 665928.9375
# Final accumulative portfolio value: 6.659289375
# Maximum DrawDown: -0.3346278753012196
# Sharpe ratio: 1.016059347107201
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 667389.3125
# Final accumulative portfolio value: 6.673893125
# Maximum DrawDown: -0.33490901521702765
# Sharpe ratio: 1.0152658141992634
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 668787.25
# Final accumulative portfolio value: 6.6878725
# Maximum DrawDown: -0.3351830251108032
# Sharpe ratio: 1.014485520213379
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 670149.5
# Final accumulative portfolio value: 6.701495
# Maximum DrawDown: -0.33544905782066803
# Sharpe ratio: 1.0137321176897025
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 671456.875
# Final accumulative portfolio value: 6.71456875
# Maximum DrawDown: -0.33570513459952855
# Sharpe ratio: 1.012993741004442
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 672724.6875
# Final accumulative portfolio value: 6.727246875
# Maximum DrawDown: -0.3359539418645331
# Sharpe ratio: 1.0122776758753593
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 673947.125
# Final accumulative portfolio value: 6.73947125
# Maximum DrawDown: -0.3361954334401468
# Sharpe ratio: 1.0115760718080806
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 675128.3125
# Final accumulative portfolio value: 6.751283125
# Maximum DrawDown: -0.33643055973035785
# Sharpe ratio: 1.0108943478940648
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 676272.0625
# Final accumulative portfolio value: 6.762720625
# Maximum DrawDown: -0.3366574310861936
# Sharpe ratio: 1.0102310314381957
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 677376.125
# Final accumulative portfolio value: 6.77376125
# Maximum DrawDown: -0.33687595068068
# Sharpe ratio: 1.0095824177926276
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 678448.0
# Final accumulative portfolio value: 6.78448
# Maximum DrawDown: -0.33708934131013113
# Sharpe ratio: 1.0089558961649538
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 679479.9375
# Final accumulative portfolio value: 6.794799375
# Maximum DrawDown: -0.3372936588039638
# Sharpe ratio: 1.0083397209717269
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 680486.5625
# Final accumulative portfolio value: 6.804865625
# Maximum DrawDown: -0.3374949234243185
# Sharpe ratio: 1.0077453703454304
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 681458.6875
# Final accumulative portfolio value: 6.814586875
# Maximum DrawDown: -0.3376909221846338
# Sharpe ratio: 1.0071645514042151
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 682401.375
# Final accumulative portfolio value: 6.82401375
# Maximum DrawDown: -0.337878435674682
# Sharpe ratio: 1.0066001782026357
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 683316.125
# Final accumulative portfolio value: 6.83316125
# Maximum DrawDown: -0.33806330416247843
# Sharpe ratio: 1.0060500719246874
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 684196.0
# Final accumulative portfolio value: 6.84196
# Maximum DrawDown: -0.33824150826876476
# Sharpe ratio: 1.0055106978446051
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 685054.375
# Final accumulative portfolio value: 6.85054375
# Maximum DrawDown: -0.33841553821466497
# Sharpe ratio: 1.004987853804936
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 685885.375
# Final accumulative portfolio value: 6.85885375
# Maximum DrawDown: -0.3385823084554642
# Sharpe ratio: 1.0044780118444268
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 686686.6875
# Final accumulative portfolio value: 6.866866875
# Maximum DrawDown: -0.33874731618592424
# Sharpe ratio: 1.0039772873259736
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 687470.875
# Final accumulative portfolio value: 6.87470875
# Maximum DrawDown: -0.3389056441945353
# Sharpe ratio: 1.0034944749923282
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 688233.8125
# Final accumulative portfolio value: 6.882338125
# Maximum DrawDown: -0.3390618584726798
# Sharpe ratio: 1.0030242860793792
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 688973.375
# Final accumulative portfolio value: 6.88973375
# Maximum DrawDown: -0.3392106431054488
# Sharpe ratio: 1.0025652557507525
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 689688.0625
# Final accumulative portfolio value: 6.896880625
# Maximum DrawDown: -0.3393571262977153
# Sharpe ratio: 1.0021155593611686
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 690389.875
# Final accumulative portfolio value: 6.90389875
# Maximum DrawDown: -0.33950037752200435
# Sharpe ratio: 1.0016817904860678
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 691060.0
# Final accumulative portfolio value: 6.9106
# Maximum DrawDown: -0.33963970374930763
# Sharpe ratio: 1.001251450580245
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 691721.9375
# Final accumulative portfolio value: 6.917219375
# Maximum DrawDown: -0.3397742994132632
# Sharpe ratio: 1.0008398712056803
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 692358.3125
# Final accumulative portfolio value: 6.923583125
# Maximum DrawDown: -0.3399073611332323
# Sharpe ratio: 1.0004314242349432
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 692984.6875
# Final accumulative portfolio value: 6.929846875
# Maximum DrawDown: -0.3400359067462365
# Sharpe ratio: 1.000038207722415
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 693587.75
# Final accumulative portfolio value: 6.9358775
# Maximum DrawDown: -0.34015932860950104
# Sharpe ratio: 0.9996517993660701
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 694177.5625
# Final accumulative portfolio value: 6.941775625
# Maximum DrawDown: -0.34028202900702953
# Sharpe ratio: 0.999275293725527
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 694745.625
# Final accumulative portfolio value: 6.94745625
# Maximum DrawDown: -0.34040121739196305
# Sharpe ratio: 0.9989063632938424
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 695303.6875
# Final accumulative portfolio value: 6.953036875
# Maximum DrawDown: -0.340515229030789
# Sharpe ratio: 0.9985462575297281
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 695851.4375
# Final accumulative portfolio value: 6.958514375
# Maximum DrawDown: -0.3406273486754958
# Sharpe ratio: 0.9981993970617287
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 696374.0625
# Final accumulative portfolio value: 6.963740625
# Maximum DrawDown: -0.34073852900281654
# Sharpe ratio: 0.9978544475956819
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 696890.0
# Final accumulative portfolio value: 6.9689
# Maximum DrawDown: -0.3408459506917695
# Sharpe ratio: 0.9975210031509867
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 697404.3125
# Final accumulative portfolio value: 6.974043125
# Maximum DrawDown: -0.3409497557936544
# Sharpe ratio: 0.9972046046494644
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 697882.3125
# Final accumulative portfolio value: 6.978823125
# Maximum DrawDown: -0.3410521257778145
# Sharpe ratio: 0.9968788773847953
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 698363.25
# Final accumulative portfolio value: 6.9836325
# Maximum DrawDown: -0.3411521580813347
# Sharpe ratio: 0.9965705105749588
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 698826.8125
# Final accumulative portfolio value: 6.988268125
# Maximum DrawDown: -0.3412493797273968
# Sharpe ratio: 0.9962656594270652
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 699279.0
# Final accumulative portfolio value: 6.99279
# Maximum DrawDown: -0.3413440338204211
# Sharpe ratio: 0.9959680643012725
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 699720.9375
# Final accumulative portfolio value: 6.997209375
# Maximum DrawDown: -0.3414367004828248
# Sharpe ratio: 0.9956781934171436
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 700147.8125
# Final accumulative portfolio value: 7.001478125
# Maximum DrawDown: -0.34152823908990915
# Sharpe ratio: 0.9953923041558737
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 700574.4375
# Final accumulative portfolio value: 7.005744375
# Maximum DrawDown: -0.3416169330526194
# Sharpe ratio: 0.9951213572003949
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 700977.9375
# Final accumulative portfolio value: 7.009779375
# Maximum DrawDown: -0.34170225950565836
# Sharpe ratio: 0.9948447191188373
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 701382.375
# Final accumulative portfolio value: 7.01382375
# Maximum DrawDown: -0.341787247879916
# Sharpe ratio: 0.9945829407286487
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 701773.625
# Final accumulative portfolio value: 7.01773625
# Maximum DrawDown: -0.3418700382472344
# Sharpe ratio: 0.9943246079670424
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702156.0
# Final accumulative portfolio value: 7.02156
# Maximum DrawDown: -0.3419500240005239
# Sharpe ratio: 0.9940722143073941
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702524.3125
# Final accumulative portfolio value: 7.025243125
# Maximum DrawDown: -0.3420293875704772
# Sharpe ratio: 0.9938214583118
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702894.375
# Final accumulative portfolio value: 7.02894375
# Maximum DrawDown: -0.3421061083516258
# Sharpe ratio: 0.9935825519076108
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703247.1875
# Final accumulative portfolio value: 7.032471875
# Maximum DrawDown: -0.3421815447194241
# Sharpe ratio: 0.9933435821433156
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703589.25
# Final accumulative portfolio value: 7.0358925
# Maximum DrawDown: -0.34225492759823783
# Sharpe ratio: 0.9931090712798301
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703932.875
# Final accumulative portfolio value: 7.03932875
# Maximum DrawDown: -0.342327369996403
# Sharpe ratio: 0.9928851931801992
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704259.75
# Final accumulative portfolio value: 7.0425975
# Maximum DrawDown: -0.34239858673279633
# Sharpe ratio: 0.9926602521264389
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704590.4375
# Final accumulative portfolio value: 7.045904375
# Maximum DrawDown: -0.3424665191047913
# Sharpe ratio: 0.9924468251411432
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704903.5625
# Final accumulative portfolio value: 7.049035625
# Maximum DrawDown: -0.3425349877509224
# Sharpe ratio: 0.9922309656573843
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705211.0625
# Final accumulative portfolio value: 7.052110625
# Maximum DrawDown: -0.34260147224044757
# Sharpe ratio: 0.9920219873400025
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705521.9375
# Final accumulative portfolio value: 7.055219375
# Maximum DrawDown: -0.34266493244311647
# Sharpe ratio: 0.9918220456129416
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705814.5
# Final accumulative portfolio value: 7.058145
# Maximum DrawDown: -0.3427285013225404
# Sharpe ratio: 0.991619362255184
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706104.8125
# Final accumulative portfolio value: 7.061048125
# Maximum DrawDown: -0.3427904218177624
# Sharpe ratio: 0.9914245715382655
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706386.0625
# Final accumulative portfolio value: 7.063860625
# Maximum DrawDown: -0.3428517042118875
# Sharpe ratio: 0.9912319500132889
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706664.625
# Final accumulative portfolio value: 7.06664625
# Maximum DrawDown: -0.342909544965602
# Sharpe ratio: 0.9910435113312781
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706944.5625
# Final accumulative portfolio value: 7.069445625
# Maximum DrawDown: -0.3429670723971797
# Sharpe ratio: 0.9908666524420244
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707202.75
# Final accumulative portfolio value: 7.0720275
# Maximum DrawDown: -0.3430256031514304
# Sharpe ratio: 0.9906813221980392
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707467.75
# Final accumulative portfolio value: 7.0746775
# Maximum DrawDown: -0.3430797996342565
# Sharpe ratio: 0.9905074817749282
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707718.8125
# Final accumulative portfolio value: 7.077188125
# Maximum DrawDown: -0.34313770484897466
# Sharpe ratio: 0.9903312466647622
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707967.3125
# Final accumulative portfolio value: 7.079673125
# Maximum DrawDown: -0.34319020140729417
# Sharpe ratio: 0.990161191625901
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708216.625
# Final accumulative portfolio value: 7.08216625
# Maximum DrawDown: -0.3432432234950501
# Sharpe ratio: 0.9899992832198438
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708445.0625
# Final accumulative portfolio value: 7.084450625
# Maximum DrawDown: -0.34329284693001805
# Sharpe ratio: 0.9898293733265985
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708686.125
# Final accumulative portfolio value: 7.08686125
# Maximum DrawDown: -0.3433444780404894
# Sharpe ratio: 0.9896738483498028
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708912.0
# Final accumulative portfolio value: 7.08912
# Maximum DrawDown: -0.34339333168833186
# Sharpe ratio: 0.9895153195379921
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709140.0
# Final accumulative portfolio value: 7.0914
# Maximum DrawDown: -0.3434408808771665
# Sharpe ratio: 0.989362100374268
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709362.375
# Final accumulative portfolio value: 7.09362375
# Maximum DrawDown: -0.3434894000450087
# Sharpe ratio: 0.9892148631458142
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709577.125
# Final accumulative portfolio value: 7.09577125
# Maximum DrawDown: -0.34353567596235135
# Sharpe ratio: 0.9890656026689199
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709787.1875
# Final accumulative portfolio value: 7.097871875
# Maximum DrawDown: -0.3435818826900776
# Sharpe ratio: 0.9889209473923094
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709998.875
# Final accumulative portfolio value: 7.09998875
# Maximum DrawDown: -0.343627051302675
# Sharpe ratio: 0.9887812299724902
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710193.0
# Final accumulative portfolio value: 7.10193
# Maximum DrawDown: -0.34367106993814656
# Sharpe ratio: 0.9886360802377855
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710401.75
# Final accumulative portfolio value: 7.1040175
# Maximum DrawDown: -0.3437149450214666
# Sharpe ratio: 0.9885053379241117
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710592.9375
# Final accumulative portfolio value: 7.105929375
# Maximum DrawDown: -0.34375688564431917
# Sharpe ratio: 0.988369083941521
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710783.75
# Final accumulative portfolio value: 7.1078375
# Maximum DrawDown: -0.3437972058688519
# Sharpe ratio: 0.9882366096751732
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710969.75
# Final accumulative portfolio value: 7.1096975
# Maximum DrawDown: -0.343838275565318
# Sharpe ratio: 0.9881065342094879
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711159.6875
# Final accumulative portfolio value: 7.111596875
# Maximum DrawDown: -0.34387890271027266
# Sharpe ratio: 0.9879828954050603
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711337.875
# Final accumulative portfolio value: 7.11337875
# Maximum DrawDown: -0.3439161539486769
# Sharpe ratio: 0.9878561266061018
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711513.0
# Final accumulative portfolio value: 7.11513
# Maximum DrawDown: -0.34395575720186555
# Sharpe ratio: 0.9877332014190431
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711688.25
# Final accumulative portfolio value: 7.1168825
# Maximum DrawDown: -0.34399258242222286
# Sharpe ratio: 0.9876143916039365
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711859.4375
# Final accumulative portfolio value: 7.118594375
# Maximum DrawDown: -0.3440296606903762
# Sharpe ratio: 0.9874970900064112
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712028.375
# Final accumulative portfolio value: 7.12028375
# Maximum DrawDown: -0.3440681383587838
# Sharpe ratio: 0.9873821542329543
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712186.25
# Final accumulative portfolio value: 7.1218625
# Maximum DrawDown: -0.34410316013938935
# Sharpe ratio: 0.9872653113656077
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712357.5625
# Final accumulative portfolio value: 7.123575625
# Maximum DrawDown: -0.3441372214075171
# Sharpe ratio: 0.9871600613413603
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712510.5
# Final accumulative portfolio value: 7.125105
# Maximum DrawDown: -0.344171290889129
# Sharpe ratio: 0.9870462722334757
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712666.3125
# Final accumulative portfolio value: 7.126663125
# Maximum DrawDown: -0.34420655691651736
# Sharpe ratio: 0.98693920912284
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712814.1875
# Final accumulative portfolio value: 7.128141875
# Maximum DrawDown: -0.34424066350929605
# Sharpe ratio: 0.9868306804494362
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712972.75
# Final accumulative portfolio value: 7.1297275
# Maximum DrawDown: -0.3442735499012868
# Sharpe ratio: 0.9867314302884497
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713115.8125
# Final accumulative portfolio value: 7.131158125
# Maximum DrawDown: -0.3443048581430448
# Sharpe ratio: 0.9866276294286099
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713257.125
# Final accumulative portfolio value: 7.13257125
# Maximum DrawDown: -0.344335311531216
# Sharpe ratio: 0.9865249035100081
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713397.5
# Final accumulative portfolio value: 7.133975
# Maximum DrawDown: -0.34436586833911387
# Sharpe ratio: 0.9864267195337143
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713536.9375
# Final accumulative portfolio value: 7.135369375
# Maximum DrawDown: -0.3443989339410132
# Sharpe ratio: 0.9863300110559997
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713681.8125
# Final accumulative portfolio value: 7.136818125
# Maximum DrawDown: -0.34442636099700763
# Sharpe ratio: 0.9862397816365713
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713811.6875
# Final accumulative portfolio value: 7.138116875
# Maximum DrawDown: -0.3444566092939936
# Sharpe ratio: 0.9861438585797299
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713937.5625
# Final accumulative portfolio value: 7.139375625
# Maximum DrawDown: -0.344486643598797
# Sharpe ratio: 0.9860485936920749
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714070.125
# Final accumulative portfolio value: 7.14070125
# Maximum DrawDown: -0.3445141620985407
# Sharpe ratio: 0.9859606442938161
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714200.5625
# Final accumulative portfolio value: 7.142005625
# Maximum DrawDown: -0.34454191654309707
# Sharpe ratio: 0.9858731503807951
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714327.5625
# Final accumulative portfolio value: 7.143275625
# Maximum DrawDown: -0.3445692669751145
# Sharpe ratio: 0.9857866813195492
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714450.0
# Final accumulative portfolio value: 7.1445
# Maximum DrawDown: -0.3445971243816789
# Sharpe ratio: 0.9857010250983067
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714573.1875
# Final accumulative portfolio value: 7.145731875
# Maximum DrawDown: -0.3446227505911935
# Sharpe ratio: 0.985617869031022
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714682.875
# Final accumulative portfolio value: 7.14682875
# Maximum DrawDown: -0.34464885446682425
# Sharpe ratio: 0.9855295914377218
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714797.25
# Final accumulative portfolio value: 7.1479725
# Maximum DrawDown: -0.34467507157177946
# Sharpe ratio: 0.9854468214247907
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714917.0625
# Final accumulative portfolio value: 7.149170625
# Maximum DrawDown: -0.3446993309501061
# Sharpe ratio: 0.985370931293527
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715028.875
# Final accumulative portfolio value: 7.15028875
# Maximum DrawDown: -0.34472574087335595
# Sharpe ratio: 0.9852911847961658
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715144.125
# Final accumulative portfolio value: 7.15144125
# Maximum DrawDown: -0.34474869519756424
# Sharpe ratio: 0.9852168660048517
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715246.0
# Final accumulative portfolio value: 7.15246
# Maximum DrawDown: -0.34477319285573604
# Sharpe ratio: 0.9851353828473284
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715358.1875
# Final accumulative portfolio value: 7.153581875
# Maximum DrawDown: -0.3447955982817381
# Sharpe ratio: 0.9850652732874072
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715461.0625
# Final accumulative portfolio value: 7.154610625
# Maximum DrawDown: -0.3448191286095942
# Sharpe ratio: 0.9849894357213347
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715562.0625
# Final accumulative portfolio value: 7.155620625
# Maximum DrawDown: -0.3448430163260242
# Sharpe ratio: 0.9849152409136736
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715662.4375
# Final accumulative portfolio value: 7.156624375
# Maximum DrawDown: -0.3448653943003409
# Sharpe ratio: 0.9848426982427372
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715766.6875
# Final accumulative portfolio value: 7.157666875
# Maximum DrawDown: -0.34488722689522333
# Sharpe ratio: 0.9847752728696756
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715867.1875
# Final accumulative portfolio value: 7.158671875
# Maximum DrawDown: -0.34490891524952405
# Sharpe ratio: 0.9847067408589292
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715958.5
# Final accumulative portfolio value: 7.159585
# Maximum DrawDown: -0.34492898367370484
# Sharpe ratio: 0.9846365803858453
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716055.5625
# Final accumulative portfolio value: 7.160555625
# Maximum DrawDown: -0.34495120231613385
# Sharpe ratio: 0.984571426284095
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716155.125
# Final accumulative portfolio value: 7.16155125
# Maximum DrawDown: -0.34497052969176767
# Sharpe ratio: 0.9845090218510514
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716242.5625
# Final accumulative portfolio value: 7.162425625
# Maximum DrawDown: -0.34499135230491984
# Sharpe ratio: 0.9844412648156314
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716333.0
# Final accumulative portfolio value: 7.16333
# Maximum DrawDown: -0.34501118456277946
# Sharpe ratio: 0.984377929743644
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716428.0
# Final accumulative portfolio value: 7.16428
# Maximum DrawDown: -0.34503142463696734
# Sharpe ratio: 0.9843192152474105
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716503.25
# Final accumulative portfolio value: 7.1650325
# Maximum DrawDown: -0.3450522455953863
# Sharpe ratio: 0.9842497593291336
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716596.0
# Final accumulative portfolio value: 7.16596
# Maximum DrawDown: -0.3450705635559096
# Sharpe ratio: 0.9841932253350404
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716679.875
# Final accumulative portfolio value: 7.16679875
# Maximum DrawDown: -0.3450869952027835
# Sharpe ratio: 0.9841319047261662
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716763.0625
# Final accumulative portfolio value: 7.167630625
# Maximum DrawDown: -0.345106318614708
# Sharpe ratio: 0.9840734883681197
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716846.5
# Final accumulative portfolio value: 7.168465
# Maximum DrawDown: -0.3451257262109627
# Sharpe ratio: 0.9840169068769928
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716918.625
# Final accumulative portfolio value: 7.16918625
# Maximum DrawDown: -0.34514438065690256
# Sharpe ratio: 0.9839559055456123
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717000.25
# Final accumulative portfolio value: 7.1700025
# Maximum DrawDown: -0.3451619488332922
# Sharpe ratio: 0.9839000228723674
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717080.0625
# Final accumulative portfolio value: 7.170800625
# Maximum DrawDown: -0.3451785484378518
# Sharpe ratio: 0.9838460049434452
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717159.5625
# Final accumulative portfolio value: 7.171595625
# Maximum DrawDown: -0.345195474917798
# Sharpe ratio: 0.9837925306488459
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717243.75
# Final accumulative portfolio value: 7.1724375
# Maximum DrawDown: -0.34521039701317324
# Sharpe ratio: 0.9837436629191316
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717313.875
# Final accumulative portfolio value: 7.17313875
# Maximum DrawDown: -0.34522825898131526
# Sharpe ratio: 0.9836897687419285
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717386.75
# Final accumulative portfolio value: 7.1738675
# Maximum DrawDown: -0.34524446156327127
# Sharpe ratio: 0.9836368085069087
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717453.3125
# Final accumulative portfolio value: 7.174533125
# Maximum DrawDown: -0.34526024006010414
# Sharpe ratio: 0.9835823385150335
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717528.625
# Final accumulative portfolio value: 7.17528625
# Maximum DrawDown: -0.3452770291178736
# Sharpe ratio: 0.9835341737725602
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717598.6875
# Final accumulative portfolio value: 7.175986875
# Maximum DrawDown: -0.34529209872022615
# Sharpe ratio: 0.983484555625376
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717664.4375
# Final accumulative portfolio value: 7.176644375
# Maximum DrawDown: -0.3453071631650716
# Sharpe ratio: 0.983433392823303
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717734.9375
# Final accumulative portfolio value: 7.177349375
# Maximum DrawDown: -0.34532298640743886
# Sharpe ratio: 0.983388666951659
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717800.0
# Final accumulative portfolio value: 7.178
# Maximum DrawDown: -0.345338304841459
# Sharpe ratio: 0.9833390205414401
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717872.8125
# Final accumulative portfolio value: 7.178728125
# Maximum DrawDown: -0.34535190528842263
# Sharpe ratio: 0.9832966865889037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717928.9375
# Final accumulative portfolio value: 7.179289375
# Maximum DrawDown: -0.34536719977592345
# Sharpe ratio: 0.9832463040026885
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717997.9375
# Final accumulative portfolio value: 7.179979375
# Maximum DrawDown: -0.34538099537615896
# Sharpe ratio: 0.9832039908657044
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718054.75
# Final accumulative portfolio value: 7.1805475
# Maximum DrawDown: -0.34539390906136713
# Sharpe ratio: 0.9831553777545938
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718116.8125
# Final accumulative portfolio value: 7.181168125
# Maximum DrawDown: -0.3454084116417142
# Sharpe ratio: 0.9831124664131824
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718180.4375
# Final accumulative portfolio value: 7.181804375
# Maximum DrawDown: -0.3454208864675077
# Sharpe ratio: 0.9830701111511085
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718239.625
# Final accumulative portfolio value: 7.18239625
# Maximum DrawDown: -0.3454357368521046
# Sharpe ratio: 0.983027360331048
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718301.125
# Final accumulative portfolio value: 7.18301125
# Maximum DrawDown: -0.3454483520345786
# Sharpe ratio: 0.9829866767980977
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718358.4375
# Final accumulative portfolio value: 7.183584375
# Maximum DrawDown: -0.34546090440195665
# Sharpe ratio: 0.9829455072252682
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718417.125
# Final accumulative portfolio value: 7.18417125
# Maximum DrawDown: -0.34547356354994696
# Sharpe ratio: 0.9829053895171405
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718475.875
# Final accumulative portfolio value: 7.18475875
# Maximum DrawDown: -0.34548688947587947
# Sharpe ratio: 0.9828652215257104
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718533.5625
# Final accumulative portfolio value: 7.185335625
# Maximum DrawDown: -0.34549842465591174
# Sharpe ratio: 0.9828278348590905
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718588.6875
# Final accumulative portfolio value: 7.185886875
# Maximum DrawDown: -0.34551049519029886
# Sharpe ratio: 0.9827897831171364
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718637.9375
# Final accumulative portfolio value: 7.186379375
# Maximum DrawDown: -0.3455233735193445
# Sharpe ratio: 0.9827482692845985
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718689.625
# Final accumulative portfolio value: 7.18689625
# Maximum DrawDown: -0.3455337669058405
# Sharpe ratio: 0.9827091867296927
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718744.0625
# Final accumulative portfolio value: 7.187440625
# Maximum DrawDown: -0.3455462575731373
# Sharpe ratio: 0.9826736031043748
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718793.125
# Final accumulative portfolio value: 7.18793125
# Maximum DrawDown: -0.3455597269477676
# Sharpe ratio: 0.982635497547845
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718846.875
# Final accumulative portfolio value: 7.18846875
# Maximum DrawDown: -0.345569747723404
# Sharpe ratio: 0.9826015302742737
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 718897.8125
# Final accumulative portfolio value: 7.188978125
# Maximum DrawDown: -0.3455820514425829
# Sharpe ratio: 0.9825653443260646
# =================================

# %% [markdown]
# ### Save Model

# %%
torch.save(algo.target_policy.state_dict(), "policy_EIIE.pt")

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Define test periods
# In this work, we are going to use three annual test periods: the year of 2020, 2021 and 2022. To get data from Yahoo Finance, we do just like in the training data.

# %%
portfolio_2020_raw_df = YahooDownloader(start_date = '2020-01-01',
                                end_date = '2020-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2021_raw_df = YahooDownloader(start_date = '2021-01-01',
                                end_date = '2021-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2022_raw_df = YahooDownloader(start_date = '2022-01-01',
                                end_date = '2022-12-31',
                                ticker_list = TOP_BRL).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2480, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2470, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2500, 8)

# %%
portfolio_2020_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   248   248   248  248    248     248  248
# BBAS3.SA   248   248   248  248    248     248  248
# BBDC4.SA   248   248   248  248    248     248  248
# ITUB4.SA   248   248   248  248    248     248  248
# LREN3.SA   248   248   248  248    248     248  248
# PETR4.SA   248   248   248  248    248     248  248
# PRIO3.SA   248   248   248  248    248     248  248
# RENT3.SA   248   248   248  248    248     248  248
# VALE3.SA   248   248   248  248    248     248  248
# WEGE3.SA   248   248   248  248    248     248  248

# %%
portfolio_2021_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   247   247   247  247    247     247  247
# BBAS3.SA   247   247   247  247    247     247  247
# BBDC4.SA   247   247   247  247    247     247  247
# ITUB4.SA   247   247   247  247    247     247  247
# LREN3.SA   247   247   247  247    247     247  247
# PETR4.SA   247   247   247  247    247     247  247
# PRIO3.SA   247   247   247  247    247     247  247
# RENT3.SA   247   247   247  247    247     247  247
# VALE3.SA   247   247   247  247    247     247  247
# WEGE3.SA   247   247   247  247    247     247  247

# %%
portfolio_2022_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   250   250   250  250    250     250  250
# BBAS3.SA   250   250   250  250    250     250  250
# BBDC4.SA   250   250   250  250    250     250  250
# ITUB4.SA   250   250   250  250    250     250  250
# LREN3.SA   250   250   250  250    250     250  250
# PETR4.SA   250   250   250  250    250     250  250
# PRIO3.SA   250   250   250  250    250     250  250
# RENT3.SA   250   250   250  250    250     250  250
# VALE3.SA   250   250   250  250    250     250  250
# WEGE3.SA   250   250   250  250    250     250  250

# %% [markdown]
# ### Instantiate different environments
#
# Since we have three different periods of time, we need three different environments instantiated to simulate them.

# %%
df_portfolio_2020 = portfolio_2020_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2021 = portfolio_2021_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2022 = portfolio_2022_raw_df[["date", "tic", "close", "high", "low"]]

environment_2020 = PortfolioOptimizationEnv(
    df_portfolio_2020,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2021 = PortfolioOptimizationEnv(
    df_portfolio_2021,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2022 = PortfolioOptimizationEnv(
    df_portfolio_2022,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...

# %% [markdown]
# ### Test EIIE architecture
# Now, we can test the EIIE architecture in the three different test periods. It's important no note three things:
# - In this code, we load the saved policy even though it's not necessary just to show how to save and load your model;
# - It's important to reset the environment before an episode and to create a new PVM (portfolio vector memory) for each case
# - The neural network is expecting a batch of data, so it's necessary to create an additional dimension to the input data if it's a single item.

# %%
EIIE_results = {
    "training": environment._asset_memory["final"],
    "2020": {},
    "2021": {},
    "2022": {}
}

policy = GradientPolicy()
policy.load_state_dict(torch.load("policy_EIIE.pt"))
policy = policy.to(device)

# 2020
done = False
obs = environment_2020.reset()
pvm = PVM(environment_2020.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2020.step(action)
EIIE_results["2020"]["value"] = environment_2020._asset_memory["final"]

# 2021
done = False
obs = environment_2021.reset()
pvm = PVM(environment_2021.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    observation, _, done, _ = environment_2021.step(action)
EIIE_results["2021"]["value"] = environment_2021._asset_memory["final"]

# 2022
done = False
obs = environment_2022.reset()
pvm = PVM(environment_2022.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2022.step(action)
EIIE_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 219689.5
# Final accumulative portfolio value: 2.196895
# Maximum DrawDown: -0.23370023437499998
# Sharpe ratio: 2.1253893835659503
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 90818.953125
# Final accumulative portfolio value: 0.90818953125
# Maximum DrawDown: -0.218329131026464
# Sharpe ratio: -0.2501943302868091
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 128775.5234375
# Final accumulative portfolio value: 1.287755234375
# Maximum DrawDown: -0.3525450893364046
# Sharpe ratio: 1.068355755457684
# =================================

# %% [markdown]
# ### Test Uniform Buy and Hold
# For comparison, we will also test the performance of a uniform buy and hold strategy. In this strategy, the portfolio has no remaining cash and the same percentage of money is allocated in each asset.

# %%
UBAH_results = {
    "train": {},
    "2020": {},
    "2021": {},
    "2022": {}
}

# train period
terminated = False
environment.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment.step(action)
UBAH_results["train"]["value"] = environment._asset_memory["final"]

# 2020
terminated = False
environment_2020.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2020.step(action)
UBAH_results["2020"]["value"] = environment_2020._asset_memory["final"]

# 2021
terminated = False
environment_2021.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2021.step(action)
UBAH_results["2021"]["value"] = environment_2021._asset_memory["final"]

# 2022
terminated = False
environment_2022.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2022.step(action)
UBAH_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 403829.625
# Final accumulative portfolio value: 4.03829625
# Maximum DrawDown: -0.4786377795312674
# Sharpe ratio: 0.786221469587266
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 171158.234375
# Final accumulative portfolio value: 1.71158234375
# Maximum DrawDown: -0.25078890625000005
# Sharpe ratio: 1.7129385029976547
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 95724.2109375
# Final accumulative portfolio value: 0.957242109375
# Maximum DrawDown: -0.17292988180179703
# Sharpe ratio: -0.15582947015178342
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 113415.03125
# Final accumulative portfolio value: 1.1341503125
# Maximum DrawDown: -0.1677040019182311
# Sharpe ratio: 0.8079255355916675
# =================================

# %% [markdown]
# ### Plot graphics

# %%
import matplotlib.pyplot as plt

plt.plot(UBAH_results["train"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["training"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in training period")
plt.legend()

plt.show()

# %%
plt.plot(UBAH_results["2020"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2020"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in 2020")
plt.legend()

plt.show()

# %%
plt.plot(UBAH_results["2021"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2021"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in 2021")
plt.legend()

plt.show()

# %%
plt.plot(UBAH_results["2022"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2022"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in 2022")
plt.legend()

plt.show()
