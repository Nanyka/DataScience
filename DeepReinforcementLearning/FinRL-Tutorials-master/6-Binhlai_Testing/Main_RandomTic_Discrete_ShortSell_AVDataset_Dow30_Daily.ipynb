# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch
# ## Main_RandomTic_Discrete_AVDataset_Dow30_Daily
# Network with 128 neutrons and 2 layers

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Check Additional Packages](#1.1)
#     * [2.2. Import Packages](#1.2)
#     * [2.3. Create Folders & Relevant Configurations¶](#1.3)
# * [3. Download Data](#2)
# * [4. Preprocess fundamental data](#3)
#     * [4.1. Import the financial data](#3.1)
#     * [4.2. Specify items needed to calculate financial ratios](#3.2)
#     * [4.3. Turn the final_ratios to daily basis](#3.3)
#     * [4.4. Merge stock price data and ratios into one dataframe](#3.4)
#     * [4.5. Finish data preparation](#3.5)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. Set up the training environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Train DRL Agent](#5)
# * [7.Backtest Our Strategy](#6)
#     * [7.1. BackTest with DJIA](#6.1)
#     * [7.2. BackTest with Buy&Hold Strategy](#6.2)
# * [8.Save & load model](#7)
#     * [8.1. Save model](#7.1)
#     * [8.2. Load model](#7.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Alpha Vantage API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# ### If continuing the previous training, jump to [**this point**](#8.1)

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import math
from stable_baselines3.common.logger import configure

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Create Folders & Relevant Configurations

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
from datetime import datetime
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

TRAIN_START_DATE = '2000-01-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

# Load price data from csv file
# tic_dir = './' + DATA_SAVE_DIR + '/sp500_price_daily.csv'
# df = pd.read_csv(tic_dir,index_col=0)

# %% [markdown]
# If the data is available locally, we can skip downloading steps and jump directly to part [**4.5.Finish data preparation**](#3.5)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Price Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# Download data from YFinance
# tic_dir = './' + DATA_SAVE_DIR + '/sp500_ticker.csv'
# tic_list = pd.read_csv(tic_dir,index_col=0)
# SP_500_TICKER = np.array(tic_list.tic).tolist()
# df = YahooDownloader(start_date = TRAIN_START_DATE,
#                      end_date = TEST_END_DATE,
#                      ticker_list = SP_500_TICKER).fetch_data()

# %%
# df.head()

# %%
# df.tail()

# %%
# df.shape

# %%
# df.sort_values(['date','tic']).head()

# %%
# len(df.tic.unique())

# %%
# df.tic.value_counts()

# %% [markdown]
# <a id='3'></a>
# # Part 4: Preprocess fundamental data
# - Import finanical data downloaded from Alpha Vantage
# - Preprocess the dataset and calculate financial ratios
# - Turn yearly ratio into daily basis

# %% [markdown]
# <a id='3.1'></a>
# ## 4.1 Import the financial data

# %% [markdown]
# #### Define configurations of the collecting data & download data via Alpha Vantage API

# %%
# import requests

# api_key = 'GZWRUSYXT18ZTR6C'
# features_cols = ['fiscalDateEnding','totalRevenue','costOfRevenue','sellingGeneralAndAdministrative','researchAndDevelopment','depreciation','interestExpense','totalCurrentLiabilities','incomeTaxExpense','netIncome','commonStockSharesOutstanding','cashAndCashEquivalentsAtCarryingValue','cashAndShortTermInvestments','operatingCashflow','totalLiabilities','inventory','currentNetReceivables','propertyPlantEquipment','capitalExpenditures','longTermInvestments','totalShareholderEquity','longTermDebt','retainedEarnings','dividendPayoutCommonStock','paymentsForRepurchaseOfCommonStock','treasuryStock','currentLongTermDebt']
# price_cols = ['open','high','low','close','volume']

# %% [markdown]
# Function to download fundamental data from financial reports by ticket

# %%
# def collect_fundamental(ticket):
#     # Download income statement
#     url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_is = r.json()

#     # Download balance sheet
#     url = f'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_bs = r.json()

#     # Download cash flow
#     url = f'https://www.alphavantage.co/query?function=CASH_FLOW&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_cf = r.json()

#     df_is = pd.json_normalize(data_is['annualReports'])
#     df_bs = pd.json_normalize(data_bs['annualReports'])
#     df_cf = pd.json_normalize(data_cf['annualReports'])

#     merged_df = df_is.merge(df_bs).merge(df_cf)
#     merged_df['tic'] = ticket
#     merged_df = merged_df[['tic']+features_cols]
#     merged_df['fiscalDateEnding'] = pd.to_datetime(merged_df.fiscalDateEnding,format='mixed')

#     return merged_df

# %% [markdown]
# Function to download stock price by ticket

# %%
# def collect_price(ticket):
#     url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol={ticket}&apikey={api_key}'
#     r = requests.get(url)
#     data_monthly_price = r.json()

#     price_monthly = pd.DataFrame.from_dict(data_monthly_price['Monthly Time Series'], orient='index')
#     price_monthly.columns = price_cols
#     price_monthly['fiscalDateEnding'] = pd.to_datetime(price_monthly.index,format='mixed')
#     price_monthly.reset_index(inplace=True,drop=True)
#     price_monthly = price_monthly[['fiscalDateEnding','open','high','low','close','volume']]
#     return price_monthly

# %% [markdown]
# Function to merge monthly stock price into yearly fundamental data

# %%
# def merge_price_to_df(merged_df,price_monthly):
#     merged_df['year'] = merged_df.fiscalDateEnding.dt.year
#     merged_df['month'] = merged_df.fiscalDateEnding.dt.month
#     price_monthly['year'] = price_monthly.fiscalDateEnding.dt.year
#     price_monthly['month'] = price_monthly.fiscalDateEnding.dt.month
#     merged_final = pd.merge(merged_df,price_monthly,how="left",on=['year','month'])
#     merged_final.drop(columns=['year','month','fiscalDateEnding_y'],inplace=True)
#     merged_final = df_final.rename(columns={'fiscalDateEnding_x': 'date'})
#     merged_final['tic'] = ticket

#     merged_columns = [merged_final.columns[-1]]
#     for i in range(0,len(merged_final.columns)-1):
#         merged_columns.append(merged_final.columns[i])
#     merged_final = merged_final[merged_columns]
    
#     return merged_final

# %%
# download_tics = SP_500_TICKER[453:]
# print(download_tics)

# %%
# fund_data = pd.DataFrame()

# for ticket in download_tics:
#     df_fund = collect_fundamental(ticket)
#     fund_data = pd.concat([fund_data, df_fund], ignore_index=True)

# %%
# fund_data.to_csv('sp500_6.csv')

# %%
# Check dropped tickers which are not available data to download from Alpha Vantage

# tics_1 = pd.DataFrame()
# tics_2 = pd.DataFrame()
# tics_1['tic'] = df.tic.unique()
# tics_2['tic'] = fund_data.tic.unique()

# merged_df = tics_1.merge(tics_2, how='outer', indicator=True)
# unique_in_df = merged_df[merged_df['_merge'] == 'left_only']
# unique_in_df

# %% [markdown]
# #### Check reach download limitation

# %%
# url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=IBM&apikey=GZWRUSYXT18ZTR6C'
# r = requests.get(url)
# data_is = r.json()
# data_is

# %% [markdown]
# #### Load data from csv file

# %%
# fund_data = pd.read_csv('./' + DATA_SAVE_DIR + '/sp500_fundamental.csv',index_col=0)
# # fund_data = fund_data.rename(columns={'fiscalDateEnding_x':'date'})
# fund_data['date'] = pd.to_datetime(fund_data.date,format='mixed')
# fund_data

# %% [markdown]
# Select tickers in DJ index only.

# %%
# fund_data = fund_data[fund_data.tic.isin(DOW_30_TICKER)].reset_index(drop=True)
# fund_data.tic.nunique()

# %%
# # UTIL TOOL: merge yearly fundamental data to daily stock price

# start_date = df.iloc[0].date
# end_date = df.iloc[-1].date
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')
# date_range = pd.DataFrame(date_range)
# date_range.columns = ['date']

# fund_data = fund_data.rename(columns={'fiscalDateEnding':'date'})
# fund_data['date'] = pd.to_datetime(fund_data.date,format='mixed')

# fund_data_with_price = pd.DataFrame()
# for ticket in fund_data.tic.unique():
#     price_by_ticket = df[df.tic == ticket]
#     price_by_ticket['date'] = pd.to_datetime(price_by_ticket['date'],format='mixed')
#     price_by_ticket = pd.merge(date_range,price_by_ticket,how='left')
#     price_by_ticket.bfill(inplace=True)
#     price_by_ticket = pd.merge(fund_data.loc[fund_data.tic==ticket],price_by_ticket,how='left',on=['date'])
#     price_by_ticket.drop(columns=['tic_y','day'],inplace=True,axis=0)
#     price_by_ticket = price_by_ticket.rename(columns={'tic_x':'tic'})
#     fund_data_with_price = pd.concat([fund_data_with_price, price_by_ticket], ignore_index=True)

# %% [markdown]
# #### Data cleaning ####
# Refine the data before computing fundamental ratios

# %%
# print(fund_data.info(),'\n')
# print(fund_data.isna().sum())

# %% [markdown]
# The company with zero totalRevenue might cause problems for computing ratios while it is the denominator in some formulars.<br>
# Deleting all tickers containing this issue is a good solution.

# %%
# zero_revenue_tics = fund_data[fund_data.totalRevenue == 0].tic.unique()
# fund_data = fund_data[~fund_data.tic.isin(zero_revenue_tics)]
# fund_data[fund_data.totalRevenue == 0]

# %% [markdown]
# While removing zero revenue data was neccessary, other columns with zero values might indicate some potential issues that require further investigations

# %%
# column_nan = fund_data.eq(0).any()
# column_nan

# %%
# fund_data = fund_data.fillna(0)
# for i in fund_data.columns:
#     print(i,'\n',fund_data[i].unique(),'\n')

# %% [markdown]
# ## 4.2 Compute fundamental ratio

# %% [markdown]
# Define support functions before computing fundamental ratios

# %%
# # Define a function to count positive values within a window
# def count_positives(window):
#   return window[window > 0].count()

# def count_positives_window(data,k):
#     df = pd.DataFrame(data, columns=['values'])

#     # Create a new column with the adjusted positive count (using a shifted window)
#     df['positive_count'] = df['values'].rolling(window=k, min_periods=1).apply(count_positives)

#     # Set positive_count of the first k rows to positive_count of row k
#     df.loc[:k-1,'positive_count'] = df.loc[k-1].positive_count

#     return df

# %%
# # Define a function to min value within a window
# def get_min(window):
#   return window.min()

# def min_in_window(data,k):
#     df = pd.DataFrame(data, columns=['values'])

#     # Create a new column with the min in the window (using a shifted window)
#     df['min'] = df['values'].rolling(window=k, min_periods=1).apply(get_min)

#     return df

# %% [markdown]
# At this point, data and supporting functions are ready for computing fundamental ratios required

# %%
# def compute_fund_ratios(df_final):
#     pos_count_window = 10  # number of years to look back for count_positive_profit
#     min_ebit_window = 4  # number of years to look back for min_ebit
    
#     gross_income = df_final.totalRevenue - df_final.costOfRevenue
#     ebit = gross_income - df_final.sellingGeneralAndAdministrative
#     profit = ebit - df_final.interestExpense - df_final.incomeTaxExpense
#     market_equity = df_final.commonStockSharesOutstanding * df_final.close
#     market_asset = df_final.totalLiabilities + market_equity
    
#     # Gross profit margin
#     gross_profit_margin = (gross_income/df_final.totalRevenue).to_frame('gross_profit_margin')
    
#     # SGA Expense / Gross Profit
#     sga_ratio = (df_final.sellingGeneralAndAdministrative/gross_income).to_frame('sga_ratio')
    
#     # Depreciation / Gross Profit
#     dep_ratio = (df_final.depreciation/gross_income).to_frame('dep_ratio')
    
#     # EBIT / Bond interest
#     ebit_on_int = (ebit/df_final.interestExpense).to_frame('ebit_on_int')
    
#     # Profit margin
#     profit_margin = (profit/df_final.totalRevenue).to_frame('profit_margin')
    
#     # Amount of positive profit within a window
#     count_positive_profit = count_positives_window(profit,pos_count_window)
#     count_positive_profit = count_positive_profit['positive_count'].to_frame('count_positive_profit')
#     count_positive_profit = count_positive_profit / pos_count_window # Standadize the positive profit
    
#     # Cash And Short Term Investments / Total Liabilities
#     csti_on_liabilities = (df_final.cashAndShortTermInvestments/df_final.totalLiabilities).to_frame('csti_on_liabilities')
    
#     # Inventory / EBIT
#     inventory_on_ebit = (df_final.inventory / ebit).to_frame('inventory_on_ebit')
    
#     # Receivable / Revenue
#     receivable_on_rev = (df_final.currentNetReceivables / df_final.totalRevenue).to_frame('receivable_on_rev')
    
#     # ROA
#     roa = (profit / market_asset).to_frame('roa')
    
#     # ROE
#     roe = (profit / market_equity).to_frame('roe')
    
#     # Long-term debt / minEBIT
#     min_ebit = min_in_window(ebit,min_ebit_window)['min']
#     debt_on_min_ebit = (df_final.longTermDebt / min_ebit).to_frame('debt_on_min_ebit')
    
#     # Total Liabilities / Total Equity
#     liabilities_on_equity = (df_final.totalLiabilities / market_equity).to_frame('liabilities_on_equity')
    
#     # Capital Expenditures / EBIT
#     capital_cost_on_ebit = (df_final.capitalExpenditures / ebit).to_frame('capital_cost_on_ebit')
    
#     # EPS / MP
#     eps = profit / df_final.commonStockSharesOutstanding
#     eps_on_mp = (eps / df_final.close).to_frame('eps_on_mp')
    
#     # Cash and Stock Dividend & Repurchase Common / MP
#     dividend_on_mp = ((df_final.dividendPayoutCommonStock + df_final.paymentsForRepurchaseOfCommonStock) / df_final.close).to_frame('dividend_on_mp')
    
#     # MP / BV
#     mp_on_bv = (df_final.close / (df_final.cashAndShortTermInvestments + df_final.currentNetReceivables*0.8 +df_final.inventory*0.5 + df_final.propertyPlantEquipment*0.2 + df_final.longTermInvestments - df_final.totalLiabilities)).to_frame('mp_on_bv')

#     # Create a dataframe that merges all the ratios
#     ratios = pd.concat([df_final.date,df_final.tic,gross_profit_margin,sga_ratio,dep_ratio,
#                     ebit_on_int,profit_margin,count_positive_profit,csti_on_liabilities,
#                     inventory_on_ebit,receivable_on_rev,roa,roe,debt_on_min_ebit,
#                    liabilities_on_equity,capital_cost_on_ebit,eps_on_mp,dividend_on_mp,mp_on_bv], axis=1)

#     return ratios

# %%
# ratios = compute_fund_ratios(fund_data)
# ratios.head()

# %% [markdown]
# Check columns with inf values

# %%
# ratio_list = ratios.columns.drop(['date','tic'])
# check_ratios = ratios[ratio_list]
# inf_cols = check_ratios.columns[~np.isfinite(check_ratios).all()]
# inf_cols

# %% [markdown]
# Check rows with inf values

# %%
# ratio_inf = ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
# print(len(ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]))
# ratio_inf.head()

# %% [markdown]
# The **ebit_on_int** has infinity values for companies without banking support. We need to address these cases separately: <br>
#  * Replace positive inf with maximum value in ebit_on_int
#  * Replace negative inf with minimum value in ebit_on_int

# %%
# ratio_finite = ratios[~((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]
# ratios['ebit_on_int'] = ratios.ebit_on_int.replace(np.inf,ratio_finite.ebit_on_int.max())
# ratios['ebit_on_int'] = ratios.ebit_on_int.replace(-np.inf,ratio_finite.ebit_on_int.min())
# print(len(ratios[((ratios == np.inf)|(ratios == -np.inf)).any(axis=1)]))

# %% [markdown]
# <a id='3.3'></a>
# ## 4.3 Turn the final_ratios to daily basis¶
# After our initial inspection, we’ll want to dig deeper to investigate the following:
# - The data type of each variable.
# - How discrete/categorical data is coded (and whether we need to make any changes).
# - How the data are scaled.
# - Whether there is missing data and how it is coded.
# - Whether there are outliers.
# - The distributions of continuous features.
# - The relationships between pairs of features.

# %% [markdown]
# ### Data types
# It is important to check the data type for each feature. <br>
# The **date** should be in datetime type <br>
# The **ratios** should be read in as float64 — and categorical variables should be stored as object

# %%
# ratios['date'] = pd.to_datetime(ratios['date'],format='mixed')
# ratios.info()

# %% [markdown]
# We see that there is no missing values from all ratios

# %% [markdown]
# ### Turn the final_ratios to daily basis

# %%
# start_date = df.iloc[0].date
# end_date = df.iloc[-1].date
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')
# date_range = pd.DataFrame(date_range)
# date_range.columns = ['date']
# date_range.head()

# %% [markdown]
# Interpolate missing data in the middle of years for each ticket

# %%
# daily_ratios = pd.DataFrame()
# for ticket in ratios.tic.unique():
#     # Interpolate data for each ticket
#     one_tic_ratios = pd.merge(date_range,ratios[ratios.tic == ticket],how="left",on=['date'])
#     one_tic_ratios['tic'] = ticket
#     one_tic_ratios = one_tic_ratios.interpolate('linear')
#     daily_ratios = pd.concat([daily_ratios, one_tic_ratios], ignore_index=True)

#     # Check data by drawing it out
#     %matplotlib inline
#     plt.figure(figsize=(16, 4)) 
#     plt.plot(one_tic_ratios.date, one_tic_ratios.gross_profit_margin, color = 'red')
#     plt.title(f'Gross profit margin of {ticket}')
#     plt.show()

# %%
# daily_ratios.dropna(subset='gross_profit_margin',inplace=True)
# daily_ratios.reset_index(inplace=True,drop=True)
# daily_ratios

# %% [markdown]
# <a id='3.4'></a>
# ## 4.4 Merge stock price data and ratios into one dataframe
# - Merge the price dataframe preprocessed in Part 3 and the ratio dataframe created in this part
# - Since the prices are daily and ratios are quartely, we have NAs in the ratio columns after merging the two dataframes. We deal with this by backfilling the ratios.

# %%
# df_date = pd.DataFrame(df)[['date','tic','close']]
# df_date.columns = ['date','tic','close']
# df_date['date'] = pd.to_datetime(df_date.date)
# final_ratios = pd.merge(df_date,daily_ratios,how="left",on=['date','tic'])

# %%
# final_ratios.dropna(subset=['gross_profit_margin'],inplace=True,how='any')
# final_ratios.reset_index(drop=True,inplace=True)
# final_ratios.isna().sum()

# %%
# final_ratios.to_csv('./' + DATA_SAVE_DIR + '/dow30_ready_data_daily.csv')

# %% [markdown]
# <a id='3.5'></a>
# ## 4.5 Finish data preparation

# %% [markdown]
# <a id='3.5.1'></a>
# ### 4.5.1 Load available data

# %%
# # If the data is available in the data storage, load processed_full from readied data
# processed_full = pd.read_csv('./' + DATA_SAVE_DIR + '/dow30_ready_data_daily.csv',index_col=0)
# processed_full['date'] = pd.to_datetime(processed_full.date,format='mixed')
# processed_full.info()

# %%
# processed_full = processed_full[processed_full.tic.isin(DOW_30_TICKER)]
# processed_full.tic.unique()

# %%
# processed_full.describe()

# %% [markdown]
# <a id='3.5.2'></a>
# ### 4.5.2 Feature engineer for specific utility
# In this case, the feature engineering is to standadize feature in the scope of Dow30

# %%
# def feature_standadize (df):
#     df_mean = np.mean(df)
#     df_std_dev = np.std(df)
#     df_standardized = (df - df_mean) / df_std_dev
#     return df_standardized

# %%
# df_standadize = pd.DataFrame()
# for feature in processed_full.columns.tolist()[3:]:
#     df_standadize[feature] = feature_standadize(processed_full[feature])
# df_standadize[processed_full.columns.tolist()[:3]] = processed_full[processed_full.columns.tolist()[:3]]

# %%
# df_standadize = df_standadize[['date', 'tic', 'close', 'gross_profit_margin', 'sga_ratio', 'dep_ratio', 'ebit_on_int',
#        'profit_margin', 'count_positive_profit', 'csti_on_liabilities',
#        'inventory_on_ebit', 'receivable_on_rev', 'roa', 'roe',
#        'debt_on_min_ebit', 'liabilities_on_equity', 'capital_cost_on_ebit',
#        'eps_on_mp', 'dividend_on_mp', 'mp_on_bv']]
# df_standadize.to_csv('./' + DATA_SAVE_DIR + '/dow30_standadized_data_daily.csv')

# %% [markdown]
# <a id='3.5.3'></a>
# ### 4.5.3 Finished data

# %%
# If the data is available in the data storage, load processed_full from readied data
processed_full = pd.read_csv('./' + DATA_SAVE_DIR + '/dow30_standadized_data_daily.csv',index_col=0)
processed_full['date'] = pd.to_datetime(processed_full.date,format='mixed')
processed_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100209 entries, 0 to 100208
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   100209 non-null  datetime64[ns]
#  1   tic                    100209 non-null  object
#  2   close                  100209 non-null  float64
#  3   gross_profit_margin    100209 non-null  float64
#  4   sga_ratio              100209 non-null  float64
#  5   dep_ratio              100209 non-null  float64
#  6   ebit_on_int            100209 non-null  float64
#  7   profit_margin          100209 non-null  float64
#  8   count_positive_profit  100209 non-null  float64
#  9   csti_on_liabilities    100209 non-null  float64
#  10  inventory_on_ebit      100209 non-null  float64
#  11  receivable_on_rev      100209 non-null  float64
#  12  roa                    100209 non-null  float64
#  13  roe                    100209 non-null  float64
#  14  debt_on_min_ebit       100209 non-null  float64
#  15  liabilities_on_equity  100209 non-null  float64
#  16  capital_cost_on_ebit   100209 non-null  float64
#  17  eps_on_mp              100209 non-null  float64
#  18  dividend_on_mp         100209 non-null  float64
#  19  mp_on_bv               100209 non-null  float64
# dtypes: datetime64[ns](1), float64(18), object(1)
# memory usage: 16.1+ MB

# %% [markdown]
# Reset **TRAIN_START_DATE** and **TEST_END_DATE**

# %%
TRAIN_START_DATE = processed_full.date.min().strftime("%Y-%m-%d")
TEST_END_DATE = processed_full.date.max().strftime("%Y-%m-%d")
print('TRAIN_START_DATE: ',TRAIN_START_DATE,'\n')
print('TRAIN_END_DATE: ',TRAIN_END_DATE,'\n')
print('TEST_START_DATE: ',TEST_START_DATE,'\n')
print('TEST_END_DATE: ',TEST_END_DATE,'\n')
# Out:
# TRAIN_START_DATE:  2009-09-30
#
# TRAIN_END_DATE:  2021-01-01
#
# TEST_START_DATE:  2021-01-01
#
# TEST_END_DATE:  2024-03-18

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.

# %% [markdown]
# <a id='4.1'></a>
# ## 5.1 Training & Trade Data Split
# - Training data period: 2009-01-01 to 2020-01-01
# - Trade data period: 2020-01-01 to 2023-12-29

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
test_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(test_data))
# Out:
# 76029
# 24150

# %%
train_data = train_data.reset_index(drop=True)
train_data
# Out:
#             date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0     2009-09-30  AAPL    5.604187            -0.139907  -0.281364  -0.534484
# 1     2009-09-30     V   15.578794             1.210325  -0.335214  -0.534484
# 2     2009-10-01  AAPL    5.468429            -0.139976  -0.281433  -0.534484
# 3     2009-10-01     V   15.581048             1.210622  -0.335287  -0.534484
# 4     2009-10-02  AAPL    5.590579            -0.140046  -0.281502  -0.534484
# ...          ...   ...         ...                  ...        ...        ...
# 76024 2020-12-31   UNH  335.059784             1.128715  -0.349634  -0.496983
# 76025 2020-12-31     V  213.664169             1.098478  -0.423877  -0.534484
# 76026 2020-12-31    VZ   48.816624             0.849726  -0.218890   0.691990
# 76027 2020-12-31   WBA   33.866371            -1.130752  -1.320279  -0.534484
# 76028 2020-12-31   WMT   45.710587            -0.318128   0.122545  -0.534484
#
#        ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0        -0.099218       0.139625               1.022816             4.639217
# 1        -0.086020       0.665147               1.022816             1.580528
# 2        -0.098829       0.139853               1.022816             4.633578
# 3        -0.085803       0.665853               1.022816             1.580880
# 4        -0.098440       0.140080               1.022816             4.627939
# ...            ...            ...                    ...                  ...
# 76024     0.031379       1.298718               1.022816            -0.367206
# 76025    -0.101929       1.077511               1.022816             0.714384
# 76026    -0.136246       0.663667               1.022816            -0.660057
# 76027    -0.252131      -0.750684              -0.478407            -0.911562
# 76028    -0.139682      -0.107671              -0.753220            -0.289744
#
#        inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0               0.057655          -0.421470  1.312460  2.546408
# 1               0.058248          -0.571434  0.438131  0.371472
# 2               0.057655          -0.421291  1.313016  2.548063
# 3               0.058248          -0.571587  0.438792  0.371799
# 4               0.057655          -0.421112  1.313573  2.549717
# ...                  ...                ...       ...       ...
# 76024           0.057603          -0.203735  1.779496  1.103206
# 76025           0.057875          -0.400303 -0.006084  0.013851
# 76026           0.057641           0.728930  0.351021  0.460178
# 76027           0.057295          -0.738858 -2.037473 -2.583365
# 76028           0.059628          -1.130862  0.141161  0.244926
#
#        debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0              0.069419               0.457517             -0.010692
# 1              0.069432              -0.297608             -0.016260
# 2              0.069419               0.457804             -0.010686
# 3              0.069432              -0.297738             -0.016270
# 4              0.069419               0.458090             -0.010681
# ...                 ...                    ...                   ...
# 76024          0.069771              -0.386675             -0.023905
# 76025          0.070944              -0.474129             -0.019314
# 76026          0.072035              -0.081097              0.023872
# 76027          0.069145               0.132519             -0.031709
# 76028          0.071345              -0.081374              0.028002
#
#        eps_on_mp  dividend_on_mp  mp_on_bv
# 0       2.546408       -0.649337  0.082000
# 1       0.371472        0.036704 -0.264662
# 2       2.548063       -0.649337  0.082002
# 3       0.371799        0.035626 -0.266902
# 4       2.549717       -0.649337  0.082004
# ...          ...             ...       ...
# 76024   1.103206       -0.554268 -0.093313
# 76025   0.013851       -0.452588 -0.139114
# 76026   0.460178        0.106448  0.071312
# 76027  -2.583365       -0.351382  0.057363
# 76028   0.244926        0.104523  0.065955
#
# [76029 rows x 20 columns]

# %%
test_data = test_data.reset_index(drop=True)
test_data
# Out:
#             date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0     2021-01-04  AAPL  127.002121            -0.104949  -0.354047   0.191547
# 1     2021-01-04  AMGN  204.389359             1.142033  -0.283165  -0.294481
# 2     2021-01-04   AXP  113.141533            -0.569008   0.836168  -0.534484
# 3     2021-01-04    BA  202.720001            -1.403903  -1.166227  -0.534484
# 4     2021-01-04   CAT  170.039978            -0.144025  -0.243412   0.605131
# ...          ...   ...         ...                  ...        ...        ...
# 24145 2024-03-15   UNH  490.820007             1.226397  -0.373073  -0.507139
# 24146 2024-03-15     V  283.040009             1.121480  -0.435690  -0.534484
# 24147 2024-03-15    VZ   39.490002             0.689381  -0.193544   0.804518
# 24148 2024-03-15   WBA   20.820000            -1.310538  -3.367343  -0.534484
# 24149 2024-03-15   WMT   60.680000            -0.332079   0.115669  -0.534484
#
#        ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0        -0.101149       0.390351               0.343358             0.239597
# 1        -0.139201       0.971418               0.722571            -0.173432
# 2        -0.167377      -0.779031              -1.078895            -0.229657
# 3        -0.172554      -0.672845              -0.174872            -0.390483
# 4        -0.126105       0.266554               1.022816            -0.395919
# ...            ...            ...                    ...                  ...
# 24145    -0.006705       1.432766               1.022816            -0.316387
# 24146    -0.232936       1.311924               0.722571             0.232620
# 24147    -0.144077       0.521580               1.022816            -0.933777
# 24148    -0.334521      -1.031224              -0.478407            -0.916612
# 24149    -0.138085      -0.093446              -1.679384            -0.546488
#
#        inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0               0.057668           0.223031  0.014103  0.024618
# 1               0.057919           0.962509  0.234288  0.183699
# 2               0.043812          -1.255194 -0.350718 -0.294830
# 3               0.056401          -0.896404 -0.320689 -0.185088
# 4               0.059036           3.015460  0.116816  0.137493
# ...                  ...                ...       ...       ...
# 24145           0.057616          -0.139126  1.861084  1.110970
# 24146           0.057845          -0.424349  0.073300  0.052393
# 24147           0.057651           0.809937  0.280448  0.505723
# 24148           0.057412          -0.847497 -3.193280 -5.568330
# 24149           0.059653          -1.110754 -0.071097 -0.016855
#
#        debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0              0.077042              -0.469056             -0.012347
# 1              0.091889              -0.372263             -0.019907
# 2              0.061247               0.043902             -0.056151
# 3              0.063676              -0.268207             -0.040983
# 4              0.072338              -0.300918              0.005038
# ...                 ...                    ...                   ...
# 24145          0.084118              -0.401355             -0.023814
# 24146          0.071266              -0.472262             -0.019407
# 24147          0.135421               0.114621              0.040383
# 24148          0.069235               0.482866             -0.031264
# 24149          0.063509              -0.470671              0.063155
#
#        eps_on_mp  dividend_on_mp  mp_on_bv
# 0       0.024618        2.057967 -0.009296
# 1       0.183699       -0.523085 -0.053750
# 2      -0.294830       -0.570047  0.041913
# 3      -0.185088       -0.630040  0.040882
# 4       0.137493       -0.577541 -0.125933
# ...          ...             ...       ...
# 24145   1.110970       -0.550262 -0.113145
# 24146   0.052393       -0.401194 -0.102455
# 24147   0.505723        0.390393  0.073204
# 24148  -5.568330       -0.382523  0.066075
# 24149  -0.016855       -0.063498  0.063249
#
# [24150 rows x 20 columns]

# %% [markdown]
# <a id='4.2'></a>
# ## 5.2 Set up the training environment

# %% [markdown]
# Describe the environment:
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. However, because StableBaseline does not support {-1,0,1} as int for discrete space, we might turn the space to {0,1,2}. For example, "Buy AAPL with all the current capital" or "Sell all available AAPL" are 2 or 0, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The surplus when selling stocks address reward for each deal and the capital gain at the end of each episode indicate total reward of the trading. To enforce the agent learn something, a punishment is applied at the begining of each step. Additionally, punishments also employ to keep the agent away from deciding unavailable buying and selling.
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents

# %%
import gymnasium as gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

from gymnasium import spaces
from gymnasium.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        # stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        stop_loss,
        # punishment_rate,
        make_plots=False,
        print_verbosity=10,
        row=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        # self.row = row
        self.df = df
        # self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        # self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        # self.punishment_rate = punishment_rate
        self.stop_loss = stop_loss # the game stops when the asset loses more than stop_loss percent
        self.action_space = spaces.Discrete(3, start=0, seed=42)
        # self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        # self.turbulence_threshold = turbulence_threshold
        # self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        self.portfolio_columns = ['tic','price','buy_price','amount','weight']
        self.tic_list = self.df.tic.unique()
        self.original_df = self.df.copy()
        self.row = 0
        
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _buy_stock(self, action):
        def _do_buy():
            if self.data.close > 0: # Buy only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                selected_row = self.portfolio[self.portfolio.tic == self.data.tic]
                # print(f'Selected row: {selected_row}')

                if (selected_row.empty):
                    selected_index = len(self.portfolio)
                    self.portfolio.loc[selected_index] = [self.data.tic,0,0,0,0]

                selected_row = self.portfolio[self.portfolio.tic == self.data.tic]
                if (selected_row.amount.item() == 0):
                    # print('Open normal position')
                    buy_amount = self.portfolio.loc[0].price * (1 - self.buy_cost_pct)
                    buy_num_shares = int(abs(buy_amount/self.data.close))
                    
                    selected_index = selected_row.index[0]
                    selected_row = self.portfolio.loc[selected_index]

                    # Update ticker in the portfolio
                    selected_row[1] = self.data.close
                    selected_row[2] = self.data.close
                    selected_row[3] += buy_num_shares
                    self.portfolio.loc[selected_index] = selected_row

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_change = buy_num_shares * self.data.close * (1 + self.buy_cost_pct)
                    capital_row[1] -= capital_change
                    capital_row[2] -= capital_change
                    self.portfolio.loc[0] = capital_row
                    
                    self._compute_weight()
                    self.cost += selected_row[1] * buy_num_shares * self.buy_cost_pct
                    self.trades += 1

                # Close short-sell position
                elif selected_row.amount.item() < 0:
                    # print('Close short-sell position')
                    buy_num_shares = abs(selected_row.amount)
                    buy_amount = buy_num_shares * self.data.close * (1 + self.buy_cost_pct)
                    
                    # Update reward
                    sell_amount = buy_num_shares * selected_row.buy_price
                    # print(f'Close short sell with buy price is {selected_row.buy_price} and close price is {self.data.close}')
                    # print(f'Reward is: {(sell_amount - buy_amount).values[0].item() * self.reward_scaling}')
                    self.reward += (sell_amount - buy_amount).values[0].item() * self.reward_scaling
                    
                    # Update ticker in the portfolio
                    selected_index = selected_row.index[0]
                    selected_row = self.portfolio.loc[selected_index]
                    selected_row[1] = self.data.close
                    selected_row[2] = self.data.close
                    selected_row[3] = 0
                    self.portfolio.loc[selected_index] = selected_row

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    # capital_change = buy_num_shares * self.data.close * (1 + self.buy_cost_pct)
                    capital_row[1] -= buy_amount
                    capital_row[2] -= buy_amount
                    self.portfolio.loc[0] = capital_row
                    
                    self._compute_weight()
                    self.cost += selected_row[1] * buy_num_shares * self.buy_cost_pct
                    self.trades += 1
                
                else:    
                    # print('Violate buy in normal position')
                    buy_num_shares = 0
                    # Punish a certain amount of money if selling without avaiable stock in the inventory
                    self.reward += -5 * self.initial_amount * self.punishment_rate * self.reward_scaling
            else:
                buy_num_shares = 0

            return buy_num_shares

        buy_num_shares = _do_buy()
        return buy_num_shares
    
    def _sell_stock(self, action):
        def _do_sell_normal():
            # TODO: Punish a certain amount of money if selling without avaiable stock in the inventory
            if self.data.close > 0: # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                selected_row = self.portfolio[self.portfolio.tic == self.data.tic]
                # print(f'Selected row: {selected_row}')
                
                if (selected_row.empty):
                    selected_index = len(self.portfolio)
                    self.portfolio.loc[selected_index] = [self.data.tic,0,0,0,0]

                selected_row = self.portfolio[self.portfolio.tic == self.data.tic]
                # In the case of short sell
                if (selected_row.amount.item() == 0):
                    # print('Open short-sell position')
                    selected_index = selected_row.index[0]
                    selected_row = self.portfolio.loc[selected_index]
                    
                    # The agent can sell an amount of stock equaling to the capital
                    capital_row = self.portfolio.loc[0]
                    sell_num_shares = int(abs(capital_row.price / self.data.close))
                    sell_amount = self.data.close * sell_num_shares * (1 - self.sell_cost_pct)
                    
                    # update stock row in the portfolio
                    # selected_index = selected_row.index[0]
                    # selected_row = self.portfolio.loc[selected_index]
                    selected_row[1] = self.data.close
                    selected_row[2] = self.data.close
                    selected_row[3] -= sell_num_shares

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_row[1] += sell_amount
                    capital_row[2] += sell_amount

                    # Update changes to portfolio
                    self.portfolio.loc[selected_index] = selected_row
                    self.portfolio.loc[0] = capital_row
                    self._compute_weight()
                    self.cost += selected_row[1] * sell_num_shares * self.sell_cost_pct
                    self.trades += 1
                
                elif (selected_row.amount.item() < 0): 
                    # print('Violate sell in short-sell')
                    sell_num_shares = 0
                    
                    # Punish a certain amount of money if selling without avaiable stock in the inventory
                    self.reward += -5 * self.initial_amount * self.punishment_rate * self.reward_scaling
                
                else:
                    # print('Close normal position')
                    sell_num_shares = selected_row.iloc[0].amount
                    sell_amount = self.data.close * sell_num_shares * (1 - self.sell_cost_pct)

                    # Update reward
                    buy_amount = selected_row.buy_price * sell_num_shares
                    self.reward += (sell_amount - buy_amount).values[0].item() * self.reward_scaling
                    
                    # update stock row in the portfolio
                    selected_index = selected_row.index[0]
                    selected_row = self.portfolio.loc[selected_index]
                    selected_row[1] = self.data.close
                    selected_row[3] -= sell_num_shares

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_row[1] += sell_amount
                    capital_row[2] += sell_amount

                    # Update changes to portfolio
                    self.portfolio.loc[selected_index] = selected_row
                    self.portfolio.loc[0] = capital_row
                    self._compute_weight()
                    self.cost += selected_row[1] * sell_num_shares * self.sell_cost_pct
                    self.trades += 1
            else:
                sell_num_shares = 0

            return sell_num_shares

        sell_num_shares = _do_sell_normal()
        return sell_num_shares

    def _compute_weight(self):
        nav = sum(self.portfolio.price*self.portfolio.amount)
        self.portfolio['weight'] = self.portfolio.apply(lambda x: x.price * x.amount / nav, axis=1)

    def step(self, actions):

        current_total_asset = sum(self.portfolio.price * self.portfolio.amount)
        self.terminal = (self.row >= len(self.df.index.unique()) - 1) | (current_total_asset < self.initial_amount*(1-self.stop_loss))
        # print(f'Step {self.row}, action: {actions}, reward: {self.reward}, Trade: {self.trades}')
                
        # --> IN CASE THE STEP IS THE TERMINATED STEP
        if self.terminal: 
            print(f"Episode: {self.episode}")
                
            # Summary the training performance after an episode
            end_total_asset = sum(self.portfolio.price*self.portfolio.amount)
            tot_reward = end_total_asset - self.initial_amount

            # Print out training results after a certain amount of episodes
            if self.episode % self.print_verbosity == 0:
                print(f"Current company: {self.df.tic.unique()}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost.item():0.2f}")
                print(f"total_trades: {self.trades}")
                # if df_total_value["daily_return"].std() != 0:
                #     print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")
            
            truncated = False  # we do not limit the number of steps here
            # Optionally we can pass additional info, we are not using that for now
            info = {}


            return (
                np.array(self.state).astype(np.float32),
                self.reward,
                self.terminal,
                truncated,
                info,
            )

        # --> IN A NORMAL STEP
        else: 

            # begin_total_asset = sum(self.portfolio.price * self.portfolio.amount)

            # Set a punishment at each step to push the agent decide an action
            self.reward += -1 * self.initial_amount * self.punishment_rate * self.reward_scaling
            
            action = actions - 1 # Turn from {0,1,2} action space to {-1,0,1}
            if action > 0:
                self._buy_stock(action)
            elif action < 0:
                self._sell_stock(action)

            self.actions_memory.append(actions)

            # Update selected row in the dataset based on state: s -> s+1
            self.row += 1
            self.data = self.df.loc[self.row]
            self.state = self._update_state()
    
            end_total_asset = sum(self.portfolio.price * self.portfolio.amount)
            # print(f'Begin asset: {begin_total_asset}, End asset: {end_total_asset}')

            # Update asset memory
            self.current_asset = end_total_asset
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())

            # Update reward
            # if self.reward == 0:
            #     self.reward = end_total_asset - self.initial_amount

            if (self.row >= len(self.df.index.unique()) - 1):
                self.reward += (end_total_asset - self.initial_amount)  * self.reward_scaling
            
            self.rewards_memory.append(self.reward)
            # self.reward = self.reward * self.reward_scaling

        truncated = False  # we do not limit the number of steps here
        # Optionally we can pass additional info, we are not using that for now
        info = {}
        
        # return self.state, self.reward, self.terminal, {}
    
        return (
            np.array(self.state).astype(np.float32),
            self.reward,
            self.terminal,
            truncated,
            info,
        )

    def reset(self, seed=None, options=None):
        # initiate state
        self.state = self._initiate_state()

        # Reset asset_memory
        self.asset_memory = [self.initial_amount]

        # if self.initial:
        #     self.asset_memory = [self.initial_amount]
        # else:
        #     previous_total_asset = sum(self.previous_port.price * self.previous_port.amount)
        #     self.asset_memory = [previous_total_asset]

        # Reset support variables
        self.cost = 0
        self.trades = 0
        self.terminal = False
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        self.episode += 1

        return np.array(self.state).astype(np.float32), {}
        # return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        
        # Reset portfolio & previous_portfolio
        self.portfolio = pd.DataFrame([['cap',self.initial_amount,self.initial_amount,1,1]])
        self.portfolio.columns = self.portfolio_columns
        
        # if self.initial:
        #     self.portfolio = pd.DataFrame([['cap',self.initial_amount,self.initial_amount,1,1]])
        #     self.portfolio.columns = self.portfolio_columns
        #     self.previous_port = self.portfolio.copy()
        # else:
        #     self.portfolio = self.previous_port.copy()

        # Select a random ticker from df
        self.df = self.original_df[self.original_df.tic == random.choice(self.tic_list)].reset_index(drop=True)
        self.punishment_rate = 1/(len(self.df)*100)
        
        # Reset data
        self.reward = 0
        self.row = 0
        self.data = self.df.loc[self.row]
        
         # Reset state
        state = self._update_state()
        
        return state

    def _update_state(self):

        # if the stock appear in the portfolio already
        if self.portfolio[self.portfolio.tic == self.data.tic].empty:
            state = ([0] + [0] + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))
            
        else:
            # Update stock's prices in portfolio before updating state
            selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
            selected_row = self.portfolio.loc[selected_index]
            selected_row['price'] = self.data.close
            self.portfolio.loc[selected_index] = selected_row
            self._compute_weight()
            selected_row = self.portfolio.loc[selected_index]
            # print("Update portfolio at ",self.data.tic," price: ", self.data.close,"; with weight: ", selected_row.weight)

            if selected_row.amount > 0:
                profit_ratio = selected_row.price/selected_row.buy_price-1
                trading_state = 1
            elif selected_row.amount < 0:
                profit_ratio = 1 - selected_row.price/selected_row.buy_price
                trading_state = -1
            else:
                profit_ratio = 0
                trading_state = 0
            
            state = ([trading_state] + [profit_ratio] + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))
            
            # state = (
            #         [self.portfolio.iloc[0].price]
            #         + [(selected_row.buy_price/selected_row.price-1)]
            #         + [self.data.close]
            #         + [selected_row.amount]
            #         + [selected_row.weight]
            #         + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
            #     )
    
        return state

    def _get_date(self):
        # return self.data.date
        return self.row

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        
        date_list = self.date_memory[:-1]
        action_list = self.actions_memory
        df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %% [markdown]
# <a id='4.3'></a>
# ## 5.3 Initialize Environment

# %% [markdown]
# State's space include stock_amount, current_return and the indicators decided in ratio_list

# %%
ratio_list = train_data.columns.drop(['date','tic','close'])

action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
state_space = 2 + len(ratio_list)
print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 19

# %% [markdown]
# #### Initiate environment

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.8,
    "print_verbosity":4,
    # "punishment_rate": 0.0001
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %%
from stable_baselines3.common.env_checker import check_env

# If the environment don't follow the interface, an error will be thrown
check_env(e_train_gym, warn=True)

# %%
from stable_baselines3 import PPO, A2C, DQN, DDPG

# Instantiate the env
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='8.1'></a>
# #### If the training starts from the previous model, the section should **run all cells above** this line and then jump to [**Load trained model**](#7.2.1) to keep the traning going.

# %% [markdown]
# #### Test Environment

# %%
# Get samples from train_data
test_env_data = train_data
# test_env_data = trade_data.iloc[:20]
# test_env_data.close = [10,100,15,90,20,80,25,85,18,92,10,100,15,90,20,80,25,85,18,92]

# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.2,
    "print_verbosity":4,
    # "punishment_rate": 0.0001
}

#Establish the training environment using StockTradingEnv() class
test_train_gym = StockTradingEnv(df = test_env_data, **env_kwargs)

# test reset state
print(test_train_gym.reset())
# Out:
# (array([ 0.        ,  0.        , -0.03273416,  0.02288383, -0.53448445,
#        -0.13993865,  0.01598341,  1.0228155 , -0.70677286,  0.0591816 ,
#        -1.1001157 ,  0.36238524,  0.30239648,  0.07072723, -0.31743494,
#        -0.00834253,  0.30239648, -0.3388628 ,  0.02676827], dtype=float32), {})

# %%
for i in range(0,3000):
    action = test_train_gym.action_space.sample()
    # print(test_train_gym.data)
    state,reward,terminal,truncated,info = test_train_gym.step(action)
    if terminal:
        test_train_gym.reset()
    print(f'Step {test_train_gym.row}, action: {action}, asset: {test_train_gym.current_asset}, reward: {test_train_gym.reward}, Trade: {test_train_gym.trades}')
    # print(f'{test_train_gym.punishment_rate}')
    print(f'Price: {test_train_gym.data.close},State:{test_train_gym.state[:2]}\n')
# Out:
# Step 1, action: 0, asset: 976456.6983763506, reward: -0.00036363636363636367, Trade: 1
# Price: 20.685415267944336,State:[-1, -0.022543329165888748]
#
# Step 2, action: 2, asset: 975434.1562434104, reward: -2.357311765371568, Trade: 2
# Price: 20.286380767822266,State:[0, 0]
#
# Step 3, action: 1, asset: 975434.1562434104, reward: -2.3576754017352046, Trade: 2
# Price: 19.901611328125,State:[0, 0]
#
# Step 4, action: 1, asset: 975434.1562434104, reward: -2.358039038098841, Trade: 2
# Price: 19.937231063842773,State:[0, 0]
#
# Step 5, action: 1, asset: 975434.1562434104, reward: -2.3584026744624778, Trade: 2
# Price: 20.37189102172852,State:[0, 0]
#
# Step 6, action: 2, asset: 984003.0793510268, reward: -2.3587663108261143, Trade: 3
# Price: 20.5714054107666,State:[1, 0.009793611639944633]
#
# Step 7, action: 0, asset: 983019.0873160136, reward: -1.503191973605202, Trade: 4
# Price: 20.414644241333008,State:[0, 0]
#
# Step 8, action: 2, asset: 993691.4693199659, reward: -1.5035556099688383, Trade: 5
# Price: 20.65691947937012,State:[1, 0.011867717858466742]
#
# Step 9, action: 0, asset: 992697.7888653303, reward: -0.4378464867423164, Trade: 6
# Price: 20.664039611816406,State:[0, 0]
#
# Step 10, action: 0, asset: 976643.5345482148, reward: -0.43821012310595275, Trade: 7
# Price: 20.97756767272949,State:[-1, -0.015172641303581091]
#
# Step 11, action: 1, asset: 956790.136484555, reward: -0.4385737594695891, Trade: 7
# Price: 21.390844345092773,State:[-1, -0.03517244192954205]
#
# Step 12, action: 2, asset: 955762.5417130612, reward: -4.033194131168947, Trade: 8
# Price: 21.590356826782227,State:[0, 0]
#
# Step 13, action: 2, asset: 950080.8514149903, reward: -4.033557767532583, Trade: 9
# Price: 21.48346900939941,State:[1, -0.004950720279445542]
#
# Step 14, action: 2, asset: 955438.2577355623, reward: -4.035739585714402, Trade: 9
# Price: 21.6046142578125,State:[1, 0.000660361065111692]
#
# Step 15, action: 2, asset: 968987.9451153993, reward: -4.03792140389622, Trade: 9
# Price: 21.911008834838867,State:[1, 0.01485163078263163]
#
# Step 16, action: 2, asset: 988209.7437356233, reward: -4.040103222078039, Trade: 9
# Price: 22.345664978027344,State:[1, 0.03498358815025138]
#
# Step 17, action: 1, asset: 988209.7437356233, reward: -4.040466858441675, Trade: 9
# Price: 22.345664978027344,State:[1, 0.03498358815025138]
#
# Step 18, action: 0, asset: 987221.5513933001, reward: -0.7994504917863554, Trade: 10
# Price: 22.23165702819824,State:[0, 0]
#
# Step 19, action: 2, asset: 993505.5251242439, reward: -0.7998141281499918, Trade: 11
# Price: 22.395544052124023,State:[1, 0.007371786264870561]
#
# Step 20, action: 1, asset: 991292.8395182411, reward: -0.8001777645136281, Trade: 11
# Price: 22.345664978027344,State:[1, 0.005128180489852863]
#
# Step 21, action: 1, asset: 994769.6268011847, reward: -0.8005414008772644, Trade: 11
# Price: 22.42403984069824,State:[1, 0.008653552555978328]
#
# Step 22, action: 1, asset: 993821.6351553719, reward: -0.8009050372409008, Trade: 11
# Price: 22.40266990661621,State:[1, 0.007692313631910697]
#
# Step 23, action: 0, asset: 992827.8303156445, reward: -0.1420189276273095, Trade: 12
# Price: 22.659183502197266,State:[0, 0]
#
# Step 24, action: 2, asset: 996826.3406530966, reward: -0.14238256399094587, Trade: 13
# Price: 22.773193359375,State:[1, 0.005031507740191898]
#
# Step 25, action: 2, asset: 995444.2207018484, reward: -0.14456438217276407, Trade: 13
# Price: 22.74161720275879,State:[1, 0.003637981949063951]
#
# Step 26, action: 1, asset: 996386.6169573416, reward: -0.14492801853640044, Trade: 13
# Price: 22.763147354125977,State:[1, 0.004588155258049342]
#
# Step 27, action: 1, asset: 1009583.5874830831, reward: -0.14529165490003682, Trade: 13
# Price: 23.064647674560547,State:[1, 0.017894032780305658]
#
# Step 28, action: 2, asset: 1019638.2909762014, reward: -0.14747347308185502, Trade: 13
# Price: 23.29435920715332,State:[1, 0.02803171195001175]
#
# Step 29, action: 1, asset: 1027179.297724401, reward: -0.1478371094454914, Trade: 13
# Price: 23.466642379760746,State:[1, 0.03563495028341079]
#
# Step 30, action: 1, asset: 1022780.2240625966, reward: -0.14820074580912776, Trade: 13
# Price: 23.366140365600582,State:[1, 0.03119957360046821]
#
# Step 31, action: 1, asset: 1021837.8278071035, reward: -0.14856438217276413, Trade: 13
# Price: 23.3446102142334,State:[1, 0.030249400291483042]
#
# Step 32, action: 0, asset: 1020816.0108734163, reward: 2.749071549348237, Trade: 14
# Price: 23.258468627929688,State:[0, 0]
#
# Step 33, action: 0, asset: 1021055.6713290438, reward: 2.7487079129846004, Trade: 15
# Price: 23.22974967956543,State:[-1, 0.0012347738289945065]
#
# Step 34, action: 1, asset: 1011288.395041965, reward: 2.748344276620964, Trade: 15
# Price: 23.452289581298828,State:[-1, -0.008333349734659379]
#
# Step 35, action: 2, asset: 1010259.0740522419, reward: 1.7943683769478604, Trade: 16
# Price: 23.39486122131348,State:[0, 0]
#
# Step 36, action: 0, asset: 1017618.8253790127, reward: 1.794004740584224, Trade: 17
# Price: 23.20103073120117,State:[-1, 0.008285173751564123]
#
# Step 37, action: 2, asset: 1016616.9584699781, reward: 2.5304532357200986, Trade: 18
# Price: 23.416400909423828,State:[0, 0]
#
# Step 38, action: 2, asset: 1019648.4532877161, reward: 2.530089599356462, Trade: 19
# Price: 23.50971412658692,State:[1, 0.003984951296488015]
#
# Step 39, action: 0, asset: 1018628.8134763319, reward: 2.8324707360124544, Trade: 20
# Price: 23.402034759521484,State:[0, 0]
#
# Step 40, action: 1, asset: 1018628.8134763319, reward: 2.832107099648818, Trade: 20
# Price: 23.466642379760746,State:[0, 0]
#
# Step 41, action: 0, asset: 1028204.5457254908, reward: 2.8317434632851812, Trade: 21
# Price: 23.22257232666016,State:[-1, 0.01040072325434549]
#
# Step 42, action: 2, asset: 1027196.5235285076, reward: 3.790012486716936, Trade: 22
# Price: 23.244102478027344,State:[0, 0]
#
# Step 43, action: 2, asset: 1035044.2593821071, reward: 3.7896488503532995, Trade: 23
# Price: 23.44511032104492,State:[1, 0.008647692170845822]
#
# Step 44, action: 1, asset: 1031557.972759106, reward: 3.789285213989663, Trade: 23
# Price: 23.366140365600582,State:[1, 0.005250273168800668]
#
# Step 45, action: 0, asset: 1030526.4277603858, reward: 4.22452774002359, Trade: 24
# Price: 23.409215927124023,State:[0, 0]
#
# Step 46, action: 2, asset: 1040862.1090724932, reward: 4.2241641036599535, Trade: 25
# Price: 23.667644500732425,State:[1, 0.011039608264237666]
#
# Step 47, action: 1, asset: 1049701.3609416946, reward: 4.223800467296317, Trade: 25
# Price: 23.868637084960938,State:[1, 0.019625653386561526]
#
# Step 48, action: 2, asset: 1056962.3846805561, reward: 4.2216186491144985, Trade: 25
# Price: 24.03374290466309,State:[1, 0.026678679861952714]
#
# Step 49, action: 2, asset: 1084112.1864727004, reward: 4.21943683093268, Trade: 25
# Price: 24.651092529296875,State:[1, 0.05305075599451836]
#
# Step 50, action: 2, asset: 1104317.0295589436, reward: 4.2172550127508615, Trade: 25
# Price: 25.11052322387696,State:[1, 0.07267681677375837]
#
# Step 51, action: 2, asset: 1109368.6177967056, reward: 4.215073194569043, Trade: 25
# Price: 25.22538948059082,State:[1, 0.077583698621978]
#
# Step 52, action: 0, asset: 1108259.2556181285, reward: 12.090941393783952, Trade: 26
# Price: 25.132061004638672,State:[0, 0]
#
# Step 53, action: 1, asset: 1108259.2556181285, reward: 12.090577757420316, Trade: 26
# Price: 25.246919631958008,State:[0, 0]
#
# Step 54, action: 1, asset: 1108259.2556181285, reward: 12.09021412105668, Trade: 26
# Price: 25.25409889221192,State:[0, 0]
#
# Step 55, action: 1, asset: 1108259.2556181285, reward: 12.089850484693045, Trade: 26
# Price: 25.31870651245117,State:[0, 0]
#
# Step 56, action: 0, asset: 1093010.8144541727, reward: 12.08948684832941, Trade: 27
# Price: 25.641748428344727,State:[-1, -0.012759021308402785]
#
# Step 57, action: 1, asset: 1071958.5302592264, reward: 12.089123211965774, Trade: 27
# Price: 26.12270164489746,State:[-1, -0.03175498448354408]
#
# Step 58, action: 0, asset: 1068816.358414744, reward: 12.086941393783956, Trade: 27
# Price: 26.194486618041992,State:[-1, -0.034590238848107635]
#
# Step 59, action: 2, asset: 1067669.7733464993, reward: 8.138454572403687, Trade: 28
# Price: 25.333065032958984,State:[0, 0]
#
# Step 60, action: 2, asset: 1063580.5716698142, reward: 8.13809093604005, Trade: 29
# Price: 25.261274337768555,State:[1, -0.0028338732441979264]
#
# Step 61, action: 2, asset: 1074763.538604018, reward: 8.135909117858233, Trade: 29
# Price: 25.52688407897949,State:[1, 0.007650832845071953]
#
# Step 62, action: 2, asset: 1064789.645247695, reward: 8.133727299676416, Trade: 29
# Price: 25.28999137878418,State:[1, -0.0017002938301687864]
#
# Step 63, action: 1, asset: 1084132.5739510031, reward: 8.13336366331278, Trade: 29
# Price: 25.74941062927246,State:[1, 0.01643486864979815]
#
# Step 64, action: 2, asset: 1070532.1023018332, reward: 8.131181845130962, Trade: 29
# Price: 25.426382064819336,State:[1, 0.003683606059469824]
#
# Step 65, action: 1, asset: 1065091.9939472647, reward: 8.130818208767327, Trade: 29
# Price: 25.29717254638672,State:[1, -0.0014168236857864391]
#
# Step 66, action: 0, asset: 1064026.9070915442, reward: 7.872827750616431, Trade: 30
# Price: 24.378318786621094,State:[0, 0]
#
# Step 67, action: 2, asset: 1046375.1144880136, reward: 7.872464114252795, Trade: 31
# Price: 23.99785804748535,State:[1, -0.015606520796854095]
#
# Step 68, action: 1, asset: 1104592.809468635, reward: 7.872100477889158, Trade: 31
# Price: 25.333065032958984,State:[1, 0.03916374441956427]
#
# Step 69, action: 0, asset: 1103488.2371670678, reward: 11.924164194651286, Trade: 32
# Price: 25.577131271362305,State:[0, 0]
#
# Step 70, action: 1, asset: 1103488.2371670678, reward: 11.92380055828765, Trade: 32
# Price: 25.763771057128903,State:[0, 0]
#
# Step 71, action: 2, asset: 1083342.4351934046, reward: 11.923436921924015, Trade: 33
# Price: 25.31870651245117,State:[1, -0.01727482144173864]
#
# Step 72, action: 0, asset: 1082259.0983791498, reward: 9.910397430367814, Trade: 34
# Price: 25.26845932006836,State:[0, 0]
#
# Step 73, action: 1, asset: 1082259.0983791498, reward: 9.910033794004178, Trade: 34
# Price: 25.54841995239257,State:[0, 0]
#
# Step 74, action: 0, asset: 1107328.8739938308, reward: 9.909670157640543, Trade: 35
# Price: 24.931058883666992,State:[-1, 0.024164354190043147]
#
# Step 75, action: 2, asset: 1106272.7694084598, reward: 12.41889928596824, Trade: 36
# Price: 24.67982292175293,State:[0, 0]
#
# Step 76, action: 1, asset: 1106272.7694084598, reward: 12.418535649604605, Trade: 36
# Price: 23.610219955444336,State:[0, 0]
#
# Step 77, action: 0, asset: 1100794.0536558107, reward: 12.41817201324097, Trade: 37
# Price: 23.70353889465332,State:[-1, -0.003952480721699736]
#
# Step 78, action: 0, asset: 1094067.1731912568, reward: 12.415990195059152, Trade: 37
# Price: 23.84710693359375,State:[-1, -0.010033238936208555]
#
# Step 79, action: 1, asset: 1068504.294601627, reward: 12.415626558695516, Trade: 37
# Price: 24.39268112182617,State:[-1, -0.03314078258730513]
#
# Step 80, action: 2, asset: 1067361.3755276639, reward: 8.634749219853504, Trade: 38
# Price: 24.435741424560547,State:[0, 0]
#
# Step 81, action: 2, asset: 1082270.5003850404, reward: 8.634385583489868, Trade: 39
# Price: 24.801847457885746,State:[1, 0.01498239922269029]
#
# Step 82, action: 1, asset: 1060657.243884796, reward: 8.634021947126232, Trade: 39
# Price: 24.30653953552246,State:[1, -0.00528741431631885]
#
# Step 83, action: 0, asset: 1059596.603725624, reward: 7.963808931838805, Trade: 40
# Price: 24.245811462402344,State:[0, 0]
#
# Step 84, action: 2, asset: 1068953.0372001573, reward: 7.963445295475168, Trade: 41
# Price: 24.4843692779541,State:[1, 0.009839135139761535]
#
# Step 85, action: 1, asset: 1055066.3444473192, reward: 7.963081659111531, Trade: 41
# Price: 24.166290283203125,State:[1, -0.003279790380393388]
#
# Step 86, action: 2, asset: 1014669.9040176317, reward: 7.960899840929713, Trade: 41
# Price: 23.240997314453125,State:[1, -0.041442793098815045]
#
# Step 87, action: 0, asset: 1013655.2485568773, reward: 3.4722530513739356, Trade: 42
# Price: 22.80725860595703,State:[0, 0]
#
# Step 88, action: 0, asset: 1004288.5165279771, reward: 3.471889415010299, Trade: 43
# Price: 22.99520492553711,State:[-1, -0.008240636142521351]
#
# Step 89, action: 2, asset: 1003266.5176402666, reward: 2.5340172671339127, Trade: 44
# Price: 22.95906639099121,State:[0, 0]
#
# Step 90, action: 2, asset: 1032558.567209202, reward: 2.533653630770276, Trade: 45
# Price: 23.65303039550781,State:[1, 0.030226142156586144]
#
# Step 91, action: 1, asset: 1016780.7362804, reward: 2.5332899944066396, Trade: 45
# Price: 23.29160118103028,State:[1, 0.014483811509406586]
#
# Step 92, action: 2, asset: 1011731.3108195842, reward: 2.531108176224821, Trade: 45
# Price: 23.175931930541992,State:[1, 0.00944574730773362]
#
# Step 93, action: 2, asset: 1018042.3432750285, reward: 2.5289263580430026, Trade: 45
# Price: 23.32050132751465,State:[1, 0.015742579875341]
#
# Step 94, action: 1, asset: 1014255.9402865947, reward: 2.528562721679366, Trade: 45
# Price: 23.2337646484375,State:[1, 0.011964696332516178]
#
# Step 95, action: 2, asset: 1006997.7866878093, reward: 2.5263809034975475, Trade: 45
# Price: 23.0674991607666,State:[1, 0.004722873653866699]
#
# Step 96, action: 0, asset: 1005990.7980794451, reward: 2.898670819474988, Trade: 46
# Price: 23.08918571472168,State:[0, 0]
#
# Step 97, action: 0, asset: 1021047.7196284276, reward: 2.8983071831113514, Trade: 47
# Price: 22.720508575439453,State:[-1, 0.01596752453020278]
#
# Step 98, action: 2, asset: 1020057.8097903044, reward: 4.405241991074123, Trade: 48
# Price: 22.12773895263672,State:[0, 0]
#
# Step 99, action: 1, asset: 1020057.8097903044, reward: 4.404878354710487, Trade: 48
# Price: 22.048215866088867,State:[0, 0]
#
# Step 100, action: 0, asset: 1046796.1887797911, reward: 4.40451471834685, Trade: 49
# Price: 21.44821548461914,State:[-1, 0.02721310355059403]
#
# Step 101, action: 2, asset: 1045803.9085386108, reward: 7.0807648226967235, Trade: 50
# Price: 21.831348419189453,State:[0, 0]
#
# Step 102, action: 0, asset: 1065881.6991053564, reward: 7.080401186333087, Trade: 51
# Price: 21.39038276672364,State:[-1, 0.020198736422447072]
#
# Step 103, action: 2, asset: 1064857.035599682, reward: 9.089928964409012, Trade: 52
# Price: 20.6964111328125,State:[0, 0]
#
# Step 104, action: 0, asset: 1084620.6501896016, reward: 9.089565328045376, Trade: 53
# Price: 20.29158973693848,State:[-1, 0.019559980388687226]
#
# Step 105, action: 2, asset: 1083576.6276060464, reward: 11.067645997237648, Trade: 54
# Price: 20.18314743041992,State:[0, 0]
#
# Step 106, action: 2, asset: 1076291.376619936, reward: 11.067282360874012, Trade: 55
# Price: 20.067495346069336,State:[1, -0.00573013127656552]
#
# Step 107, action: 2, asset: 1060007.6650472889, reward: 11.065100542692194, Trade: 55
# Price: 19.76388168334961,State:[1, -0.020773060718884406]
#
# Step 108, action: 1, asset: 1085984.0011888752, reward: 11.064736906328559, Trade: 55
# Price: 20.24821662902832,State:[1, 0.003223937140266253]
#
# Step 109, action: 1, asset: 1091412.0755411396, reward: 11.064373269964923, Trade: 55
# Price: 20.349424362182617,State:[1, 0.008238404457774795]
#
# Step 110, action: 2, asset: 1095676.6257578144, reward: 11.062191451783105, Trade: 55
# Price: 20.428937911987305,State:[1, 0.012178005557098137]
#
# Step 111, action: 0, asset: 1094580.9605307807, reward: 12.270509382506471, Trade: 56
# Price: 20.46507835388184,State:[0, 0]
#
# Step 112, action: 2, asset: 1106233.7716604555, reward: 12.270145746142836, Trade: 57
# Price: 20.70363426208496,State:[1, 0.011656730752651612]
#
# Step 113, action: 1, asset: 1092328.8585764254, reward: 12.2697821097792, Trade: 57
# Price: 20.44339370727539,State:[1, -0.0010595926500489572]
#
# Step 114, action: 1, asset: 1094646.1232820833, reward: 12.269418473415564, Trade: 57
# Price: 20.48676300048828,State:[1, 0.001059592650048513]
#
# Step 115, action: 1, asset: 1047138.0184427586, reward: 12.269054837051929, Trade: 57
# Price: 19.59761428833008,State:[1, -0.04238752720862249]
#
# Step 116, action: 1, asset: 1045593.0394235933, reward: 12.268691200688293, Trade: 57
# Price: 19.56869888305664,State:[1, -0.04380044167557129]
#
# Step 117, action: 0, asset: 1044547.4642735727, reward: 7.374324898756467, Trade: 58
# Price: 20.190380096435547,State:[0, 0]
#
# Step 118, action: 0, asset: 1060705.500579351, reward: 7.373961262392831, Trade: 59
# Price: 19.857860565185547,State:[-1, 0.01646920611012681]
#
# Step 119, action: 0, asset: 1032657.5907206475, reward: 7.371779444211012, Trade: 59
# Price: 20.40001678466797,State:[-1, -0.010382998597903148]
#
# Step 120, action: 0, asset: 1031535.5598635613, reward: 7.3695976260291935, Trade: 59
# Price: 20.42170524597168,State:[-1, -0.011457196369323075]
#
# Step 121, action: 1, asset: 1003860.5419764458, reward: 7.369233989665557, Trade: 59
# Price: 20.956653594970703,State:[-1, -0.037952405793016064]
#
# Step 122, action: 2, asset: 1002776.3704593638, reward: 3.296213884271941, Trade: 60
# Price: 20.660261154174805,State:[0, 0]
#
# Step 123, action: 1, asset: 1002776.3704593638, reward: 3.2958502479083043, Trade: 60
# Price: 20.298809051513672,State:[0, 0]
#
# Step 124, action: 1, asset: 1002776.3704593638, reward: 3.2954866115446677, Trade: 60
# Price: 20.27712821960449,State:[0, 0]
#
# Step 125, action: 2, asset: 1018202.7710612852, reward: 3.295122975181031, Trade: 61
# Price: 20.609655380249023,State:[1, 0.016399125016284932]
#
# Step 126, action: 1, asset: 1039988.6150783137, reward: 3.2947593388173946, Trade: 61
# Price: 21.05062866210937,State:[1, 0.038146449247040914]
#
# Step 127, action: 0, asset: 1038948.6298198908, reward: 7.011798762762591, Trade: 62
# Price: 20.566286087036133,State:[0, 0]
#
# Step 128, action: 2, asset: 1047760.9230820634, reward: 7.011435126398954, Trade: 63
# Price: 20.76147079467773,State:[1, 0.00949051796788103]
#
# Step 129, action: 1, asset: 1047395.8231026633, reward: 7.0110714900353175, Trade: 63
# Price: 20.75423622131348,State:[1, 0.009138749382457512]
#
# Step 130, action: 1, asset: 1046301.3894707661, reward: 7.010707853671681, Trade: 63
# Price: 20.7325496673584,State:[1, 0.008084278299866243]
#
# Step 131, action: 1, asset: 1047031.011892031, reward: 7.010344217308044, Trade: 63
# Price: 20.74700736999512,State:[1, 0.00878725902159383]
#
# Step 132, action: 1, asset: 1030249.7924591999, reward: 7.009980580944408, Trade: 63
# Price: 20.41448211669922,State:[1, -0.007381204836618638]
#
# Step 133, action: 0, asset: 1029219.5552046986, reward: 6.140499302428369, Trade: 64
# Price: 20.031354904174805,State:[0, 0]
#
# Step 134, action: 1, asset: 1029219.5552046986, reward: 6.140135666064732, Trade: 64
# Price: 19.959060668945312,State:[0, 0]
#
# Step 135, action: 2, asset: 1017019.2814731924, reward: 6.139772029701096, Trade: 65
# Price: 19.742185592651367,State:[1, -0.010865996145368984]
#
# Step 136, action: 0, asset: 1016002.2825245726, reward: 4.9204982304548475, Trade: 66
# Price: 19.79279518127441,State:[0, 0]
#
# Step 137, action: 1, asset: 1016002.2825245726, reward: 4.920134594091211, Trade: 66
# Price: 20.46507835388184,State:[0, 0]
#
# Step 138, action: 0, asset: 995247.5277642598, reward: 4.919770957727574, Trade: 67
# Price: 20.8626766204834,State:[-1, -0.019428133121520252]
#
# Step 139, action: 1, asset: 1018216.2753133168, reward: 4.919407321363938, Trade: 67
# Price: 20.40001678466797,State:[-1, 0.0031791507507973327]
#
# Step 140, action: 1, asset: 1020010.6569318168, reward: 4.919043685000301, Trade: 67
# Price: 20.36387252807617,State:[-1, 0.0049452938344833886]
#
# Step 141, action: 2, asset: 1018999.6924801606, reward: 5.320019925683309, Trade: 68
# Price: 20.118099212646484,State:[0, 0]
#
# Step 142, action: 0, asset: 1019811.8037802472, reward: 5.319656289319672, Trade: 69
# Price: 20.08194732666016,State:[-1, 0.001796983184355616]
#
# Step 143, action: 0, asset: 999673.6447912948, reward: 5.317474471137854, Trade: 69
# Price: 20.479541778564453,State:[-1, -0.017966039539697665]
#
# Step 144, action: 1, asset: 997843.0348021286, reward: 5.317110834774217, Trade: 69
# Price: 20.515684127807617,State:[-1, -0.01976254868607108]
#
# Step 145, action: 2, asset: 996803.9154010552, reward: 3.1990676630121113, Trade: 70
# Price: 20.775924682617188,State:[0, 0]
#
# Step 146, action: 2, asset: 969822.2120543452, reward: 3.1987040266484748, Trade: 71
# Price: 20.233760833740234,State:[1, -0.02609577466030044]
#
# Step 147, action: 0, asset: 968852.407897584, reward: 0.5027686469414867, Trade: 72
# Price: 20.281871795654297,State:[0, 0]
#
# Step 148, action: 0, asset: 938281.9588012896, reward: 0.5024050105778504, Trade: 73
# Price: 20.901554107666016,State:[-1, -0.030553507006414238]
#
# Step 149, action: 2, asset: 937283.5124631205, reward: -2.5579636958514698, Trade: 74
# Price: 21.44104385375977,State:[0, 0]
#
# Step 150, action: 0, asset: 922323.5037210779, reward: -2.5583273322151063, Trade: 75
# Price: 21.76182746887207,State:[-1, -0.014961193927881089]
#
# Step 151, action: 2, asset: 921372.2071951038, reward: -4.056094116278078, Trade: 76
# Price: 21.38272476196289,State:[0, 0]
#
# Step 152, action: 0, asset: 916681.3977624368, reward: -4.056457752641714, Trade: 77
# Price: 21.47020530700684,State:[-1, -0.00409117855735408]
#
# Step 153, action: 2, asset: 915756.2680859632, reward: -4.526279277192574, Trade: 78
# Price: 21.44104385375977,State:[0, 0]
#
# Step 154, action: 0, asset: 906433.1466255828, reward: -4.526642913556211, Trade: 79
# Price: 21.63789176940918,State:[-1, -0.009180892357295134]
#
# Step 155, action: 1, asset: 896780.7752571746, reward: -4.5270065499198475, Trade: 79
# Price: 21.863889694213867,State:[-1, -0.019721327158236823]
#
# Step 156, action: 1, asset: 897403.4773598358, reward: -4.527370186283484, Trade: 79
# Price: 21.84930992126465,State:[-1, -0.019041333541850225]
#
# Step 157, action: 0, asset: 898337.6934395477, reward: -4.529552004465303, Trade: 79
# Price: 21.827436447143555,State:[-1, -0.018021165201620004]
#
# Step 158, action: 1, asset: 898026.4238510772, reward: -4.529915640828939, Trade: 79
# Price: 21.83472442626953,State:[-1, -0.018361073051988086]
#
# Step 159, action: 1, asset: 899894.6116219208, reward: -4.530279277192576, Trade: 79
# Price: 21.79098320007324,State:[-1, -0.016321003245003185]
#
# Step 160, action: 2, asset: 898963.9187294458, reward: -6.118303150908552, Trade: 80
# Price: 22.34505081176757,State:[0, 0]
#
# Step 161, action: 2, asset: 905684.2849861982, reward: -6.118666787272189, Trade: 81
# Price: 22.534610748291016,State:[1, 0.00848330747243664]
#
# Step 162, action: 1, asset: 904804.9600922468, reward: -6.1190304236358255, Trade: 81
# Price: 22.512731552124023,State:[1, 0.007504155697338977]
#
# Step 163, action: 1, asset: 903633.0379425884, reward: -6.119394059999462, Trade: 81
# Price: 22.483572006225582,State:[1, 0.006199189056444787]
#
# Step 164, action: 1, asset: 927073.0140625837, reward: -6.119757696363099, Trade: 81
# Price: 23.066801071166992,State:[1, 0.03230022905203356]
#
# Step 165, action: 1, asset: 925900.9386002424, reward: -6.120121332726735, Trade: 81
# Price: 23.03763771057129,State:[1, 0.03099509169336878]
#
# Step 166, action: 2, asset: 932054.0664803389, reward: -6.122303150908554, Trade: 81
# Price: 23.19073867797852,State:[1, 0.03784676407026044]
#
# Step 167, action: 0, asset: 931122.030692871, reward: -2.8170508317171934, Trade: 82
# Price: 23.19073867797852,State:[0, 0]
#
# Step 168, action: 0, asset: 933996.1851005629, reward: -2.81741446808083, Trade: 83
# Price: 23.095962524414062,State:[-1, 0.00408681046690651]
#
# Step 169, action: 1, asset: 929898.0804328993, reward: -2.8177781044444665, Trade: 83
# Price: 23.19803237915039,State:[-1, -0.0003145092216831902]
#
# Step 170, action: 0, asset: 934288.8740425184, reward: -2.819959922626285, Trade: 83
# Price: 23.088672637939453,State:[-1, 0.004401155196319229]
#
# Step 171, action: 0, asset: 932239.9748687819, reward: -2.8221417408081035, Trade: 83
# Price: 23.13970375061035,State:[-1, 0.002200659844295072]
#
# Step 172, action: 0, asset: 932239.9748687819, reward: -2.824323558989922, Trade: 83
# Price: 23.13970375061035,State:[-1, 0.002200659844295072]
#
# Step 173, action: 2, asset: 931310.9157631949, reward: -2.712687872529064, Trade: 84
# Price: 23.13970375061035,State:[0, 0]
#
# Step 174, action: 2, asset: 934777.5648093624, reward: -2.7130515088927005, Trade: 85
# Price: 23.24906349182129,State:[1, 0.004726064879203795]
#
# Step 175, action: 2, asset: 931846.5968432827, reward: -2.715233327074519, Trade: 85
# Price: 23.176166534423828,State:[1, 0.0015757670973861604]
#
# Step 176, action: 1, asset: 920707.6302009029, reward: -2.7155969634381556, Trade: 85
# Price: 22.899126052856445,State:[1, -0.010396749256029736]
#
# Step 177, action: 2, asset: 908689.6569171353, reward: -2.717778781619974, Trade: 85
# Price: 22.60022354125977,State:[1, -0.02331404996212849]
#
# Step 178, action: 0, asset: 907780.9697292119, reward: -4.978099214511847, Trade: 86
# Price: 22.46170425415039,State:[0, 0]
#
# Step 179, action: 2, asset: 903636.098196108, reward: -4.978462850875483, Trade: 87
# Price: 22.38150405883789,State:[1, -0.003570530285905704]
#
# Step 180, action: 1, asset: 898632.5492878744, reward: -4.97882648723912, Trade: 87
# Price: 22.2575740814209,State:[1, -0.009087920062511468]
#
# Step 181, action: 2, asset: 895100.2247258016, reward: -4.981008305420938, Trade: 87
# Price: 22.17008399963379,State:[1, -0.01298299769318334]
#
# Step 182, action: 0, asset: 894205.1297544003, reward: -6.248269054510029, Trade: 88
# Price: 22.403377532958984,State:[0, 0]
#
# Step 183, action: 1, asset: 894205.1297544003, reward: -6.248632690873666, Trade: 88
# Price: 23.19073867797852,State:[0, 0]
#
# Step 184, action: 2, asset: 884044.5491698361, reward: -6.248996327237302, Trade: 89
# Price: 22.95015525817871,State:[1, -0.010374116285837065]
#
# Step 185, action: 1, asset: 881798.0242827511, reward: -6.249359963600939, Trade: 89
# Price: 22.891834259033203,State:[1, -0.01288895636727394]
#
# Step 186, action: 1, asset: 878709.0801146603, reward: -6.249723599964575, Trade: 89
# Price: 22.811643600463867,State:[1, -0.01634683063694875]
#
# Step 187, action: 0, asset: 877830.3756031705, reward: -7.798231926063632, Trade: 90
# Price: 22.527315139770508,State:[0, 0]
#
# Step 188, action: 1, asset: 877830.3756031705, reward: -7.798595562427269, Trade: 90
# Price: 22.738739013671875,State:[0, 0]
#
# Step 189, action: 0, asset: 885114.56523551, reward: -7.7989591987909055, Trade: 91
# Price: 22.527315139770508,State:[-1, 0.0092979594767435]
#
# Step 190, action: 0, asset: 890462.2495807554, reward: -7.801141016972724, Trade: 91
# Price: 22.388792037963867,State:[-1, 0.015389902469859829]
#
# Step 191, action: 2, asset: 889597.9302641299, reward: -6.536966285278144, Trade: 92
# Price: 22.97203063964844,State:[0, 0]
#
# Step 192, action: 1, asset: 889597.9302641299, reward: -6.53732992164178, Trade: 92
# Price: 22.935577392578125,State:[0, 0]
#
# Step 193, action: 1, asset: 889597.9302641299, reward: -6.537693558005417, Trade: 92
# Price: 23.28551483154297,State:[0, 0]
#
# Step 194, action: 1, asset: 889597.9302641299, reward: -6.5380571943690535, Trade: 92
# Price: 23.270931243896484,State:[0, 0]
#
# Step 195, action: 2, asset: 876737.5888665968, reward: -6.53842083073269, Trade: 93
# Price: 22.95744705200196,State:[1, -0.01347106347438265]
#
# Step 196, action: 0, asset: 875860.8669211279, reward: -7.8236214420692205, Trade: 94
# Price: 22.94286155700684,State:[0, 0]
#
# Step 197, action: 1, asset: 875860.8669211279, reward: -7.823985078432857, Trade: 94
# Price: 23.095962524414062,State:[0, 0]
#
# Step 198, action: 0, asset: 874432.0553500217, reward: -7.824348714796494, Trade: 95
# Price: 23.11054420471192,State:[-1, -0.0006313519205984885]
#
# Step 199, action: 1, asset: 881620.1856104895, reward: -7.82471235116013, Trade: 95
# Price: 22.92099380493164,State:[-1, 0.007575727545343414]
#
# Step 200, action: 2, asset: 880750.9756834189, reward: -7.24848060220958, Trade: 96
# Price: 22.88454818725586,State:[0, 0]
#
# Step 201, action: 1, asset: 880750.9756834189, reward: -7.248844238573216, Trade: 96
# Price: 23.11783790588379,State:[0, 0]
#
# Step 202, action: 2, asset: 855453.4975525063, reward: -7.249207874936853, Trade: 97
# Price: 22.476282119750977,State:[1, -0.02775154790619616]
#
# Step 203, action: 1, asset: 856563.3824630898, reward: -7.2495715113004895, Trade: 97
# Price: 22.505443572998047,State:[1, -0.02649012141095941]
#
# Step 204, action: 2, asset: 866274.9661728066, reward: -7.251753329482308, Trade: 97
# Price: 22.760608673095703,State:[1, -0.015452536445770604]
#
# Step 205, action: 1, asset: 862667.7131744545, reward: -7.252116965845945, Trade: 97
# Price: 22.665830612182617,State:[1, -0.019552316939904224]
#
# Step 206, action: 0, asset: 861805.0516613548, reward: -9.059086513346209, Trade: 98
# Price: 22.534610748291016,State:[0, 0]
#
# Step 207, action: 2, asset: 867906.9425470323, reward: -9.059450149709845, Trade: 99
# Price: 22.716859817504883,State:[1, 0.008087517962904522]
#
# Step 208, action: 2, asset: 863450.8536130877, reward: -9.061631967891662, Trade: 99
# Price: 22.60022354125977,State:[1, 0.00291164527764165]
#
# Step 209, action: 0, asset: 862587.4120726938, reward: -8.897666082757564, Trade: 100
# Price: 22.37421989440918,State:[0, 0]
#
# Step 210, action: 2, asset: 854821.4415698596, reward: -8.8980297191212, Trade: 101
# Price: 22.19495391845703,State:[1, -0.008012166538013843]
#
# Step 211, action: 0, asset: 853966.6251146442, reward: -9.674299980788485, Trade: 102
# Price: 23.2235164642334,State:[0, 0]
#
# Step 212, action: 2, asset: 900342.500608125, reward: -9.67466361715212, Trade: 103
# Price: 24.509218215942383,State:[1, 0.055362061714000044]
#
# Step 213, action: 2, asset: 903580.9539276746, reward: -9.676845435333938, Trade: 103
# Price: 24.59737777709961,State:[1, 0.059158194883281334]
#
# Step 214, action: 1, asset: 899803.0036141064, reward: -9.677209071697574, Trade: 103
# Price: 24.494531631469727,State:[1, 0.05472966030763793]
#
# Step 215, action: 2, asset: 905470.2443749097, reward: -9.679390889879391, Trade: 103
# Price: 24.6488094329834,State:[1, 0.06137283175634045]
#
# Step 216, action: 0, asset: 904564.7950091985, reward: -4.534628271407896, Trade: 104
# Price: 25.00146102905273,State:[0, 0]
#
# Step 217, action: 0, asset: 895951.786643796, reward: -4.534991907771532, Trade: 105
# Price: 25.214519500732425,State:[-1, -0.008521840840905792]
#
# Step 218, action: 0, asset: 893825.3090208103, reward: -4.537173725953351, Trade: 105
# Price: 25.27329444885254,State:[-1, -0.010872701378688454]
#
# Step 219, action: 1, asset: 889572.3537748386, reward: -4.5375373623169875, Trade: 105
# Price: 25.390844345092773,State:[-1, -0.015574422454254222]
#
# Step 220, action: 2, asset: 888653.7130264333, reward: -6.038553910954033, Trade: 106
# Price: 25.50840187072754,State:[0, 0]
#
# Step 221, action: 0, asset: 885973.6844659606, reward: -6.03891754731767, Trade: 107
# Price: 25.559823989868164,State:[-1, -0.002015889486186806]
#
# Step 222, action: 1, asset: 877527.628277377, reward: -6.0392811836813065, Trade: 107
# Price: 25.8022689819336,State:[-1, -0.01152040463747328]
#
# Step 223, action: 2, asset: 876628.7546328534, reward: -7.153277039805855, Trade: 108
# Price: 25.787578582763672,State:[0, 0]
#
# Step 224, action: 0, asset: 873254.4913170958, reward: -7.153640676169491, Trade: 109
# Price: 25.86105155944824,State:[-1, -0.00284916152359016]
#
# Step 225, action: 2, asset: 872375.370730384, reward: -7.491680408145824, Trade: 110
# Price: 25.77288627624512,State:[0, 0]
#
# Step 226, action: 0, asset: 869016.2904406961, reward: -7.492044044509461, Trade: 111
# Price: 25.84635353088379,State:[-1, -0.0028505637223248392]
#
# Step 227, action: 2, asset: 868141.4430663828, reward: -7.82856438180539, Trade: 112
# Price: 25.78023338317871,State:[0, 0]
#
# Step 228, action: 1, asset: 868141.4430663828, reward: -7.828928018169027, Trade: 112
# Price: 25.890439987182617,State:[0, 0]
#
# Step 229, action: 1, asset: 868141.4430663828, reward: -7.829291654532663, Trade: 112
# Price: 25.78023338317871,State:[0, 0]
#
# Step 230, action: 0, asset: 872221.2563809009, reward: -7.8296552908963, Trade: 113
# Price: 25.63329696655273,State:[-1, 0.005699576665657902]
#
# Step 231, action: 1, asset: 872963.604273662, reward: -7.830018927259936, Trade: 113
# Price: 25.611251831054688,State:[-1, 0.006554694428572594]
#
# Step 232, action: 2, asset: 872101.1709795031, reward: -7.3475974144170255, Trade: 114
# Price: 25.758190155029297,State:[0, 0]
#
# Step 233, action: 0, asset: 865010.4301033625, reward: -7.347961050780662, Trade: 115
# Price: 25.941864013671875,State:[-1, -0.0071306973641047655]
#
# Step 234, action: 2, asset: 864132.1164134517, reward: -8.058020639341557, Trade: 116
# Price: 25.4716739654541,State:[0, 0]
#
# Step 235, action: 1, asset: 864132.1164134517, reward: -8.058384275705192, Trade: 116
# Price: 25.390844345092773,State:[0, 0]
#
# Step 236, action: 2, asset: 859772.0572954003, reward: -8.058747912068828, Trade: 117
# Price: 25.287994384765625,State:[1, -0.0040506711367802595]
#
# Step 237, action: 1, asset: 858772.750444967, reward: -8.059111548432464, Trade: 117
# Price: 25.258602142333984,State:[1, -0.005208263300009008]
#
# Step 238, action: 1, asset: 859022.4150377099, reward: -8.0594751847961, Trade: 117
# Price: 25.265945434570312,State:[1, -0.004919053058060285]
#
# Step 239, action: 0, asset: 858163.39815888, reward: -8.570384314928042, Trade: 118
# Price: 25.611251831054688,State:[0, 0]
#
# Step 240, action: 1, asset: 858163.39815888, reward: -8.570747951291677, Trade: 118
# Price: 25.589204788208008,State:[0, 0]
#
# Step 241, action: 0, asset: 846464.1570441339, reward: -8.571111587655313, Trade: 119
# Price: 25.912471771240234,State:[-1, -0.012632943684955489]
#
# Step 242, action: 1, asset: 831188.3289191339, reward: -8.571475224018949, Trade: 119
# Price: 26.367977142333984,State:[-1, -0.030433628577815286]
#
# Step 243, action: 0, asset: 827985.0335089776, reward: -8.573657042200766, Trade: 119
# Price: 26.4634952545166,State:[-1, -0.03416637889081575]
#
# Step 244, action: 1, asset: 837593.9602667902, reward: -8.574020678564402, Trade: 119
# Price: 26.17696952819824,State:[-1, -0.022969246010375644]
#
# Step 245, action: 1, asset: 816405.0940558526, reward: -8.574384314928038, Trade: 119
# Price: 26.808794021606445,State:[-1, -0.04766030220526618]
#
# Step 246, action: 0, asset: 815912.3088996024, reward: -8.576566133109855, Trade: 119
# Price: 26.82348823547364,State:[-1, -0.048234537082387785]
#
# Step 247, action: 2, asset: 815012.7563981377, reward: -12.806177988369988, Trade: 120
# Price: 26.92635726928711,State:[0, 0]
#
# Step 248, action: 1, asset: 815012.7563981377, reward: -12.806541624733624, Trade: 120
# Price: 27.301034927368164,State:[0, 0]
#
# Step 249, action: 2, asset: 819895.3828127992, reward: -12.80690526109726, Trade: 121
# Price: 27.492061614990234,State:[1, 0.006997049310778047]
#
# Step 250, action: 0, asset: 819075.514551317, reward: -12.319575935782579, Trade: 122
# Price: 27.90348243713379,State:[0, 0]
#
# Step 251, action: 0, asset: 845860.056452461, reward: -12.319939572146215, Trade: 123
# Price: 26.96308135986328,State:[-1, 0.0337019251768742]
#
# Step 252, action: 1, asset: 844350.5510165176, reward: -12.32030320850985, Trade: 123
# Price: 27.01450729370117,State:[-1, 0.03185893178156063]
#
# Step 253, action: 0, asset: 839605.7592284163, reward: -12.322485026691668, Trade: 123
# Price: 27.1761531829834,State:[-1, 0.026065895387396676]
#
# Step 254, action: 0, asset: 848879.1233107527, reward: -12.324666844873486, Trade: 123
# Price: 26.860227584838867,State:[-1, 0.03738798032272006]
#
# Step 255, action: 1, asset: 845860.056452461, reward: -12.325030481237121, Trade: 123
# Price: 26.96308135986328,State:[-1, 0.0337019251768742]
#
# Step 256, action: 0, asset: 843703.4601542433, reward: -12.327212299418939, Trade: 123
# Price: 27.03655242919922,State:[-1, 0.03106888216865955]
#
# Step 257, action: 2, asset: 842909.8562307891, reward: -9.862236675837648, Trade: 124
# Price: 26.88961410522461,State:[0, 0]
#
# Step 258, action: 0, asset: 829170.1389856986, reward: -9.862600312201284, Trade: 125
# Price: 27.301034927368164,State:[-1, -0.015300361713395327]
#
# Step 259, action: 0, asset: 828940.128172939, reward: -9.864782130383102, Trade: 125
# Price: 27.3083724975586,State:[-1, -0.015573239195449284]
#
# Step 260, action: 1, asset: 825715.372990673, reward: -9.865145766746737, Trade: 125
# Price: 27.411245346069336,State:[-1, -0.019398985749794484]
#
# Step 261, action: 2, asset: 824856.1126828098, reward: -11.58659288457265, Trade: 126
# Price: 27.536142349243164,State:[0, 0]
#
# Step 262, action: 0, asset: 821830.6701952934, reward: -11.586956520936285, Trade: 127
# Price: 27.60960578918457,State:[-1, -0.002667891493647323]
#
# Step 263, action: 0, asset: 819409.647455883, reward: -11.589138339118103, Trade: 127
# Price: 27.690427780151367,State:[-1, -0.005603015446077775]
#
# Step 264, action: 2, asset: 818580.1806917286, reward: -12.134610660182698, Trade: 128
# Price: 27.815332412719727,State:[0, 0]
#
# Step 265, action: 2, asset: 824673.9122366906, reward: -12.134974296546334, Trade: 129
# Price: 28.050424575805664,State:[1, 0.008451891194312333]
#
# Step 266, action: 1, asset: 831153.2793974878, reward: -12.13533793290997, Trade: 129
# Price: 28.27081871032715,State:[1, 0.01637536775937032]
#
# Step 267, action: 1, asset: 822729.9899401668, reward: -12.135701569273605, Trade: 129
# Price: 27.98430252075196,State:[1, 0.0060747110811074645]
#
# Step 268, action: 1, asset: 805666.7966132165, reward: -12.136065205637241, Trade: 129
# Price: 27.403902053833008,State:[1, -0.014791495308485891]
#
# Step 269, action: 1, asset: 802210.3864722253, reward: -12.136428842000877, Trade: 129
# Price: 27.286333084106445,State:[1, -0.01901826376776916]
#
# Step 270, action: 1, asset: 800914.6812624932, reward: -12.136792478364512, Trade: 129
# Price: 27.242259979248047,State:[1, -0.02060275336524897]
#
# Step 271, action: 0, asset: 800113.7860613633, reward: -13.902021282004535, Trade: 130
# Price: 27.52879524230957,State:[0, 0]
#
# Step 272, action: 0, asset: 814474.4349755326, reward: -13.90238491836817, Trade: 131
# Price: 27.00716209411621,State:[-1, 0.01894863700361471]
#
# Step 273, action: 0, asset: 816609.6872643509, reward: -13.904566736549988, Trade: 131
# Price: 26.93369483947754,State:[-1, 0.02161737909683059]
#
# Step 274, action: 2, asset: 815826.8863575364, reward: -12.25361065280406, Trade: 132
# Price: 27.58756828308105,State:[0, 0]
#
# Step 275, action: 1, asset: 815826.8863575364, reward: -12.253974289167695, Trade: 132
# Price: 27.34512710571289,State:[0, 0]
#
# Step 276, action: 1, asset: 815826.8863575364, reward: -12.254337925531331, Trade: 132
# Price: 27.087980270385746,State:[0, 0]
#
# Step 277, action: 1, asset: 815826.8863575364, reward: -12.254701561894967, Trade: 132
# Price: 27.398651123046875,State:[0, 0]
#
# Step 278, action: 2, asset: 828874.0776400683, reward: -12.255065198258603, Trade: 133
# Price: 27.864669799804688,State:[1, 0.017008818232143286]
#
# Step 279, action: 0, asset: 828045.2151722033, reward: -10.952095925524949, Trade: 134
# Price: 27.420848846435547,State:[0, 0]
#
# Step 280, action: 0, asset: 825653.9115582849, reward: -10.952459561888585, Trade: 135
# Price: 27.472618103027344,State:[-1, -0.001887952370902779]
#
# Step 281, action: 0, asset: 835928.8444425012, reward: -10.954641380070402, Trade: 135
# Price: 27.132354736328125,State:[-1, 0.010520976637998003]
#
# Step 282, action: 1, asset: 844639.982719555, reward: -10.955005016434038, Trade: 135
# Price: 26.8438777923584,State:[-1, 0.021041327250966857]
#
# Step 283, action: 2, asset: 843829.3781418593, reward: -9.294149618570481, Trade: 136
# Price: 26.392656326293945,State:[0, 0]
#
# Step 284, action: 1, asset: 843829.3781418593, reward: -9.294513254934117, Trade: 136
# Price: 26.451828002929688,State:[0, 0]
#
# Step 285, action: 1, asset: 843829.3781418593, reward: -9.294876891297752, Trade: 136
# Price: 26.62936210632324,State:[0, 0]
#
# Step 286, action: 2, asset: 853055.3869548022, reward: -9.295240527661388, Trade: 137
# Price: 26.94743728637696,State:[1, 0.011944528704207702]
#
# Step 287, action: 0, asset: 852202.3388800647, reward: -8.374010181520715, Trade: 138
# Price: 26.8438777923584,State:[0, 0]
#
# Step 288, action: 1, asset: 852202.3388800647, reward: -8.37437381788435, Trade: 138
# Price: 27.087984085083008,State:[0, 0]
#
# Step 289, action: 1, asset: 852202.3388800647, reward: -8.374737454247986, Trade: 138
# Price: 27.63535690307617,State:[0, 0]
#
# Step 290, action: 1, asset: 852202.3388800647, reward: -8.375101090611622, Trade: 138
# Price: 27.679750442504883,State:[0, 0]
#
# Step 291, action: 2, asset: 833832.5943257797, reward: -8.375464726975258, Trade: 139
# Price: 27.11017608642578,State:[1, -0.020577293760729365]
#
# Step 292, action: 0, asset: 832998.7666398895, reward: -10.211050978920412, Trade: 140
# Price: 27.88686180114746,State:[0, 0]
#
# Step 293, action: 2, asset: 829297.3525116241, reward: -10.211414615284047, Trade: 141
# Price: 27.790706634521484,State:[1, -0.003448045438444458]
#
# Step 294, action: 0, asset: 828468.07782565, reward: -10.581632737457008, Trade: 142
# Price: 27.413442611694336,State:[0, 0]
#
# Step 295, action: 1, asset: 828468.07782565, reward: -10.581996373820644, Trade: 142
# Price: 27.783308029174805,State:[0, 0]
#
# Step 296, action: 1, asset: 828468.07782565, reward: -10.58236001018428, Trade: 142
# Price: 27.71673011779785,State:[0, 0]
#
# Step 297, action: 2, asset: 830511.7064932145, reward: -10.582723646547915, Trade: 143
# Price: 27.81288719177246,State:[1, 0.0034692791525527955]
#
# Step 298, action: 1, asset: 828303.2233312882, reward: -10.583087282911551, Trade: 143
# Price: 27.73892593383789,State:[1, 0.0008008093287232843]
#
# Step 299, action: 0, asset: 827474.9390029038, reward: -10.600002645418074, Trade: 144
# Price: 27.98301315307617,State:[0, 0]
#
# Step 300, action: 0, asset: 834739.9090154539, reward: -10.60036628178171, Trade: 145
# Price: 27.70934295654297,State:[-1, 0.00977986877382131]
#
# Step 301, action: 1, asset: 831678.1059797178, reward: -10.600729918145346, Trade: 145
# Price: 27.81288719177246,State:[-1, 0.006079615528644555]
#
# Step 302, action: 2, asset: 830855.6789054571, reward: -10.180273794359985, Trade: 146
# Price: 27.931241989135746,State:[0, 0]
#
# Step 303, action: 0, asset: 832005.0925250901, reward: -10.180637430723621, Trade: 147
# Price: 27.864669799804688,State:[-1, 0.0023834310467452102]
#
# Step 304, action: 2, asset: 831176.2300572252, reward: -10.065861679489577, Trade: 148
# Price: 27.99041557312012,State:[0, 0]
#
# Step 305, action: 1, asset: 831176.2300572252, reward: -10.066225315853213, Trade: 148
# Price: 28.23451232910156,State:[0, 0]
#
# Step 306, action: 0, asset: 839272.7347511946, reward: -10.066588952216849, Trade: 149
# Price: 27.931241989135746,State:[-1, 0.010741121944338627]
#
# Step 307, action: 0, asset: 839055.1592011154, reward: -10.068770770398666, Trade: 149
# Price: 27.93863296508789,State:[-1, 0.010479350964695211]
#
# Step 308, action: 1, asset: 835353.4551262558, reward: -10.069134406762302, Trade: 149
# Price: 28.06437873840332,State:[-1, 0.006025731513091492]
#
# Step 309, action: 0, asset: 838401.9272141159, reward: -10.07131622494412, Trade: 149
# Price: 27.96082305908203,State:[-1, 0.009693430041553541]
#
# Step 310, action: 0, asset: 843627.6146645248, reward: -10.073498043125937, Trade: 149
# Price: 27.783308029174805,State:[-1, 0.015980594765282796]
#
# Step 311, action: 1, asset: 851249.1598496139, reward: -10.073861679489573, Trade: 149
# Price: 27.52440643310547,State:[-1, 0.025150280186145735]
#
# Step 312, action: 2, asset: 850438.8963730362, reward: -8.06484192687769, Trade: 150
# Price: 27.60576438903809,State:[0, 0]
#
# Step 313, action: 0, asset: 846170.0629550943, reward: -8.065205563241326, Trade: 151
# Price: 27.71673011779785,State:[-1, -0.004019657894487549]
#
# Step 314, action: 0, asset: 853462.0212146768, reward: -8.067387381423144, Trade: 151
# Price: 27.480024337768555,State:[-1, 0.004554847657812555]
#
# Step 315, action: 0, asset: 848904.7676441203, reward: -8.069569199604961, Trade: 151
# Price: 27.62795829772949,State:[-1, -0.0008039592158590736]
#
# Step 316, action: 1, asset: 848904.7676441203, reward: -8.069932835968597, Trade: 151
# Price: 27.62795829772949,State:[-1, -0.0008039592158590736]
#
# Step 317, action: 2, asset: 848053.6607608005, reward: -8.223777715778935, Trade: 152
# Price: 27.50960159301757,State:[0, 0]
#
# Step 318, action: 2, asset: 843106.3370009894, reward: -8.22414135214257, Trade: 153
# Price: 27.376462936401367,State:[1, -0.004839715913951936]
#
# Step 319, action: 2, asset: 842651.1120101446, reward: -8.226323170324388, Trade: 153
# Price: 27.36168098449707,State:[1, -0.005377053826837175]
#
# Step 320, action: 2, asset: 841967.1584884161, reward: -8.228504988506206, Trade: 153
# Price: 27.3394718170166,State:[1, -0.006184378040725691]
#
# Step 321, action: 0, asset: 841125.2121143392, reward: -8.836994920450113, Trade: 154
# Price: 27.56878471374512,State:[0, 0]
#
# Step 322, action: 0, asset: 841186.8397096114, reward: -8.837358556813749, Trade: 155
# Price: 27.539196014404297,State:[-1, 0.0010732681780518671]
#
# Step 323, action: 1, asset: 839832.5674012618, reward: -8.837722193177385, Trade: 155
# Price: 27.58358383178711,State:[-1, -0.0005368070517308698]
#
# Step 324, action: 2, asset: 838990.9922585541, reward: -8.967395452957895, Trade: 156
# Price: 27.376462936401367,State:[0, 0]
#
# Step 325, action: 2, asset: 837473.3953311689, reward: -8.96775908932153, Trade: 157
# Price: 27.35426902770996,State:[1, -0.0008106930666305079]
#
# Step 326, action: 0, asset: 836635.9443848856, reward: -9.119814471772235, Trade: 158
# Price: 27.66494369506836,State:[0, 0]
#
# Step 327, action: 0, asset: 834456.6507563493, reward: -9.120178108135871, Trade: 159
# Price: 27.70934295654297,State:[-1, -0.0016048925298381977]
#
# Step 328, action: 0, asset: 836023.0700468919, reward: -9.122359926317689, Trade: 159
# Price: 27.65754508972168,State:[-1, 0.0002674361252359425]
#
# Step 329, action: 0, asset: 843628.3105482956, reward: -9.124541744499506, Trade: 159
# Price: 27.40605735778809,State:[-1, 0.009357920266666597]
#
# Step 330, action: 1, asset: 848773.6088652513, reward: -9.124905380863142, Trade: 159
# Price: 27.23591423034668,State:[-1, 0.015508054867220289]
#
# Step 331, action: 1, asset: 854813.2375979325, reward: -9.125269017226778, Trade: 159
# Price: 27.03619766235352,State:[-1, 0.022727175578055592]
#
# Step 332, action: 1, asset: 853023.653884401, reward: -9.125632653590413, Trade: 159
# Price: 27.09537506103516,State:[-1, 0.020588100243801755]
#
# Step 333, action: 0, asset: 862866.1335883043, reward: -9.127814471772231, Trade: 159
# Price: 26.769906997680664,State:[-1, 0.032352738803775205]
#
# Step 334, action: 2, asset: 862056.5848307875, reward: -6.502452507317415, Trade: 160
# Price: 26.62936210632324,State:[0, 0]
#
# Step 335, action: 1, asset: 862056.5848307875, reward: -6.502816143681051, Trade: 160
# Price: 26.836483001708984,State:[0, 0]
#
# Step 336, action: 2, asset: 840306.8617851714, reward: -6.503179780044688, Trade: 161
# Price: 26.185546875,State:[1, -0.024255642092428142]
#
# Step 337, action: 2, asset: 832948.3333427886, reward: -6.505361598226506, Trade: 161
# Price: 25.95623779296875,State:[1, -0.03280031920293647]
#
# Step 338, action: 0, asset: 832115.3976720122, reward: -9.413725676515195, Trade: 162
# Price: 25.61596298217773,State:[0, 0]
#
# Step 339, action: 0, asset: 839452.6162146297, reward: -9.414089312878831, Trade: 163
# Price: 25.36447525024414,State:[-1, 0.00981761771394507]
#
# Step 340, action: 2, asset: 838628.676600601, reward: -8.67991416223227, Trade: 164
# Price: 25.39405632019043,State:[0, 0]
#
# Step 341, action: 1, asset: 838628.676600601, reward: -8.680277798595906, Trade: 164
# Price: 25.223920822143555,State:[0, 0]
#
# Step 342, action: 0, asset: 832133.5620014626, reward: -8.680641434959542, Trade: 165
# Price: 25.39405632019043,State:[-1, -0.00674500603005046]
#
# Step 343, action: 1, asset: 853283.653023954, reward: -8.681005071323177, Trade: 165
# Price: 24.757905960083008,State:[-1, 0.01847511595625695]
#
# Step 344, action: 1, asset: 852299.9175369698, reward: -8.681368707686813, Trade: 165
# Price: 24.787494659423828,State:[-1, 0.017302074716972538]
#
# Step 345, action: 2, asset: 851475.807702028, reward: -7.313157264350354, Trade: 166
# Price: 25.897947311401367,State:[0, 0]
#
# Step 346, action: 0, asset: 871941.9699504983, reward: -7.313520900713991, Trade: 167
# Price: 25.249561309814453,State:[-1, 0.02503619278356739]
#
# Step 347, action: 2, asset: 871111.8148737543, reward: -5.265136548734574, Trade: 168
# Price: 25.71162414550781,State:[0, 0]
#
# Step 348, action: 2, asset: 870998.2415468502, reward: -5.265500185098211, Trade: 169
# Price: 25.733980178833008,State:[1, 0.0008694912930695686]
#
# Step 349, action: 0, asset: 870127.2492537174, reward: -5.277296820382661, Trade: 170
# Price: 25.912845611572266,State:[0, 0]
#
# Step 350, action: 0, asset: 852740.9792209645, reward: -5.277660456746298, Trade: 171
# ...
#
# Step 1269, action: 0, asset: 1478919.8930569822, reward: 79.65713276826217, Trade: 559
# Price: 28.257213592529297,State:[-1, 0.008433017656549135]
#
# Step 1270, action: 2, asset: 1477464.2792131903, reward: 80.74917184861572, Trade: 560
# Price: 27.978126525878903,State:[0, 0]
#
# Step 1271, action: 0, asset: 1460020.6898596815, reward: 80.7488108377854, Trade: 561
# Price: 28.28047561645508,State:[-1, -0.010806623892293699]
#
# Step 1272, action: 0, asset: 1442417.114296251, reward: 80.74664477280346, Trade: 561
# Price: 28.613832473754883,State:[-1, -0.022721533812779526]
#
# Step 1273, action: 0, asset: 1461249.0875571305, reward: 80.74447870782153, Trade: 561
# Price: 28.257213592529297,State:[-1, -0.009975187809385666]
#
# Step 1274, action: 0, asset: 1487448.8282473616, reward: 80.7423126428396, Trade: 561
# Price: 27.76107215881348,State:[-1, 0.007758002197347014]
#
# Step 1275, action: 1, asset: 1553768.0014765793, reward: 80.74195163200928, Trade: 561
# Price: 26.50519371032715,State:[-1, 0.05264587012962918]
#
# Step 1276, action: 1, asset: 1570552.7123892838, reward: 80.74159062117896, Trade: 561
# Price: 26.18734359741211,State:[-1, 0.06400653477674334]
#
# Step 1277, action: 2, asset: 1569169.8373359353, reward: 90.05952951536838, Trade: 562
# Price: 26.520692825317383,State:[0, 0]
#
# Step 1278, action: 0, asset: 1621266.1477963561, reward: 90.05916850453806, Trade: 563
# Price: 25.613676071166992,State:[-1, 0.0342003416021065]
#
# Step 1279, action: 1, asset: 1593286.3889405364, reward: 90.05880749370775, Trade: 563
# Price: 26.086570739746094,State:[-1, 0.016369183430866685]
#
# Step 1280, action: 1, asset: 1590992.8957821957, reward: 90.05844648287743, Trade: 563
# Price: 26.125333786010746,State:[-1, 0.014907568286798956]
#
# Step 1281, action: 1, asset: 1584525.0035721892, reward: 90.05808547204711, Trade: 563
# Price: 26.234649658203125,State:[-1, 0.010785659673309578]
#
# Step 1282, action: 2, asset: 1582972.7780558625, reward: 91.59493351644905, Trade: 564
# Price: 26.50010108947754,State:[0, 0]
#
# Step 1283, action: 0, asset: 1611238.7055808294, reward: 91.59457250561873, Trade: 565
# Price: 26.00040435791016,State:[-1, 0.01885640850501491]
#
# Step 1284, action: 1, asset: 1628495.3109351387, reward: 91.59421149478841, Trade: 565
# Price: 25.71151351928711,State:[-1, 0.029757907999209743]
#
# Step 1285, action: 2, asset: 1626959.4593865778, reward: 96.15081432087752, Trade: 566
# Price: 26.312721252441406,State:[0, 0]
#
# Step 1286, action: 2, asset: 1618099.9533756908, reward: 96.1504533100472, Trade: 567
# Price: 26.19560432434082,State:[1, -0.004450962216221543]
#
# Step 1287, action: 1, asset: 1646072.3017681774, reward: 96.15009229921688, Trade: 567
# Price: 26.64845848083496,State:[1, 0.012759502340047968]
#
# Step 1288, action: 1, asset: 1657164.8213146862, reward: 96.14973128838656, Trade: 567
# Price: 26.828039169311523,State:[1, 0.01958436422923393]
#
# Step 1289, action: 2, asset: 1675491.7720230755, reward: 96.14756522340463, Trade: 567
# Price: 27.124740600585938,State:[1, 0.030860333310040566]
#
# Step 1290, action: 1, asset: 1652824.6338776287, reward: 96.14720421257431, Trade: 567
# Price: 26.757774353027344,State:[1, 0.016913989865059875]
#
# Step 1291, action: 2, asset: 1649930.7435978588, reward: 96.14503814759237, Trade: 567
# Price: 26.71092414855957,State:[1, 0.015133474500711896]
#
# Step 1292, action: 0, asset: 1648280.8365241264, reward: 98.4393458984211, Trade: 568
# Price: 26.86708641052246,State:[0, 0]
#
# Step 1293, action: 1, asset: 1648280.8365241264, reward: 98.43898488759078, Trade: 568
# Price: 26.35956764221192,State:[0, 0]
#
# Step 1294, action: 0, asset: 1614897.4241770008, reward: 98.43862387676046, Trade: 569
# Price: 26.86708641052246,State:[-1, -0.019253683338030347]
#
# Step 1295, action: 0, asset: 1637355.7850778797, reward: 98.43645781177852, Trade: 569
# Price: 26.507925033569336,State:[-1, -0.005628217934797952]
#
# Step 1296, action: 1, asset: 1652002.547372649, reward: 98.4360968009482, Trade: 569
# Price: 26.27368927001953,State:[-1, 0.003257958300304842]
#
# Step 1297, action: 0, asset: 1671532.676919768, reward: 98.43393073596627, Trade: 569
# Price: 25.96135711669922,State:[-1, 0.015106868629932046]
#
# Step 1298, action: 1, asset: 1631985.45266516, reward: 98.43356972513595, Trade: 569
# Price: 26.593809127807617,State:[-1, -0.00888639331172425]
#
# Step 1299, action: 1, asset: 1630032.70209677, reward: 98.43320871430564, Trade: 569
# Price: 26.625038146972656,State:[-1, -0.010071125155164395]
#
# Step 1300, action: 1, asset: 1629056.14791281, reward: 98.43284770347532, Trade: 569
# Price: 26.640655517578125,State:[-1, -0.01066359961519514]
#
# Step 1301, action: 2, asset: 1627390.307723296, reward: 96.50826018902873, Trade: 570
# Price: 26.336143493652344,State:[0, 0]
#
# Step 1302, action: 2, asset: 1599736.8566692115, reward: 96.50789917819841, Trade: 571
# Price: 25.914512634277344,State:[1, -0.01600958999470148]
#
# Step 1303, action: 1, asset: 1577083.663241172, reward: 96.5075381673681, Trade: 571
# Price: 25.54754638671875,State:[1, -0.029943530157468423]
#
# Step 1304, action: 0, asset: 1575506.5876551734, reward: 91.48138079712615, Trade: 572
# Price: 24.75113677978516,State:[0, 0]
#
# Step 1305, action: 2, asset: 1605212.9153240118, reward: 91.48101978629583, Trade: 573
# Price: 25.2430419921875,State:[1, 0.019874045252098904]
#
# Step 1306, action: 0, asset: 1603607.7102837285, reward: 94.44816351710367, Trade: 574
# Price: 24.048418045043945,State:[0, 0]
#
# Step 1307, action: 1, asset: 1603607.7102837285, reward: 94.44780250627335, Trade: 574
# Price: 24.1499252319336,State:[0, 0]
#
# Step 1308, action: 1, asset: 1603607.7102837285, reward: 94.44744149544303, Trade: 574
# Price: 24.071853637695312,State:[0, 0]
#
# Step 1309, action: 0, asset: 1614488.1958940648, reward: 94.44708048461271, Trade: 575
# Price: 23.88445281982422,State:[-1, 0.00778505970880583]
#
# Step 1310, action: 1, asset: 1598883.8579099798, reward: 94.4467194737824, Trade: 575
# Price: 24.11869239807129,State:[-1, -0.0019457895133854208]
#
# Step 1311, action: 0, asset: 1606685.8363092565, reward: 94.44455340880046, Trade: 575
# Price: 24.001575469970703,State:[-1, 0.0029195162442562372]
#
# Step 1312, action: 0, asset: 1577038.1150930545, reward: 94.44238734381852, Trade: 575
# Price: 24.446622848510746,State:[-1, -0.01556877241179988]
#
# Step 1313, action: 1, asset: 1582759.709922614, reward: 94.4420263329882, Trade: 575
# Price: 24.360734939575195,State:[-1, -0.012000791722474924]
#
# Step 1314, action: 0, asset: 1604085.134488883, reward: 94.43986026800627, Trade: 575
# Price: 24.04061508178711,State:[-1, 0.0012977212464969634]
#
# Step 1315, action: 2, asset: 1602483.6208339797, reward: 94.48744977957931, Trade: 576
# Price: 23.3378963470459,State:[0, 0]
#
# Step 1316, action: 0, asset: 1590694.2046328532, reward: 94.48708876874899, Trade: 577
# Price: 23.48625564575196,State:[-1, -0.006357012495894487]
#
# Step 1317, action: 1, asset: 1487758.9729434005, reward: 94.48672775791867, Trade: 577
# Price: 24.985370635986328,State:[-1, -0.07059223609710497]
#
# Step 1318, action: 2, asset: 1486043.3774540513, reward: 83.00258974057286, Trade: 578
# Price: 24.56373786926269,State:[0, 0]
#
# Step 1319, action: 0, asset: 1493531.8297759024, reward: 83.00222872974254, Trade: 579
# Price: 24.41539192199707,State:[-1, 0.0060392253025648435]
#
# Step 1320, action: 2, asset: 1492054.7718107975, reward: 83.75161039957456, Trade: 580
# Price: 24.056228637695312,State:[0, 0]
#
# Step 1321, action: 2, asset: 1490564.2238281774, reward: 83.75124938874424, Trade: 581
# Price: 24.056228637695312,State:[1, 0.0]
#
# Step 1322, action: 2, asset: 1501691.3410481024, reward: 83.7490833237623, Trade: 581
# Price: 24.235811233520508,State:[1, 0.00746511843272879]
#
# Step 1323, action: 0, asset: 1500189.6659482622, reward: 84.71126652494047, Trade: 582
# Price: 24.407583236694336,State:[0, 0]
#
# Step 1324, action: 2, asset: 1501088.1017671141, reward: 84.71090551411015, Trade: 583
# Price: 24.446622848510746,State:[1, 0.001599486988851817]
#
# Step 1325, action: 2, asset: 1497732.1708474667, reward: 84.70873944912822, Trade: 583
# Price: 24.3919677734375,State:[1, -0.0006397791663927954]
#
# Step 1326, action: 2, asset: 1530812.596724084, reward: 84.70657338414628, Trade: 583
# Price: 24.93071937561035,State:[1, 0.021433344458681836]
#
# Step 1327, action: 0, asset: 1529281.800692983, reward: 87.76529329037797, Trade: 584
# Price: 24.774559020996094,State:[0, 0]
#
# Step 1328, action: 2, asset: 1516198.1467572378, reward: 87.76493227954765, Trade: 585
# Price: 24.5871639251709,State:[1, -0.007564013376237355]
#
# Step 1329, action: 0, asset: 1514681.9547066283, reward: 86.45736146574073, Trade: 586
# Price: 25.63343620300293,State:[0, 0]
#
# Step 1330, action: 1, asset: 1514681.9547066283, reward: 86.45700045491041, Trade: 586
# Price: 25.66465759277344,State:[0, 0]
#
# Step 1331, action: 1, asset: 1514681.9547066283, reward: 86.4566394440801, Trade: 586
# Price: 25.35234832763672,State:[0, 0]
#
# Step 1332, action: 1, asset: 1514681.9547066283, reward: 86.45627843324978, Trade: 586
# Price: 25.555349349975582,State:[0, 0]
#
# Step 1333, action: 1, asset: 1514681.9547066283, reward: 86.45591742241946, Trade: 586
# Price: 25.321117401123047,State:[0, 0]
#
# Step 1334, action: 0, asset: 1500557.195108003, reward: 86.45555641158914, Trade: 587
# Price: 25.531925201416016,State:[-1, -0.008325375099110799]
#
# Step 1335, action: 1, asset: 1516903.981511659, reward: 86.45519540075883, Trade: 587
# Price: 25.258649826049805,State:[-1, 0.0024670149458124735]
#
# Step 1336, action: 2, asset: 1515393.0595963646, reward: 86.67741073897218, Trade: 588
# Price: 25.047840118408203,State:[0, 0]
#
# Step 1337, action: 1, asset: 1515393.0595963646, reward: 86.67704972814187, Trade: 588
# Price: 25.375768661499023,State:[0, 0]
#
# Step 1338, action: 0, asset: 1489631.355921098, reward: 86.67668871731155, Trade: 589
# Price: 25.781782150268555,State:[-1, -0.016000046902443055]
#
# Step 1339, action: 2, asset: 1488091.7194546484, reward: 84.09773270760239, Trade: 590
# Price: 25.68027687072754,State:[0, 0]
#
# Step 1340, action: 0, asset: 1501986.3829535153, reward: 84.09737169677207, Trade: 591
# Price: 25.414810180664062,State:[-1, 0.010337376477668636]
#
# Step 1341, action: 1, asset: 1462624.5314787533, reward: 84.09701068594175, Trade: 591
# Price: 26.09409523010254,State:[-1, -0.01611424835713926]
#
# Step 1342, action: 1, asset: 1462171.7178305297, reward: 84.09664967511144, Trade: 591
# Price: 26.10190963745117,State:[-1, -0.01641854442793189]
#
# Step 1343, action: 1, asset: 1487235.953494897, reward: 84.09628866428112, Trade: 591
# Price: 25.66936492919922,State:[-1, 0.0004249152601917272]
#
# Step 1344, action: 2, asset: 1485748.5164747098, reward: 84.01041428781208, Trade: 592
# Price: 25.339067459106445,State:[0, 0]
#
# Step 1345, action: 1, asset: 1485748.5164747098, reward: 84.01005327698176, Trade: 592
# Price: 25.35479164123535,State:[0, 0]
#
# Step 1346, action: 2, asset: 1510044.910989162, reward: 84.00969226615145, Trade: 593
# Price: 25.79519271850586,State:[1, 0.01736954038124572]
#
# Step 1347, action: 0, asset: 1508534.8862026134, reward: 86.43639264290009, Trade: 594
# Price: 25.70868873596192,State:[0, 0]
#
# Step 1348, action: 2, asset: 1486743.5308910608, reward: 86.43603163206977, Trade: 595
# Price: 25.36265182495117,State:[1, -0.013459920673694614]
#
# Step 1349, action: 1, asset: 1504722.7463489773, reward: 86.43567062123945, Trade: 595
# Price: 25.66936492919922,State:[1, -0.0015295920833058307]
#
# Step 1350, action: 0, asset: 1503218.0338461925, reward: 86.05432613726836, Trade: 596
# Price: 25.928890228271484,State:[0, 0]
#
# Step 1351, action: 0, asset: 1500803.1280527278, reward: 86.05396512643804, Trade: 597
# Price: 25.944616317749023,State:[-1, -0.0006065083904127633]
#
# Step 1352, action: 2, asset: 1499299.0148663227, reward: 85.81202236583013, Trade: 598
# Price: 26.27493095397949,State:[0, 0]
#
# Step 1353, action: 1, asset: 1499299.0148663227, reward: 85.81166135499981, Trade: 598
# Price: 26.070453643798828,State:[0, 0]
#
# Step 1354, action: 1, asset: 1499299.0148663227, reward: 85.8113003441695, Trade: 598
# Price: 26.24346351623535,State:[0, 0]
#
# Step 1355, action: 0, asset: 1489712.3168333904, reward: 85.81093933333918, Trade: 599
# Price: 26.385025024414062,State:[-1, -0.005394162553701509]
#
# Step 1356, action: 1, asset: 1494205.454994096, reward: 85.81057832250886, Trade: 599
# Price: 26.306377410888672,State:[-1, -0.002397316749536582]
#
# Step 1357, action: 2, asset: 1492702.571652612, reward: 85.30050189737572, Trade: 600
# Price: 26.0311222076416,State:[0, 0]
#
# Step 1358, action: 0, asset: 1463701.2920003785, reward: 85.3001408865454, Trade: 601
# Price: 26.51085090637207,State:[-1, -0.0184290440843784]
#
# Step 1359, action: 1, asset: 1450172.1857496155, reward: 85.29977987571509, Trade: 601
# Price: 26.746788024902344,State:[-1, -0.02749269937546739]
#
# Step 1360, action: 1, asset: 1429878.690430249, reward: 85.29941886488477, Trade: 601
# Price: 27.100690841674805,State:[-1, -0.041088072404317]
#
# Step 1361, action: 2, asset: 1428324.682616006, reward: 79.01053661135694, Trade: 602
# Price: 26.668148040771484,State:[0, 0]
#
# Step 1362, action: 0, asset: 1453854.022790471, reward: 79.01017560052662, Trade: 603
# Price: 26.16482162475586,State:[-1, 0.01887369213813106]
#
# Step 1363, action: 1, asset: 1476599.3947730456, reward: 79.0098145896963, Trade: 603
# Price: 25.740142822265625,State:[-1, 0.03479826259727836]
#
# Step 1364, action: 2, asset: 1475220.778463628, reward: 83.84189509771976, Trade: 604
# Price: 25.409847259521484,State:[0, 0]
#
# Step 1365, action: 0, asset: 1495205.2151063774, reward: 83.84153408688944, Trade: 605
# Price: 25.04021644592285,State:[-1, 0.01454675464293187]
#
# Step 1366, action: 2, asset: 1493751.4552601767, reward: 85.84176270594864, Trade: 606
# Price: 24.61553382873535,State:[0, 0]
#
# Step 1367, action: 2, asset: 1489876.018318576, reward: 85.84140169511832, Trade: 607
# Price: 24.576221466064453,State:[1, -0.0015970550524890825]
#
# Step 1368, action: 2, asset: 1517050.8593639557, reward: 85.83923563013639, Trade: 607
# Price: 25.02448844909668,State:[1, 0.016613680743495784]
#
# Step 1369, action: 1, asset: 1518480.8220447723, reward: 85.83887461930607, Trade: 607
# Price: 25.048076629638672,State:[1, 0.01757194476921664]
#
# Step 1370, action: 2, asset: 1493212.5593647186, reward: 85.83670855432413, Trade: 607
# Price: 24.63125991821289,State:[1, 0.0006388685123368543]
#
# Step 1371, action: 2, asset: 1496550.0254291717, reward: 85.8345424893422, Trade: 607
# Price: 24.68631362915039,State:[1, 0.0028754119617107055]
#
# Step 1372, action: 2, asset: 1508469.001987857, reward: 85.83237642436026, Trade: 607
# Price: 24.882925033569336,State:[1, 0.01086270184893734]
#
# Step 1373, action: 1, asset: 1523248.7132991971, reward: 85.83201541352994, Trade: 607
# Price: 25.12672615051269,State:[1, 0.020767062186585195]
#
# Step 1374, action: 1, asset: 1543749.3159794037, reward: 85.83165440269963, Trade: 607
# Price: 25.46489715576172,State:[1, 0.03450517599723346]
#
# Step 1375, action: 1, asset: 1528969.4890407745, reward: 85.83129339186931, Trade: 607
# Price: 25.221094131469727,State:[1, 0.02460073817401698]
#
# Step 1376, action: 0, asset: 1527440.5358723365, reward: 89.34906473143151, Trade: 608
# Price: 25.37052154541016,State:[0, 0]
#
# Step 1377, action: 2, asset: 1517873.6185641014, reward: 89.3487037206012, Trade: 609
# Price: 25.2368278503418,State:[1, -0.0052696470913718985]
#
# Step 1378, action: 2, asset: 1509359.6310896596, reward: 89.34653765561926, Trade: 609
# Price: 25.09527015686035,State:[1, -0.010849260156403973]
#
# Step 1379, action: 1, asset: 1513143.4725661, reward: 89.34617664478894, Trade: 609
# Price: 25.15818214416504,State:[1, -0.008369532367123789]
#
# Step 1380, action: 0, asset: 1511630.3337010392, reward: 87.91738641866375, Trade: 610
# Price: 24.39533805847168,State:[0, 0]
#
# Step 1381, action: 1, asset: 1511630.3337010392, reward: 87.91702540783344, Trade: 610
# Price: 23.89988136291504,State:[0, 0]
#
# Step 1382, action: 1, asset: 1511630.3337010392, reward: 87.91666439700312, Trade: 610
# Price: 23.92347526550293,State:[0, 0]
#
# Step 1383, action: 1, asset: 1511630.3337010392, reward: 87.9163033861728, Trade: 610
# Price: 23.734729766845703,State:[0, 0]

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# Define callback function for the training

# %%
from stable_baselines3.common.callbacks import BaseCallback

class TensorboardCallback(BaseCallback):
    """
    Custom callback for plotting additional values in tensorboard.
    """

    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self) -> bool:
        try:
            self.logger.record(key="train/reward", value=self.locals["rewards"][0])

        except BaseException as error:
            try:
                self.logger.record(key="train/reward", value=self.locals["reward"][0])

            except BaseException as inner_error:
                # Handle the case where neither "rewards" nor "reward" is found
                self.logger.record(key="train/reward", value=None)
                # Print the original error and the inner error for debugging
                print("Original Error:", error)
                print("Inner Error:", inner_error)
        return True

# %% [markdown]
# ### Model 1: PPO

# %%
# policy_kwargs = dict(net_arch=dict(pi=[128, 64, 32, 16], vf=[128, 64, 32, 16]))
policy_kwargs = dict(net_arch=dict(pi=[64,64,64], vf=[64,64,64]))
total_training_step = 2000000

# %%
try:
  trained_model
except NameError:
    print('No any model')
else:
    print('Ready for keeping training')
# Out:
# No any model

# %%
try:
  trained_model
except NameError:
    trained_ppo = PPO("MlpPolicy", env_train,n_steps=1024,ent_coef=0.01,learning_rate=0.00025,batch_size=2048,clip_range=0.1,
                      policy_kwargs=policy_kwargs,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo",verbose=1)
    trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
else:
    trained_model.env = env_train
    trained_ppo = trained_model.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
# Out:
# Using cpu device
# Logging to tensorboard_log/test_ppo/ppo_26
# ----------------------------------
# | time/              |           |
# |    fps             | 258       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 1024      |
# | train/             |           |
# |    reward          | 10.271585 |
# ----------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 243           |
# |    iterations           | 2             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 1.8315564e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00064       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.1e+05       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00014      |
# |    reward               | -3.0939438    |
# |    value_loss           | 2.21e+05      |
# -------------------------------------------
# Episode: 5
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 3             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 4.0892337e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00243       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.02e+04      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000109     |
# |    reward               | -10.30586     |
# |    value_loss           | 2.05e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 4            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.552735e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00414     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.5e+03      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000354    |
# |    reward               | -36.060333   |
# |    value_loss           | 1.7e+04      |
# ------------------------------------------
# Episode: 6
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 1.883437e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00111      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9e+04        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000228    |
# |    reward               | 9.463967     |
# |    value_loss           | 1.8e+05      |
# ------------------------------------------
# Episode: 7
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 6            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 5.804177e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -9.51e-05    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.35e+05     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -6.4e-05     |
# |    reward               | -28.322102   |
# |    value_loss           | 4.7e+05      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 7             |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.9039726e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.00146      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.63e+04      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | 3.05e-06      |
# |    reward               | -49.39333     |
# |    value_loss           | 1.33e+05      |
# -------------------------------------------
# Episode: 8
# Current company: ['WMT']
# begin_total_asset: 1000000.00
# end_total_asset: 199240.41
# total_reward: -800759.59
# total_cost: 504543.56
# total_trades: 945
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 8             |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.0151492e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0014        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.15e+05      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -5.01e-06     |
# |    reward               | 27.123255     |
# |    value_loss           | 4.3e+05       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 243           |
# |    iterations           | 9             |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 1.6854086e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00153       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.01e+05      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000211     |
# |    reward               | -12.314718    |
# |    value_loss           | 2.02e+05      |
# -------------------------------------------
# Episode: 9
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 10           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 7.785112e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00169      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.76e+04     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000299    |
# |    reward               | -21.585815   |
# |    value_loss           | 7.52e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 11            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 3.9716193e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00733       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.54e+04      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -9.52e-05     |
# |    reward               | -32.906246    |
# |    value_loss           | 1.11e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 12           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 1.431501e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00133     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.86e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -5.54e-06    |
# |    reward               | -29.21299    |
# |    value_loss           | 3.72e+05     |
# ------------------------------------------
# Episode: 10
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 13            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 5.7012658e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.000632     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.03e+05      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -6.67e-05     |
# |    reward               | -2.489233     |
# |    value_loss           | 2.07e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 14           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 2.047629e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00553     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.66e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -2.13e-05    |
# |    reward               | -31.083836   |
# |    value_loss           | 1.53e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 15           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 6.850343e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000291    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.81e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -2.46e-05    |
# |    reward               | -12.626052   |
# |    value_loss           | 1.56e+05     |
# ------------------------------------------
# Episode: 11
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 246           |
# |    iterations           | 16            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 3.1428062e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00157       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.81e+04      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -2.3e-05      |
# |    reward               | -11.489497    |
# |    value_loss           | 1.77e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 17           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 4.720228e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0051      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.21e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000182    |
# |    reward               | -15.69278    |
# |    value_loss           | 1.65e+04     |
# ------------------------------------------
# Episode: 12
# Current company: ['PG']
# begin_total_asset: 1000000.00
# end_total_asset: 298655.60
# total_reward: -701344.40
# total_cost: 805483.87
# total_trades: 1177
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 18           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 6.152404e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.05e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000192    |
# |    reward               | 35.651344    |
# |    value_loss           | 1.22e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 19           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 3.184704e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00955     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.97e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000255    |
# |    reward               | 56.12595     |
# |    value_loss           | 9.96e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 251           |
# |    iterations           | 20            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 6.9478236e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.000296      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.59e+05      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00047      |
# |    reward               | 38.380302     |
# |    value_loss           | 9.18e+05      |
# -------------------------------------------
# Episode: 13
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 252           |
# |    iterations           | 21            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 1.2120756e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.000102      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.02e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 1.44e-05      |
# |    reward               | -39.934235    |
# |    value_loss           | 1.2e+06       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 253           |
# |    iterations           | 22            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 8.4680505e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.000521      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.62e+05      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -6.84e-06     |
# |    reward               | -30.482359    |
# |    value_loss           | 3.24e+05      |
# -------------------------------------------
# Episode: 14
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 23           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 3.623718e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00146      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.26e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -5.72e-05    |
# |    reward               | -1.9419286   |
# |    value_loss           | 4.52e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 24           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 9.716023e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00087     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.45e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -5.26e-06    |
# |    reward               | -19.112492   |
# |    value_loss           | 2.9e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 25           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 2.341054e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00176     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.21e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -4.69e-05    |
# |    reward               | -29.916048   |
# |    value_loss           | 1.44e+05     |
# ------------------------------------------
# Episode: 15
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 26            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.4429679e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.000246      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.58e+05      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -1.1e-05      |
# |    reward               | -37.13932     |
# |    value_loss           | 3.17e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 27           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 5.499285e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0133       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.77e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000121    |
# |    reward               | -50.599144   |
# |    value_loss           | 1.56e+05     |
# ------------------------------------------
# Episode: 16
# Current company: ['BA']
# begin_total_asset: 1000000.00
# end_total_asset: 196448.71
# total_reward: -803551.29
# total_cost: 446418.89
# total_trades: 885
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 256           |
# |    iterations           | 28            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.4384353e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00319       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.44e+05      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -2.04e-05     |
# |    reward               | -16.801289    |
# |    value_loss           | 4.88e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 29            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 1.0141521e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.00375      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.61e+05      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -2e-05        |
# |    reward               | -37.963104    |
# |    value_loss           | 3.22e+05      |
# -------------------------------------------
# Episode: 17
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 30           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 6.100163e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000485    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.19e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 3.81e-06     |
# |    reward               | -33.62648    |
# |    value_loss           | 2.38e+05     |
# ------------------------------------------
# Episode: 18
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 258           |
# |    iterations           | 31            |
# |    time_elapsed         | 122           |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 1.8393621e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0197        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.86e+05      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -9.88e-06     |
# |    reward               | -12.217985    |
# |    value_loss           | 3.73e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 32           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 8.789584e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0164      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.71e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000371    |
# |    reward               | -35.418808   |
# |    value_loss           | 7.42e+04     |
# ------------------------------------------
# Episode: 19
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 33           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 8.655194e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000425    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.19e+05     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -6.93e-05    |
# |    reward               | 13.154482    |
# |    value_loss           | 2.37e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 34            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 3.3480464e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00713       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.32e+05      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 2.12e-05      |
# |    reward               | 4.6445155     |
# |    value_loss           | 2.65e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 35            |
# |    time_elapsed         | 137           |
# |    total_timesteps      | 35840         |
# | train/                  |               |
# |    approx_kl            | 2.2351742e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00588       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.57e+04      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -3.71e-05     |
# |    reward               | 6.3639436     |
# |    value_loss           | 1.32e+05      |
# -------------------------------------------
# Episode: 20
# Current company: ['BA']
# begin_total_asset: 1000000.00
# end_total_asset: 189522.43
# total_reward: -810477.57
# total_cost: 981756.44
# total_trades: 1145
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 36           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 3.824185e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00164     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.83e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -4.69e-05    |
# |    reward               | -3.5024657   |
# |    value_loss           | 3.67e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 259           |
# |    iterations           | 37            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 37888         |
# | train/                  |               |
# |    approx_kl            | 5.5292854e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00112       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.38e+04      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000272     |
# |    reward               | -26.960981    |
# |    value_loss           | 4.76e+04      |
# -------------------------------------------
# Episode: 21
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 38           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 3.168278e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00503      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.59e+04     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 5.71e-05     |
# |    reward               | 15.226435    |
# |    value_loss           | 5.18e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 39            |
# |    time_elapsed         | 153           |
# |    total_timesteps      | 39936         |
# | train/                  |               |
# |    approx_kl            | 6.4821797e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.000218     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.07e+05      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000139     |
# |    reward               | 3.8915293     |
# |    value_loss           | 2.15e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 40           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 7.624505e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00116     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.01e+04     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000271    |
# |    reward               | 43.123672    |
# |    value_loss           | 4.03e+04     |
# ------------------------------------------
# Episode: 22
# Episode: 23
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 41           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 3.961887e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00953      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.98e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000111    |
# |    reward               | 19.49604     |
# |    value_loss           | 2e+05        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 42           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 2.287794e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.005       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.39e+04     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -2.28e-05    |
# |    reward               | 49.97469     |
# |    value_loss           | 1.88e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 43          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 4.84474e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.000222    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.82e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -2.9e-05    |
# |    reward               | 20.221634   |
# |    value_loss           | 1.37e+06    |
# -----------------------------------------
# Episode: 24
# Current company: ['CSCO']
# begin_total_asset: 1000000.00
# end_total_asset: 661004.18
# total_reward: -338995.82
# total_cost: 1327358.76
# total_trades: 1210
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 258           |
# |    iterations           | 44            |
# |    time_elapsed         | 174           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 7.2602415e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00585       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.19e+05      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -9.48e-06     |
# |    reward               | -16.551197    |
# |    value_loss           | 6.39e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 258           |
# |    iterations           | 45            |
# |    time_elapsed         | 177           |
# |    total_timesteps      | 46080         |
# | train/                  |               |
# |    approx_kl            | 1.9544386e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.00579      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.85e+04      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -2.42e-05     |
# |    reward               | -49.899185    |
# |    value_loss           | 7.7e+04       |
# -------------------------------------------
# Episode: 25
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 46           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 3.280351e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00186     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.09e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -2.79e-05    |
# |    reward               | -1.5519059   |
# |    value_loss           | 4.19e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 47          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 2.49187e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.00969     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.34e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -4.7e-05    |
# |    reward               | -29.855955  |
# |    value_loss           | 2.68e+05    |
# -----------------------------------------
# Episode: 26
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 48           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 8.773641e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00799      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.54e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -9.34e-06    |
# |    reward               | 5.7620096    |
# |    value_loss           | 1.11e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 49           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 3.015739e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0063      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.82e+05     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -2.05e-05    |
# |    reward               | -27.795174   |
# |    value_loss           | 3.66e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 260           |
# |    iterations           | 50            |
# |    time_elapsed         | 196           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 4.9561495e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.0034       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.98e+04      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -6.91e-05     |
# |    reward               | -51.164944    |
# |    value_loss           | 3.96e+04      |
# -------------------------------------------
# Episode: 27
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 261           |
# |    iterations           | 51            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 52224         |
# | train/                  |               |
# |    approx_kl            | 2.2952445e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.000132     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.12e+05      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -2.52e-05     |
# |    reward               | 68.76487      |
# |    value_loss           | 4.25e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 261           |
# |    iterations           | 52            |
# |    time_elapsed         | 203           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 2.6388443e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00798       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.99e+05      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -8.77e-05     |
# |    reward               | 121.569626    |
# |    value_loss           | 3.97e+05      |
# -------------------------------------------
# Episode: 28
# Current company: ['CAT']
# begin_total_asset: 1000000.00
# end_total_asset: 780673.73
# total_reward: -219326.27
# total_cost: 1484480.84
# total_trades: 1199
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 261           |
# |    iterations           | 53            |
# |    time_elapsed         | 207           |
# |    total_timesteps      | 54272         |
# | train/                  |               |
# |    approx_kl            | 1.7260318e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00142       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.47e+06      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -3.97e-05     |
# |    reward               | 9.111606      |
# |    value_loss           | 2.95e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 262           |
# |    iterations           | 54            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.1846423e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00199       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.87e+05      |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -4.15e-05     |
# |    reward               | -18.74533     |
# |    value_loss           | 9.74e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 262           |
# |    iterations           | 55            |
# |    time_elapsed         | 214           |
# |    total_timesteps      | 56320         |
# | train/                  |               |
# |    approx_kl            | 3.7389516e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.0144       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.39e+04      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000229     |
# |    reward               | -35.422173    |
# |    value_loss           | 2.78e+04      |
# -------------------------------------------
# Episode: 29
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 262          |
# |    iterations           | 56           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 7.812446e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00193     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.04e+04     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000358    |
# |    reward               | -42.17191    |
# |    value_loss           | 1.81e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 263           |
# |    iterations           | 57            |
# |    time_elapsed         | 221           |
# |    total_timesteps      | 58368         |
# | train/                  |               |
# |    approx_kl            | 1.1046708e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00289       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.54e+05      |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -3.38e-05     |
# |    reward               | -40.53203     |
# |    value_loss           | 3.09e+05      |
# ...
# |    explained_variance   | 0.164         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.01e+05      |
# |    n_updates            | 9440          |
# |    policy_gradient_loss | 3.63e-06      |
# |    reward               | 38.312943     |
# |    value_loss           | 6.03e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 946           |
# |    time_elapsed         | 3756          |
# |    total_timesteps      | 968704        |
# | train/                  |               |
# |    approx_kl            | 2.5343616e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -0.986        |
# |    explained_variance   | 0.0474        |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.25e+04      |
# |    n_updates            | 9450          |
# |    policy_gradient_loss | -8.9e-06      |
# |    reward               | 13.260209     |
# |    value_loss           | 1.45e+05      |
# -------------------------------------------
# Episode: 428
# Current company: ['KO']
# begin_total_asset: 1000000.00
# end_total_asset: 571057.54
# total_reward: -428942.46
# total_cost: 912769.15
# total_trades: 970
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 947           |
# |    time_elapsed         | 3760          |
# |    total_timesteps      | 969728        |
# | train/                  |               |
# |    approx_kl            | 1.8673018e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0.538         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.05e+05      |
# |    n_updates            | 9460          |
# |    policy_gradient_loss | -9.37e-06     |
# |    reward               | -4.7373357    |
# |    value_loss           | 2.11e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 948          |
# |    time_elapsed         | 3764         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 8.475385e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.992       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.91e+03     |
# |    n_updates            | 9470         |
# |    policy_gradient_loss | -0.000134    |
# |    reward               | -10.529047   |
# |    value_loss           | 1.78e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 949         |
# |    time_elapsed         | 3767        |
# |    total_timesteps      | 971776      |
# | train/                  |             |
# |    approx_kl            | 0.005957111 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 9.54e-07    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.38e+03    |
# |    n_updates            | 9480        |
# |    policy_gradient_loss | -0.00263    |
# |    reward               | 2.2429116   |
# |    value_loss           | 4.77e+03    |
# -----------------------------------------
# Episode: 429
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 950          |
# |    time_elapsed         | 3771         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0008064569 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.52e+04     |
# |    n_updates            | 9490         |
# |    policy_gradient_loss | -0.000497    |
# |    reward               | -49.4228     |
# |    value_loss           | 3.05e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 951           |
# |    time_elapsed         | 3775          |
# |    total_timesteps      | 973824        |
# | train/                  |               |
# |    approx_kl            | 1.8089195e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 6.17e-05      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.72e+04      |
# |    n_updates            | 9500          |
# |    policy_gradient_loss | -3.7e-05      |
# |    reward               | -49.92869     |
# |    value_loss           | 1.95e+05      |
# -------------------------------------------
# Episode: 430
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 952          |
# |    time_elapsed         | 3778         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 7.710187e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.84e+05     |
# |    n_updates            | 9510         |
# |    policy_gradient_loss | -2.38e-06    |
# |    reward               | -16.423874   |
# |    value_loss           | 7.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 953          |
# |    time_elapsed         | 3782         |
# |    total_timesteps      | 975872       |
# | train/                  |              |
# |    approx_kl            | 9.621726e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.29e+05     |
# |    n_updates            | 9520         |
# |    policy_gradient_loss | -1.61e-06    |
# |    reward               | -41.220318   |
# |    value_loss           | 4.59e+05     |
# ------------------------------------------
# Episode: 431
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 954           |
# |    time_elapsed         | 3787          |
# |    total_timesteps      | 976896        |
# | train/                  |               |
# |    approx_kl            | 5.6927092e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.74e+05      |
# |    n_updates            | 9530          |
# |    policy_gradient_loss | 5.84e-07      |
# |    reward               | 12.594757     |
# |    value_loss           | 3.48e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 955          |
# |    time_elapsed         | 3791         |
# |    total_timesteps      | 977920       |
# | train/                  |              |
# |    approx_kl            | 6.670598e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 2.5e-06      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.8e+05      |
# |    n_updates            | 9540         |
# |    policy_gradient_loss | -1.01e-05    |
# |    reward               | -34.791435   |
# |    value_loss           | 5.61e+05     |
# ------------------------------------------
# Episode: 432
# Current company: ['UNH']
# begin_total_asset: 1000000.00
# end_total_asset: 199857.71
# total_reward: -800142.29
# total_cost: 479777.94
# total_trades: 790
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 956           |
# |    time_elapsed         | 3795          |
# |    total_timesteps      | 978944        |
# | train/                  |               |
# |    approx_kl            | 4.6996865e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | -5.72e-06     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.42e+04      |
# |    n_updates            | 9550          |
# |    policy_gradient_loss | -3.58e-05     |
# |    reward               | 7.090523      |
# |    value_loss           | 8.85e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 957           |
# |    time_elapsed         | 3799          |
# |    total_timesteps      | 979968        |
# | train/                  |               |
# |    approx_kl            | 1.4913385e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 0.288         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.13e+05      |
# |    n_updates            | 9560          |
# |    policy_gradient_loss | -1.83e-05     |
# |    reward               | 36.669724     |
# |    value_loss           | 4.25e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 958           |
# |    time_elapsed         | 3803          |
# |    total_timesteps      | 980992        |
# | train/                  |               |
# |    approx_kl            | 3.7666177e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -0.98         |
# |    explained_variance   | 0.000222      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.45e+04      |
# |    n_updates            | 9570          |
# |    policy_gradient_loss | -1.42e-05     |
# |    reward               | 19.711094     |
# |    value_loss           | 1.49e+05      |
# -------------------------------------------
# Episode: 433
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 try:
# ----> 2   trained_model
#       3 except NameError:
#
# NameError: name 'trained_model' is not defined
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yp/xsyhd9vn1bj7xbmj2dyszbh40000gn/T/ipykernel_1880/1636729403.py in ?()
#       2   trained_model
#       3 except NameError:
#       4     trained_ppo = PPO("MlpPolicy", env_train,n_steps=1024,ent_coef=0.01,learning_rate=0.00025,batch_size=2048,clip_range=0.1,
#       5                       policy_kwargs=policy_kwargs,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo",verbose=1)
# ----> 6     trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
#       7 else:
#       8     trained_model.env = env_train
#       9     trained_ppo = trained_model.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py in ?(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     311         tb_log_name: str = "PPO",
#     312         reset_num_timesteps: bool = True,
#     313         progress_bar: bool = False,
#     314     ) -> SelfPPO:
# --> 315         return super().learn(
#     316             total_timesteps=total_timesteps,
#     317             callback=callback,
#     318             log_interval=log_interval,
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py in ?(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     273
#     274         assert self.env is not None
#     275
#     276         while self.num_timesteps < total_timesteps:
# --> 277             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     278
#     279             if not continue_training:
#     280                 break
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py in ?(self, env, callback, rollout_buffer, n_rollout_steps)
#     190                     # Otherwise, clip the actions to avoid out of bound error
#     191                     # as we are sampling from an unbounded Gaussian distribution
#     192                     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     193
# --> 194             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     195
#     196             self.num_timesteps += env.num_envs
#     197
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in ?(self, actions)
#     202         :param actions: the action
#     203         :return: observation, reward, done, information
#     204         """
#     205         self.step_async(actions)
# --> 206         return self.step_wait()
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in ?(self)
#      55     def step_wait(self) -> VecEnvStepReturn:
#      56         # Avoid circular imports
#      57         for env_idx in range(self.num_envs):
# ---> 58             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59                 self.actions[env_idx]
#      60             )
#      61             # convert to SB3 VecEnv api
#
# /var/folders/yp/xsyhd9vn1bj7xbmj2dyszbh40000gn/T/ipykernel_1880/907671134.py in ?(self, actions)
#     265     def step(self, actions):
#     266
# --> 267         current_total_asset = sum(self.portfolio.price * self.portfolio.amount)
#     268         self.terminal = (self.row >= len(self.df.index.unique()) - 1) | (current_total_asset < self.initial_amount*(1-self.stop_loss))
#     269         # print(f'Step {self.row}, action: {actions}, reward: {self.reward}, Trade: {self.trades}')
#     270
#
# ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
# -> 6281     @final
#    6282     def __getattr__(self, name: str):
#    6283         """
#    6284         After regular attribute access, try looking up the name
#
# KeyboardInterrupt:

# %% [markdown]
# Keep continuing the current training

# %%
# trained_ppo = trained_ppo.learn(total_timesteps=total_training_step,tb_log_name='ppo',callback=TensorboardCallback())

# %% [markdown]
# ### Model 2: DDPG

# %%
# agent_ddpg = DRLAgent(env = env_train)
# DDPG_PARAMS = {"batch_size": 128, "buffer_size": episode_length, "learning_rate": 0.001}
# model_ddpg = agent_ddpg.get_model("ddpg",model_kwargs = DDPG_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ddpg_tensorboard/")

# # set up logger
# tmp_path = TENSORBOARD_LOG_DIR + '/ddpg'
# new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_ddpg)

# %%
# the training log just show up when total_timesteps higher than 15.000
# trained_ddpg = agent_ddpg.train_model(model=model_ddpg,
#                              tb_log_name='ddpg',
#                              total_timesteps=total_training_step)

# %%
# from stable_baselines3.common.noise import NormalActionNoise

# # The noise objects for DDPG
# n_actions = env_train.action_space.shape[-1]
# action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# # Train the agent
# trained_ddpg = DDPG("MlpPolicy", env_train, action_noise=action_noise, verbose=1)
# trained_ddpg.learn(total_timesteps=total_timesteps, log_interval=10)

# %% [markdown]
# ### Model 3: SAC

# %%
# episode_length = len(e_train_gym.df) + 1
# episode_amount = 4
# total_training_step = episode_length*episode_amount

# %%
# agent_sac = DRLAgent(env = env_train)
# SAC_PARAMS = {
#     "batch_size": 2048,
#     "buffer_size": episode_length,
#     "learning_rate": 0.0003,
#     "learning_starts": episode_length,
#     "ent_coef": "auto_0.1",
# }

# model_sac = agent_sac.get_model("sac",model_kwargs = SAC_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_sac/")

# # # set up logger
# # tmp_path = TENSORBOARD_LOG_DIR + '/test_sac/sac_12'
# # new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # # Set new logger
# # model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 2048, 'buffer_size': 58204, 'learning_rate': 0.0003, 'learning_starts': 58204, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
# trained_sac = agent_sac.train_model(model=model_sac, 
#                              tb_log_name='sac',
#                              total_timesteps=total_training_step)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ### Model 4: TD3

# %%
# agent_td3 = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100, 
#               "buffer_size": 1000000, 
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3, 
#                              tb_log_name='td3',
#                              total_timesteps=10000)

# %% [markdown]
# ### Model 5: A2C

# %%
# agent_a2c = DRLAgent(env = env_train)

# A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
# model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)

# %%
# trained_a2c = agent.train_model(model=model_a2c, 
#                                 tb_log_name='a2c',
#                                 total_timesteps=10000)

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at the begining. We use the PPO model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2018-12 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
trade_data = trade_data.reset_index(drop=True)

# trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = trade_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %% [markdown]
# DRL_prediction function allow testing the model using trading_data dataset

# %%
def DRL_prediction(model, environment, deterministic=False):
        """make a prediction and get results"""
        # test_env, test_obs = environment.get_sb_env()
        # account_memory = None  # This help avoid unnecessary list creation
        # actions_memory = None  # optimize memory consumption

        test_obs = environment.reset()[0]
        # max_steps = len(environment.df.index.unique()) - 1

        for i in range(0,len(environment.df)):
            action = model.predict(np.asarray(test_obs), deterministic=deterministic)
            test_obs,reward,terminal,truncated,info = environment.step(action)
            # test_obs, rewards, dones, info = test_env.step(action)

            # if (i == max_steps - 1):  # more descriptive condition for early termination to clarify the logic
            #     account_memory = environment.env_method(method_name="save_asset_memory")
            #     actions_memory = environment.env_method(method_name="save_action_memory")

            if terminal:
                print("hit end!")
                break
        return pd.DataFrame(e_trade_gym.asset_memory, columns=['account_value']), pd.DataFrame(e_trade_gym.actions_memory,columns=['actions','none'])

# %%
df_account_value_ppo, df_actions_ppo = DRL_prediction(model=trained_ppo, environment = e_trade_gym)

# df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
#     model=trained_ddpg, 
#     environment = e_trade_gym)

# df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
#     model=trained_sac, 
#     environment = e_trade_gym)

# df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
#     model=trained_a2c, 
#     environment = e_trade_gym) if if_using_a2c else [None, None]

# df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
#     model=trained_td3, 
#     environment = e_trade_gym) if if_using_td3 else [None, None]
# Out:
# Episode: 3
# hit end!

# %%
df_account_value_ppo.shape
# df_account_value_ddpg.shape
# df_account_value_sac.shape
# df_account_value_td3.shape
# df_account_value_a2c.shape
# Out:
# (1140, 1)

# %%
df_account_value_ppo['date'] = trade_data.date
# df_account_value_ddpg['date'] = trade_data.date

# %%
df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
# df_account_value_sac.tail()
# df_account_value_td3.tail()
# df_account_value_a2c.tail()
# Out:
#       account_value       date
# 1135   1.127245e+06 2024-02-29
# 1136   1.129035e+06 2024-02-29
# 1137   1.128967e+06 2024-02-29
# 1138   1.126539e+06 2024-02-29
# 1139   1.126491e+06 2024-02-29

# %%
# df_actions_ppo.actions.unique()
# df_actions_ddpg.head()
# df_actions_sac.head()
# df_actions_td3.head()
# df_actions_a2c.head()

# %%
df_actions_ppo['date'] = trade_data.date
df_actions_ppo.head()
# Out:
#         actions  none       date
# 0         [1.0]  None 2021-01-31
# 1        [-1.0]  None 2021-01-31
# 2        [-1.0]  None 2021-01-31
# 3  [-0.9013582]  None 2021-01-31
# 4        [-1.0]  None 2021-01-31

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_account_value = pd.DataFrame(df_account_value_ppo.date.unique())
df_account_value.columns = ['date']
df_account_value['account_value'] = df_account_value.apply(lambda x: \
                                    df_account_value_ppo[df_account_value_ppo.date == x.date].iloc[-1].account_value, axis=1)
df_account_value.head()

# df_account_value = pd.DataFrame(df_account_value_ddpg.date.unique())
# df_account_value.columns = ['date']
# df_account_value['account_value'] = df_account_value.apply(lambda x: \
#                                     df_account_value_ddpg[df_account_value_ddpg.date == x.date].iloc[-1].account_value, axis=1)
# df_account_value.head()
# Out:
#         date  account_value
# 0 2021-01-31   9.990001e+05
# 1 2021-02-28   9.174570e+05
# 2 2021-03-31   9.603747e+05
# 3 2021-04-30   9.505173e+05
# 4 2021-05-31   1.049017e+06

# %% [markdown]
# There's a missmatch between the quarterly computation of df_account_value and the daily frequency of the comparison datasets. We need to transform the df_account_value to a daily basis.
# To fill up the missing data, th **ffill** function effectively imputes values, providing the continous picture of account value trends until the next recorded change. However, for the entries preceding the first recorded change, we will use the **initial_amount**.

# %%
daily_account_value = pd.DataFrame(df.date.unique())
daily_account_value.columns = ['date']
daily_account_value['date'] = pd.to_datetime(daily_account_value.date)
daily_account_value = daily_account_value.merge(df_account_value,how='left')
daily_account_value.ffill(inplace=True)
daily_account_value.fillna(env_kwargs["initial_amount"],inplace=True)
daily_account_value = daily_account_value[daily_account_value.date >= TEST_START_DATE]
daily_account_value.reset_index(inplace=True,drop=True)
daily_account_value
# Out:
#          date  account_value
# 0  2021-01-31   9.990001e+05
# 1  2021-02-28   9.174570e+05
# 2  2021-03-31   9.603747e+05
# 3  2021-04-30   9.505173e+05
# 4  2021-05-31   1.049017e+06
# 5  2021-06-30   1.048674e+06
# 6  2021-07-31   1.126485e+06
# 7  2021-08-31   1.127625e+06
# 8  2021-09-30   1.126538e+06
# 9  2021-10-31   1.214924e+06
# 10 2021-11-30   1.162212e+06
# 11 2021-12-31   1.231293e+06
# 12 2022-01-31   1.214851e+06
# 13 2022-02-28   1.203596e+06
# 14 2022-03-31   1.239295e+06
# 15 2022-04-30   1.302839e+06
# 16 2022-05-31   1.326611e+06
# 17 2022-06-30   1.262456e+06
# 18 2022-07-31   1.271055e+06
# 19 2022-08-31   1.279077e+06
# 20 2022-09-30   1.271961e+06
# 21 2022-10-31   1.450595e+06
# 22 2022-11-30   1.608961e+06
# 23 2022-12-31   1.428349e+06
# 24 2023-01-31   1.350539e+06
# 25 2023-02-28   1.270791e+06
# 26 2023-03-31   1.280473e+06
# 27 2023-04-30   1.288394e+06
# 28 2023-05-31   1.205204e+06
# 29 2023-06-30   1.253580e+06
# 30 2023-07-31   1.254508e+06
# 31 2023-08-31   1.227742e+06
# 32 2023-09-30   1.188535e+06
# 33 2023-10-31   1.201624e+06
# 34 2023-11-30   1.300744e+06
# 35 2023-12-31   1.324027e+06
# 36 2024-01-31   1.129046e+06
# 37 2024-02-29   1.126491e+06
# 38 2024-03-31   1.126491e+06

# %%
print("==============Get Backtest Results===========")
# now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

print("\n ppo:")
perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
# perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

# print("\n ddpg:")
# perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
# perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
# perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

# print("\n sac:")
# perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
# perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
#   perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')

#   print("\n atd3:")
#   perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
#   perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
#   perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

#   print("\n a2c:")
#   perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
#   perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
#   perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.026679
# Cumulative returns     0.126491
# Annual volatility      0.157634
# Sharpe ratio           0.245803
# Calmar ratio           0.083626
# Stability              0.339569
# Max drawdown          -0.319024
# Omega ratio            1.195159
# Sortino ratio          0.373782
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.280696
# Daily value at risk   -0.019706
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Annual return          0.089358
# Cumulative returns     0.316223
# Annual volatility      0.146547
# Sharpe ratio           0.658110
# Calmar ratio           0.407268
# Stability              0.108092
# Max drawdown          -0.219408
# Omega ratio            1.118655
# Sortino ratio          0.940026
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.003905
# Daily value at risk   -0.018081
# dtype: float64

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTest with DJIA

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

backtest_plot(daily_account_value, 
            baseline_ticker = '^DJI', 
            baseline_start = TEST_START_DATE,
            baseline_end = TEST_END_DATE)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ==============Compare to DJIA===========
# Shape of DataFrame:  (809, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-01-31</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-03-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>1</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>117.294%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>12.762%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>93.886%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.31</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.91</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.22</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-29.986%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.99</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.21</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-11.341%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.68</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>29.99</td>
#       <td>2022-11-30</td>
#       <td>2024-02-29</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.16</td>
#       <td>2021-01-31</td>
#       <td>2021-02-28</td>
#       <td>2021-05-31</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.84</td>
#       <td>2022-05-31</td>
#       <td>2022-06-30</td>
#       <td>2022-10-31</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.34</td>
#       <td>2021-10-31</td>
#       <td>2021-11-30</td>
#       <td>2021-12-31</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.25</td>
#       <td>2021-12-31</td>
#       <td>2022-02-28</td>
#       <td>2022-03-31</td>
#       <td>65</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compare to Buy&Hold Strategy
# pass in df_account_value, this information is stored in env class

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTest with Buy&Hold Strategy

# %%
# print(DOW_30_TICKER)
test_portfolio = DOW_30_TICKER
modify_fields = ['open','high','low','close']
used_columns = ['date','close']

# %%
# df_stock_test_ = get_baseline(
#         ticker='AXP', 
#         start = TEST_START_DATE,
#         end = TEST_END_DATE)
# df_stock_test_

# %%
# for field in modify_fields:
#     df_stock_test_[field] = df_stock_test_[field]/df_stock_test_.iloc[0][field]/len(test_portfolio)
# df_stock_test_ = df_stock_test_[used_columns]

# %%
#baseline stats
print("==============Get Baseline Stats===========")
shape = daily_account_value.shape
df_hold_ = pd.DataFrame(0,index=range(shape[0]), columns=range(shape[1]))
df_hold_.columns = used_columns
df_hold_['date'] = daily_account_value.date

for stock in test_portfolio:
    df_stock_ = get_baseline(
        ticker=stock, 
        start = TEST_START_DATE,
        end = TEST_END_DATE)
    # for field in modify_fields:
    if len(df_stock_) < len(df_hold_):
        final_row = df_stock_.iloc[-1]
        new_rows = pd.DataFrame([final_row] * (len(df_hold_) - len(df_stock_)))
        df_stock_ = pd.concat([df_stock_, new_rows], ignore_index=True)
        
        for i in range(0,len(df_stock_) < len(df_hold_)):
            df_stock_.iloc[en(df_stock_)] = df_stock_.iloc[len(df_stock_-1)]
    df_stock_['close'] = df_stock_['close']/df_stock_.iloc[0]['close']/len(test_portfolio)
    df_hold_['close'] = df_hold_.close + df_stock_.close

stats = backtest_stats(df_hold_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Shape of DataFrame:  (809, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (809, 8)
# Annual return           0.415405
# Cumulative returns      0.055238
# Annual volatility       0.142013
# Sharpe ratio            2.581803
# Calmar ratio           10.349362
# Stability               0.407411
# Max drawdown           -0.040138
# Omega ratio             1.575704
# Sortino ratio           3.763793
# Skew                         NaN
# Kurtosis                     NaN
# Tail ratio              0.848874
# Daily value at risk    -0.016437
# dtype: float64

# %% [markdown]
# The model' calculation encompass the entire timeframe, including non-working days. To address this, we need to determine the most appropriate method to fill up the weekend plots, for example backfilling.

# %%
# df_hold_.date = pd.to_datetime(df_hold_['date'])
# df_hold_ = pd.merge(df_account_value_ppo['date'],df_hold_,how='left')
# df_hold_.bfill(inplace=True)
# df_hold_

# %%
df_hold = pd.DataFrame()
df_hold['date'] = daily_account_value['date']
df_hold['hold'] = df_hold_['close'] / df_hold_['close'][0] * env_kwargs["initial_amount"]
# print("df_hold: ", df_hold)
# df_dji.to_csv("df_dji.csv")
df_hold = df_hold.set_index(df_hold.columns[0])
print("df_hold: ", df_hold)
# df_hold.to_csv("df_dji+.csv")

# df_account_value.to_csv('df_account_value.csv')
# Out:
# df_hold:                      hold
# date
# 2021-01-31  1.000000e+06
# 2021-02-28  1.006314e+06
# 2021-03-31  1.021052e+06
# 2021-04-30  1.029017e+06
# 2021-05-31  1.030249e+06
# 2021-06-30  1.029785e+06
# 2021-07-31  1.033666e+06
# 2021-08-31  1.035076e+06
# 2021-09-30  1.035051e+06
# 2021-10-31  1.026937e+06
# 2021-11-30  1.030746e+06
# 2021-12-31  1.039045e+06
# 2022-01-31  1.038597e+06
# 2022-02-28  1.029507e+06
# 2022-03-31  1.028421e+06
# 2022-04-30  1.027227e+06
# 2022-05-31  1.009060e+06
# 2022-06-30  1.018215e+06
# 2022-07-31  9.973398e+05
# 2022-08-31  1.004524e+06
# 2022-09-30  1.018989e+06
# 2022-10-31  1.020445e+06
# 2022-11-30  1.033378e+06
# 2022-12-31  1.038320e+06
# 2023-01-31  1.046430e+06
# 2023-02-28  1.044933e+06
# 2023-03-31  1.047083e+06
# 2023-04-30  1.047593e+06
# 2023-05-31  1.049621e+06
# 2023-06-30  1.051232e+06
# 2023-07-31  1.054914e+06
# 2023-08-31  1.050851e+06
# 2023-09-30  1.052054e+06
# 2023-10-31  1.054023e+06
# 2023-11-30  1.055057e+06
# 2023-12-31  1.069562e+06
# 2024-01-31  1.051501e+06
# 2024-02-29  1.034710e+06
# 2024-03-31  1.055238e+06

# %%
print("==============Compare to Buy&Hold===========")
df_result = pd.DataFrame({'date': df_account_value_ppo['date'], 'stock': df_account_value_ppo['account_value']})
df_result = df_result.set_index('date')

result = pd.DataFrame()
result = pd.merge(df_result, df_hold, left_index=True, right_index=True)
print("result: ", result)
# result.to_csv("result.csv")
result.columns = ['model', 'buy_and_hold']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# ==============Compare to Buy&Hold===========
# result:                     stock          hold
# date
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# 2021-01-31  1.000000e+06  1.000000e+06
# ...                  ...           ...
# 2024-02-29  1.380588e+06  1.034710e+06
# 2024-02-29  1.380471e+06  1.034710e+06
# 2024-02-29  1.380471e+06  1.034710e+06
# 2024-02-29  1.380471e+06  1.034710e+06
# 2024-02-29  1.380407e+06  1.034710e+06
#
# [1140 rows x 2 columns]

# %% [markdown]
# <a id='7'></a>
# # 8. Save and load model #

# %% [markdown]
# <a id='7.1'></a>
# ## 8.1 Save model

# %% [markdown]
# ### 8.1.1 Save trained model

# %%
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/DeepReinforcementLearning/FinRL-Tutorials-master/6-Binhlai_Testing
# ERROR! Session/line number was not unique in database. History logging moved to new session 2

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/main_dow30_randomTic_discrete_standadized_shortSell_64x3_ppo2_1m_steps"
model_name
# Out:
# './trained_models/main_dow30_randomTic_discrete_standadized_shortSell_64x3_ppo2_1m_steps'

# %%
trained_ppo.save(model_name)

# %% [markdown]
# ### 8.1.2 Save model as ONNX file

# %%
import torch as th
import torch.onnx
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import DDPG
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(trained_ppo.policy)
observation_size = trained_ppo.observation_space.shape
dummy_input = th.randn(1, *observation_size)

# th.onnx.export(
#     onnx_policy,
#     dummy_input,
#     "main_dow30_randomTic_discrete_shortSell_256neu_ppo_4m_steps.onnx",
#     opset_version=17,
#     input_names=["input"],
# )

# %%
onnx_policy
# Out:
# OnnxableSB3Policy(
#   (policy): ActorCriticPolicy(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (pi_features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (vf_features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (mlp_extractor): MlpExtractor(
#       (policy_net): Sequential(
#         (0): Linear(in_features=19, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=256, out_features=256, bias=True)
#         (3): Tanh()
#       )
#       (value_net): Sequential(
#         (0): Linear(in_features=19, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=256, out_features=256, bias=True)
#         (3): Tanh()
#       )
#     )
#     (action_net): Linear(in_features=256, out_features=3, bias=True)
#     (value_net): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# <a id='7.2'></a>
# ## 8.2 Load model

# %% [markdown]
# <a id='7.2.1'></a>
# ### 8.2.1 Load trained model

# %%
from stable_baselines3 import PPO
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/DeepReinforcementLearning/FinRL-Tutorials-master/6-Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/main_dow30_randomTic_discrete_standadized_shortSell_64x3_ppo_6m_steps"
model_name
# Out:
# './trained_models/main_dow30_randomTic_discrete_standadized_shortSell_64x3_ppo_6m_steps'

# %%
trained_model = PPO.load(model_name)

# %% [markdown]
# Continous training based on the previous model at [**Part5. Train DRL Agents**](#5)

# %%
# #Establish the training environment using StockTradingEnv() class
# agent = DRLAgent(env = env_train)
# trained_model.env = env_train

# %%
# trained_ppo = agent.train_model(model=trained_model, 
#                              tb_log_name='ppo',
#                              total_timesteps=total_training_step)

# %% [markdown]
# #### Test loaded model

# %%
test_env = StockTradingEnv(df = trade_data, **env_kwargs)

# %%
test_step = 1000
test_result = []
test_env.reset()
for i in range(0,test_step):
    observation = [test_env.state]
    observation = np.array(observation).astype(np.float32)
    actions, values, log_prob = ort_sess.run(None, {"input": observation})
    result = test_env.step(actions)
    test_result.append(result[1])
    if result[2] == True:
        break

# %% [markdown]
# ### 8.2.2 Load ONNX model

# %%
import onnx
import onnxruntime as ort
import numpy as np

# %%
onnx_path = "all_in_one_ppo.onnx"
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)

# # Check that the predictions are the same
# with th.no_grad():
#     print(model.policy(th.as_tensor(observation), deterministic=True))

# %%
observation = np.zeros((1, state_space)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
actions, values, log_prob = ort_sess.run(None, {"input": observation})
print(actions, values, log_prob)
