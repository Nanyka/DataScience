# %%
import pandas as pd

# %%
fund_data = pd.read_csv('./' + 'datasets/sp500_fundamental.csv',index_col=0)
fund_data
# Out:
#        tic        date  totalRevenue  costOfRevenue  \
# 0     WYNN  2023-12-31    6041535000     1856250000
# 1     WYNN  2022-12-31    3310708000     1581172000
# 2     WYNN  2021-12-31    3369783000     1529675000
# 3     WYNN  2020-12-31    1656561000     1452857000
# 4     WYNN  2019-12-31    6181404000     1623557000
# ...    ...         ...           ...            ...
# 6776   DLR  2014-12-31    1616438000     1239395000
# 6777   DLR  2013-12-31    1482259000     1094847000
# 6778   DLR  2012-12-31    1279067000      912989000
# 6779   DLR  2011-12-31    1062710000      884076000
# 6780   DLR  2010-12-31     865401000       90400000
#
#       sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                        1.065022e+09                     0.0   625000000.0
# 1                        8.304500e+08                     0.0   652100000.0
# 2                        7.965920e+08                     0.0   685700000.0
# 3                        7.208490e+08                     0.0   699600000.0
# 4                        8.966700e+08                     0.0   602900000.0
# ...                               ...                     ...           ...
# 6776                     9.318800e+07                     0.0           0.0
# 6777                     6.565300e+07                     0.0           0.0
# 6778                     5.720900e+07                     0.0           0.0
# 6779                     5.362400e+07                     0.0           0.0
# 6780                     4.719600e+07                     0.0           0.0
#
#       interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0         751509000.0             2.200454e+09        -496834000  ...
# 1         650885000.0             1.811423e+09           9332000  ...
# 2         605562000.0             1.287880e+09            474000  ...
# 3         556474000.0             1.880888e+09         564671000  ...
# 4         414030000.0             1.982884e+09         176840000  ...
# ...               ...                      ...               ...  ...
# 6776      191085000.0             1.252657e+09           5238000  ...
# 6777      189399000.0             1.489864e+09           1292000  ...
# 6778      157108000.0             1.463590e+09           2647000  ...
# 6779      149350000.0             3.905880e+08            -42000  ...
# 6780      137384000.0             2.888410e+08           1851000  ...
#
#       retainedEarnings  dividendPayoutCommonStock  \
# 0        -2.066953e+09                 84733000.0
# 1        -2.711808e+09                  1445000.0
# 2        -2.288078e+09                  1553000.0
# 3        -1.532420e+09                108777000.0
# 4         6.418180e+08                566521000.0
# ...                ...                        ...
# 6776     -1.096603e+09                441694000.0
# 6777     -7.852220e+08                400953000.0
# 6778     -6.561040e+08                334429000.0
# 6779     -4.886920e+08                261286000.0
# 6780     -3.481480e+08                171549000.0
#
#       paymentsForRepurchaseOfCommonStock  treasuryStock  currentLongTermDebt  \
# 0                            212455000.0   1.836326e+09         7.095930e+08
# 1                            187499000.0   1.623872e+09         5.475430e+08
# 2                             13842000.0   1.436373e+09         5.000000e+07
# 3                             11533000.0   1.422531e+09         5.964080e+08
# 4                             66986000.0   1.410998e+09         3.238760e+08
# ...                                  ...            ...                  ...
# 6776                                 0.0   0.000000e+00         4.673127e+09
# 6777                                 0.0   0.000000e+00         0.000000e+00
# 6778                                 0.0   0.000000e+00         0.000000e+00
# 6779                                 0.0   0.000000e+00         0.000000e+00
# 6780                                 0.0   0.000000e+00         0.000000e+00
#
#             open        high         low       close     volume
# 0      90.830002   95.680000   90.680000   94.376312  3013600.0
# 1      86.120003   86.500000   83.930000   84.742332  3318600.0
# 2      85.510002   86.839996   84.889999   84.178108  2406200.0
# 3     112.769997  113.919998  110.059998  111.686455  2103400.0
# 4     138.660004  140.070007  138.250000  136.318619  1142600.0
# ...          ...         ...         ...         ...        ...
# 6776   67.139999   67.900002   66.190002   46.811867   653700.0
# 6777   48.750000   49.419998   48.700001   32.833439  1259300.0
# 6778   67.379997   67.980003   67.230003   42.913818   757000.0
# 6779   67.830002   68.010002   65.879997   40.241833   866200.0
# 6780   51.779999   52.380001   51.450001   29.862902  1427300.0
#
# [6781 rows x 33 columns]

# %%
demo_data = fund_data[fund_data.tic == 'AAPL'].reset_index(drop=True)
demo_data
# Out:
#      tic        date  totalRevenue  costOfRevenue  \
# 0   AAPL  2023-09-30  379352000000   239069000000
# 1   AAPL  2022-09-30  391397000000   248640000000
# 2   AAPL  2021-09-30  363172000000   234954000000
# 3   AAPL  2020-09-30  271642000000   189475000000
# 4   AAPL  2019-09-30  256598000000   180027000000
# 5   AAPL  2018-09-30  265595000000   163756000000
# 6   AAPL  2017-09-30  229234000000   141048000000
# 7   AAPL  2016-09-30  215639000000   131376000000
# 8   AAPL  2015-09-30  232982000000   163618000000
# 9   AAPL  2014-09-30  182411000000   131151000000
# 10  AAPL  2013-09-30  170774000000   123236000000
# 11  AAPL  2012-09-30  156508000000   100486000000
# 12  AAPL  2011-09-30  108249000000    73630000000
# 13  AAPL  2010-09-30   65225000000    45873000000
# 14  AAPL  2009-09-30   42905000000    29832000000
#
#     sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                      2.493200e+10            2.991500e+10  8.500000e+09
# 1                      2.509400e+10            2.625100e+10  8.700000e+09
# 2                      2.197300e+10            2.191400e+10  9.500000e+09
# 3                      1.991600e+10            1.875200e+10  9.700000e+09
# 4                      1.824500e+10            1.621700e+10  1.130000e+10
# 5                      1.670500e+10            1.423600e+10  9.300000e+09
# 6                      1.526100e+10            1.158100e+10  8.200000e+09
# 7                      1.419400e+10            1.004500e+10  8.300000e+09
# 8                      1.432900e+10            8.067000e+09  0.000000e+00
# 9                      1.199300e+10            6.041000e+09  0.000000e+00
# 10                     1.083000e+10            4.475000e+09  0.000000e+00
# 11                     1.004000e+10            3.381000e+09  0.000000e+00
# 12                     7.599000e+09            2.429000e+09  0.000000e+00
# 13                     5.517000e+09            1.782000e+09  0.000000e+00
# 14                     4.149000e+09            1.333000e+09  0.000000e+00
#
#     interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0      3.933000e+09             1.453080e+11       16741000000  ...
# 1      2.931000e+09             1.539820e+11       19300000000  ...
# 2      2.645000e+09             1.254810e+11       14527000000  ...
# 3      2.873000e+09             1.053920e+11        9680000000  ...
# 4      3.576000e+09             1.057180e+11       10481000000  ...
# 5      3.240000e+09             1.159290e+11       13372000000  ...
# 6      2.323000e+09             1.008140e+11       15738000000  ...
# 7      1.456000e+09             7.900600e+10       15685000000  ...
# 8      7.330000e+08             8.061000e+10       19121000000  ...
# 9      3.840000e+08             6.344800e+10       13973000000  ...
# 10     1.360000e+08             4.365800e+10       13118000000  ...
# 11     0.000000e+00             3.854200e+10       14030000000  ...
# 12     0.000000e+00             2.797000e+10        8283000000  ...
# 13     1.550000e+08             2.072200e+10        4527000000  ...
# 14     3.260000e+08             1.150600e+10        3831000000  ...
#
#     retainedEarnings  dividendPayoutCommonStock  \
# 0      -2.140000e+08               1.502500e+10
# 1      -3.068000e+09               1.484100e+10
# 2       5.562000e+09               1.446700e+10
# 3       1.496600e+10               1.408100e+10
# 4       4.589800e+10               1.411900e+10
# 5       7.040000e+10               1.371200e+10
# 6       9.833000e+10               1.256300e+10
# 7       9.636400e+10               1.196500e+10
# 8       9.228400e+10               1.156100e+10
# 9       8.715200e+10               1.112600e+10
# 10      1.042560e+11               1.056400e+10
# 11      1.012890e+11               2.488000e+09
# 12      6.284100e+10               0.000000e+00
# 13      3.716900e+10               0.000000e+00
# 14      2.335300e+10               0.000000e+00
#
#     paymentsForRepurchaseOfCommonStock  treasuryStock  currentLongTermDebt  \
# 0                         7.755000e+10            0.0         9.822000e+09
# 1                         8.940200e+10            0.0         1.112800e+10
# 2                         8.597100e+10            0.0         9.613000e+09
# 3                         7.235800e+10            0.0         8.773000e+09
# 4                         6.689700e+10            0.0         1.026000e+10
# 5                         7.273800e+10            0.0         8.784000e+09
# 6                         3.290000e+10            0.0         6.496000e+09
# 7                         2.972200e+10            0.0         3.500000e+09
# 8                         3.525300e+10            0.0         2.500000e+09
# 9                         4.500000e+10            0.0         0.000000e+00
# 10                        2.286000e+10            0.0         0.000000e+00
# 11                        0.000000e+00            0.0         0.000000e+00
# 12                        0.000000e+00            0.0         0.000000e+00
# 13                        0.000000e+00            0.0         0.000000e+00
# 14                        0.000000e+00            0.0         0.000000e+00
#
#           open        high         low       close       volume
# 0   171.220001  174.300003  170.929993  173.300247   52164500.0
# 1   141.279999  143.100006  138.000000  137.029373  124925300.0
# 2   143.660004  144.380005  141.279999  139.519592   89056700.0
# 3   113.790001  117.260002  113.620003  113.459412  142675200.0
# 4    55.224998   56.145000   55.197498   54.317093  103909600.0
# 5    56.987499   57.355000   56.587502   54.272793   94403200.0
# 6    38.564999   38.612499   38.180000   36.184814   74795200.0
# 7    28.115000   28.342501   27.950001   26.134754  145516400.0
# 8    27.542500   27.885000   27.182501   24.965233  265892000.0
# 9    25.202499   25.385000   25.132500   22.420414  221056400.0
# 10   17.044643   17.202143   16.943214   14.821681  260156400.0
# 11   23.969999   24.169643   23.446428   20.022720  543594800.0
# 12   13.825714   13.888929   13.613571   11.529477  547640800.0
# 13   10.321429   10.357143   10.044643    8.579379  673391600.0
# 14    6.647500    6.658929    6.521786    5.604187  539585200.0
#
# [15 rows x 33 columns]

# %%
demo_data.to_csv('demo_fund_data_appl.csv')

# %%
from stable_baselines3 import PPO
import os
current_dir = os.getcwd()

model_name = "./"+"/trained_models/main_dow30_randomTic_discrete_shortSell_256neu_ppo_4m_steps"
model_name

trained_model = PPO.load(model_name)

# %% [markdown]
# # SAVE MODEL AS A ONNX FILE

# %%
# !pip3 install onnx
# Out:
# Collecting onnx
#   Using cached onnx-1.15.0-cp310-cp310-macosx_10_12_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /Users/admin/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages (from onnx) (4.25.3)
# Using cached onnx-1.15.0-cp310-cp310-macosx_10_12_x86_64.whl (14.9 MB)
# Installing collected packages: onnx
# Successfully installed onnx-1.15.0

# %%
import torch as th
import torch.onnx
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import DDPG
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(trained_model.policy)
observation_size = trained_model.observation_space.shape
dummy_input = th.randn(1, *observation_size)

th.onnx.export(
    onnx_policy,
    dummy_input,
    "main_dow30_randomTic_discrete_shortSell_256neu_ppo_4m_steps.onnx",
    opset_version=17,
    input_names=["input"],
)
