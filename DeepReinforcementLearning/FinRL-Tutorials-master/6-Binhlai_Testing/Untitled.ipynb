# %%
import pandas as pd

# %%
fund_data = pd.read_csv('./' + 'datasets/DataForGame.csv',index_col=0)
fund_data
# Out:
#              date   tic       close  gross_profit_margin  sga_ratio  \
# 0      2021-01-04  AAPL  127.002121             0.315783   0.223707
# 1      2021-01-04  AMGN  204.389359             0.711232   0.315051
# 2      2021-01-04   AXP  113.141533             0.168618   1.757511
# 3      2021-01-04    BA  202.720001            -0.096149  -0.822932
# 4      2021-01-04   CAT  170.039978             0.303390   0.366280
# ...           ...   ...         ...                  ...        ...
# 24145  2024-03-15   UNH  490.820007             0.737986   0.199189
# 24146  2024-03-15     V  283.040009             0.704715   0.118495
# 24147  2024-03-15    VZ   39.490002             0.567685   0.430544
# 24148  2024-03-15   WBA   20.820000            -0.066540  -3.659463
# 24149  2024-03-15   WMT   60.680000             0.243754   0.829020
#
#        dep_ratio  ebit_on_int  profit_margin  count_positive_profit  \
# 0       0.106490    26.533518       0.199342               7.736986
# ...

# %%
demo_data = fund_data[fund_data.tic == 'AAPL'].reset_index(drop=True)
demo_data
# Out:
#            date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0    2021-01-04  AAPL  127.002121             0.315783   0.223707   0.106490
# 1    2021-01-05  AAPL  128.572311             0.315921   0.223513   0.106370
# 2    2021-01-06  AAPL  124.244370             0.316060   0.223318   0.106249
# 3    2021-01-07  AAPL  128.484009             0.316198   0.223124   0.106129
# 4    2021-01-08  AAPL  129.593002             0.316337   0.222929   0.106009
# ..          ...   ...         ...                  ...        ...        ...
# 800  2024-03-11  AAPL  172.750000             0.369796   0.177726   0.060592
# 801  2024-03-12  AAPL  173.229996             0.369796   0.177726   0.060592
# 802  2024-03-13  AAPL  171.130005             0.369796   0.177726   0.060592
# 803  2024-03-14  AAPL  173.000000             0.369796   0.177726   0.060592
# 804  2024-03-15  AAPL  172.619995             0.369796   0.177726   0.060592
#
# ...

# %%
demo_data.to_csv('demo_data_appl.csv')
