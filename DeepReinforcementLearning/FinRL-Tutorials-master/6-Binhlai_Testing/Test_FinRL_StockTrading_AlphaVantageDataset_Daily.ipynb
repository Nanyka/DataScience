# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch
# ## BinhLai_Dataset_Daily

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess fundamental data](#3)
#     * [4.1. Import the financial data](#3.1)
#     * [4.2. Specify items needed to calculate financial ratios](#3.2)
#     * [4.3. Turn the final_ratios to daily basis](#3.3)
#     * [4.4. Merge stock price data and ratios into one dataframe](#3.4)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. Set up the training environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Train DRL Agent](#5)
# * [7.Backtest Our Strategy](#6)
#     * [7.1. BackTest with DJIA](#6.1)
#     * [7.2. BackTest with Buy&Hold Strategy](#6.2)
# * [8.Save & load model](#7)
#     * [8.1. Save model](#7.1)
#     * [8.2. Load model](#7.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
import math
from stable_baselines3.common.logger import configure

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
# from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
from datetime import datetime
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-01-01'
TEST_START_DATE = '2020-01-01'
TEST_END_DATE = datetime.today().strftime('%Y-%m-%d')

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER[:2]).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (7652, 8)

# %%
df.head()
# Out:
#          date       open       high    low      close    volume   tic  day
# 0  2009-01-02  58.590000  59.080002  57.75  42.406387   6547900  AMGN    4
# 1  2009-01-02  18.570000  19.520000  18.40  15.144920  10955700   AXP    4
# 2  2009-01-05  59.220001  59.650002  58.00  42.880844  10940100  AMGN    0
# 3  2009-01-05  19.200001  20.240000  19.00  15.630692  16019200   AXP    0
# 4  2009-01-06  60.040001  60.150002  57.75  41.939125   8974000  AMGN    1

# %%
df.tail()
# Out:
#             date        open        high         low       close   volume  \
# 7647  2024-03-13  223.139999  223.490005  221.869995  222.809998  2693100
# 7648  2024-03-14  276.839996  277.230011  270.450012  271.540009  2370500
# 7649  2024-03-14  224.279999  224.289993  219.100006  220.470001  2417900
# 7650  2024-03-15  272.089996  275.179993  268.170013  268.869995  8794200
# 7651  2024-03-15  220.979996  221.600006  217.220001  218.460007  5266600
#
#        tic  day
# 7647   AXP    2
# 7648  AMGN    3
# 7649   AXP    3
# 7650  AMGN    4
# 7651   AXP    4

# %%
df.shape
# Out:
# (7652, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high    low      close    volume   tic  day
# 0  2009-01-02  58.590000  59.080002  57.75  42.406387   6547900  AMGN    4
# 1  2009-01-02  18.570000  19.520000  18.40  15.144920  10955700   AXP    4
# 2  2009-01-05  59.220001  59.650002  58.00  42.880844  10940100  AMGN    0
# 3  2009-01-05  19.200001  20.240000  19.00  15.630692  16019200   AXP    0
# 4  2009-01-06  60.040001  60.150002  57.75  41.939125   8974000  AMGN    1

# %%
len(df.tic.unique())
# Out:
# 2

# %%
df.tic.value_counts()
# Out:
# tic
# AMGN    3826
# AXP     3826
# Name: count, dtype: int64

# %% [markdown]
# <a id='3'></a>
# # Part 4: Preprocess fundamental data
# - Import finanical data downloaded from Alpha Vantage
# - Preprocess the dataset and calculate financial ratios
# - Turn yearly ratio into daily basis

# %% [markdown]
# <a id='3.1'></a>
# ## 4.1 Import the financial data

# %% [markdown]
# #### Define configurations of the collecting data & download data via Alpha Vantage API

# %%
import requests

api_key = 'EEAI5CE759SUIP6I'
features_cols = ['fiscalDateEnding','totalRevenue','costOfRevenue','sellingGeneralAndAdministrative','researchAndDevelopment','depreciation','interestExpense','totalCurrentLiabilities','incomeTaxExpense','netIncome','commonStockSharesOutstanding','cashAndCashEquivalentsAtCarryingValue','cashAndShortTermInvestments','operatingCashflow','totalLiabilities','inventory','currentNetReceivables','propertyPlantEquipment','capitalExpenditures','longTermInvestments','totalShareholderEquity','longTermDebt','retainedEarnings','dividendPayoutCommonStock','paymentsForRepurchaseOfCommonStock','treasuryStock','currentLongTermDebt']
price_cols = ['open','high','low','close','volume']

# %% [markdown]
# Function to download fundamental data from financial reports by ticket

# %%
def collect_fundamental(ticket):
    # Download income statement
    url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticket}&apikey={api_key}'
    r = requests.get(url)
    data_is = r.json()

    # Download balance sheet
    url = f'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticket}&apikey={api_key}'
    r = requests.get(url)
    data_bs = r.json()

    # Download cash flow
    url = f'https://www.alphavantage.co/query?function=CASH_FLOW&symbol={ticket}&apikey={api_key}'
    r = requests.get(url)
    data_cf = r.json()

    df_is = pd.json_normalize(data_is['annualReports'])
    df_bs = pd.json_normalize(data_bs['annualReports'])
    df_cf = pd.json_normalize(data_cf['annualReports'])

    merged_df = df_is.merge(df_bs).merge(df_cf)
    merged_df = merged_df[features_cols]
    merged_df['fiscalDateEnding'] = pd.to_datetime(merged_df.fiscalDateEnding,format='mixed')

    return merged_df

# %% [markdown]
# Function to download stock price by ticket

# %%
def collect_price(ticket):
    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol={ticket}&apikey={api_key}'
    r = requests.get(url)
    data_monthly_price = r.json()

    price_monthly = pd.DataFrame.from_dict(data_monthly_price['Monthly Time Series'], orient='index')
    price_monthly.columns = price_cols
    price_monthly['fiscalDateEnding'] = pd.to_datetime(price_monthly.index,format='mixed')
    price_monthly.reset_index(inplace=True,drop=True)
    price_monthly = price_monthly[['fiscalDateEnding','open','high','low','close','volume']]
    return price_monthly

# %% [markdown]
# Function to merge monthly stock price into yearly fundamental data

# %%
def merge_price_to_df(merged_df,price_monthly):
    merged_df['year'] = merged_df.fiscalDateEnding.dt.year
    merged_df['month'] = merged_df.fiscalDateEnding.dt.month
    price_monthly['year'] = price_monthly.fiscalDateEnding.dt.year
    price_monthly['month'] = price_monthly.fiscalDateEnding.dt.month
    merged_final = pd.merge(merged_df,price_monthly,how="left",on=['year','month'])
    merged_final.drop(columns=['year','month','fiscalDateEnding_y'],inplace=True)
    merged_final = df_final.rename(columns={'fiscalDateEnding_x': 'date'})
    merged_final['tic'] = ticket

    merged_columns = [merged_final.columns[-1]]
    for i in range(0,len(merged_final.columns)-1):
        merged_columns.append(merged_final.columns[i])
    merged_final = merged_final[merged_columns]
    
    return merged_final

# %%
fund_cols = ['tic','totalRevenue','costOfRevenue','sellingGeneralAndAdministrative','researchAndDevelopment','depreciation','interestExpense','totalCurrentLiabilities','incomeTaxExpense','netIncome','commonStockSharesOutstanding','cashAndCashEquivalentsAtCarryingValue','cashAndShortTermInvestments','operatingCashflow','totalLiabilities','inventory','currentNetReceivables','propertyPlantEquipment','capitalExpenditures','longTermInvestments','totalShareholderEquity','longTermDebt','retainedEarnings','dividendPayoutCommonStock','paymentsForRepurchaseOfCommonStock','treasuryStock','currentLongTermDebt']
fund_cols = fund_cols + price_cols
len(fund_cols)
# Out:
# 32

# %%
first_10 = DOW_30_TICKER[2:10]
first_10
# Out:
# ['AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON']

# %%
fund_data = pd.DataFrame()

for ticket in DOW_30_TICKER[2:10]:
    df_fund = collect_fundamental(ticket)
    price = collect_price(ticket)
    merged_df = merge_price_to_df(df,price)
    fund_data = pd.concat([fund_data, merged_df], ignore_index=True)

# ticket = 'AAPL'
# df = collect_fundamental(ticket)
# price = collect_price(ticket)
# merged_df = merge_price_to_df(df,price)
# fund_data = pd.concat([fund_data, merged_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 4
#       1 fund_data = pd.DataFrame()
#       3 for ticket in DOW_30_TICKER[2:10]:
# ----> 4     df_fund = collect_fundamental(ticket)
#       5     price = collect_price(ticket)
#       6     merged_df = merge_price_to_df(df,price)
#
# Cell In[14], line 17, in collect_fundamental(ticket)
#      14 r = requests.get(url)
#      15 data_cf = r.json()
# ---> 17 df_is = pd.json_normalize(data_is['annualReports'])
#      18 df_bs = pd.json_normalize(data_bs['annualReports'])
#      19 df_cf = pd.json_normalize(data_cf['annualReports'])
#
# KeyError: 'annualReports'

# %%
fund_data.to_csv('dow30_1.csv')

# %% [markdown]
# #### Check reach download limitation

# %%
# url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=AAPL&apikey=GUKB8WJD0YFELJD3'
# r = requests.get(url)
# data_is = r.json()
# data_is

# %% [markdown]
# #### Load data from csv file

# %%
fund_data = pd.read_csv('dow30_1.csv',index_col=0)
fund_data = fund_data.rename(columns={'fiscalDateEnding_x':'date'})
fund_data.head()
# Out:
#    tic        date  totalRevenue  costOfRevenue  \
# 0  AXP  2023-12-31   67364000000    50002000000
# 1  AXP  2022-12-31   55625000000    43277000000
# 2  AXP  2021-12-31   43663000000    31691000000
# 3  AXP  2020-12-31   38185000000    31791000000
# 4  AXP  2019-12-31   47020000000    35127000000
#
#    sellingGeneralAndAdministrative  researchAndDevelopment  depreciation  \
# 0                      13513000000                     NaN           NaN
# 1                      13036000000                     NaN           NaN
# 2                      11498000000                     NaN           NaN
# 3                      11294000000                     NaN           NaN
# 4                      11804000000                     NaN           NaN
#
#    interestExpense  totalCurrentLiabilities  incomeTaxExpense  ...  \
# 0       6849000000               3860000000        2139000000  ...
# 1       2763000000               3878000000        2071000000  ...
# 2       1283000000               4771000000        2629000000  ...
# 3       2098000000               4214000000        1161000000  ...
# 4       3464000000               8871000000        1670000000  ...
#
#    retainedEarnings  dividendPayoutCommonStock  \
# 0       19612000000                 1780000000
# 1       16279000000                 1565000000
# 2       13474000000                 1448000000
# 3       13837000000                 1474000000
# 4       13871000000                 1422000000
#
#    paymentsForRepurchaseOfCommonStock  treasuryStock  currentLongTermDebt  \
# 0                        3.650000e+09            NaN         1.293000e+09
# 1                        3.502000e+09            NaN         1.000000e+09
# 2                        7.652000e+09   -271000000.0         2.000000e+09
# 3                        1.029000e+09   -279000000.0         2.000000e+09
# 4                                 NaN   -292000000.0         6.442000e+09
#
#      open    high     low   close    volume
# 0  170.67  188.30  165.93  187.34  66652096
# 1  157.72  161.55  142.72  147.75  53953591
# 2  156.10  170.58  149.89  163.60  83511760
# 3  120.32  125.32  113.72  120.91  77371622
# 4  120.31  126.33  114.65  124.49  63680336
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Data cleaning ####
# Refine the data before computing fundamental ratios

# %%
print(fund_data.info(),'\n')
print(fund_data.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 29
# Data columns (total 33 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tic                                    30 non-null     object
#  1   date                                   30 non-null     object
#  2   totalRevenue                           30 non-null     int64
#  3   costOfRevenue                          30 non-null     int64
#  4   sellingGeneralAndAdministrative        30 non-null     int64
#  5   researchAndDevelopment                 15 non-null     float64
#  6   depreciation                           15 non-null     float64
#  7   interestExpense                        30 non-null     int64
#  8   totalCurrentLiabilities                30 non-null     int64
#  9   incomeTaxExpense                       30 non-null     int64
#  10  netIncome                              30 non-null     int64
#  11  commonStockSharesOutstanding           30 non-null     int64
#  12  cashAndCashEquivalentsAtCarryingValue  30 non-null     int64
#  13  cashAndShortTermInvestments            30 non-null     int64
#  14  operatingCashflow                      30 non-null     int64
#  15  totalLiabilities                       30 non-null     int64
#  16  inventory                              21 non-null     float64
#  17  currentNetReceivables                  15 non-null     float64
#  18  propertyPlantEquipment                 30 non-null     int64
#  19  capitalExpenditures                    30 non-null     int64
#  20  longTermInvestments                    20 non-null     float64
#  21  totalShareholderEquity                 30 non-null     int64
#  22  longTermDebt                           30 non-null     int64
#  23  retainedEarnings                       30 non-null     int64
#  24  dividendPayoutCommonStock              30 non-null     int64
#  25  paymentsForRepurchaseOfCommonStock     29 non-null     float64
#  26  treasuryStock                          5 non-null      float64
#  27  currentLongTermDebt                    24 non-null     float64
#  28  open                                   30 non-null     float64
#  29  high                                   30 non-null     float64
#  30  low                                    30 non-null     float64
#  31  close                                  30 non-null     float64
#  32  volume                                 30 non-null     int64
# dtypes: float64(12), int64(19), object(2)
# memory usage: 8.0+ KB
# None
#
# tic                                       0
# date                                      0
# totalRevenue                              0
# costOfRevenue                             0
# sellingGeneralAndAdministrative           0
# researchAndDevelopment                   15
# depreciation                             15
# interestExpense                           0
# totalCurrentLiabilities                   0
# incomeTaxExpense                          0
# netIncome                                 0
# commonStockSharesOutstanding              0
# cashAndCashEquivalentsAtCarryingValue     0
# cashAndShortTermInvestments               0
# operatingCashflow                         0
# totalLiabilities                          0
# inventory                                 9
# currentNetReceivables                    15
# propertyPlantEquipment                    0
# capitalExpenditures                       0
# longTermInvestments                      10
# totalShareholderEquity                    0
# longTermDebt                              0
# retainedEarnings                          0
# dividendPayoutCommonStock                 0
# paymentsForRepurchaseOfCommonStock        1
# treasuryStock                            25
# currentLongTermDebt                       6
# open                                      0
# high                                      0
# low                                       0
# close                                     0
# volume                                    0
# dtype: int64

# %% [markdown]
# Those features, expect date as datatime64 and tic as string, is required to turn them into numeric datatype or float.<br>
# Before adjusting datatypes, checking unique values in each features is neccessary to ensure dataset clearn from missing data and nan data points

# %%
fund_data = fund_data.fillna(0)
# for i in fund_data.columns:
#     print(i,'\n',fund_data[i].unique(),'\n')

# %% [markdown]
# 'None' value is replaced with '0' and correcting datatype can now being apply on the features. In this case, all data points must be turned into float instead of object.

# %%
float_columns = fund_data.columns
float_columns = float_columns.drop(['date','tic'])

for column in float_columns:
    fund_data[column] = fund_data[column].astype(float)

fund_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 29
# Data columns (total 33 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   tic                                    30 non-null     object
#  1   date                                   30 non-null     object
#  2   totalRevenue                           30 non-null     float64
#  3   costOfRevenue                          30 non-null     float64
#  4   sellingGeneralAndAdministrative        30 non-null     float64
#  5   researchAndDevelopment                 30 non-null     float64
#  6   depreciation                           30 non-null     float64
#  7   interestExpense                        30 non-null     float64
#  8   totalCurrentLiabilities                30 non-null     float64
#  9   incomeTaxExpense                       30 non-null     float64
#  10  netIncome                              30 non-null     float64
#  11  commonStockSharesOutstanding           30 non-null     float64
#  12  cashAndCashEquivalentsAtCarryingValue  30 non-null     float64
#  13  cashAndShortTermInvestments            30 non-null     float64
#  14  operatingCashflow                      30 non-null     float64
#  15  totalLiabilities                       30 non-null     float64
#  16  inventory                              30 non-null     float64
#  17  currentNetReceivables                  30 non-null     float64
#  18  propertyPlantEquipment                 30 non-null     float64
#  19  capitalExpenditures                    30 non-null     float64
#  20  longTermInvestments                    30 non-null     float64
#  21  totalShareholderEquity                 30 non-null     float64
#  22  longTermDebt                           30 non-null     float64
#  23  retainedEarnings                       30 non-null     float64
#  24  dividendPayoutCommonStock              30 non-null     float64
#  25  paymentsForRepurchaseOfCommonStock     30 non-null     float64
#  26  treasuryStock                          30 non-null     float64
#  27  currentLongTermDebt                    30 non-null     float64
#  28  open                                   30 non-null     float64
#  29  high                                   30 non-null     float64
#  30  low                                    30 non-null     float64
#  31  close                                  30 non-null     float64
#  32  volume                                 30 non-null     float64
# dtypes: float64(31), object(2)
# memory usage: 8.0+ KB

# %% [markdown]
# ## 4.2 Compute fundamental ratio

# %% [markdown]
# Define support functions before computing fundamental ratios

# %%
# Define a function to count positive values within a window
def count_positives(window):
  return window[window > 0].count()

def count_positives_window(data,k):
    df = pd.DataFrame(data, columns=['values'])

    # Create a new column with the adjusted positive count (using a shifted window)
    df['positive_count'] = df['values'].rolling(window=k, min_periods=1).apply(count_positives)

    # Set positive_count of the first k rows to positive_count of row k
    df.loc[:k-1,'positive_count'] = df.loc[k-1].positive_count

    return df

# %%
# Define a function to min value within a window
def get_min(window):
  return window.min()

def min_in_window(data,k):
    df = pd.DataFrame(data, columns=['values'])

    # Create a new column with the min in the window (using a shifted window)
    df['min'] = df['values'].rolling(window=k, min_periods=1).apply(get_min)

    return df

# %% [markdown]
# At this point, data and supporting functions are ready for computing fundamental ratios required

# %%
def compute_fund_ratios(df_final):
    pos_count_window = 10  # number of years to look back for count_positive_profit
    min_ebit_window = 4  # number of years to look back for min_ebit
    
    gross_income = df_final.totalRevenue - df_final.costOfRevenue
    ebit = gross_income - df_final.sellingGeneralAndAdministrative
    profit = ebit - df_final.interestExpense - df_final.incomeTaxExpense
    market_equity = df_final.commonStockSharesOutstanding * df_final.close
    market_asset = df_final.totalLiabilities + market_equity
    
    # Gross profit margin
    gross_profit_margin = (gross_income/df_final.totalRevenue).to_frame('gross_profit_margin')
    
    # SGA Expense / Gross Profit
    sga_ratio = (df_final.sellingGeneralAndAdministrative/gross_income).to_frame('sga_ratio')
    
    # Depreciation / Gross Profit
    dep_ratio = (df_final.depreciation/gross_income).to_frame('dep_ratio')
    
    # EBIT / Bond interest
    ebit_on_int = (ebit/df_final.interestExpense).to_frame('ebit_on_int')
    
    # Profit margin
    profit_margin = (profit/df_final.totalRevenue).to_frame('profit_margin')
    
    # Amount of positive profit within a window
    count_positive_profit = count_positives_window(profit,pos_count_window)
    count_positive_profit = count_positive_profit['positive_count'].to_frame('count_positive_profit')
    
    # Cash And Short Term Investments / Total Liabilities
    csti_on_liabilities = (df_final.cashAndShortTermInvestments/df_final.totalLiabilities).to_frame('csti_on_liabilities')
    
    # Inventory / EBIT
    inventory_on_ebit = (df_final.inventory / ebit).to_frame('inventory_on_ebit')
    
    # Receivable / Revenue
    receivable_on_rev = (df_final.currentNetReceivables / df_final.totalRevenue).to_frame('receivable_on_rev')
    
    # ROA
    roa = (profit / market_asset).to_frame('roa')
    
    # ROE
    roe = (profit / market_equity).to_frame('roe')
    
    # Long-term debt / minEBIT
    min_ebit = min_in_window(ebit,min_ebit_window)['min']
    debt_on_min_ebit = (df_final.longTermDebt / min_ebit).to_frame('debt_on_min_ebit')
    
    # Total Liabilities / Total Equity
    liabilities_on_equity = (df_final.totalLiabilities / market_equity).to_frame('liabilities_on_equity')
    
    # Capital Expenditures / EBIT
    capital_cost_on_ebit = (df_final.capitalExpenditures / ebit).to_frame('capital_cost_on_ebit')
    
    # EPS / MP
    eps = profit / df_final.commonStockSharesOutstanding
    eps_on_mp = (eps / df_final.close).to_frame('eps_on_mp')
    
    # Cash and Stock Dividend & Repurchase Common / MP
    dividend_on_mp = ((df_final.dividendPayoutCommonStock + df_final.paymentsForRepurchaseOfCommonStock) / df_final.close).to_frame('dividend_on_mp')
    
    # MP / BV
    mp_on_bv = (df_final.close / (df_final.cashAndShortTermInvestments + df_final.currentNetReceivables*0.8 +df_final.inventory*0.5 + df_final.propertyPlantEquipment*0.2 + df_final.longTermInvestments - df_final.totalLiabilities)).to_frame('mp_on_bv')

    # Create a dataframe that merges all the ratios
    ratios = pd.concat([df_final.date,df_final.tic,gross_profit_margin,sga_ratio,dep_ratio,
                    ebit_on_int,profit_margin,count_positive_profit,csti_on_liabilities,
                    inventory_on_ebit,receivable_on_rev,roa,roe,debt_on_min_ebit,
                   liabilities_on_equity,capital_cost_on_ebit,eps_on_mp,dividend_on_mp,mp_on_bv], axis=1)

    return ratios

# %%
ratios = compute_fund_ratios(fund_data)
ratios.head()
# Out:
#          date  tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 0  2023-12-31  AXP             0.257734   0.778309        0.0     0.561980
# 1  2022-12-31  AXP             0.221987   1.055718        0.0    -0.249005
# 2  2021-12-31  AXP             0.274191   0.960408        0.0     0.369447
# 3  2020-12-31  AXP             0.167448   1.766343        0.0    -2.335558
# 4  2019-12-31  AXP             0.252935   0.992517        0.0     0.025693
#
#    profit_margin  count_positive_profit  csti_on_liabilities  \
# 0      -0.076287                    1.0             0.198446
# 1      -0.099272                    1.0             0.165373
# 2      -0.078739                    1.0             0.130377
# 3      -0.213670                    1.0             0.193107
# 4      -0.107295                    1.0             0.137832
#
#    inventory_on_ebit  receivable_on_rev       roa       roe  debt_on_min_ebit  \
# 0          28.710314                0.0 -0.013946 -0.037941         12.435957
# 1         -53.305233                0.0 -0.017618 -0.050301        -61.879360
# 2         159.512658                0.0 -0.011820 -0.027615        -56.213663
# 3         -15.591633                0.0 -0.030706 -0.083826         -8.765714
# 4         907.033708                0.0 -0.018273 -0.050031        -11.803061
#
#    liabilities_on_equity  capital_cost_on_ebit  eps_on_mp  dividend_on_mp  \
# 0               1.720609              0.406080  -0.037941    2.898473e+07
# 1               1.855040             -2.696221  -0.050301    3.429442e+07
# 2               1.336318              3.270042  -0.027615    5.562347e+07
# 3               1.729976             -0.301633  -0.083826    2.070135e+07
# 4               1.737955             18.483146  -0.050031    1.142260e+07
#
#        mp_on_bv
# 0 -1.459757e-09
# 1 -1.014864e-09
# 2 -1.590235e-09
# 3 -1.619377e-09
# 4 -5.026406e-09

# %% [markdown]
# <a id='3.3'></a>
# ## 4.3 Turn the final_ratios to daily basis¶
# After our initial inspection, we’ll want to dig deeper to investigate the following:
# - The data type of each variable.
# - How discrete/categorical data is coded (and whether we need to make any changes).
# - How the data are scaled.
# - Whether there is missing data and how it is coded.
# - Whether there are outliers.
# - The distributions of continuous features.
# - The relationships between pairs of features.

# %% [markdown]
# ### Data types
# It is important to check the data type for each feature. <br>
# The **date** should be in datetime type <br>
# The **ratios** should be read in as float64 — and categorical variables should be stored as object

# %%
ratios['date'] = pd.to_datetime(ratios['date'],format='mixed')
ratios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 29
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   30 non-null     datetime64[ns]
#  1   tic                    30 non-null     object
#  2   gross_profit_margin    30 non-null     float64
#  3   sga_ratio              30 non-null     float64
#  4   dep_ratio              30 non-null     float64
#  5   ebit_on_int            30 non-null     float64
#  6   profit_margin          30 non-null     float64
#  7   count_positive_profit  30 non-null     float64
#  8   csti_on_liabilities    30 non-null     float64
#  9   inventory_on_ebit      30 non-null     float64
#  10  receivable_on_rev      30 non-null     float64
#  11  roa                    30 non-null     float64
#  12  roe                    30 non-null     float64
#  13  debt_on_min_ebit       30 non-null     float64
#  14  liabilities_on_equity  30 non-null     float64
#  15  capital_cost_on_ebit   30 non-null     float64
#  16  eps_on_mp              30 non-null     float64
#  17  dividend_on_mp         30 non-null     float64
#  18  mp_on_bv               30 non-null     float64
# dtypes: datetime64[ns](1), float64(17), object(1)
# memory usage: 5.7+ KB

# %%
ratios.isna().sum()
# Out:
# date                     0
# tic                      0
# gross_profit_margin      0
# sga_ratio                0
# dep_ratio                0
# ebit_on_int              0
# profit_margin            0
# count_positive_profit    0
# csti_on_liabilities      0
# inventory_on_ebit        0
# receivable_on_rev        0
# roa                      0
# roe                      0
# debt_on_min_ebit         0
# liabilities_on_equity    0
# capital_cost_on_ebit     0
# eps_on_mp                0
# dividend_on_mp           0
# mp_on_bv                 0
# dtype: int64

# %% [markdown]
# We see that there is no missing values in all ratios

# %%
# Replace NAs infinite values with zero
ratios = ratios.fillna(0)
ratios = ratios.replace(np.inf,0)

# %%
ratios.head()
# Out:
#         date  tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 0 2023-12-31  AXP             0.257734   0.778309        0.0     0.561980
# 1 2022-12-31  AXP             0.221987   1.055718        0.0    -0.249005
# 2 2021-12-31  AXP             0.274191   0.960408        0.0     0.369447
# 3 2020-12-31  AXP             0.167448   1.766343        0.0    -2.335558
# 4 2019-12-31  AXP             0.252935   0.992517        0.0     0.025693
#
#    profit_margin  count_positive_profit  csti_on_liabilities  \
# 0      -0.076287                    1.0             0.198446
# 1      -0.099272                    1.0             0.165373
# 2      -0.078739                    1.0             0.130377
# 3      -0.213670                    1.0             0.193107
# 4      -0.107295                    1.0             0.137832
#
#    inventory_on_ebit  receivable_on_rev       roa       roe  debt_on_min_ebit  \
# 0          28.710314                0.0 -0.013946 -0.037941         12.435957
# 1         -53.305233                0.0 -0.017618 -0.050301        -61.879360
# 2         159.512658                0.0 -0.011820 -0.027615        -56.213663
# 3         -15.591633                0.0 -0.030706 -0.083826         -8.765714
# 4         907.033708                0.0 -0.018273 -0.050031        -11.803061
#
#    liabilities_on_equity  capital_cost_on_ebit  eps_on_mp  dividend_on_mp  \
# 0               1.720609              0.406080  -0.037941    2.898473e+07
# 1               1.855040             -2.696221  -0.050301    3.429442e+07
# 2               1.336318              3.270042  -0.027615    5.562347e+07
# 3               1.729976             -0.301633  -0.083826    2.070135e+07
# 4               1.737955             18.483146  -0.050031    1.142260e+07
#
#        mp_on_bv
# 0 -1.459757e-09
# 1 -1.014864e-09
# 2 -1.590235e-09
# 3 -1.619377e-09
# 4 -5.026406e-09

# %%
ratios.tail()
# Out:
#          date   tic  gross_profit_margin  sga_ratio  dep_ratio  ebit_on_int  \
# 25 2013-12-31  AMGN             0.794924   0.349185   0.043379     9.454012
# 26 2012-12-31  AMGN             0.778454   0.358185   0.051265     7.994439
# 27 2011-12-31  AMGN             0.825825   0.349627   0.052767    13.719672
# 28 2010-12-31  AMGN             0.826413   0.320177   0.047749    14.001656
# 29 2009-12-31  AMGN             0.837317   0.311582   0.050897    14.602076
#
#     profit_margin  count_positive_profit  csti_on_liabilities  \
# 25       0.452774                   10.0             0.440641
# 26       0.398668                   10.0             0.682814
# 27       0.467976                   10.0             0.691676
# 28       0.475852                   10.0             0.891516
# 29       0.496039                   10.0             0.792477
#
#     inventory_on_ebit  receivable_on_rev       roa       roe  \
# 25           0.312461           0.144410  0.064989  0.098229
# 26           0.318108           0.145844  0.068535  0.105579
# 27           0.296810           0.185855  0.090105  0.142741
# 28           0.239092           0.155119  0.101303  0.139993
# 29           0.263033           0.144038  0.099155  0.129035
#
#     debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  eps_on_mp  \
# 25          3.325191               0.511461              0.071724   0.098229
# 26          3.075470               0.540518              0.079875   0.105579
# 27          2.560401               0.584158              0.067750   0.142741
# 28          1.596607               0.381927              0.068582   0.139993
# 29          1.266699               0.301348              0.062796   0.129035
#
#     dividend_on_mp      mp_on_bv
# 25    1.969670e+07 -5.735228e-09
# 26    6.641531e+07 -1.281708e-08
# 27    1.372839e+08 -1.408670e-08
# 28    6.896175e+07  2.946227e-08
# 29    5.670850e+07  1.331685e-07

# %% [markdown]
# ### Turn the final_ratios to daily basis

# %%
start_date = df.iloc[0].date
end_date = df.iloc[-1].date
date_range = pd.date_range(start=start_date, end=end_date, freq='D')
date_range = pd.DataFrame(date_range)
date_range.columns = ['date']
date_range.head()
# Out:
#         date
# 0 2009-01-02
# 1 2009-01-03
# 2 2009-01-04
# 3 2009-01-05
# 4 2009-01-06

# %% [markdown]
# Interpolate missing data in the middle of years for each ticket

# %%
daily_ratios = pd.DataFrame()
for ticket in ratios.tic.unique():
    # Interpolate data for each ticket
    one_tic_ratios = pd.merge(date_range,ratios[ratios.tic == ticket],how="left",on=['date'])
    one_tic_ratios['tic'] = ticket
    one_tic_ratios = one_tic_ratios.interpolate('linear')
    daily_ratios = pd.concat([daily_ratios, one_tic_ratios], ignore_index=True)

    # Check data by drawing it out
    # %matplotlib inline
    plt.figure(figsize=(16, 4)) 
    plt.plot(one_tic_ratios.date, one_tic_ratios.gross_profit_margin, color = 'red')
    plt.title(f'Gross profit margin of {ticket}')
    plt.show()

# %%
daily_ratios.dropna(subset='gross_profit_margin',inplace=True)
daily_ratios
# Out:
#             date   tic  gross_profit_margin  sga_ratio  dep_ratio  \
# 363   2009-12-31   AXP             0.158545   1.306584   0.000000
# 364   2010-01-01   AXP             0.158765   1.305403   0.000000
# 365   2010-01-02   AXP             0.158985   1.304222   0.000000
# 366   2010-01-03   AXP             0.159205   1.303040   0.000000
# 367   2010-01-04   AXP             0.159425   1.301859   0.000000
# ...          ...   ...                  ...        ...        ...
# 11099 2024-03-11  AMGN             0.292201   0.827065   0.091688
# 11100 2024-03-12  AMGN             0.292201   0.827065   0.091688
# 11101 2024-03-13  AMGN             0.292201   0.827065   0.091688
# 11102 2024-03-14  AMGN             0.292201   0.827065   0.091688
# 11103 2024-03-15  AMGN             0.292201   0.827065   0.091688
#
#        ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 363      -0.540100      -0.167312                    1.0             0.140348
# 364      -0.537684      -0.167199                    1.0             0.139977
# 365      -0.535268      -0.167085                    1.0             0.139606
# 366      -0.532852      -0.166972                    1.0             0.139236
# 367      -0.530436      -0.166858                    1.0             0.138865
# ...            ...            ...                    ...                  ...
# 11099     0.449391      -0.106422                    1.0             0.170014
# 11100     0.449391      -0.106422                    1.0             0.170014
# 11101     0.449391      -0.106422                    1.0             0.170014
# 11102     0.449391      -0.106422                    1.0             0.170014
# 11103     0.449391      -0.106422                    1.0             0.170014
#
#        inventory_on_ebit  receivable_on_rev       roa       roe  \
# 363            -0.000000           0.000000 -0.025799 -0.084949
# 364             0.000000           0.000000 -0.025781 -0.084903
# 365             0.000000           0.000000 -0.025763 -0.084857
# 366             0.000000           0.000000 -0.025745 -0.084811
# 367             0.000000           0.000000 -0.025727 -0.084765
# ...                  ...                ...       ...       ...
# 11099           7.366873           0.310623 -0.011100 -0.017645
# 11100           7.366873           0.310623 -0.011100 -0.017645
# 11101           7.366873           0.310623 -0.011100 -0.017645
# 11102           7.366873           0.310623 -0.011100 -0.017645
# 11103           7.366873           0.310623 -0.011100 -0.017645
#
#        debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 363          -52.477936               2.292741             -0.647651
# 364          -52.457692               2.293416             -0.642942
# 365          -52.437449               2.294092             -0.638232
# 366          -52.417205               2.294767             -0.633523
# 367          -52.396961               2.295443             -0.628814
# ...                 ...                    ...                   ...
# 11099        -54.205537               0.589614              0.860681
# 11100        -54.205537               0.589614              0.860681
# 11101        -54.205537               0.589614              0.860681
# 11102        -54.205537               0.589614              0.860681
# 11103        -54.205537               0.589614              0.860681
#
#        eps_on_mp  dividend_on_mp      mp_on_bv
# 363    -0.084949    2.280355e+07 -4.281461e-10
# 364    -0.084903    2.283408e+07 -4.278830e-10
# 365    -0.084857    2.286461e+07 -4.276200e-10
# 366    -0.084811    2.289514e+07 -4.273569e-10
# 367    -0.084765    2.292567e+07 -4.270939e-10
# ...          ...             ...           ...
# 11099  -0.017645    1.581835e+07 -4.559934e-09
# 11100  -0.017645    1.581835e+07 -4.559934e-09
# 11101  -0.017645    1.581835e+07 -4.559934e-09
# 11102  -0.017645    1.581835e+07 -4.559934e-09
# 11103  -0.017645    1.581835e+07 -4.559934e-09
#
# [10378 rows x 19 columns]

# %% [markdown]
# <a id='3.4'></a>
# ## 4.4 Merge stock price data and ratios into one dataframe
# - Merge the price dataframe preprocessed in Part 3 and the ratio dataframe created in this part
# - Since the prices are daily and ratios are quartely, we have NAs in the ratio columns after merging the two dataframes. We deal with this by backfilling the ratios.

# %%
df_date = pd.DataFrame(df)[['date','tic','close']]
df_date.columns = ['date','tic','close']
df_date['date'] = pd.to_datetime(df_date.date)
final_ratios = pd.merge(df_date,daily_ratios,how="left",on=['date','tic'])

# %%
final_ratios.dropna(subset=['gross_profit_margin'],inplace=True,how='any')
final_ratios.reset_index(drop=True,inplace=True)
final_ratios.isna().sum()
# Out:
# date                     0
# tic                      0
# close                    0
# gross_profit_margin      0
# sga_ratio                0
# dep_ratio                0
# ebit_on_int              0
# profit_margin            0
# count_positive_profit    0
# csti_on_liabilities      0
# inventory_on_ebit        0
# receivable_on_rev        0
# roa                      0
# roe                      0
# debt_on_min_ebit         0
# liabilities_on_equity    0
# capital_cost_on_ebit     0
# eps_on_mp                0
# dividend_on_mp           0
# mp_on_bv                 0
# dtype: int64

# %%
processed_full = final_ratios.copy()
processed_full
# Out:
#            date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0    2009-12-31  AMGN   40.666710             0.837317   0.311582   0.050897
# 1    2009-12-31   AXP   32.868496             0.158545   1.306584   0.000000
# 2    2010-01-04  AMGN   41.493420             0.837198   0.311677   0.050863
# 3    2010-01-04   AXP   33.192955             0.159425   1.301859   0.000000
# 4    2010-01-05  AMGN   41.133972             0.837168   0.311700   0.050854
# ...         ...   ...         ...                  ...        ...        ...
# 7145 2024-03-13   AXP  222.809998             0.257734   0.778309   0.000000
# 7146 2024-03-14  AMGN  271.540009             0.292201   0.827065   0.091688
# 7147 2024-03-14   AXP  220.470001             0.257734   0.778309   0.000000
# 7148 2024-03-15  AMGN  268.869995             0.292201   0.827065   0.091688
# 7149 2024-03-15   AXP  218.460007             0.257734   0.778309   0.000000
#
#       ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0       14.602076       0.496039                   10.0             0.792477
# 1       -0.540100      -0.167312                    1.0             0.140348
# 2       14.595496       0.495818                   10.0             0.793563
# 3       -0.530436      -0.166858                    1.0             0.138865
# 4       14.593851       0.495762                   10.0             0.793834
# ...           ...            ...                    ...                  ...
# 7145     0.561980      -0.076287                    1.0             0.198446
# 7146     0.449391      -0.106422                    1.0             0.170014
# 7147     0.561980      -0.076287                    1.0             0.198446
# 7148     0.449391      -0.106422                    1.0             0.170014
# 7149     0.561980      -0.076287                    1.0             0.198446
#
#       inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0              0.263033           0.144038  0.099155  0.129035
# 1             -0.000000           0.000000 -0.025799 -0.084949
# 2              0.262771           0.144159  0.099178  0.129155
# 3              0.000000           0.000000 -0.025727 -0.084765
# 4              0.262705           0.144189  0.099184  0.129185
# ...                 ...                ...       ...       ...
# 7145          28.710314           0.000000 -0.013946 -0.037941
# 7146           7.366873           0.310623 -0.011100 -0.017645
# 7147          28.710314           0.000000 -0.013946 -0.037941
# 7148           7.366873           0.310623 -0.011100 -0.017645
# 7149          28.710314           0.000000 -0.013946 -0.037941
#
#       debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0             1.266699               0.301348              0.062796
# 1           -52.477936               2.292741             -0.647651
# 2             1.270314               0.302231              0.062860
# 3           -52.396961               2.295443             -0.628814
# 4             1.271218               0.302451              0.062875
# ...                ...                    ...                   ...
# 7145         12.435957               1.720609              0.406080
# 7146        -54.205537               0.589614              0.860681
# 7147         12.435957               1.720609              0.406080
# 7148        -54.205537               0.589614              0.860681
# 7149         12.435957               1.720609              0.406080
#
#       eps_on_mp  dividend_on_mp      mp_on_bv
# 0      0.129035    5.670850e+07  1.331685e-07
# 1     -0.084949    2.280355e+07 -4.281461e-10
# 2      0.129155    5.684278e+07  1.320320e-07
# 3     -0.084765    2.292567e+07 -4.270939e-10
# 4      0.129185    5.687636e+07  1.317479e-07
# ...         ...             ...           ...
# 7145  -0.037941    2.898473e+07 -1.459757e-09
# 7146  -0.017645    1.581835e+07 -4.559934e-09
# 7147  -0.037941    2.898473e+07 -1.459757e-09
# 7148  -0.017645    1.581835e+07 -4.559934e-09
# 7149  -0.037941    2.898473e+07 -1.459757e-09
#
# [7150 rows x 20 columns]

# %% [markdown]
# Reset **TRAIN_START_DATE** and **TEST_END_DATE**

# %%
TRAIN_START_DATE = final_ratios.date.min().strftime("%Y-%m-%d")
TEST_END_DATE = final_ratios.date.max().strftime("%Y-%m-%d")
print('TRAIN_START_DATE: ',TRAIN_START_DATE,'\n')
print('TEST_END_DATE: ',TEST_END_DATE,'\n')
# Out:
# TRAIN_START_DATE:  2009-12-31
#
# TEST_END_DATE:  2024-03-15

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %% [markdown]
# <a id='4.1'></a>
# ## 5.1 Training & Trade Data Split
# - Training data period: 2009-01-01 to 2020-01-01
# - Trade data period: 2020-01-01 to 2023-12-29

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(trade_data))
# Out:
# 5034
# 2114

# %%
train_data = train_data.reset_index(drop=True)
train_data
# Out:
#            date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0    2009-12-31  AMGN   40.666710             0.837317   0.311582   0.050897
# 1    2009-12-31   AXP   32.868496             0.158545   1.306584   0.000000
# 2    2010-01-04  AMGN   41.493420             0.837198   0.311677   0.050863
# 3    2010-01-04   AXP   33.192955             0.159425   1.301859   0.000000
# 4    2010-01-05  AMGN   41.133972             0.837168   0.311700   0.050854
# ...         ...   ...         ...                  ...        ...        ...
# 5029 2019-12-27   AXP  117.890228             0.252965   0.992592   0.000000
# 5030 2019-12-30  AMGN  210.834442             0.764009   0.288550   0.035574
# 5031 2019-12-30   AXP  117.052124             0.252942   0.992535   0.000000
# 5032 2019-12-31  AMGN  211.536484             0.763976   0.288548   0.035578
# 5033 2019-12-31   AXP  117.231056             0.252935   0.992517   0.000000
#
#       ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0       14.602076       0.496039               10.00000             0.792477
# 1       -0.540100      -0.167312                1.00000             0.140348
# 2       14.595496       0.495818               10.00000             0.793563
# 3       -0.530436      -0.166858                1.00000             0.138865
# 4       14.593851       0.495762               10.00000             0.793834
# ...           ...            ...                    ...                  ...
# 5029     0.025437      -0.107166                1.00000             0.138141
# 5030     9.849841       0.432914                4.00274             0.185148
# 5031     0.025629      -0.107263                1.00000             0.137909
# 5032     9.851047       0.432882                4.00000             0.184155
# 5033     0.025693      -0.107295                1.00000             0.137832
#
#       inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0              0.263033           0.144038  0.099155  0.129035
# 1             -0.000000           0.000000 -0.025799 -0.084949
# 2              0.262771           0.144159  0.099178  0.129155
# 3              0.000000           0.000000 -0.025727 -0.084765
# 4              0.262705           0.144189  0.099184  0.129185
# ...                 ...                ...       ...       ...
# 5029         897.093612           0.000000 -0.018256 -0.050045
# 5030           0.282091           0.198994  0.052527  0.070976
# 5031         904.548684           0.000000 -0.018269 -0.050035
# 5032           0.282249           0.199127  0.052507  0.070934
# 5033         907.033708           0.000000 -0.018273 -0.050031
#
#       debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0             1.266699               0.301348              0.062796
# 1           -52.477936               2.292741             -0.647651
# 2             1.270314               0.302231              0.062860
# 3           -52.396961               2.295443             -0.628814
# 4             1.271218               0.302451              0.062875
# ...                ...                    ...                   ...
# 5029        -11.804376               1.741484             20.331472
# 5030          2.421993               0.351190              0.048690
# 5031        -11.803390               1.738837             18.945227
# 5032          2.421100               0.350946              0.048669
# 5033        -11.803061               1.737955             18.483146
#
#       eps_on_mp  dividend_on_mp      mp_on_bv
# 0      0.129035    5.670850e+07  1.331685e-07
# 1     -0.084949    2.280355e+07 -4.281461e-10
# 2      0.129155    5.684278e+07  1.320320e-07
# 3     -0.084765    2.292567e+07 -4.270939e-10
# 4      0.129185    5.687636e+07  1.317479e-07
# ...         ...             ...           ...
# 5029  -0.050045    1.163360e+07 -4.979228e-09
# 5030   0.070976    4.667754e+07 -7.200680e-09
# 5031  -0.050035    1.147535e+07 -5.014611e-09
# 5032   0.070934    4.650516e+07 -7.191440e-09
# 5033  -0.050031    1.142260e+07 -5.026406e-09
#
# [5034 rows x 20 columns]

# %%
trade_data = trade_data.reset_index(drop=True)
trade_data
# Out:
#            date   tic       close  gross_profit_margin  sga_ratio  dep_ratio  \
# 0    2020-01-02  AMGN  210.685318             0.763687   0.288703   0.035577
# 1    2020-01-02   AXP  118.922523             0.252468   0.996745   0.000000
# 2    2020-01-03  AMGN  209.255005             0.763543   0.288780   0.035577
# 3    2020-01-03   AXP  117.741310             0.252234   0.998859   0.000000
# 4    2020-01-06  AMGN  210.860825             0.763110   0.289013   0.035575
# ...         ...   ...         ...                  ...        ...        ...
# 2109 2024-03-12   AXP  222.649994             0.257734   0.778309   0.000000
# 2110 2024-03-13  AMGN  275.989990             0.292201   0.827065   0.091688
# 2111 2024-03-13   AXP  222.809998             0.257734   0.778309   0.000000
# 2112 2024-03-14  AMGN  271.540009             0.292201   0.827065   0.091688
# 2113 2024-03-14   AXP  220.470001             0.257734   0.778309   0.000000
#
#       ebit_on_int  profit_margin  count_positive_profit  csti_on_liabilities  \
# 0        9.850696       0.432714               3.994536             0.184284
# 1        0.012790      -0.107876               1.000000             0.138134
# 2        9.850521       0.432629               3.991803             0.184348
# 3        0.006338      -0.108167               1.000000             0.138285
# 4        9.849995       0.432376               3.983607             0.184542
# ...           ...            ...                    ...                  ...
# 2109     0.561980      -0.076287               1.000000             0.198446
# 2110     0.449391      -0.106422               1.000000             0.170014
# 2111     0.561980      -0.076287               1.000000             0.198446
# 2112     0.449391      -0.106422               1.000000             0.170014
# 2113     0.561980      -0.076287               1.000000             0.198446
#
#       inventory_on_ebit  receivable_on_rev       roa       roe  \
# 0              0.282429           0.199183  0.052520  0.070967
# 1            901.992039           0.000000 -0.018341 -0.050216
# 2              0.282519           0.199211  0.052526  0.070983
# 3            899.471205           0.000000 -0.018375 -0.050308
# 4              0.282789           0.199295  0.052545  0.071031
# ...                 ...                ...       ...       ...
# 2109          28.710314           0.000000 -0.013946 -0.037941
# 2110           7.366873           0.310623 -0.011100 -0.017645
# 2111          28.710314           0.000000 -0.013946 -0.037941
# 2112           7.366873           0.310623 -0.011100 -0.017645
# 2113          28.710314           0.000000 -0.013946 -0.037941
#
#       debt_on_min_ebit  liabilities_on_equity  capital_cost_on_ebit  \
# 0             2.547383               0.351229              0.048672
# 1           -11.786464               1.737911             18.380497
# 2             2.610525               0.351370              0.048674
# 3           -11.778165               1.737890             18.329172
# 4             2.799950               0.351794              0.048678
# ...                ...                    ...                   ...
# 2109         12.435957               1.720609              0.406080
# 2110        -54.205537               0.589614              0.860681
# 2111         12.435957               1.720609              0.406080
# 2112        -54.205537               0.589614              0.860681
# 2113         12.435957               1.720609              0.406080
#
#       eps_on_mp  dividend_on_mp      mp_on_bv
# 0      0.070967    4.642313e+07 -7.187803e-09
# 1     -0.050216    1.147331e+07 -5.007788e-09
# 2      0.070983    4.638212e+07 -7.185985e-09
# 3     -0.050308    1.149866e+07 -4.998479e-09
# 4      0.071031    4.625907e+07 -7.180530e-09
# ...         ...             ...           ...
# 2109  -0.037941    2.898473e+07 -1.459757e-09
# 2110  -0.017645    1.581835e+07 -4.559934e-09
# 2111  -0.037941    2.898473e+07 -1.459757e-09
# 2112  -0.017645    1.581835e+07 -4.559934e-09
# 2113  -0.037941    2.898473e+07 -1.459757e-09
#
# [2114 rows x 20 columns]

# %% [markdown]
# <a id='4.2'></a>
# ## 5.2 Set up the training environment

# %% [markdown]
# Describe the environment

# %%
import gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv
# from gym.spaces import Box

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        # stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        stop_loss,
        # turbulence_threshold=None,
        # risk_indicator_col="turbulence",
        make_plots=False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        # self.day = day
        self.df = df
        # self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.stop_loss = stop_loss # the game stops when the asset loses more than stop_loss percent
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        # self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        # self.turbulence_threshold = turbulence_threshold
        # self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        self.portfolio_columns = ['tic','price','buy_price','amount','weight']
        self.row = 0
        
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _buy_stock(self, action):
        def _do_buy():
            if self.data.close > 0: # Buy only if the price is > 0 (no missing data in this particular date)
                buy_amount = (self.portfolio.loc[0].price * action)
                buy_num_shares = math.floor(buy_amount/self.data.close)
                if buy_num_shares > 0:
                    if self.portfolio[self.portfolio.tic == self.data.tic].empty:
                        selected_index = len(self.portfolio)
                        selected_row = [self.data.tic,0,self.data.close,0,0]
                    else:
                        selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
                        selected_row = self.portfolio.loc[selected_index]
                        selected_row[2] = (buy_num_shares*self.data.close + selected_row[2]*selected_row[3]) \
                                    /(buy_num_shares + selected_row[3])
                    selected_row[1] = self.data.close
                    selected_row[3] += buy_num_shares
                    self.portfolio.loc[selected_index] = selected_row
    
                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_change = buy_num_shares * self.data.close * (1 + self.buy_cost_pct)
                    capital_row[1] -= capital_change
                    capital_row[2] -= capital_change
                    self.portfolio.loc[0] = capital_row
                    
                    self._compute_weight()
                    self.cost += selected_row[1] * buy_num_shares * self.buy_cost_pct
                    self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        buy_num_shares = _do_buy()
        return buy_num_shares
    
    def _sell_stock(self, action):
        def _do_sell_normal():
            if self.data.close > 0: # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.portfolio[self.portfolio.tic == self.data.tic].empty:            
                    sell_num_shares = 0
                else:
                    sell_num_shares = math.floor(abs(action) * self.portfolio[self.portfolio.tic == self.data.tic].amount) 
                    sell_amount = self.data.close * sell_num_shares * (1 - self.sell_cost_pct) # remember to adjust buy_cost_pct
                    
                    # update stock row in the portfolio
                    selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
                    selected_row = self.portfolio.loc[selected_index]
                    selected_row[1] = self.data.close
                    selected_row[3] -= sell_num_shares
                    self.portfolio.loc[selected_index] = selected_row

                    # Update remain capital
                    capital_row = self.portfolio.loc[0]
                    capital_row[1] += sell_amount
                    capital_row[2] += sell_amount
                    self.portfolio.loc[0] = capital_row

                    self._compute_weight()
                    self.cost += selected_row[1] * sell_num_shares * self.sell_cost_pct
                    self.trades += 1
            else:
                sell_num_shares = 0

            return sell_num_shares

        sell_num_shares = _do_sell_normal()
        return sell_num_shares

    def _compute_weight(self):
        nav = sum(self.portfolio.price*self.portfolio.amount)
        self.portfolio['weight'] = self.portfolio.apply(lambda x: x.price * x.amount / nav, axis=1)
    
    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig("results/account_value_trade_{}.png".format(self.episode))
        plt.close()

    def step(self, actions):
        current_total_asset = sum(self.portfolio.price * self.portfolio.amount)
        self.terminal = (self.day >= len(self.df.index.unique()) - 1) | (current_total_asset < self.initial_amount*(1-self.stop_loss))
        print(f'Action of step {self.day} is {actions[0]}')
        
        # --> IN CASE THE STEP IS THE TERMINATED STEP
        if self.terminal: 
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
                
            # Summary the training performance after an episode
            end_total_asset = sum(self.portfolio.price*self.portfolio.amount)
            tot_reward = end_total_asset - self.initial_amount

            # Summary total_value
            df_total_value = pd.DataFrame(self.asset_memory)
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(1)
            if df_total_value["daily_return"].std() != 0:
                sharpe = ((252 ** 0.5)* df_total_value["daily_return"].mean()/ df_total_value["daily_return"].std())

            # Summary rewards
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]

            # Print out training results after a certain amount of episodes
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.close()

            return self.state, self.reward, self.terminal, {}

        # --> IN A NORMAL STEP
        else: 

            begin_total_asset = sum(self.portfolio.price * self.portfolio.amount)
            
            # update previous_portfolio
            self.previous_port = self.portfolio.copy()
        
            # self.data = self.df.loc[self.day]
            if actions[0] > 0:
                self._buy_stock(actions[0])
            else:
                self._sell_stock(actions[0])

            # actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            # actions = actions.astype(int)  # convert into integer because we can't by fraction of shares
            # print(type(actions))
            self.actions_memory.append(actions)

            # Update selected row in the dataset based on state: s -> s+1
            # self.day += 1
            # self.data = self.df.loc[self.day, :]
            self.day += 1
            self.data = self.df.loc[self.day]
            self.state = self._update_state()
    
            end_total_asset = sum(self.portfolio.price * self.portfolio.amount)
            # print(f'Begin asset: {begin_total_asset}, End asset: {end_total_asset}')

            # Update summary arrays
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset # - self.initial_amount * self.idle_punishment
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        # initiate state
        self.state = self._initiate_state()

        # Reset asset_memory
        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = sum(self.previous_port.price * self.previous_port.amount)
            self.asset_memory = [previous_total_asset]

        # Reset support variables
        # self.day = 0
        # self.data = self.df.loc[self.day, :]
        # self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        self.episode += 1

        return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        
        # Reset portfolio & previous_portfolio
        if self.initial:
            self.portfolio = pd.DataFrame([['cap',self.initial_amount,self.initial_amount,1,1]])
            self.portfolio.columns = self.portfolio_columns
            self.previous_port = self.portfolio.copy()
        else:
            self.portfolio = self.previous_port.copy()

        # Reset data
        self.day = 0
        self.data = self.df.loc[self.day]
        
         # Reset state
        state = self._update_state()
        
        return state

    def _update_state(self):

        # if the stock appear in the portfolio already
        if self.portfolio[self.portfolio.tic == self.data.tic].empty:
            state = ([self.portfolio.loc[0].price] + [0] + [0] + sum([[self.data[tech]] for tech in self.tech_indicator_list], []))
            
        else:
            # Update stock's prices in portfolio before updating state
            selected_index = self.portfolio[self.portfolio.tic == self.data.tic].index[0]
            selected_row = self.portfolio.loc[selected_index]
            selected_row['price'] = self.data.close
            self.portfolio.loc[selected_index] = selected_row
            self._compute_weight()
            selected_row = self.portfolio.loc[selected_index]
            # print("Update portfolio at ",self.data.tic," price: ", self.data.close,"; with weight: ", selected_row.weight)
            
            state = (
                    [self.portfolio.iloc[0].price]
                    + [(selected_row.buy_price/selected_row.price-1)]
                    + [selected_row.weight]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
    
        return state

    def _get_date(self):
        # return self.data.date
        return self.day

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        
        date_list = self.date_memory[:-1]
        action_list = self.actions_memory
        df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %% [markdown]
# <a id='4.3'></a>
# ## 5.3 Initialize Environment

# %% [markdown]
# State's space include current capital amount, the return of the current stock, the weight of this stock in the portfolio, and the indicators decided in ratio_list

# %%
ratio_list = train_data.columns.drop(['date','tic','close'])

action_dimension = 1 # k float in range (-1,1) to decide sell (k<0) or buy (k>0) decisions
state_space = 1 + 2*action_dimension + len(ratio_list)
print(f"Action Dimension: {action_dimension}, State Space: {state_space}")
# Out:
# Action Dimension: 1, State Space: 20

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.3,
    "print_verbosity":4
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ### Test environment

# %%
# from gym.spaces import Box

# %%
# # Define bounds, shape, and data type
# lower_bound = -1.0
# upper_bound = 1.0
# shape = (1,)
# dtype = np.float32

# # Create the Box object
# action_space = Box(low=lower_bound, high=upper_bound, shape=shape, dtype=dtype)

# # Sample a value within the action space
# action = action_space.sample()

# print(f"Action: {action}")
# Out:
# Action: [0.13998286]

# %%
# Get samples from train_data
sample_data = train_data #.sample(10).reset_index(drop=True)

# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.3
}

#Establish the training environment using StockTradingEnv() class
test_train_gym = StockTradingEnv(df = sample_data, **env_kwargs)

# test reset state
print(test_train_gym.reset())
# Out:
# [1000000, 0, 0, 0.83731730637891, 0.31158238172920066, 0.05089722675367047, 14.602076124567475, 0.4960387925146838, 10.0, 0.7924773022049286, 0.26303317535545023, 0.1440376997677913, 0.09915473421875885, 0.12903477969660926, 1.2666985302903573, 0.3013476432898095, 0.06279620853080568, 0.12903477969660926, 56708502.73996818, 1.3316854990583805e-07]

# %%
 # test buying 50% capital each step
test_train_gym.step([0.5])
print(test_train_gym.reward,'\n')
print(test_train_gym.data,'\n')
print(test_train_gym.state,'\n')
print(test_train_gym.portfolio,'\n')
print(test_train_gym.previous_port)
# Out:
# Begin asset: 1102368.5387495672, End asset: 1098283.381355158
# -0.408515739440918
#
# date                     2010-11-30 00:00:00
# tic                                     AMGN
# close                              37.877472
# gross_profit_margin                 0.827339
# sga_ratio                           0.319447
# dep_ratio                           0.048017
# ebit_on_int                         14.05265
# profit_margin                       0.477566
# count_positive_profit                   10.0
# csti_on_liabilities                 0.883104
# inventory_on_ebit                   0.241125
# receivable_on_rev                   0.154177
# roa                                  0.10112
# roe                                 0.139062
# debt_on_min_ebit                    1.568587
# liabilities_on_equity               0.375084
# capital_cost_on_ebit                0.068091
# eps_on_mp                           0.139062
# dividend_on_mp               67921061.996315
# mp_on_bv                                 0.0
# Name: 460, dtype: object
#
# [32.08667742370717, 0.03210455862142103, 0.3110807306684056, 0.8273394298684509, 0.3194469078293725, 0.04801656312498029, 14.052650246559018, 0.4775664852235216, 10.0, 0.8831042285643076, 0.24112524713527816, 0.15417746507231372, 0.10112036898233236, 0.13906241213877849, 1.5685869410430209, 0.37508358815048803, 0.06809082323045859, 0.13906241213877849, 67921061.99631469, 3.8270203608855667e-08]
#
#     tic      price  buy_price  amount    weight
# 0   cap  32.086677  32.086677       1  0.000029
# 1   AXP  35.783035  33.384812   21144  0.688890
# 2  AMGN  37.877472  39.093511    9020  0.311081
#
#     tic      price  buy_price  amount    weight
# 0   cap  32.086677  32.086677       1  0.000029
# 1   AXP  35.783035  33.384812   21144  0.686337
# 2  AMGN  38.330372  39.093511    9020  0.313634

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Model 1: PPO

# %%
# agent_ppo = DRLAgent(env = env_train)
# PPO_PARAMS = {
#     "n_steps": 2048,
#     "ent_coef": 0.01,
#     "learning_rate": 0.00025,
#     "batch_size": 128,
#     "clip_range":0.1
# }
# model_ppo = agent_ppo.get_model("ppo",model_kwargs = PPO_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ppo/")

# %%
# trained_ppo = agent_ppo.train_model(model=model_ppo, 
#                              tb_log_name='ppo',
#                              total_timesteps=300000)

# %% [markdown]
# ### Model 2: DDPG

# %%
episode_length = len(e_train_gym.df) + 1
episode_amount = 4
total_training_step = episode_length*episode_amount

# %%
agent_ddpg = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": episode_length, "learning_rate": 0.001}
model_ddpg = agent_ddpg.get_model("ddpg",model_kwargs = DDPG_PARAMS,tensorboard_log=TENSORBOARD_LOG_DIR + "/test_ddpg_tensorboard/")

# set up logger
tmp_path = TENSORBOARD_LOG_DIR + '/ddpg'
new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_sac.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 5035, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/ddpg

# %%
# the training log just show up when total_timesteps higher than 15.000
trained_ddpg = agent_ddpg.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=total_training_step)
# Out:
# Logging to tensorboard_log/test_ddpg_tensorboard/ddpg_2
# Action of step 0 is -0.15145081281661987
# Action of step 1 is -0.5379790663719177
# Action of step 2 is -0.07730358839035034
# Action of step 84 is 0.14544677734375
# Action of step 85 is -0.17805373668670654
# Action of step 86 is -0.6032857894897461
# Action of step 87 is 0.00828397274017334
# Action of step 88 is -0.17669802904129028
# Action of step 89 is -0.9806928634643555
# Action of step 90 is 0.8977217674255371
# Action of step 91 is -0.6530212759971619
# Action of step 92 is -0.28616368770599365
# Action of step 93 is -0.19841647148132324
# Action of step 94 is -0.6270554661750793
# Action of step 95 is -0.026516079902648926
# Action of step 96 is 0.4407515525817871
# Action of step 97 is 0.5885341167449951
# Action of step 98 is 0.3188554048538208
# Action of step 99 is 0.8974771499633789
# Action of step 100 is 1.0
# Action of step 101 is 1.0
# Action of step 102 is 1.0
# Action of step 103 is 1.0
# Action of step 104 is 1.0
# Action of step 105 is 1.0
# Action of step 106 is 1.0
# Action of step 107 is 1.0
# Action of step 108 is 1.0
# Action of step 109 is 1.0
# Action of step 110 is 1.0
# Action of step 111 is 1.0
# Action of step 112 is 1.0
# Action of step 113 is 1.0
# Action of step 114 is 1.0
# Action of step 115 is 1.0
# Action of step 116 is 1.0
# Action of step 117 is 1.0
# Action of step 118 is 1.0
# Action of step 119 is 1.0
# Action of step 120 is 1.0
# Action of step 121 is 1.0
# Action of step 122 is 1.0
# Action of step 123 is 1.0
# Action of step 124 is 1.0
# Action of step 125 is 1.0
# Action of step 126 is 1.0
# Action of step 127 is 1.0
# Action of step 128 is 1.0
# Action of step 129 is 1.0
# Action of step 130 is 1.0
# Action of step 131 is 1.0
# Action of step 132 is 1.0
# Action of step 133 is 1.0
# Action of step 134 is 1.0
# Action of step 135 is 1.0
# Action of step 136 is 1.0
# Action of step 137 is 1.0
# Action of step 138 is 1.0
# Action of step 139 is 1.0
# Action of step 140 is 1.0
# Action of step 141 is 1.0
# Action of step 142 is 1.0
# Action of step 143 is 1.0
# Action of step 144 is 1.0
# Action of step 145 is 1.0
# Action of step 146 is 1.0
# Action of step 147 is 1.0
# Action of step 148 is 1.0
# Action of step 149 is 1.0
# Action of step 150 is 1.0
# Action of step 151 is 1.0
# Action of step 152 is 1.0
# Action of step 153 is 1.0
# Action of step 154 is 1.0
# Action of step 155 is 1.0
# Action of step 156 is 1.0
# Action of step 157 is 1.0
# Action of step 158 is 1.0
# Action of step 159 is 1.0
# Action of step 160 is 1.0
# Action of step 161 is 1.0
# Action of step 162 is 1.0
# Action of step 163 is 1.0
# Action of step 164 is 1.0
# Action of step 165 is 1.0
# Action of step 166 is 1.0
# Action of step 167 is 1.0
# Action of step 168 is 1.0
# Action of step 169 is 1.0
# Action of step 170 is 1.0
# Action of step 171 is 1.0
# Action of step 172 is 1.0
# Action of step 173 is 1.0
# Action of step 174 is 1.0
# Action of step 175 is 1.0
# Action of step 176 is 1.0
# Action of step 177 is 1.0
# Action of step 178 is 1.0
# Action of step 179 is 1.0
# Action of step 180 is 1.0
# Action of step 181 is 1.0
# Action of step 182 is 1.0
# Action of step 183 is 1.0
# Action of step 184 is 1.0
# Action of step 185 is 1.0
# Action of step 186 is 1.0
# Action of step 187 is 1.0
# Action of step 188 is 1.0
# Action of step 189 is 1.0
# Action of step 190 is 1.0
# Action of step 191 is 1.0
# Action of step 192 is 1.0
# Action of step 193 is 1.0
# Action of step 194 is 1.0
# Action of step 195 is 1.0
# Action of step 196 is 1.0
# Action of step 197 is 1.0
# Action of step 198 is 1.0
# Action of step 199 is 1.0
# Action of step 200 is 1.0
# Action of step 201 is 1.0
# Action of step 202 is 1.0
# Action of step 203 is 1.0
# Action of step 204 is 1.0
# Action of step 205 is 1.0
# Action of step 206 is 1.0
# Action of step 207 is 1.0
# Action of step 208 is 1.0
# Action of step 209 is 1.0
# Action of step 210 is 1.0
# Action of step 211 is 1.0
# Action of step 212 is 1.0
# Action of step 213 is 1.0
# Action of step 214 is 1.0
# Action of step 215 is 1.0
# Action of step 216 is 1.0
# Action of step 217 is 1.0
# Action of step 218 is 1.0
# Action of step 219 is 1.0
# Action of step 220 is 1.0
# Action of step 221 is 1.0
# Action of step 222 is 1.0
# Action of step 223 is 1.0
# Action of step 224 is 1.0
# Action of step 225 is 1.0
# Action of step 226 is 1.0
# Action of step 227 is 1.0
# Action of step 228 is 1.0
# Action of step 229 is 1.0
# Action of step 230 is 1.0
# Action of step 231 is 1.0
# Action of step 232 is 1.0
# Action of step 233 is 1.0
# Action of step 234 is 1.0
# Action of step 235 is 1.0
# Action of step 236 is 1.0
# Action of step 237 is 1.0
# Action of step 238 is 1.0
# Action of step 239 is 1.0
# Action of step 240 is 1.0
# Action of step 241 is 1.0
# Action of step 242 is 1.0
# Action of step 243 is 1.0
# Action of step 244 is 1.0
# Action of step 245 is 1.0
# Action of step 246 is 1.0
# Action of step 247 is 1.0
# Action of step 248 is 1.0
# Action of step 249 is 1.0
# Action of step 250 is 1.0
# Action of step 251 is 1.0
# Action of step 252 is 1.0
# Action of step 253 is 1.0
# Action of step 254 is 1.0
# Action of step 255 is 1.0
# Action of step 256 is 1.0
# Action of step 257 is 1.0
# Action of step 258 is 1.0
# Action of step 259 is 1.0
# Action of step 260 is 1.0
# Action of step 261 is 1.0
# Action of step 262 is 1.0
# Action of step 263 is 1.0
# Action of step 264 is 1.0
# Action of step 265 is 1.0
# Action of step 266 is 1.0
# Action of step 267 is 1.0
# Action of step 268 is 1.0
# Action of step 269 is 1.0
# Action of step 270 is 1.0
# Action of step 271 is 1.0
# Action of step 272 is 1.0
# Action of step 273 is 1.0
# Action of step 274 is 1.0
# Action of step 275 is 1.0
# Action of step 276 is 1.0
# Action of step 277 is 1.0
# Action of step 278 is 1.0
# Action of step 279 is 1.0
# Action of step 280 is 1.0
# Action of step 281 is 1.0
# Action of step 282 is 1.0
# Action of step 283 is 1.0
# Action of step 284 is 1.0
# Action of step 285 is 1.0
# Action of step 286 is 1.0
# Action of step 287 is 1.0
# Action of step 288 is 1.0
# Action of step 289 is 1.0
# Action of step 290 is 1.0
# Action of step 291 is 1.0
# Action of step 292 is 1.0
# Action of step 293 is 1.0
# Action of step 294 is 1.0
# Action of step 295 is 1.0
# Action of step 296 is 1.0
# Action of step 297 is 1.0
# Action of step 298 is 1.0
# Action of step 299 is 1.0
# Action of step 300 is 1.0
# Action of step 301 is 1.0
# Action of step 302 is 1.0
# Action of step 303 is 1.0
# Action of step 304 is 1.0
# Action of step 305 is 1.0
# Action of step 306 is 1.0
# Action of step 307 is 1.0
# Action of step 308 is 1.0
# Action of step 309 is 1.0
# Action of step 310 is 1.0
# Action of step 311 is 1.0
# Action of step 312 is 1.0
# Action of step 313 is 1.0
# Action of step 314 is 1.0
# Action of step 315 is 1.0
# Action of step 316 is 1.0
# Action of step 317 is 1.0
# Action of step 318 is 1.0
# Action of step 319 is 1.0
# Action of step 320 is 1.0
# Action of step 321 is 1.0
# Action of step 322 is 1.0
# Action of step 323 is 1.0
# Action of step 324 is 1.0
# Action of step 325 is 1.0
# Action of step 326 is 1.0
# Action of step 327 is 1.0
# Action of step 328 is 1.0
# Action of step 329 is 1.0
# Action of step 330 is 1.0
# Action of step 331 is 1.0
# Action of step 332 is 1.0
# Action of step 333 is 1.0
# Action of step 334 is 1.0
# Action of step 335 is 1.0
# Action of step 336 is 1.0
# Action of step 337 is 1.0
# Action of step 338 is 1.0
# Action of step 339 is 1.0
# Action of step 340 is 1.0
# Action of step 341 is 1.0
# Action of step 342 is 1.0
# Action of step 343 is 1.0
# Action of step 344 is 1.0
# Action of step 345 is 1.0
# Action of step 346 is 1.0
# Action of step 347 is 1.0
# Action of step 348 is 1.0
# Action of step 349 is 1.0
# Action of step 350 is 1.0
# Action of step 351 is 1.0
# Action of step 352 is 1.0
# Action of step 353 is 1.0
# Action of step 354 is 1.0
# Action of step 355 is 1.0
# Action of step 356 is 1.0
# Action of step 357 is 1.0
# Action of step 358 is 1.0
# Action of step 359 is 1.0
# Action of step 360 is 1.0
# Action of step 361 is 1.0
# Action of step 362 is 1.0
# Action of step 363 is 1.0
# Action of step 364 is 1.0
# Action of step 365 is 1.0
# Action of step 366 is 1.0
# Action of step 367 is 1.0
# Action of step 368 is 1.0
# Action of step 369 is 1.0
# Action of step 370 is 1.0
# Action of step 371 is 1.0
# Action of step 372 is 1.0
# Action of step 373 is 1.0
# Action of step 374 is 1.0
# Action of step 375 is 1.0
# Action of step 376 is 1.0
# Action of step 377 is 1.0
# Action of step 378 is 1.0
# Action of step 379 is 1.0
# Action of step 380 is 1.0
# Action of step 381 is 1.0
# Action of step 382 is 1.0
# Action of step 383 is 1.0
# Action of step 384 is 1.0
# Action of step 385 is 1.0
# Action of step 386 is 1.0
# Action of step 387 is 1.0
# Action of step 388 is 1.0
# Action of step 389 is 1.0
# Action of step 390 is 1.0
# Action of step 391 is 1.0
# Action of step 392 is 1.0
# Action of step 393 is 1.0
# Action of step 394 is 1.0
# Action of step 395 is 1.0
# Action of step 396 is 1.0
# Action of step 397 is 1.0
# Action of step 398 is 1.0
# Action of step 399 is 1.0
# Action of step 400 is 1.0
# Action of step 401 is 1.0
# Action of step 402 is 1.0
# Action of step 403 is 1.0
# Action of step 404 is 1.0
# Action of step 405 is 1.0
# Action of step 406 is 1.0
# Action of step 407 is 1.0
# Action of step 408 is 1.0
# Action of step 409 is 1.0
# Action of step 410 is 1.0
# Action of step 411 is 1.0
# Action of step 412 is 1.0
# Action of step 413 is 1.0
# Action of step 414 is 1.0
# Action of step 415 is 1.0
# Action of step 416 is 1.0
# Action of step 417 is 1.0
# Action of step 418 is 1.0
# Action of step 419 is 1.0
# Action of step 420 is 1.0
# Action of step 421 is 1.0
# Action of step 422 is 1.0
# Action of step 423 is 1.0
# Action of step 424 is 1.0
# Action of step 425 is 1.0
# Action of step 426 is 1.0
# Action of step 427 is 1.0
# Action of step 428 is 1.0
# Action of step 429 is 1.0
# Action of step 430 is 1.0
# Action of step 431 is 1.0
# Action of step 432 is 1.0
# Action of step 433 is 1.0
# Action of step 434 is 1.0
# Action of step 435 is 1.0
# Action of step 436 is 1.0
# Action of step 437 is 1.0
# Action of step 438 is 1.0
# Action of step 439 is 1.0
# Action of step 440 is 1.0
# Action of step 441 is 1.0
# Action of step 442 is 1.0
# Action of step 443 is 1.0
# Action of step 444 is 1.0
# Action of step 445 is 1.0
# Action of step 446 is 1.0
# Action of step 447 is 1.0
# Action of step 448 is 1.0
# Action of step 449 is 1.0
# Action of step 450 is 1.0
# Action of step 451 is 1.0
# Action of step 452 is 1.0
# Action of step 453 is 1.0
# Action of step 454 is 1.0
# Action of step 455 is 1.0
# Action of step 456 is 1.0
# Action of step 457 is 1.0
# Action of step 458 is 1.0
# Action of step 459 is 1.0
# Action of step 460 is 1.0
# Action of step 461 is 1.0
# Action of step 462 is 1.0
# Action of step 463 is 1.0
# Action of step 464 is 1.0
# Action of step 465 is 1.0
# Action of step 466 is 1.0
# Action of step 467 is 1.0
# Action of step 468 is 1.0
# Action of step 469 is 1.0
# Action of step 470 is 1.0
# Action of step 471 is 1.0
# Action of step 472 is 1.0
# Action of step 473 is 1.0
# Action of step 474 is 1.0
# Action of step 475 is 1.0
# Action of step 476 is 1.0
# Action of step 477 is 1.0
# Action of step 478 is 1.0
# Action of step 479 is 1.0
# Action of step 480 is 1.0
# Action of step 481 is 1.0
# Action of step 482 is 1.0
# Action of step 483 is 1.0
# Action of step 484 is 1.0
# Action of step 485 is 1.0
# Action of step 486 is 1.0
# Action of step 487 is 1.0
# Action of step 488 is 1.0
# Action of step 489 is 1.0
# Action of step 490 is 1.0
# Action of step 491 is 1.0
# Action of step 492 is 1.0
# Action of step 493 is 1.0
# Action of step 494 is 1.0
# Action of step 495 is 1.0
# Action of step 496 is 1.0
# Action of step 497 is 1.0
# Action of step 498 is 1.0
# Action of step 499 is 1.0
# Action of step 500 is 1.0
# Action of step 501 is 1.0
# Action of step 502 is 1.0
# Action of step 503 is 1.0
# Action of step 504 is 1.0
# Action of step 505 is 1.0
# Action of step 506 is 1.0
# Action of step 507 is 1.0
# Action of step 508 is 1.0
# Action of step 509 is 1.0
# Action of step 510 is 1.0
# Action of step 511 is 1.0
# Action of step 512 is 1.0
# Action of step 513 is 1.0
# Action of step 514 is 1.0
# Action of step 515 is 1.0
# Action of step 516 is 1.0
# Action of step 517 is 1.0
# Action of step 518 is 1.0
# Action of step 519 is 1.0
# Action of step 520 is 1.0
# Action of step 521 is 1.0
# Action of step 522 is 1.0
# Action of step 523 is 1.0
# Action of step 524 is 1.0
# Action of step 525 is 1.0
# Action of step 526 is 1.0
# Action of step 527 is 1.0
# Action of step 528 is 1.0
# Action of step 529 is 1.0
# Action of step 530 is 1.0
# Action of step 531 is 1.0
# Action of step 532 is 1.0
# Action of step 533 is 1.0
# Action of step 534 is 1.0
# Action of step 535 is 1.0
# Action of step 536 is 1.0
# Action of step 537 is 1.0
# Action of step 538 is 1.0
# Action of step 539 is 1.0
# Action of step 540 is 1.0
# Action of step 541 is 1.0
# Action of step 542 is 1.0
# Action of step 543 is 1.0
# Action of step 544 is 1.0
# Action of step 545 is 1.0
# Action of step 546 is 1.0
# Action of step 547 is 1.0
# Action of step 548 is 1.0
# Action of step 549 is 1.0
# Action of step 550 is 1.0
# Action of step 551 is 1.0
# Action of step 552 is 1.0
# Action of step 553 is 1.0
# Action of step 554 is 1.0
# Action of step 555 is 1.0
# Action of step 556 is 1.0
# Action of step 557 is 1.0
# Action of step 558 is 1.0
# Action of step 559 is 1.0
# Action of step 560 is 1.0
# Action of step 561 is 1.0
# Action of step 562 is 1.0
# Action of step 563 is 1.0
# Action of step 564 is 1.0
# Action of step 565 is 1.0
# Action of step 566 is 1.0
# Action of step 567 is 1.0
# Action of step 568 is 1.0
# Action of step 569 is 1.0
# Action of step 570 is 1.0
# Action of step 571 is 1.0
# Action of step 572 is 1.0
# Action of step 573 is 1.0
# Action of step 574 is 1.0
# Action of step 575 is 1.0
# Action of step 576 is 1.0
# Action of step 577 is 1.0
# Action of step 578 is 1.0
# Action of step 579 is 1.0
# Action of step 580 is 1.0
# Action of step 581 is 1.0
# Action of step 582 is 1.0
# Action of step 583 is 1.0
# Action of step 584 is 1.0
# Action of step 585 is 1.0
# Action of step 586 is 1.0
# Action of step 587 is 1.0
# Action of step 588 is 1.0
# Action of step 589 is 1.0
# Action of step 590 is 1.0
# Action of step 591 is 1.0
# Action of step 592 is 1.0
# Action of step 593 is 1.0
# Action of step 594 is 1.0
# Action of step 595 is 1.0
# Action of step 596 is 1.0
# Action of step 597 is 1.0
# Action of step 598 is 1.0
# Action of step 599 is 1.0
# Action of step 600 is 1.0
# Action of step 601 is 1.0
# Action of step 602 is 1.0
# Action of step 603 is 1.0
# Action of step 604 is 1.0
# Action of step 605 is 1.0
# Action of step 606 is 1.0
# Action of step 607 is 1.0
# Action of step 608 is 1.0
# Action of step 609 is 1.0
# Action of step 610 is 1.0
# Action of step 611 is 1.0
# Action of step 612 is 1.0
# Action of step 613 is 1.0
# Action of step 614 is 1.0
# Action of step 615 is 1.0
# Action of step 616 is 1.0
# Action of step 617 is 1.0
# Action of step 618 is 1.0
# Action of step 619 is 1.0
# Action of step 620 is 1.0
# Action of step 621 is 1.0
# Action of step 622 is 1.0
# Action of step 623 is 1.0
# Action of step 624 is 1.0
# Action of step 625 is 1.0
# Action of step 626 is 1.0
# Action of step 627 is 1.0
# Action of step 628 is 1.0
# Action of step 629 is 1.0
# Action of step 630 is 1.0
# Action of step 631 is 1.0
# Action of step 632 is 1.0
# Action of step 633 is 1.0
# Action of step 634 is 1.0
# Action of step 635 is 1.0
# Action of step 636 is 1.0
# Action of step 637 is 1.0
# Action of step 638 is 1.0
# Action of step 639 is 1.0
# Action of step 640 is 1.0
# Action of step 641 is 1.0
# Action of step 642 is 1.0
# Action of step 643 is 1.0
# Action of step 644 is 1.0
# Action of step 645 is 1.0
# Action of step 646 is 1.0
# Action of step 647 is 1.0
# Action of step 648 is 1.0
# Action of step 649 is 1.0
# Action of step 650 is 1.0
# Action of step 651 is 1.0
# Action of step 652 is 1.0
# Action of step 653 is 1.0
# Action of step 654 is 1.0
# Action of step 655 is 1.0
# Action of step 656 is 1.0
# Action of step 657 is 1.0
# Action of step 658 is 1.0
# Action of step 659 is 1.0
# Action of step 660 is 1.0
# Action of step 661 is 1.0
# Action of step 662 is 1.0
# Action of step 663 is 1.0
# Action of step 664 is 1.0
# Action of step 665 is 1.0
# Action of step 666 is 1.0
# Action of step 667 is 1.0
# Action of step 668 is 1.0
# Action of step 669 is 1.0
# Action of step 670 is 1.0
# Action of step 671 is 1.0
# Action of step 672 is 1.0
# Action of step 673 is 1.0
# Action of step 674 is 1.0
# Action of step 675 is 1.0
# Action of step 676 is 1.0
# Action of step 677 is 1.0
# Action of step 678 is 1.0
# Action of step 679 is 1.0
# Action of step 680 is 1.0
# Action of step 681 is 1.0
# Action of step 682 is 1.0
# Action of step 683 is 1.0
# Action of step 684 is 1.0
# Action of step 685 is 1.0
# Action of step 686 is 1.0
# Action of step 687 is 1.0
# Action of step 688 is 1.0
# Action of step 689 is 1.0
# Action of step 690 is 1.0
# Action of step 691 is 1.0
# Action of step 692 is 1.0
# Action of step 693 is 1.0
# Action of step 694 is 1.0
# Action of step 695 is 1.0
# Action of step 696 is 1.0
# Action of step 697 is 1.0
# Action of step 698 is 1.0
# Action of step 699 is 1.0
# Action of step 700 is 1.0
# Action of step 701 is 1.0
# Action of step 702 is 1.0
# Action of step 703 is 1.0
# Action of step 704 is 1.0
# Action of step 705 is 1.0
# Action of step 706 is 1.0
# Action of step 707 is 1.0
# Action of step 708 is 1.0
# Action of step 709 is 1.0
# Action of step 710 is 1.0
# Action of step 711 is 1.0
# Action of step 712 is 1.0
# Action of step 713 is 1.0
# Action of step 714 is 1.0
# Action of step 715 is 1.0
# Action of step 716 is 1.0
# Action of step 717 is 1.0
# Action of step 718 is 1.0
# Action of step 719 is 1.0
# Action of step 720 is 1.0
# Action of step 721 is 1.0
# Action of step 722 is 1.0
# Action of step 723 is 1.0
# Action of step 724 is 1.0
# Action of step 725 is 1.0
# Action of step 726 is 1.0
# Action of step 727 is 1.0
# Action of step 728 is 1.0
# Action of step 729 is 1.0
# Action of step 730 is 1.0
# Action of step 731 is 1.0
# Action of step 732 is 1.0
# Action of step 733 is 1.0
# Action of step 734 is 1.0
# Action of step 735 is 1.0
# Action of step 736 is 1.0
# Action of step 737 is 1.0
# Action of step 738 is 1.0
# Action of step 739 is 1.0
# Action of step 740 is 1.0
# Action of step 741 is 1.0
# Action of step 742 is 1.0
# Action of step 743 is 1.0
# Action of step 744 is 1.0
# Action of step 745 is 1.0
# Action of step 746 is 1.0
# Action of step 747 is 1.0
# Action of step 748 is 1.0
# Action of step 749 is 1.0
# Action of step 750 is 1.0
# Action of step 751 is 1.0
# Action of step 752 is 1.0
# Action of step 753 is 1.0
# Action of step 754 is 1.0
# Action of step 755 is 1.0
# Action of step 756 is 1.0
# Action of step 757 is 1.0
# Action of step 758 is 1.0
# Action of step 759 is 1.0
# Action of step 760 is 1.0
# Action of step 761 is 1.0
# Action of step 762 is 1.0
# Action of step 763 is 1.0
# Action of step 764 is 1.0
# Action of step 765 is 1.0
# Action of step 766 is 1.0
# Action of step 767 is 1.0
# Action of step 768 is 1.0
# Action of step 769 is 1.0
# Action of step 770 is 1.0
# Action of step 771 is 1.0
# Action of step 772 is 1.0
# Action of step 773 is 1.0
# Action of step 774 is 1.0
# Action of step 775 is 1.0
# Action of step 776 is 1.0
# Action of step 777 is 1.0
# Action of step 778 is 1.0
# Action of step 779 is 1.0
# Action of step 780 is 1.0
# Action of step 781 is 1.0
# Action of step 782 is 1.0
# Action of step 783 is 1.0
# Action of step 784 is 1.0
# Action of step 785 is 1.0
# Action of step 786 is 1.0
# Action of step 787 is 1.0
# Action of step 788 is 1.0
# Action of step 789 is 1.0
# Action of step 790 is 1.0
# Action of step 791 is 1.0
# Action of step 792 is 1.0
# Action of step 793 is 1.0
# Action of step 794 is 1.0
# Action of step 795 is 1.0
# Action of step 796 is 1.0
# Action of step 797 is 1.0
# Action of step 798 is 1.0
# Action of step 799 is 1.0
# Action of step 800 is 1.0
# Action of step 801 is 1.0
# Action of step 802 is 1.0
# Action of step 803 is 1.0
# Action of step 804 is 1.0
# Action of step 805 is 1.0
# Action of step 806 is 1.0
# Action of step 807 is 1.0
# Action of step 808 is 1.0
# Action of step 809 is 1.0
# Action of step 810 is 1.0
# Action of step 811 is 1.0
# Action of step 812 is 1.0
# Action of step 813 is 1.0
# Action of step 814 is 1.0
# Action of step 815 is 1.0
# Action of step 816 is 1.0
# Action of step 817 is 1.0
# Action of step 818 is 1.0
# Action of step 819 is 1.0
# Action of step 820 is 1.0
# Action of step 821 is 1.0
# Action of step 822 is 1.0
# Action of step 823 is 1.0
# Action of step 824 is 1.0
# Action of step 825 is 1.0
# Action of step 826 is 1.0
# Action of step 827 is 1.0
# Action of step 828 is 1.0
# Action of step 829 is 1.0
# Action of step 830 is 1.0
# Action of step 831 is 1.0
# Action of step 832 is 1.0
# Action of step 833 is 1.0
# Action of step 834 is 1.0
# Action of step 835 is 1.0
# Action of step 836 is 1.0
# Action of step 837 is 1.0
# Action of step 838 is 1.0
# Action of step 839 is 1.0
# Action of step 840 is 1.0
# Action of step 841 is 1.0
# Action of step 842 is 1.0
# Action of step 843 is 1.0
# Action of step 844 is 1.0
# Action of step 845 is 1.0
# Action of step 846 is 1.0
# Action of step 847 is 1.0
# Action of step 848 is 1.0
# Action of step 849 is 1.0
# Action of step 850 is 1.0
# Action of step 851 is 1.0
# Action of step 852 is 1.0
# Action of step 853 is 1.0
# Action of step 854 is 1.0
# Action of step 855 is 1.0
# Action of step 856 is 1.0
# Action of step 857 is 1.0
# Action of step 858 is 1.0
# Action of step 859 is 1.0
# Action of step 860 is 1.0
# Action of step 861 is 1.0
# Action of step 862 is 1.0
# Action of step 863 is 1.0
# Action of step 864 is 1.0
# Action of step 865 is 1.0
# Action of step 866 is 1.0
# Action of step 867 is 1.0
# Action of step 868 is 1.0
# Action of step 869 is 1.0
# Action of step 870 is 1.0
# Action of step 871 is 1.0
# Action of step 872 is 1.0
# Action of step 873 is 1.0
# Action of step 874 is 1.0
# Action of step 875 is 1.0
# Action of step 876 is 1.0
# Action of step 877 is 1.0
# Action of step 878 is 1.0
# Action of step 879 is 1.0
# Action of step 880 is 1.0
# Action of step 881 is 1.0
# Action of step 882 is 1.0
# Action of step 883 is 1.0
# Action of step 884 is 1.0
# Action of step 885 is 1.0
# Action of step 886 is 1.0
# Action of step 887 is 1.0
# Action of step 888 is 1.0
# Action of step 889 is 1.0
# Action of step 890 is 1.0
# Action of step 891 is 1.0
# Action of step 892 is 1.0
# Action of step 893 is 1.0
# Action of step 894 is 1.0
# Action of step 895 is 1.0
# Action of step 896 is 1.0
# Action of step 897 is 1.0
# Action of step 898 is 1.0
# Action of step 899 is 1.0
# Action of step 900 is 1.0
# Action of step 901 is 1.0
# Action of step 902 is 1.0
# Action of step 903 is 1.0
# Action of step 904 is 1.0
# Action of step 905 is 1.0
# Action of step 906 is 1.0
# Action of step 907 is 1.0
# Action of step 908 is 1.0
# Action of step 909 is 1.0
# Action of step 910 is 1.0
# Action of step 911 is 1.0
# Action of step 912 is 1.0
# Action of step 913 is 1.0
# Action of step 914 is 1.0
# Action of step 915 is 1.0
# Action of step 916 is 1.0
# Action of step 917 is 1.0
# Action of step 918 is 1.0
# Action of step 919 is 1.0
# Action of step 920 is 1.0
# Action of step 921 is 1.0
# Action of step 922 is 1.0
# Action of step 923 is 1.0
# Action of step 924 is 1.0
# Action of step 925 is 1.0
# Action of step 926 is 1.0
# Action of step 927 is 1.0
# Action of step 928 is 1.0
# Action of step 929 is 1.0
# Action of step 930 is 1.0
# Action of step 931 is 1.0
# Action of step 932 is 1.0
# Action of step 933 is 1.0
# Action of step 934 is 1.0
# Action of step 935 is 1.0
# Action of step 936 is 1.0
# Action of step 937 is 1.0
# Action of step 938 is 1.0
# Action of step 939 is 1.0
# Action of step 940 is 1.0
# Action of step 941 is 1.0
# Action of step 942 is 1.0
# Action of step 943 is 1.0
# Action of step 944 is 1.0
# Action of step 945 is 1.0
# Action of step 946 is 1.0
# Action of step 947 is 1.0
# Action of step 948 is 1.0
# Action of step 949 is 1.0
# Action of step 950 is 1.0
# Action of step 951 is 1.0
# Action of step 952 is 1.0
# Action of step 953 is 1.0
# Action of step 954 is 1.0
# Action of step 955 is 1.0
# Action of step 956 is 1.0
# Action of step 957 is 1.0
# Action of step 958 is 1.0
# Action of step 959 is 1.0
# Action of step 960 is 1.0
# Action of step 961 is 1.0
# Action of step 962 is 1.0
# Action of step 963 is 1.0
# Action of step 964 is 1.0
# Action of step 965 is 1.0
# Action of step 966 is 1.0
# Action of step 967 is 1.0
# Action of step 968 is 1.0
# Action of step 969 is 1.0
# Action of step 970 is 1.0
# Action of step 971 is 1.0
# Action of step 972 is 1.0
# Action of step 973 is 1.0
# Action of step 974 is 1.0
# Action of step 975 is 1.0
# Action of step 976 is 1.0
# Action of step 977 is 1.0
# Action of step 978 is 1.0
# Action of step 979 is 1.0
# Action of step 980 is 1.0
# Action of step 981 is 1.0
# Action of step 982 is 1.0
# Action of step 983 is 1.0
# Action of step 984 is 1.0
# Action of step 985 is 1.0
# Action of step 986 is 1.0
# Action of step 987 is 1.0
# Action of step 988 is 1.0
# Action of step 989 is 1.0
# Action of step 990 is 1.0
# Action of step 991 is 1.0
# Action of step 992 is 1.0
# Action of step 993 is 1.0
# Action of step 994 is 1.0
# Action of step 995 is 1.0
# Action of step 996 is 1.0
# Action of step 997 is 1.0
# Action of step 998 is 1.0
# Action of step 999 is 1.0
# Action of step 1000 is 1.0
# Action of step 1001 is 1.0
# Action of step 1002 is 1.0
# Action of step 1003 is 1.0
# Action of step 1004 is 1.0
# Action of step 1005 is 1.0
# Action of step 1006 is 1.0
# Action of step 1007 is 1.0
# Action of step 1008 is 1.0
# Action of step 1009 is 1.0
# Action of step 1010 is 1.0
# Action of step 1011 is 1.0
# Action of step 1012 is 1.0
# Action of step 1013 is 1.0
# Action of step 1014 is 1.0
# Action of step 1015 is 1.0
# Action of step 1016 is 1.0
# Action of step 1017 is 1.0
# Action of step 1018 is 1.0
# Action of step 1019 is 1.0
# Action of step 1020 is 1.0
# Action of step 1021 is 1.0
# Action of step 1022 is 1.0
# Action of step 1023 is 1.0
# Action of step 1024 is 1.0
# Action of step 1025 is 1.0
# Action of step 1026 is 1.0
# Action of step 1027 is 1.0
# Action of step 1028 is 1.0
# Action of step 1029 is 1.0
# Action of step 1030 is 1.0
# Action of step 1031 is 1.0
# Action of step 1032 is 1.0
# Action of step 1033 is 1.0
# Action of step 1034 is 1.0
# Action of step 1035 is 1.0
# Action of step 1036 is 1.0
# Action of step 1037 is 1.0
# Action of step 1038 is 1.0
# Action of step 1039 is 1.0
# Action of step 1040 is 1.0
# Action of step 1041 is 1.0
# Action of step 1042 is 1.0
# Action of step 1043 is 1.0
# Action of step 1044 is 1.0
# Action of step 1045 is 1.0
# Action of step 1046 is 1.0
# Action of step 1047 is 1.0
# Action of step 1048 is 1.0
# Action of step 1049 is 1.0
# Action of step 1050 is 1.0
# Action of step 1051 is 1.0
# Action of step 1052 is 1.0
# Action of step 1053 is 1.0
# Action of step 1054 is 1.0
# Action of step 1055 is 1.0
# Action of step 1056 is 1.0
# Action of step 1057 is 1.0
# Action of step 1058 is 1.0
# Action of step 1059 is 1.0
# Action of step 1060 is 1.0
# Action of step 1061 is 1.0
# Action of step 1062 is 1.0
# Action of step 1063 is 1.0
# Action of step 1064 is 1.0
# Action of step 1065 is 1.0
# Action of step 1066 is 1.0
# Action of step 1067 is 1.0
# Action of step 1068 is 1.0
# Action of step 1069 is 1.0
# Action of step 1070 is 1.0
# Action of step 1071 is 1.0
# Action of step 1072 is 1.0
# Action of step 1073 is 1.0
# Action of step 1074 is 1.0
# Action of step 1075 is 1.0
# Action of step 1076 is 1.0
# Action of step 1077 is 1.0
# Action of step 1078 is 1.0
# Action of step 1079 is 1.0
# Action of step 1080 is 1.0
# Action of step 1081 is 1.0
# Action of step 1082 is 1.0
# Action of step 1083 is 1.0
# Action of step 1084 is 1.0
# Action of step 1085 is 1.0
# Action of step 1086 is 1.0
# Action of step 1087 is 1.0
# Action of step 1088 is 1.0
# Action of step 1089 is 1.0
# Action of step 1090 is 1.0
# Action of step 1091 is 1.0
# Action of step 1092 is 1.0
# Action of step 1093 is 1.0
# Action of step 1094 is 1.0
# Action of step 1095 is 1.0
# Action of step 1096 is 1.0
# Action of step 1097 is 1.0
# Action of step 1098 is 1.0
# Action of step 1099 is 1.0
# Action of step 1100 is 1.0
# Action of step 1101 is 1.0
# Action of step 1102 is 1.0
# Action of step 1103 is 1.0
# Action of step 1104 is 1.0
# Action of step 1105 is 1.0
# Action of step 1106 is 1.0
# Action of step 1107 is 1.0
# Action of step 1108 is 1.0
# Action of step 1109 is 1.0
# Action of step 1110 is 1.0
# Action of step 1111 is 1.0
# Action of step 1112 is 1.0
# Action of step 1113 is 1.0
# Action of step 1114 is 1.0
# Action of step 1115 is 1.0
# Action of step 1116 is 1.0
# Action of step 1117 is 1.0
# Action of step 1118 is 1.0
# Action of step 1119 is 1.0
# Action of step 1120 is 1.0
# Action of step 1121 is 1.0
# Action of step 1122 is 1.0
# Action of step 1123 is 1.0
# Action of step 1124 is 1.0
# Action of step 1125 is 1.0
# Action of step 1126 is 1.0
# Action of step 1127 is 1.0
# Action of step 1128 is 1.0
# Action of step 1129 is 1.0
# Action of step 1130 is 1.0
# Action of step 1131 is 1.0
# Action of step 1132 is 1.0
# Action of step 1133 is 1.0
# Action of step 1134 is 1.0
# Action of step 1135 is 1.0
# Action of step 1136 is 1.0
# Action of step 1137 is 1.0
# Action of step 1138 is 1.0
# Action of step 1139 is 1.0
# Action of step 1140 is 1.0
# Action of step 1141 is 1.0
# Action of step 1142 is 1.0
# Action of step 1143 is 1.0
# Action of step 1144 is 1.0
# Action of step 1145 is 1.0
# Action of step 1146 is 1.0
# Action of step 1147 is 1.0
# Action of step 1148 is 1.0
# Action of step 1149 is 1.0
# Action of step 1150 is 1.0
# Action of step 1151 is 1.0
# Action of step 1152 is 1.0
# Action of step 1153 is 1.0
# Action of step 1154 is 1.0
# Action of step 1155 is 1.0
# Action of step 1156 is 1.0
# Action of step 1157 is 1.0
# Action of step 1158 is 1.0
# Action of step 1159 is 1.0
# Action of step 1160 is 1.0
# Action of step 1161 is 1.0
# Action of step 1162 is 1.0
# Action of step 1163 is 1.0
# Action of step 1164 is 1.0
# Action of step 1165 is 1.0
# Action of step 1166 is 1.0
# Action of step 1167 is 1.0
# Action of step 1168 is 1.0
# Action of step 1169 is 1.0
# Action of step 1170 is 1.0
# Action of step 1171 is 1.0
# Action of step 1172 is 1.0
# Action of step 1173 is 1.0
# Action of step 1174 is 1.0
# Action of step 1175 is 1.0
# Action of step 1176 is 1.0
# Action of step 1177 is 1.0
# Action of step 1178 is 1.0
# Action of step 1179 is 1.0
# Action of step 1180 is 1.0
# Action of step 1181 is 1.0
# Action of step 1182 is 1.0
# Action of step 1183 is 1.0
# Action of step 1184 is 1.0
# Action of step 1185 is 1.0
# Action of step 1186 is 1.0
# Action of step 1187 is 1.0
# Action of step 1188 is 1.0
# Action of step 1189 is 1.0
# Action of step 1190 is 1.0
# Action of step 1191 is 1.0
# Action of step 1192 is 1.0
# Action of step 1193 is 1.0
# Action of step 1194 is 1.0
# Action of step 1195 is 1.0
# Action of step 1196 is 1.0
# Action of step 1197 is 1.0
# Action of step 1198 is 1.0
# Action of step 1199 is 1.0
# Action of step 1200 is 1.0
# Action of step 1201 is 1.0
# Action of step 1202 is 1.0
# Action of step 1203 is 1.0
# Action of step 1204 is 1.0
# Action of step 1205 is 1.0
# Action of step 1206 is 1.0
# Action of step 1207 is 1.0
# Action of step 1208 is 1.0
# Action of step 1209 is 1.0
# Action of step 1210 is 1.0
# Action of step 1211 is 1.0
# Action of step 1212 is 1.0
# Action of step 1213 is 1.0
# Action of step 1214 is 1.0
# Action of step 1215 is 1.0
# Action of step 1216 is 1.0
# Action of step 1217 is 1.0
# Action of step 1218 is 1.0
# Action of step 1219 is 1.0
# Action of step 1220 is 1.0
# Action of step 1221 is 1.0
# Action of step 1222 is 1.0
# Action of step 1223 is 1.0
# Action of step 1224 is 1.0
# Action of step 1225 is 1.0
# Action of step 1226 is 1.0
# Action of step 1227 is 1.0
# Action of step 1228 is 1.0
# Action of step 1229 is 1.0
# Action of step 1230 is 1.0
# Action of step 1231 is 1.0
# Action of step 1232 is 1.0
# Action of step 1233 is 1.0
# Action of step 1234 is 1.0
# Action of step 1235 is 1.0
# Action of step 1236 is 1.0
# Action of step 1237 is 1.0
# Action of step 1238 is 1.0
# Action of step 1239 is 1.0
# Action of step 1240 is 1.0
# Action of step 1241 is 1.0
# Action of step 1242 is 1.0
# Action of step 1243 is 1.0
# Action of step 1244 is 1.0
# Action of step 1245 is 1.0
# Action of step 1246 is 1.0
# Action of step 1247 is 1.0
# Action of step 1248 is 1.0
# Action of step 1249 is 1.0
# Action of step 1250 is 1.0
# Action of step 1251 is 1.0
# Action of step 1252 is 1.0
# Action of step 1253 is 1.0
# Action of step 1254 is 1.0
# Action of step 1255 is 1.0
# Action of step 1256 is 1.0
# Action of step 1257 is 1.0
# Action of step 1258 is 1.0
# Action of step 1259 is 1.0
# Action of step 1260 is 1.0
# Action of step 1261 is 1.0
# Action of step 1262 is 1.0
# Action of step 1263 is 1.0
# Action of step 1264 is 1.0
# Action of step 1265 is 1.0
# Action of step 1266 is 1.0
# Action of step 1267 is 1.0
# Action of step 1268 is 1.0
# Action of step 1269 is 1.0
# Action of step 1270 is 1.0
# Action of step 1271 is 1.0
# Action of step 1272 is 1.0
# Action of step 1273 is 1.0
# Action of step 1274 is 1.0
# Action of step 1275 is 1.0
# Action of step 1276 is 1.0
# Action of step 1277 is 1.0
# Action of step 1278 is 1.0
# Action of step 1279 is 1.0
# Action of step 1280 is 1.0
# Action of step 1281 is 1.0
# Action of step 1282 is 1.0
# Action of step 1283 is 1.0
# Action of step 1284 is 1.0
# Action of step 1285 is 1.0
# Action of step 1286 is 1.0
# Action of step 1287 is 1.0
# Action of step 1288 is 1.0
# Action of step 1289 is 1.0
# Action of step 1290 is 1.0
# Action of step 1291 is 1.0
# Action of step 1292 is 1.0
# Action of step 1293 is 1.0
# Action of step 1294 is 1.0
# Action of step 1295 is 1.0
# Action of step 1296 is 1.0
# Action of step 1297 is 1.0
# Action of step 1298 is 1.0
# Action of step 1299 is 1.0
# Action of step 1300 is 1.0
# Action of step 1301 is 1.0
# Action of step 1302 is 1.0
# Action of step 1303 is 1.0
# Action of step 1304 is 1.0
# Action of step 1305 is 1.0
# Action of step 1306 is 1.0
# Action of step 1307 is 1.0
# Action of step 1308 is 1.0
# Action of step 1309 is 1.0
# Action of step 1310 is 1.0
# Action of step 1311 is 1.0
# Action of step 1312 is 1.0
# Action of step 1313 is 1.0
# Action of step 1314 is 1.0
# Action of step 1315 is 1.0
# Action of step 1316 is 1.0
# Action of step 1317 is 1.0
# Action of step 1318 is 1.0
# Action of step 1319 is 1.0
# Action of step 1320 is 1.0
# Action of step 1321 is 1.0
# Action of step 1322 is 1.0
# Action of step 1323 is 1.0
# Action of step 1324 is 1.0
# Action of step 1325 is 1.0
# Action of step 1326 is 1.0
# Action of step 1327 is 1.0
# Action of step 1328 is 1.0
# Action of step 1329 is 1.0
# Action of step 1330 is 1.0
# Action of step 1331 is 1.0
# Action of step 1332 is 1.0
# Action of step 1333 is 1.0
# Action of step 1334 is 1.0
# Action of step 1335 is 1.0
# Action of step 1336 is 1.0
# Action of step 1337 is 1.0
# Action of step 1338 is 1.0
# Action of step 1339 is 1.0
# Action of step 1340 is 1.0
# Action of step 1341 is 1.0
# Action of step 1342 is 1.0
# Action of step 1343 is 1.0
# Action of step 1344 is 1.0
# Action of step 1345 is 1.0
# Action of step 1346 is 1.0
# Action of step 1347 is 1.0
# Action of step 1348 is 1.0
# Action of step 1349 is 1.0
# Action of step 1350 is 1.0
# Action of step 1351 is 1.0
# Action of step 1352 is 1.0
# Action of step 1353 is 1.0
# Action of step 1354 is 1.0
# Action of step 1355 is 1.0
# Action of step 1356 is 1.0
# Action of step 1357 is 1.0
# Action of step 1358 is 1.0
# Action of step 1359 is 1.0
# Action of step 1360 is 1.0
# Action of step 1361 is 1.0
# Action of step 1362 is 1.0
# Action of step 1363 is 1.0
# Action of step 1364 is 1.0
# Action of step 1365 is 1.0
# Action of step 1366 is 1.0
# Action of step 1367 is 1.0
# Action of step 1368 is 1.0
# Action of step 1369 is 1.0
# Action of step 1370 is 1.0
# Action of step 1371 is 1.0
# Action of step 1372 is 1.0
# Action of step 1373 is 1.0
# Action of step 1374 is 1.0
# Action of step 1375 is 1.0
# Action of step 1376 is 1.0
# Action of step 1377 is 1.0
# Action of step 1378 is 1.0
# Action of step 1379 is 1.0
# Action of step 1380 is 1.0
# Action of step 1381 is 1.0
# Action of step 1382 is 1.0
# Action of step 1383 is 1.0
# Action of step 1384 is 1.0
# Action of step 1385 is 1.0
# Action of step 1386 is 1.0
# Action of step 1387 is 1.0
# Action of step 1388 is 1.0
# Action of step 1389 is 1.0
# Action of step 1390 is 1.0
# Action of step 1391 is 1.0
# Action of step 1392 is 1.0
# Action of step 1393 is 1.0
# Action of step 1394 is 1.0
# Action of step 1395 is 1.0
# Action of step 1396 is 1.0
# Action of step 1397 is 1.0
# Action of step 1398 is 1.0
# Action of step 1399 is 1.0
# Action of step 1400 is 1.0
# Action of step 1401 is 1.0
# Action of step 1402 is 1.0
# Action of step 1403 is 1.0
# Action of step 1404 is 1.0
# Action of step 1405 is 1.0
# Action of step 1406 is 1.0
# Action of step 1407 is 1.0
# Action of step 1408 is 1.0
# Action of step 1409 is 1.0
# Action of step 1410 is 1.0
# Action of step 1411 is 1.0
# Action of step 1412 is 1.0
# Action of step 1413 is 1.0
# Action of step 1414 is 1.0
# Action of step 1415 is 1.0
# Action of step 1416 is 1.0
# Action of step 1417 is 1.0
# Action of step 1418 is 1.0
# Action of step 1419 is 1.0
# Action of step 1420 is 1.0
# Action of step 1421 is 1.0
# Action of step 1422 is 1.0
# Action of step 1423 is 1.0
# Action of step 1424 is 1.0
# Action of step 1425 is 1.0
# Action of step 1426 is 1.0
# Action of step 1427 is 1.0
# Action of step 1428 is 1.0
# Action of step 1429 is 1.0
# Action of step 1430 is 1.0
# Action of step 1431 is 1.0
# Action of step 1432 is 1.0
# Action of step 1433 is 1.0
# Action of step 1434 is 1.0
# Action of step 1435 is 1.0
# Action of step 1436 is 1.0
# Action of step 1437 is 1.0
# Action of step 1438 is 1.0
# Action of step 1439 is 1.0
# Action of step 1440 is 1.0
# Action of step 1441 is 1.0
# Action of step 1442 is 1.0
# Action of step 1443 is 1.0
# Action of step 1444 is 1.0
# Action of step 1445 is 1.0
# Action of step 1446 is 1.0
# Action of step 1447 is 1.0
# Action of step 1448 is 1.0
# Action of step 1449 is 1.0
# Action of step 1450 is 1.0
# Action of step 1451 is 1.0
# Action of step 1452 is 1.0
# Action of step 1453 is 1.0
# Action of step 1454 is 1.0
# Action of step 1455 is 1.0
# Action of step 1456 is 1.0
# Action of step 1457 is 1.0
# Action of step 1458 is 1.0
# Action of step 1459 is 1.0
# Action of step 1460 is 1.0
# Action of step 1461 is 1.0
# Action of step 1462 is 1.0
# Action of step 1463 is 1.0
# Action of step 1464 is 1.0
# Action of step 1465 is 1.0
# Action of step 1466 is 1.0
# Action of step 1467 is 1.0
# Action of step 1468 is 1.0
# Action of step 1469 is 1.0
# Action of step 1470 is 1.0
# Action of step 1471 is 1.0
# Action of step 1472 is 1.0
# Action of step 1473 is 1.0
# Action of step 1474 is 1.0
# Action of step 1475 is 1.0
# Action of step 1476 is 1.0
# Action of step 1477 is 1.0
# Action of step 1478 is 1.0
# Action of step 1479 is 1.0
# Action of step 1480 is 1.0
# Action of step 1481 is 1.0
# Action of step 1482 is 1.0
# Action of step 1483 is 1.0
# Action of step 1484 is 1.0
# Action of step 1485 is 1.0
# Action of step 1486 is 1.0
# Action of step 1487 is 1.0
# Action of step 1488 is 1.0
# Action of step 1489 is 1.0
# Action of step 1490 is 1.0
# Action of step 1491 is 1.0
# Action of step 1492 is 1.0
# Action of step 1493 is 1.0
# Action of step 1494 is 1.0
# Action of step 1495 is 1.0
# Action of step 1496 is 1.0
# Action of step 1497 is 1.0
# Action of step 1498 is 1.0
# Action of step 1499 is 1.0
# Action of step 1500 is 1.0
# Action of step 1501 is 1.0
# Action of step 1502 is 1.0
# Action of step 1503 is 1.0
# Action of step 1504 is 1.0
# Action of step 1505 is 1.0
# Action of step 1506 is 1.0
# Action of step 1507 is 1.0
# Action of step 1508 is 1.0
# Action of step 1509 is 1.0
# Action of step 1510 is 1.0
# Action of step 1511 is 1.0
# Action of step 1512 is 1.0
# Action of step 1513 is 1.0
# Action of step 1514 is 1.0
# Action of step 1515 is 1.0
# Action of step 1516 is 1.0
# Action of step 1517 is 1.0
# Action of step 1518 is 1.0
# Action of step 1519 is 1.0
# Action of step 1520 is 1.0
# Action of step 1521 is 1.0
# Action of step 1522 is 1.0
# Action of step 1523 is 1.0
# Action of step 1524 is 1.0
# Action of step 1525 is 1.0
# Action of step 1526 is 1.0
# Action of step 1527 is 1.0
# Action of step 1528 is 1.0
# Action of step 1529 is 1.0
# Action of step 1530 is 1.0
# Action of step 1531 is 1.0
# Action of step 1532 is 1.0
# Action of step 1533 is 1.0
# Action of step 1534 is 1.0
# Action of step 1535 is 1.0
# Action of step 1536 is 1.0
# Action of step 1537 is 1.0
# Action of step 1538 is 1.0
# Action of step 1539 is 1.0
# Action of step 1540 is 1.0
# Action of step 1541 is 1.0
# Action of step 1542 is 1.0
# Action of step 1543 is 1.0
# Action of step 1544 is 1.0
# Action of step 1545 is 1.0
# Action of step 1546 is 1.0
# Action of step 1547 is 1.0
# Action of step 1548 is 1.0
# Action of step 1549 is 1.0
# Action of step 1550 is 1.0
# Action of step 1551 is 1.0
# Action of step 1552 is 1.0
# Action of step 1553 is 1.0
# Action of step 1554 is 1.0
# Action of step 1555 is 1.0
# Action of step 1556 is 1.0
# Action of step 1557 is 1.0
# Action of step 1558 is 1.0
# Action of step 1559 is 1.0
# Action of step 1560 is 1.0
# Action of step 1561 is 1.0
# Action of step 1562 is 1.0
# Action of step 1563 is 1.0
# Action of step 1564 is 1.0
# Action of step 1565 is 1.0
# Action of step 1566 is 1.0
# Action of step 1567 is 1.0
# Action of step 1568 is 1.0
# Action of step 1569 is 1.0
# Action of step 1570 is 1.0
# Action of step 1571 is 1.0
# Action of step 1572 is 1.0
# Action of step 1573 is 1.0
# Action of step 1574 is 1.0
# Action of step 1575 is 1.0
# Action of step 1576 is 1.0
# Action of step 1577 is 1.0
# Action of step 1578 is 1.0
# Action of step 1579 is 1.0
# Action of step 1580 is 1.0
# Action of step 1581 is 1.0
# Action of step 1582 is 1.0
# Action of step 1583 is 1.0
# Action of step 1584 is 1.0
# Action of step 1585 is 1.0
# Action of step 1586 is 1.0
# Action of step 1587 is 1.0
# Action of step 1588 is 1.0
# Action of step 1589 is 1.0
# Action of step 1590 is 1.0
# Action of step 1591 is 1.0
# Action of step 1592 is 1.0
# Action of step 1593 is 1.0
# Action of step 1594 is 1.0
# Action of step 1595 is 1.0
# Action of step 1596 is 1.0
# Action of step 1597 is 1.0
# Action of step 1598 is 1.0
# Action of step 1599 is 1.0
# Action of step 1600 is 1.0
# Action of step 1601 is 1.0
# Action of step 1602 is 1.0
# Action of step 1603 is 1.0
# Action of step 1604 is 1.0
# Action of step 1605 is 1.0
# Action of step 1606 is 1.0
# Action of step 1607 is 1.0
# Action of step 1608 is 1.0
# Action of step 1609 is 1.0
# Action of step 1610 is 1.0
# Action of step 1611 is 1.0
# Action of step 1612 is 1.0
# Action of step 1613 is 1.0
# Action of step 1614 is 1.0
# Action of step 1615 is 1.0
# Action of step 1616 is 1.0
# Action of step 1617 is 1.0
# Action of step 1618 is 1.0
# Action of step 1619 is 1.0
# Action of step 1620 is 1.0
# Action of step 1621 is 1.0
# Action of step 1622 is 1.0
# Action of step 1623 is 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[637], line 2
#       1 # the training log just show up when total_timesteps higher than 15.000
# ----> 2 trained_ddpg = agent_ddpg.train_model(model=model_ddpg,
#       3                              tb_log_name='ddpg',
#       4                              total_timesteps=total_training_step)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/finrl/agents/stablebaselines3/models.py:117, in DRLAgent.train_model(model, tb_log_name, total_timesteps)
#     113 @staticmethod
#     114 def train_model(
#     115     model, tb_log_name, total_timesteps=5000
#     116 ):  # this function is static method, so it can be called without creating an instance of the class
# --> 117     model = model.learn(
#     118         total_timesteps=total_timesteps,
#     119         tb_log_name=tb_log_name,
#     120         callback=TensorboardCallback(),
#     121     )
#     122     return model
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/ddpg/ddpg.py:123, in DDPG.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     114 def learn(
#     115     self: SelfDDPG,
#     116     total_timesteps: int,
#    (...)
#     121     progress_bar: bool = False,
#     122 ) -> SelfDDPG:
# --> 123     return super().learn(
#     124         total_timesteps=total_timesteps,
#     125         callback=callback,
#     126         log_interval=log_interval,
#     127         tb_log_name=tb_log_name,
#     128         reset_num_timesteps=reset_num_timesteps,
#     129         progress_bar=progress_bar,
#     130     )
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:203, in TD3.train(self, gradient_steps, batch_size)
#     200 self.actor.optimizer.step()
#     202 polyak_update(self.critic.parameters(), self.critic_target.parameters(), self.tau)
# --> 203 polyak_update(self.actor.parameters(), self.actor_target.parameters(), self.tau)
#     204 # Copy running stats, see GH issue #996
#     205 polyak_update(self.critic_batch_norm_stats, self.critic_batch_norm_stats_target, 1.0)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:469, in polyak_update(params, target_params, tau)
#     452 """
#     453 Perform a Polyak average update on ``target_params`` using ``params``:
#     454 target parameters are slowly updated towards the main parameters.
#    (...)
#     465 :param tau: the soft update coefficient ("Polyak update", between 0 and 1)
#     466 """
#     467 with th.no_grad():
#     468     # zip does not raise an exception if length of parameters does not match.
# --> 469     for param, target_param in zip_strict(params, target_params):
#     470         target_param.data.mul_(1 - tau)
#     471         th.add(target_param.data, param.data, alpha=tau, out=target_param.data)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/utils.py:442, in zip_strict(*iterables)
#     440 sentinel = object()
#     441 for combo in zip_longest(*iterables, fillvalue=sentinel):
# --> 442     if sentinel in combo:
#     443         raise ValueError("Iterables have different lengths")
#     444     yield combo
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model 3: SAC

# %%
# episode_length = len(e_train_gym.df) + 1
# episode_amount = 4
# total_training_step = episode_length*episode_amount

# %%
# agent_sac = DRLAgent(env = env_train)
# SAC_PARAMS = {
#     "batch_size": 128,
#     "buffer_size": episode_length,
#     "learning_rate": 0.0003,
#     "learning_starts": episode_length,
#     "ent_coef": "auto_0.1",
# }

# model_sac = agent_sac.get_model("sac",model_kwargs = SAC_PARAMS)

# # set up logger
# tmp_path = TENSORBOARD_LOG_DIR + '/test_sac/sac_12'
# new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# # Set new logger
# model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 5035, 'learning_rate': 0.0003, 'learning_starts': 5035, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/test_sac/sac_12

# %%
# trained_sac = agent_sac.train_model(model=model_sac, 
#                              tb_log_name='sac',
#                              total_timesteps=total_training_step)
# Out:
# Action of step 0 is -0.8199819326400757
# Action of step 1 is 0.014607906341552734
# Action of step 2 is 0.040423035621643066
# Action of step 3 is 0.45287370681762695
# Action of step 4 is 0.1833662986755371
# Action of step 736 is 0.3336104154586792
# Action of step 737 is 0.35383105278015137
# Action of step 738 is 0.4734402894973755
# Action of step 739 is 0.6137903928756714
# Action of step 740 is -0.2509857416152954
# Action of step 741 is 0.16837787628173828
# Action of step 742 is -0.7856350541114807
# Action of step 743 is -0.04267263412475586
# Action of step 744 is -0.6798879504203796
# Action of step 745 is -0.4462670087814331
# Action of step 746 is 0.43280184268951416
# Action of step 747 is 0.48212945461273193
# Action of step 748 is 0.7186977863311768
# Action of step 749 is 0.9765748977661133
# Action of step 750 is -0.2302594780921936
# Action of step 751 is 0.1794145107269287
# Action of step 752 is 0.170052170753479
# Action of step 753 is -0.09916722774505615
# Action of step 754 is -0.40924108028411865
# Action of step 755 is -0.36897265911102295
# Action of step 756 is -0.160006582736969
# Action of step 757 is -0.18367338180541992
# Action of step 758 is 0.04540431499481201
# Action of step 759 is -0.21550285816192627
# Action of step 760 is 0.21210932731628418
# Action of step 761 is 0.3975445032119751
# Action of step 762 is -0.1894749402999878
# Action of step 763 is -0.17603200674057007
# Action of step 764 is 0.9166792631149292
# Action of step 765 is 0.45329058170318604
# Action of step 766 is -0.8278434872627258
# Action of step 767 is 0.12585783004760742
# Action of step 768 is 0.28299522399902344
# Action of step 769 is 0.018952608108520508
# Action of step 770 is -0.019663512706756592
# Action of step 771 is 0.3841993808746338
# Action of step 772 is 0.8265714645385742
# Action of step 773 is 0.3468146324157715
# Action of step 774 is -0.5796538591384888
# Action of step 775 is -0.4710797667503357
# Action of step 776 is -0.06250154972076416
# Action of step 777 is 0.33916211128234863
# Action of step 778 is 0.6081064939498901
# Action of step 779 is -0.9473083019256592
# Action of step 780 is -0.8356497287750244
# Action of step 781 is -0.04901862144470215
# Action of step 782 is 0.5983378887176514
# Action of step 783 is 0.8971296548843384
# Action of step 784 is 0.34521329402923584
# Action of step 785 is -0.10405910015106201
# Action of step 786 is -0.8039102554321289
# Action of step 787 is -0.8565484285354614
# Action of step 788 is -0.17318564653396606
# Action of step 789 is -0.20725756883621216
# Action of step 790 is -0.9823253750801086
# Action of step 791 is 0.8667645454406738
# Action of step 792 is -0.36963140964508057
# Action of step 793 is 0.15801680088043213
# Action of step 794 is 0.05047571659088135
# Action of step 795 is -0.20209002494812012
# Action of step 796 is -0.09710592031478882
# Action of step 797 is 0.3508636951446533
# Action of step 798 is 0.8018560409545898
# Action of step 799 is 0.7232694625854492
# Action of step 800 is 0.604200005531311
# Action of step 801 is -0.9336616396903992
# Action of step 802 is -0.10655772686004639
# Action of step 803 is -0.1778661012649536
# Action of step 804 is -0.7846968173980713
# Action of step 805 is -0.969441831111908
# Action of step 806 is 0.7220523357391357
# Action of step 807 is 0.16820204257965088
# Action of step 808 is -0.2537803053855896
# Action of step 809 is 0.8483221530914307
# Action of step 810 is -0.15737509727478027
# Action of step 811 is -0.8807049989700317
# Action of step 812 is 0.37457871437072754
# Action of step 813 is 0.7673227787017822
# Action of step 814 is 0.8884153366088867
# Action of step 815 is -0.8336143493652344
# Action of step 816 is -0.490093469619751
# Action of step 1136 is 0.6960036754608154
# Action of step 1137 is -0.6675008535385132
# Action of step 1138 is -0.13864284753799438
# Action of step 1139 is 0.03032839298248291
# Action of step 1140 is 0.5715254545211792
# Action of step 1141 is -0.1072956919670105
# Action of step 1142 is 0.7626786231994629
# Action of step 1143 is -0.5180010795593262
# Action of step 1144 is -0.9476404190063477
# Action of step 1145 is 0.7711327075958252
# Action of step 1146 is -0.6994069814682007
# Action of step 1147 is 0.4722578525543213
# ...
# Action of step 1684 is 1.0
# Action of step 1685 is 1.0
# Action of step 1686 is 1.0
# Action of step 1687 is 1.0
# Action of step 1688 is 1.0
# Action of step 1689 is 1.0
# Action of step 1690 is 1.0
# Action of step 1691 is 1.0
# Action of step 1692 is 1.0
# Action of step 1693 is 1.0
# Action of step 1694 is 1.0
# Action of step 1695 is 1.0
# Action of step 1696 is 1.0
# Action of step 1697 is 1.0
# Action of step 1698 is 1.0
# Action of step 1699 is 1.0
# Action of step 1700 is 1.0
# Action of step 1701 is 1.0
# Action of step 1702 is 1.0
# Action of step 1703 is 1.0
# Action of step 1704 is 1.0
# Action of step 1705 is 1.0
# Action of step 1706 is 1.0
# Action of step 1707 is 1.0
# Action of step 1708 is 1.0
# Action of step 1709 is 1.0
# Action of step 1710 is 1.0
# Action of step 1711 is 1.0
# Action of step 1712 is 1.0
# Action of step 1713 is 1.0
# Action of step 1714 is 1.0
# Action of step 1715 is 1.0
# Action of step 1716 is 1.0
# Action of step 1717 is 1.0
# Action of step 1718 is 1.0
# Action of step 1719 is 1.0
# Action of step 1720 is 1.0
# Action of step 1721 is 1.0
# Action of step 1722 is 1.0
# Action of step 1723 is 1.0
# Action of step 1724 is 1.0
# Action of step 1725 is 1.0
# Action of step 1726 is 1.0
# Action of step 1727 is 1.0
# Action of step 1728 is 1.0
# Action of step 1729 is 1.0
# Action of step 1730 is 1.0
# Action of step 1731 is 1.0
# Action of step 1732 is 1.0
# Action of step 1733 is 1.0
# Action of step 1734 is 1.0
# Action of step 1735 is 1.0
# Action of step 1736 is 1.0
# Action of step 1737 is 1.0
# Action of step 1738 is 1.0
# Action of step 1739 is 1.0
# Action of step 1740 is 1.0
# Action of step 1741 is 1.0
# Action of step 1742 is 1.0
# Action of step 1743 is 1.0
# Action of step 1744 is 1.0
# Action of step 1745 is 1.0
# Action of step 1746 is 1.0
# Action of step 1747 is 1.0
# Action of step 1748 is 1.0
# Action of step 1749 is 1.0
# Action of step 1750 is 1.0
# Action of step 1751 is 1.0
# Action of step 1752 is 1.0
# Action of step 1753 is 1.0
# Action of step 1754 is 1.0
# Action of step 1755 is 1.0
# Action of step 1756 is 1.0
# Action of step 1757 is 1.0
# Action of step 1758 is 1.0
# Action of step 1759 is 1.0
# Action of step 1760 is 1.0
# Action of step 1761 is 1.0
# Action of step 1762 is 1.0
# Action of step 1763 is 1.0
# Action of step 1764 is 1.0
# Action of step 1765 is 1.0
# Action of step 1766 is 1.0
# Action of step 1767 is 1.0
# Action of step 1768 is 1.0
# Action of step 1769 is 1.0
# Action of step 1770 is 1.0
# Action of step 1771 is 1.0
# Action of step 1772 is 1.0
# Action of step 1773 is 1.0
# Action of step 1774 is 1.0
# Action of step 1775 is 1.0
# Action of step 1776 is 1.0
# Action of step 1777 is 1.0
# Action of step 1778 is 1.0
# Action of step 1779 is 1.0
# Action of step 1780 is 1.0
# Action of step 1781 is 1.0
# Action of step 1782 is 1.0
# Action of step 1783 is 1.0
# Action of step 1784 is 1.0
# Action of step 1785 is 1.0
# Action of step 1786 is 1.0
# Action of step 1787 is 1.0
# Action of step 1788 is 1.0
# Action of step 1789 is 1.0
# Action of step 1790 is 1.0
# Action of step 1791 is 1.0
# Action of step 1792 is 1.0
# Action of step 1793 is 1.0
# Action of step 1794 is 1.0
# Action of step 1795 is 1.0
# Action of step 1796 is 1.0
# Action of step 1797 is 1.0
# Action of step 1798 is 1.0
# Action of step 1799 is 1.0
# Action of step 1800 is 1.0
# Action of step 1801 is 1.0
# Action of step 1802 is 1.0
# Action of step 1803 is 1.0
# Action of step 1804 is 1.0
# Action of step 1805 is 1.0
# Action of step 1806 is 1.0
# Action of step 1807 is 1.0
# Action of step 1808 is 1.0
# Action of step 1809 is 1.0
# Action of step 1810 is 1.0
# Action of step 1811 is 1.0
# Action of step 1812 is 1.0
# Action of step 1813 is 1.0
# Action of step 1814 is 1.0
# Action of step 1815 is 1.0
# Action of step 1816 is 1.0
# Action of step 1817 is 1.0
# Action of step 1818 is 1.0
# Action of step 1819 is 1.0
# Action of step 1820 is 1.0
# Action of step 1821 is 1.0
# Action of step 1822 is 1.0
# Action of step 1823 is 1.0
# Action of step 1824 is 1.0
# Action of step 1825 is 1.0
# Action of step 1826 is 1.0
# Action of step 1827 is 1.0
# Action of step 1828 is 1.0
# Action of step 1829 is 1.0
# Action of step 1830 is 1.0
# Action of step 1831 is 1.0
# Action of step 1832 is 1.0
# Action of step 1833 is 1.0
# Action of step 1834 is 1.0
# Action of step 1835 is 1.0
# Action of step 1836 is 1.0
# Action of step 1837 is 1.0
# Action of step 1838 is 1.0
# Action of step 1839 is 1.0
# Action of step 1840 is 1.0
# Action of step 1841 is 1.0
# Action of step 1842 is 1.0
# Action of step 1843 is 1.0
# Action of step 1844 is 1.0
# Action of step 1845 is 1.0
# Action of step 1846 is 1.0
# Action of step 1847 is 1.0
# Action of step 1848 is 1.0
# Action of step 1849 is 1.0
# Action of step 1850 is 1.0
# Action of step 1851 is 1.0
# Action of step 1852 is 1.0
# Action of step 1853 is 1.0
# Action of step 1854 is 1.0
# Action of step 1855 is 1.0
# Action of step 1856 is 1.0
# Action of step 1857 is 1.0
# Action of step 1858 is 1.0
# Action of step 1859 is 1.0
# Action of step 1860 is 1.0
# Action of step 1861 is 1.0
# Action of step 1862 is 1.0
# Action of step 1863 is 1.0
# Action of step 1864 is 1.0
# Action of step 1865 is 1.0
# Action of step 1866 is 1.0
# Action of step 1867 is 1.0
# Action of step 1868 is 1.0
# Action of step 1869 is 1.0
# Action of step 1870 is 1.0
# Action of step 1871 is 1.0
# Action of step 1872 is 1.0
# Action of step 1873 is 1.0
# Action of step 1874 is 1.0
# Action of step 1875 is 1.0
# Action of step 1876 is 1.0
# Action of step 1877 is 1.0
# Action of step 1878 is 1.0
# Action of step 1879 is 1.0
# Action of step 1880 is 1.0
# Action of step 1881 is 1.0
# Action of step 1882 is 1.0
# Action of step 1883 is 1.0
# Action of step 1884 is 1.0
# Action of step 1885 is 1.0
# Action of step 1886 is 1.0
# Action of step 1887 is 1.0
# Action of step 1888 is 1.0
# Action of step 1889 is 1.0
# Action of step 1890 is 1.0
# Action of step 1891 is 1.0
# Action of step 1892 is 1.0
# Action of step 1893 is 1.0
# Action of step 1894 is 1.0
# Action of step 1895 is 1.0
# Action of step 1896 is 1.0
# Action of step 1897 is 1.0
# Action of step 1898 is 1.0
# Action of step 1899 is 1.0
# Action of step 1900 is 1.0
# Action of step 1901 is 1.0
# Action of step 1902 is 1.0
# Action of step 1903 is 1.0
# Action of step 1904 is 1.0
# Action of step 1905 is 1.0
# Action of step 1906 is 1.0
# Action of step 1907 is 1.0
# Action of step 1908 is 1.0
# Action of step 1909 is 1.0
# Action of step 1910 is 1.0
# Action of step 1911 is 1.0
# Action of step 1912 is 1.0
# Action of step 1913 is 1.0
# Action of step 1914 is 1.0
# Action of step 1915 is 1.0
# Action of step 1916 is 1.0
# Action of step 1917 is 1.0
# Action of step 1918 is 1.0
# Action of step 1919 is 1.0
# Action of step 1920 is 1.0
# Action of step 1921 is 1.0
# Action of step 1922 is 1.0
# Action of step 1923 is 1.0
# Action of step 1924 is 1.0
# Action of step 1925 is 1.0
# Action of step 1926 is 1.0
# Action of step 1927 is 1.0
# Action of step 1928 is 1.0
# Action of step 1929 is 1.0
# Action of step 1930 is 1.0
# Action of step 1931 is 1.0
# Action of step 1932 is 1.0
# Action of step 1933 is 1.0
# Action of step 1934 is 1.0
# Action of step 1935 is 1.0
# Action of step 1936 is 1.0
# Action of step 1937 is 1.0
# Action of step 1938 is 1.0
# Action of step 1939 is 1.0
# Action of step 1940 is 1.0
# Action of step 1941 is 1.0
# Action of step 1942 is 1.0
# Action of step 1943 is 1.0
# Action of step 1944 is 1.0
# Action of step 1945 is 1.0
# Action of step 1946 is 1.0
# Action of step 1947 is 1.0
# Action of step 1948 is 1.0
# Action of step 1949 is 1.0
# Action of step 1950 is 1.0
# Action of step 1951 is 1.0
# Action of step 1952 is 1.0
# Action of step 1953 is 1.0
# Action of step 1954 is 1.0
# Action of step 1955 is 1.0
# Action of step 1956 is 1.0
# Action of step 1957 is 1.0
# Action of step 1958 is 1.0
# Action of step 1959 is 1.0
# Action of step 1960 is 1.0
# Action of step 1961 is 1.0
# Action of step 1962 is 1.0
# Action of step 1963 is 1.0
# Action of step 1964 is 1.0
# Action of step 1965 is 1.0
# Action of step 1966 is 1.0
# Action of step 1967 is 1.0
# Action of step 1968 is 1.0
# Action of step 1969 is 1.0
# Action of step 1970 is 1.0
# Action of step 1971 is 1.0
# Action of step 1972 is 1.0
# Action of step 1973 is 1.0
# Action of step 1974 is 1.0
# Action of step 1975 is 1.0
# Action of step 1976 is 1.0
# Action of step 1977 is 1.0
# Action of step 1978 is 1.0
# Action of step 1979 is 1.0
# Action of step 1980 is 1.0
# Action of step 1981 is 1.0
# Action of step 1982 is 1.0
# Action of step 1983 is 1.0
# Action of step 1984 is 1.0
# Action of step 1985 is 1.0
# Action of step 1986 is 1.0
# Action of step 1987 is 1.0
# Action of step 1988 is 1.0
# Action of step 1989 is 1.0
# Action of step 1990 is 1.0
# Action of step 1991 is 1.0
# Action of step 1992 is 1.0
# Action of step 1993 is 1.0
# Action of step 1994 is 1.0
# Action of step 1995 is 1.0
# Action of step 1996 is 1.0
# Action of step 1997 is 1.0
# Action of step 1998 is 1.0
# Action of step 1999 is 1.0
# Action of step 2000 is 1.0
# Action of step 2001 is 1.0
# Action of step 2002 is 1.0
# Action of step 2003 is 1.0
# Action of step 2004 is 1.0
# Action of step 2005 is 1.0
# Action of step 2006 is 1.0
# Action of step 2007 is 1.0
# Action of step 2008 is 1.0
# Action of step 2009 is 1.0
# Action of step 2010 is 1.0
# Action of step 2011 is 1.0
# Action of step 2012 is 1.0
# Action of step 2013 is 1.0
# Action of step 2014 is 1.0
# Action of step 2015 is 1.0
# Action of step 2016 is 1.0
# Action of step 2017 is 1.0
# Action of step 2018 is 1.0
# Action of step 2019 is 1.0
# Action of step 2020 is 1.0
# Action of step 2021 is 1.0
# Action of step 2022 is 1.0
# Action of step 2023 is 1.0
# Action of step 2024 is 1.0
# Action of step 2025 is 1.0
# Action of step 2026 is 1.0
# Action of step 2027 is 1.0
# Action of step 2028 is 1.0
# Action of step 2029 is 1.0
# Action of step 2030 is 1.0
# Action of step 2031 is 1.0
# Action of step 2032 is 1.0
# Action of step 2033 is 1.0
# Action of step 2034 is 1.0
# Action of step 2035 is 1.0
# Action of step 2036 is 1.0
# Action of step 2037 is 1.0
# Action of step 2038 is 1.0
# Action of step 2039 is 1.0
# Action of step 2040 is 1.0
# Action of step 2041 is 1.0
# Action of step 2042 is 1.0
# Action of step 2043 is 1.0
# Action of step 2044 is 1.0
# Action of step 2045 is 1.0
# Action of step 2046 is 1.0
# Action of step 2047 is 1.0
# Action of step 2048 is 1.0
# Action of step 2049 is 1.0
# Action of step 2050 is 1.0
# Action of step 2051 is 1.0
# Action of step 2052 is 1.0
# Action of step 2053 is 1.0
# Action of step 2054 is 1.0
# Action of step 2055 is 1.0
# Action of step 2056 is 1.0
# Action of step 2057 is 1.0
# Action of step 2058 is 1.0
# Action of step 2059 is 1.0
# Action of step 2060 is 1.0
# Action of step 2061 is 1.0
# Action of step 2062 is 1.0
# Action of step 2063 is 1.0
# Action of step 2064 is 1.0
# Action of step 2065 is 1.0
# Action of step 2066 is 1.0
# Action of step 2067 is 1.0
# Action of step 2068 is 1.0
# Action of step 2069 is 1.0
# Action of step 2070 is 1.0
# Action of step 2071 is 1.0
# Action of step 2072 is 1.0
# Action of step 2073 is 1.0
# Action of step 2074 is 1.0
# Action of step 2075 is 1.0
# Action of step 2076 is 1.0
# Action of step 2077 is 1.0
# Action of step 2078 is 1.0
# Action of step 2079 is 1.0
# Action of step 2080 is 1.0
# Action of step 2081 is 1.0
# Action of step 2082 is 1.0
# Action of step 2083 is 1.0
# Action of step 2084 is 1.0
# Action of step 2085 is 1.0
# Action of step 2086 is 1.0
# Action of step 2087 is 1.0
# Action of step 2088 is 1.0
# Action of step 2089 is 1.0
# Action of step 2090 is 1.0
# Action of step 2091 is 1.0
# Action of step 2092 is 1.0
# Action of step 2093 is 1.0
# Action of step 2094 is 1.0
# Action of step 2095 is 1.0
# Action of step 2096 is 1.0
# Action of step 2097 is 1.0
# Action of step 2098 is 1.0
# Action of step 2099 is 1.0
# Action of step 2100 is 1.0
# Action of step 2101 is 1.0
# Action of step 2102 is 1.0
# Action of step 2103 is 1.0
# Action of step 2104 is 1.0
# Action of step 2105 is 1.0
# Action of step 2106 is 1.0
# Action of step 2107 is 1.0
# Action of step 2108 is 1.0
# Action of step 2109 is 1.0
# Action of step 2110 is 1.0
# Action of step 2111 is 1.0
# Action of step 2112 is 1.0
# Action of step 2113 is 1.0
# Action of step 2114 is 1.0
# Action of step 2115 is 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[633], line 1
# ----> 1 trained_sac = agent_sac.train_model(model=model_sac,
#       2                              tb_log_name='sac',
#       3                              total_timesteps=total_training_step)
#       5 # trained_sac = agent_sac.train_model(model=trained_sac,
#       6 #                              tb_log_name='sac',
#       7 #                              total_timesteps=total_training_step)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/finrl/agents/stablebaselines3/models.py:117, in DRLAgent.train_model(model, tb_log_name, total_timesteps)
#     113 @staticmethod
#     114 def train_model(
#     115     model, tb_log_name, total_timesteps=5000
#     116 ):  # this function is static method, so it can be called without creating an instance of the class
# --> 117     model = model.learn(
#     118         total_timesteps=total_timesteps,
#     119         tb_log_name=tb_log_name,
#     120         callback=TensorboardCallback(),
#     121     )
#     122     return model
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:261, in SAC.train(self, gradient_steps, batch_size)
#     258 current_q_values = self.critic(replay_data.observations, replay_data.actions)
#     260 # Compute critic loss
# --> 261 critic_loss = 0.5 * sum(F.mse_loss(current_q, target_q_values) for current_q in current_q_values)
#     262 assert isinstance(critic_loss, th.Tensor)  # for type checker
#     263 critic_losses.append(critic_loss.item())  # type: ignore[union-attr]
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:261, in <genexpr>(.0)
#     258 current_q_values = self.critic(replay_data.observations, replay_data.actions)
#     260 # Compute critic loss
# --> 261 critic_loss = 0.5 * sum(F.mse_loss(current_q, target_q_values) for current_q in current_q_values)
#     262 assert isinstance(critic_loss, th.Tensor)  # for type checker
#     263 critic_losses.append(critic_loss.item())  # type: ignore[union-attr]
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/torch/nn/functional.py:3338, in mse_loss(input, target, size_average, reduce, reduction)
#    3335 if size_average is not None or reduce is not None:
#    3336     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3338 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3339 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/torch/functional.py:76, in broadcast_tensors(*tensors)
#      74 if has_torch_function(tensors):
#      75     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 76 return _VF.broadcast_tensors(tensors)
#
# File ~/opt/anaconda3/envs/fin_rl_env/lib/python3.10/site-packages/torch/_VF.py:27, in VFModule.__getattr__(self, attr)
#      26 def __getattr__(self, attr):
# ---> 27     return getattr(self.vf, attr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model 4: TD3

# %%
# agent_td3 = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100, 
#               "buffer_size": 1000000, 
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3, 
#                              tb_log_name='td3',
#                              total_timesteps=10000)

# %% [markdown]
# ### Model 5: A2C

# %%
# agent_a2c = DRLAgent(env = env_train)

# A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
# model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)

# %%
# trained_a2c = agent.train_model(model=model_a2c, 
#                                 tb_log_name='a2c',
#                                 total_timesteps=10000)

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at the begining. We use the PPO model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2018-12 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
trade_data = trade_data.reset_index(drop=True)

# %%
# trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = trade_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
# df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
#     model=trained_ppo, 
#     environment = e_trade_gym)

# df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
#     model=trained_ddpg, 
#     environment = e_trade_gym)

df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)

# df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
#     model=trained_a2c, 
#     environment = e_trade_gym) if if_using_a2c else [None, None]

# df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
#     model=trained_td3, 
#     environment = e_trade_gym) if if_using_td3 else [None, None]
# Out:
# hit end!

# %%
# df_account_value_ppo.shape
# df_account_value_ddpg.shape
df_account_value_sac.shape
# df_account_value_td3.shape
# df_account_value_a2c.shape
# Out:
# (2114, 2)

# %%
df_account_value_sac['date'] = trade_data.date

# %%
# df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
df_account_value_sac.tail()
# df_account_value_td3.tail()
# df_account_value_a2c.tail()
# Out:
#            date  account_value
# 2109 2024-03-12   1.311546e+06
# 2110 2024-03-13   1.308936e+06
# 2111 2024-03-13   1.308936e+06
# 2112 2024-03-14   1.287816e+06
# 2113 2024-03-14   1.287816e+06

# %%
# df_actions_ppo.head()
# df_actions_ddpg.head()
df_actions_sac.head()
# df_actions_td3.head()
# df_actions_a2c.head()
# Out:
#    date actions
# 0     0   [1.0]
# 1     1   [1.0]
# 2     2   [1.0]
# 3     3   [1.0]
# 4     4   [1.0]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_account_value = pd.DataFrame(df_account_value_sac.date.unique())
df_account_value.columns = ['date']
df_account_value['account_value'] = df_account_value.apply(lambda x: \
                                    df_account_value_sac[df_account_value_sac.date == x.date].iloc[-1].account_value, axis=1)
df_account_value.head()
# Out:
#         date  account_value
# 0 2020-01-02  999000.087481
# 1 2020-01-03  992211.821459
# 2 2020-01-06  999832.969347
# 3 2020-01-07  990420.919054
# 4 2020-01-08  991170.737231

# %% [markdown]
# There's a missmatch between the quarterly computation of df_account_value and the daily frequency of the comparison datasets. We need to transform the df_account_value to a daily basis.
# To fill up the missing data, th **ffill** function effectively imputes values, providing the continous picture of account value trends until the next recorded change. However, for the entries preceding the first recorded change, we will use the **initial_amount**.

# %%
daily_account_value = pd.DataFrame(df.date.unique())
daily_account_value.columns = ['date']
daily_account_value['date'] = pd.to_datetime(daily_account_value.date)
daily_account_value = daily_account_value.merge(df_account_value,how='left')
daily_account_value.ffill(inplace=True)
daily_account_value.fillna(env_kwargs["initial_amount"],inplace=True)
daily_account_value = daily_account_value[daily_account_value.date >= TEST_START_DATE]
daily_account_value.reset_index(inplace=True,drop=True)
daily_account_value
# Out:
#            date  account_value
# 0    2020-01-02   9.990001e+05
# 1    2020-01-03   9.922118e+05
# 2    2020-01-06   9.998330e+05
# 3    2020-01-07   9.904209e+05
# 4    2020-01-08   9.911707e+05
# ...         ...            ...
# 1053 2024-03-11   1.305946e+06
# 1054 2024-03-12   1.311546e+06
# 1055 2024-03-13   1.308936e+06
# 1056 2024-03-14   1.287816e+06
# 1057 2024-03-15   1.287816e+06
#
# [1058 rows x 2 columns]

# %%
print("==============Get Backtest Results===========")
# now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

# print("\n ppo:")
# perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
# perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
# perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

# print("\n ddpg:")
# perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
# perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
# perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

print("\n sac:")
perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
#   perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')

#   print("\n atd3:")
#   perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
#   perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
#   perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

#   print("\n a2c:")
#   perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
#   perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
#   perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  sac:
# Annual return          0.030612
# Cumulative returns     0.287816
# Annual volatility      0.185525
# Sharpe ratio           0.254800
# Calmar ratio           0.123053
# Stability              0.566103
# Max drawdown          -0.248771
# Omega ratio            1.069030
# Sortino ratio          0.385087
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.112145
# Daily value at risk   -0.023186
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (1057, 8)
# Annual return          0.073728
# Cumulative returns     0.347672
# Annual volatility      0.220586
# Sharpe ratio           0.433766
# Calmar ratio           0.198801
# Stability              0.510630
# Max drawdown          -0.370862
# Omega ratio            1.092403
# Sortino ratio          0.602529
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.988535
# Daily value at risk   -0.027411
# dtype: float64

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTest with DJIA

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

backtest_plot(daily_account_value, 
            baseline_ticker = '^DJI', 
            baseline_start = TEST_START_DATE,
            baseline_end = TEST_END_DATE)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ==============Compare to DJIA===========
# Shape of DataFrame:  (1057, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2024-03-15</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>50</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.235%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>28.911%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.234%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.877%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.268%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.68</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24.88</td>
#       <td>2022-11-08</td>
#       <td>2023-06-01</td>
#       <td>2023-10-11</td>
#       <td>242</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>24.09</td>
#       <td>2020-01-15</td>
#       <td>2020-03-12</td>
#       <td>2020-04-27</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21.48</td>
#       <td>2021-04-20</td>
#       <td>2021-11-30</td>
#       <td>2022-04-07</td>
#       <td>253</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.54</td>
#       <td>2020-07-20</td>
#       <td>2020-10-28</td>
#       <td>2021-01-26</td>
#       <td>137</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>15.69</td>
#       <td>2024-02-01</td>
#       <td>2024-03-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compare to Buy&Hold Strategy
# pass in df_account_value, this information is stored in env class

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTest with Buy&Hold Strategy

# %%
# print(DOW_30_TICKER)
test_portfolio = DOW_30_TICKER[:2]
len(test_portfolio)
# Out:
# 2

# %%
modify_fields = ['open','high','low','close']
used_columns = ['date','close']

# %%
# df_stock_test_ = get_baseline(
#         ticker='AXP', 
#         start = TEST_START_DATE,
#         end = TEST_END_DATE)
# df_stock_test_

# %%
# for field in modify_fields:
#     df_stock_test_[field] = df_stock_test_[field]/df_stock_test_.iloc[0][field]/len(test_portfolio)
# df_stock_test_ = df_stock_test_[used_columns]

# %%
daily_account_value.shape
# Out:
# (1058, 2)

# %%
#baseline stats
print("==============Get Baseline Stats===========")
shape = daily_account_value.shape
df_hold_ = pd.DataFrame(0,index=range(shape[0]), columns=range(shape[1]))
df_hold_.columns = used_columns
df_hold_['date'] = daily_account_value.date

for stock in test_portfolio:
    df_stock_ = get_baseline(
        ticker=stock, 
        start = TEST_START_DATE,
        end = TEST_END_DATE)
    # for field in modify_fields:
    if len(df_stock_) < len(df_hold_):
        final_row = df_stock_.iloc[-1]
        new_rows = pd.DataFrame([final_row] * (len(df_hold_) - len(df_stock_)))
        df_stock_ = pd.concat([df_stock_, new_rows], ignore_index=True)
        
        for i in range(0,len(df_stock_) < len(df_hold_)):
            df_stock_.iloc[en(df_stock_)] = df_stock_.iloc[len(df_stock_-1)]
    df_stock_['close'] = df_stock_['close']/df_stock_.iloc[0]['close']/len(test_portfolio)
    df_hold_['close'] = df_hold_.close + df_stock_.close

stats = backtest_stats(df_hold_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (1057, 8)
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (1057, 8)
# Annual return          0.113655
# Cumulative returns     0.571369
# Annual volatility      0.272331
# Sharpe ratio           0.530754
# Calmar ratio           0.322387
# Stability              0.732961
# Max drawdown          -0.352541
# Omega ratio            1.105579
# Sortino ratio          0.796600
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.051676
# Daily value at risk   -0.033737
# dtype: float64

# %%
df_hold_
# Out:
#            date     close
# 0    2020-01-02  1.000000
# 1    2020-01-03  0.991639
# 2    2020-01-06  0.993305
# 3    2020-01-07  0.986016
# 4    2020-01-08  0.994853
# ...         ...       ...
# 1053 2024-03-11  1.579257
# 1054 2024-03-12  1.592401
# 1055 2024-03-13  1.591768
# 1056 2024-03-14  1.571369
# 1057 2024-03-15  1.571369
#
# [1058 rows x 2 columns]

# %% [markdown]
# The model' calculation encompass the entire timeframe, including non-working days. To address this, we need to determine the most appropriate method to fill up the weekend plots, for example backfilling.

# %%
# df_hold_.date = pd.to_datetime(df_hold_['date'])
# df_hold_ = pd.merge(df_account_value_ppo['date'],df_hold_,how='left')
# df_hold_.bfill(inplace=True)
# df_hold_

# %%
df_hold = pd.DataFrame()
df_hold['date'] = daily_account_value['date']
df_hold['hold'] = df_hold_['close'] / df_hold_['close'][0] * env_kwargs["initial_amount"]
# print("df_hold: ", df_hold)
# df_dji.to_csv("df_dji.csv")
df_hold = df_hold.set_index(df_hold.columns[0])
print("df_hold: ", df_hold)
# df_hold.to_csv("df_dji+.csv")

# df_account_value.to_csv('df_account_value.csv')
# Out:
# df_hold:                      hold
# date
# 2020-01-02  1.000000e+06
# 2020-01-03  9.916394e+05
# 2020-01-06  9.933049e+05
# 2020-01-07  9.860160e+05
# 2020-01-08  9.948532e+05
# ...                  ...
# 2024-03-11  1.579257e+06
# 2024-03-12  1.592401e+06
# 2024-03-13  1.591768e+06
# 2024-03-14  1.571369e+06
# 2024-03-15  1.571369e+06
#
# [1058 rows x 1 columns]

# %%
print("==============Compare to Buy&Hold===========")
df_result = pd.DataFrame({'date': df_account_value_sac['date'], 'stock': df_account_value_sac['account_value']})
df_result = df_result.set_index('date')

result = pd.DataFrame()
result = pd.merge(df_result, df_hold, left_index=True, right_index=True)
print("result: ", result)
# result.to_csv("result.csv")
result.columns = ['model', 'buy_and_hold']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# ==============Compare to Buy&Hold===========
# result:                     stock          hold
# date
# 2020-01-02  1.000000e+06  1.000000e+06
# 2020-01-02  9.990001e+05  1.000000e+06
# 2020-01-03  9.922118e+05  9.916394e+05
# 2020-01-03  9.922118e+05  9.916394e+05
# 2020-01-06  9.998330e+05  9.933049e+05
# ...                  ...           ...
# 2024-03-12  1.311546e+06  1.592401e+06
# 2024-03-13  1.308936e+06  1.591768e+06
# 2024-03-13  1.308936e+06  1.591768e+06
# 2024-03-14  1.287816e+06  1.571369e+06
# 2024-03-14  1.287816e+06  1.571369e+06
#
# [2114 rows x 2 columns]

# %% [markdown]
# <a id='7'></a>
# # 8. Save and load model #

# %% [markdown]
# <a id='7.1'></a>
# ## 8.1 Save model

# %% [markdown]
# ### 8.1.1 Save trained model

# %%
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/DeepReinforcementLearning/FinRL-Tutorials-master/6-Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/sac_model_300k_sac9"
model_name
# Out:
# './trained_models/sac_model_1200k_sac9'

# %%
trained_sac.save(model_name)

# %% [markdown]
# ### 8.1.2 Save model as ONNX file

# %%
import torch as th
import torch.onnx
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import DDPG
from stable_baselines3.common.policies import BasePolicy
from typing import Tuple

# %%
class OnnxableSB3Policy(th.nn.Module):
    def __init__(self, policy: BasePolicy):
        super().__init__()
        self.policy = policy

    def forward(self, observation: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
        # NOTE: Preprocessing is included, but postprocessing
        # (clipping/inscaling actions) is not,
        # If needed, you also need to transpose the images so that they are channel first
        # use deterministic=False if you want to export the stochastic policy
        # policy() returns `actions, values, log_prob` for PPO
        return self.policy(observation, deterministic=True)

# %%
onnx_policy = OnnxableSB3Policy(trained_sac.policy)
observation_size = trained_sac.observation_space.shape
dummy_input = th.randn(1, *observation_size)

th.onnx.export(
    onnx_policy,
    dummy_input,
    "sac_model_1200k_sac9.onnx",
    opset_version=17,
    input_names=["input"],
)

# %% [markdown]
# <a id='7.2'></a>
# ## 8.2 Load model

# %% [markdown]
# ### 8.2.1 Load trained model

# %%
from stable_baselines3 import SAC
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# /Users/admin/Desktop/GameProjects/DataScience/DeepReinforcementLearning/FinRL-Tutorials-master/6-Binhlai_Testing

# %%
model_name = "./"+TRAINED_MODEL_DIR+"/sac_model_1200k_sac9"
model_name
# Out:
# './trained_models/sac_model_1200k_sac9'

# %%
trained_model = SAC.load(model_name)

# %% [markdown]
# Continous training based on the previous model

# %%
# Parameters for the environment
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "tech_indicator_list": ratio_list, 
    "action_space": action_dimension, 
    "reward_scaling": 1e-4,
    "stop_loss": 0.3
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()

# %%
agent_sac = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

# %%
episode_length = len(e_train_gym.df) + 1
episode_amount = 8
total_training_step = episode_length*episode_amount
trained_model.env = env_train

# %%
trained_sac = agent_sac.train_model(model=trained_model, 
                             tb_log_name='sac',
                             total_timesteps=total_training_step)
# Out:
# Logging to tensorboard_log/test_sac/sac_11
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 60        |
# |    time_elapsed    | 1457      |
# |    total_timesteps | 87928     |
# | train/             |           |
# |    actor_loss      | 2.92e+08  |
# |    critic_loss     | 1.66e+16  |
# |    ent_coef        | 2.06e+07  |
# |    ent_coef_loss   | -9.83     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1298402   |
# |    reward          | 0.7721382 |
# ----------------------------------
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 55             |
# |    time_elapsed    | 3167           |
# |    total_timesteps | 175856         |
# | train/             |                |
# |    actor_loss      | -9.5e+09       |
# |    critic_loss     | 7.87e+19       |
# |    ent_coef        | 5.35e+05       |
# |    ent_coef_loss   | 15.5           |
# |    learning_rate   | 0.0003         |
# |    n_updates       | 1386330        |
# |    reward          | -0.00043655798 |
# ---------------------------------------

# %% [markdown]
# #### Test loaded model

# %%
test_env = StockTradingEnv(df = trade_data, **env_kwargs)

# %%
test_step = 1000
test_result = []
test_env.reset()
for i in range(0,test_step):
    observation = [test_env.state]
    observation = np.array(observation).astype(np.float32)
    actions, values, log_prob = ort_sess.run(None, {"input": observation})
    result = test_env.step(actions)
    test_result.append(result[1])
    if result[2] == True:
        break

# %% [markdown]
# ### 8.2.2 Load ONNX model

# %%
import onnx
import onnxruntime as ort
import numpy as np

# %%
onnx_path = "all_in_one_ppo.onnx"
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)

# # Check that the predictions are the same
# with th.no_grad():
#     print(model.policy(th.as_tensor(observation), deterministic=True))

# %%
observation = np.zeros((1, state_space)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
actions, values, log_prob = ort_sess.run(None, {"input": observation})
print(actions, values, log_prob)
